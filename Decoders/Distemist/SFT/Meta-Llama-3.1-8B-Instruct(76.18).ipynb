# %% [markdown]
# # Pipeline QLoRA NER — DisTemIST con Meta-Llama-3.1-8B-Instruct
#
# Flujo completo de fine-tuning generativo para reconocimiento de enfermedades en textos clínicos en español.
# Cubre configuración, entrenamiento con SFT, inferencia por oraciones y evaluación.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Adaptadores LoRA](#4-adaptadores-lora)
# 5. [Dataset](#5-dataset)
# 6. [Entrenamiento](#6-entrenamiento)
# 7. [Preparación para inferencia](#7-preparacion-para-inferencia)
# 8. [Inferencia](#8-inferencia)
# 9. [Evaluación](#9-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install peft accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit"

# ── LoRA ──────────────────────────────────────────────────────────────────────
LORA_R         = 64
LORA_ALPHA     = 128
LORA_DROPOUT   = 0
MAX_SEQ_LENGTH = 4096

# ── Entrenamiento ─────────────────────────────────────────────────────────────
BATCH_SIZE       = 1
GRAD_ACCUM       = 32
LEARNING_RATE    = 3e-5
NUM_TRAIN_EPOCHS = 2
WARMUP_RATIO     = 0.05
WEIGHT_DECAY     = 0.01
MAX_GRAD_NORM    = 0.3
TRAIN_SEED       = 3407
OUTPUT_DIR       = "outputs_lora"

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS      = None   # None para oraciones sueltas
SPACY_MODEL          = "es_core_news_md"
MAX_NEGATIVE_RATIO   = None   # Ej: 0.5 => 1 negativo por cada 2 positivos
NEGATIVE_SAMPLE_SEED = 3407

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo ENFERMEDAD.\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'neoplasia', no escribas 'cancer'.\n"
    "4. REPETICIONES: Si una enfermedad aparece varias veces en el texto, debes listarla varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio (como '-', '*', '•', '1.').\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
DISTEMIST_ROOT       = f"{PROJECT_ROOT}/distemist/distemist"
TEXT_FILES_TRAIN_DIR = f"{DISTEMIST_ROOT}/text_files_train"
TEXT_FILES_TEST_DIR  = f"{DISTEMIST_ROOT}/text_files_test"
GS_TRAIN_TSV         = f"{DISTEMIST_ROOT}/distemist_subtrack1_training_mentions.tsv"
GS_TEST_TSV          = f"{DISTEMIST_ROOT}/distemist_subtrack1_test_mentions.tsv"
PREDICTIONS_TSV      = "distemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"LoRA r={LORA_R}, alpha={LORA_ALPHA}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"Epochs             : {NUM_TRAIN_EPOCHS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
print(f"MAX_NEGATIVE_RATIO : {MAX_NEGATIVE_RATIO}")
# Out:
# Modelo base        : unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit
# LoRA r=64, alpha=128
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# Epochs             : 2
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250
# MAX_NEGATIVE_RATIO : None

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# Unsloth: Will load unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit as a legacy tokenizer.
# Modelo cargado: unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit
# Parámetros totales: 4,540,600,320

# %% [markdown]
# ## 4. Adaptadores LoRA
#
# Inyección de adaptadores LoRA sobre todas las proyecciones lineales del modelo.

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r              = LORA_R,
    lora_alpha     = LORA_ALPHA,
    target_modules = "all-linear",
    lora_dropout   = LORA_DROPOUT,
    bias           = "none",
    task_type      = "CAUSAL_LM",
)

model = get_peft_model(model, lora_config)
model.config.use_cache = False

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total     = sum(p.numel() for p in model.parameters())
print(f"Parámetros entrenables: {trainable:,}  ({100*trainable/total:.2f}%)")
model.print_trainable_parameters()
# Out:
# Parámetros entrenables: 167,772,160  (3.56%)
# trainable params: 167,772,160 || all params: 8,198,033,408 || trainable%: 2.0465

# %% [markdown]
# ## 5. Dataset
#
# Segmentación por oraciones, construcción de prompts y ensamblado del dataset de entrenamiento.

# %%
import random
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from datasets import Dataset

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    """Divide el texto en chunks de oraciones completas con sus offsets.
    Si max_chars es None, devuelve una oración por chunk."""
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


def mentions_in_chunk(spans_with_offsets, chunk_start, chunk_end):
    return [span for span, off0, off1 in spans_with_offsets if chunk_start <= off0 < chunk_end]


def build_training_example(text, mentions):
    messages = [
        {"role": "system",    "content": SYSTEM_PROMPT},
        {"role": "user",      "content": f"Texto para analizar:\n{text}"},
        {"role": "assistant", "content": "\n".join(mentions) if mentions else ""},
    ]
    return tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=False)


df_gs = pd.read_csv(GS_TRAIN_TSV, sep="\t").sort_values(["filename", "off0"])
text_dir = Path(TEXT_FILES_TRAIN_DIR)

positive_texts, negative_texts = [], []
for doc_id, group in df_gs.groupby("filename", sort=False):
    txt_path = text_dir / f"{doc_id}.txt"
    if not txt_path.exists():
        continue
    text = txt_path.read_text(encoding="utf-8")
    spans = list(zip(group["span"], group["off0"], group["off1"]))
    chunks = chunk_text_by_sentences(text, nlp_spacy)
    changed = True
    while changed:
        changed = False
        for i in range(len(chunks) - 1):
            _, cs, ce = chunks[i]
            _, ns, ne = chunks[i + 1]
            for _, off0, off1 in spans:
                if cs <= off0 < ce and off1 > ce:
                    chunks[i] = (text[cs:ne], cs, ne)
                    chunks.pop(i + 1)
                    changed = True
                    break
            if changed:
                break
    for chunk_text, char_start, char_end in chunks:
        mentions = mentions_in_chunk(spans, char_start, char_end)
        example  = build_training_example(chunk_text, mentions)
        (positive_texts if mentions else negative_texts).append(example)

if MAX_NEGATIVE_RATIO is None:
    negative_texts_used = negative_texts
else:
    max_neg = max(0, int(len(positive_texts) * MAX_NEGATIVE_RATIO))
    negative_texts_used = (
        random.Random(NEGATIVE_SAMPLE_SEED).sample(negative_texts, k=max_neg)
        if max_neg < len(negative_texts) else negative_texts
    )

formatted_texts = positive_texts + negative_texts_used
dataset = Dataset.from_dict({"text": formatted_texts})

lengths   = [len(tokenizer.encode(t)) for t in formatted_texts]
truncados = sum(1 for l in lengths if l > MAX_SEQ_LENGTH)

print(f"Dataset: {len(dataset)} chunks (max_chars={MAX_CHUNK_CHARS})")
print(f"Positivos: {len(positive_texts)} | Negativos usados: {len(negative_texts_used)} / {len(negative_texts)} (ratio={MAX_NEGATIVE_RATIO})")
print(f"Tokens — min:{min(lengths)}  max:{max(lengths)}  media:{np.mean(lengths):.0f}  p95:{np.percentile(lengths,95):.0f}")
print(f"Truncados (>{MAX_SEQ_LENGTH}): {truncados} ({100*truncados/len(lengths):.1f}%)")
print(f"Menciones totales GS: {len(df_gs)}")
# Out:
# spaCy: core_news_md v3.8.0
# Dataset: 11711 chunks (max_chars=None)
# Positivos: 5185 | Negativos usados: 6526 / 6526 (ratio=None)
# Tokens — min:245  max:588  media:292  p95:351
# Truncados (>4096): 0 (0.0%)
# Menciones totales GS: 8065

# %% [markdown]
# ## 6. Entrenamiento
#
# `SFTTrainer` con `DataCollatorForCompletionOnlyLM` para entrenar únicamente sobre las respuestas del asistente.

# %%
import gc
import torch
from trl import SFTTrainer, SFTConfig, DataCollatorForCompletionOnlyLM

os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"
os.environ["ACCELERATE_MIXED_PRECISION"] = "fp16"

tokenizer.padding_side = "right"

def filter_fn(examples):
    tokens = tokenizer(examples["text"], add_special_tokens=False)
    return [len(t) <= MAX_SEQ_LENGTH for t in tokens["input_ids"]]

def tokenize_fn(examples):
    return tokenizer(examples["text"], truncation=True, max_length=MAX_SEQ_LENGTH)

train_data = (
    dataset
    .filter(filter_fn, batched=True, num_proc=2)
    .map(tokenize_fn, batched=True, num_proc=2, remove_columns=["text"])
)
print(f"Train: {len(train_data)} ejemplos")

response_template_text = "<|start_header_id|>assistant<|end_header_id|>"
response_template_ids  = tokenizer.encode(response_template_text, add_special_tokens=False)

data_collator = DataCollatorForCompletionOnlyLM(
    response_template=response_template_ids,
    tokenizer=tokenizer,
)

trainer = SFTTrainer(
    model         = model,
    tokenizer     = tokenizer,
    train_dataset = train_data,
    data_collator = data_collator,
    args = SFTConfig(
        max_seq_length              = MAX_SEQ_LENGTH,
        packing                     = False,
        dataset_kwargs              = {"skip_prepare_dataset": True},
        per_device_train_batch_size = BATCH_SIZE,
        gradient_accumulation_steps = GRAD_ACCUM,
        num_train_epochs            = NUM_TRAIN_EPOCHS,
        warmup_ratio                = WARMUP_RATIO,
        learning_rate               = LEARNING_RATE,
        fp16                        = True,
        bf16                        = False,
        logging_steps               = 10,
        optim                       = "paged_adamw_8bit",
        weight_decay                = WEIGHT_DECAY,
        max_grad_norm               = MAX_GRAD_NORM,
        lr_scheduler_type           = "linear",
        seed                        = TRAIN_SEED,
        output_dir                  = OUTPUT_DIR,
        report_to                   = "none",
        remove_unused_columns       = False,
        ddp_find_unused_parameters  = False,
        gradient_checkpointing      = True,
        eval_strategy               = "no",
        save_strategy               = "no",
    ),
)

trainer_stats = trainer.train()

for i in range(torch.cuda.device_count()):
    used  = round(torch.cuda.max_memory_reserved(i) / 1024**3, 3)
    total = round(torch.cuda.get_device_properties(i).total_memory / 1024**3, 1)
    print(f"GPU {i}: VRAM pico = {used} GB / {total} GB ({100*used/total:.1f}%)")

print(f"Tiempo : {trainer_stats.metrics['train_runtime']:.0f} s  ({trainer_stats.metrics['train_runtime']/60:.1f} min)")
print(f"Loss   : {trainer_stats.metrics.get('train_loss', 'N/A'):.4f}")
# Out:
# Filter (num_proc=2):   0%|          | 0/11711 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/11711 [00:00<?, ? examples/s]
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Train: 11711 ejemplos
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 11,711 | Num Epochs = 2 | Total steps = 732
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 32
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 32 x 1) = 32
#  "-____-"     Trainable parameters = 167,772,160 of 8,198,033,408 (2.05% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
# Unsloth: Will smartly offload gradients to save VRAM!
# Unsloth: Double buffering enabled (parallel H2D + compute) for backward pass.
#     <div>
#
#       <progress value='732' max='732' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [732/732 10:59:32, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.171821</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.416447</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.267442</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.275806</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.221349</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.204508</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.218961</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.169717</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.172225</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.158578</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.168290</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.169529</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.151633</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.134499</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.154687</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.133852</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.161280</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.112848</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.141604</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.149641</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.126719</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.152374</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.122567</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.103630</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.122722</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.124517</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.128671</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.101295</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.134007</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.106857</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.101056</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.087102</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.113546</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.086623</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.119420</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.124830</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.082735</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.072811</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.068873</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.066960</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.062575</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.067709</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.061618</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.059636</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.059974</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.058014</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.043539</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.069268</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.044458</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.052468</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.057124</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.068236</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.056250</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.067389</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.080207</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.040316</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.058591</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.049591</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.065491</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.063378</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.068395</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.046926</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.063669</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.062243</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.066514</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.061769</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.056056</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.062524</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.045137</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.062380</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.057600</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.059357</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.080187</td>
#     </tr>
#   </tbody>
# </table><p>
# GPU 0: VRAM pico = 7.369 GB / 14.6 GB (50.5%)
# GPU 1: VRAM pico = 0.117 GB / 14.6 GB (0.8%)
# Tiempo : 39625 s  (660.4 min)
# Loss   : 0.1214

# %%
# ── Guardar adaptador LoRA ────────────────────────────────────────────────────
LORA_SAVE_DIR = "/kaggle/working/lora_adapter"
model.save_pretrained(LORA_SAVE_DIR)
tokenizer.save_pretrained(LORA_SAVE_DIR)
print(f"Adaptador guardado en {LORA_SAVE_DIR}")
# Out:
# Unsloth: Restored added_tokens_decoder metadata in /kaggle/working/lora_adapter/tokenizer_config.json.
# Adaptador guardado en /kaggle/working/lora_adapter

# %% [markdown]
# ## 7. Preparación para inferencia
#
# Liberación del trainer, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc, time, re, json, logging
import pandas as pd
from pathlib import Path
from transformers import pipeline

LORA_SAVE_DIR = "/kaggle/input/datasets/user/checkpoint/lora_adapter"

if "trainer" in dir():
    del trainer
    gc.collect()
    torch.cuda.empty_cache()
else:

    import torch
    from unsloth import FastLanguageModel
    from peft import PeftModel
    model_base, tokenizer = FastLanguageModel.from_pretrained(
        model_name     = MODEL_NAME,
        max_seq_length = MAX_SEQ_LENGTH,
        dtype          = torch.float16,
        load_in_4bit   = True,
        token          = hf_token,
    )
    if hasattr(tokenizer, "tokenizer"):
        tokenizer = tokenizer.tokenizer
    model = PeftModel.from_pretrained(model_base, LORA_SAVE_DIR)
    print(f"Adaptador cargado desde {LORA_SAVE_DIR}")

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)
model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

def build_ner_messages(text):
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": f"Texto para analizar:\n{text}"},
    ]

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")

# %% [markdown]
# ## 8. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.

# %%
import json 
import gc
import time
import re
from pathlib import Path
import pandas as pd
import torch

CHECKPOINT_INPUT = Path("/kaggle/input/datasets/user/checkpoint/inference_checkpoint.json")
CHECKPOINT_FILE = Path("/kaggle/working/inference_checkpoint.json")

if CHECKPOINT_INPUT.exists():
    with open(CHECKPOINT_INPUT) as f:
        ckpt = json.load(f)
    print(f"Retomando desde checkpoint inicial de Input: {len(ckpt['done_files'])} archivos ya procesados")
elif CHECKPOINT_FILE.exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    print(f"Retomando desde checkpoint de trabajo: {len(ckpt['done_files'])} archivos ya procesados")
else:
    ckpt = None

if ckpt:
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0 = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            result = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename": txt_path.stem,
            "mark":     f"T{mark_idx}",
            "label":    "ENFERMEDAD",
            "off0":     off0,
            "off1":     off1,
            "span":     span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "mark", "label", "off0", "off1", "span"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Retomando desde checkpoint inicial de Input: 239 archivos ya procesados
# [1/250] S0004-06142006000100010-1.txt — ya procesado, saltando
# [2/250] S0004-06142006000100014-1.txt — ya procesado, saltando
# [3/250] S0004-06142006000500002-2.txt — ya procesado, saltando
# [4/250] S0004-06142006000500002-3.txt — ya procesado, saltando
# [5/250] S0004-06142006000900015-1.txt — ya procesado, saltando
# [6/250] S0004-06142007000200017-1.txt — ya procesado, saltando
# [7/250] S0004-06142007000600012-1.txt — ya procesado, saltando
# [8/250] S0004-06142007000600014-1.txt — ya procesado, saltando
# [9/250] es-S0004-06142007000900010-1.txt — ya procesado, saltando
# [10/250] es-S0004-06142007000900012-1.txt — ya procesado, saltando
# [11/250] es-S0004-06142008000300011-1.txt — ya procesado, saltando
# [12/250] es-S0004-06142008000300012-1.txt — ya procesado, saltando
# [13/250] es-S0004-06142008000300013-1.txt — ya procesado, saltando
# [14/250] es-S0004-06142008000400011-2.txt — ya procesado, saltando
# [15/250] es-S0004-06142008000400013-1.txt — ya procesado, saltando
# [16/250] es-S0004-06142008000400016-1.txt — ya procesado, saltando
# [17/250] es-S0004-06142008000500009-1.txt — ya procesado, saltando
# [18/250] es-S0004-06142008000700003-1.txt — ya procesado, saltando
# [19/250] es-S0004-06142009000400011-1.txt — ya procesado, saltando
# [20/250] es-S0004-06142010000100015-1.txt — ya procesado, saltando
# [21/250] es-S0210-48062003000900009-1.txt — ya procesado, saltando
# [22/250] es-S0210-48062004000200011-1.txt — ya procesado, saltando
# [23/250] es-S0210-48062004000500009-1.txt — ya procesado, saltando
# [24/250] es-S0210-48062004000800009-1.txt — ya procesado, saltando
# [25/250] es-S0210-48062005000300014-1.txt — ya procesado, saltando
# [26/250] es-S0210-48062005000400012-1.txt — ya procesado, saltando
# [27/250] es-S0210-48062005000700012-1.txt — ya procesado, saltando
# [28/250] es-S0210-48062006000200018-1.txt — ya procesado, saltando
# [29/250] es-S0210-48062006000400012-1.txt — ya procesado, saltando
# [30/250] es-S0210-48062006000700012-1.txt — ya procesado, saltando
# [31/250] es-S0210-48062006000900012-2.txt — ya procesado, saltando
# [32/250] es-S0210-48062007000300014-1.txt — ya procesado, saltando
# [33/250] es-S0210-48062007000700014-1.txt — ya procesado, saltando
# [34/250] es-S0210-48062007001000004-1.txt — ya procesado, saltando
# [35/250] es-S0210-48062009000200019-1.txt — ya procesado, saltando
# [36/250] es-S0210-48062009000300013-1.txt — ya procesado, saltando
# [37/250] es-S0210-48062009000400015-2.txt — ya procesado, saltando
# [38/250] es-S0210-48062009000400020-1.txt — ya procesado, saltando
# [39/250] es-S0210-48062009000600012-1.txt — ya procesado, saltando
# [40/250] es-S0210-56912008000200007-1.txt — ya procesado, saltando
# [41/250] es-S0210-56912008000400007-3.txt — ya procesado, saltando
# [42/250] es-S0210-56912009000800006-3.txt — ya procesado, saltando
# [43/250] es-S0210-56912011000200009-1.txt — ya procesado, saltando
# [44/250] es-S0211-57352011000400009-1.txt — ya procesado, saltando
# [45/250] es-S0211-57352013000300011-1.txt — ya procesado, saltando
# [46/250] es-S0211-69952009000600023-1.txt — ya procesado, saltando
# [47/250] es-S0211-69952011000100019-1.txt — ya procesado, saltando
# [48/250] es-S0211-69952012000500025-1.txt — ya procesado, saltando
# [49/250] es-S0211-69952012000700028-1.txt — ya procesado, saltando
# [50/250] es-S0211-69952013000200018-1.txt — ya procesado, saltando
# [51/250] es-S0211-69952013000200019-2.txt — ya procesado, saltando
# [52/250] es-S0211-69952014000400019-1.txt — ya procesado, saltando
# [53/250] es-S0211-69952014000600016-1.txt — ya procesado, saltando
# [54/250] es-S0211-69952015000500015-2.txt — ya procesado, saltando
# [55/250] es-S0211-69952015000600014-2.txt — ya procesado, saltando
# [56/250] es-S0211-69952016000200176-1.txt — ya procesado, saltando
# [57/250] es-S0211-69952016000600552-1.txt — ya procesado, saltando
# [58/250] es-S0212-16112007000100015-1.txt — ya procesado, saltando
# [59/250] es-S0212-16112009000600018-1.txt — ya procesado, saltando
# [60/250] es-S0212-16112010000100017-1.txt — ya procesado, saltando
# [61/250] es-S0212-16112010000600024-1.txt — ya procesado, saltando
# [62/250] es-S0212-16112011000300031-1.txt — ya procesado, saltando
# [63/250] es-S0212-16112013000400053-1.txt — ya procesado, saltando
# [64/250] es-S0212-16112014000300032-1.txt — ya procesado, saltando
# [65/250] es-S0212-71992000001200006-1.txt — ya procesado, saltando
# [66/250] es-S0212-71992004000300009-1.txt — ya procesado, saltando
# [67/250] es-S0212-71992004001100006-1.txt — ya procesado, saltando
# [68/250] es-S0212-71992005000400007-1.txt — ya procesado, saltando
# [69/250] es-S0212-71992005000500009-1.txt — ya procesado, saltando
# [70/250] es-S0212-71992005000600008-1.txt — ya procesado, saltando
# [71/250] es-S0212-71992005001100007-1.txt — ya procesado, saltando
# [72/250] es-S0212-71992008000700009-1.txt — ya procesado, saltando
# [73/250] es-S0213-12852003000500002-1.txt — ya procesado, saltando
# [74/250] es-S0213-12852005000400003-1.txt — ya procesado, saltando
# [75/250] es-S0213-12852006000600002-1.txt — ya procesado, saltando
# [76/250] es-S0213-12852007000100002-1.txt — ya procesado, saltando
# [77/250] es-S0213-12852013000400006-1.txt — ya procesado, saltando
# [78/250] es-S0365-66912004000800009-1.txt — ya procesado, saltando
# [79/250] es-S0365-66912004000900009-1.txt — ya procesado, saltando
# [80/250] es-S0365-66912004001000008-1.txt — ya procesado, saltando
# [81/250] es-S0365-66912004001100012-1.txt — ya procesado, saltando
# [82/250] es-S0365-66912004001200010-2.txt — ya procesado, saltando
# [83/250] es-S0365-66912005001100009-1.txt — ya procesado, saltando
# [84/250] es-S0365-66912005001100009-2.txt — ya procesado, saltando
# [85/250] es-S0365-66912005001100010-2.txt — ya procesado, saltando
# [86/250] es-S0365-66912006000100008-1.txt — ya procesado, saltando
# [87/250] es-S0365-66912006000700009-1.txt — ya procesado, saltando
# [88/250] es-S0365-66912006000900010-1.txt — ya procesado, saltando
# [89/250] es-S0365-66912006001100006-4.txt — ya procesado, saltando
# [90/250] es-S0365-66912007000100009-1.txt — ya procesado, saltando
# [91/250] es-S0365-66912007000100010-1.txt — ya procesado, saltando
# [92/250] es-S0365-66912007000200009-1.txt — ya procesado, saltando
# [93/250] es-S0365-66912007000200011-1.txt — ya procesado, saltando
# [94/250] es-S0365-66912007000700011-1.txt — ya procesado, saltando
# [95/250] es-S0365-66912007000900010-1.txt — ya procesado, saltando
# [96/250] es-S0365-66912007000900011-1.txt — ya procesado, saltando
# [97/250] es-S0365-66912007000900016-1.txt — ya procesado, saltando
# [98/250] es-S0365-66912007001000008-1.txt — ya procesado, saltando
# [99/250] es-S0365-66912007001200009-1.txt — ya procesado, saltando
# [100/250] es-S0365-66912007001200011-1.txt — ya procesado, saltando
# [101/250] es-S0365-66912008000700010-1.txt — ya procesado, saltando
# [102/250] es-S0365-66912009000300009-1.txt — ya procesado, saltando
# [103/250] es-S0365-66912009001100005-3.txt — ya procesado, saltando
# [104/250] es-S0365-66912010000700004-1.txt — ya procesado, saltando
# [105/250] es-S0365-66912012000300005-1.txt — ya procesado, saltando
# [106/250] es-S0365-66912012000500003-1.txt — ya procesado, saltando
# [107/250] es-S0365-66912012000700004-1.txt — ya procesado, saltando
# [108/250] es-S0365-66912012000800005-1.txt — ya procesado, saltando
# [109/250] es-S0365-66912012001100004-5.txt — ya procesado, saltando
# [110/250] es-S0376-78922007000300006-3.txt — ya procesado, saltando
# [111/250] es-S0376-78922008000400008-1.txt — ya procesado, saltando
# [112/250] es-S0376-78922009000100005-1.txt — ya procesado, saltando
# [113/250] es-S0376-78922009000100014-1.txt — ya procesado, saltando
# [114/250] es-S0376-78922009000300005-1.txt — ya procesado, saltando
# [115/250] es-S0376-78922009000400002-2.txt — ya procesado, saltando
# [116/250] es-S0376-78922009000400010-3.txt — ya procesado, saltando
# [117/250] es-S0376-78922009000400011-1.txt — ya procesado, saltando
# [118/250] es-S0376-78922011000100010-1.txt — ya procesado, saltando
# [119/250] es-S0376-78922011000500012-1.txt — ya procesado, saltando
# [120/250] es-S0376-78922012000300010-1.txt — ya procesado, saltando
# [121/250] es-S0376-78922012000400009-1.txt — ya procesado, saltando
# [122/250] es-S0376-78922015000400012-1.txt — ya procesado, saltando
# [123/250] es-S0376-78922016000200011-1.txt — ya procesado, saltando
# [124/250] es-S0376-78922016000200012-1.txt — ya procesado, saltando
# [125/250] es-S0378-48352004001000003-1.txt — ya procesado, saltando
# [126/250] es-S0378-48352005000100005-2.txt — ya procesado, saltando
# [127/250] es-S0378-48352006000300005-1.txt — ya procesado, saltando
# [128/250] es-S1130-01082004001200010-1.txt — ya procesado, saltando
# [129/250] es-S1130-01082005001100016-1.txt — ya procesado, saltando
# [130/250] es-S1130-01082005001100017-2.txt — ya procesado, saltando
# [131/250] es-S1130-01082005001200011-1.txt — ya procesado, saltando
# [132/250] es-S1130-01082006000900014-1.txt — ya procesado, saltando
# [133/250] es-S1130-01082007000100009-1.txt — ya procesado, saltando
# [134/250] es-S1130-01082007000100013-1.txt — ya procesado, saltando
# [135/250] es-S1130-01082007000400010-1.txt — ya procesado, saltando
# [136/250] es-S1130-01082007000700011-1.txt — ya procesado, saltando
# [137/250] es-S1130-01082007001100009-1.txt — ya procesado, saltando
# [138/250] es-S1130-01082007001100010-1.txt — ya procesado, saltando
# [139/250] es-S1130-01082007001100010-2.txt — ya procesado, saltando
# [140/250] es-S1130-01082007001200014-1.txt — ya procesado, saltando
# [141/250] es-S1130-01082008000200010-1.txt — ya procesado, saltando
# [142/250] es-S1130-01082008000300010-1.txt — ya procesado, saltando
# [143/250] es-S1130-01082008000500008-1.txt — ya procesado, saltando
# [144/250] es-S1130-01082008000800009-1.txt — ya procesado, saltando
# [145/250] es-S1130-01082008000900011-1.txt — ya procesado, saltando
# [146/250] es-S1130-01082008000900017-1.txt — ya procesado, saltando
# [147/250] es-S1130-01082008001000008-1.txt — ya procesado, saltando
# [148/250] es-S1130-01082009000200012-1.txt — ya procesado, saltando
# [149/250] es-S1130-01082009000200016-1.txt — ya procesado, saltando
# [150/250] es-S1130-01082009000300015-1.txt — ya procesado, saltando
# [151/250] es-S1130-01082009000400012-1.txt — ya procesado, saltando
# [152/250] es-S1130-01082009000400015-1.txt — ya procesado, saltando
# [153/250] es-S1130-01082009000500007-1.txt — ya procesado, saltando
# [154/250] es-S1130-01082009000500013-1.txt — ya procesado, saltando
# [155/250] es-S1130-01082009000600013-1.txt — ya procesado, saltando
# [156/250] es-S1130-01082009000900012-1.txt — ya procesado, saltando
# [157/250] es-S1130-01082010000200011-1.txt — ya procesado, saltando
# [158/250] es-S1130-01082010000400015-1.txt — ya procesado, saltando
# [159/250] es-S1130-01082010000700014-1.txt — ya procesado, saltando
# [160/250] es-S1130-01082010001100014-1.txt — ya procesado, saltando
# [161/250] es-S1130-05582003000600004-2.txt — ya procesado, saltando
# [162/250] es-S1130-05582007000500007-1.txt — ya procesado, saltando
# [163/250] es-S1130-05582008000400004-1.txt — ya procesado, saltando
# [164/250] es-S1130-05582008000400004-5.txt — ya procesado, saltando
# [165/250] es-S1130-05582008000600006-1.txt — ya procesado, saltando
# [166/250] es-S1130-05582009000600004-1.txt — ya procesado, saltando
# [167/250] es-S1130-05582010000200004-1.txt — ya procesado, saltando
# [168/250] es-S1130-05582012000300005-1.txt — ya procesado, saltando
# [169/250] es-S1130-05582013000400005-1.txt — ya procesado, saltando
# [170/250] es-S1130-05582014000300006-1.txt — ya procesado, saltando
# [171/250] es-S1130-05582014000400006-2.txt — ya procesado, saltando
# [172/250] es-S1130-05582015000100004-1.txt — ya procesado, saltando
# [173/250] es-S1130-05582015000400005-1.txt — ya procesado, saltando
# [174/250] es-S1130-05582017000200119-1.txt — ya procesado, saltando
# [175/250] es-S1130-05582017000300150-3.txt — ya procesado, saltando
# [176/250] es-S1130-14732005000200009-1.txt — ya procesado, saltando
# [177/250] es-S1130-14732005000300004-1.txt — ya procesado, saltando
# [178/250] es-S1130-14732005000600009-1.txt — ya procesado, saltando
# [179/250] es-S1130-14732006000200011-1.txt — ya procesado, saltando
# [180/250] es-S1130-14732006000400005-1.txt — ya procesado, saltando
# [181/250] es-S1130-63432014000400016-1.txt — ya procesado, saltando
# [182/250] es-S1130-63432014000500008-1.txt — ya procesado, saltando
# [183/250] es-S1130-63432015000100008-1.txt — ya procesado, saltando
# [184/250] es-S1134-80462005000100007-1.txt — ya procesado, saltando
# [185/250] es-S1134-80462005000300004-1.txt — ya procesado, saltando
# [186/250] es-S1134-80462009000100005-1.txt — ya procesado, saltando
# [187/250] es-S1134-80462009000200004-1.txt — ya procesado, saltando
# [188/250] es-S1134-80462009000500006-1.txt — ya procesado, saltando
# [189/250] es-S1134-80462013000400006-2.txt — ya procesado, saltando
# [190/250] es-S1134-80462014000300009-1.txt — ya procesado, saltando
# [191/250] es-S1134-80462014000500004-1.txt — ya procesado, saltando
# [192/250] es-S1134-80462015000200005-1.txt — ya procesado, saltando
# [193/250] es-S1134-80462015000500005-1.txt — ya procesado, saltando
# [194/250] es-S1135-76062005000100002-1.txt — ya procesado, saltando
# [195/250] es-S1135-76062010000300006-1.txt — ya procesado, saltando
# [196/250] es-S1135-76062013000100008-1.txt — ya procesado, saltando
# [197/250] es-S1135-76062013000200010-1.txt — ya procesado, saltando
# [198/250] es-S1135-76062014000100006-1.txt — ya procesado, saltando
# [199/250] es-S1137-66272007000500016-1.txt — ya procesado, saltando
# [200/250] es-S1137-66272009000500016-1.txt — ya procesado, saltando
# [201/250] es-S1137-66272010000400007-1.txt — ya procesado, saltando
# [202/250] es-S1137-66272011000100013-2.txt — ya procesado, saltando
# [203/250] es-S1137-66272011000300024-1.txt — ya procesado, saltando
# [204/250] es-S1137-66272012000100017-1.txt — ya procesado, saltando
# [205/250] es-S1137-66272012000300023-1.txt — ya procesado, saltando
# [206/250] es-S1137-66272012000300024-1.txt — ya procesado, saltando
# [207/250] es-S1137-66272013000100023-1.txt — ya procesado, saltando
# [208/250] es-S1137-66272013000100024-1.txt — ya procesado, saltando
# [209/250] es-S1137-66272013000200023-1.txt — ya procesado, saltando
# [210/250] es-S1137-66272014000100019-1.txt — ya procesado, saltando
# [211/250] es-S1137-66272014000200011-1.txt — ya procesado, saltando
# [212/250] es-S1137-66272014000200013-1.txt — ya procesado, saltando
# [213/250] es-S1137-66272015000200019-2.txt — ya procesado, saltando
# [214/250] es-S1137-66272016000200010-1.txt — ya procesado, saltando
# [215/250] es-S1137-66272016000300010-1.txt — ya procesado, saltando
# [216/250] es-S1138-123X2004000100006-2.txt — ya procesado, saltando
# [217/250] es-S1138-123X2005000200006-2.txt — ya procesado, saltando
# [218/250] es-S1138-123X2006000200007-1.txt — ya procesado, saltando
# [219/250] es-S1139-76322009000100006-1.txt — ya procesado, saltando
# [220/250] es-S1139-76322009000700016-1.txt — ya procesado, saltando
# [221/250] es-S1139-76322013000200009-1.txt — ya procesado, saltando
# [222/250] es-S1139-76322014000100006-1.txt — ya procesado, saltando
# [223/250] es-S1139-76322015000300013-1.txt — ya procesado, saltando
# [224/250] es-S1139-76322015000400012-1.txt — ya procesado, saltando
# [225/250] es-S1139-76322016000200013-1.txt — ya procesado, saltando
# [226/250] es-S1139-76322016000300008-1.txt — ya procesado, saltando
# [227/250] es-S1139-76322016000300009-1.txt — ya procesado, saltando
# [228/250] es-S1139-76322016000300015-1.txt — ya procesado, saltando
# [229/250] es-S1139-76322016000300016-2.txt — ya procesado, saltando
# [230/250] es-S1139-76322016000400018-1.txt — ya procesado, saltando
# [231/250] es-S1139-76322017000100010-1.txt — ya procesado, saltando
# [232/250] es-S1575-06202010000200004-1.txt — ya procesado, saltando
# [233/250] es-S1698-44472004000200012-1.txt — ya procesado, saltando
# [234/250] es-S1698-44472004000400011-1.txt — ya procesado, saltando
# [235/250] es-S1698-44472004000400012-1.txt — ya procesado, saltando
# [236/250] es-S1698-69462006000100003-1.txt — ya procesado, saltando
# [237/250] es-S1698-69462006000100006-1.txt — ya procesado, saltando
# [238/250] es-S1698-69462006000200016-1.txt — ya procesado, saltando
# [239/250] es-S1699-65852007000300003-1.txt — ya procesado, saltando
#   [chunk 1/24 | chars 0-207]
#   RAW: ''
#   [chunk 2/24 | chars 208-373]
#   RAW: 'deformidad de las muñecas'
#   [chunk 3/24 | chars 374-466]
#   RAW: 'traumatismo'
#   [chunk 4/24 | chars 467-515]
#   RAW: ''
#   [chunk 5/24 | chars 516-556]
#   RAW: ''
#   [chunk 6/24 | chars 556-720]
#   RAW: 'deformidad en la cara dorsal a nivel del estiloides cubital\ndesviación cubital'
#   [chunk 7/24 | chars 721-800]
#   RAW: ''
#   [chunk 8/24 | chars 800-876]
#   RAW: ''
#   [chunk 9/24 | chars 877-897]
#   RAW: ''
#   [chunk 10/24 | chars 898-921]
#   RAW: ''
#   [chunk 11/24 | chars 922-946]
#   RAW: ''
#   [chunk 12/24 | chars 947-985]
#   RAW: ''
#   [chunk 13/24 | chars 986-1007]
#   RAW: ''
#   [chunk 14/24 | chars 1007-1136]
#   RAW: ''
#   [chunk 15/24 | chars 1137-1168]
#   RAW: ''
#   [chunk 16/24 | chars 1169-1233]
#   RAW: ''
#   [chunk 17/24 | chars 1233-1281]
#   RAW: ''
#   [chunk 18/24 | chars 1282-1322]
#   RAW: ''
#   [chunk 19/24 | chars 1323-1431]
#   RAW: ''
#   [chunk 20/24 | chars 1432-1514]
#   RAW: ''
#   [chunk 21/24 | chars 1514-1626]
#   RAW: ''
#   [chunk 22/24 | chars 1626-1846]
#   RAW: 'deformidad\ndeformidad de Madelung\nluxación cubital distal bilateral'
#   [chunk 23/24 | chars 1846-1991]
#   RAW: ''
#   [chunk 24/24 | chars 1992-2144]
#   RAW: ''
# [240/250] es-S1699-695X2015000200010-1.txt | 16.18s | 24 chunks | 7 menciones
#   [chunk 1/18 | chars 0-157]
#   RAW: ''
#   [chunk 2/18 | chars 158-245]
#   RAW: ''
#   [chunk 3/18 | chars 246-338]
#   RAW: ''
#   [chunk 4/18 | chars 339-432]
#   RAW: ''
#   [chunk 5/18 | chars 433-612]
#   RAW: ''
#   [chunk 6/18 | chars 612-737]
#   RAW: ''
#   [chunk 7/18 | chars 738-798]
#   RAW: ''
#   [chunk 8/18 | chars 799-885]
#   RAW: ''
#   [chunk 9/18 | chars 886-938]
#   RAW: 'exoftalmos'
#   [chunk 10/18 | chars 939-1073]
#   RAW: ''
#   [chunk 11/18 | chars 1074-1370]
#   RAW: ''
#   [chunk 12/18 | chars 1371-1489]
#   RAW: 'hipopotasemia\nparálisis periódica'
#   [chunk 13/18 | chars 1490-1884]
#   RAW: 'patología tiroidea\nhipertiroidismo primario de origen autoinmune'
#   [chunk 14/18 | chars 1885-1976]
#   RAW: ''
#   [chunk 15/18 | chars 1977-2140]
#   RAW: 'hipertiroidismo'
#   [chunk 16/18 | chars 2141-2226]
#   RAW: 'enfermedad de Graves'
#   [chunk 17/18 | chars 2227-2475]
#   RAW: ''
#   [chunk 18/18 | chars 2476-2661]
#   RAW: 'parálisis'
# [241/250] es-S1699-695X2015000300013-1.txt | 13.63s | 18 chunks | 8 menciones
#   [chunk 1/17 | chars 0-186]
#   RAW: ''
#   [chunk 2/17 | chars 187-277]
#   RAW: ''
#   [chunk 3/17 | chars 278-624]
#   RAW: 'cicatriz de laparotomía media infraumbilical'
#   [chunk 4/17 | chars 625-667]
#   RAW: 'hernias inguinales o crurales'
#   [chunk 5/17 | chars 667-838]
#   RAW: ''
#   [chunk 6/17 | chars 839-939]
#   RAW: 'suboclusión de intestino delgado\ncolelitiasis'
#   [chunk 7/17 | chars 940-1072]
#   RAW: 'torsión intestinal'
#   [chunk 8/17 | chars 1072-1396]
#   RAW: ''
#   [chunk 9/17 | chars 1397-1846]
#   RAW: 'oclusión intestinal por bridas\nasa de intestino delgado estrangulada y necrosada'
#   [chunk 10/17 | chars 1847-2323]
#   RAW: ''
#   [chunk 11/17 | chars 2324-2480]
#   RAW: ''
#   [chunk 12/17 | chars 2481-2686]
#   RAW: 'perforación al manipular el asa necrosada'
#   [chunk 13/17 | chars 2687-2916]
#   RAW: 'obstrucción y estrangulación del ileon\nhernia interna a través de la hoja derecha del ligamento ancho del útero'
#   [chunk 14/17 | chars 2917-3052]
#   RAW: 'hernia\nileon necrosado'
#   [chunk 15/17 | chars 3053-3134]
#   RAW: ''
#   [chunk 16/17 | chars 3135-3259]
#   RAW: ''
#   [chunk 17/17 | chars 3260-3307]
#   RAW: ''
# [242/250] es-S1887-85712012000400006-1.txt | 17.51s | 17 chunks | 12 menciones
#   [chunk 1/13 | chars 0-274]
#   RAW: 'visión borrosa\nvisión doble vertical'
#   [chunk 2/13 | chars 275-356]
#   RAW: ''
#   [chunk 3/13 | chars 356-532]
#   RAW: 'exfumador\nhipertenso\ndislipémico'
#   [chunk 4/13 | chars 532-751]
#   RAW: 'diplopía binocular vertical'
#   [chunk 5/13 | chars 752-797]
#   RAW: ''
#   [chunk 6/13 | chars 798-911]
#   RAW: ''
#   [chunk 7/13 | chars 912-1000]
#   RAW: ''
#   [chunk 8/13 | chars 1000-1343]
#   RAW: ''
#   [chunk 9/13 | chars 1343-1492]
#   RAW: 'diplopia'
#   [chunk 10/13 | chars 1492-1824]
#   RAW: 'microinfartos solitarios en sustancia blanca profunda\nlesiones isquémicas agudas de localización paramedial en ambos tálamos y mesencéfalo anterior\nobstrucción de la arteria de Percheron'
#   [chunk 11/13 | chars 1825-1931]
#   RAW: 'lesiones'
#   [chunk 12/13 | chars 1931-2108]
#   RAW: ''
#   [chunk 13/13 | chars 2109-2269]
#   RAW: 'diplopía'
# [243/250] es-S1887-85712014000100005-1.txt | 13.28s | 13 chunks | 12 menciones
#   [chunk 1/21 | chars 0-234]
#   RAW: 'hipertensión arterial\ncarcinoma de recto'
#   [chunk 2/21 | chars 235-357]
#   RAW: 'artrosis generalizada'
#   [chunk 3/21 | chars 357-745]
#   RAW: 'SCASEST-Killip III'
#   [chunk 4/21 | chars 746-996]
#   RAW: 'hematoma en cara volar de antebrazo'
#   [chunk 5/21 | chars 996-1242]
#   RAW: ''
#   [chunk 6/21 | chars 1242-1253]
#   RAW: ''
#   [chunk 7/21 | chars 1253-1307]
#   RAW: ''
#   [chunk 8/21 | chars 1307-1373]
#   RAW: ''
#   [chunk 9/21 | chars 1373-1425]
#   RAW: ''
#   [chunk 10/21 | chars 1425-1655]
#   RAW: ''
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'síndrome compartimental agudo en antebrazo'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: ''
#   [chunk 13/21 | chars 1907-1969]
#   RAW: ''
#   [chunk 14/21 | chars 1970-2110]
#   RAW: ''
#   [chunk 15/21 | chars 2111-2191]
#   RAW: 'hematoma'
#   [chunk 16/21 | chars 2192-2410]
#   RAW: ''
#   [chunk 17/21 | chars 2411-2487]
#   RAW: 'lesiones vasculares'
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'herida'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: ''
#   [chunk 20/21 | chars 2901-3087]
#   RAW: ''
#   [chunk 21/21 | chars 3088-3211]
#   RAW: ''
# [244/250] es-S1887-85712016000100005-1.txt | 15.11s | 21 chunks | 9 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: ''
#   [chunk 2/22 | chars 128-229]
#   RAW: ''
#   [chunk 3/22 | chars 230-429]
#   RAW: ''
#   [chunk 4/22 | chars 430-528]
#   RAW: ''
#   [chunk 5/22 | chars 528-725]
#   RAW: ''
#   [chunk 6/22 | chars 726-884]
#   RAW: ''
#   [chunk 7/22 | chars 885-956]
#   RAW: ''
#   [chunk 8/22 | chars 957-1077]
#   RAW: ''
#   [chunk 9/22 | chars 1078-1172]
#   RAW: ''
#   [chunk 10/22 | chars 1173-1326]
#   RAW: ''
#   [chunk 11/22 | chars 1327-1397]
#   RAW: ''
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'deformidad en forma de joroba en región cérvico-cefálica femoral'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: ''
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'sinovitis en interlínea articular'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: ''
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'pinzamiento de la interlinea articular antero-superior y posteroinferior\nincipiente collar osteofitario femoral\nlesiones subcondrales antero-superiores de cabeza femoral'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'lesiones en el labrum'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'lesión quística yuxtaarticular en relación con trocánter mayor'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'síndrome de pinzamiento femoroacetabular tipo LEVA (también conocido por CAM)'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: ''
#   [chunk 21/22 | chars 2841-3040]
#   RAW: ''
#   [chunk 22/22 | chars 3040-3146]
#   RAW: ''
# [245/250] es-S1888-75462015000400006-1.txt | 20.17s | 22 chunks | 8 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'hábitos tóxicos\nreacción alérgica conocida a medicamentos\nfractura de tercio medio de clavícula\nfractura de arcos costales'
#   [chunk 2/7 | chars 348-577]
#   RAW: ''
#   [chunk 3/7 | chars 578-865]
#   RAW: 'fractura de arcos costales derechos cuarto y quinto\nhemotórax\nneumotórax\nfractura de tercio medio de la clavícula derecha con tercer fragmento'
#   [chunk 4/7 | chars 865-1387]
#   RAW: ''
#   [chunk 5/7 | chars 1387-1636]
#   RAW: ''
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'trombosis venosa de las venas axilar, cefálica y basílica'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'fractura de clavícula'
# [246/250] es-S1888-75462016000400180-1.txt | 11.61s | 7 chunks | 10 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: ''
#   [chunk 2/20 | chars 48-140]
#   RAW: 'metrorragias secundarias a miomas'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'osteoporosis densitométrica lumbar\nhábitos tóxicos\nfractura'
#   [chunk 4/20 | chars 449-629]
#   RAW: ''
#   [chunk 5/20 | chars 630-736]
#   RAW: ''
#   [chunk 6/20 | chars 737-790]
#   RAW: ''
#   [chunk 7/20 | chars 791-861]
#   RAW: ''
#   [chunk 8/20 | chars 862-995]
#   RAW: 'fractura de estrés en el 2o MTT con callo perióstico'
#   [chunk 9/20 | chars 996-1240]
#   RAW: ''
#   [chunk 10/20 | chars 1241-1311]
#   RAW: ''
#   [chunk 11/20 | chars 1312-1467]
#   RAW: ''
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'osteoporosis a nivel lumbar'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'callo de fractura\nfractura de estrés'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'tenosinovitis del tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: ''
#   [chunk 16/20 | chars 2235-2436]
#   RAW: ''
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'fracturas'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'osteoporosis\nobesa'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: ''
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'fracturas de estrés'
# [247/250] es-S1889-836X2015000200005-2.txt | 17.36s | 20 chunks | 13 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'infección por VIH'
#   [chunk 2/16 | chars 158-268]
#   RAW: ''
#   [chunk 3/16 | chars 269-407]
#   RAW: ''
#   [chunk 4/16 | chars 408-569]
#   RAW: ''
#   [chunk 5/16 | chars 570-697]
#   RAW: ''
#   [chunk 6/16 | chars 697-865]
#   RAW: ''
#   [chunk 7/16 | chars 866-953]
#   RAW: ''
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperglucemia leve\nhipofosfatemia\nhipouricemia\nacidosis metabólica'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: ''
#   [chunk 10/16 | chars 1316-1347]
#   RAW: ''
#   [chunk 11/16 | chars 1348-1392]
#   RAW: ''
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'síndrome de Fanconi incompleto\nhipofosfatemia grave\nosteomalacia'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: ''
#   [chunk 14/16 | chars 1656-1750]
#   RAW: ''
#   [chunk 15/16 | chars 1751-1800]
#   RAW: ''
#   [chunk 16/16 | chars 1801-2071]
#   RAW: ''
# [248/250] es-S1889-836X2015000400006-1.txt | 11.91s | 16 chunks | 8 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'alergias\nlupus cutáneo con eritema malar'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Tiroiditis de Hashimoto'
#   [chunk 3/40 | chars 231-246]
#   RAW: ''
#   [chunk 4/40 | chars 247-276]
#   RAW: 'Exfumadora'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'bebedora'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'hábitos tóxicos'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'anemia'
#   [chunk 8/40 | chars 400-440]
#   RAW: ''
#   [chunk 9/40 | chars 440-603]
#   RAW: 'presíncopes'
#   [chunk 10/40 | chars 604-651]
#   RAW: ''
#   [chunk 11/40 | chars 652-697]
#   RAW: 'heces melénicas'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'gingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'anemia'
#   [chunk 14/40 | chars 826-889]
#   RAW: ''
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'PTT\nLES'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: ''
#   [chunk 17/40 | chars 1127-1300]
#   RAW: ''
#   [chunk 18/40 | chars 1301-1366]
#   RAW: ''
#   [chunk 19/40 | chars 1366-1445]
#   RAW: ''
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'microangiopatía trombótica\ncrisis convulsivas'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: ''
#   [chunk 22/40 | chars 1649-1762]
#   RAW: ''
#   [chunk 23/40 | chars 1762-1838]
#   RAW: ''
#   [chunk 24/40 | chars 1838-1862]
#   RAW: ''
#   [chunk 25/40 | chars 1862-1927]
#   RAW: ''
#   [chunk 26/40 | chars 1928-1987]
#   RAW: ''
#   [chunk 27/40 | chars 1988-2014]
#   RAW: ''
#   [chunk 28/40 | chars 2015-2052]
#   RAW: ''
#   [chunk 29/40 | chars 2053-2101]
#   RAW: ''
#   [chunk 30/40 | chars 2101-2334]
#   RAW: ''
#   [chunk 31/40 | chars 2334-2426]
#   RAW: ''
#   [chunk 32/40 | chars 2426-2627]
#   RAW: ''
#   [chunk 33/40 | chars 2628-2709]
#   RAW: ''
#   [chunk 34/40 | chars 2709-2799]
#   RAW: ''
#   [chunk 35/40 | chars 2800-2842]
#   RAW: ''
#   [chunk 36/40 | chars 2842-2902]
#   RAW: ''
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'hipotensión'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: ''
#   [chunk 39/40 | chars 3125-3228]
#   RAW: ''
#   [chunk 40/40 | chars 3228-3322]
#   RAW: ''
# [249/250] es-S2254-28842014000200009-1.txt | 26.32s | 40 chunks | 16 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'carcinoma seroso papilar en ovario izquierdo con afectación de un ganglio de la cadena aorto-cava'
#   [chunk 2/11 | chars 208-315]
#   RAW: ''
#   [chunk 3/11 | chars 316-458]
#   RAW: ''
#   [chunk 4/11 | chars 459-661]
#   RAW: 'lesión hepática que confirmó la naturaleza metastásica'
#   [chunk 5/11 | chars 661-783]
#   RAW: ''
#   [chunk 6/11 | chars 784-1007]
#   RAW: ''
#   [chunk 7/11 | chars 1008-1110]
#   RAW: ''
#   [chunk 8/11 | chars 1111-1225]
#   RAW: ''
#   [chunk 9/11 | chars 1226-1678]
#   RAW: ''
#   [chunk 10/11 | chars 1678-1796]
#   RAW: ''
#   [chunk 11/11 | chars 1797-1934]
#   RAW: ''
# [250/250] es-S2340-98942015000100005-1.txt | 8.95s | 11 chunks | 2 menciones
#
# Predicciones guardadas en distemist_llm_predictions.tsv
# Tiempo medio por archivo: 14.02s

# %% [markdown]
# ## 9. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd


def prf(tp, fp, fn):
    p  = tp / (tp + fp) if (tp + fp) else 0.0
    r  = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1


df_pred  = pd.read_csv(PREDICTIONS_TSV, sep="\t")
df_gs    = pd.read_csv(GS_TEST_TSV, sep="\t")
df_gs    = df_gs[df_gs["filename"].isin(df_pred["filename"].unique())]

set_gs   = set(zip(df_gs["filename"],   df_gs["label"],   df_gs["off0"],   df_gs["off1"]))
set_pred = set(zip(df_pred["filename"], df_pred["label"], df_pred["off0"], df_pred["off1"]))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1   = prf(tp, fp, fn)

report = {"Estricta": {"tp": tp, "fp": fp, "fn": fn, "precision": round(p, 4), "recall": round(r, 4), "fscore": round(f1, 4)}}

print(f"── ESTRICTA ──  P={p:.4f}  R={r:.4f}  F1={f1:.4f}  (TP={tp} FP={fp} FN={fn})\n")

thresholds = [0.0, 0.5, 0.8]
results    = {t: {"tp": 0, "fp": 0, "fn": 0} for t in thresholds}

for filename in df_pred["filename"].unique():
    gs_ints   = list(zip(df_gs[df_gs["filename"] == filename]["off0"],   df_gs[df_gs["filename"] == filename]["off1"]))
    pred_ints = list(zip(df_pred[df_pred["filename"] == filename]["off0"], df_pred[df_pred["filename"] == filename]["off1"]))

    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )

    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi); matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ──  P=0.7835  R=0.7412  F1=0.7618  (TP=1922 FP=531 FN=671)
#
# ── IoU ──
# IoU >= 0.0:  P=0.9144  R=0.8650  F1=0.8890  (TP=2243 FP=210 FN=350)
# IoU >= 0.5:  P=0.8512  R=0.8052  F1=0.8276  (TP=2088 FP=365 FN=505)
# IoU >= 0.8:  P=0.7966  R=0.7536  F1=0.7745  (TP=1954 FP=499 FN=639)
