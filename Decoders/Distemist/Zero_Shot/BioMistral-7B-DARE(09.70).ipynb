# %% [markdown]
# # Pipeline Zero-Shot NER — DisTemIST con BioMistral-7B-DARE
#
# Inferencia zero-shot para reconocimiento de enfermedades en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "BioMistral/BioMistral-7B-DARE"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo ENFERMEDAD.\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'neoplasia', no escribas 'cancer'.\n"
    "4. REPETICIONES: Si una enfermedad aparece varias veces en el texto, debes listarla varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio (como '-', '*', '•', '1.').\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
DISTEMIST_ROOT       = f"{PROJECT_ROOT}/distemist/distemist"
TEXT_FILES_TEST_DIR  = f"{DISTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{DISTEMIST_ROOT}/distemist_subtrack1_test_mentions.tsv"
PREDICTIONS_TSV      = "distemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : BioMistral/BioMistral-7B-DARE
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
    trust_remote_code = True,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.6.2: Fast Mistral patching. Transformers: 5.10.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# BioMistral/BioMistral-7B-DARE does not have a padding token! Will use pad_token = <unk>.
#
# Modelo cargado: BioMistral/BioMistral-7B-DARE
# Parámetros totales: 3,752,071,168

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

def build_ner_messages(text):
    return [
        {
            "role": "user",
            "content": f"{SYSTEM_PROMPT}\n\nTexto para analizar:\n{text}",
        }
    ]

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            full_output = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        marker = "<|im_start|>assistant"
        idx    = full_output.rfind(marker)
        result = full_output[idx + len(marker):].strip() if idx != -1 else full_output.strip()
        result = re.sub(r"<think>.*?</think>", "", result, flags=re.DOTALL).strip()
        result = re.sub(r"<think>.*",          "", result, flags=re.DOTALL).strip()

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename": txt_path.stem,
            "mark":     f"T{mark_idx}",
            "label":    "ENFERMEDAD",
            "off0":     off0,
            "off1":     off1,
            "span":     span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "mark", "label", "off0", "off1", "span"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'Enfermedad: diabetes, hipertensión, obesidad'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'Enfermedad: dolor lumbar derecho'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'Enfermedad:'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'Enfermedad: masa suprarrenal derecha hipoecogénica de 80 mms que comprime el polo superior de riñón derecha.'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'Enfermedad: Urograma descendente, proceso expansivo en la suprarrenal derecha, el polo superior de riñón derecho desplazado hacia abajo.'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'Enfermedad: tumoral, masa, suprarrenal, densidad grasa.'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'Enfermedad:'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'Enfermedad:'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'Los hallazgos transoperatorios fueron un tumor localizado en la glándula suprarrenal derecha, bien delimitado de bordes irregulares con lobulaciones.'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'Enfermedad: adrenalectomía'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'La evolución post operatoria de la paciente es favorable, manteniéndose asintomática.'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'Enfermedad: patólogo, pieza, peso, dimensiones, áreas amarillas - naranjas, hemorragias, tejido adiposo, calcificaciones.'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'Mielolipoma de la glándula adrenal con extensas áreas de calcificaciones.'
# [1/250] S0004-06142006000100010-1.txt | 25.09s | 13 chunks | 3 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'Enfermedad: adenocarcinoma gástrico'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'Enfermedad: anorexia, pérdida de peso, anemia hipocrómica, estreñimiento.'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'Enfermedad: tumoración'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'Enfermedad: adenocarcinoma gástrico, ascitis, carcinomatosis, obstrucción intestinal tumoral, tumoración abdominal.'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'Enfermedad: Hemoglobina, Hematocrito, VCM, RDW, VSG, PCR, PSA, Creatinina, Urea'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'Los marcadores tumorales hepáticos y digestivos resultaron anodinos.'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'Enfermedad: gastroscopia, pólipo inflamatorio, muñón gástrico, recidiva tumoral.'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'Enfermedad: desplazamiento intestinal, intolerancia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'Enfermedad: tumoración quística'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: '"riñón izquierdo"'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'Enfermedad: lesión quística voluminosa intraabdominal'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'Enfermedad: TAC, masa quística, abdomen'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'Enfermedad: hidronefrótico'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'Hidronefrosis gigante secundaria a uropatía obstructiva litiásica'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'Nefrectomía simple derecha'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'Enfermedad: linfadenectomía hiliar ampliada, adenopatías'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'Enfermedad:'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'Enfermedad: multiquístico, dilatación del sistema pielocalicial, atrofia parenquimatosa'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'Enfermedad: displasia, patrón papilar, infiltración'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'En otras zonas se identificaron nidos sólidos de células de citoplasma amplio, claro y de alto grado nuclear (grado 3 de Fuhrman); así como infiltración ganglionar de carcinoma de células renales tipo célula clara.'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'La evolución posterior fue desfavorable, con aparición de metástasis hepáticas y el eventual fallecimiento del paciente a los dos meses.'
# [2/250] S0004-06142006000100014-1.txt | 35.57s | 21 chunks | 5 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'Enfermedad: varicocele'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'Prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'Enfermedad: varicocele'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'Enfermedad: próstata irregular, ligeramente aumentada de tamaño con zonas induradas y algo dolorosa a la exploración.'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'Enfermedad: ecografía urológica integral, imagen nodular hipoecoica, hipervascularización circundante, quiste simple.'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'Enfermedad: metástasis, hemangiomas'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'Hemangiomas'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'La Rx de tórax no presentaba alteraciones.'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'Los marcadores tumorales y el PSA presentaban unos valores dentro de la normalidad.'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'Enfermedad: Alfa-feto-proteína, beta-HCG, PSA.'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'Orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'Enfermedad: nodular'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'Leydig diffuse tumor, perineural spaces infiltration, vasculares channels capsulares adyacentes, smooth muscle liso, moderate atypia, scarce mitosis.'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'Enfermedad: neoplasia'
# [3/250] S0004-06142006000500002-2.txt | 21.11s | 14 chunks | 5 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'Neoplasia de testículo'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Enfermedad: Uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'Enfermedad: nefríticos, litiasis, LEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Enfermedad: Ureterolitectomía'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'Enfermedad: Fumador de 1 paquete de cigarrillos/día.'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'Enfermedad: esterilidad, nódulo en testículo izquierdo, aumento de tamaño en últimas semanas.'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'Enfermedad: azoospermia'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'Enfermedad: tumor testicular, quiste de cordón izquierdo.'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'Enfermedad: quiste de epidídimo'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'El testículo derecho no se pudo explorar puesto que se encontraba en el canal inguinal.'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'Enfermedad:'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'Enfermedad: Tórax, TAC toraco-abdómino-pélvico, metástasis'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'La analítica tampoco mostraba alteraciones, tanto en los valores séricos hormonales como los marcadores tumorales (alfa-fetoproteina 2,2 ng/ml, beta-HCG 0,0 ng/ml).'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'Enfermedad: orquiectomía radical inguinal derecha, biopsia del testículo izquierdo vía inguinal.'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'Enfermedad: testículo'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'Enfermedad: superficie testicular, infiltración de túnica vaginalis.'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'Enfermedad: Nódulo sólido'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'Enfermedad: testicular'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'El cordón espermático no presenta alteraciones.'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'Enfermedad: biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Leydig cell tumor of 3.2 x 3 cm without objective epididymal infiltration, tunica albuginea or vascular invasion.'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'Enfermedad: resto de parénquima testicular, atrofia, hiperplasia de células de Leydig, práctica ausencia de espermiogénesis.'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'Enfermedad: Bordes quirúrgicos libres.'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'La biopsia del teste izquierdo fue informada como atrofia testicular con ausencia de espermiogénesis e hiperplasia de células de Leydig intersticial.'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'Enfermedad: metástasis'
# [4/250] S0004-06142006000500002-3.txt | 45.46s | 25 chunks | 5 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'Enfermedad: masa renal derecha'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'La TAC abdomino-pélvica confirmó la presencia de una masa sólida y heterogénea de aproximadamente 6 cm, localizada en polo superior del riñón derecho con vena renal permeable.'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'Nefrectomía radical derecha'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'Carcinoma renal de células claras'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'Enfermedad:'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'Neoplasia'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'Enfermedad: recidiva tumoral, infiltración pilar diafragmático derecho posterior, infiltración hígado, implantes peritoneales'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'Carcinoma de células claras de alto grado'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'La masa retroperitoneal paravertebral resultó inaccesible por su íntimo contacto con los grandes vasos.'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Enfermedad: Ante estos hallazgos se decidió contactar con el Servicio de Oncología, iniciándose tratamiento con Interferón (Intrón A), con mala tolerancia del mismo y precisándose reducción de la dosis.'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'Enfermedad: molestias abdominales inespecíficas, metástasis, recidiva del lecho quirúrgico, implantes peritoneales'
# [5/250] S0004-06142006000900015-1.txt | 22.24s | 11 chunks | 6 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'Enfermedad:'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'La extracción de entidades de tipo enfermedad es:\n\n* tumoración indolora\n* neoplasia'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'No presenta otra sintomatología urológica, no astenia, no pérdida de peso.'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'Enfermedad:'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'Enfermedad: hipotrófico, aumentado'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'Enfermedad: Ambos'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'Epidídimos y cordones sin hallazgos patológicos.'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'Enfermedad: hemostasia, bioquímica, hemograma, alfa-feto proteína, beta-hCG.'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'Enfermedad: testicular'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'Enfermedad: lesión focal ligeramente hipoecoica'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'Microlitiasis testiculares bilaterales.'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Enfermedad: Radiografía de tórax, TAC toraco-abdomino-pélvico con contraste.'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'Tumor testicular bilateral'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'Enfermedad: testículo izquierdo atrófico, múltiples focos microscópicos de seminoma clásico, neoplasia intratubular de células germinales, ausencia de infiltración tumoral en albugínea, rete testis, epidídimo, infiltración vascular.'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'Enfermedad: tumoración, seminoma clásico, neoplasia intratubular de células germinales, atrofia.'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'Túnica albugínea, rete testis, epidídimo y borde quirúrgico libres de tumor.'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'El tratamiento se completó con dos ciclos de quimioterapia con carboplatino según protocolo del hospital.'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'Enfermedad'
# [6/250] S0004-06142007000200017-1.txt | 32.80s | 18 chunks | 7 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'Enfermedad: YSS'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'Enfermedad: HEA'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'Enfermedad: Edema del pene y escroto con eritema y dolor.'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'Adenopatías inguinales no dolorosas.'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'Enfermedad: Hemograma completo'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'Enfermedad: No reactiva.'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Enfermedad: Tuberculosis'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'Enfermedad: necrosis aséptica de la cabeza del fémur, hipertrofia del psoas'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'Enfermedad: Exploración retroperitoneal derecha.'
#   [chunk 10/20 | chars 947-985]
#   RAW: '-Adenectomía de ilíaca derecha y cava.'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'Linfangioplastia con aguja.'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: '-Fasciotomía de la raíz del pene.'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'Enfermedad:'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'Enfermedad: Linfedema primario inflamatorio local de pene y escroto.'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'Necosis aséptica de la cabeza del fémur.'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'Enfermedad:'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'La entidad encontrada es: "linfangiectomía"'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'Enfermedad: distorsionada, afección, impide, linfa, conductillos linfáticos, tejido conjuntivo fibroso, disminución, fibras elásticas, peneano.'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'Enfermedad: piel, dermis, dartos, túnica muscular de fibras lisas, cubierta celulosa, vasos linfáticos, venas, arterias, nervios superficiales.'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'Enfermedad: bolsas de las seis cubiertas, escroto, dartos muscular, celulosa, fascia de Cooper, eritroide, capa vaginal, paquete vasculo nervioso, epidídimo.'
# [7/250] S0004-06142007000600012-1.txt | 35.15s | 20 chunks | 5 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'Enfermedad: Nódulo testicular'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'Enfermedad: nódulo duro, móvil y doloroso a la palpación a nivel de cordón espermático derecho.'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'La determinación de marcadores tumorales y hormonas se encuentran dentro de la normalidad.'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'Enfermedad: imagen ovalada, hipoecoica, de ecogenicidad mixta, que tiene un eje longitudinal máximo de 2,8 cm y que impresiona estar en relación con el cordón espermático.'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'Enfermedad: RNM, tejido con bajo contenido en agua, fibroso o cicatricial.'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'Tumoración paratesticular derecha'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'Enfermedad: sin incidentes, asintomático'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'Enfermedad: formación redondeada de coloración pardusca y consistencia elástica, bien delimitada, de 5 cm de diámetro máximo, y al corte presenta una superficie blanquecina y homogénea de aspecto fibroso.'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'Enfermedad: lesión, células, amplio citoplasma, eosinófilo, estriaciones transversales, estroma fibroblástico, células vacuoladas, células multinucleadas, actividad mitótica.'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'Desmina, vimentina, actina de músculo liso específica'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'Granada.'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'Enfermedad: España'
# [8/250] S0004-06142007000600014-1.txt | 26.53s | 12 chunks | 3 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'Enfermedad: herida de arma de fuego, nalga'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'Enfermedad: herida de bala'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'Enfermedad: ligera defensa abdominal'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'Enfermedad: bala, fractura'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'Enfermedad: retención'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'Enfermedad: laparotomía, colostomía'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'Enfermedad: Uretrografía, Fiebre alta con escalofríos'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'Enfermedad: perforación rectal'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'Enfermedad: Uretra prostática'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'Enfermedad: vejiga'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'Enfermedad: laparotomía'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'Enfermedad: hiperplasia de próstata'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'Neoplasia'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'Enfermedad: postoperatorio'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'Enfermedad:'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'Enfermedad:'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'Uretrografía, brecha, sonda.'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'Enfermedad:'
# [9/250] es-S0004-06142007000900010-1.txt | 20.51s | 18 chunks | 0 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Enfermedad: cólico nefrítico'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'Neoformación sólida en riñón derecha'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'Enfermedad: masa, riñón, cortical, derecho, 5 cm, lobulados, perirrenal, adenopatías, dilatación, vía renal excretora.'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'Hipernefroma'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'Neoformación cortical, neoplasia cortical, neoplasia cortical de 5 cm de diámetro máximo, neoplasia cortical bien delimitada, neoplasia cortical no encapsulada, neoplasia cortical que deforma la superficie cortical sin atravesarla, neoplasia cortical con una superficie de corte de coloración amarillenta con áreas de aspecto hemorrágicas y áreas quísticas.'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'neoformación, estructuras acinares, células cuboidales, citoplasma, núcleos, cromatina, estroma celular'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'Enfermedad: vimentina, citoqueratina 7, citoqueratina de amplio espectro, CD34, cromogranina, EMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'Granada.'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'Enfermedad: España'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'Enfermedad: expresión generalizada de vimentina, focal de citoqueraina 7 y EMA en las células epiteliales, y CD34 en el componente estromal.'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'La paciente cursa tras la intervención sin incidentes destacables y se encuentra asintomática a los 24 meses de la intervención.'
# [10/250] es-S0004-06142007000900012-1.txt | 27.84s | 11 chunks | 3 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'Enfermedad: dolor lumbar, testículo izquierdo.'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'neoplasia'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'No se palpan adenopatías.'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'Tumor testicular tipo seminoma'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'Enfermedad: situs inversus, bronquiectasias'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'Enfermedad: LDH, GOT, GPT'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'Enfermedad: Marcadores tumorales, a-fetoproteína, HCG.'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'Seminoma clásico'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'No se evidencia invasión vascular.'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Neoplasia germinal intratubular.'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'Fibrosis e hialinización tubular de testículo no tumoral.'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'Seminoma grado I sin criterios de mal pronóstico'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'Enfermedad: orquiectomía, espermiogramas, azooospermia.'
# [11/250] es-S0004-06142008000300011-1.txt | 18.40s | 14 chunks | 9 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'Enfermedad: dolor abdominal, náuseas, vómitos biliosos'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'La tos y la inspiración aumentan el dolor.'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'Enfermedad: No refiere fiebre ni sensación distérmica.'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'No coluria ni acolia.'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'Enfermedad: dolor'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'Palidez mucocutánea.'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'Enfermedad: afebril, normotensa.'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Enfermedad: Auscultación cardiopulmonar sin hallazgos.'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'Enfermedad: Abdominal generalizado, dolor abdominal, epigastrio, masas, megalias, irritación peritoneal, neoplasia, cáncer.'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'No se aprecia circulación colateral.'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'No edemas en miembros inferiores.'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'No signos de trombosis venosa profunda (TVP).'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'Enfermedad:'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'Enfermedad: Hemograma con hemoglobina: 11.4 g/dL, hematocrito: 34%, leucocitos: 12700 sin neutrofilia y plaquetas: 291000.'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'Enfermedad: Hemostasia'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'Enfermedad: trombo, densidad grasa, trombo en riñón izquierdo, trombo en vena renal izquierda, trombo en vena cava inferior, trombo en ostium de aurícula derecha.'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'Enfermedad: Venas suprahepáticas libres.'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'Enfermedad: No oclusión completa de la luz de VCI.'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'Enfermedad: Anormalidad inespecífica de cabeza de páncreas.'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'Enfermedad: epigastralgia'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Lipoma en VCI.'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'Colecistitis, perforada, pancreatitis.'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'Enfermedad: Líquido libre'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'Enfermedad: patología bilio-pancreática'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'Enfermedad: Síndrome de Budd-Chiari\nEnfermedad: derrame pleural bilateral\nEnfermedad: engrosamiento de pliegues gástricos\nEnfermedad: aumento de la captación de contraste\nEnfermedad: angiomiolipoma (AML)'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'lipoma renal, VCI, aurícula derecha, contraste, estructuras venosas, vena porta, suprahepáticas'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'Hepatomegalia, aumento de calibre de vena porta y suprahepáticas con retardo e la llegada de contraste a las mismas, edema periportal, bazo y páncreas atigrado y abundante líquido libre.'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'Budd-Chiari syndrome'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'Enfermedad: trasudado'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'Enfermedad: ecografía transesofágica, tricúspide, derrame pericárdico.'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Síndrome de Budd-Chiari secundario a trombo en cava (AML vs.'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'Lipoma'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'Enfermedad: INTERVENCIÓN QUIRÚRGICA.'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'Enfermedad: trombo, nivel quirúrgico IV, situación supradiafragmática, ostium de aurícula derecha.'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'Enfermedad: incisión tipo Chevron, acceso a retroperitoneo, ligadura de vena mesentérica inferior.'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'Enfermedad: movilización hepática'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'Enfermedad: hiato diafragmático, trombo'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'Enfermedad: clampaje de pedículo hepático, maniobra de Pringle, VCI proximal y distal, VRD, cavotomía, apertura VRI, trombo, nefrectomía izquierda.'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'Enfermedad: angiomiolipoma de predominio lipomatoso del seno renal con infiltración vascular.'
# [12/250] es-S0004-06142008000300012-1.txt | 75.37s | 40 chunks | 9 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'Enfermedad: nefrítico, hematuria'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'Enfermedad: artrosis, lumbalgia'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'Enfermedad: litiasis, quiste renal gigante'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'Quiste renal simple (Bosniak I)'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'Hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Enfermedad: Hemograma'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'Enfermedad: molestias lumbares, quiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'Enfermedad: distintas posibilidades.'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'Enfermedad: Quedó pendiente de drenaje percutáneo, esclerosis del quiste.'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'Cistitis'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'Enfermedad: tratamiento antibiótico de modo domiciliario.'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'Enfermedad: quiste'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'Enfermedad: Mide'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'Enfermedad: calcificación de la pared'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'Enfermedad: quiste'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'Microhematuria y leucocituria.'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'Enfermedad: cistitis'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'La litiasis en pelvis renal.'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'Enfermedad: infección urinaria, E.Coli, Amoxicilina-Clavulanico, Trimetropin-Sulfametoxazol.'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'La infección fue curada y se trató la litiasis mediante litotricia extracorpórea.'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'La paciente esta asintomática.'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'Enfermedad: ruptura del quiste, lesión, calcificaciones gruesas, nodulares, no capta contraste.'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Enfermedad: Bosniak IIF.'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'Enfermedad: lesión'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'Enfermedad: comunicación con la vía urinaria'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'La paciente permanece asintomática.'
# [13/250] es-S0004-06142008000300013-1.txt | 35.11s | 26 chunks | 7 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'Enfermedad: carcinoma de próstata'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'Enfermedad: aumento de volumen testicular derecho, masa con áreas irregulares en ecografía, disminución de flujo vascular en estudio doppler.'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'La evaluación preoperatoria había incluido un TAC abdominal sin hallazgos.'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'El TAC post orquiectomía detecta adenopatías retroperitoneales desde área inguinal hasta bifurcación de renales.'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'Linfoma testicular difuso de célula grande tipo B'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'Enfermedad: recidiva precoz, esquema IFOVM / DHAP, remisión, neoplasia'
# [14/250] es-S0004-06142008000400011-2.txt | 12.49s | 6 chunks | 3 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'Enfermedad: hipertensión arterial'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'Enfermedad: metrorragias, dolor abdominal'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'No refería hematuria ni dolor en fosas renales.'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'Enfermedad: masa anexial izquierda, útero grande, ovario derecho'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'Carcinoma ovárico primario'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'Enfermedad: nódulo'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'Lesión sólido-quística'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'No se observaron adenopatías regionales ni implantes metastásicos peritoneales.'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'Carcinoma ovárico primario y metástasis renal secundaria.'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'Metástasis de carcinoma de células renales en ovario.'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'Carcinoma de células renales grado I de Fuhrman extendiéndose a grasa perirrenal, sin infiltrar la vena renal.'
# [15/250] es-S0004-06142008000400013-1.txt | 17.17s | 11 chunks | 6 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'Enfermedades:\ngastrectomía por adenocarcinoma gástrico\ncarcinoma de próstata Gleason VII\nganglio linfático afectado por el tumor'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'Enfermedad: lesión exofítica'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'Enfermedad: lesión'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'Enfermedad: lesión redondeada exofítica de color rojizo oscuro de aproximadamente dos centímetros de diámetro, con tendencia al sangrado, consistencia elástica y no dolorosa.'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'Enfermedad: linfadenectomías, tumoración, mucosa, trombosado, friables.'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'La extracción de entidades de tipo enfermedad es: melanoma.'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'Enfermedad: penectomía subtotal, resección, linfadenectomía inguinal superficial bilateral, ganglios no afectados por el tumor.'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'Neoplasia'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'Enfermedad:'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'El análisis inmunohistoquímico con S-100 y HMB 45 confirmó el diagnóstico de melanoma.'
# [16/250] es-S0004-06142008000400016-1.txt | 20.92s | 10 chunks | 3 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'Enfermedad: endometriosis ovárica, endometriosis, ectasia renal.'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'La paciente presenta dolor y defensa a la palpación profunda de fosa lumbar derecha y dolorimiento a la percusión y palpación de fosa lumbar izquierda, sugestivo de patología retroperitoneal.'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'Enfermedad: urografía intravenosa, Tomografía computerizada, retraso en la captación y eliminación de contraste, borramiento de la línea de psoas derecho.'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'Enfermedad: lobulada, extravasación, uréter'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'Urinoma'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'Enfermedad: catéter doble J tutorizando el uréter'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'La evolución de la paciente ha sido favorable sin complicaciones en el postoperatorio.'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'Enfermedad: buena función renal, normalidad de la vía urinaria'
# [17/250] es-S0004-06142008000500009-1.txt | 16.90s | 8 chunks | 3 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'Enfermedad: Infecciones Urinarias'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'Enfermedad: absceso de cúpula vaginal'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'No DM.'
#   [chunk 4/15 | chars 616-623]
#   RAW: 'No HTA.'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'Enfermedad: No alergias conocidas.'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'No hematuria.'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'No colicos.'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'Infecciones de orina esporádicas.'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'Enfermedad: G2 A0V2'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'Enfermedad: litiasis vesical'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'Enfermedad: Ante el hallazgo en la Rx.'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'La extracción de entidades de tipo enfermedad en el texto proporcionado es:\n\n* litiasis intravesical\n* cuerpo extraño intravesical'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'Enfermedad: uretrocistoscopia, gran "pelotón de gasas", calcificada.'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'Litiasis intravesical'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'Enfermedad: infección de orina'
# [18/250] es-S0004-06142008000700003-1.txt | 19.62s | 15 chunks | 5 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'EPOC'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'Enfermedad: hábitos tóxicos'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'Enfermedad: No factores ambientales de riesgo ni antecedentes familiares.'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'La enfermedad del paciente es uretrorragia.'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'Enfermedad: imposibilidad para el sondaje urinario'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'neoplasia vesical'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'Enfermedad: tumor sólido, enfermedad residual'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'Enfermedad: proliferación fibroblástica reactiva o tumor fibroso solitario.'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'Leiomiosarcoma de bajo grado (mitosis =3 X10 campos de gran aumento)'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'Enfermedad: Marcado pleomorfismo celular.'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'Necrosis intratumoral, necrosis celular aislada.'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'Enfermedad: Mixoma'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'Enfermedad: Intensa inflamación intra y peritumoral.'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'Infiltración de todo el espesor de la pared diverticular hasta el tejido adiposo peridiverticular provocando reacción fibrosa peritumoral.'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'Enfermedad: Márgenes quirúrgicos libres de tumor.'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'Vimentina, Actina, Desmina, EMA, Citoqueratinas de Alto Peso Molecular.'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'Leiomiosarcoma de bajo grado con infiltración de todas las capas'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'Enfermedad:'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'Neoplasia'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'Enfermedad: radioterapia locorregional'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'La quimioterapia administrada consistió en la combinación ifosfamida-adriamicina a dosis habituales, recibiendo el paciente tres ciclos de dicho tratamiento.'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'Enfermedad: cistoscopias, citología urinaria, TAC toraco-abdomino-pélvico'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: 'Enfermedad:'
# [19/250] es-S0004-06142009000400011-1.txt | 37.37s | 23 chunks | 6 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'Enfermedad: masa testicular'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'Enfermedad:'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'Enfermedad: ecografía testicular, aumento difuso del tamaño del testículo derecho, alteración difusa de la ecogenicidad del mismo.'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'Enfermedad: orquidectomia'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'neoplasia maligna hematolinfoide'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'ACL, CD3, Ki67, TdT, CD30, ALK, bcl2, bcl6, CD10.'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'Linfoma no Hodgkin T periférico no especificado'
# [20/250] es-S0004-06142010000100015-1.txt | 11.23s | 7 chunks | 2 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'Enfermedad: enfermedad pulmonar obstructiva, hipertensión arterial, hipercolesterolemia, lesión renal.'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'Lesión quística compleja, multiseptada, de contornos polilobulados, de 11 cm de diámetro y con calcificaciones puntiformes periféricas, que ocupa la práctica totalidad de dicho riñón.'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'Enfermedad: lesión renal izquierda'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'Ausencia de adenopatías retroperitoneales.'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'La extracción de entidades de tipo enfermedad del texto proporcionado es la siguiente:\n\n* nefroma multilocular quístico\n* carcinoma de células renales quístico'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'Enfermedad: Renograma isotópico con Tc-99m. Enfermedad: Riñón izquierda de inferior captación y funcionalismo. Enfermedad: Lesión ocupante.'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'Enfermedad: Función del R.I.: 25%.'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'Nefrectomía'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'Nefroma quístico multilocular'
# [21/250] es-S0210-48062003000900009-1.txt | 20.49s | 9 chunks | 4 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'Enfermedad: dolor testicular derecho, aumento del diámetro y de la consistencia testicular'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'Enfermedad: síndrome constitucional, pérdida de peso'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'Enfermedad: Fiebre, sudación profusa, no-clínica miccional, nohematuria.'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'Enfermedad: palidez mucocutánea, crepitantes en la auscultación pulmonar, edemas en miembros inferiores.'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'Enfermedad: edema, aumento de la consistencia, desaparición del surco, fluctuación, abcesificación.'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'Enfermedad: Tacto rectal, próstata, adenomatosa, grado II-III/IV.'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'Hemoglobina, 8,1 gr/dl, Plaquetas, 51000, Leucocitos, 9100.'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'Enfermedad: Coagulación elevación del fibrinógeno 1500 (límites de la normalidad inferior a 400).'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'Lactato deshidrogenasa (LDH) elevada, BHCG, CEA, AFP, función renal, hepática y pancreática normales.'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'Enfermedad: radiografia de tórax, congestión vascular, radiografia de abdomen'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'Enfermedad: ecografía renal y vesical, próstata'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'Enfermedad: Ecografía testicular, testículo derecho se distingue hasta tres áreas heterogéneas con disminución de la ecogenicidad, sin calcificaciones que afectan a polo superior, inferior y epidídimo, no-hidrocele.'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'Absceso testicular, tuberculosis testicular, brucelosis, tumor testicular.'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'Enfermedad: tumor testículo'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'Enfermedad: linfoma difuso B de células grandes, microscópicamente, testículo, linfoma, células grandes, linfoma difuso B, células grandes, proliferación, minb1, índice de proliferación, marcadores CD 20+.'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'Linfoma testicular primario'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'Enfermedad: sudación profusa, fiebre en picos, astenia, edemas de los miembros inferiores.'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'Enfermedad: anemia'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'Linfoma testicular primario'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'Plasmocitosis intersticial, infiltración por células linfoblásticas.'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'Enfermedad: anemia, trombocitopenia'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'Enfermedad: agregación plaquetaria, test de Coombs directo, débilmente positivo a inmunoglobulina G, causa de la agregación.'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'Enfermedad: disfonía, disfagia, lesión polipoidea'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'Enfermedad: TAC cervical normal.'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab, CHOP, ciclofosfamida, doxorrubicina, vincristina, prednisona, B, síntomas, fiebre.'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'Enfermedad: radioterapia genital coadyuvante, quimioprofilaxis cerebral.'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: 'Enfermedad:'
# [22/250] es-S0210-48062004000200011-1.txt | 60.63s | 29 chunks | 4 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: 'Enfermedad: tracto urinario inferior, inicio de aumento de frecuencia miccional nocturna, ligera disuria, leve disminución del calibre miccional.'
#   [chunk 2/12 | chars 224-442]
#   RAW: 'Enfermedad: prostática incipiente'
#   [chunk 3/12 | chars 442-700]
#   RAW: 'Enfermedad: traumatismo, ureterolitectomía'
#   [chunk 4/12 | chars 700-997]
#   RAW: 'Enfermedad: masa parahiliar en el riñón izquierdo'
#   [chunk 5/12 | chars 997-1381]
#   RAW: 'Enfermedad: tumoración renal'
#   [chunk 6/12 | chars 1381-1562]
#   RAW: 'MASA RENAL'
#   [chunk 7/12 | chars 1562-1624]
#   RAW: 'Enfermedad: lumbotomía izquierda'
#   [chunk 8/12 | chars 1624-1775]
#   RAW: 'Enfermedad: masa comprimiendo riñón'
#   [chunk 9/12 | chars 1776-1889]
#   RAW: 'Enfermedad: masa'
#   [chunk 10/12 | chars 1889-2050]
#   RAW: 'La mención de enfermedad es "tumoración".'
#   [chunk 11/12 | chars 2050-2234]
#   RAW: 'Enfermedad: exéresis de la masa, fragmentos deshilachados de una o varias gasas, material de aspecto caseoso.'
#   [chunk 12/12 | chars 2234-2418]
#   RAW: 'Enfermedad: tumoración'
# [23/250] es-S0210-48062004000500009-1.txt | 18.76s | 12 chunks | 1 menciones
#   [chunk 1/11 | chars 0-130]
#   RAW: 'Enfermedad: masa renal'
#   [chunk 2/11 | chars 130-212]
#   RAW: 'Colelitiasis, hidrocelectomía'
#   [chunk 3/11 | chars 213-358]
#   RAW: 'Enfermedad:'
#   [chunk 4/11 | chars 359-424]
#   RAW: 'La exploración física no objetiva masas abdominales ni megalias.'
#   [chunk 5/11 | chars 424-618]
#   RAW: 'Enfermedad: nódulo exofítico, ecografía, riñón derecho, áreas sólidas, quísticas, zonas vascularizadas (Eco-doppler)'
#   [chunk 6/11 | chars 619-824]
#   RAW: 'MASA RENAL COMPLEJA'
#   [chunk 7/11 | chars 825-1174]
#   RAW: 'Enfermedad: masa quística mínimamente complicada.'
#   [chunk 8/11 | chars 1174-1373]
#   RAW: 'Tumor renal'
#   [chunk 9/11 | chars 1373-1584]
#   RAW: 'Carcinoma de células claras renales, quístico multilocular, grado I de Fuhrman, con márgenes de resección negativos.'
#   [chunk 10/11 | chars 1584-1768]
#   RAW: 'Enfermedad: cortical renal, grasa adyacente, recidiva local'
#   [chunk 11/11 | chars 1769-1877]
#   RAW: 'Enfermedad:'
# [24/250] es-S0210-48062004000800009-1.txt | 17.42s | 11 chunks | 3 menciones
#   [chunk 1/18 | chars 0-125]
#   RAW: 'Enfermedades: HTA, Hipertiroidismo, Diabetes Mellitus tipo II, síndrome de ansiedad.'
#   [chunk 2/18 | chars 126-342]
#   RAW: 'Enfermedad: hematuria'
#   [chunk 3/18 | chars 342-444]
#   RAW: 'La exploración física puso de manifiesto la presencia de masa palpable a nivel de fosa lumbar derecha.'
#   [chunk 4/18 | chars 445-481]
#   RAW: 'Enfermedad: abdomen'
#   [chunk 5/18 | chars 481-622]
#   RAW: 'neoplasia'
#   [chunk 6/18 | chars 623-681]
#   RAW: 'La vejiga presentó ecos internos compatibles con coágulos.'
#   [chunk 7/18 | chars 682-723]
#   RAW: 'La enfermedad extraída del texto es: "estudio cistoscópico resultó anodino".'
#   [chunk 8/18 | chars 723-815]
#   RAW: 'Enfermedad: TAC abdominopélvico, Rx torax, bioquímica hemática y hemograma.'
#   [chunk 9/18 | chars 815-1067]
#   RAW: 'La TC mostró gran masa tumoral derecha de 9x10 cm heterogénea y con zonas hipodensas (áreas de necrosis) con distorsión del parénquima renal y su contorno, localizada en el polo inferior y con valores de atenuación inferiores a los del parénquima sano.'
#   [chunk 10/18 | chars 1068-1159]
#   RAW: 'La vena renal estaba trombosada y existían adenopatías locorregionales retroperitoneales.'
#   [chunk 11/18 | chars 1159-1259]
#   RAW: 'La presencia de anemia ferropénica, aumento de la VSG y normocalcemia.'
#   [chunk 12/18 | chars 1259-1377]
#   RAW: 'Enfermedad:'
#   [chunk 13/18 | chars 1377-1611]
#   RAW: 'Enfermedad: punción en la arteria femoral común derecha, arteriografía de aorta abdominal, cateterización selectiva de la arteria renal derecha.'
#   [chunk 14/18 | chars 1612-1842]
#   RAW: 'Enfermedad: tumor'
#   [chunk 15/18 | chars 1842-1978]
#   RAW: 'Enfermedad: buena evolución'
#   [chunk 16/18 | chars 1978-2122]
#   RAW: 'Cefalea'
#   [chunk 17/18 | chars 2123-2327]
#   RAW: 'Enfermedad:'
#   [chunk 18/18 | chars 2328-2451]
#   RAW: 'Enfermedad: IECAS, calcio antagonistas'
# [25/250] es-S0210-48062005000300014-1.txt | 33.01s | 18 chunks | 6 menciones
#   [chunk 1/23 | chars 0-303]
#   RAW: 'Enfermedades:\ncardiopatía isquémica, infarto de miocardio, arteriosclerosis de troncos supraaórticos, arteriosclerosis de extremidades inferiores, EPOC, hernia discal, estenosis de canal.'
#   [chunk 2/23 | chars 304-472]
#   RAW: 'Enfermedad: tramo urinario inferior'
#   [chunk 3/23 | chars 473-537]
#   RAW: 'Enfermedad: Hematuria con coágulos'
#   [chunk 4/23 | chars 538-662]
#   RAW: 'Enfermedad: deterioro del estado general, abdomen globuloso, cicatriz de toracotomía.'
#   [chunk 5/23 | chars 663-744]
#   RAW: 'Hiperplasia benigna grado II.'
#   [chunk 6/23 | chars 744-859]
#   RAW: 'Enfermedad:'
#   [chunk 7/23 | chars 859-954]
#   RAW: 'Enfermedad: lesión exofítica'
#   [chunk 8/23 | chars 955-1058]
#   RAW: 'La citología fue positiva para células malignas y la cistoscopia confirmó la lesión neoplásica vesical.'
#   [chunk 9/23 | chars 1059-1337]
#   RAW: 'carcinoma mixto, papilar de células transicionales grado II-III infiltrante de músculo liso con áreas de adenocarcinoma mucoide infiltrante asociado a lesiones de carcinoma in situ y cistitis glandular quística (estadio pT2-pT3 G-III)'
#   [chunk 10/23 | chars 1337-1535]
#   RAW: 'Enfermedad: engrosamiento de pared vesical, ateromatosis calcificada aorto-ilio-femoral'
#   [chunk 11/23 | chars 1535-1606]
#   RAW: 'Enfermedad: cistoprostatectomía, neovejiga ileal'
#   [chunk 12/23 | chars 1607-1681]
#   RAW: 'Enfermedad: postoperatorio'
#   [chunk 13/23 | chars 1681-2063]
#   RAW: 'La enfermedad es: carcinoma seroso ovárico.'
#   [chunk 14/23 | chars 2064-2101]
#   RAW: 'Enfermedad: psammoma'
#   [chunk 15/23 | chars 2102-2257]
#   RAW: 'Displasia epitelial en uretra prostática, carcinoma de próstata bien diferenciado en lóbulo derecho Gleason 4 (2+2).'
#   [chunk 16/23 | chars 2258-2433]
#   RAW: 'En pieza de linfadenectomía izquierda se aislaron 11 ganglios afectados por carcinoma micropapilar mientras que los ganglios linfáticos contralaterales no estaban afectados.'
#   [chunk 17/23 | chars 2433-2569]
#   RAW: 'Enfermedad: Immunofenotípico, componente micropapilar, citoqueratina 7, CA125, citoqueratina 20, BX2, P53, CEA.'
#   [chunk 18/23 | chars 2569-2698]
#   RAW: 'Neoplasia'
#   [chunk 19/23 | chars 2699-2883]
#   RAW: 'Enfermedades: infección urinaria, anemia, leucopenia'
#   [chunk 20/23 | chars 2883-3084]
#   RAW: 'La mención de la enfermedad es "neovejiga".'
#   [chunk 21/23 | chars 3085-3184]
#   RAW: 'Neoplasia'
#   [chunk 22/23 | chars 3185-3362]
#   RAW: 'Enfermedad: recidiva mesentérica, dilatación renoureteral'
#   [chunk 23/23 | chars 3363-3520]
#   RAW: 'Enfermedad: neoplasia'
# [26/250] es-S0210-48062005000400012-1.txt | 46.35s | 23 chunks | 4 menciones
#   [chunk 1/14 | chars 0-252]
#   RAW: 'Diabetes mellitus tipo I, prostatitis crónica, neoplasia'
#   [chunk 2/14 | chars 253-383]
#   RAW: 'Enfermedad:'
#   [chunk 3/14 | chars 384-463]
#   RAW: 'Enfermedad: Hemocultivos en medios convencionales y de Ruiz Castañeda fueron negativos.'
#   [chunk 4/14 | chars 464-603]
#   RAW: 'Enfermedad: Brucella'
#   [chunk 5/14 | chars 603-699]
#   RAW: 'Enfermedad:'
#   [chunk 6/14 | chars 699-778]
#   RAW: 'Enfermedad: recaída, dolor lumbar, fiebre'
#   [chunk 7/14 | chars 779-873]
#   RAW: 'La exploración la región ilíaca izquierda está empastada junto con signo del psoas positivo.'
#   [chunk 8/14 | chars 874-1072]
#   RAW: 'Enfermedad: espondilodiscitis, absceso'
#   [chunk 9/14 | chars 1073-1166]
#   RAW: 'Enfermedad: reanudar tratamiento antibiótico previo'
#   [chunk 10/14 | chars 1167-1288]
#   RAW: 'Enfermedad: mala respuesta al tratamiento, colecciones del psoas.'
#   [chunk 11/14 | chars 1288-1512]
#   RAW: 'Enfermedad: abscesos de psoas, espondilodiscitis'
#   [chunk 12/14 | chars 1513-1701]
#   RAW: 'Enfermedad: drenaje, discectomía'
#   [chunk 13/14 | chars 1702-1889]
#   RAW: 'Enfermedad: postoperatorio'
#   [chunk 14/14 | chars 1889-2001]
#   RAW: 'Enfermedad:'
# [27/250] es-S0210-48062005000700012-1.txt | 20.23s | 14 chunks | 1 menciones
#   [chunk 1/9 | chars 0-273]
#   RAW: 'Enfermedad: ulcus gástrico, vasectomizado, aumento moderado de volumen escrotal izquierdo, molestias sordas.'
#   [chunk 2/9 | chars 274-308]
#   RAW: 'Enfermedad: No síntomas miccionales ni fiebre.'
#   [chunk 3/9 | chars 309-436]
#   RAW: 'Hidrocele de mediano tamaño'
#   [chunk 4/9 | chars 437-494]
#   RAW: 'Enfermedad:'
#   [chunk 5/9 | chars 495-675]
#   RAW: 'neoplasia testicular hidrocele'
#   [chunk 6/9 | chars 676-720]
#   RAW: 'Enfermedad: Marcadores tumorales (AFP y ß-HCG) normales.'
#   [chunk 7/9 | chars 721-814]
#   RAW: 'Enfermedad: orquiectomía, prótesis testicular siliconada'
#   [chunk 8/9 | chars 815-895]
#   RAW: 'Enfermedad: TAC abdominal'
#   [chunk 9/9 | chars 896-1115]
#   RAW: 'Enfermedad: infarto testicular'
# [28/250] es-S0210-48062006000200018-1.txt | 13.40s | 9 chunks | 1 menciones
#   [chunk 1/20 | chars 0-213]
#   RAW: 'Enfermedad: masa testicular izquierda'
#   [chunk 2/20 | chars 214-416]
#   RAW: 'Enfermedad: masa testicular'
#   [chunk 3/20 | chars 417-715]
#   RAW: 'Enfermedad: 2 imágenes redondeadas, bien definidas de tamaño, forma y ecogenicidad similar, con medidas en promedio 9 x 11 mm, que presentaban además un patrón doppler similar.'
#   [chunk 4/20 | chars 716-764]
#   RAW: 'Enfermedad: lesiones'
#   [chunk 5/20 | chars 765-1091]
#   RAW: 'MASA TESTICULAR, TESTICULO SUPERNUMERARIO, RESONANCIA NUCLEAR MAGNÉTICA, TESTÍCULO, ESTRUCTURAS, SACO ESCROTAL, PRESENCIA, OVALADO, DOS, UNO, ADICIONAL, FIGURA'
#   [chunk 6/20 | chars 1092-1094]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 7/20 | chars 1094-1121]
#   RAW: 'Enfermedad: sin masas ni adenopatías.'
# ...
#   [chunk 12/17 | chars 2481-2686]
#   RAW: 'Enfermedad: necrosada, perforación, asa, cirugía abierta.'
#   [chunk 13/17 | chars 2687-2916]
#   RAW: 'Enfermedad: hernia interna, obstrucción, estrangulación del ileon.'
#   [chunk 14/17 | chars 2917-3052]
#   RAW: 'Hernia, ileon necrosado, anastomosis termino-terminal manual.'
#   [chunk 15/17 | chars 3053-3134]
#   RAW: 'Enfermedad: herniario'
#   [chunk 16/17 | chars 3135-3259]
#   RAW: 'Enfermedad:'
#   [chunk 17/17 | chars 3260-3307]
#   RAW: 'El control postoperatorio al mes es correcto.'
# [242/250] es-S1887-85712012000400006-1.txt | 30.59s | 17 chunks | 4 menciones
#   [chunk 1/13 | chars 0-274]
#   RAW: 'Enfermedad: desorientación, dificultad en la articulación del lenguaje, visión borrosa, visión doble vertical.'
#   [chunk 2/13 | chars 275-356]
#   RAW: 'No ha presentado pérdida de conciencia, palpitaciones, dolor torácico ni fiebre.'
#   [chunk 3/13 | chars 356-532]
#   RAW: 'Enfermedad: hipertension, dislipidemia, neoplasia'
#   [chunk 4/13 | chars 532-751]
#   RAW: 'Enfermedades:\nparesia del IV par craneal del ojo derecho, afectación incompleta del III par bilateral y VI par derecho de predominio inferior manifestada en forma de diplopía binocular vertical.'
#   [chunk 5/13 | chars 752-797]
#   RAW: 'Enfermedad: resto de los pares craneales'
#   [chunk 6/13 | chars 798-911]
#   RAW: 'Enfermedad: Tampoco se evidencia déficit motor ni sensitivo asociados, Romberg negativo, no dismetrías y no signos meníngeos.'
#   [chunk 7/13 | chars 912-1000]
#   RAW: 'Enfermedad: alteración de la marcha, tendencia a la lateropulsión'
#   [chunk 8/13 | chars 1000-1343]
#   RAW: 'Enfermedad: TC craneal de 64 canales'
#   [chunk 9/13 | chars 1343-1492]
#   RAW: 'Enfermedad: diplopia, oclusión monocular alternante, inestabilidad, trastorno de la marcha.'
#   [chunk 10/13 | chars 1492-1824]
#   RAW: 'Enfermedad: microinfartos solitarios, lesiones isquémicas agudas.'
#   [chunk 11/13 | chars 1825-1931]
#   RAW: 'Enfermedad: lesiones'
#   [chunk 12/13 | chars 1931-2108]
#   RAW: 'Enfermedad: Embolía'
#   [chunk 13/13 | chars 2109-2269]
#   RAW: 'La evolución de la paciente fue favorable y, con el tratamiento rehabilitador se consiguió autonomía de la marcha, presentó mejoría progresiva de la diplopía.'
# [243/250] es-S1887-85712014000100005-1.txt | 27.69s | 13 chunks | 2 menciones
#   [chunk 1/21 | chars 0-234]
#   RAW: 'Enfermedad: carcinoma de recto'
#   [chunk 2/21 | chars 235-357]
#   RAW: 'Artrosis'
#   [chunk 3/21 | chars 357-745]
#   RAW: 'Enfermedad: SCAEST-Killip III'
#   [chunk 4/21 | chars 746-996]
#   RAW: 'Enfermedad: hematoma'
#   [chunk 5/21 | chars 996-1242]
#   RAW: 'Enfermedad: dolor, exacerbado con la extensión pasiva de dedos (extensión de musculatura flexora de antebrazo).'
#   [chunk 6/21 | chars 1242-1253]
#   RAW: 'Palidez.'
#   [chunk 7/21 | chars 1253-1307]
#   RAW: 'Enfermedad: imposibilidad para detectar pulso radial o cubital.'
#   [chunk 8/21 | chars 1307-1373]
#   RAW: 'Enfermedad: Disminución de la temperatura'
#   [chunk 9/21 | chars 1373-1425]
#   RAW: '- Anestesia y parálisis total del miembro afectado.'
#   [chunk 10/21 | chars 1425-1655]
#   RAW: 'Enfermedad: Intra-Compartmental pressure monitor system'
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'Síndrome compartimental agudo en antebrazo derecho'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: 'Enfermedad:'
#   [chunk 13/21 | chars 1907-1969]
#   RAW: 'Enfermedad: Profilaxis antibiótica con 2 gramos de Cefazolina intravenosa.'
#   [chunk 14/21 | chars 1970-2110]
#   RAW: 'Enfermedad: incisión cutánea, línea media, cara volar, antebrazo, flexura de codo, línea de Kaplan.'
#   [chunk 15/21 | chars 2111-2191]
#   RAW: 'Enfermedad: Hematoma'
#   [chunk 16/21 | chars 2192-2410]
#   RAW: 'Enfermedad: \n- neoplasia\n- descompresión del nervio mediano\n- ligamento anular del carpo'
#   [chunk 17/21 | chars 2411-2487]
#   RAW: 'No se observaron lesiones vasculares con signos de sangrado activo arterial.'
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'Enfermedad: Nitrofural'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: 'Enfermedad: fasciotomía'
#   [chunk 20/21 | chars 2901-3087]
#   RAW: 'Enfermedad: relleno capilar inferior a 2 segundos, movilidad y sensibilidad distal'
#   [chunk 21/21 | chars 3088-3211]
#   RAW: 'La paciente presentó ausencia de dolor en antebrazo derecho, con buen estado vasculonervioso distal.'
# [244/250] es-S1887-85712016000100005-1.txt | 32.91s | 21 chunks | 6 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: 'Enfermedad: coxalgia'
#   [chunk 2/22 | chars 128-229]
#   RAW: 'Enfermedad: dolor, limitación de movilidad'
#   [chunk 3/22 | chars 230-429]
#   RAW: 'Enfermedad:'
#   [chunk 4/22 | chars 430-528]
#   RAW: 'Enfermedad: dolor'
#   [chunk 5/22 | chars 528-725]
#   RAW: 'Enfermedad: dolor a la palpación en tercio medio de la región inguinal derecha con dolor a la flexión, aducción y rotaciones sobre todo interna (maniobra de choque positiva).'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'Enfermedad: balance articular de caderas, flexión, rotación interna, rotación externa.'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'Enfermedad: balance muscular'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'Enfermedad: No presenta dolor a la palpación de puntos ciáticos y las maniobras de Valleix, Fabere, Lasegue y Bragard son negativas.'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'Enfermedad: Tampoco presenta dolor a la palpación en la cintilla iliotibial y el test de Ober es negativo.'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'Enfermedad: claudicación'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'Enfermedad: dolor para la marcha con flexión forzada de cadera y rodilla.'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'Enfermedad: joroba'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'Enfermedad:'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'Enfermedad: leve alteración subcondral, edema óseo, irregularidad cortical, sinovitis, distensión de la bursa ilio-psoas.'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'Enfermedad: islote óseo, ángulo alfa'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'Enfermedad: artrografía, pinzamiento, interlinea articular antero-superior y posteroinferior, incipiente collar osteofitario femoral, lesiones subcondrales antero-superiores de cabeza femoral, edema en acetábulo anterosuperior.'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'Necrosis avascular, lesiones en el labrum.'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'Lesión quística yuxtaarticular en relación con trocánter mayor.'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'Enfermedad: síndrome de pinzamiento femoroacetabular tipo LEVA (CAM)'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'Enfermedad: glucosamina-condroitin sulfato, antiinflamatorios no esteroideos'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'Enfermedad: reposo deportivo, choque en la articulación, actividad física activa controlada, flexión de la cadera, rotaciones.'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'Enfermedad: artroscopia, cirugía artroscópica'
# [245/250] es-S1888-75462015000400006-1.txt | 43.80s | 22 chunks | 1 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'Enfermedad: fractura de tercio medio de clavícula derecha, fractura de arcos costales derechos'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'Enfermedad:'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'Fractura de arcos costales derechos cuarto y quinto, fractura de tercio medio de la clavícula derecha con tercer fragmento.'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'Enfermedad: edematización del miembro superior derecho'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'Enfermedad: CHCM, neutrófilos, linfocitos, eosinófilos, fibrinógeno, GGT, D-Dímero.'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'Enfermedad: trombosis venosa de las venas axilar, cefálica y basílica con compresión de la rama cubital del nervio cutáneo braquial medial a nivel del hiato basílico.'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'Enfermedad: fractura de clavícula, trombosis de las venas'
# [246/250] es-S1888-75462016000400180-1.txt | 15.94s | 7 chunks | 0 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'Enfermedad:'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'Enfermedad: histerectomía, miomas'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'Enfermedad: osteoporosis densitométrica lumbar, osteoporosis'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'Enfermedad: dolor mecánico en el pie izquierdo, refractario a AINEs.'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'Enfermedad: dolor a la movilización del antepié izquierdo.'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'Enfermedad: No se observaron alteraciones de la estática de pies.'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'La paciente aportaba Rx de pies que no mostraba hallazgos patológicos.'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'Enfermedad: fractura de estrés en el 2o MTT con callo perióstico y edema de tejidos blandos.'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'Enfermedad: Hipoparatireoidismo'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'Enfermedad:'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'Enfermedad: Traumatología'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'Enfermedad: osteoporosis'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'Enfermedad: callo de fractura antiguo, fractura de estrés previa'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'Enfermedad: edema, tenosinovitis, tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: '-3.5'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'Enfermedad: osteoporosis'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'Las fracturas fueron tratadas con rehabilitación y descarga con mejoría progresiva.'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'Osteoporosis'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'Enfermedad: episodios de dolor'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'Enfermedad: fracturas de estrés'
# [247/250] es-S1889-836X2015000200005-2.txt | 29.02s | 20 chunks | 3 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'Enfermedad: infección por VIH'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'Enfermedad: astenia, dolores óseos'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'Enfermedad: elevación de la fosfatasa alcalina (FA) total y ósea, así como de la paratohormona (PTH).'
#   [chunk 4/16 | chars 408-569]
#   RAW: '25-hidroxivitamina D, calcio total e iónico, y otros parámetros bioquímicos rutinarios en suero, y elemental y sedimento de orina fueron normales.'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'Enfermedad: radiografia simple de columna, degenerativos, gammagrafía con Tc99, normal.'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'Enfermedad: empeoró, astenia, disminución de fuerza, dificultad para caminar, pérdida de peso.'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'Enfermedad: debilidad muscular de predominio proximal.'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'Enfermedad: hiperglucemia, glucosuria, hipofosfatemia, fosfaturia, hipouricemia, acidosis metabólica, proteinuria.'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'Enfermedad: aminoaciduria moderada, con valores aumentados de glicina, valina, serina y treonina.'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'Enfermedad: FGF23'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Enfermedad: Otros parámetros se muestran en la Tabla 1.'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'Fanconi syndrome incomplete, hypophosphatemia, osteomalacia'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'Enfermedad: retiró, fármaco, tratamiento, raltegravir, darunavir, ritonavir.'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'Enfermedad: 25-HCC, 1,25-dihidroxivitamina D (1,25 DHCC)'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'Enfermedad:'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'Enfermedad: retirada de TDF, dolores óseos, debilidad muscular, recuperación del peso basal, alteraciones analíticas séricas, reabsorción de fosfato.'
# [248/250] es-S1889-836X2015000400006-1.txt | 35.66s | 16 chunks | 0 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'Enfermedad: lupus cutáneo, eritema malar'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Tiroiditis de Hashimoto.'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'Apendicectomía.'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'Enfermedad: Exfumadora'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'Enfermedad: No bebedora.'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'Enfermedad: No hábitos tóxicos, excepto en tomas de bebidas con quinina (tónicas).'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'Anemia'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'Enfermedad: Cesárea, ligadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'Enfermedad actual:\nIntensa astenia y presíncopes (de una semana de evolución), que dificultan la deambulación, junto con anorexia sin pérdida de peso.'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'Enfermedad: Menstruación muy duradera (8 días) y abundante.'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'Enfermedad: melénicas, palidez cutánea y mucosa.'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'Epistaxis y gingivorragia.'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'Enfermedad: anemia, trombopenia'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'Enfermedad: LDH 1696 UI/l. Frotis sanguíneo con presencia de esquistocitos.'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'Enfermedad: PTT, LES'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'Enfermedad:'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'Enfermedad: afasia global, desviación de la comisura bucal a la izquierda'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'Enfermedad: Posteriormente habla con lenguaje normal sin focalidad evidente.'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'Enfermedad:'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'Microangiopatía trombótica, crisis convulsivas'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'La paciente ingresa en UCI debido al empeoramiento clínico.'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'Enfermedad: plasmaféresis'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'Enfermedad: tratamiento'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'La paciente pesa 75 kgr.'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'Enfermedad:'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'Enfermedad: volumen a reinfundir'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'Enfermedad: plasma fresco'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'Enfermedad: albúmina humana al 20% + 1.400 cc.'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'Enfermedad: solución Dianeal® 1,36% de diálisis peritoneal.'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'Enfermedad: plasmaféresis, catéter, yugular, femoral'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE (Hospal®)'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'Enfermedad: heparina'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'Enfermedad: hipertensión'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'Enfermedad: mal estado general'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: 'Enfermedad:'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'Enfermedad: Incidencia'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'Enfermedad: hipotensión, convulsiones'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'Enfermedad: PTM'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'Enfermedad: fallo del test de aire'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'Enfermedad: resto de las sesiones, paciente.'
# [249/250] es-S2254-28842014000200009-1.txt | 55.73s | 40 chunks | 8 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Enfermedad: carcinoma seroso papilar en ovario izquierdo, afectación de un ganglio de la cadena aorto-cava'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'Neoplasia'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'Enfermedad: metastasis'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'Enfermedad: CA 125'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'Enfermedad: disnea, vómitos, pérdida de conocimiento, TAS/TAD de 70/50 mmHg.'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'Neoplasia'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'La Unidad de Alergología, recomendó esquema de desensibilización5 con enlentecimiento de la velocidad de infusión.'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'Enfermedad: disnea, sudoración, tensiones de 85/60 mmHg'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'Trabectedina, adriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'Enfermedad:'
# [250/250] es-S2340-98942015000100005-1.txt | 17.41s | 11 chunks | 1 menciones
#
# Predicciones guardadas en distemist_llm_predictions.tsv
# Tiempo medio por archivo: 28.66s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd


def prf(tp, fp, fn):
    p  = tp / (tp + fp) if (tp + fp) else 0.0
    r  = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1


df_pred  = pd.read_csv(PREDICTIONS_TSV, sep="\t")
df_gs    = pd.read_csv(GS_TEST_TSV, sep="\t")
df_gs    = df_gs[df_gs["filename"].isin(df_pred["filename"].unique())]

set_gs   = set(zip(df_gs["filename"],   df_gs["label"],   df_gs["off0"],   df_gs["off1"]))
set_pred = set(zip(df_pred["filename"], df_pred["label"], df_pred["off0"], df_pred["off1"]))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1   = prf(tp, fp, fn)

report = {"Estricta": {"tp": tp, "fp": fp, "fn": fn, "precision": round(p, 4), "recall": round(r, 4), "fscore": round(f1, 4)}}

print(f"── ESTRICTA ──  P={p:.4f}  R={r:.4f}  F1={f1:.4f}  (TP={tp} FP={fp} FN={fn})\n")

thresholds = [0.0, 0.5, 0.8]
results    = {t: {"tp": 0, "fp": 0, "fn": 0} for t in thresholds}

for filename in df_pred["filename"].unique():
    gs_ints   = list(zip(df_gs[df_gs["filename"] == filename]["off0"],   df_gs[df_gs["filename"] == filename]["off1"]))
    pred_ints = list(zip(df_pred[df_pred["filename"] == filename]["off0"], df_pred[df_pred["filename"] == filename]["off1"]))

    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )

    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi); matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ──  P=0.1958  R=0.0644  F1=0.0970  (TP=157 FP=645 FN=2279)
#
# ── IoU ──
# IoU >= 0.0:  P=0.5761  R=0.1897  F1=0.2854  (TP=462 FP=340 FN=1974)
# IoU >= 0.5:  P=0.3180  R=0.1047  F1=0.1575  (TP=255 FP=547 FN=2181)
# IoU >= 0.8:  P=0.2544  R=0.0837  F1=0.1260  (TP=204 FP=598 FN=2232)
