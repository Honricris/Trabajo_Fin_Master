# %% [markdown]
# # Pipeline Zero-Shot NER — DisTemIST con salamandra-7b-instruct
#
# Inferencia zero-shot para reconocimiento de enfermedades en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "BSC-LT/salamandra-7b-instruct"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo ENFERMEDAD.\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'neoplasia', no escribas 'cancer'.\n"
    "4. REPETICIONES: Si una enfermedad aparece varias veces en el texto, debes listarla varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio (como '-', '*', '•', '1.').\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
DISTEMIST_ROOT       = f"{PROJECT_ROOT}/distemist/distemist"
TEXT_FILES_TEST_DIR  = f"{DISTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{DISTEMIST_ROOT}/distemist_subtrack1_test_mentions.tsv"
PREDICTIONS_TSV      = "distemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : BSC-LT/salamandra-7b-instruct
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name        = MODEL_NAME,
    max_seq_length    = MAX_SEQ_LENGTH,
    dtype             = torch.float16,
    load_in_4bit      = True,
    token             = hf_token,
    trust_remote_code = True,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.6.1: Fast Llama patching. Transformers: 5.10.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.81M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/19.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/513 [00:00<?, ?B/s]
# Unsloth: Will load BSC-LT/salamandra-7b-instruct as a legacy tokenizer.
# Modelo cargado: BSC-LT/salamandra-7b-instruct
# Parámetros totales: 4,932,767,744

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    """Divide el texto en chunks de oraciones completas con sus offsets.
    Si max_chars es None, devuelve una oración por chunk."""
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

def build_ner_messages(text):
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": f"Texto para analizar:\n{text}"},
    ]

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            full_output = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue


        marker = "<|im_start|>assistant"
        idx    = full_output.rfind(marker)
        result = full_output[idx + len(marker):].strip() if idx != -1 else full_output.strip()
        result = re.sub(r"<think>.*?</think>", "", result, flags=re.DOTALL).strip()

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        # Búsqueda de offsets con cursor por mención (maneja repeticiones)
        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename": txt_path.stem,
            "mark":     f"T{mark_idx}",
            "label":    "ENFERMEDAD",
            "off0":     off0,
            "off1":     off1,
            "span":     span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "mark", "label", "off0", "off1", "span"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer LlamaTokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'Enfermedad: Obesidad\nEnfermedad: Diabetes Mellitus\nEnfermedad: Hipertensión Arterial'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'Esporádico es sinónimo de ocasional o poco frecuente. Por lo tanto, si se trata de una sola ocasión y ya pasó, entonces no tengo ninguna sugerencia médica sobre este asunto. De otra manera, te recomiendo consultar con tu médico tratante.'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'No se encontró ninguna enfermedad en la exploración física.'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'Masa suprarrenal derecha hipoecogénica de 80 mm que comprime el polo superior del riñón derecho.'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'Enfermedad: Proceso expansivo en la suprarrenal derecha y desplazamiento del polo superior del riñón derecho.'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'Neoplasia suprarrenal'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'No se encontró ninguna entidad de tipo "ENFERMEDAD" en el texto proporcionado. Por lo tanto, mi respuesta será un texto vacío.'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'Enfermedad: Cirugía por abordaje lumbar.'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'Tumor de la glandula supresrenal derecha'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'Adrenalectomia derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'Asintomatica'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'No se encontraron enfermedades en este texto.'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'Mielolipoma de la glandula adrenal con extensas areas de calcificaciones.'
# [1/250] S0004-06142006000100010-1.txt | 21.75s | 13 chunks | 0 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'Adenocarcinoma gástrico'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'Enfermedad: Anorexia\nEnfermedad: Pérdida de peso\nEnfermedad: Hipocromica Anemia\nEnfermedad: Estreñimiento'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'Tumoración abdominal firme e indolora'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'Adenocarcinoma gastrico'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'Análisis del texto:\nNo se menciona ninguna entidad relacionada con enfermedades. Por lo tanto, no es posible extraer ninguna información relevante sobre patologías o condiciones médicas específicas.'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'PÓLIPO INFLAMATORIO'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'Desplazamiento intestinal e intolerancia del paciente.'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'Tumoración quística con tabiques incompletos'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'riñon normal izquierda'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'Enfermedad: Lesión quística voluminosa intraabdominal'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'Enfermedad: Hidronefrosis'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'Hidronefrosis gigante'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'Nefrectomia simple derecha'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'Enfermedad: Linfadenectomia hiliar ampliada'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'Resultado del análisis:\nNegativo'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'Neoplasia renal'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'Enfermedad: Displasia renal'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'Carcinoma de células renales tipo célula clara'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'Metastasis hepaticas'
# [2/250] S0004-06142006000100014-1.txt | 21.34s | 21 chunks | 7 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'Varicocele derecho'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'Prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'No se encontró ninguna entidad del tipo "ENFERMEDAD".'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'Enfermedad: Prostatitis'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'texto vacío'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'Hemangioma'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'No se encontró ninguna entidad relacionada con enfermedades en el texto proporcionado. Por lo tanto, mi respuesta es vacía.'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'PSA'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'PSA'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'Orquiectomia radical inguinal derecha.'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'Tumor de células de Leydig difuso'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'Enfermedad: cáncer/tumor/metastasis'
# [3/250] S0004-06142006000500002-2.txt | 12.38s | 14 chunks | 6 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'Neoplasia de testículo'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Enfermedad: Uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'Enfermedad: Cólico nefrítico \nSubenfermedades: Repetición, litiasis, tratamiento con LEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Enfermedad: Ureterolitectomia'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'No se menciona ninguna enfermedad relacionada con fumar. Por lo tanto, mi respuesta es vacía.'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'Nódulo testicular'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'Azoospermia'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'Tumor testicular'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'Quiste de epididimitis'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'No es posible determinar ninguna entidad patológica a partir del texto proporcionado.'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'Vacío.'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'Enfermedad: Analíticas normales'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'Vacío'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'Enfermedad: Sin observaarse infiltracion de tunica vaginalis.'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'Nódulo sólido bien delimitado de 1,5 cm de diámetro de coloración parda con área amarillenta central.'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'No se menciona ninguna enfermedad en este texto. Por lo tanto, mi respuesta será "texto vacío".'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'No se encontraron enfermedades relacionadas con el texto proporcionado.'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'Biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Tumor de celulas de Leydig'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'Enfermedad: Atrofia testicular \nEnfermedad: Hiperplasia de células de Leydig \nEnfermedad: Práctica ausencia de espermiogenesis'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'No se encontraron enfermedades relacionadas con los bordes quirúrgicos libres.'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'ATROFIA TESTIULAR \n- Hiperplasia de celulas de Leydig intersticial.\nAusencia de ESPERMIOGENESIS'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'Enfermedad: cáncer'
# [4/250] S0004-06142006000500002-3.txt | 31.03s | 25 chunks | 5 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'Masa renal derecha'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'Nefrectomia radical derecha'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'Carcinoma renal de células claras de 8,4 cm, estadio T3aN0M0, II de Robson y grado nuclear IV de Fuhrman.'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'No se menciona ninguna enfermedad o condición médica específica en este texto. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'Neoplasia'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'Enfermedad: Recidiva tumoral'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'Carcinoma de células claras de alto grado'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'No se menciona ninguna enfermedad o afección específica en este texto. Por lo tanto, mi respuesta es vacía.'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Enfermedad: cáncer'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'Múltiples lesiones hepáticas'
# [5/250] S0004-06142006000900015-1.txt | 13.46s | 11 chunks | 3 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'No se menciona ninguna enfermedad relacionada con este paciente. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'Neoplasia testicular izquierda e indeterminaciones en la derecha.'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'Enfermedad: Urología'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'No se menciona ninguna entidad relacionada con enfermedades en este texto, así que mi respuesta es vacía: " ".'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'No es posible determinar ninguna patología a partir del texto proporcionado.'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'No se encontraron enfermedades en este texto.'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'epididymis and spermatic cords without pathological findings.'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'alfa-feto proteina 2.7 ng/ml'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'Lesión hipoecoica, de bordes lobulados, heterogénea, que ocupa prácticamente todo el testículo, y que presenta aumento del flujo Doppler.'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'Microlitiasis testicular bilateral.'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'Tumor testicular bilateral'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'Neoplasia intraepitelial testicular'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'Seminoma classic'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'Enfermedad: Tumor'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'Carboplatino'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'Enfermedad: REMISION COMPLETA'
# [6/250] S0004-06142007000200017-1.txt | 20.35s | 18 chunks | 3 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'No se menciona ninguna enfermedad o afección relacionada con el paciente. Por lo tanto, mi respuesta es: "No se especifica".'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'Enfermedad: Aumento progresivo de los órganos genitales externos, trasudación de la linfa e impotencia sexual.'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'Neoplasia genital externa.'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'Enfermedad: Adenopatías inguinales no dolorosas.'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'Enfermedad: Normalidad del hemograma completo.'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'Enfermedad: Serología'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'Psoas derecho engrosado de 48 mm'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'Enfermedad: Exploración retroperitoneal derecha.'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'Enfermedad: Adenoma de células de Merkel'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'Linfangioplastia con aguja.'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'fasciotomia de la raiz del pene'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'Quiluria'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'linfedema primario inflamatorio local de pene y escroto'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'Necosis aséptica de la cabeza del femur.'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'Linfangiectomia'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'Enfermedad: Distorsión y atrapamiento de los conductillos linfáticos a consecuencia del tejido conjuntivo fibroso aumentado y disminución de las fibras elásticas.'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'Neoplasia, tumor, cáncer, sarcoma, carcinoma, neoplasias malignas, hiperplasia, hipertrofia, atrofia, inflamación, infección, traumatismo, isquemia, congestión, hematomas, hemorragias, necrosis, gangrena, abscesos, fístulas, estenosis, oclusión arterial, trombosis, embolismos, compresiones nerviosas, parestesias, neuralgia, neuritis, radiculopatías, mononeuropatía, polineuritis, poliradiculopatías, mielinólisis, mielopatías, neuroinfecciones, síndromes dolorosos, síndrome de cauda equina, lesiones medulares, hernias discales, espondilolistesis, escoliosis, lordosis, cifoescoliosis, artrosis, artritis, bursitis, tendinitis, entesitis, epicondilitis, epitrocleítis, tenosinovitis, periartritis, capsulitis, sinovitis, osteomielitis, osteoporosis, fracturas, luxaciones, dislocaciones, esguinces, contusiones, quemaduras, amputaciones, infecciones, tumores, metástasis, enfermedades autoinmunitarias, trastornos vasculares periféricos, insuficiencia vascular, claudicación intermitente, flebitis, tromboflebitis, varices'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'La respuesta es: neoplasia'
# [7/250] S0004-06142007000600012-1.txt | 40.98s | 20 chunks | 4 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'Nódulo testicular'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'Nódulo duro, móvil y doloroso a la palpación a nivel del cordón espermático derecho.'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'Marcador tumoral'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'Imagen ovalada e hipoecoica'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'fibrosis del cordón espermático derecho'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'Tumoración paratestícular derecha'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'Asintomatico'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'No es posible determinar ninguna entidad patológica a partir del texto proporcionado.'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'La respuesta es: Neoplasia'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'Neoplásica, desmina, vimentina, actina de músculo liso.'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'No se encontraron enfermedades relacionadas con "Granada".'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'No se encontró ninguna entidad de tipo "ENFERMEDAD" en el texto proporcionado. Por lo tanto, mi respuesta es vacía.'
# [8/250] S0004-06142007000600014-1.txt | 14.06s | 12 chunks | 1 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'Herida de arma de fuego en la nalga'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'Enfermedad: Herida de bala en el muslo derecho.'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'No se menciona ninguna enfermedad específica en el texto proporcionado. Por lo tanto, mi respuesta será "no se especifica".'
#   [chunk 4/18 | chars 406-568]
#   RAW: '- Bala \n- Fractura de la rama descendente derecha del pubis'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'Enfermedad: Retención urinaria \nCausante: Imposibilidad del sondaje uretral.\nSolución: Colocación de Cateterismo suprapúbico.'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'La respuesta es "colostomia"'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'Enfermedad: Urethritis'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'Enfermedad: Perforación rectal.'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'Enfermedad: Uretritis'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'Sonda 18'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'No hay enfermedades mencionadas en este texto.'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'Enfermedad: Hiperplasia prostática.'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'No es posible determinar ninguna entidad patológica a partir del texto proporcionado. Por lo tanto, mi respuesta será "texto vacío".'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'Sonda'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'Enfermedad: Colitis ulcerosa'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'No hay enfermedades en este texto.'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'No es posible determinar ninguna enfermedad a partir del texto proporcionado. Por lo tanto, mi respuesta será vacía.'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'Ultrasonido normal'
# [9/250] es-S0004-06142007000900010-1.txt | 22.58s | 18 chunks | 1 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Enfermedad: Hernia Discal'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'neoformacion solida en rinon derecho de 5 cm'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'Masa cortical de riñon derecho de aprox 5cm con bordes lobulares sin afectación del espacio peripatelar y sin adenompatías ni dilatacion de vias renales excretoras.'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'hipernefroma'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'Neoformacion cortical de 5cm de diametro maximo'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'Neoplasia'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'Vimentina\nCitoqueratina 7\nCitoqueratina de amplio espectro\nCD34\nCromogranina\nEMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'No se encontraron enfermedades relacionadas con "Granada".'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'No se encontró ninguna entidad de tipo "ENFERMEDAD" en el texto proporcionado. Por lo tanto, mi respuesta es vacía.'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'vimentina\ncitoqueraina 7\nEMA\nCD34'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'Asintomatica'
# [10/250] es-S0004-06142007000900012-1.txt | 15.52s | 11 chunks | 11 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK, sinusitis bilateral, bronquiectasias, desprendimiento retina ojo derecho, aumento del tamaño testicular e induración.'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'Dolor Lumbar'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'Neoplasia'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'Adenopatía'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'Tumor testicular tipo seminoma'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'Situs inversus\nCámara de gases gástrica derecha\nImagen cicatrizal con posibles bronquiectasias en lóbulo inferior izquierdo'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'No es posible determinar ninguna enfermedad a partir del texto proporcionado.'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'a-Fetoproteina\nb-hCG'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'Seminoma classic of 2.5 cm in diameter affecting the tunica albuginea (without exceeding it) and respecting the epididymis, the rete testis, the spermatic cord, and the surgical margins.'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'texto vacío'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Neoplasia germinal intratubular.'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'fibrosis e hialinizacion tubular de testiculo no tumoral'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'Seminoma grado 1'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'Azooespermia'
# [11/250] es-S0004-06142008000300011-1.txt | 17.66s | 14 chunks | 7 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'Enfermedad: Dolor abdominal difuso'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'Dolor + aumento + tos + inspiracion'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'Enfermedad: Sin síntomas específicos.'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'Respuesta: Colitis ulcerosa. Acolia.'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'No es posible determinar ninguna entidad patológica a partir del texto proporcionado.'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'Enfermedad: Palidez mucocutáneo.'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'Enfermedad: Afebrilidad.'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Enfermedad: Auscultación cardiopulmonar normal.'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'Dolor abdominal generalizado'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'Circulación colateral.'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'Edema en miembros inferiores.'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'TVP'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'Enfermedad: Aumento de transaminasas'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'INR: Hemostasia con INR: 1.3 y tiempo de cefalina 53.3 seg.'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'Trombo con densidad grasa que se extiende desde riñón izquierdo a vena renal izquierda (VRI), vena cava inferior (VCI) y ostium de aurícula derecha.'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'Enfermedad: Vena suprahepatica libre.'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'Vació'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'Enfermedad: Anomalías del páncreas'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'Enfermedad: Hígado y vías biliares anormales.'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Enfermedad: Lipoma \nLugar: VCI'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'Colecistitis probable perforada y posible pancreatitis.'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'Enfermedad: Líquido libre en pelvis, espacios perihepático, periesplénico y perirrenal derecho (en mayor cuantía que en TC previo)'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'patología pancreático-duodenal. En este sentido, se debe tener presente la posibilidad de neoplasias intraepiteliales del páncreas y tumores carcinoides; así como también enfermedades autoinmunes tales como la tiroiditis de Hashimoto o la diabetes mellitus insulino dependiente.'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'Síndrome de Budd-Chiari'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'Enfermedad: lipoma renal'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'Enfermedad: Congestión Hepática \nSignos: Hepaomegalia, Aumento del Calibre de Vena Porta y Suprahepáticas, Retardo en la Llegada de Contraste a las Mismas, Edema Periportal, Bazo Atrigado y Abundante Líquido Libre.'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'Síndrome de Budd-Chiari'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'Resultado analítico de trasudado sin evidencia de proceso peritoneal.'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'Tricúspide libre y derrame pericárdico.'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Síndrome de Budd-Chiari secundario a trombo en cava'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'Enfermedad: Lipoma'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'No se menciona ninguna enfermedad o condición médica específica en este contexto. Por lo tanto, mi respuesta será "texto vacío".'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'Trombo - Enfermedad cardiovascular - Patología del corazón y los vasos sanguíneos'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'No se menciona ninguna enfermedad o condición médica específica en este texto. Por lo tanto, mi respuesta es vacía.'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'Enfermedad: Hepatitis B'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'Vena cava superior'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'Enfermedad: Trombo infradiagramatico'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'Enfermedad: Tromboembolismo pulmonar'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'Angiomiolipoma de predominio lipomatoso del seno renal con infiltración vascular.'
# [12/250] es-S0004-06142008000300012-1.txt | 55.75s | 40 chunks | 8 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'Nefritis derecha con hematuria.'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'Artrosis'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'Enfermedad: Litiasis renal derecha \nEnfermedad: Quiste renal gigante'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'Quiste renal simple (enfermedad)'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'Enfermedad: Hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Respuesta: Normal'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'Quiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'No se menciona ninguna enfermedad en este texto. Por lo tanto mi respuesta es: "enfermedad"'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'Respuesta: Quistes.'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'Cistitis'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'Antibioticos domicilio'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'Quiste'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'No es posible determinar ninguna entidad a partir del texto proporcionado.'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'Quiste'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'Enfermedad: Microhematuria \nEnfermedad: Leucocituria'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'Enfermedad: CISTITIS'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'Litiasis en pelvis renal.'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'Amoxicilina-clavulánico\nTrimetoprim-sulfametoxazol'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'Enfermedad: Infección \nEnfermedad: Litiasis'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'Asintomatica'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'Enfermedad: Quiste.'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'No se ha encontrado ninguna entidad de tipo "ENFERMEDAD" en el texto proporcionado. Por lo tanto, mi respuesta es vacía.'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'Vía urinaria.'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'Asintomatica'
# [13/250] es-S0004-06142008000300013-1.txt | 25.79s | 26 chunks | 6 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'Carcinoma de próstata'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'Enfermedad: Aumento de volumen testicular derecho'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'Adenopatías retroperitoneales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'linfoma testicular difuso de celula grande tipo B'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'Enfermedad = Recidiva Precoz'
# [14/250] es-S0004-06142008000400011-2.txt | 6.14s | 6 chunks | 2 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'Enfermedad: Hipertensión Arterial'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'Metrorragia'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'Enfermedad: Hematuria'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'Masa anexial izquierda de 7cm de diámetro mayor y muy vascularizada'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'Carcinoma ovárico primario'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'Nódulo renal'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'Lesión sólido-quística de 90 x 65 mm'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'Adenopatía regional \nImplante metastático peritoneal'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'Carcinoma ovárico primario y metástasis renal secundarias. Histerectomía total y doble anexectomía con nefrectomía radical derecha.'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'Carcinoma renal metastásico en ovario.'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'Carcinoma de celulas renales grade I de Fuhrman'
# [15/250] es-S0004-06142008000400013-1.txt | 13.34s | 11 chunks | 3 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'Enfermedad: Adenocarcinoma gástrico; Carcinoma de próstata; Prostatectomía radical; Bloqueo androgénico; Hiperplasia prostática benigna; Hiperplasia prostática maligna; Hiperplasia prostática; Hiperplasia glandular prostática; Hiperplasia nodular prostática; Hiperplasia ductal prostática; Hiperplasia lobulillar prostática; Hiperplasia acinar prostática; Hiperplasia intraductal prostática; Hiperplasia papilar prostática; Hiperplasia quística prostática; Hiperplasia periuretral prostática; Hiperplasia subcapsular prostática; Hiperplasia intersticial prostática; Hiperplasia perirrenal prostática; Hiperplasia parenquimatosa prostática; Hiperplasia cortical prostática; Hiperplasia medular prostática; Hiperplasia periférica prostática; Hiperplasia central prostática; Hiperplasia endocervical; Hiperplasia endometrial; Hiperplasia vaginal; Hiperplasia vulvar; Hiperplasia del cuello uterino; Hiperplasia cervicovaginal; Hiperplasia uretral; Hiperplasia conjuntival; Hiperplasia folicular ovárica; Hiperplasia tubaria; Hiperplasia suprarrenal; Hiperplasia testicular; Hiperplasia hipofisaria; Hiperplasia tiroidea;'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'Enfermedad: Lesión exofítica no dolorosa a nivel del glande.'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'Enfermedad: Lesión previa o traumatismo en la zona.'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'Neoplasia'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'Tumoración de aspecto macroscópico no infiltrante, asentada en la mucosa del glande, con areas de aspecto trombosado y facilmente friable.'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'Melanoma'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'Enfermedad: Penectomia Subtotal'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'Enfermedad: Ausencia de enfermedad metastásica.'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'No se encontró ninguna entidad de tipo "ENFERMEDAD" en el texto proporcionado. Por lo tanto, mi respuesta será un texto vacío.'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'Melanoma'
# [16/250] es-S0004-06142008000400016-1.txt | 30.69s | 10 chunks | 2 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'Endometriosis ovárica'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'Enfermedad: Patología retroperitoneal.'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'Enfermedad: Riñon derecho funcional con retraso en la captacion y eliminacion del contraste y borramiento de la linea de psoas derecho.'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'Neoplasia'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'Urinoma'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'Cateterismo uretral con tubo doble j'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'No se menciona ninguna enfermedad o afección específica en el texto proporcionado. Por lo tanto, mi respuesta será "Sin enfermedades".'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'No se menciona ninguna enfermedad específica en este texto. Por lo tanto, mi respuesta es vacía: " ".'
# [17/250] es-S0004-06142008000500009-1.txt | 10.59s | 8 chunks | 2 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'Infección urinaria'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'absceso de cúpula vaginal'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'DM es sinónimo de **Diabetes Mellitus**. Por lo tanto, se puede extraer la siguiente entidad:\n- Diabetes Mellitus'
#   [chunk 4/15 | chars 616-623]
#   RAW: 'Respuesta: Hipertensión arterial sistémica.'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'Enfermedad: Alergias'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'Enfermedad: Hematuria.'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'Enfermedad: Cólico.'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'Enfermedad: Infección urinaria.'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'Enfermedad: Litiasis Vesical'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'No se especifica ninguna entidad relacionada con enfermedades, por lo tanto mi respuesta será vacía.'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'Enfermedad: Litiasis intravesical'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'Enfermedad: Uretrocistoscopia'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'Litiasis intravesical por cuerpo extraño'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'Enfermedad: infección de orina de repetición'
# [18/250] es-S0004-06142008000700003-1.txt | 16.42s | 15 chunks | 2 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'EPOC'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'Respuesta: Sin enfermedades asociadas.'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'Uretrorragia'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'No he encontrado ninguna entidad relacionada con enfermedades.'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'Neoplasia vesical'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'Tumor solido de practicamente 7cm, calcificado en cara lateral. Reseccion transuretral. Enfermedad residual.'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'vimentina y actina'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'Cistectomia parcial y diverticulectomia + Leiomioma sarcoma de bajo grado'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'Pleomorfismo celular.'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'Necrosis tumoral. Necrosis celular aislada.'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'MIXED TISSUE CHANGE'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'Enfermedad: Inflamacion intra y peritumoral.'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'Enfermedad: Infiltración de todo el espesor de la pared diverticular hasta el tejido adiposo peridiverticular provocando reacción fibrosa peritumoral.'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'Enfermedad: Tumor.'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'Vimentina\nActina\nDesmina\nEMA\nCitoqueratinas de alto peso molecular'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'Leiomioma sarcoma de bajo grado'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'Enfermedad: TAC toracoabdominal, gammagrafía ósea, RMN pélvica.'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'radioterapia local regional y quimio terapia complementarias'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'radioterapia local regional 57Gy'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'Ifosamida-Adriamina'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'Enfermedad: cáncer de vejiga'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: 'Enfermedad: Asintomática'
# [19/250] es-S0004-06142009000400011-1.txt | 26.01s | 23 chunks | 9 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'Masa testicular derecha.'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'No se encuentra información sobre enfermedades o patologías específicas en el contexto proporcionado. Por lo tanto, no es posible extraer ninguna entidad relacionada con enfermedades.'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'Enfermedad: Aumento difuso del tamaño del testículo derecho'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'Orquidectomía'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'La respuesta es cáncer.'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'ACL\nCD3\nKi67\nTdT\nCD30\nALK\nbcl2\nbcl6\nCD10'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'Linfoma no Hodgkin T periférico no especificado'
# [20/250] es-S0004-06142010000100015-1.txt | 9.38s | 7 chunks | 10 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'Enfermedad Renal'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'Neoplasia renal.'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'Lesion renal izquierda de 11x7cm de diametro, multiseptada y con calcificaciones puntiformes.'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'Enfermedad: Ausencia de adenopatías retroperitoneales.'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'Nefrosis Multilocular Quística'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'Enfermedad: Lesión ocupante del riñon izquierdo.'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'Sin resultados.'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'Nefrectomia'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'Nefroma quístico multilocular'
# [21/250] es-S0210-48062003000900009-1.txt | 9.43s | 9 chunks | 1 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'Torsión testicular.'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'Síndrome constitucional'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'Neutropenia'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'Enfermedad: Edema de cubiertas; Aumento de la consistencia del epidídimo; Disparición del surco epidídimo testicular'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'Enfermedad: Adenoma de prostata'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'Enfermedad: Coagulopatía.'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'Enfermedad: LDH elevada'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'Enfermedad: Congestión Vascular'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'Próstata normal.'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'Enfermedad: Ecografia Testicular \nEnfermedades: Testículo Izquierdo Normal, Testículo Derecho, Área Heterogénea, Disminución De La Ecogenicidad, Sin Calcificaciones, Polo Superior, Inferior, Epidídimo, Hidrocele.'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'absceso testicular'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'Tumor testicular'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'linfoma difuso B de células grandes'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'Enfermedad: Linfoma Testicular Primario'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'Fiebre, sudacion, edema, astenia, neoplasia, cancer, tumor, gangrena, infeccion, sepsis, shock, trombosis, embolismo, isquemica, infarto, arritmia, insuficiencia cardiaca congestiva, hipertension arterial, angina de pecho, disnea, hipoacusia, anosmia, paralisis facial, diplopia, cefalea, convulsion, coma, hipoxia, anoxia, intoxicacion, hemorragia, hematoma, ulcera, dermatitis, psoriasis, urticaria, prurito, eritema, celulitis, absceso, osteomielitis, artritis, gota, espondilitis, cistitis, uretritis, prostatitis, nefritis, hepatitis, pancreatitis, gastritis, enterocolitis, colangitis, colecistitis, peritonitis, pericarditis, endocarditis, miocarditis, pleuresia, neumonia, bronconeumonia, asma, enfisema pulmonar, traqueobronquitis, laringotraqueobronquitis, faringoamigdalitis, sinusitis, otitis media, rinitis alergica, conjuntivitis, blefaroconjunctivitis, queratoconjunctivitis, glaucoma, catarata, retinopatía diabética, ceguera, sordera, hipoac'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'Anemia'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'linfoma testicular primary'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'Plasmocitosis intersticial y Linfoblastosis.'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'Anemia y trombocitopenia sin infiltración medular.'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'Agregacion plaquetaria'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'Disfonia Disfagia Seno Pirifome Polipodea'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'Enfermedad: TAC cervical normal.'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab\nCHOP'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'R-CHOP'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'radioterapia genital coadyuvante y quimioprofilaxis cerebral'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: 'Enfermedad: Libre de enfermedad.'
# [22/250] es-S0210-48062004000200011-1.txt | 48.94s | 29 chunks | 9 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: 'Enfermedad: Tracto Urinario Inferior'
#   [chunk 2/12 | chars 224-442]
#   RAW: 'Adenoma II'
#   [chunk 3/12 | chars 442-700]
#   RAW: 'Enfermedad: Ureterolitectomia'
#   [chunk 4/12 | chars 700-997]
#   RAW: 'Masa parahiliar del riñon izquierdo de aproximadamente 6cm de diametro'
#   [chunk 5/12 | chars 997-1381]
#   RAW: 'Neoplasia renal'
#   [chunk 6/12 | chars 1381-1562]
#   RAW: 'Masa renal'
#   [chunk 7/12 | chars 1562-1624]
#   RAW: 'Lumbotomía izquierda'
#   [chunk 8/12 | chars 1624-1775]
#   RAW: 'No es posible identificar ninguna entidad de tipo "enfermedad" en el texto proporcionado. Por lo tanto, mi respuesta será vacía.'
#   [chunk 9/12 | chars 1776-1889]
#   RAW: 'fibras textiles'
#   [chunk 10/12 | chars 1889-2050]
#   RAW: 'Tumoracion'
#   [chunk 11/12 | chars 2050-2234]
#   RAW: 'Enfermedad: Caseosis'
#   [chunk 12/12 | chars 2234-2418]
#   RAW: 'Tumoracion'
# [23/250] es-S0210-48062004000500009-1.txt | 11.78s | 12 chunks | 4 menciones
#   [chunk 1/11 | chars 0-130]
#   RAW: 'Masa renal'
#   [chunk 2/11 | chars 130-212]
#   RAW: 'colelitis-asi-idroceelectomia-derecha'
#   [chunk 3/11 | chars 213-358]
#   RAW: 'No se menciona ninguna enfermedad relacionada con los riñones.'
#   [chunk 4/11 | chars 359-424]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 5/11 | chars 424-618]
#   RAW: 'Nódulo exofítico de 4x2cm en polo superior del riñon derecho'
#   [chunk 6/11 | chars 619-824]
#   RAW: 'Masa renal compleja'
#   [chunk 7/11 | chars 825-1174]
#   RAW: 'Enfermedad: Masa quística mínimamente complicada.'
#   [chunk 8/11 | chars 1174-1373]
#   RAW: 'Enfermedad: Tumorectomia'
#   [chunk 9/11 | chars 1373-1584]
#   RAW: 'Carcinoma de células claras renal'
#   [chunk 10/11 | chars 1584-1768]
#   RAW: 'Resultado: Sin resultados.'
#   [chunk 11/11 | chars 1769-1877]
#   RAW: 'texto vacío'
# [24/250] es-S0210-48062004000800009-1.txt | 10.87s | 11 chunks | 3 menciones
#   [chunk 1/18 | chars 0-125]
#   RAW: 'Enfermedades del paciente:\n- Hipertensión arterial\n- Hiperactividad tiroidea\n- Diabetes mellitus tipo II\n- Síndrome de ansiedad'
#   [chunk 2/18 | chars 126-342]
#   RAW: 'Enfermedad: Hematuria'
#   [chunk 3/18 | chars 342-444]
#   RAW: 'Masa palpable a nivel de fossa lumbar derecha.'
#   [chunk 4/18 | chars 445-481]
#   RAW: 'No se encontró ninguna entidad de tipo "ENFERMEDAD".'
#   [chunk 5/18 | chars 481-622]
#   RAW: 'Enfermedad: neoplasia renal.'
#   [chunk 6/18 | chars 623-681]
#   RAW: 'Coágulos en la vejiga.'
#   [chunk 7/18 | chars 682-723]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 8/18 | chars 723-815]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 9/18 | chars 815-1067]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 10/18 | chars 1068-1159]
#   RAW: 'Enfermedad: Trombosis venosa renal \nAdenopatía: Enfermedades del tejido linfático y sistemas asociados'
#   [chunk 11/18 | chars 1159-1259]
#   RAW: 'Análisis sangre: Anemia Ferropénica; VSG normal; Calcio Normal'
#   [chunk 12/18 | chars 1259-1377]
#   RAW: 'Enfermedad: Embolización selectiva'
#   [chunk 13/18 | chars 1377-1611]
#   RAW: 'Arteriografia de aorta abdominal y posterior cateterismo selectivo de arteria renal derecha'
#   [chunk 14/18 | chars 1612-1842]
#   RAW: 'Enfermedad: Tumor'
#   [chunk 15/18 | chars 1842-1978]
#   RAW: 'Enfermedad: Buena evolucion de la paciente.'
#   [chunk 16/18 | chars 1978-2122]
#   RAW: 'Enfermedad: Cefalea'
#   [chunk 17/18 | chars 2123-2327]
#   RAW: 'Insomnio y algia músculo-esquelética.'
#   [chunk 18/18 | chars 2328-2451]
#   RAW: 'texto vacio'
# [25/250] es-S0210-48062005000300014-1.txt | 21.32s | 18 chunks | 0 menciones
#   [chunk 1/23 | chars 0-303]
#   RAW: 'Enfermedades del paciente:\ncardiopatía isquémica\ninfarto de miocardio\nby-pass aorto-coronario\narteriosclerosis de troncos supraaórticos\naterosclerosis de extremidades inferiores\nEPOC\nfumador\nhernia discal\nestenosis de canal'
#   [chunk 2/23 | chars 304-472]
#   RAW: 'Enfermedad: Tramo Urinario Inferior'
#   [chunk 3/23 | chars 473-537]
#   RAW: 'Hematuria total con coágulos.'
#   [chunk 4/23 | chars 538-662]
#   RAW: 'texto vacío'
#   [chunk 5/23 | chars 663-744]
#   RAW: 'hiperplasia benigna grado II'
#   [chunk 6/23 | chars 744-859]
#   RAW: 'Enfermedad: Hiperuricemia'
#   [chunk 7/23 | chars 859-954]
#   RAW: 'Lesión exofítica en base vesical-cara derecha'
#   [chunk 8/23 | chars 955-1058]
#   RAW: 'Neoplasia vesical'
#   [chunk 9/23 | chars 1059-1337]
#   RAW: 'Carcinoma mixed grade II-III invasive of smooth muscle with areas of mucinous infiltrating associated to lesions of noninvasive carcinoma and cystic glandular cysts (stage pT2-pT3 G-III)'
#   [chunk 10/23 | chars 1337-1535]
#   RAW: 'Adenopatías significantementeEngrosamiento de pared vesicalTumores o neoplasias en aorta, ilio e inglesCalcificaciones arteriales ateroscleróticas'
#   [chunk 11/23 | chars 1535-1606]
#   RAW: 'Cistoprostatectomia radical y neovejiga ileal tipo Camey II.'
#   [chunk 12/23 | chars 1607-1681]
#   RAW: 'No se menciona ninguna enfermedad o condición médica específica en este texto. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 13/23 | chars 1681-2063]
#   RAW: 'Carcinoma seroso ovárico'
#   [chunk 14/23 | chars 2064-2101]
#   RAW: 'Psammoma'
#   [chunk 15/23 | chars 2102-2257]
#   RAW: 'Lesiones de displasia epitelial en uretra prostática y un carcinoma de próstata bien diferenciado en lóbulo derecho Gleason 4 (2 + 2)'
#   [chunk 16/23 | chars 2258-2433]
#   RAW: 'Carcinoma micropapilar'
#   [chunk 17/23 | chars 2433-2569]
#   RAW: 'CA125'
#   [chunk 18/23 | chars 2569-2698]
#   RAW: 'Enfermedad: Afectacion cardiaca.'
#   [chunk 19/23 | chars 2699-2883]
#   RAW: 'infecciones urinarias\nanemia\nleucopenia\ntransfusiones sanguineas\nfactores estimulantes de colonias(filgastrim)'
#   [chunk 20/23 | chars 2883-3084]
#   RAW: 'Neoveijiga'
#   [chunk 21/23 | chars 3085-3184]
#   RAW: 'Dolor óseo\nDolor abdominal'
#   [chunk 22/23 | chars 3185-3362]
#   RAW: 'Recidiva mesenterica e hidroureterorrenitis bilaterales.'
#   [chunk 23/23 | chars 3363-3520]
#   RAW: 'Enfermedad: Progresión intra y retroperitoneal.'
# [26/250] es-S0210-48062005000400012-1.txt | 34.56s | 23 chunks | 18 menciones
#   [chunk 1/14 | chars 0-252]
#   RAW: 'Enfermedad: Prostatitis crónica.\nEnfermedad: Diabetes Mellitus Tipo I.'
#   [chunk 2/14 | chars 253-383]
#   RAW: 'Enfermedad: Sin Alteraciones.'
#   [chunk 3/14 | chars 384-463]
#   RAW: 'No se encontró ninguna enfermedad en los resultados de los hemocultivos realizados en medios convencionales y de Ruiz Castañeda.'
#   [chunk 4/14 | chars 464-603]
#   RAW: 'Brucella'
#   [chunk 5/14 | chars 603-699]
#   RAW: 'Rifampicina y Doxiciclina son dos fármacos empleados comúnmente para tratar infecciones bacterianas. Sin embargo, no se menciona ninguna infección específica en el contexto provisto. Por lo tanto, es difícil determinar si estas medicaciones están siendo prescritas para alguna afección médica particular. En ausencia de información adicional, no puedo proporcionar una respuesta precisa a su pregunta sobre enfermedades tratadas con estos medicamentos.'
#   [chunk 6/14 | chars 699-778]
#   RAW: 'Fiebre y dolor lumbar.'
#   [chunk 7/14 | chars 779-873]
#   RAW: 'Enfermedad: Signo del psoas positivo'
#   [chunk 8/14 | chars 874-1072]
#   RAW: 'Espondilodiscitis L5-S1'
#   [chunk 9/14 | chars 1073-1166]
#   RAW: 'Ciprofloxacino'
#   [chunk 10/14 | chars 1167-1288]
#   RAW: 'Drenaje Transcutaneo'
#   [chunk 11/14 | chars 1288-1512]
#   RAW: 'Espondiloartritis'
#   [chunk 12/14 | chars 1513-1701]
#   RAW: 'Discectomia L5-S1'
#   [chunk 13/14 | chars 1702-1889]
#   RAW: 'Doxiciclina 100mg/12 horas\nSeptrim Forte 1/12 horas'
#   [chunk 14/14 | chars 1889-2001]
#   RAW: 'No se menciona ninguna enfermedad o afección específica en este texto. Por lo tanto, mi respuesta es vacía: " ".'
# [27/250] es-S0210-48062005000700012-1.txt | 21.20s | 14 chunks | 3 menciones
#   [chunk 1/9 | chars 0-273]
#   RAW: 'Enfermedad: tumor testicular'
#   [chunk 2/9 | chars 274-308]
#   RAW: 'Fiebre'
#   [chunk 3/9 | chars 309-436]
#   RAW: 'Hidrocele'
#   [chunk 4/9 | chars 437-494]
#   RAW: 'No se encontraron enfermedades en los analisis de sangre y orina.'
#   [chunk 5/9 | chars 495-675]
#   RAW: 'Neoplasia testicular'
#   [chunk 6/9 | chars 676-720]
#   RAW: 'Enfermedad: Marcadores tumorales (AFP y ß-HCG).'
#   [chunk 7/9 | chars 721-814]
#   RAW: 'Orquiectomia inguinal izquierda'
#   [chunk 8/9 | chars 815-895]
#   RAW: 'Enfermedad: Normal'
#   [chunk 9/9 | chars 896-1115]
#   RAW: 'Enfermedad: Infarto testicular'
# [28/250] es-S0210-48062006000200018-1.txt | 8.24s | 9 chunks | 3 menciones
#   [chunk 1/20 | chars 0-213]
#   RAW: 'Masa testicular izquierda'
#   [chunk 2/20 | chars 214-416]
#   RAW: 'Masa testicular'
#   [chunk 3/20 | chars 417-715]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 4/20 | chars 716-764]
#   RAW: 'epididymis lesion-free study'
#   [chunk 5/20 | chars 765-1091]
#   RAW: 'Enfermedad: Masa testicular/Testículo supernumerario'
#   [chunk 6/20 | chars 1092-1094]
#   RAW: 'No se encontró ninguna entidad de tipo "ENFERMEDAD" en el texto proporcionado. Por lo tanto, mi respuesta es: """.'
#   [chunk 7/20 | chars 1094-1121]
#   RAW: 'No se encontraron enfermedades.'
#   [chunk 8/20 | chars 1122-1164]
#   RAW: 'Urologia'
#   [chunk 9/20 | chars 1165-1212]
#   RAW: 'Antecedentes personales negativos.'
#   [chunk 10/20 | chars 1213-1487]
#   RAW: 'No se menciona ninguna enfermedad o afección específica en este texto. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 11/20 | chars 1488-1795]
#   RAW: 'Adenoma testicular izquierda'
#   [chunk 12/20 | chars 1795-1944]
#   RAW: 'PQ'
#   [chunk 13/20 | chars 1945-2128]
#   RAW: 'Lesión'
#   [chunk 14/20 | chars 2129-2822]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 15/20 | chars 2823-3076]
#   RAW: 'Enfermedad: neoplasia'
#   [chunk 16/20 | chars 3077-3268]
#   RAW: 'No he encontrado ninguna entidad del tipo "ENFERMEDAD" en el texto proporcionado. Por lo tanto, mi respuesta será un texto vacío.'
#   [chunk 17/20 | chars 3269-3370]
#   RAW: 'No es posible determinar ninguna enfermedad con la información proporcionada.'
#   [chunk 18/20 | chars 3371-3478]
#   RAW: 'No se encuentran enfermedades en este texto.'
#   [chunk 19/20 | chars 3479-3595]
#   RAW: 'Enfermedad: Testículos normales.'
#   [chunk 20/20 | chars 3596-3633]
#   RAW: 'Neoplasia intratubular seminal.'
# [29/250] es-S0210-48062006000400012-1.txt | 20.85s | 20 chunks | 6 menciones
#   [chunk 1/10 | chars 0-478]
#   RAW: 'Enfermedad: Prostatitis aguda'
#   [chunk 2/10 | chars 478-650]
#   RAW: 'Enfermedad: Tumefacción en la zona perineal con enrojecimiento y calor local.'
#   [chunk 3/10 | chars 651-736]
#   RAW: 'Dolor durante el tacto rectal.'
#   [chunk 4/10 | chars 736-917]
#   RAW: 'Leucemia'
#   [chunk 5/10 | chars 917-1100]
#   RAW: 'Absceso prostatico'
#   [chunk 6/10 | chars 1100-1248]
#   RAW: 'Absceso'
#   [chunk 7/10 | chars 1249-1377]
#   RAW: 'Enfermedad: Infección del tracto urinario'
# ...
#   [chunk 13/17 | chars 2687-2916]
#   RAW: 'Enfermedad: Hernia interna a través de la hoja derecha del ligamento ancho del útero.'
#   [chunk 14/17 | chars 2917-3052]
#   RAW: 'Enfermedad: Hernia\nEnfermedad: Necrosis del intestino delgado'
#   [chunk 15/17 | chars 3053-3134]
#   RAW: 'No he encontrado ninguna entidad relacionada a enfermedades.'
#   [chunk 16/17 | chars 3135-3259]
#   RAW: 'No se menciona ninguna enfermedad o afección específica en el texto proporcionado. Por lo tanto, mi respuesta será vacía: " ".'
#   [chunk 17/17 | chars 3260-3307]
#   RAW: 'No se encontraron enfermedades en este texto.'
# [242/250] es-S1887-85712012000400006-1.txt | 34.50s | 17 chunks | 0 menciones
#   [chunk 1/13 | chars 0-274]
#   RAW: 'Enfermedad: Desviacion Vertical de los Ejes Visuales'
#   [chunk 2/13 | chars 275-356]
#   RAW: 'Enfermedad: Palpitaciones \nEnfermedad: Fiebre'
#   [chunk 3/13 | chars 356-532]
#   RAW: 'Enfermedades: Hipertensión arterial, Dislipidemia, Ex fumador. Tratamientos: Enalapril, Simvastatina.'
#   [chunk 4/13 | chars 532-751]
#   RAW: 'Enfermedad: Diplopía binocular vertical.'
#   [chunk 5/13 | chars 752-797]
#   RAW: 'No se menciona ninguna entidad relacionada con enfermedades. Por lo tanto, mi respuesta es: "No se especifica".'
#   [chunk 6/13 | chars 798-911]
#   RAW: 'Resultado:\nNo enfermedades detectadas.'
#   [chunk 7/13 | chars 912-1000]
#   RAW: 'Lateropulsion derecha'
#   [chunk 8/13 | chars 1000-1343]
#   RAW: 'Enfermedad: TC craneal de 64 canales'
#   [chunk 9/13 | chars 1343-1492]
#   RAW: 'Diplopía'
#   [chunk 10/13 | chars 1492-1824]
#   RAW: 'microinfartos solitarios en sustancia blanca profunda, así como lesiones isquémicas agudas de localización paramedial en ambos tálamos y mesencéfalo anterior, compatibles con obstrucción de la arteria de Percheron'
#   [chunk 11/13 | chars 1825-1931]
#   RAW: 'Flair'
#   [chunk 12/13 | chars 1931-2108]
#   RAW: 'Dabigatrán'
#   [chunk 13/13 | chars 2109-2269]
#   RAW: 'Diplopía'
# [243/250] es-S1887-85712014000100005-1.txt | 17.23s | 13 chunks | 3 menciones
#   [chunk 1/21 | chars 0-234]
#   RAW: 'Carcinoma de recto'
#   [chunk 2/21 | chars 235-357]
#   RAW: 'Artrosis generalizada'
#   [chunk 3/21 | chars 357-745]
#   RAW: 'SCASEST-Killip III'
#   [chunk 4/21 | chars 746-996]
#   RAW: 'Cateterismo'
#   [chunk 5/21 | chars 996-1242]
#   RAW: 'Enfermedad: Dedos dolorosos durante la extensión passiva'
#   [chunk 6/21 | chars 1242-1253]
#   RAW: 'Palidez'
#   [chunk 7/21 | chars 1253-1307]
#   RAW: 'Imposibilidad para detectar pulso radial o cubital.'
#   [chunk 8/21 | chars 1307-1373]
#   RAW: 'Disminucion de la temperatura respecto a miembro contralateral.'
#   [chunk 9/21 | chars 1373-1425]
#   RAW: 'Paralisis total del miembro afecto.'
#   [chunk 10/21 | chars 1425-1655]
#   RAW: 'No hay ninguna entidad de tipo Enfermedad en este texto.'
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'Síndrome compartamental agudo del antebrazo derecho.'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: 'No hay enfermedades mencionadas en este texto.'
#   [chunk 13/21 | chars 1907-1969]
#   RAW: 'Cefazolina'
#   [chunk 14/21 | chars 1970-2110]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 15/21 | chars 2111-2191]
#   RAW: 'Hematoma'
#   [chunk 16/21 | chars 2192-2410]
#   RAW: 'Nervio Mediano'
#   [chunk 17/21 | chars 2411-2487]
#   RAW: 'Arterial.'
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'Nitrofural Vessel Loops'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: 'Fasciotomía'
#   [chunk 20/21 | chars 2901-3087]
#   RAW: 'Enfermedad: Relleno capilar inferior a 2 segundos'
#   [chunk 21/21 | chars 3088-3211]
#   RAW: 'Ausencia de dolor en antebrazo derecho'
# [244/250] es-S1887-85712016000100005-1.txt | 19.02s | 21 chunks | 12 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: 'Coxalgia derecha'
#   [chunk 2/22 | chars 128-229]
#   RAW: 'Dolor durante actividad física y limitaciones menores en posiciones corporales.'
#   [chunk 3/22 | chars 230-429]
#   RAW: 'No se menciona ninguna enfermedad o condición médica específica en este texto. Por lo tanto, mi respuesta es vacía.'
#   [chunk 4/22 | chars 430-528]
#   RAW: 'Dolor'
#   [chunk 5/22 | chars 528-725]
#   RAW: 'Enfermedad: Dolor a la palpación en tercio medio de la región inguinal derecha con dolor a la flexión, aducción y rotaciones sobre todo interna (maniobra de choque positiva)'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'No se encontraron enfermedades en el texto proporcionado.'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'Enfermedad: Sin Dolor a la Palpacion de Puntos Ciaticos'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'Enfermedad: Dolor a la palpación en la cintilla iliotibial Negativo: Test de Ober'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'No se encontraron enfermedades en este texto.'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'Dolor para la marcha con flexión forzada de cadera y rodilla.'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'Deformidad en forma de joroba en región cérvico-cefálica femoral derecha.'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'Enfermedad: Normal'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'Resonancia magnética de cadera: Leve alteración subcondral, edema óseo, irregularidad cortical y leve sinovitis en interlínea articular, con distensión de la bursa ilio-psoas.'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'Islote óseo en la cabeza femoral con un ángulo alfa superior a 50 grados.'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'Artroplastia de cadera dolorosa debido a desgaste articular.'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'Necrosis avascular'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'Lesión quística yuxtaarticular del trocanter mayor.'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'Síndrome de pinzamiento femoroacetabular tipo LEVA'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'Sulfato de glucosamina-condroitinsulfato orales 400mg c/12h durante 3meses y AINEs a demanda si tiene dolor.'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'No se menciona ninguna enfermedad o condición médica específica en este texto. Por lo tanto, mi respuesta es vacía.'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'Artroscopia'
# [245/250] es-S1888-75462015000400006-1.txt | 33.06s | 22 chunks | 7 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'Fractura de tercio medio de clavicula derecha. Fractura de arcos costales derechos.'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'Enfermedad: Dolor a nivel de clavicula y pared costal derecha.'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'Fractura del arco costo-vertebral derecho 4º y 5º; Fractura del tercio medio de la clavicula derecha.'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'Enfermedad: Edematización del miembro superior derecho'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'Espirometria normal\nElectrocardiograma normal\nEcocardiograma normal\nAnalitica sangre con anormalidades:\nCHCM 31.4 g/dl\nNeutrofilos 76.6%\nLinfocitos 16.4%\nEoisinofilicos 0.9%\nFibrinogeno 645 mg/dl\nGGT 52 U/l\nD-DiMero Positivo'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'Trombosis venosa de las venas axilar, cefálica y basílica'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'Tinzapain sódico'
# [246/250] es-S1888-75462016000400180-1.txt | 15.77s | 7 chunks | 1 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'Vacío'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomia'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'Osteoporosis'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'Dolor mecanico del pie izquierdo'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'Antepié izquierdo'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'Enfermedad: Ninguna'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Rx de pies normal.'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'Fractura de estrés del segundo metatarsiano derecho.'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'La hiperparatiroidismo secundario es la causa más probable del aumento de los niveles de PTH.'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'Denosumab es una medicación utilizada para tratar osteoporosis.'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'Enfermedad: Tratamiento conservador con descarga, reposo relativo, AINEs y magnetoterapia.'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'Dolor en el pie izquierdo'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'Fractura de estrés'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'Enfermedad: Tenosinovitis del Tibial Posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'Enfermedad: Osteoporosis'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'BAZEDOXIFENO VITAMINA D'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'Fractura'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'Osteoporosis'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'No es posible determinar ninguna entidad patológica a partir del texto proporcionado.'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'Fracturas de estres'
# [247/250] es-S1889-836X2015000200005-2.txt | 19.41s | 20 chunks | 5 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'didanosina\ntenofovir\nlopinavir/ritonavir'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'Enfermedad: Astenia \nEnfermedad: Dolor osseo difuso'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'Fosfatasa alcalina (FA), Paratohormona (PTH)'
#   [chunk 4/16 | chars 408-569]
#   RAW: 'No se encontraron enfermedades en este texto.'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'Enfermedad: Degeneración de columna vertebral \nEnfermedad: Gammagrafía con Tc-99 normal'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'Enfermedad: Astenia.'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'Deficit de fuerza en extremidades superiores e inferiores. Deformación en codo y rodilla. Sensibilidad conservada. Resto normal.'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperfosfatemia'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'Aminoaciduria moderada'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'No se encontraron enfermedades.'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Tabla 1'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'Síndrome de Fanconi incompleto'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'Raltegravir \nDarunavir potenciado con ritonavir'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'Fósforo, 25-HCC y 1,25-dihidroxivitamina D (1,25 DHCC)'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'Enfermedad: Reabsorcion de fosfato baja'
# [248/250] es-S1889-836X2015000400006-1.txt | 20.03s | 16 chunks | 9 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'Enfermedad: Lupus Cutaneo'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Enfermedad autoimmune crónica que afecta a la glándula tiroides y provoca inflamación e hipotiroidismo.'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'Enfermedad: Apendicitis.'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'No se menciona ninguna enfermedad relacionada con los hábitos de fumar. Por lo tanto, no puedo extraer ninguna entidad de enfermedad del texto proporcionado.'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'Nada.'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'Quinina'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'Anemia postparto.'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'Enfermedad: Cesárea\nEnfermedad: Ligadura de Trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'Intensa astenia \nPresincones\nAnorexia'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'Enfermedad: Menstruación muy duradera (8 días) y abundante.'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'Enfermedad: Palidez cutáneo-mucoso'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'Enfermedad: Epistaxis \nEnfermedad: Gingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'Anemia y Trombopenia'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'Esquistositemia.'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'Prueba de tiempo parcial de protrombina (PTT)'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'No he encontrado ninguna entidad relacionada con enfermedades.'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'Afasia global y desviacion de la comisura bucal a la izquierda'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'No se menciona ninguna enfermedad en este texto. Por lo tanto mi respuesta es: "Enfermedad"'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'Neurologia'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'microangiopatía trombótica'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'UCI'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'plasmaféresis'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'No es posible extraer información sobre enfermedades del texto proporcionado. Por favor proporciona más contexto o detalles adicionales.'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'Vacío.'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'No se menciona ninguna entidad relacionada con enfermedades. Por lo tanto, mi respuesta es vacía.'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'No es posible determinar ninguna entidad patológica con los datos proporcionados. Por tanto, mi respuesta será "texto vacío".'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'No se encontraron enfermedades en este texto.'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'No se encontraron enfermedades en este texto.'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'Dianeal® 1,36% de diálisis peritoneal.'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'Cateterismo cardiaco'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE (Hospal®)'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'No se menciona ninguna enfermedad.'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'Enfermedad: Mal estado general y sedación.'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: 'No se menciona ninguna entidad relacionada con enfermedades. Por lo tanto, mi respuesta es vacía.'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'No se encontró ninguna entidad de tipo "ENFERMEDAD" en el texto proporcionado. Por lo tanto, mi respuesta es vacía.'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'convulsioness'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'No se menciona ninguna enfermedad o condición médica específica en este texto. Por lo tanto, mi respuesta es vacía.'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'No se menciona ninguna enfermedad o condición médica específica en este texto. Por lo tanto, mi respuesta es vacía.'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'No es posible identificar ninguna entidad relacionada con enfermedades en este texto proporcionado. Por lo tanto, mi respuesta será "texto vacío".'
# [249/250] es-S2254-28842014000200009-1.txt | 48.41s | 40 chunks | 8 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Carcinoma seroso papilar'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'Carboplatino y Paclitaxel son medicamentos utilizados en tratamientos contra el cáncer.'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'CA 125'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'RESECCION ANTERIOR DEL RECTO SUPERIOR\nBIOPCIA INTRAOPERATORIA LENTION HEPATICA\nMETASTATIS'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'CA 125'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'Carboplatino'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'Remisión del cuadro clínico tras la interrupción de la perfusión y posterior administración de corticosteroides.'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'Enfermedad: Desensibilización \nVelocidad de infusión: Enlentecimiento'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'Congestión nasal\nDisnea\nSudores nocturnos\nTensión arterial baja'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'Trabecedina'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'Enfermedad: Libre de enfermedad.'
# [250/250] es-S2340-98942015000100005-1.txt | 13.66s | 11 chunks | 5 menciones
#
# Predicciones guardadas en distemist_llm_predictions.tsv
# Tiempo medio por archivo: 20.76s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd


def prf(tp, fp, fn):
    p  = tp / (tp + fp) if (tp + fp) else 0.0
    r  = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1


df_pred  = pd.read_csv(PREDICTIONS_TSV, sep="\t")
df_gs    = pd.read_csv(GS_TEST_TSV, sep="\t")
df_gs    = df_gs[df_gs["filename"].isin(df_pred["filename"].unique())]

set_gs   = set(zip(df_gs["filename"],   df_gs["label"],   df_gs["off0"],   df_gs["off1"]))
set_pred = set(zip(df_pred["filename"], df_pred["label"], df_pred["off0"], df_pred["off1"]))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1   = prf(tp, fp, fn)

report = {"Estricta": {"tp": tp, "fp": fp, "fn": fn, "precision": round(p, 4), "recall": round(r, 4), "fscore": round(f1, 4)}}

print(f"── ESTRICTA ──  P={p:.4f}  R={r:.4f}  F1={f1:.4f}  (TP={tp} FP={fp} FN={fn})\n")

thresholds = [0.0, 0.5, 0.8]
results    = {t: {"tp": 0, "fp": 0, "fn": 0} for t in thresholds}

for filename in df_pred["filename"].unique():
    gs_ints   = list(zip(df_gs[df_gs["filename"] == filename]["off0"],   df_gs[df_gs["filename"] == filename]["off1"]))
    pred_ints = list(zip(df_pred[df_pred["filename"] == filename]["off0"], df_pred[df_pred["filename"] == filename]["off1"]))

    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )

    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi); matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ──  P=0.3123  R=0.1574  F1=0.2093  (TP=400 FP=881 FN=2141)
#
# ── IoU ──
# IoU >= 0.0:  P=0.4598  R=0.2318  F1=0.3082  (TP=589 FP=692 FN=1952)
# IoU >= 0.5:  P=0.3950  R=0.1991  F1=0.2648  (TP=506 FP=775 FN=2035)
# IoU >= 0.8:  P=0.3404  R=0.1716  F1=0.2282  (TP=436 FP=845 FN=2105)
