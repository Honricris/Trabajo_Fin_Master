# %% [markdown]
# # Pipeline Five-Shot NER — DisTemIST con BioMistral-7B-DARE
#
# Inferencia five-shot para reconocimiento de enfermedades en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "BioMistral/BioMistral-7B-DARE"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo ENFERMEDAD.\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'neoplasia', no escribas 'cancer'.\n"
    "4. REPETICIONES: Si una enfermedad aparece varias veces en el texto, debes listarla varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio (como '-', '*', '•', '1.').\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
DISTEMIST_ROOT       = f"{PROJECT_ROOT}/distemist/distemist"
TEXT_FILES_TEST_DIR  = f"{DISTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{DISTEMIST_ROOT}/distemist_subtrack1_test_mentions.tsv"
PREDICTIONS_TSV      = "distemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : BioMistral/BioMistral-7B-DARE
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
    trust_remote_code = True,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.6.6: Fast Mistral patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# BioMistral/BioMistral-7B-DARE does not have a padding token! Will use pad_token = <unk>.
#
# Modelo cargado: BioMistral/BioMistral-7B-DARE
# Parámetros totales: 3,752,071,168

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

EXAMPLES = [
    {
        "text": "Con el diagnóstico de hipernefroma se realizó nefrectomía. La anatomía patológica fue de carcinoma de células renales del tipo de células claras de 8 cm de diámetro con invasión tumoral del uréter y de la vena renal. Tres meses después de la cirugía, la radiografía mostraba múltiples imágenes nodulares compatibles con metástasis.",
        "mentions": "hipernefroma\ncarcinoma de células renales del tipo de células claras de 8 cm de diámetro con invasión tumoral del uréter y de la vena renal\nmetástasis",
    },
    {
        "text": "Había sido fumador de 10 cigarrillos/día. No era consumidor de bebidas alcohólicas, no tenía hábitos tóxicos ni tomaba regularmente ningún medicamento. No refería antecedentes de muerte súbita ni de síncopes. Tras realizar un test de flecainida, se realizó un diagnóstico de SB.",
        "mentions": "fumador\nconsumidor de bebidas alcohólicas\nhábitos tóxicos\nmuerte súbita\nsíncopes\nSB",
    },
    {
        "text": "El paciente presenta fístula urinaria con abundante salida de orina e infección de herida quirúrgica. Tras la estabilización, se observa desaparición de fístula urinaria y necrosis grasa. Con el diagnóstico de fístula vésico-rectal se indica sondaje vesical hasta resolución de infección de herida quirúrgica.",
        "mentions": "fístula urinaria\ninfección de herida quirúrgica\nfístula urinaria\nnecrosis grasa\nfístula vésico-rectal\ninfección de herida quirúrgica",
    },
    {
        "text": "La tomografía reveló agenesia de cuerpo calloso aunada a un lipoma con bordes irregulares; espina bífida oculta a nivel de columna cervical y fisura central a nivel de la arcada del maxilar superior. Neurológicamente, a pesar de presentar agenesia del cuerpo calloso, se mantiene alerta y sin crisis convulsivas.",
        "mentions": "agenesia de cuerpo calloso\nlipoma\nespina bífida oculta a nivel de columna cervical\nfisura central a nivel de la arcada del maxilar superior\nagenesia del cuerpo calloso\ncrisis convulsivas",
    },
    {
        "text": "El paciente se lesionó ambos ojos concentrando los rayos solares con ayuda de una lupa buscando un fin estético. Asimismo se autoinduce unas quemaduras de segundo y tercer grado en la piel de la cara y los brazos para hacer desaparecer unos supuestos quistes.",
        "mentions": "se lesionó ambos ojos concentrando los rayos solares con ayuda de una lupa\nse autoinduce unas quemaduras\nquemaduras de segundo y tercer grado en la piel de la cara y los brazos\nquistes",
    },
]

def build_ner_messages(text):
    messages = []
    for i, ex in enumerate(EXAMPLES):
        prefix = f"{SYSTEM_PROMPT}\n\n" if i == 0 else ""
        messages.append({"role": "user", "content": f"{prefix}Texto para analizar:\n{ex['text']}"})
        messages.append({"role": "assistant", "content": ex["mentions"]})
    messages.append({"role": "user", "content": f"Texto para analizar:\n{text}"})
    return messages

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            full_output = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        marker = "<|im_start|>assistant"
        idx    = full_output.rfind(marker)
        result = full_output[idx + len(marker):].strip() if idx != -1 else full_output.strip()
        result = re.sub(r"<think>.*?</think>", "", result, flags=re.DOTALL).strip()
        result = re.sub(r"<think>.*",          "", result, flags=re.DOTALL).strip()

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename": txt_path.stem,
            "mark":     f"T{mark_idx}",
            "label":    "ENFERMEDAD",
            "off0":     off0,
            "off1":     off1,
            "span":     span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "mark", "label", "off0", "off1", "span"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'paciente femenina de 62 años de edad\nobesa\ndiabetes\nhipertensa'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'dolor lumbar derecho\nesporádico de baja intensidad'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'la exploración física fue normal'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'ultrasonido abdominal\nmasa suprarrenal derecha hipoecogénica de 80 mms\nriñón derecha'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'urograma descendente\nproceso expansivo en la suprarrenal derecha\nriñón derecha desplazado hacia abajo'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'masa tumoral\ndiámetro mayor de 8,7x76 cms\ncontornos irregulares\ndensidad heterogénea de 100 - 37 UH\ntabicada\ntumor suprarrenal de densidad grasa'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'estudio hormonal para la determinación de cortisol fue normal.'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'cirugía por abordaje lumbar'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'tumor localizado en la glándula suprarrenal derecha\nbien delimitado de bordes irregulares con lobulaciones'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'adrenalectomía derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'evolución post operatoria\npaciente'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'patólogo\npieza\npeso de 171,4 g\ndimensiones de 9 x 8 x 6 cms\náreas amarillas - naranjas y otras de hemorragias y tejido adiposo alternando con zonas de calcificaciones'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'mielolipoma de la glándula adrenal con extensas áreas de calcificaciones'
# [1/250] S0004-06142006000100010-1.txt | 44.95s | 13 chunks | 30 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'gastrectomía subtotal\nadenocarcinoma gástrico\nhipertensión arterial\nespironolactona'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'anorexia\npérdida de 12 kilos en 6 meses (peso actual 42 kilos)\nanemia hipocrómica\nestreñimiento'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'tumoración de consistencia firme, indolora, móvil y que ocupaba las tres cuartas partes del abdomen.'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'adenocarcinoma gástrico\nestreñimiento\nanemia\nascitis por carcinomatosis\nobstrucción intestinal tumoral\ntumoración abdominal'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'hemoglobina\nhematies\nhematocrito\nVCM\nRDW\nVSG\nPCR\nPSA\ncreatinina\nurea'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'marcadores tumorales hepáticos y digestivos'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'gastroscopia\npólipo inflamatorio en muñón gástrico\nrecidiva tumoral'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'imposible la realización de una colonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'ecografía abdominopélvica\ntumoración quística\ntabiques incompletos\ncontenido anecoico mixto\ncavidad abdominal'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'riñón izquierdo\nriñón derecho'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'lesión quística voluminosa intraabdominal\nlesión quística voluminosa intraabdominal\nlesión quística voluminosa intraabdominal'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'TAC\nmasa quística\ngran masa quística de 29,5 cm x 27,5 cm x 16 cm\nmúltiples tabiques y paredes bien definidas\nocupa la práctica totalidad del abdomen'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'imagen cálcica\nteórica zona de pelvis renal de riñón hidronefrótico con compresión y desplazamiento de todas las estructuras abdominales.'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'hidronefrosis gigante secundaria a uropatía obstructiva litiásica\ndrenaje percutáneo\nnefrectomía'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'nefrectomía simple derecha\nlumbotomía subcostal\nevacuando 7.800 mililitros de contenido serohemático'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'linfadenectomía hiliar ampliada\nadenopatías'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'cultivo del fluido resulto negativo\ncitología\nsospecha clínica\ntumoración urotelial'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'riñón de aspecto multiquístico\ndilatación del sistema pielocalicial\natrofia parenquimatosa severa'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'revestimiento epitelial\ndisplasia de diferentes grados\ncan áreas de patrón papilar\nzonas de infiltración del parénquima renal'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'nidos sólidos de células de citoplasma amplio, claro y de alto grado nuclear (grado 3 de Fuhrman)\ninfiltración ganglionar de carcinoma de células renales tipo célula clara'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'metástasis hepáticas'
# [2/250] S0004-06142006000100014-1.txt | 84.85s | 21 chunks | 67 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'paciente de 46 años\ndolor a nivel de hipogastrio\neyaculación dolorosa\nhemospermia\nsensación de peso a nivel testicular\nvaricocele derecho'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'varicocele derecho'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'próstata irregular\nligeramente aumentada de tamaño\nzonas induradas\ndolorosa a la exploración'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'ecografía urológica integral\nimagen nodular hipoecoica en teste derecho con hipervascularización circundante y un quiste simple en testículo izquierdo.'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'TAC abdómino-pélvica\nmetástasis\nhemangiomas'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'hemangiomas'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'RX de tórax'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'marcadores tumorales\nPSA'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'Alfa-feto-proteína: 6 ng/ml, beta-HCG: 0.1 ng/ml, PSA: 1.5 ng/ml.'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'pieza\nformación nodular\ncoloración\npulpa testicular\npolo superior del testículo'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'tumor de células de Leydig difuso\nespacios perineurales\ncanales vasculares capsulares adyacentes\nmúsculo liso\natípia\nmitosis'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'paciente\n10 años de controles evolutivos\nasintomático\nmetástasis\nmarcadores tumorales'
# [3/250] S0004-06142006000500002-2.txt | 46.67s | 14 chunks | 39 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'neoplasia de testículo\norquidopexia'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'cólicos nefríticos\nlitiasis\nLEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Ureterolitectomía'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'fumador'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'esterilidad\nnódulo en testículo izquierdo\nmeses de evolución\naumentado de tamaño en las últimas semanas'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'espermiograma\nazoospermia total'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'ecografía-doppler testicular\ntestículo derecho\nmasa de 19 x 23 mm en polo superior\nflujo aumentado\ntumor testicular\nquiste de cordón izquierdo'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'testículo izquierdo\nquiste de epidídimo'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'testículo derecho'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'No se encontró ninguna entidad en el texto.'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'Rx de tórax\nTAC toraco-abdómino-pélvico\nmetástasis'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'analítica tampoco mostraba alteraciones\nvalores séricos hormonales\nmarcadores tumorales\nalfa-fetoproteina 2,2 ng/ml\nbeta-HCG 0,0 ng/ml'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'orquiectomía radical inguinal derecha\nbiopsia del testículo izquierdo vía inguinal'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'testículo derecho de 3,2 x 3 cm.'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'superficie testicular\ninfiltración de túnica vaginalis'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'nódulo sólido bien delimitado de 1,5 cm de diámetro de coloración parda con área amarillenta central'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'tejido testicular restante'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'cordón espermático'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'biopsia del testículo izquierdo\ncoloración parda'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Tumor de células de Leydig de 3,2 x 3 cm sin objetivarse infiltración del epidídimo, túnica albugínea ni invasión vascular.'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'parénquima testicular\natrofia\nhiperplasia de células de Leydig\nintersticio\nespermiogénesis'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'Bordes quirúrgicos libres.'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'atrofia testicular\nausencia de espermiogénesis\nhiperplasia de células de Leydig intersticial'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: '30 meses de controles evolutivos\nbuen estado general\nevidencia radiológica de metástasis\nmarcadores tumorales'
# [4/250] S0004-06142006000500002-3.txt | 78.57s | 25 chunks | 55 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'varón de 47 años\nantecedentes de interés\nmasa renal derecha\ndolor abdominal'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'masa sólida y heterogénea de aproximadamente 6 cm, localizada en polo superior del riñón derecho con vena renal permeable.'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'nefrectomía radical derecha\nadenopatías'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'carcinoma renal de células claras de 8,4 centímetros\nstadio pT3aNoMo, II de Robson\ngrado nuclear IV de Fuhrman'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'no se encontró ninguna enfermedad'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'neoplasia'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'masa dolorosa en el hipocondrio derecho\nrecidiva tumoral en el lecho quirúrgico\ninfiltraba pilar diafragmático derecho posterior e hígado\nimplantes peritoneales'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'extirpación de las masas tumorales\nresecándose la adyacente al hígado así como varios implantes peritoneales y retroperitoneales\nbiopsia intraoperatoria compatible en todas las piezas con carcinoma de células claras de alto grado'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'masa retroperitoneal paravertebral'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'ante estos hallazgos\nServicio de Oncología\ntratamiento con Interferón (Intrón A)\nmala tolerancia del mismo\nprecisándose reducción de la dosis'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'molestias abdominales inespecíficas\nanalgésicos suaves\nlesiones hepáticas sugerentes de metástasis\nrecidiva del lecho quirúrgico\nimplantes peritoneales en epiplon'
# [5/250] S0004-06142006000900015-1.txt | 44.82s | 11 chunks | 29 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'Paciente varón de 29 años.'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'tumoración indolora en su testículo izquierdo de un mes de evolución\ntestículo izquierdo hipogénico y disminuido de tamaño\ntestículo derecho con parénquima heterogéneo sospechoso de neoplasia'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'no presenta otra sintomatología urológica\nno astenia\nno pérdida de peso'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'no tiene antecedentes personales de interés'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'teste izquierdo hipotrófico\nteste derecho aumentado de tamaño'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'no dolorosos\nde consistencia normales\nde superficie regulares'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'epidídimos\ncordones'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'hemostasia\nbioquímica\nhemograma\nparámetros correspondientes a la normalidad\nalfa-feto proteína\nbeta-hCG'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'ecografía con flujo Doppler\nteste derecho de 49mm x 36mm x 26mm\nlesión hipoecoica\nbordes lobulados\nheterogénea\nque ocupa prácticamente todo el testículo\naumento del flujo Doppler'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'teste izquierdo\n32mm x 22mm x 20mm\nhetrogéneo\nlesión focal ligeramente hipoecoica\naproximadamente 9mm\nsutil flujo Doppler'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'microlitiasis testiculares bilaterales'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de tórax\nTAC toraco-abdomino-pélvico con contraste'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'tumor testicular bilateral\norquiectomía bilateral vía inguinal\ntratamiento hormonal sustitutivo'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'testículo izquierdo atrófico con múltiples focos microscópicos de seminoma clásico asociado a amplias áreas de neoplasia intratubular de células germinales (NICG) con ausencia de infiltración tumoral en albugínea, rete testis, epidídimo o infiltración vascular.'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'tumoración con características de seminoma clásico\ntestículo derecho\nfocos de neoplasia intratubular de células germinales (NICG)\nfocos de atrofia'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'túnica albugínea\nrete testis\nepidídimo\nborde quirúrgico'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'quimioterapia\ncarboplatino'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'enfermedad'
# [6/250] S0004-06142007000200017-1.txt | 70.00s | 18 chunks | 50 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'Paciente: YSS Edad: 32años Raza: Negra.'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'Antecedentes personales: Paciente que acude a consulta por presentar desde hacía dos años aumento progresivo de los órganos genitales externos, trasudación de la linfa e impotencia sexual.'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'Edema marcado del pene y escroto con eritema y dolor.'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'Adenopatías inguinales'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'Hemograma completo: Cifras normales.'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'No reactiva'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Prueba de Mantoux: Negativa\nProteinas totales y fraccionadas: Normales\nRX de cadera: Ausencia de lesión ósea'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'U/S abdominal: Psoas derecho engrosado de 48 mm\nTAC simple de hipogastrio y pelvis: Necrosis aséptica de la cabeza del fémur con hipertrofia del psoas a ese nivel.'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'exploración retroperitoneal derecha'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'Adenectomía de ilíaca derecha y cava.'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'linfangioplastia con aguja'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'Fasciotomía de la raíz del pene.'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'quiluria\nedema de los miembros inferiores\nvaricocele\nhidrocele'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'linfedema primario inflamatorio local de pene y escroto'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'necosis aséptica de la cabeza del fémur.'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'urólogos\nangiológos\ncirujanos plásticos'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'distorsionada\nafección\nnormal evacuación de la linfa\ndistorsión y atrapamiento de los conductillos linfáticos\ntejido conjuntivo fibroso aumentado\ndisminución de las fibras elásticas\nórganos\npeneano'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'piel y dermis\ndartos\ntúnica muscular de fibras lisas (músculo peripeneal de Sappey)\nvasos linfáticos dilatados\nvenas\narterias\nnervios superficiales\nfascia penis delgada\nórganos eréctiles\nuretra\narteria peneana'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'bolsas de las seis cubiertas que componen el recubrimiento de los testículos: el escroto, el dartos muscular, la celulosa, la fascia de Cooper, la segunda túnica muscular llamada eritroide, forman también un bloque que debe ser extirpado en su totalidad, dejando la capa vaginal que recubre los testículos, el paquete vasculo nervioso y el epidídimo.'
# [7/250] S0004-06142007000600012-1.txt | 76.24s | 20 chunks | 44 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'paciente de 28 años de edad\nantecedentes de interés\nnódulo testicular\nha detectado hace tres meses\nha aumentado de tamaño'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'nódulo duro\nmóvil\ndoloroso a la palpación\ncordón espermático derecho'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'marcadores tumorales\nhormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'ecografía\nimagen ovalada\nhipoecoica\necogenicidad mixta\neje longitudinal máximo de 2,8 cm\ncordón espermático'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'RNM\ncordón espermático derecho\nseñal baja en T2\ntejido con bajo contenido en agua\nfibroso o cicatricial\n43 mm de diámetro máximo'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'tumoración paratesticular derecha\nexéresis quirúrgica\ntumoración del conducto deferente'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'paciente cursa sin incidentes\nasintomático'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'formación redondeada de coloración pardusca y consistencia elástica\nformación redondeada de coloración pardusca y consistencia elástica\nformación redondeada de coloración pardusca y consistencia elástica'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'lesión bien circunscrita\ncélulas con amplio citoplasma eosinófilo\npresencia de estriaciones transversales en algunas de ellas\ninmersas en un estroma fibroblástico\ncélulas de aspecto vacuolado\ncélulas multinucleadas\nactividad mitótica'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'desmina\nvimentina\nactina de músculo liso específica'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'Granada'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'No se encontró ninguna entidad en el texto.'
# [8/250] S0004-06142007000600014-1.txt | 47.49s | 12 chunks | 40 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'herida de arma de fuego\norificio de entrada en la nalga\norificio de salida'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'herida de bala\nmuslo derecho\norificio de entrada por detrás\nsalida por delante'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'El paciente está consciente, orientado y con una ligera defensa abdominal.'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'balas\nradiografía simple de abdomen\nbalas situadas a la altura de la sínfisis del pubis\nfractura de la rama descendente derecha del mismo'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'enfermo llega en retención\nsondaje\ncatéter suprapúbico'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'laparotomía\ncolostomía izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'uretrografía\npaso de contraste desde la uretra hasta el recto\nfiebre alta con escalofríos'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'perforación rectal'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'uretrotomo endoscópico\nuretra prostática\norificio grande que une la uretra con el recto'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'camino que lleva hasta la vejiga\nsonda del dieciocho'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'laparotomía hasta la sínfisis del pubis\nrevisa de nuevo el abdomen\nlesión'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'espacio de Retzius\nhiperplásica\nproyectil'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'balas'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'postoperatorio cursa sin incidencias\npaciente es dado de alta a los pocos días con la sonda.'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'orificio rectal\ncolostomía'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'sonda'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'uretrografía\nbrecha\nsonda'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'paciente\nasintomático\nfunción sexual normal\nultrasonido\nnormal'
# [9/250] es-S0004-06142007000900010-1.txt | 55.16s | 18 chunks | 42 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'mujer\nedad\nantecedentes personales\napendicectomía\nhernia discal\nhiato\nfractura de tibia y peroné\ncólico nefrítico derecho'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'neoformación sólida en riñón derecho de 5 cm'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'TAC\nmasa a nivel cortical de riñón derecho\nmasa de aproximadamente 5 cm\nbordes externos lobulados\nespacio perirrenal\nadenopatías\ndilatación de vía renal excretora'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'hipernefroma\nnefrectomía radical derecha'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'neoformación cortical\n5 cm de diámetro máximo\nencapsulada\ndeforma la superficie cortical sin atravesarla\ncoloración amarillenta\náreas de aspecto hemorrágicas\náreas quísticas'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'neoformación\nestructuras acinares\ncélulas cuboidales\ncitoplasma\nnúcleos con cromatina uniforme\nestroma celular'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'vimentina\ncitoqueratina 7\ncitoqueratina de amplio espectro\nCD34\ncromogranina\nEMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'Granada'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'España'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'vimentina\ncitoqueraina 7\nEMA\nCD34'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'La paciente cursa tras la intervención sin incidentes destacables y se encuentra asintomática a los 24 meses de la intervención.'
# [10/250] es-S0004-06142007000900012-1.txt | 41.70s | 11 chunks | 42 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK\nantecedentes de sinusitis bilateral\nbronquiectasias\ndesprendimiento retina de ojo derecho\ntamaño testicular\ninduración'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'dolor lumbar\nirradia\ntestículo izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'neoplasia'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'No se palpan adenopatías.'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'tumor testicular\ntipo seminoma\nsignos compatibles con tumor testicular'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'situs inversus\napex de la silueta cardiaca\ncámara de gases gástrica a la derecha\nbronquiectasias en lóbulo inferior izquierdo'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'LDH: 340 (230-460)\nGOT: 44 (2-37)\nGPT: 44 (2-40)'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'Marcadores tumorales: a-fetoproteína: 1.1 ng/ml (1-7) y b-HCG <5.0 mUI/ml.'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'seminoma clásico\nalbugínea\nepidídimo\nrete testis\ncordón espermático\nborde quirúrgico'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'invasión vascular'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Neoplasia germinal intratubular.'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'fibrosis e hialinización tubular de testículo no tumoral'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'seminoma grado I\ncriterios de mal pronóstico\ntratamiento adicional\nnormalidad bioquímica de los parámetros tumorales\nexploración física\npruebas por imágenes'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'orquiectomía\nespermiogramas\nazooospermia'
# [11/250] es-S0004-06142008000300011-1.txt | 48.97s | 14 chunks | 38 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'mujer\n41 años\nantecedentes de interés\ndolor abdominal difuso\nintensidad en epigastrio\n1 semana de evolución\nnáuseas\nvómitos biliosos\nmal estado general'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'dolor\ntos\ninspiración'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'fiebre\nsensación distérmica'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'No coluria ni acolia.'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'consciente\norientada\ndolor\ngravedad'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'Palidez mucocutánea'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'Paciente afebril y normotensa'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'auscultación cardiopulmonar'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'Abdomen sin masas ni megalias\ndolor abdominal generalizado a la palpación\nintenso en epigastrio\nsignos de irritación peritoneal (Murphy negativo)'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'circulación colateral'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'no edemas en miembros inferiores'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'No signos de trombosis venosa profunda (TVP).'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'bioquímica normal\ntransaminasas\nGOT: 146 U/L\nGPT: 171 U/L'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'hemograma\nhemoglobina\nhematocrito\nleucocitos\nneutrofilia\nplaquetas'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'Hemostasia con INR: 1.3 y tiempo de cefalina 53.3 seg.'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'TC\ntrombo con densidad grasa\nextiende desde riñón izquierdo a vena renal izquierda (VRI), vena cava inferior (VCI) y ostium de aurícula derecha'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'venas suprahepáticas libres'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'No oclusión completa de la luz de VCI.'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'Anormalidad inespecífica de cabeza de páncreas.'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'TC\nintensa epigastralgia\nECO abdómino-pélvico\nhígado y vía biliar intra y extrahepática normales'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Lipoma en VCI.'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'colecistitis\nperforada\npancreatitis'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'Líquido libre en pelvis, espacios perihepático, periesplénico y perirrenal derecho (en mayor cuantía que en TC previo).'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'patología bilio-pancreática vs.'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'Síndrome de Budd-Chiari\nsegundo TC\nderrame pleural bilateral\nengrosamiento de pliegues gástricos con aumento de la captación de contraste\nangiomiolipoma (AML)'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'lipoma renal\nVCI\nostium de la aurícula derecha\ncontraste en todo el recorrido de las estructuras venosas\nvena porta\nsuprahepáticas'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'congestión hepática\nhepatomegalia\naumento de calibre de vena porta y suprahepáticas con retardo e la llegada de contraste a las mismas\nedema periportal\nbazo y páncreas atigrado\nlíquido libre'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'diagnóstico de presunción de síndrome de Budd-Chiari secundario a trombo en cava\nparacentesis bajo control ecográfico\nexcluir con mayor certeza proceso peritoneal infeccioso/ tumoral como causante de dicho sín drome'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'resultado analítico de trasudado\nproceso peritoneal'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'ecografía transesofágica\nbuena función ventricular\ntrombo intracavitario\ntricúspide\nderrame pericárdico'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Síndrome de Budd-Chiari secundario a trombo en cava (AML vs.'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'Lipoma)'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'INTERVENCIÓN QUIRÚRGICA'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'trombo con nivel quirúrgico IV\nsituación supradiafragmática\nostium de aurícula derecha'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'incisión tipo Chevron\nretroperitoneo\napertura desde asa fija hasta hiato de Winslow\nligadura de vena mesentérica inferior'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'movilización hepática\nligamentos redondo\ncoronario\ntriangulares derecho e izquierdo\nfalciforme'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'riñón izquierdo\nhilio correspondiente\nliberación de la vena cava\nempezando a nivel infrarrenal y ascendiendo hasta nivel suprahepático\ncontrol de vena renal derecha (VRD)\nsección del resto de ramas excepto venas suprahepáticas\nvenas suprahepáticas'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'hiato diafragmático\ntrombo'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'clampaje de pedículo hepático (maniobra de Pringle)\nVCI proximal y distal\nVRD con posterior cavotomía y apertura VRI\nextracción completa del trombo\nnefrectomía izquierda'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'angiomiolipoma de predominio lipomatoso del seno renal con infiltración vascular'
# [12/250] es-S0004-06142008000300012-1.txt | 145.69s | 40 chunks | 112 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'mujer\nedad\n47 años\nnefrítico\nderecho\nhematuria'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'diclofenaco\nartrosis\nlumbalgia'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'litiasis en el grupo calicial medio del riñón derecho\nquiste renal gigante'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'quiste renal simple (Bosniak I)\nriñón derecho\nlitiasis ipsilateral'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Hemograma'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'molestias lumbares\nquiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'posibilidades'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'pendiente de drenaje percutáneo\nesclerosis del quiste'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'cistitis\nfiebre elevada\ndolor lumbar derecho'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'tratamiento antibiótico de modo domiciliario'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'quiste'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'Mide 6,4 centímetros.'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'se calcificó'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'quiste\nTAC con cortes tardíos\nquiste se comunicaba con el sistema pielocalicial'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'microhematuria\nleucocituria'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'cólico derecho\ncistitis'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'litiasis'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'infección urinaria por E.Coli\nAmoxicilina-Clavulanico\nTrimetropin-Sulfametoxazol'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'infección\nlitiasis\nlitotricia extracorpórea'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: ''
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'quiste\nruptura del quiste\nTAC\nlesión mide 2,9 centímetros de diámetro\npresenta calcificaciones gruesas y nodulares\nno capta contraste'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Bosniak IIF'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'ecografías de control\nUIV\nTAC'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'comunicación con la vía urinaria'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'La paciente permanece asintomática.'
# [13/250] es-S0004-06142008000300013-1.txt | 68.24s | 26 chunks | 54 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'prostatectomía radical con linfadenectomía obturatriz\ncarcinoma de próstata medianamente diferenciado (suma Gleason 5)\nafectación microscópica limitada de los márgenes de resección'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'cirugía prostática\naumento de volumen testicular derecho\nmarcadores de tumor testicular negativos\nmasa con áreas irregulares en ecografía\ndisminución de flujo vascular'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'TAC abdominal'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'TAC post orquiectomía\nadenopatías retroperitoneales\narea inguinal\nbifurcación de renales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'orquiectomía inguinal\nlinfoma testicular difuso de célula grande tipo B\nquimioterapia citorreductiva según esquema R-CHOPx8\nremisión completa tras la inducción'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'recidiva precoz\nIFOVM / DHAP\nremisión inicial\nrecidiva'
# [14/250] es-S0004-06142008000400011-2.txt | 25.93s | 6 chunks | 20 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'mujer\nedad\nhipertensión arterial'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'metrorragias\ndolor abdominal'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'hematuria\ndolor en fosas renales'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'ecografía vaginal\nmasa anexial izquierda de 7 cm de diámetro mayor\nútero grande\novario derecho de características normales'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'sospecha de carcinoma ovárico primario\nestudio de estadificación\nTC abdómino-pélvico\nmasa compleja en polo inferior de riñón derecho\nmasa compleja en polo inferior de riñón derecho\n64 x 65 mm de diámetro\nintensa captación de contraste\náreas hipodensas centrales'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'nódulos de 17 y 10 mm dependientes del polo superior del mismo riñón'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'anejo izquierdo\nlesión sólido-quística\n90 x 65 mm\nintensa captación de contraste'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'adenopatías regionales\nimplantes metastásicos peritoneales'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'carcinoma ovárico primario\nmetástasis renal secundaria\nhisterectomía total\nanelectomía\nnefrectomía radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'metástasis de carcinoma de células renales en ovario'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'carcinoma de células renales grado I de Fuhrman extendiéndose a grasa perirrenal, sin infiltrar la vena renal.'
# [15/250] es-S0004-06142008000400013-1.txt | 41.67s | 11 chunks | 31 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'gastrectomía\nadenocarcinoma gástrico\ncarcinoma de próstata\nGleason VII\nprostatectomía radical\nganglio linfático\nbloqueo androgénico\nPSA'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'lesión exofítica\nglande'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'lesión previa\ntraumatismo en la zona\nsangrado con el roce'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'lesión redondeada exofítica de color rojizo oscuro de aproximadamente dos centímetros de diámetro\ntendencia al sangrado\nconsistencia elástica\ndolorosa'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'linfadenectomías\nbiopsia de la lesión\ntumoración de aspecto macroscópico no infiltrante\nasentanda en la mucosa del glande\náreas de aspecto trombosado y fácilmente friables'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'lesión compuesta por células indiferenciadas con hipercromatismo nuclear, pleomorfismo y gran número de mitosis y pigmento negruzco\nmelanoma'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'penectomía subtotal\nmargen de seguridad desde el borde de la lesión\nlinfadenectomía inguinal superficial bilateral\nganglios no afectados por el tumor'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'TAC tóracoabdominal\nausencia de enfermedad metastásica'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'pieza penectomía\nprofundidad máxima de invasión'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'melanoma'
# [16/250] es-S0004-06142008000400016-1.txt | 39.91s | 10 chunks | 33 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'Mujer de 46 años de edad\nantecedente de endometriosis ovárica\nhisterectomía abdominal con doble anexectomía por endometriosis\n45 días antes de acudir a consulta\ndolor continuo en región iliaca y sacra derecha\nmejora con antiinflamatorios\necografía abdominal\ndiscreta ectasia renal'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'dolor y defensa a la palpación profunda de fosa lumbar derecha\ndolorimiento a la percusión y palpación de fosa lumbar izquierda'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'urografía intravenosa (UIV)\nTomografía computerizada (TAC) simultáneos\nriñón derecho funcionante con retraso en la captación y eliminación de contraste y borramiento de la línea de psoas derecho.'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'TAC\nlobulada de contenido líquido\naparente extravasación de contraste\nuréter'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'urinoma\nligadura o sección del uréter derecho\nureterolisis\nexéresis del urinoma\nanastomosis termino-terminal del uréter\nrefrescamiento de los bordes'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'catéter doble J\ntutorizando el uréter\ncirugía'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'evolución favorable'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'buena función renal\nnormalidad de la vía urinaria en UIV'
# [17/250] es-S0004-06142008000500009-1.txt | 36.50s | 8 chunks | 27 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'Paciente mujer de 74 años\nInfecciones Urinarias (ITUs)\ndolor hipogástrico\nal menos seis meses de evolución'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'histerectomía vía vaginal por prolapso uterino\nprolapso uterino\nreingreso a los 18 días de la cirugía\nabsceso de cúpula vaginal\nabsceso en cúpula vaginal\nECO y TC absceso en cúpula vaginal'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'DM'
#   [chunk 4/15 | chars 616-623]
#   RAW: 'No HTA'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'No alergias conocidas.'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'no hematuria'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'No cólicos.'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'infecciones de orina'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'G2 A0V2'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'Rx aparato urinario simple que es informada como normal, aunque se aprecia claramente contorno débilmente cálcico en pelvis en área vesical, y ecografía transvaginal que informa de probable litiasis vesical, diagnóstico por el cual junto a las infecciones de orina de repetición es remitido al Servicio de Urología de nuestro centro.'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'No se encontró ninguna entidad en el texto.'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'litiasis intravesical\ncuerpo extraño intravesical'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'uretrocistoscopia\nsospecha diagnóstica\npelotón de gasas\ncalcificada\nTC pélvico'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'litiasis intravesical\ncuerpo extraño\ncuerpo extraño\nextracción de la misma\ncistoslitectomía\ncistogasomectomía'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'buena evolución\nasintomática\ninfecciones de orina de repetición\nepisodio aislado'
# [18/250] es-S0004-06142008000700003-1.txt | 51.95s | 15 chunks | 35 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'varón\nEPOC moderado'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'fumador\nhábitos tóxicos'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'factores ambientales de riesgo\nantecedentes familiares'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'uretrorragia\nmicción'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'sondaje urinario\ntalla suprapúbica'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'ecografía\ndivertículo único\ntamaño similar a vejiga\nimágenes polipoideas parietales menores de 2-3 cm\nneoplasia vesical'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'ante los hallazgos ecográficos y la estenosis uretral se procedió a realizar ureterotomía, y cistoscopia donde se observó un tumor sólido de prácticamente 7 cm, calcificado en cara lateral, realizándose en el mismo acto una resección transuretral, observándose enfermedad residual en el acto.'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'resultado anatomopatológico\nmarcadores epiteliales\nmarcadores fibroblásticos\nvimentina\nactina'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'cistectomía parcial\ndiverticulectomía\nleiomiosarcoma de bajo grado (mitosis =3 X10 campos de gran aumento)'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'pleomorfismo celular'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'necrosis intratumoral\nnecrosis celular aislada'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'mixoide'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'inflamación intra y peritumoral'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'infiltración de todo el espesor de la pared diverticular hasta el tejido adiposo peridiverticular\nreacción fibrosa peritumoral'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'Márgenes quirúrgicos libres de tumor.'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'Inmunohistoquímica\nmarcadores de diferenciación muscular (vimentina y actina)\ndesmina\nmarcadores epiteliales (EMA Y Citoquerqatinas de Alto Peso Molecular)'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'leiomiosarcoma de bajo grado con infiltración de todas las capas\ntratamiento complementario\nriesgo del paciente'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'TAC toracoabdominal\ngammagrafía ósea\nRMN pélvica'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'radioterapia locorregional\nquimioterapia complementaria'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'radioterapia locorregional\ndosis de 57 Gy'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'quimioterapia\nifosfamida-adriamicina a dosis habituales\nciclos de dicho tratamiento'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'cistoscopias periódicas\ncitología urinaria\nTAC toraco-abdomino-pélvico'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: ''
# [19/250] es-S0004-06142009000400011-1.txt | 78.42s | 23 chunks | 52 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'Hombre de 42 años\nmasa y dolor testicular derecho\ndolor testicular derecho\nmasa testicular derecha'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'niega antecedentes patológicos\nsintomatología'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'ecografía testicular\naumento difuso del tamaño del testículo derecho\necogenicidad del mismo'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'orquidectomia\ntestículo aumentado de tamaño\ncauchoso\nblanquecino'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'infiltración difusa del parénquima testicular por una neoplasia maligna hematolinfoide\ncélulas de pequeño tamaño\nirregulares\ncitoplasma escaso\náreas de necrosis asociadas'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'ACL\nCD3\nKi67\nTdT\nCD30\nALK\nbcl2\nbcl6\nCD10'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'Linfoma no Hodgkin T periférico no especificado'
# [20/250] es-S0004-06142010000100015-1.txt | 26.23s | 7 chunks | 27 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'Mujer de 75 años de edad\nantecedentes de enfermedad pulmonar obstructiva, hipertensión arterial e hipercolesterolemia\nlesión renal'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'lesión quística compleja, multiseptada, de contornos polilobulados, de 11 cm de diámetro y con calcificaciones puntiformes periféricas, que ocupa la práctica totalidad de dicho riñón.'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'lesión renal izquierda de 11 x 7 cm de diámetro\nmultiseptada\ncalcificaciones puntiformes'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'ausencia de adenopatías retroperitoneales'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'nefroma multilocular quístico\ncarcinoma de células renales quístico'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'renograma isotópico con Tc-99m\nriñón izquierdo de inferior captación y funcionalismo\nlesión ocupante'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'R.I.: 25%\ngammagrafía ósea: Sin alteraciones.'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'lesión renal Bosniak III\nnefrectomía'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'nefroma quístico multilocular'
# [21/250] es-S0210-48062003000900009-1.txt | 32.98s | 9 chunks | 18 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'varón de 71 años de edad\ndolor testicular derecho\nirradiado\naumento del diámetro y de la consistencia testicular'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'síndrome constitucional\npérdida de peso'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'fiebre en picos de hasta 39ºC\nsudación profusa\nmicción no-clínica\nhematuria'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC\ninhaladores\noxígeno crónico domiciliario'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'palidez mucocutánea\ncrepitantes en la auscultación pulmonar\nedemas en miembros inferiores\nadenopatías\nhematomas en ambos miembros superiores'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'exploración genital\nhemiescroto derecho\nedema de cubiertas\naumento de la consistencia del epidídimo y del teste\ndesaparición del surco epidídimo testicular\nsignos de fluctuación\nabcesificación'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'Tacto rectal\npróstata adenomatosa\ngrado II-III/IV'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'hemoglobina\nplaquetas\nleucocitos'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'coagulación elevación del fibrinógeno 1500 (límites de la normalidad inferior a 400).'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'Lactato deshidrogenasa (LDH) elevada\nBHCG\nCEA\nAFP\nfunción renal\nhepática y pancreática normales'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'radiografía de tórax\ncongestión vascular\nradiografía de abdomen'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'ecografía renal y vesical sin alteraciones\npróstata de 4,5 x 4 x 4,1 cm.'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'Ecografía testicular, testículo izquierdo normal, testículo derecho se distingue hasta tres áreas heterogéneas con disminución de la ecogenicidad, sin calcificaciones que afectan a polo superior, inferior y epidídimo, no-hidrocele.'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'absceso testicular\ntuberculosis testicular\nbrucelosis\ntumor testicular'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'anatomía patológica\ntumor testículo de 8 x 6 x 4 cm\nmacroscópica de tumor testículo\nmasa blanquecina lobulada de 5,5 cm\ninfiltra albugínea y epidídimo\ncapa externa ni el borde hiliar'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'linfoma difuso B de células grandes\nalto índice de proliferación (minb1 > 80%)\nmarcadores CD 20+'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'Estadio 1E-B.\n\nlinfoma testicular primario\nTAC de cuerpo completo de estadiaje\nesplenomegalia homogénea\nadenopatías retroperitoneales aisladas inferiores a 1 cm'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'sudación profusa\nfiebre en picos\nastenia\nedemas de los miembros inferiores'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'anemia 8,9 gr/dl de hemoglobina\nplaquetas de 37000'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'síntomas B\nlinfoma testicular primario\nbiopsia de medula ósea\ncilindro de 3 x 0,3 cm\nmédula ósea hipercelular con cambios regenerativos y displásicos\nserie granulocítica'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'plasmocitosis intersticial\ninfiltración por células linfoblásticas'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'infiltración de la médula ósea\nfrotis sanguíneo\nanemia\ntrombocitopenia'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'agregación plaquetaria\ntest de Coombs directo\ninmunoglobulina G'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'disfonía\ndisfagia\nfibroscopia\nlesión polipoidea en seno piriforme'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'TAC cervical'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab\nCHOP (ciclofosfamida, doxorrubicina, vincristina, prednisona)'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'quimioterapia\nR-CHOP'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'radioterapia genital coadyuvante\nquimioprofilaxis cerebral'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: ''
# [22/250] es-S0210-48062004000200011-1.txt | 113.32s | 29 chunks | 91 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: 'paciente de 70 años\nsintomatología de tracto urinario inferior\ninicio de aumento de frecuencia miccional nocturna\nligera disuria\nleve disminución del calibre miccional'
#   [chunk 2/12 | chars 224-442]
#   RAW: 'sintomatología prostática incipiente\ntacto rectal (adenoma II)\ndeterminación de PSA\necografía abdominal'
#   [chunk 3/12 | chars 442-700]
#   RAW: 'intervención sobre el ojo izquierdo\ntraumatismo\nureterolitectomía del tercio superior del uréter\nlumbotomía'
#   [chunk 4/12 | chars 700-997]
#   RAW: 'masa parahiliar en el riñón izquierdo de unos 6 cm de diámetro\nriñón derecho normal\npróstata de 35 cc\nPSA dentro de los rangos normales'
#   [chunk 5/12 | chars 997-1381]
#   RAW: 'tumoración renal\nTAC\nimagen parapiélica izquierda\n5-6 cm de diámetro\naspecto sólido\nextiende desde el hilio renal hasta por debajo del polo inferior\ncompresión del riñón\nplano graso de separación con el mismo\ncalcificaciones en su interior\nvascularización'
#   [chunk 6/12 | chars 1381-1562]
#   RAW: 'masa renal\nmasa renal\nmasa renal'
#   [chunk 7/12 | chars 1562-1624]
#   RAW: 'lumbotomía izquierda'
#   [chunk 8/12 | chars 1624-1775]
#   RAW: 'masa comprimiendo riñón\nplano de disección entre ambos'
#   [chunk 9/12 | chars 1776-1889]
#   RAW: 'masa'
#   [chunk 10/12 | chars 1889-2050]
#   RAW: 'gas de la intervención previa\nexéresis de la totalidad de la tumoración'
#   [chunk 11/12 | chars 2050-2234]
#   RAW: 'exéresis de la masa\ngasas\nmaterial de aspecto caseoso'
#   [chunk 12/12 | chars 2234-2418]
#   RAW: 'análisis anatomopatológico\npared de la tumoración\nmaterial hialino con tendencia a la colagenización\nreacción inflamatoria sobre todo a expensas de histiocitos'
# [23/250] es-S0210-48062004000500009-1.txt | 47.95s | 12 chunks | 40 menciones
#   [chunk 1/11 | chars 0-130]
#   RAW: 'paciente varón de 61 años\nmasa renal\nepigastralgia'
#   [chunk 2/11 | chars 130-212]
#   RAW: 'colelitiasis\nhidrocelectomía'
#   [chunk 3/11 | chars 213-358]
#   RAW: 'dolor en fosas renales\nhematuria\nepisodios de infección urinaria\nastenia\nanorexia\npérdida de peso'
#   [chunk 4/11 | chars 359-424]
#   RAW: 'masas abdominales\nmegalias'
#   [chunk 5/11 | chars 424-618]
#   RAW: 'ecografía\nnódulo exofítico\ndiámetro mayor a nivel del polo superior del riñón derecho\náreas sólidas y quísticas\nzonas vascularizadas (Eco-doppler)'
#   [chunk 6/11 | chars 619-824]
# ...
#   [chunk 6/21 | chars 1242-1253]
#   RAW: 'Palidez'
#   [chunk 7/21 | chars 1253-1307]
#   RAW: 'imposibilidad para detectar pulso radial o cubital.'
#   [chunk 8/21 | chars 1307-1373]
#   RAW: 'Disminución de la temperatura'
#   [chunk 9/21 | chars 1373-1425]
#   RAW: 'Anestesia y parálisis total del miembro afectado.'
#   [chunk 10/21 | chars 1425-1655]
#   RAW: 'Ante los hallazgos clínicos, se decide realizar un diagnóstico de confirmación mediante medición de la presión intracompartimental con "Intra-Compartmental pressure monitor system" de Stryker®, obteniéndose un registro de 42mm Hg.'
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'síndrome compartimental agudo\nantebrazo derecho\nquirúrgico urgente'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: 'procedimiento quirúrgico\nanestesia general balanceada\ncontrol de la vía aérea con mascarilla laríngea'
#   [chunk 13/21 | chars 1907-1969]
#   RAW: 'Cefazolina'
#   [chunk 14/21 | chars 1970-2110]
#   RAW: 'incisión cutánea\nlínea media de cara volar de antebrazo\nflexura de codo\nlínea de Kaplan'
#   [chunk 15/21 | chars 2111-2191]
#   RAW: 'tejido celular subcutáneo\nhematoma'
#   [chunk 16/21 | chars 2192-2410]
#   RAW: 'sección longitudinal de la fascia antebraquial\nmusculatura epitroclear del antebrazo\nsección del ligamento anular del carpo'
#   [chunk 17/21 | chars 2411-2487]
#   RAW: 'lesiones vasculares\nsangrado activo arterial'
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'Nitrofural'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: 'fasciotomía\nrecuperación de la coloración y temperatura del miembro afecto\npulso arterial'
#   [chunk 20/21 | chars 2901-3087]
#   RAW: 'cirugía\nrelleno capilar inferior a 2 segundos\nmovilidad y sensibilidad distal\ndolor'
#   [chunk 21/21 | chars 3088-3211]
#   RAW: 'ausencia de dolor en antebrazo derecho\nbuen estado vasculonervioso distal'
# [244/250] es-S1887-85712016000100005-1.txt | 70.37s | 21 chunks | 56 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: 'coxalgia derecha'
#   [chunk 2/22 | chars 128-229]
#   RAW: 'dolor con práctica de ejercicio físico\nleve limitación de la movilidad en ciertas posturas'
#   [chunk 3/22 | chars 230-429]
#   RAW: 'Mecánico de profesión\nbicicleta (40 km diarios en fines de semana)\ncarrera 3 veces por semana durante 50 minutos\nmarcha de una hora los días que no realizaba carrera'
#   [chunk 4/22 | chars 430-528]
#   RAW: 'dolor\nincrementando progresivamente\nmarcha'
#   [chunk 5/22 | chars 528-725]
#   RAW: 'dolor a la palpación en tercio medio de la región inguinal derecha\ndolor a la flexión, aducción y rotaciones sobre todo interna (maniobra de choque positiva)'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'balance articular de caderas\nflexión 110o bilateral\nrotación interna de 10o derecha\nrotación externa de 30o derecha'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'balance muscular\nescala de Daniels\nbilateral'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'dolor a la palpación de puntos ciáticos\nmaniobras de Valleix, Fabere, Lasegue y Bragard'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'dolor a la palpación en la cintilla iliotibial\ntest de Ober'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'ausencia de claudicación\napoyo monopodal alterno derecho-izquierdo\nTrendelenburg negativo'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'dolor para la marcha\nflexión forzada de cadera y rodilla'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'radiología simple anteroposterior (AP)\ndeformidad en forma de joroba en región cérvico-cefálica femoral derecha'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'hemograma\nbioquímica\nhormonas tiroideas\nanticuerpos\nreactantes de fase aguda'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'leve alteración subcondral\nedema óseo en cadera derecha\nirregularidad cortical\nleve sinovitis en interlínea articular\ndistensión de la bursa ilio-psoas'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'cabeza femoral\nislote óseo\nángulo alfa'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'artrografía\npinzamiento de la interlinea articular antero-superior y posteroinferior\nincipiente collar osteofitario femoral con pequeñas lesiones subcondrales antero-superiores de cabeza femoral\npequeños focos de edema en acetábulo anterosuperior'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'necrosis avascular\nlesiones en el labrum'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'lesión quística\ntrocánter mayor'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'síndrome de pinzamiento femoroacetabular tipo LEVA (también conocido por CAM)\nmagnetoterapia (15 sesiones)\ndolor y trofismo óseo'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'sulfato de glucosamina-condroitin sulfato oral 400 mg cada 12 horas durante 3 meses\nantiinflamatorios no esteroideos'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'reposo deportivo\nchoque en la articulación\nactividad física activa controlada\nno sobrepasar los 90 grados de flexión de la cadera\nevitar las rotaciones'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'artroscopia\ncirugía artroscópica'
# [245/250] es-S1888-75462015000400006-1.txt | 86.34s | 22 chunks | 62 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'varón de 53 años de edad\nciclista veterano de carretera\nsin antecedentes médico-quirúrgicos de interés\nhábitos tóxicos ni reacción alérgica conocida a medicamentos\nfractura de tercio medio de clavícula derecha\nfractura de arcos costales derechos'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'buen estado general\nestando hemodinámicamente estable\nsin disnea\ndolor a nivel de clavícula y pared costal derechas\nsin síntomas ni signos de afectación neurovascular del miembro superior derecho'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'fractura de arcos costales derechos cuarto y quinto sin evidencia de hemotórax ni neumotórax, y fractura de tercio medio de la clavícula derecha con tercer fragmento, confirmada en la tomografía axial computarizada (a, 1b).'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'edematización del miembro superior derecho\npérdida de sensibilidad\npulsos periféricos conservados\nnormalidad de constantes\nauscultación cardiorrespiratoria con ruidos cardíacos normales a frecuencia normal sin soplos ni extratonos\nmurmullo vesicular conservado en ambos campos pulmonares'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'espirometría\nelectrocardiograma\necocardiograma\nCHCM=31.4g/dl\nneutrófilos=76.6%\nlinfocitos=16.4%\neosinófilos=0.9%\nfibrinógeno=645mg/dl\nGGT=52U/l\nD-Dímero positivo'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'eco-Doppler venoso\ntrombosis venosa\nvenas axilar, cefálica y basílica\ncompresión de la rama cubital del nervio cutáneo braquial medial a nivel del hiato basílico'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'vendaje en ocho por cabestrillo sencillo\nTinzapaina sódica\nradiografías y utrasonografía-Doppler seriadas de control\nfractura de clavícula\nvenas trombosadas'
# [246/250] es-S1888-75462016000400180-1.txt | 47.26s | 7 chunks | 37 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'paciente de 58 años'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomía\nmetrorragias secundarias a miomas'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'osteoporosis densitométrica lumbar\nT-score en L1-L4 de -3\ncifras normales en cuello femoral\ndenosumab\nsuplementos de vitamina D\nhábitos tóxicos\nantecedentes personales ni familiares de fractura\nIMC'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'dolor mecánico en el pie izquierdo\ninicio agudo\ninflamación\ncausa desencadenante\ndolor refractario a AINEs'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'dolor a la movilización del antepié izquierdo'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'No se observaron alteraciones de la estática de pies.'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Rx de pies'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'fractura de estrés\ncallo perióstico\nedema de tejidos blandos'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'PTH\nvitamina D\nexceso de suplementación de vitamina D\ncalcio sérico y urinario'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'suplementos de vitamina D\ndenosumab'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'Servicio de Traumatología\ntratamiento conservador\ndescarga\nreposo relativo\nAINEs\nmagnetoterapia'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'edad de la paciente\nosteoporosis a nivel lumbar\nSERMS (bazedoxifeno)\nsuplementos de calcio con vitamina D\ndolor en el episodio anterior\ndolor en pie izquierdo'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'callo de fractura antiguo\nfractura de estrés previa'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'RMN de pie izquierdo\nedema de 1er y 3er MTT\nhuesos cuneiforme, escafoides y astrágalo\ntenosinovitis del tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'densitometría ósea\nT-score en columna lumbar'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'bazedoxifeno\nvitamina D\ncifras de densidad mineral ósea'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'fracturas'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'osteoporosis'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'episodios de dolor\niniciasen el mismo mes (coincidiendo con cambio de estación) con un año de diferencia'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'paciente\ncambio en sus costumbres\nsedentaria\ncalzado\nfracturas de estrés'
# [247/250] es-S1889-836X2015000200005-2.txt | 68.71s | 20 chunks | 58 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'VIH'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'astenia\ndolores óseos difusos'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'elevación de la fosfatasa alcalina (FA) total y ósea\nelevación de la paratohormona (PTH)'
#   [chunk 4/16 | chars 408-569]
#   RAW: '25-hidroxivitamina D (25-HCC)\ncalcio total e iónico\nparámetros bioquímicos rutinarios en suero\nelemental y sedimento de orina'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'radiografía simple de columna\nsignos degenerativos\ngammagrafía con Tc99'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'empeoró su estado\nmayor astenia\ndisminución de fuerza\ndificultad para caminar\npérdida de 7 kg de peso'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'exploración física\ndebilidad muscular de predominio proximal'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperglucemia leve (154 mg/dl)\nglucosuria marcada (4+)\nhipofosfatemia\nfosfaturia inapropiadamente alta\nhipouricemia (2 mg/dl)\nligera acidosis metabólica (bicarbonato 19 mmol/l)\nproteinuria (945 mg/24h)'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'aminoaciduria moderada\nglicina (x2)\nvalina (x2)\nserina (x4)\ntreonina (x4)'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'FGF23'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Tabla 1'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'síndrome de Fanconi incompleto\nhipofosfatemia grave\nprobable osteomalacia\nTDF'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'raltegravir\ndarunavir potenciado con ritonavir'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'suplementos de fósforo\n25-HCC\n1,25-dihidroxivitamina D (1,25 DHCC)'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: ''
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'TDF\ndolores óseos\ndebilidad muscular\npeso basal\nalteraciones analíticas séricas\nreabsorción de fosfato'
# [248/250] es-S1889-836X2015000400006-1.txt | 58.60s | 16 chunks | 47 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'mujer\n33 años\ncuadro de astenia\nalergias no conocidas\nlupus cutáneo con eritema malar sin tratamiento desde hace 8 años\nreumatología'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Tiroiditis de Hashimoto.'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'apendicectomía'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'exfumadora'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'No bebedora.'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'habitos tóxicos\nquinina'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'anemia'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'cesárea\nligadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'Enfermedad actual:\nconsulta por intensa astenia y presíncopes (de una semana de evolución), que dificultan la deambulación, junto con anorexia sin pérdida de peso.'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'menstruación\nduradera\nabundante'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'melénicas\npalidez cutánea\nmucosa'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'epistaxis\ngingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'anemia\nhemoglobina\ntrombopenia\nplaquetas'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'LDH 1696 UI/l. Frotis sanguíneo con presencia de esquistocitos.'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'PTT\nLES'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'hematíes\nplaquetas'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'afasia global\ndesviación de la comisura bucal a la izquierda'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'lenguaje normal'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'añadido síntoma neurológico'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'microangiopatía trombótica\ncrisis convulsivas\nplasmaféresis'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: ''
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'plan de sesiones de plasmaféresis\nvolumen de recambio\nvolumen plasmático'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'tratamiento'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'paciente\npesa'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'tablas de relación'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'volumen a reinfundir'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'plasma fresco'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'albúmina humana al 20% + 1.400 cc.'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'solución Dianeal® 1,36% de diálisis peritoneal.'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'incidencia de las sesiones\n1a plasmaféresis en UCI\ncatéter en yugular derecha\ncatéter doble luz en femoral izquierda'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE (Hospal®)\nfiltro PTE-2000'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'heparina\ndosis de heparina\nsesiones de 210 minutos\ninfusión media de 980 ml/h\nflujos de sangre entre 120-140 ml/min\npresiones de PA.'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: '- 85 a -170 mmHg, y PV de 70 a 90 mmHg, manteniéndose una PTM entre 25-55 mmHg).'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'paciente en UCI\nmal estado general (sedada)\nconstantes mantenidas'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: '17 sesiones'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'incidencia de las mismas'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'hipotensión\nconvulsiones importantes\ndiazepam\nsalino fisiológico'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: '16a'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'fallo del test de aire\nfaltan 90 minutos'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'El resto de las sesiones se realizaron sin problemas, siendo bien toleradas por la paciente.'
# [249/250] es-S2254-28842014000200009-1.txt | 112.39s | 40 chunks | 75 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'carcinoma seroso papilar en ovario izquierdo\ncadena aorto-cava'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'quimioterapia adyuvante con carboplatino y paclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'CA 125'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'TAC\nresección anterior de recto superior con biopsia intraoperatoria de una lesión hepática que confirmó la naturaleza metastásica.'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'CA 125'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'carboplatino\ndisnea\nvómitos\npérdida de conocimiento\nTAS/TAD de 70/50 mmHg'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'infusión\ncorticoides'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'Unidad de Alergología\nesquema de desensibilización5\nenlentecimiento de la velocidad de infusión'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'disoluciones con concentraciones de 0,02, 0,2 y 2 mg/ml respectivamente, además de la premedicación la noche anterior y media hora antes de la infusión con:\n- Cetirizina 10 mg - Prednisona 1 mg/kg - Ranitidina 150 mg - Montelukast 10 mg'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'trabectedina\nadriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'marcadores\nenfermedad'
# [250/250] es-S2340-98942015000100005-1.txt | 38.40s | 11 chunks | 23 menciones
#
# Predicciones guardadas en distemist_llm_predictions.tsv
# Tiempo medio por archivo: 58.35s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd


def prf(tp, fp, fn):
    p  = tp / (tp + fp) if (tp + fp) else 0.0
    r  = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1


df_pred  = pd.read_csv(PREDICTIONS_TSV, sep="\t")
df_gs    = pd.read_csv(GS_TEST_TSV, sep="\t")
df_gs    = df_gs[df_gs["filename"].isin(df_pred["filename"].unique())]

set_gs   = set(zip(df_gs["filename"],   df_gs["label"],   df_gs["off0"],   df_gs["off1"]))
set_pred = set(zip(df_pred["filename"], df_pred["label"], df_pred["off0"], df_pred["off1"]))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1   = prf(tp, fp, fn)

report = {"Estricta": {"tp": tp, "fp": fp, "fn": fn, "precision": round(p, 4), "recall": round(r, 4), "fscore": round(f1, 4)}}

print(f"── ESTRICTA ──  P={p:.4f}  R={r:.4f}  F1={f1:.4f}  (TP={tp} FP={fp} FN={fn})\n")

thresholds = [0.0, 0.5, 0.8]
results    = {t: {"tp": 0, "fp": 0, "fn": 0} for t in thresholds}

for filename in df_pred["filename"].unique():
    gs_ints   = list(zip(df_gs[df_gs["filename"] == filename]["off0"],   df_gs[df_gs["filename"] == filename]["off1"]))
    pred_ints = list(zip(df_pred[df_pred["filename"] == filename]["off0"], df_pred[df_pred["filename"] == filename]["off1"]))

    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )

    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi); matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ──  P=0.1210  R=0.5008  F1=0.1949  (TP=1301 FP=9449 FN=1297)
#
# ── IoU ──
# IoU >= 0.0:  P=0.2102  R=0.8699  F1=0.3386  (TP=2260 FP=8490 FN=338)
# IoU >= 0.5:  P=0.1622  R=0.6713  F1=0.2613  (TP=1744 FP=9006 FN=854)
# IoU >= 0.8:  P=0.1276  R=0.5281  F1=0.2056  (TP=1372 FP=9378 FN=1226)
