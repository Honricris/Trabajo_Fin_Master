# %% [markdown]
# # Pipeline Five-Shot NER — DisTemIST con Mistral-7B-Instruct-v0.3
#
# Inferencia five-shot para reconocimiento de enfermedades en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install peft accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "unsloth/mistral-7b-instruct-v0.3-bnb-4bit"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo ENFERMEDAD.\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'neoplasia', no escribas 'cancer'.\n"
    "4. REPETICIONES: Si una enfermedad aparece varias veces en el texto, debes listarla varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio (como '-', '*', '•', '1.').\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
DISTEMIST_ROOT       = f"{PROJECT_ROOT}/distemist/distemist"
TEXT_FILES_TEST_DIR  = f"{DISTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{DISTEMIST_ROOT}/distemist_subtrack1_test_mentions.tsv"
PREDICTIONS_TSV      = "distemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : unsloth/mistral-7b-instruct-v0.3-bnb-4bit
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
import unsloth
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# ==((====))==  Unsloth 2026.6.6: Fast Mistral patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/4.14G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/157 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# Modelo cargado: unsloth/mistral-7b-instruct-v0.3-bnb-4bit
# Parámetros totales: 3,758,362,624

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

EXAMPLES = [
    {
        "text": "Con el diagnóstico de hipernefroma se realizó nefrectomía. La anatomía patológica fue de carcinoma de células renales del tipo de células claras de 8 cm de diámetro con invasión tumoral del uréter y de la vena renal. Tres meses después de la cirugía, la radiografía mostraba múltiples imágenes nodulares compatibles con metástasis.",
        "mentions": "hipernefroma\ncarcinoma de células renales del tipo de células claras de 8 cm de diámetro con invasión tumoral del uréter y de la vena renal\nmetástasis",
    },
    {
        "text": "Había sido fumador de 10 cigarrillos/día. No era consumidor de bebidas alcohólicas, no tenía hábitos tóxicos ni tomaba regularmente ningún medicamento. No refería antecedentes de muerte súbita ni de síncopes. Tras realizar un test de flecainida, se realizó un diagnóstico de SB.",
        "mentions": "fumador\nconsumidor de bebidas alcohólicas\nhábitos tóxicos\nmuerte súbita\nsíncopes\nSB",
    },
    {
        "text": "El paciente presenta fístula urinaria con abundante salida de orina e infección de herida quirúrgica. Tras la estabilización, se observa desaparición de fístula urinaria y necrosis grasa. Con el diagnóstico de fístula vésico-rectal se indica sondaje vesical hasta resolución de infección de herida quirúrgica.",
        "mentions": "fístula urinaria\ninfección de herida quirúrgica\nfístula urinaria\nnecrosis grasa\nfístula vésico-rectal\ninfección de herida quirúrgica",
    },
    {
        "text": "La tomografía reveló agenesia de cuerpo calloso aunada a un lipoma con bordes irregulares; espina bífida oculta a nivel de columna cervical y fisura central a nivel de la arcada del maxilar superior. Neurológicamente, a pesar de presentar agenesia del cuerpo calloso, se mantiene alerta y sin crisis convulsivas.",
        "mentions": "agenesia de cuerpo calloso\nlipoma\nespina bífida oculta a nivel de columna cervical\nfisura central a nivel de la arcada del maxilar superior\nagenesia del cuerpo calloso\ncrisis convulsivas",
    },
    {
        "text": "El paciente se lesionó ambos ojos concentrando los rayos solares con ayuda de una lupa buscando un fin estético. Asimismo se autoinduce unas quemaduras de segundo y tercer grado en la piel de la cara y los brazos para hacer desaparecer unos supuestos quistes.",
        "mentions": "se lesionó ambos ojos concentrando los rayos solares con ayuda de una lupa\nse autoinduce unas quemaduras\nquemaduras de segundo y tercer grado en la piel de la cara y los brazos\nquistes",
    },
]

def build_ner_messages(text):
    messages = [{"role": "system", "content": SYSTEM_PROMPT}]
    for ex in EXAMPLES:
        messages.append({"role": "user",      "content": f"Texto para analizar:\n{ex['text']}"})
        messages.append({"role": "assistant", "content": ex["mentions"]})
    messages.append({"role": "user", "content": f"Texto para analizar:\n{text}"})
    return messages

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            result = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
                eos_token_id=tokenizer.eos_token_id,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename": txt_path.stem,
            "mark":     f"T{mark_idx}",
            "label":    "ENFERMEDAD",
            "off0":     off0,
            "off1":     off1,
            "span":     span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "mark", "label", "off0", "off1", "span"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'diabetes\nhipertensión\nobesidad\nedad 62 años\nevolución 1 año'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'ENFERMEDAD\ndolor lumbar derecho\nbaja intensidad'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'Enfermedad\nnormal'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'enfermedad\nmasa suprarrenal derecha\nhipoecogénica\n80 mms\ncomprime el polo superior de riñón derecho'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'ENFERMEDAD\nurograma descendente\npolo superior de riñón derecho desplazado hacia abajo\nsuprarrenal derecha\nproceso expansivo'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'ENFERMEDAD\ntumor suprarrenal\ndensidad grasa'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'ENFERMEDAD\nnormal cortisol'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'cirugía\nabordaje lumbar'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'tumor\nglándula suprarrenal derecha\ntumor bien delimitado de bordes irregulares\nlobulaciones'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'adrenalectomía derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'ENFERMEDAD\nasintomática'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'ENFERMEDAD\npieza con un peso de 171,4 g\ndimensiones de 9 x 8 x 6 cms\ncorte con áreas amarillas - naranjas\ncorte con áreas de hemorragias\ncorte con tejido adiposo\ncorte con zonas de calcificaciones'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'mielolipoma\nglándula adrenal\ncalcificaciones'
# [1/250] S0004-06142006000100010-1.txt | 39.71s | 13 chunks | 27 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'adenocarcinoma gástrico\nhipertensión arterial\ngastrectomía subtotal'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'anorexia\npérdida de 12 kilos en 6 meses\npeso actual 42 kilos\nanemia hipocrómica\nestreñimiento'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'tumoración\nenfermedad\nconsistencia firme\nindolora\nmóvil\nocupaba las tres cuartas partes del abdomen'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'adenocarcinoma gástrico\nascitis por carcinomatosis\nobstrucción intestinal tumoral\ntumoración abdominal'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'ENFERMEDAD\nhemoglobina 7,5 gr/dl\nhematies 3,35 millones\nhematocrito 27%\nVCM 71,3\nRDW 18\nVSG 37 mm/h\nPCR 0,7\nPSA 2,6 ng/ml\ncreatinina 0,89\nurea 24'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'ENFERMEDAD\nhepáticos\ndigestivos\ntumorales\ntumorales hepáticos\ntumorales digestivos'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'gastroscopia\npólipo inflamatorio\nmuñón gástrico\nrecidiva tumoral'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'enfermedad\nintolerancia del paciente\ndesplazamiento intestinal\ncolonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'tumoración quística\ncontenido anecoico mixto\ntabiques incompletos\nocupa la totalidad de la cavidad abdominal'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'riñón izquierdo\nriñón derecho'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'ENFERMEDAD\nlesión quística voluminosa intraabdominal\nanulación funcional derecha\nnormofunción contralateral\ngran efecto masa\nurografía intravenosa\ndesplaza el luminograma digestivo hacia el hipocondrio izquierdo\nimpronta sobre la pared lateral derecha del cistograma'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'ENFERMEDAD\ngran masa quística\n29,5 cm x 27,5 cm x 16 cm\nmúltiples tabiques y paredes bien definidas\npráctica totalidad del abdomen'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'hidronefrótico\ncompresión\ndesplazamiento\nestructuras abdominales\nimagen cálcica\nteórica zona de pelvis renal de riñón'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'hidronefrosis gigante\nuropatía obstructiva litiásica\nnefrectomía'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'nefrectomía simple derecha\ncontenido serohemático\n7.800 mililitros'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'linfadenectomía hiliar ampliada\nadenopatías a dicho nivel'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'El cultivo del fluido resultó negativo\nno realizó citología\nno sospecha clínica de tumoración urotelial\nno sospecha radiológica de tumoración urotelial'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'ENFERMEDAD\nriñón de aspecto multiquístico\ndilatación del sistema pielocalicial\natrofia parenquimatosa severa\nespesor 0,5 cm'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'displasia de diferentes grados\ncambios en el revestimiento epitelial\npatrón papilar\ninfiltración del parénquima renal'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'carcinoma de células renales tipo célula clara\ncélulas de citoplasma amplio\ncélulas de citoplasma claro\ngrado 3 de Fuhrman\ninfiltración ganglionar\nnidos sólidos de células'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'metástasis hepáticas'
# [2/250] S0004-06142006000100014-1.txt | 88.26s | 21 chunks | 79 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'ENFERMEDAD\ndolor a nivel de hipogastrio\neyaculación dolorosa\nhemospermia\nsensación de peso a nivel testicular\nvaricocele derecho'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'varicocele derecho\nno se palpaban masas a nivel de ambos testículos'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'El tacto rectal mostraba una próstata irregular\nEl tacto rectal mostraba una próstata ligeramente aumentada de tamaño\nEl tacto rectal mostraba zonas induradas\nEl tacto rectal mostraba algo dolorosa a la exploración'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'enfermedad\nnodular hipoecoica en teste derecho\nhipervascularización circundante\nquiste simple en testículo izquierdo'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'Enfermedad:\nmetástasis\nhemangiomas'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'hemangiomas'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'tórax\nenfermedad\nalteraciones'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'ENFERMEDAD\nPSA\nnormalidad'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'Alfa-feto-proteína\nbeta-HCG\nPSA'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'ENFERMEDAD\nformación nodular\ncoloración a la de la pulpa testicular\n2,5 x 1,8 x 1,5 cm\npolo superior del testículo'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'tumor de células de Leydig difuso\ninfiltraba espacios perineurales\ninfiltraba canales vasculares capsulares adyacentes\ninfiltraba músculo liso\natípia moderada\nmitosis escasas'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'enfermedad\nneoplasia\nmetástasis\nmarcadores tumorales'
# [3/250] S0004-06142006000500002-2.txt | 46.41s | 14 chunks | 31 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'neoplasia de testículo\ncriptorquidia bilateral\norquidopexia (2 veces)'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'nefríticos\ncolicos\nlitiasis\nLEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Ureterolitectomía'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'fumador\ncigarrillos/día'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'enfermedad\nesterilidad\nnódulo en testículo izquierdo\nmes de evolución\naumentado de tamaño en las últimesemanas'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'azoospermia total'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'tumor testicular\nquiste de cordón izquierdo'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'ENFERMEDAD\nquiste de epidídimo en cabeza'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'El testículo derecho\nencontrado en el canal inguinal'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'Se procedió a completar el estudio.'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'enfermedad\nTAC toraco-abdómino-pélvico\nmetástasis'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'enfermedad\nneoplasia\nalfa-fetoproteina\nbeta-HCG'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'orquiectomía radical inguinal derecha\nbiopsia del testículo izquierdo vía inguinal'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'ENFERMEDAD\ntesticular\ntesticular derecho\ntesticular derecho de 3,2 x 3 cm'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'ENFERMEDAD\ninfiltración de túnica vaginalis'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'ENFERMEDAD\nneoplasia\nneoplasia sólida\nneoplasia sólida bien delimitada\nneoplasia de 1,5 cm de diámetro\nneoplasia de coloración parda\nneoplasia con área amarillenta central'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'ENFERMEDAD\nanaranjado tejido testicular restante'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'El cordón espermático no presenta alteraciones.'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'ENFERMEDAD\nneoplasia\ntesticular\nizquierdo\nbiopsia\ncoloración parda\n0,3 cm'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'ENFERMEDAD\nTumor de células de Leydig\n3,2 x 3 cm\nsin infiltración del epidídimo\nsin infiltración de la túnica albugínea\nsin invasión vascular'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'Resto de parénquima testicular\natrofia\nhiperplasia de células de Leydig en el intersticio\nausencia de espermiogénesis'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'Bordes quirúrgicos libres.'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'atrofia testicular\nausencia de espermiogénesis\nhiperplasia de células de Leydig intersticial'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'ENFERMEDAD\nmetástasis\nmarcadores tumorales'
# [4/250] S0004-06142006000500002-3.txt | 76.92s | 25 chunks | 41 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'masa renal derecha'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'masa sólida y heterogénea de aproximadamente 6 cm\nlocalizada en polo superior del riñón derecho\npresencia de una masa sólida y heterogénea\nvena renal permeable'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'nefrectomía radical derecha\nadenopatías'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'carcinoma renal de células claras\n8,4 centímetros\npT3aNoMo\nII de Robson\ngrado nuclear IV de Fuhrman'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'El paciente\ncirugía'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'neoplasia\ndolor en hipocondrio derecho\ndolor en hipocondrio derecho de reciente aparición'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'recidiva tumoral\nmasa dolorosa en el hipocondrio derecho\nTAC\nimplantes peritoneales\nimplante peritoneal de cuatro centímetros adyacente al hilio hepático\ninfiltración pilar diafragmático derecho posterior\ninfiltración hígado'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'carcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células claras de alto grado\ncarcinoma de células'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'masa retroperitoneal paravertebral\nenfermedad'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Enfermedad:\nOncología\nInterferón (Intrón A)\nmala tolerancia\nreducción de la dosis'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'Enfermedad:\nmetástasis\nrecidiva del lecho quirúrgico\nimplantes peritoneales en epiplon'
# [5/250] S0004-06142006000900015-1.txt | 58.46s | 11 chunks | 31 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'ENFERMEDAD\nPaciente varón de 29 años.'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'tumoración indolora en testículo izquierdo\ntestículo izquierdo hipogénico\ntestículo izquierdo disminuido de tamaño\ntestículo derecho con parénquima heterogéneo\nneoplasia'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'ENFERMEDAD\nNo presenta otra sintomatología urológica\nNo astenia\nNo pérdida de peso'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'Enfermedad\nNo hay enfermedad en el texto.'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'Enfermedad\nteste izquierdo hipotrófico\nteste derecho aumentado de tamaño'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'ENFERMEDAD\nnormal\nconsistencia normales\nsuperficie regulares'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'Epididimitis\ncordones sin hallazgos patológicos'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'hemostasia\nbioquímica\nhemograma\nalfa-feto proteína\n2.7ng/ml\nbeta-hCG\n4.2mUI/ml'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'ENFERMEDAD\ntesticular\nlesión hipoecoica\nbordes lobulados\nheterogénea\nocupa prácticamente todo el testículo\naumento del flujo Doppler'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'ENFERMEDAD\nteste izquierdo de 32mm x 22mm x 20mm hetrogéneo\nlesión focal ligeramente hipoecoica\naproximadamente 9mm\nsutil flujo Doppler'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'microlitiasis testiculares bilaterales'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Enfermedad\nadenopatías\nmetástasis'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'tumor testicular bilateral\norquiectomía bilateral vía inguinal\ntratamiento hormonal sustitutivo'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'testículo izquierdo atrófico\nmúltiples focos microscópicos de seminoma clásico\nneoplasia intratubular de células germinales (NICG)\nausencia de infiltración tumoral en albugínea\nausencia de infiltración tumoral en rete testis\nausencia de infiltración tumoral en epidídimo'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'tumoración\nseminoma clásico\nneoplasia\nNICG\natrofia'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'Túnica albugínea\nrete testis\nepidídimo\nborde quirúrgico libres de tumor'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'El tratamiento se completó con dos ciclos de quimioterapia con carboplatino'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'enfermedad\nremisión completa\nenfermedad'
# [6/250] S0004-06142007000200017-1.txt | 66.40s | 18 chunks | 50 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'ENFERMEDAD\nneoplasia\ncáncer\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nne'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'HEA\naumento progresivo de los órganos genitales externos\ntrasudación de la linfa\nimpotencia sexual'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'ENFERMEDAD\nedema marcado del pene\neritema\ndolor\nescroto'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'adenopatías inguinales\nno dolorosas'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'enfermedad\nHemograma completo\ncifras normales'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'ENFERMEDAD\nserología\nNo reactiva'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'ENFERMEDAD\nPrueba de Mantoux: Negativa\nProteinas totales y fraccionadas: Normales\nRX de cadera: Ausencia de lesión ósea'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'necrosis aséptica de la cabeza del fémur\nhipertrofia del psoas a ese nivel'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'exploración retroperitoneal derecha'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'adenectomía de ilíaca derecha\ncava'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'linfangioplastia con aguja'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'fasciotomía\nraíz del pene'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'quiluria\nedema de los miembros inferiores\nvaricocele\nhidrocele'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'Linfedema primario inflamatorio local de pene y escroto'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'Necosis aséptica de la cabeza del fémur.'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'ENFERMEDAD\nurólogo\nangiología\ncirujano plástico'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'Estenosis linfática\ndistorsión de la anatomía\ndistorsión y atrapamiento de los conductillos linfáticos\ntejido conjuntivo fibroso aumentado\ndisminución de las fibras elásticas\nestenosis linfática a nivel peneano'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'piel\ndermis\ndartos\nmúsculo peripeneal de Sappey\nuretra\narteria peneana'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'escroto\ndartos muscular\ncelulosa\nfascia de Cooper\nsegunda túnica muscular llamada eritroide\nbloque que debe ser extirpado en su totalidad\ncapa vaginal que recubre los testículos\npaquete vasculo nervioso\nepidídimo'
# [7/250] S0004-06142007000600012-1.txt | 83.60s | 20 chunks | 52 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'ENFERMEDAD\nnódulo testicular'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'nódulo duro\nmóvil\ndoloroso a la palpación\ncordón espermático derecho\nenfermedad'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'Enfermedad\nnormalidad\nmarcadores tumorales\nhormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'ENFERMEDAD\nhipoecoica\necogenicidad mixta\n2,8 cm\ncordón espermático'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'Enfermedad\ncordón espermático derecho\ntejido con bajo contenido en agua\nfibroso o cicatricial\n43 mm de diámetro máximo'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'tumoración paratesticular derecha\ntumoración paratesticular derecha'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'El paciente cursa sin incidentes\nEl paciente se encuentra asintomático en la actualidad'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'ENFERMEDAD\nformación redondeada de coloración pardusca y consistencia elástica\n5 cm de diámetro máximo\nsuperficie blanquecina y homogénea de aspecto fibroso'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'ENFERMEDAD\nlesión bien circunscrita\ncélulas con amplio citoplasma eosinófilo\npresencia de estriaciones transversales\ncélulas inmersas en un estroma fibroblástico\ncélulas de aspecto vacuolado\ncélulas multinucleadas\nno observándose actividad mitótica'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'ENFERMEDAD\nneoplasia\nneoplasia (intensa y generalizada expresión para desmina y vimentina)\nneoplasia (focal para actina de músculo liso específica)'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'ENFERMEDAD\nGranada'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'enfermedad\nEspaña'
# [8/250] S0004-06142007000600014-1.txt | 45.04s | 12 chunks | 29 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'ENFERMEDAD\nherida de arma de fuego\nherida de arma de fuego con orificio de entrada en la nalga\nherida de arma de fuego con diámetro de 4 milímetros\nherida de arma de fuego sin orificio de salida'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'herida de bala\nmuslo derecho\norificio de entrada por detrás\norificio de salida por delante\nsin afectación de estructuras importantes'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'El paciente\nenfermedad\nligera defensa abdominal'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'Enfermedad:\n- bala a la altura de la sínfisis del pubis\n- fractura de la rama descendente derecha del pubis'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'enfermedad: retención\nenfermedad: catéter suprapúbico'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'laparotomía\ncolostomía izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'ENFERMEDAD\nuretritis\nfiebre alta\nescalofríos\nrectitis'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'enfermedad\nperforación rectal'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'uretrotomo endoscópico\nuretra prostática\nuretra\nrecto\norificio\nuretra con el recto'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'vejiga\nsonda del dieciocho'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'laparotomía\nsínfisis del pubis\nabdomen\nninguna lesión'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'hiperplasia de próstata'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'ENFERMEDAD\nbalas'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'El paciente cursa sin incidencias\nsonda'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'enfermedad\norificio rectal\ncolostomía\nasintomático'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'enfermedad\nsonda\ntres meses\nseis meses'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'uretrografía\nbrecha\nsonda'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'enfermedad\nasintomático\nfunción sexual normal\nultrasonido\nnormal'
# [9/250] es-S0004-06142007000900010-1.txt | 55.05s | 18 chunks | 39 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'enfermedad\napendicectomía\nhernia discal y de hiato\nfractura de tibia y peroné\ncólico nefrítico derecho'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'neoformación sólida en riñón derecho de 5 cm.'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'ENFERMEDAD\nmasa a nivel cortical de riñón derecho\naproximadamente 5 cm\nbordes externos lobulados\nno afectar al espacio perirrenal\nno adenopatías\nno dilatación de vía renal excretora'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'hipernefroma\nnefrectomía radical derecha\nlaparoscopia'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'neoformación cortical\n5 cm de diámetro máximo\nbien delimitada\nno encapsulada\ndeforma la superficie cortical sin atravesarla\ncoloración amarillenta\náreas de aspecto hemorrágicas\náreas quísticas'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'ENFERMEDAD\nneoplasia\nneoplasia acinar\nneoplasia acinar con estructuras acinares\nneoplasia acinar con pequeñas células cuboidales uniformes\nneoplasia acinar con escaso citoplasma\nneoplasia acinar con núcleos con cromatina uniforme\nneoplasia acinar inmersa en un estroma ligeramente celular'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'enfermedad\nvimentina\ncitoqueratina 7\ncitoqueratina de amplio espectro\nCD34\ncromogranina\nEMA (Master Diagnostic.)'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'ENFERMEDAD\nGranada'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'ENFERMEDAD\nEspaña'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'vimentina\ncitoqueraina 7\nEMA\nCD34'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'intervención\nasintomática\n24 meses de la intervención'
# [10/250] es-S0004-06142007000900012-1.txt | 44.96s | 11 chunks | 33 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK\nsinusitis bilateral\nbronquiectasias\ndesprendimiento retina de ojo derecho\naumento del tamaño testicular\ninduración'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'dolor lumbar\ndolor testicular izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'neoplasia\nneoplasia'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'enfermedad\nadenopatías'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'tumor testicular tipo seminoma\nganglios locorregionales'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'situs inversus\ncámara de gases gástrica a la derecha\napex de la silueta cardiaca a la izquierda\ncicatricial\nbronquiectasias en lóbulo inferior izquierdo'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'LDH: 340\nGOT: 44\nGPT: 44'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'Marcadores tumorales\na-fetoproteína: 1.1 ng/ml (1-7)\nb-HCG <5.0 mUI/ml\norquiectomía inguinal\nraquianestesia a nivel L3-L4\nbupivacaína hiperbárica\nprótesis testicular'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'seminoma clásico\n2.5 cms de diámetro\nalbugínea\nsin sobrepasarla\nrete testis\ncordón espermático\nbordes quirúrgicos'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'No se evidencia invasión vascular.'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Neoplasia germinal intratubular'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'fibrosis\nhialinización tubular de testículo no tumoral'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'seminoma grado I\ntratamiento adicional\nnormalidad bioquímica de los parámetros tumorales\nexploración física\npruebas por imágenes negativas'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'azooospermia\nazooospermia\nazooospermia'
# [11/250] es-S0004-06142008000300011-1.txt | 48.75s | 14 chunks | 41 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'ENFERMEDAD\ndolor abdominal difuso\ndolor abdominal difuso con mayor intensidad en epigastrio\nnáuseas\nvómitos biliosos\nmal estado general'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'dolor\ntos\ninspiración'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'ENFERMEDAD\nfiebre\nsensación distérmica'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'No coluria\nNo acolia'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'enfermedad\ndolor\ngravedad'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'Palidez mucocutánea.'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'Enfermedad\nafebril\nnormotensa'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Enfermedad\ncardiopulmonar\nsin hallazgos'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'ENFERMEDAD\ndolor abdominal generalizado\ndolor abdominal más intenso en epigastrio\nMurphy negativo'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'circulación colateral'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'ENFERMEDAD\nedemas\nedemas en miembros inferiores'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'ENFERMEDAD\ntrombosis venosa profunda (TVP)'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'Enfermedad:\n- aumento de transaminasas\n- GOT: 146 U/L\n- GPT: 171 U/L'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'ENFERMEDAD\nhemograma con hemoglobina: 11.4 g/dL\nhematocrito: 34%\nleucocitos: 12700 sin neutrofilia\nplaquetas: 291000'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'enfermedad\nHemostasia\nINR\n1.3\ntiempo de cefalina\n53.3 seg.'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'trombo\ndensidad grasa\nriñón izquierdo\nvena renal izquierda (VRI)\nvena cava inferior (VCI)\nostium de aurícula derecha'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'enfermedad\nVenas suprahepáticas libres'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'ENFERMEDAD\nNo oclusión completa de la luz de VCI.'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'Anormalidad inespecífica de cabeza de páncreas.'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'hígado\nvía biliar intra y extrahepática normales\nepigastralgia'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Lipoma\nenfermedad\nVCI'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'colecistitis\ncolecistitis perforada\npancreatitis'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'Líquido libre en pelvis\nLíquido libre en espacios perihepático\nLíquido libre en espacios periesplénico\nLíquido libre en espacios perirrenal derecho'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'ENFERMEDAD\npatología bilio-pancreática'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'Síndrome de Budd-Chiari\nderrame pleural bilateral\nengrosamiento de pliegues gástricos\naumento de la captación de contraste\nangiomiolipoma (AML)'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'lipoma renal\nVCI\nostium de la aurícula derecha\nvenas venosas\nvena porta\nvenas suprahepáticas\npermeables'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'hepatomegalia\naumento de calibre de vena porta y suprahepáticas con retardo e la llegada de contraste a las mismas\nedema periportal\nbazo\npáncreas atigrado\nabundante líquido libre'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'presunción de síndrome de Budd-Chiari\nsecundario a trombo en cava\nparacentesis bajo control ecográfico\nexcluir con mayor certeza proceso peritoneal infeccioso/ tumoral como causante de dicho sín drome'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'Se obtiene resultado analítico de trasudado\nperitoneal'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'En ecografía transesofágica\nderrame pericárdico'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Síndrome de Budd-Chiari\nAML vs.'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'Lipoma'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'INTERVENCIÓN QUIRÚRGICA.'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'trombo\nnivel quirúrgico IV\nsituación supradiafragmática\nostium de aurícula derecha'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'ENFERMEDAD\nligadura de vena mesentérica inferior'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'movilización hepática\nligamentos redondo\nligamentos coronario\nligamentos triangulares derecho e izquierdo\nligamentos falciforme'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'riñón izquierdo\nhilio correspondiente\nliberación de la vena cava\nnivel infrarrenal\nnivel suprahepático\ncontrol de vena renal derecha (VRD)\nsección del resto de ramas\nvenas suprahepáticas\nvenas suprahepáticas que se comprueban libres de trombo tumoral\nvenas suprahepáticas que fijan la cava al hígado'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'hiato diafragmático\ntrombo\nhiato diafragmático\ntrombo\nnivel infradiafragmático'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'clampaje de pedículo hepático\nVCI proximal y distal\nVRD\ncavotomía\napertura VRI\nextracción completa del trombo\nnefrectomía izquierda'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'angiomiolipoma\npredominio lipomatoso\nseno renal\ninfiltración vascular'
# [12/250] es-S0004-06142008000300012-1.txt | 139.46s | 40 chunks | 109 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'ENFERMEDAD\ncólico nefrítico derecho\nhematuria'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'diclofenaco\nartrosis\nlumbalgia'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'litiasis\nquiste renal gigante'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'quiste renal simple (Bosniak I)\n17 centímetros\nriñón derecho\nlitiasis ipsilateral de 8 milímetros'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Hemograma\nenfermedad\nnormalidad'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'ENFERMEDAD\nquiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'enfermedad\nposibilidades'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'Quiste\ndrenaje percutáneo\nesclerosis del quiste'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'cistitis'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'antibiótico\ntratamiento\ntratamiento antibiótico de modo domiciliario'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'ENFERMEDAD\nquiste\nreducido de tamaño'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'ENFERMEDAD\nneoplasia\ncáncer\ntumor\ncarcinoma\ncáncer de células renales\ncáncer de riñón\ncáncer de hígado\ncáncer de páncreas\ncáncer de pulmón\ncáncer de mama\ncáncer de colon\ncáncer de vejiga\ncáncer de próstata\ncáncer de piel\ncáncer de hueso\ncáncer de cerebro\ncáncer de ovario\ncáncer de testículo\ncáncer de garganta\ncáncer de garganta de adulto\ncáncer de garganta de niño\ncáncer de garganta de adolescente\ncáncer de garganta de anciano\ncáncer de garganta de mujer\ncáncer de garganta de hombre\ncáncer de garganta de niña\ncáncer de garganta de niño\ncáncer de garganta de adolescente\ncáncer de garganta de anciano\ncáncer de garganta de mujer\ncáncer de garganta de hombre\ncáncer de garganta de niña\ncáncer de garganta de niño\ncáncer'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'calcificación\nAdemás\nse calcificó\nPared'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'ENFERMEDAD\nquiste\ncomunicaba con el sistema pielocalicial'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'microhematuria\nleucocituria'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'cólico derecho\ncistitis'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'litiasis\npelvis renal'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'infección urinaria\nE.Coli\nAmoxicilina-Clavulanico\nTrimetropin-Sulfametoxazol'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'infección\nlitiasis\nlitotricia extracorpórea'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'enfermedad\nasintomática'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'ENFERMEDAD\nquiste\nruptura del quiste\nTAC\nlesión\ndiámetro\n2,9 centímetros\ncalcificaciones gruesas y nodulares\nno capta contraste'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Bosniak IIF'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'enfermedad\nlesión\necografías de control\nUIV\nTAC\nconfirman\naspecto\nno ha variado'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'ENFERMEDAD\ncomunicación con la vía urinaria'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'La paciente permanece asintomática.'
# [13/250] es-S0004-06142008000300013-1.txt | 87.44s | 26 chunks | 62 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'carcinoma de próstata\nmedianamente diferenciado\nestadio Gleason 5\nprostatectomía radical\nlinfadenectomía obturatriz\nafectación microscópica limitada de los márgenes de resección'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'ENFERMEDAD\ntumor testicular derecho\ntumor testicular negativos\nmasa con áreas irregulares\ndisminución de flujo vascular en estudio doppler'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'ENFERMEDAD\nTAC abdominal sin hallazgos'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'adenopatías retroperitoneales\narea inguinal\nbifurcación de renales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'linfoma testicular difuso de célula grande tipo B\norquiectomía inguinal\nquimioterapia citorreductiva según esquema R-CHOPx8\nremisión completa tras la inducción'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'ENFERMEDAD\nrecidiva precoz\ntratada en segunda línea\nIFOVM / DHAP\nremisión inicial\ntres ciclos\nnueva recidiva\nfalleciendo a los 14 meses del diagnóstico'
# [14/250] es-S0004-06142008000400011-2.txt | 26.84s | 6 chunks | 22 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'hipertensión arterial'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'ENFERMEDAD\nmetrorragias\ndolor abdominal'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'no refería hematuria\nno refería dolor en fosas renales'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'ENFERMEDAD\nmasa anexial izquierda de 7 cm de diámetro mayor y muy vascularizada'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'carcinoma ovárico primario\ncarcinoma ovárico primario'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'ENFERMEDAD\nnódulos\n17 mm\n10 mm\ndependientes del polo superior del mismo riñón\nsimilares características que las lesiones anteriores'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'ENFERMEDAD\nlesión sólido-quística\n90 x 65 mm\nintensa captación de contraste'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'adenopatías regionales\nimplantes metastásicos peritoneales'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'carcinoma ovárico primario\nmetástasis renal secundaria\nhisterectomía total\ndoble anexectomía\nnefrectomía radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'metástasis\ncarcinoma de células renales'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'carcinoma de células renales grado I de Fuhrman\ncarcinoma de células renales\ncarcinoma de células renales extendiéndese a grasa perirrenal\ninfiltrar la vena renal'
# [15/250] es-S0004-06142008000400013-1.txt | 36.79s | 11 chunks | 25 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'adenocarcinoma gástrico\ncarcinoma de próstata Gleason VII\nprostatectomía radical\nganglio linfático afectado por el tumor\nbloqueo androgénico\nPSA de 0,06 en la ultima revisión'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'ENFERMEDAD\nlesión exofítica\nglande\ncinco semanas de evolución'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'enfermedad\nlesión\nsangrado\ntraumatismo\nlesión previa'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'ENFERMEDAD\nlesión redondeada exofítica\ncolor rojizo oscuro\ndiámetro 2 cm\nsangrado\nconsistencia elástica\nno dolorosa'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'enfermedad\ntumoración\ntumoración de aspecto macroscópico no infiltrante\ntumoración asentanda en la mucosa del glande\náreas de aspecto trombosado\náreas fácilmente friables'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'melanoma'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'resección\npenectomía subtotal\nmargen de seguridad desde el borde de la lesión\nlinfadenectomía inguinal superficial bilateral\nganglios no afectados por el tumor'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'enfermedad metastásica'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'ENFERMEDAD\ninvasión de 1,5 mm'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'melanoma'
# [16/250] es-S0004-06142008000400016-1.txt | 36.69s | 10 chunks | 30 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'endometriosis ovárica\nhisterectomía abdominal\ndoble anexectomía por endometriosis\nedad 46 años\ndolor continuo en región iliaca y sacra derecha\nantiinflamatorios\nectasia renal'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'dolor\ndoloramiento\npatología retroperitoneal\nfosa lumbar derecha\nfosa lumbar izquierda'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'enfermedad\nriñón derecho\nretraso en la captación y eliminación de contraste\nborramiento de la línea de psoas derecho'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'ENFERMEDAD\nimagen lobulada de contenido líquido\naparente extravasación de contraste\nincluido en dicha formación\nuréter'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'urinoma\nligadura o sección del uréter derecho\nureterolisis\nexéresis del urinoma\nanastomosis termino-terminal del uréter\nrefrescamiento de los bordes\nliberación de ambos extremos'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'Se deja catéter doble J\ntutorizando el uréter\nque se retira al mes de la cirugía'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'ENFERMEDAD\ncomplicaciones en el postoperatorio'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'Enfermedad:\nnormalidad de la vía urinaria en UIV'
# [17/250] es-S0004-06142008000500009-1.txt | 32.82s | 8 chunks | 29 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'Infecciones Urinarias (ITUs)\ndolor hipogástrico\n74 años\nmujer\nConsulta Externa de Ginecología\nUrología\nrepetición\n6 meses de evolución'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'histerectomía\nprolapso uterino\nhisterectomía vía vaginal\ncirugía\nfiebre\ndolor\nabsceso de cúpula vaginal\nabsceso\ndrena espontáneamente\ndesapareciendo el cuadro clínico\nECO\nTC\nabsceso en cúpula vaginal\nningún otro hallazgo'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'No DM.'
#   [chunk 4/15 | chars 616-623]
#   RAW: 'No HTA.'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'ENFERMEDAD\nNo alergias conocidas.'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'No hematuria'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'ENFERMEDAD\nNo cólicos'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'Infecciones de orina'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'G2 A0V2'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'ENFERMEDAD\nlitiasis vesical\ninfecciones de orina de repetición'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'Enfermedad'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'ENFERMEDAD\ncuerpo extraño intravesical\nlitiasis intravesical\ncirugía referido'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'uretrocistoscopia\ngran "pelotón de gasas"\nadherida a la pared vesical\ncalcificada\nno se moviliza\nTC pélvico\nvalorar extensión y tamaño\nrelaciones con el área'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'litiasis intravesical\ncuerpo extraño\ncistoslitectomía\ncistogasomectomía\ncuerpo extraño abandonado probablemente en la cirugía de la histerectomía'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'ENFERMEDAD\ninfecciones de orina de repetición'
# [18/250] es-S0004-06142008000700003-1.txt | 49.06s | 15 chunks | 45 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'EPOC moderado'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'fumador\n20 paquetes/año\nbebedor'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'Enfermedad\nNo hay ninguna mención de enfermedad en el texto.'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'uretrorragia\nimposibilidad para la micción'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'Ante la imposibilidad para el sondaje urinario\ntalla suprapúbica\nestudio'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'neoplasia vesical\ndivertículo único\ntamaño similar a vejiga (mayor de 13 cm de diámetro máximo)\npolipoideas parietales menores de 2-3 cm tanto en vejiga como en divertículo'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'ureterotomía\nestenosis uretral\ncistoscopia\ntumor sólido de prácticamente 7 cm\ncalcificado en cara lateral\nresección transuretral\nenfermedad residual'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'fibroblástica reactiva\ntumor fibroso solitario'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'cistectomía parcial\ndiverticulectomía\nleiomiosarcoma de bajo grado\nmitosis =3 X10 campos de gran aumento'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'pleomorfismo celular'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'necrosis intratumoral\nnecrosis celular aislada'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'Extensas áreas de cambio mixoide'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'inflamación intra y peritumoral'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'infiltración de todo el espesor de la pared diverticular\nreacción fibrosa peritumoral'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'Márgenes quirúrgicos libres de tumor.'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'Inmunohistoquímica\nvimentina\nactina\ndesmina\nEMA\nCitoquerqatinas de Alto Peso Molecular'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'leiomiosarcoma de bajo grado\ninfiltración de todas las capas\ntratamiento complementario\nalto riesgo del paciente'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'enfermedad a distancia\nTAC toracoabdominal\ngammagrafía ósea\nRMN pélvica'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'radioterapia locorregional\nquimioterapia complementaria'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'radioterapia locorregional\n57 Gy'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'ifosfamida-adriamicina\nquimioterapia\ncombinación\ndosis habituales\ntres ciclos\ntratamiento'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'enfermedad\ncistoscopias\ncitología urinaria\nTAC toraco-abdomino-pélvico\nrevisión estricta\nperiódica'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: 'enfermedad\nasintomático\ncalidad de vida'
# [19/250] es-S0004-06142009000400011-1.txt | 75.76s | 23 chunks | 65 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'ENFERMEDAD\nmasa\ndolor testicular derecho\ndolor testicular derecho de 2 meses de evolución\nmasa y dolor testicular derecho de 2 meses de evolución'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'Enfermedad\nNiega antecedentes patológicos\nNiega otra sintomatología'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'ENFERMEDAD\naumento difuso del tamaño del testículo derecho\nalteración difusa de la ecogenicidad del testículo derecho\n6.2x5.8x4.2 cm'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'enfermedad\norquidectomia\ntestículo aumentado de tamaño\ncauchoso\nblanquecino'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'neoplasia maligna hematolinfoide\ninfiltración difusa del parénquima testicular\ncélulas de pequeño tamaño\ncélulas irregulares\ncítoplasma escaso\nangiotropismo\náreas de necrosis asociadas'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'ENFERMEDAD\nACL positiva\nCD3 positiva\nKi67 del 90%\nTdT negativa\nCD30 negativa\nALK negativa\nbcl2 negativa\nbcl6 negativa\nCD10 negativa'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'Linfoma no Hodgkin T periférico no especificado'
# [20/250] es-S0004-06142010000100015-1.txt | 31.05s | 7 chunks | 16 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'enfermedad pulmonar obstructiva\nhipertensión arterial\nhipercolesterolemia\nenfermedad renal'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'ENFERMEDAD\nlesión quística compleja\nmultiseptada\nde contornos polilobulados\nde 11 cm de diámetro\ncon calcificaciones puntiformes periféricas\nocupa la práctica totalidad de dicho riñón'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'ENFERMEDAD\nlesión renal izquierda\ndiámetro 11 x 7 cm\nmultiseptada\ncalcificaciones puntiformes'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'Ausencia de adenopatías retroperitoneales.'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'nefroma multilocular quístico\ncarcinoma de células renales quístico'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'renograma isotópico con Tc-99m\nriñón izquierdo de inferior captación y funcionalismo\nlesión ocupante\nimagen fría central'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'ENFERMEDAD\n25%\nGammagrafía ósea\nSin alteraciones'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'lesión renal Bosniak III\nnefrectomía'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'nefroma\nquístico\nmultilocular\nsin atipias'
# [21/250] es-S0210-48062003000900009-1.txt | 31.99s | 9 chunks | 28 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'ENFERMEDAD\ndolor testicular derecho\ndolor testicular derecho de tres meses de evolución\naumento del diámetro y de la consistencia testicular en el último mes'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'ENFERMEDAD\nsíndrome constitucional\npérdida de peso\npeso en el último mes'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'fiebre\nsudación profusa\nno-clínica miccional\nnohematuria'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC\ntratamiento con inhaladores\noxígeno crónico domiciliario'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'Enfermedad:\npalidez mucocutánea\ncrepitantes en la auscultación pulmonar\nedemas en miembros inferiores\nhematomas en ambos miembros superiores'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'edema de cubiertas\naumento de la consistencia del epidídimo y del teste\ndesaparición del surco epidídimo testicular\nsin signos de fluctuación ni de abcesificación'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'Tacto rectal\npróstata\nadenomatosa\ngrado II-III/IV'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'ENFERMEDAD\nhemoglobina de 8,1 gr/dl\nplaquetas 51000\nleucocitos 9100'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'Coagulación\nelevación del fibrinógeno\n1500 (límites de la normalidad inferior a 400)'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'Lactato deshidrogenasa (LDH) elevada'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'ENFERMEDAD\ncongestión vascular'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'ENFERMEDAD\npróstata de 4,5 x 4 x 4,1 cm'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'Ecografía testicular\ntestículo izquierdo normal\ntestículo derecho\náreas heterogéneas con disminución de la ecogenicidad\npolo superior\npolo inferior\nepidídimo\nsin calcificaciones'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'absceso testicular\ntuberculosis testicular\nbrucelosis\ntumor testicular'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'ENFERMEDAD\ntumor testicular\ntumor testicular de 8 x 6 x 4 cm\nmasa blanquecina lobulada de 5,5 cm\ninfiltra albugínea y epidídimo\ninfiltra albugínea y epidídimo pero que no sobrepasa la capa externa ni el borde hiliar'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'ENFERMEDAD\nlinfoma difuso B de células grandes\ncélulas grandes\níndice de proliferación (minb1 > 80%)\nmarcadores CD 20+'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'linfoma testicular primario\nesplenomegalia\nadenopatías retroperitoneales\n1 cm'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'sudación profusa\nfiebre en picos\nastenia\nedemas de los miembros inferiores'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'anemia\n8,9 gr/dl de hemoglobina\nplaquetas\n37000\nfórmula leucocitaria y linfocitaria normales'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'síntomas B\nlinfoma testicular primario\nbiopsia de medula ósea\ncilindro de 3 x 0,3 cm\nmédula ósea hipercelular\ncambios regenerativos y displásicos\nserie granulocítica'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'plasmocitosis intersticial\ninfiltración por células linfoblásticas'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'anemia\ntrombocitopenia'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'agregación plaquetaria\ntest de Coombs directo\ninmunoglobulina G\npositivo a inmunoglobulina G'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'disfonía\ndisfagia\nlesión polipoidea en seno piriforme\nfibroscopia'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'ENFERMEDAD\nTAC cervical normal'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab\nCHOP (ciclofosfamida, doxorrubicina, vincristina, prednisona)\nfiebre\nintensa mejoría de los síntomas B\ndesaparición de la fiebre'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'ENFERMEDAD\nquimioterapia\nR-CHOP\n6 ciclos'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'radioterapia genital\nquimioprofilaxis cerebral'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: 'enfermedad\nenfermedad'
# [22/250] es-S0210-48062004000200011-1.txt | 109.03s | 29 chunks | 92 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: 'tracto urinario inferior\ninicio de aumento de frecuencia miccional nocturna\ndisuria\ndisminución del calibre miccional'
#   [chunk 2/12 | chars 224-442]
# ...
#   RAW: 'dolor a la palpación en tercio medio de la región inguinal derecha\ndolor a la flexión\ndolor a la aducción\ndolor a las rotaciones sobre todo interna\nmaniobra de choque positiva'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'flexión 110o bilateral\nrotación interna de 10o derecha\nrotación interna de 40o izquierda\nrotación externa de 30o derecha\nrotación externa de 40o izquierda\nenfermedad de caderas'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'Enfermedad:\n- balance muscular en la escala de Daniels es de 5/5 global bilateral'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'Enfermedad\nneoplasia\ncáncer\ntumor\ncarcinoma\nneurofibroma\nmeningioma\nleucemia\nsarcoidosis\nencefalitis\nencefalitis viral\nencefalitis bacteriana\nencefalitis fungica\nencefalitis parásitica\nencefalitis vasculitis\nencefalitis demielinizante\nencefalitis degenerativa\nencefalitis degenerativa progresiva\nencefalitis degenerativa crónica\nencefalitis degenerativa subaguda\nencefalitis degenerativa aguda\nencefalitis degenerativa fulminante\nencefalitis degenerativa infantil\nencefalitis degenerativa juvenil\nencefalitis degenerativa adolescente\nencefalitis degenerativa adulta\nencefalitis degenerativa en ancianos\nencefalitis degenerativa en niños\nencefalitis degenerativa en adolescentes\nencefalitis degenerativa en adultos\nencefalitis degenerativa en ancianos\nencefalitis degenerativa en niños\nencefalitis degenerativa en adolescentes\nencefalitis degenerativa en adultos\nencefalitis degenerativa en ancianos\nencefalitis degenerativa en niños\nencef'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'ENFERMEDAD\ncintilla iliotibial\ntest de Ober negativo'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'ausencia de claudicación\napoyo monopodal alterno derecho-izquierdo es estable\nTrendelenburg negativo'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'ENFERMEDAD\ndolor para la marcha\nflexión forzada de cadera\nrodilla'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'deformidad en forma de joroba\nen región cérvico-cefálica femoral derecha\nenfermedad'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'enfermedad\nnormal\nhemograma\nbioquímica\nhormonas tiroideas\nanticuerpos\nreactantes de fase aguda'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'ENFERMEDAD\nleve alteración subcondral\nedema óseo en cadera derecha\nirregularidad cortical\nleve sinovitis en interlínea articular\ndistensión de la bursa ilio-psoas'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'islote óseo\nángulo alfa mayor de 50o'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'pinzamiento de la interlinea articular antero-superior y posteroinferior\ncollar osteofitario femoral\nlesiones subcondrales antero-superiores de cabeza femoral\nedema en acetábulo anterosuperior'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'necrosis avascular\nlesiones en el labrum'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'lesión quística\nyuxtaarticular\ntrocánter mayor'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'síndrome de pinzamiento femoroacetabular tipo LEVA\nCAM\nmagnetoterapia\ntratamiento\ndolor\ntrofismo óseo'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'ENFERMEDAD\nsulfato de glucosamina-condroitin sulfato oral 400 mg cada 12 horas durante 3 meses\nantiinflamatorios no esteroideos a demanda si presenta dolor'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'reposo deportivo\nchoque en la articulación\nactividad física activa controlada\nflexión de la cadera\nrotaciones'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'artroscopia\ntraumatología\ncirugía artroscópica'
# [245/250] es-S1888-75462015000400006-1.txt | 103.40s | 22 chunks | 66 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'fractura de tercio medio de clavícula derecha\nfractura de arcos costales derechos\nciclista veterano de carretera\nvarón de 53 años de edad\nsin antecedentes médico-quirúrgicos de interés\nhábitos tóxicos\nreacción alérgica conocida a medicamentos'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'ENFERMEDAD\ndolor a nivel de clavícula y pared costal derechas'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'fractura de arcos costales derechos cuarto y quinto\nfractura de tercio medio de la clavícula derecha con tercer fragmento\nhemotórax\nneumotórax'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'ENFERMEDAD\nedematización del miembro superior derecho\n\nTexto vacío si no hay nada más en el texto.'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'CHCM=31.4g/dl\nneutrófilos=76.6%\nlinfocitos=16.4%\neosinófilos=0.9%\nfibrinógeno=645mg/dl\nGGT=52U/l\nD-Dímero positivo'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'trombosis venosa de las venas axilar\ntrombosis venosa de la vena cefálica\ntrombosis venosa de la vena basílica\ncompresión del nervio cutáneo braquial medial a nivel del hiato basílico'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'fractura de clavícula\ntratamiento con Tinzapaina sódica\nradiografías y utrasonografía-Doppler seriadas de control hasta la consolidación de la fractura de clavícula y la recanalización completa de las venas trombosadas'
# [246/250] es-S1888-75462016000400180-1.txt | 37.38s | 7 chunks | 24 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'ENFERMEDAD\npaciente de 58 años'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomía\nmetrorragias\nmiomas'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'osteoporosis densitométrica lumbar\nT-score en L1-L4 de -3\nhábitos tóxicos\nantecedentes personales ni familiares de fractura\nIMC normal'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'dolor mecánico en el pie izquierdo\ndolor mecánico\ndolor\npie izquierdo\ninflamación\ncausa desencadenante\nAINEs'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'dolor a la movilización del antepié izquierdo\nenfermedad'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'ENFERMEDAD\nalteraciones de la estática de pies'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'enfermedad\npies\nRx de pies\nenfermedad patológicos\nno mostraba hallazgos patológicos'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'fractura de estrés\nfractura de estrés en el 2o MTT\ncallo perióstico\nedema de tejidos blandos'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'ENFERMEDAD\nincremento de niveles de PTH y vitamina D\nexceso de suplementación de vitamina D\nPTH\nvitamina D\n103,7 pg/ml\n272 ng/ml\nnormales\nfunción renal\ncalcio sérico y urinario'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'Se suspendió el tratamiento con suplementos de vitamina D y denosumab.'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'ENFERMEDAD\ntratamiento conservador\ndescarga\nreposo relativo\nAINEs\nmagnetoterapia\nmejoría progresiva'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'osteoporosis\nSERMS (bazedoxifeno)\nsuplementos de calcio con vitamina D\nosteoporosis\nosteoporosis\ndolor en el pie izquierdo\ndolor en el pie izquierdo'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'callo de fractura antigua\nfractura de estrés previa\nRx\nhallazgos'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'ENFERMEDAD\nedema de 1er y 3er MTT\nedema de huesos cuneiforme\nedema de escafoides\nedema de astrágalo\ntenosinovitis del tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'ENFERMEDAD\nosteoporosis'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'enfermedad\nbazedoxifeno\nvitamina D\ncifras de densidad mineral ósea\nempeorado'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'fracturas\nrehabilitación\ndescarga\nmejoría progresiva'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'osteoporosis'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'enfermedad\ndolor\ncoincidiendo con cambio de estación\ncambio de estación\ndiferencia de un año'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'fracturas de estrés'
# [247/250] es-S1889-836X2015000200005-2.txt | 71.07s | 20 chunks | 61 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'VIH\ninfección por VIH\ntratamiento con didanosina\ntratamiento con tenofovir\ntratamiento con lopinavir/ritonavir'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'enfermedad\nasenia\ndolores óseos difusos'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'fosfatasa alcalina (FA)\nfosfatasa alcalina (FA) total\nfosfatasa alcalina (FA) ósea\nparatohormona (PTH)'
#   [chunk 4/16 | chars 408-569]
#   RAW: 'ENFERMEDAD\n25-hidroxivitamina D (25-HCC)\ncalcio total e iónico\nparámetros bioquímicos rutinarios en suero\nelemental y sedimento de orina\nnormal'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'degenerativos\nenfermedad degenerativa\nnormal (gammagrafía con Tc99)'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'enfermedad\nasenia\ndisminución de fuerza\ndificultad para caminar\npérdida de peso\npeso'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'ENFERMEDAD\ndebilidad muscular de predominio proximal'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperglucemia leve\nglucosuria marcada\nhipofosfatemia\nfosfaturia inapropiadamente alta\nhipouricemia\nacidosis metabólica\nproteinuria'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'aminoaciduria moderada\nglicina\nvalina\nserina\ntreonina'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'El paciente presenta una enfermedad de tipo FGF23.'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Enfermedad\nNo se encontraron enfermedades en el texto.'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'síndrome de Fanconi incompleto\nhipofosfatemia grave\nprobable osteomalacia\nTDF'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'raltegravir\ndarunavir\nritonavir'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: '25-HCC\n1,25-dihidroxivitamina D (1,25 DHCC)\nfósforo'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'mejorando progresivamente'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'ENFERMEDAD\nbaja reabsorción de fosfato'
# [248/250] es-S1889-836X2015000400006-1.txt | 55.16s | 16 chunks | 40 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'enfermedad\nlupus cutáneo\neritema malar\nreumatología'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Tiroiditis de Hashimoto'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'Apendicectomía'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'exfumadora\nenfermedad\n7 años'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'No bebedora.'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'ENFERMEDAD\ntomas de bebidas con quinina (tónicas)'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'anemia\nanemia\nanemia'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'Cesárea\nligadura de trompas\nen el 3o.'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'Enfermedad actual:\nintensa astenia\npresíncopes\nanorexia\ndeambulación dificultada'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'Menstruación muy duradera\nMenstruación abundante'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'No heces melénicas\npalidez cutánea\npalidez mucosa'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'Epistaxis\ngingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'anemia\ntrombopenia\nplaquetas de 6.000/ mm3'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'ENFERMEDAD\nneoplasia\nhemolisis\nesquistocitos'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'PTT\nLES'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'hematíes\nplaquetas'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'afasia global\ndesviación de la comisura bucal a la izquierda\nninguna otra focalidad neurológica'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'Enfermedad:\nnormal\nfocalidad evidente'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'enfermedad neurológica\nhematología\nestudio'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'microangiopatía trombótica\ncrisis convulsivas\nplasmaféresis'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'empeoramiento clínico\npaciente\nUCI'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'plasmaféresis\nvolumen de recambio\n1-1,5 veces el volumen plasmático'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: "El tratamiento se prolongará hasta 48 h. después de conseguir la respuesta.\n\nREGLAS DE EXTRACCION:\n1. Extrae exclusivamente entidades de tipo ENFERMEDAD.\n2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'respuesta', no escribas 'respuesta al tratamiento'.\n4. REPETICIONES: Si una enfermedad aparece varias veces en el texto, debes listarla varias veces en lineas separadas.\n5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio (como '-', '*', '•', '1.').\n7. Si no hay nada, devuelve un texto vacio.\n\nTexto extraído:\nEl tratamiento se prolongará hasta 48 h. después de conseguir la respuesta."
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'ENFERMEDAD\nobesidad'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'ENFERMEDAD\nhipernefroma\ncarcinoma de células renales del tipo de células claras\nmetástasis'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'ENFERMEDAD\nvolumen a reinfundir\n1.750 cc.'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'ENFERMEDAD\nplasma fresco'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'albúmina humana al 20%'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'ENFERMEDAD:\nsolución Dianeal® 1,36% de diálisis peritoneal.'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'plasmaféresis\nsesiones\ncatéter en yugular derecha\ncatéter doble luz\ncatéter en femoral izquierda\nsangrado'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE (Hospal®)'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'heparina\nenfermedad'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'ENFERMEDAD\nhipertensión arterial\nhipotensión arterial\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia\nneoplasia'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'ENFERMEDAD\nmal estado general\nsedada\n(sin más información)'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: 'Se le realizaron un total de 17 sesiones.'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'enfermedad\nIncidencia de las mismas:\nLa 1a sesión la pasó muy agitada.'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'hipotensión\nconvulsiones importantes\ndiazepam\nsalino fisiológico'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'PTM\naumento de PTM\nPTM hasta 55 mm Hg\nfaltando 50 minutos\nsesión'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'Enfermedad: fallo del test de aire'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'El resto de las sesiones se realizaron sin problemas\n\nEnfermedad: Ninguna enfermedad mencionada en el texto'
# [249/250] es-S2254-28842014000200009-1.txt | 146.73s | 40 chunks | 73 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'carcinoma seroso papilar\ncarcinoma seroso papilar en ovario izquierdo\ncarcinoma seroso papilar\nganglio de la cadena aorto-cava\nestadio IIIC'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'enfermedad\nneoplasia\ncarcinoma de células renales\nquimioterapia adyuvante\ncarboplatino\npaclitaxel\njunio de 2011'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'ENFERMEDAD\nCA 125\nelevación de CA 125\n88.4 U/ml\n0-35 U/ml'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'enfermedad metastásica\nenfermedad hepática'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'ENFERMEDAD\nneoplasia\ncáncer ovario\nneoplasia\ncáncer ovario\nCA 125\nneoplasia\ncáncer ovario'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'ENFERMEDAD\ndisnea\nvómitos\npérdida de conocimiento\nTAS/TAD de 70/50 mmHg'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'infusión\ncorticoides\nremitir'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'enfermedad\ndesensibilización\nenlentecimiento de la velocidad de infusión'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'ENFERMEDAD\ndisnea\nsudoración\ntensiones de 85/60 mmHg\nsal de platino'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'Enfermedad:\n3a línea de quimioterapia con trabectedina y adriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'enfermedad\nenfermedad\nenfermedad'
# [250/250] es-S2340-98942015000100005-1.txt | 40.98s | 11 chunks | 28 menciones
#
# Predicciones guardadas en distemist_llm_predictions.tsv
# Tiempo medio por archivo: 60.36s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd


def prf(tp, fp, fn):
    p  = tp / (tp + fp) if (tp + fp) else 0.0
    r  = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1


df_pred  = pd.read_csv(PREDICTIONS_TSV, sep="\t")
df_gs    = pd.read_csv(GS_TEST_TSV, sep="\t")
df_gs    = df_gs[df_gs["filename"].isin(df_pred["filename"].unique())]

set_gs   = set(zip(df_gs["filename"],   df_gs["label"],   df_gs["off0"],   df_gs["off1"]))
set_pred = set(zip(df_pred["filename"], df_pred["label"], df_pred["off0"], df_pred["off1"]))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1   = prf(tp, fp, fn)

report = {"Estricta": {"tp": tp, "fp": fp, "fn": fn, "precision": round(p, 4), "recall": round(r, 4), "fscore": round(f1, 4)}}

print(f"── ESTRICTA ──  P={p:.4f}  R={r:.4f}  F1={f1:.4f}  (TP={tp} FP={fp} FN={fn})\n")

thresholds = [0.0, 0.5, 0.8]
results    = {t: {"tp": 0, "fp": 0, "fn": 0} for t in thresholds}

for filename in df_pred["filename"].unique():
    gs_ints   = list(zip(df_gs[df_gs["filename"] == filename]["off0"],   df_gs[df_gs["filename"] == filename]["off1"]))
    pred_ints = list(zip(df_pred[df_pred["filename"] == filename]["off0"], df_pred[df_pred["filename"] == filename]["off1"]))

    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )

    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi); matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ──  P=0.1342  R=0.5747  F1=0.2175  (TP=1493 FP=9635 FN=1105)
#
# ── IoU ──
# IoU >= 0.0:  P=0.2039  R=0.8734  F1=0.3306  (TP=2269 FP=8859 FN=329)
# IoU >= 0.5:  P=0.1703  R=0.7294  F1=0.2761  (TP=1895 FP=9233 FN=703)
# IoU >= 0.8:  P=0.1390  R=0.5955  F1=0.2254  (TP=1547 FP=9581 FN=1051)
