# %% [markdown]
# # Pipeline Five-Shot NER — DisTemIST con Qwen3-8B
#
# Inferencia five-shot para reconocimiento de enfermedades en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "unsloth/Qwen3-8B-unsloth-bnb-4bit"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo ENFERMEDAD.\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'neoplasia', no escribas 'cancer'.\n"
    "4. REPETICIONES: Si una enfermedad aparece varias veces en el texto, debes listarla varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio (como '-', '*', '•', '1.').\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
DISTEMIST_ROOT       = f"{PROJECT_ROOT}/distemist/distemist"
TEXT_FILES_TEST_DIR  = f"{DISTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{DISTEMIST_ROOT}/distemist_subtrack1_test_mentions.tsv"
PREDICTIONS_TSV      = "distemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : unsloth/Qwen3-8B-unsloth-bnb-4bit
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# ==((====))==  Unsloth 2026.6.6: Fast Qwen3 patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/399 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/707 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# unsloth/Qwen3-8B-unsloth-bnb-4bit does not have a padding token! Will use pad_token = <|PAD_TOKEN|>.
#
# Modelo cargado: unsloth/Qwen3-8B-unsloth-bnb-4bit
# Parámetros totales: 5,191,808,000

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=True,
)

EXAMPLES = [
    {
        "text": "Con el diagnóstico de hipernefroma se realizó nefrectomía. La anatomía patológica fue de carcinoma de células renales del tipo de células claras de 8 cm de diámetro con invasión tumoral del uréter y de la vena renal. Tres meses después de la cirugía, la radiografía mostraba múltiples imágenes nodulares compatibles con metástasis.",
        "mentions": "hipernefroma\ncarcinoma de células renales del tipo de células claras de 8 cm de diámetro con invasión tumoral del uréter y de la vena renal\nmetástasis",
    },
    {
        "text": "Había sido fumador de 10 cigarrillos/día. No era consumidor de bebidas alcohólicas, no tenía hábitos tóxicos ni tomaba regularmente ningún medicamento. No refería antecedentes de muerte súbita ni de síncopes. Tras realizar un test de flecainida, se realizó un diagnóstico de SB.",
        "mentions": "fumador\nconsumidor de bebidas alcohólicas\nhábitos tóxicos\nmuerte súbita\nsíncopes\nSB",
    },
    {
        "text": "El paciente presenta fístula urinaria con abundante salida de orina e infección de herida quirúrgica. Tras la estabilización, se observa desaparición de fístula urinaria y necrosis grasa. Con el diagnóstico de fístula vésico-rectal se indica sondaje vesical hasta resolución de infección de herida quirúrgica.",
        "mentions": "fístula urinaria\ninfección de herida quirúrgica\nfístula urinaria\nnecrosis grasa\nfístula vésico-rectal\ninfección de herida quirúrgica",
    },
    {
        "text": "La tomografía reveló agenesia de cuerpo calloso aunada a un lipoma con bordes irregulares; espina bífida oculta a nivel de columna cervical y fisura central a nivel de la arcada del maxilar superior. Neurológicamente, a pesar de presentar agenesia del cuerpo calloso, se mantiene alerta y sin crisis convulsivas.",
        "mentions": "agenesia de cuerpo calloso\nlipoma\nespina bífida oculta a nivel de columna cervical\nfisura central a nivel de la arcada del maxilar superior\nagenesia del cuerpo calloso\ncrisis convulsivas",
    },
    {
        "text": "El paciente se lesionó ambos ojos concentrando los rayos solares con ayuda de una lupa buscando un fin estético. Asimismo se autoinduce unas quemaduras de segundo y tercer grado en la piel de la cara y los brazos para hacer desaparecer unos supuestos quistes.",
        "mentions": "se lesionó ambos ojos concentrando los rayos solares con ayuda de una lupa\nse autoinduce unas quemaduras\nquemaduras de segundo y tercer grado en la piel de la cara y los brazos\nquistes",
    },
]

def build_ner_messages(text):
    messages = [{"role": "system", "content": SYSTEM_PROMPT}]
    for ex in EXAMPLES:
        messages.append({"role": "user",      "content": f"Texto para analizar:\n{ex['text']}"})
        messages.append({"role": "assistant", "content": ex["mentions"]})
    messages.append({"role": "user", "content": f"Texto para analizar:\n{text}"})
    return messages

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
            enable_thinking=False,
        )
        try:
            full_output = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        marker = "<|im_start|>assistant"
        idx    = full_output.rfind(marker)
        result = full_output[idx + len(marker):].strip() if idx != -1 else full_output.strip()
        result = re.sub(r"<think>.*?</think>", "", result, flags=re.DOTALL).strip()
        result = re.sub(r"<think>.*",          "", result, flags=re.DOTALL).strip()

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename": txt_path.stem,
            "mark":     f"T{mark_idx}",
            "label":    "ENFERMEDAD",
            "off0":     off0,
            "off1":     off1,
            "span":     span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "mark", "label", "off0", "off1", "span"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer Qwen2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'diabetes\nhipertensa'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'dolor lumbar derecho'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'exploración física'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'masa suprarrenal derecha hipoecogénica de 80 mms'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'proceso expansivo en la suprarrenal derecha'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'masa tumoral\ntumor suprarrenal'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'estudio hormonal para la determinación de cortisol'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'cirugía'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'tumor localizado en la glándula suprarrenal derecha'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'adrenalectomía derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'evolución post operatoria'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'peso de 171,4 g\ndimensiones de 9 x 8 x 6 cms\náreas amarillas - naranjas\nhemorragias\ntejido adiposo\ncalcificaciones'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'mielolipoma de la glándula adrenal'
# [1/250] S0004-06142006000100010-1.txt | 28.68s | 13 chunks | 20 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'adenocarcinoma gástrico\nhipertensión arterial\nespironolactona'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'anorexia\npérdida de 12 kilos en 6 meses\nanemia hipocrómica\nestreñimiento'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'tumoración'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'adenocarcinoma gástrico\nascitis por carcinomatosis\nobstrucción intestinal tumoral\ntumoración abdominal'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'hemoglobina\nhematies\nhematocrito\nVCM\nRDW\nVSG\nPCR\nPSA\ncreatinina\nurea'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'marcadores tumorales hepáticos y digestivos'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'pólipo inflamatorio en muñón gástrico\nrecidiva tumoral'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'colonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'tumoración quística'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'riñón izquierdo'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'lesión quística voluminosa intraabdominal'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'gran masa quística'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'imagen cálcica en teórica zona de pelvis renal\nhidronefrótico\ncompresión\ndesplazamiento de todas las estructuras abdominales'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'hidronefrosis gigante\nuropatía obstructiva litiásica\ndrenaje percutáneo\nnefrectomía'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'nefrectomía simple derecha\ncontenido serohemático'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'linfadenectomía hiliar ampliada'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'tumoración urotelial'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'riñón de aspecto multiquístico\nmarcada dilatación del sistema pielocalicial\natrofia parenquimatosa severa'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'displasia'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'nidos sólidos de células de citoplasma amplio, claro y de alto grado nuclear (grado 3 de Fuhrman)  \ninfiltración ganglionar de carcinoma de células renales tipo célula clara'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'metástasis hepáticas'
# [2/250] S0004-06142006000100014-1.txt | 52.49s | 21 chunks | 49 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'dolor a nivel de hipogastrio\neyaculación dolorosa\nhemospermia\nsensación de peso a nivel testicular\nvaricocele derecho'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'varicocele derecho'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'próstata irregular\npróstata aumentada de tamaño\nzonas induradas\ndolor a la exploración'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'imagen nodular hipoecoica en teste derecho con hipervascularización circundante\nquiste simple en testículo izquierdo'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'metástasis\nhemangiomas'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'hemangiomas'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'alteraciones'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'PSA'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'Alfa-feto-proteína\nbeta-HCG\nPSA'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'formación nodular\npulpa testicular'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'tumor de células de Leydig difuso'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'metástasis'
# [3/250] S0004-06142006000500002-2.txt | 32.03s | 14 chunks | 24 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'neoplasia de testículo\ncriptorquidia bilateral\norquidopexia'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'cólicos nefríticos  \nlitiasis  \nLEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Ureterolitectomía'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'fumador'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'esterilidad\nnódulo en testículo izquierdo'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'azoospermia total'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'testículo derecho con masa de 19 x 23 mm en polo superior con flujo aumentado\ntumor testicular\nquiste de cordón izquierdo'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'quiste de epidídimo'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'testículo derecho'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: ''
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'metástasis'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'alfa-fetoproteina\nbeta-HCG'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'orquiectomía radical inguinal derecha\nbiopsia del testículo izquierdo vía inguinal'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'testículo derecho'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'infiltración de túnica vaginalis'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'nódulo sólido bien delimitado de 1,5 cm de diámetro de coloración parda con área amarillenta central'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'tejido testicular restante'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'cordón espermático'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Tumor de células de Leydig'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'atrofia  \nhiperplasia de células de Leydig  \nausencia de espermiogénesis'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'Bordes quirúrgicos libres'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'atrofia testicular\nausencia de espermiogénesis\nhiperplasia de células de Leydig intersticial'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'metástasis'
# [4/250] S0004-06142006000500002-3.txt | 55.49s | 25 chunks | 37 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'masa renal derecha'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'masa sólida y heterogénea'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'nefrectomía radical derecha'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'carcinoma renal de células claras de 8,4 centímetros'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'cirugía'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'neoplasia\ndolor en hipocondrio derecho'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'masa dolorosa en el hipocondrio derecho\nrecidiva tumoral\nlecho quirúrgico\ninfiltraba pilar diafragmático derecho posterior\nhígado\nimplantes peritoneales\nmayor\ncuatro centímetros adyacente al hilio hepático'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'masas tumorales\ncarcinoma de células claras de alto grado'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'masa retroperitoneal paravertebral'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Interferón (Intrón A)'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'molestias abdominales inespecíficas\nanalgésicos suaves\nTAC de abdomen\nmetástasis\nrecidiva del lecho quirúrgico\nimplantes peritoneales'
# [5/250] S0004-06142006000900015-1.txt | 29.93s | 11 chunks | 25 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'Paciente varón de 29 años.'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'tumoración indolora\nneoplasia'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'sintomatología urológica\nastenia\npérdida de peso'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'antecedentes personales'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'teste izquierdo hipotrófico\nteste derecho algo aumentado de tamaño'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'dolorosos'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'epidídimos\ncordones'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'hemostasia\nbioquímica\nhemograma\nalfa-feto proteína\nbeta-hCG'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'testículo'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'lesión focal ligeramente hipoecoica'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'microlitiasis testiculares bilaterales'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de tórax\nTAC toraco-abdomino-pélvico con contraste'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'tumor testicular bilateral'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'testículo izquierdo atrófico\nseminoma clásico\nneoplasia intratubular de células germinales\nNICG'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'tumoración con características de seminoma clásico\nneoplasia intratubular de células germinales\natrofia'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'tumor'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'quimioterapia\ncarboplatino'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'enfermedad'
# [6/250] S0004-06142007000200017-1.txt | 41.80s | 18 chunks | 34 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'YSS'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'aumento progresivo de los órganos genitales externos\ntrasudación de la linfa\nimpotencia sexual'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'Edema marcado del pene y escroto con eritema y dolor'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'adenopatías inguinales no dolorosas'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'Hemograma completo'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'Serología'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Prueba de Mantoux\nProteinas totales y fraccionadas\nRX de cadera'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'psoas derecho engrosado de 48 mm\nnecrosis aséptica de la cabeza del fémur\nhipertrofia del psoas'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'Exploración retroperitoneal derecha'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'Adenectomía de ilíaca derecha y cava'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'linfangioplastia con aguja'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'Fasciotomía de la raíz del pene'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'quiluria  \nedema de los miembros inferiores  \nvaricocele  \nhidrocele'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'linfedema de pene y escroto\nlinfedema primario inflamatorio local de pene y escroto'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'Necosis aséptica de la cabeza del fémur'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'urólogos\nangiológos\ncirujanos plásticos'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'afección'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'piel y dermis\ndartos\ntúnica muscular de fibras lisas (músculo peripeneal de Sappey)\nconductos venosos subyacentes\nerección\nvasos linfáticos dilatados\nvenas\narterias\nnervios superficiales\nbloque\nfascia penis\nórganos eréctiles\nesponjosos\ncavernosos\nuretra\narteria peneana'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'escroto\ndartos muscular\ncelulosa\nfascia de Cooper\nsegunda túnica muscular llamada eritroide\nbloque\ncapa vaginal\npaquete vasculo nervioso\nepidídimo'
# [7/250] S0004-06142007000600012-1.txt | 56.80s | 20 chunks | 55 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'nódulo testicular'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'nódulo duro\nnódulo móvil\nnódulo doloroso a la palpación\ncordón espermático derecho'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'marcadores tumorales\nhormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'imagen ovalada, hipoecoica, de ecogenicidad mixta'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'tejido con bajo contenido en agua, posiblemente fibroso o cicatricial'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'tumoración paratesticular derecha'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'incidentes\nasintomático'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'formación redondeada de coloración pardusca y consistencia elástica'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'células con amplio citoplasma eosinófilo con presencia de estriaciones transversales  \nestroma fibroblástico  \ncélulas de aspecto vacuolado  \ncélulas multinucleadas'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'células neoplásicas'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'Granada'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: ''
# [8/250] S0004-06142007000600014-1.txt | 28.86s | 12 chunks | 17 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'herida de arma de fuego'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'herida de bala'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'consciencia\norientación\ndefensa abdominal'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'bala\nfractura de la rama descendente derecha'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'retención'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'laparotomía\nlesión\ncolostomía izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'uretrografía\nfiebre alta\nescalofríos'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'perforación rectal'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'uretra prostática'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'vejiga'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'laparotomía\nsínfisis del pubis\nabdomen'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'hiperplásica'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'bala'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'postoperatorio'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'asintomático\norificio rectal\ncolostomía'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'sonda'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'brecha'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'función sexual normal'
# [9/250] es-S0004-06142007000900010-1.txt | 34.81s | 18 chunks | 27 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'apendicectomía\nhernia discal\nhiato\nfractura de tibia y peroné\ncólico nefrítico derecho'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'neoformación sólida'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'masa a nivel cortical de riñón derecho'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'hipernefroma'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'neoformación cortical'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'neoformación'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'vimentina\ncitoqueratina 7\ncitoqueratina de amplio espectro\nCD34\ncromogranina\nEMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'Granada'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: ''
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'vimentina\ncitoqueraina 7\nEMA\nCD34'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'La paciente cursa tras la intervención sin incidentes destacables y se encuentra asintomática a los 24 meses de la intervención.'
# [10/250] es-S0004-06142007000900012-1.txt | 25.72s | 11 chunks | 22 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK  \nsinusitis bilateral  \nbronquiectasias  \ndesprendimiento retina de ojo derecho  \naumento del tamaño testicular  \ninduración'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'dolor lumbar\nirradia a testículo izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'neoplasia'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'adenopatías'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'tumor testicular tipo seminoma\nganglios locorregionales'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'situs inversus\nbronquiectasias'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'LDH'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'a-fetoproteína\nb-HCG\norquiectomía inguinal\nraquianestesia\nprótesis testicular'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'seminoma clásico de 2.5 cms de diámetro'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'invasión vascular'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Neoplasia germinal intratubular'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'Fibrosis e hialinización tubular de testículo no tumoral'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'seminoma grado I'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'orquiectomía\nazooospermia\nazooospermia'
# [11/250] es-S0004-06142008000300011-1.txt | 32.81s | 14 chunks | 27 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'dolor abdominal difuso\nepigastrio\nnáuseas\nvómitos biliosos\nmal estado general'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'dolor'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'fiebre\nsensación distérmica'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'coluria'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'dolor'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'Palidez mucocutánea'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'afebril\nnormotensa'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Auscultación cardiopulmonar sin hallazgos'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'dolor abdominal generalizado\ndolor abdominal generalizado a la palpación\ndolor abdominal generalizado más intenso en epigastrio\ndolor abdominal generalizado a la palpación más intenso en epigastrio'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'circulación colateral'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'edemas'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'TVP'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'aumento de transaminasas'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'hemoglobina'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'INR'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'trombo con densidad grasa'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'venas suprahepáticas libres'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'VCI'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'anormalidad inespecífica de cabeza de páncreas'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'epigastralgia'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Lipoma'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'colecistitis\npancreatitis'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'líquido libre en pelvis\nespacios perihepático\nperiesplénico\nperirrenal derecho'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'patología bilio-pancreática'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'Síndrome de Budd-Chiari\nderrame pleural bilateral\nengrosamiento de pliegues gástricos\naumento de la captación de contraste\nangiomiolipoma (AML)'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'lipoma renal  \nVCI  \nostium de la aurícula derecha'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'congestión hepática\nhepatomegalia\naumento de calibre de vena porta\nsuprahepáticas\nedema periportal\nbazo\npáncreas atigrado\nlíquido libre'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'presunción de síndrome de Budd-Chiari secundario a trombo en cava\nproceso peritoneal infeccioso/ tumoral\nsíndrome'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'trasudado'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'función ventricular'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Síndrome de Budd-Chiari\ntrombo en cava'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'Lipoma\nmal estado general'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'INTERVENCIÓN QUIRÚRGICA'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'trombo'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'incisión tipo Chevron\nretroperitoneo\nasa fija\nhiato de Winslow\npaquete intestinal\nvena mesentérica inferior'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'ligamentos redondo\nligamentos coronario\nligamentos triangulares derecho\nligamentos triangulares izquierdo\nligamento falciforme'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'vena cava  \nvena renal derecha  \ntrombo tumoral'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'hiato diafragmático\ntrombo'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'clampaje de pedículo hepático (maniobra de Pringle)  \nVCI proximal  \nVCI distal  \nVRD  \ncavotomía  \napertura VRI  \ntrombo  \nnefrectomía izquierda'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'angiomiolipoma de predominio lipomatoso del seno renal\ninfiltración vascular'
# [12/250] es-S0004-06142008000300012-1.txt | 97.55s | 40 chunks | 83 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'cólico nefrítico derecho\nhematuria'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'artrosis\nlumbalgia'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'litiasis en el grupo calicial medio del riñón derecho\nquiste renal gigante'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'quiste renal simple (Bosniak I)  \nlitiasis ipsilateral'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Hemograma dentro de la normalidad.'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'quiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'Se le informó de las distintas posibilidades.'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'quiste'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'cistitis\nfiebre elevada\ndolor lumbar derecho'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'tratamiento antibiótico'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'quiste'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: '6,4 centímetros'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'calcificación'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'quiste'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'microhematuria\nleucocituria'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'cólico derecho\ncistitis'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'litiasis'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'infección urinaria por E.Coli'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'infección\nlitiasis'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'asintomática'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'quiste'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Bosniak IIF'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'lesión'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'comunicación con la vía urinaria'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'asintomática'
# [13/250] es-S0004-06142008000300013-1.txt | 49.96s | 26 chunks | 34 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'prostatectomía radical  \nlinfadenectomía obturatriz  \ncarcinoma de próstata medianamente diferenciado  \nsuma Gleason 5  \nafectación microscópica limitada de los márgenes de resección'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'aumento de volumen testicular derecho  \nmasa con áreas irregulares  \ndisminución de flujo vascular'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'TAC abdominal'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'adenopatías retroperitoneales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'linfoma testicular difuso de célula grande tipo B'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'recidiva precoz  \nrecidiva  \nfalleciendo'
# [14/250] es-S0004-06142008000400011-2.txt | 16.89s | 6 chunks | 14 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'hipertensión arterial'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'metrorragias\ndolor abdominal'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'hematuria\ndolor en fosas renales'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'masa anexial izquierda de 7 cm de diámetro mayor y muy vascularizada\nútero grande'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'carcinoma ovárico primario\nTC abdómino-pélvico\nmasa compleja en polo inferior de riñón derecho\nintensa captación de contraste\náreas hipodensas centrales'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'nódulos'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'lesión sólido-quística'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'adenopatías regionales\nimplantes metastásicos peritoneales'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'carcinoma ovárico primario\nmetástasis renal secundaria\nhisterectomía total\ndoble anexectomía\nnefrectomía radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'metástasis de carcinoma de células renales en ovario'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'carcinoma de células renales grado I de Fuhrman\ngrasa perirrenal\nvena renal'
# [15/250] es-S0004-06142008000400013-1.txt | 29.92s | 11 chunks | 25 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'adenocarcinoma gástrico\ncarcinoma de próstata\ncarcinoma de próstata Gleason VII\nprostatectomía radical\nganglio linfático afectado por el tumor\nbloqueo androgénico\nPSA'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'lesión exofítica no dolorosa a nivel del glande'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'lesión'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'lesión redondeada exofítica de color rojizo oscuro de aproximadamente dos centímetros de diámetro'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'linfadenectomías\ntumoración\ntrombosado\nfriables'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'melanoma'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'penectomía subtotal  \nlinfadenectomía inguinal superficial bilateral  \nganglios no afectados por el tumor'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'enfermedad metastásica'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'penectomía'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'melanoma'
# [16/250] es-S0004-06142008000400016-1.txt | 25.74s | 10 chunks | 21 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'endometriosis ovárica\nhisterectomía abdominal\ndoble anexectomía\nendometriosis\nectasia renal'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'dolor y defensa a la palpación profunda de fosa lumbar derecha\ndolorimiento a la percusión y palpación de fosa lumbar izquierda\npatología retroperitoneal'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'riñón derecho'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'imagen lobulada de contenido líquido y con aparente extravasación de contraste\nuréter'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'urinoma\nligadura o sección del uréter derecho\nureterolisis\nexéresis del urinoma\nanastomosis termino-terminal del uréter\nrefrescamiento de los bordes\nliberación de ambos extremos'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'catéter doble J\nuréter'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'evolución favorable'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'función renal\nvía urinaria'
# [17/250] es-S0004-06142008000500009-1.txt | 24.40s | 8 chunks | 22 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'Infecciones Urinarias (ITUs)'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'histerectomía vía vaginal por prolapso uterino  \nabsceso de cúpula vaginal  \nabsceso en cúpula vaginal  \nfiebre  \ndolor  \nabsceso de cúpula vaginal  \nECO  \nTC  \nabsceso en cúpula vaginal'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'DM'
#   [chunk 4/15 | chars 616-623]
#   RAW: 'HTA'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'alergias'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'hematuria'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'cólicos'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'infecciones de orina'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'G2 A0V2'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'clínica miccional\nITU\nlitiasis vesical'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'hallazgo'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'litiasis intravesical  \ncuerpo extraño intravesical'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'uretrocistoscopia\npelotón de gasas\ncalcificada\nTC pélvico'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'litiasis intravesical por cuerpo extraño\ncuerpo extraño\nhisterectomía\ncistoslitectomía\ncistogasomectomía\napertura vesical a cielo abierto\ncuerpo extraño'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'infecciones de orina de repetición'
# [18/250] es-S0004-06142008000700003-1.txt | 36.29s | 15 chunks | 33 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'EPOC moderado'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'fumador'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'factores ambientales de riesgo\nantecedentes familiares'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'uretrorragia\nimposibilidad para la micción'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'sondaje urinario'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'gran globo vesical\ndivertículo único de tamaño similar a vejiga\nvejiga\nneoplasia vesical'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'ureterotomía\ncistoscopia\ntumor sólido\nenfermedad residual'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'proliferación fibroblástica reactiva\ntumor fibroso solitario'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'cistectomía parcial\ndiverticulectomía\nleiomiosarcoma de bajo grado'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'pleomorfismo celular'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'necrosis intratumoral\nnecrosis celular'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'cambio mixoide'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'inflamación intra y peritumoral'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'infiltración de todo el espesor de la pared diverticular hasta el tejido adiposo peridiverticular provocando reacción fibrosa peritumoral'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'tumor'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'vimentina\nactina\ndesmina\nEMA\nCitoquerqatinas de Alto Peso Molecular'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'leiomiosarcoma de bajo grado'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'enfermedad a distancia'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'radioterapia locorregional\nquimioterapia complementaria'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'radioterapia locorregional'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'quimioterapia'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'cistoscopias\ncitología urinaria\nTAC toraco-abdomino-pélvico'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: 'enfermedad'
# [19/250] es-S0004-06142009000400011-1.txt | 53.71s | 23 chunks | 42 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'masa testicular\ndolor testicular'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'antecedentes patológicos'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'aumento difuso del tamaño del testículo derecho\nalteración difusa de la ecogenicidad del mismo'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'orquidectomia\ntestículo aumentado de tamaño\ncauchoso\nblanquecino'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'neoplasia maligna hematolinfoide'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'ACL  \nCD3  \nKi67  \nTdT  \nCD30  \nALK  \nbcl2  \nbcl6  \nCD10'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'Linfoma no Hodgkin T periférico no especificado'
# [20/250] es-S0004-06142010000100015-1.txt | 18.05s | 7 chunks | 19 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'enfermedad pulmonar obstructiva\nhipertensión arterial\nhipercolesterolemia'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'lesión quística compleja\nmultiseptada\ncontornos polilobulados\ncalcificaciones puntiformes periféricas\nriñón'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'lesión renal izquierda'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'adenopatías retroperitoneales'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'nefroma multilocular quístico\ncarcinoma de células renales quístico'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'renograma isotópico con Tc-99m\nlesión ocupante'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'Función del R.I.: 25%'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'lesión renal Bosniak III'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'Nefroma quístico multilocular'
# [21/250] es-S0210-48062003000900009-1.txt | 22.25s | 9 chunks | 17 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'dolor testicular derecho'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'síndrome constitucional'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'fiebre'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'palidez mucocutánea\ncrepitantes en la auscultación pulmonar\nedemas en miembros inferiores\nhematomas'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'edema de cubiertas\naumento de la consistencia del epidídimo\naumento de la consistencia del teste\ndesaparición del surco epidídimo testicular'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'adenomatosa'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'hemoglobina'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'fibrinógeno'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'Lactato deshidrogenosa (LDH) elevada\nBHCG\nCEA\nAFP'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'radiografía de tórax\nradiografía de abdomen'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'Ecografía renal y vesical sin alteraciones\npróstata'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'testículo derecho'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'absceso testicular  \ntuberculosis testicular  \nbrucelosis  \ntumor testicular'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'tumor testículo'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'linfoma difuso B de células grandes'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'linfoma testicular primario\nesplenomegalia\nadenopatías retroperitoneales'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'sudación profusa\nfiebre en picos\nastenia\nedemas de los miembros inferiores'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'anemia'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'síntomas B\nlinfoma testicular primario\nmedula ósea\nmédula ósea hipercelular\ncambios regenerativos\ndisplásicos\nserie granulocítica'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'plasmocitosis intersticial\ninfiltración por células linfoblásticas'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'frotis sanguíneo\nanemia\ntrombocitopenia'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'agregación plaquetaria\ntest de Coombs directo\ninmunoglobulina G'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'disfonía\ndisfagia\nlesión polipoidea en seno piriforme'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'TAC cervical'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab\nciclofosfamida\ndoxorrubicina\nvincristina\nprednisona\nfiebre'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'quimioterapia'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'radioterapia genital\nquimioprofilaxis cerebral'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: 'enfermedad'
# [22/250] es-S0210-48062004000200011-1.txt | 70.51s | 29 chunks | 66 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: 'aumento de frecuencia miccional nocturna\ndisuria\ndisminución del calibre miccional'
#   [chunk 2/12 | chars 224-442]
#   RAW: 'sintomatología prostática incipiente\nadenoma\nPSA\necografía abdominal'
#   [chunk 3/12 | chars 442-700]
#   RAW: 'intervención sobre el ojo izquierdo\ntraumatismo\nureterolitectomía del tercio superior del uréter\nlumbotomía'
#   [chunk 4/12 | chars 700-997]
#   RAW: 'masa parahiliar\nriñón izquierdo\nriñón derecho\npróstata\nPSA'
#   [chunk 5/12 | chars 997-1381]
#   RAW: 'tumoración renal\nparapiélica izquierda\nriñón'
#   [chunk 6/12 | chars 1381-1562]
#   RAW: 'masa renal'
#   [chunk 7/12 | chars 1562-1624]
#   RAW: 'lumbotomía izquierda'
#   [chunk 8/12 | chars 1624-1775]
#   RAW: 'masa comprimiendo riñón'
#   [chunk 9/12 | chars 1776-1889]
#   RAW: 'masa'
#   [chunk 10/12 | chars 1889-2050]
#   RAW: 'tumoración'
#   [chunk 11/12 | chars 2050-2234]
#   RAW: 'masa'
#   [chunk 12/12 | chars 2234-2418]
#   RAW: 'tumoración'
# [23/250] es-S0210-48062004000500009-1.txt | 27.51s | 12 chunks | 26 menciones
#   [chunk 1/11 | chars 0-130]
#   RAW: 'masa renal'
#   [chunk 2/11 | chars 130-212]
#   RAW: 'colelitiasis\nhidrocelectomía derecha'
#   [chunk 3/11 | chars 213-358]
#   RAW: 'dolor en fosas renales\nhematuria\ninfección urinaria\nastenia\nanorexia\npérdida de peso'
#   [chunk 4/11 | chars 359-424]
#   RAW: 'masas abdominales\nmegalias'
#   [chunk 5/11 | chars 424-618]
#   RAW: 'nódulo exofítico\náreas sólidas\nquistes\nzonas vascularizadas'
#   [chunk 6/11 | chars 619-824]
#   RAW: 'masa renal compleja\nlesión quística compleja a nivel renal'
#   [chunk 7/11 | chars 825-1174]
#   RAW: 'masa quística mínimamente complicada'
#   [chunk 8/11 | chars 1174-1373]
#   RAW: 'quiste renal grado III de Bosniak\ntumorectomía'
#   [chunk 9/11 | chars 1373-1584]
#   RAW: 'carcinoma de células claras renales\nquístico multilocular\nmárgenes de resección negativos'
#   [chunk 10/11 | chars 1584-1768]
#   RAW: 'cortical renal\ngrasa adyacente\nrecidiva local'
#   [chunk 11/11 | chars 1769-1877]
#   RAW: 'asintomático'
# [24/250] es-S0210-48062004000800009-1.txt | 27.45s | 11 chunks | 26 menciones
#   [chunk 1/18 | chars 0-125]
#   RAW: 'HTA\nHipertiroidismo\nDiabetes Mellitus tipo II\nsíndrome de ansiedad'
#   [chunk 2/18 | chars 126-342]
#   RAW: 'hematuria franca monosintomática'
#   [chunk 3/18 | chars 342-444]
#   RAW: 'masa palpable a nivel de fosa lumbar derecha'
#   [chunk 4/18 | chars 445-481]
#   RAW: 'abdomen'
#   [chunk 5/18 | chars 481-622]
#   RAW: 'gran masa sólida heterogénea en polo inferior del riñón derecho'
#   [chunk 6/18 | chars 623-681]
#   RAW: 'coágulos'
#   [chunk 7/18 | chars 682-723]
#   RAW: 'cistoscópico'
#   [chunk 8/18 | chars 723-815]
#   RAW: 'TAC abdominopélvico\nRx torax\nbioquímica hemática\nhemograma'
#   [chunk 9/18 | chars 815-1067]
#   RAW: 'masa tumoral derecha de 9x10 cm heterogénea\náreas de necrosis\ndistorsión del parénquima renal\ncontorno\nparénquima sano'
#   [chunk 10/18 | chars 1068-1159]
#   RAW: 'trombosada\nadenopatías locorregionales retroperitoneales'
#   [chunk 11/18 | chars 1159-1259]
#   RAW: 'anemia ferropénica\naumento de la VSG\nnormocalcemia'
#   [chunk 12/18 | chars 1259-1377]
#   RAW: 'cirugía radical'
#   [chunk 13/18 | chars 1377-1611]
#   RAW: 'arteria femoral común derecha\narteriografía de aorta abdominal\narteria renal derecha\ncatéter angiográfico visceral Cobra 2 de 5 Fr\nAngiodinamics®'
#   [chunk 14/18 | chars 1612-1842]
#   RAW: 'arteria que irriga al tumor'
#   [chunk 15/18 | chars 1842-1978]
#   RAW: 'alta hospitalaria'
#   [chunk 16/18 | chars 1978-2122]
#   RAW: 'cefalea\nTC cerebral'
#   [chunk 17/18 | chars 2123-2327]
#   RAW: 'hematuria\ninsomnio\nalgia músculoesquelética'
#   [chunk 18/18 | chars 2328-2451]
#   RAW: 'tensión arterial\nIECAS\ncalcio antagonistas'
# [25/250] es-S0210-48062005000300014-1.txt | 44.43s | 18 chunks | 40 menciones
#   [chunk 1/23 | chars 0-303]
#   RAW: 'cardiopatía isquémica\ninfarto de miocardio\ntriple by-pass aorto-coronario\narteriosclerosis de troncos supraaórticos\narteriosclerosis de extremidades inferiores\nEPOC\nhernia discal\nestenosis de canal'
#   [chunk 2/23 | chars 304-472]
#   RAW: 'tramo urinario inferior'
#   [chunk 3/23 | chars 473-537]
#   RAW: 'hematuria total con coágulos'
#   [chunk 4/23 | chars 538-662]
#   RAW: 'deterioro del estado general\nabdomen globuloso\ncicatriz de toracotomía'
#   [chunk 5/23 | chars 663-744]
#   RAW: 'hiperplasia benigna'
#   [chunk 6/23 | chars 744-859]
#   RAW: 'hemograma normal\nfunción renal normal\nhiperuricemia\nPSA'
#   [chunk 7/23 | chars 859-954]
#   RAW: 'riñones normales\nlesión exofítica\nbase vesical\ncara derecha'
#   [chunk 8/23 | chars 955-1058]
#   RAW: 'células malignas\nlesión neoplásica vesical'
#   [chunk 9/23 | chars 1059-1337]
#   RAW: 'carcinoma mixto, papilar de células transicionales grado II-III infiltrante de músculo liso  \nadenocarcinoma mucoide infiltrante  \ncarcinoma in situ  \ncistitis glandular quística'
#   [chunk 10/23 | chars 1337-1535]
#   RAW: 'engrosamiento de pared vesical\nateromatosis calcificada aorto-ilio-femoral'
#   [chunk 11/23 | chars 1535-1606]
#   RAW: 'cistoprostatectomía radical\nneovejiga ileal tipo Camey II'
#   [chunk 12/23 | chars 1607-1681]
#   RAW: 'postoperatorio'
#   [chunk 13/23 | chars 1681-2063]
#   RAW: 'tumoración epitelial ulcerada infiltrante de todo el espesor de pared hasta tejido adiposo perivesical\nnidos pequeños de células uroteliales dispuestas en lagunas artefactuales\nimágenes concluyentes de invasión vascular\nformaciones papilares sin tallo\ncarcinoma seroso ovárico'
#   [chunk 14/23 | chars 2064-2101]
#   RAW: 'cuerpos de psammoma'
#   [chunk 15/23 | chars 2102-2257]
#   RAW: 'displasia epitelial en uretra prostática\ncarcinoma de próstata bien diferenciado en lóbulo derecho\nGleason 4 (2+2)'
#   [chunk 16/23 | chars 2258-2433]
#   RAW: 'carcinoma micropapilar'
#   [chunk 17/23 | chars 2433-2569]
#   RAW: 'citoqueratina 7\nCA125\ncitoqueratina 20\nBX2\nP53\nCEA'
#   [chunk 18/23 | chars 2569-2698]
#   RAW: 'quimioterapia\ncarboplatino\ngencitabina\nafectación cardíaca'
#   [chunk 19/23 | chars 2699-2883]
#   RAW: 'infecciones urinarias\nanemia\nleucopenia\ntransfusiones sanguíneas\nfactores estimulantes de colonias'
#   [chunk 20/23 | chars 2883-3084]
#   RAW: 'QMT  \nneovejiga'
#   [chunk 21/23 | chars 3085-3184]
#   RAW: 'dolores óseos\ndolores abdominales'
#   [chunk 22/23 | chars 3185-3362]
#   RAW: 'recidiva mesentérica\ndilatación renoureteral bilateral'
#   [chunk 23/23 | chars 3363-3520]
#   RAW: 'deterioro progresivo de la función renal\nestado general\nprogresión intra y retroperitoneal'
# [26/250] es-S0210-48062005000400012-1.txt | 70.48s | 23 chunks | 65 menciones
#   [chunk 1/14 | chars 0-252]
#   RAW: 'diabetes mellitus tipo I\nprostatitis crónica\nfiebre\nmalestar general'
#   [chunk 2/14 | chars 253-383]
#   RAW: 'hemograma\nbioquímica\npruebas de coagulación\nradiología convencional'
#   [chunk 3/14 | chars 384-463]
#   RAW: 'hemocultivos'
#   [chunk 4/14 | chars 464-603]
#   RAW: 'Brucella'
#   [chunk 5/14 | chars 603-699]
#   RAW: 'Rifampicina'
#   [chunk 6/14 | chars 699-778]
#   RAW: 'recaída\ndolor lumbar\nfiebre'
#   [chunk 7/14 | chars 779-873]
#   RAW: 'región ilíaca izquierda  \nsigno del psoas'
#   [chunk 8/14 | chars 874-1072]
#   RAW: 'espondilodiscitis L5-S1\npartes blandas circundantes\nabsceso de psoas bilateral'
#   [chunk 9/14 | chars 1073-1166]
#   RAW: 'tratamiento antibiótico previo'
#   [chunk 10/14 | chars 1167-1288]
#   RAW: 'drenaje transcutáneo\ncolecciones del psoas'
#   [chunk 11/14 | chars 1288-1512]
#   RAW: 'abscesos de psoas bilaterales de gran tamaño\nafectación de tejido circundante\nespondilodiscitis en L5-S1'
#   [chunk 12/14 | chars 1513-1701]
#   RAW: 'drenaje de ambos músculos\ndiscectomía L5-S1'
#   [chunk 13/14 | chars 1702-1889]
#   RAW: 'doxiciclina 100mgr/12horas\nseptrim forte 1/12horas'
#   [chunk 14/14 | chars 1889-2001]
#   RAW: 'asintomático\nestado general'
# [27/250] es-S0210-48062005000700012-1.txt | 35.22s | 14 chunks | 31 menciones
#   [chunk 1/9 | chars 0-273]
#   RAW: 'ulcus gástrico\nfumador\nvasectomizado\naumento moderado de volumen escrotal izquierdo\nincremento\nmolestias sordas'
#   [chunk 2/9 | chars 274-308]
#   RAW: 'síntomas miccionales\nfiebre'
#   [chunk 3/9 | chars 309-436]
#   RAW: 'hidrocele'
#   [chunk 4/9 | chars 437-494]
#   RAW: 'análisis generales de sangre\nanálisis generales de orina'
#   [chunk 5/9 | chars 495-675]
#   RAW: 'imagen nodular intratesticular izquierda de bordes bien definidos\nneoplasia testicular\nhidrocele de contenido anecoico'
#   [chunk 6/9 | chars 676-720]
#   RAW: 'AFP\nß-HCG'
#   [chunk 7/9 | chars 721-814]
#   RAW: 'orquiectomía inguinal izquierda\nprótesis testicular siliconada'
#   [chunk 8/9 | chars 815-895]
#   RAW: 'postoperatorio inmediato normal\nTAC abdominal'
#   [chunk 9/9 | chars 896-1115]
#   RAW: 'testículo infartada\ninfarto testicular'
# [28/250] es-S0210-48062006000200018-1.txt | 23.12s | 9 chunks | 21 menciones
#   [chunk 1/20 | chars 0-213]
#   RAW: 'masa testicular izquierda'
#   [chunk 2/20 | chars 214-416]
#   RAW: 'masa testicular'
#   [chunk 3/20 | chars 417-715]
#   RAW: 'saco escrotal izquierdo'
#   [chunk 4/20 | chars 716-764]
#   RAW: 'lesiones en el epidídimo'
#   [chunk 5/20 | chars 765-1091]
#   RAW: 'masa testicular\ntestículo supernumerario\ntestículos\naditional'
#   [chunk 6/20 | chars 1092-1094]
#   RAW: ''
#   [chunk 7/20 | chars 1094-1121]
#   RAW: 'masas'
#   [chunk 8/20 | chars 1122-1164]
#   RAW: 'urología'
#   [chunk 9/20 | chars 1165-1212]
#   RAW: 'antecedentes personales negativos'
#   [chunk 10/20 | chars 1213-1487]
#   RAW: 'condiciones generales\nsignos vitales\ndesarrollo pondoestural\nmasas palpables\nhernias\nadenopatías inguinales'
#   [chunk 11/20 | chars 1488-1795]
#   RAW: 'masa esférica adenomatosa'
#   [chunk 12/20 | chars 1795-1944]
#   RAW: 'masa paratesticular\nPQ'
#   [chunk 13/20 | chars 1945-2128]
#   RAW: 'lesión'
#   [chunk 14/20 | chars 2129-2822]
#   RAW: 'testículos\nepidídimo\nconducto deferente\napéndice testicular\npaquete vascular\npaquete venoso'
#   [chunk 15/20 | chars 2823-3076]
#   RAW: 'estructura redondeada color carmelita'
#   [chunk 16/20 | chars 3077-3268]
#   RAW: 'testículo sano'
#   [chunk 17/20 | chars 3269-3370]
#   RAW: 'cierre por planos\nbloqueo del nervio ilioinguinal'
#   [chunk 18/20 | chars 3371-3478]
#   RAW: 'postoperatorio inmediato'
#   [chunk 19/20 | chars 3479-3595]
#   RAW: 'testículo normal'
#   [chunk 20/20 | chars 3596-3633]
#   RAW: 'neoplasia intratubular seminal'
# [29/250] es-S0210-48062006000400012-1.txt | 41.38s | 20 chunks | 33 menciones
#   [chunk 1/10 | chars 0-478]
#   RAW: 'prostatitis aguda\ndisuria\npolaquiuria\nfiebre\nlevofloxacino\nurocultivo\nimposibilidad para la micción\ndolor testicular bilateral\ndolor perineal\nempeoramiento del estado general'
#   [chunk 2/10 | chars 478-650]
#   RAW: 'temperatura de 38,6ºC\ntumefacción\nenrojecimiento\ncalor local'
#   [chunk 3/10 | chars 651-736]
#   RAW: 'dolor'
#   [chunk 4/10 | chars 736-917]
#   RAW: 'leucocitosis'
#   [chunk 5/10 | chars 917-1100]
#   RAW: 'orina en vejiga\nabsceso multiloculado prostático'
#   [chunk 6/10 | chars 1100-1248]
#   RAW: 'absceso\ncatéter suprapúbico'
#   [chunk 7/10 | chars 1249-1377]
#   RAW: 'punción transperineal ecodirigida'
#   [chunk 8/10 | chars 1377-1517]
#   RAW: 'cultivos negativos'
#   [chunk 9/10 | chars 1517-1642]
#   RAW: 'débito del "pig-tail"'
#   [chunk 10/10 | chars 1643-1786]
#   RAW: 'afebril\nmicción uretral normal\nnormalidad de la zona prostática'
# [30/250] es-S0210-48062006000700012-1.txt | 25.34s | 10 chunks | 24 menciones
#   [chunk 1/20 | chars 0-17]
#   RAW: 'Varón de 63 años.'
#   [chunk 2/20 | chars 18-70]
#   RAW: 'hematuria macroscópica monosintomática'
#   [chunk 3/20 | chars 71-230]
#   RAW: 'masa\nureterohidronefrosis'
#   [chunk 4/20 | chars 231-314]
#   RAW: 'tumor vesical infiltrante de alto grado'
#   [chunk 5/20 | chars 315-356]
#   RAW: 'estudio de extensión'
#   [chunk 6/20 | chars 357-401]
#   RAW: 'creatinina'
#   [chunk 7/20 | chars 402-582]
#   RAW: 'cistoprostatectomía radical laparoscópica\nderivación urinaria tipo Bricker\npT2b No Mo de alto grado\nzona trigonal\ncara posterior'
#   [chunk 8/20 | chars 582-628]
#   RAW: 'curso operatorio'
#   [chunk 9/20 | chars 629-826]
#   RAW: 'ureterohidronefrosis izquierda\natrofia cortical\nfunción renal\ncreatinina de 1,65 mg/dl'
#   [chunk 10/20 | chars 826-938]
#   RAW: 'tolerancia al estoma\nderivación continente'
#   [chunk 11/20 | chars 939-1003]
#   RAW: 'función renal'
#   [chunk 12/20 | chars 1004-1132]
#   RAW: 'laparotomía exploradora\ndisección pélvica\nmuñón uretral'
#   [chunk 13/20 | chars 1133-1184]
#   RAW: 'neovejiga ileal'
#   [chunk 14/20 | chars 1185-1257]
#   RAW: 'sangrado menor'
#   [chunk 15/20 | chars 1258-1345]
#   RAW: 'dado de alta'
#   [chunk 16/20 | chars 1345-1454]
#   RAW: 'reservorio'
#   [chunk 17/20 | chars 1454-1746]
#   RAW: 'trastornos metabólicos\ndiarrea persistente\nincontinencia\nnecesidad de autocateterismos\nalto residuo post-miccional'
#   [chunk 18/20 | chars 1747-1906]
#   RAW: 'asa de Bricker\nneovejiga\nureteral'
#   [chunk 19/20 | chars 1907-2008]
#   RAW: 'continencia'
#   [chunk 20/20 | chars 2009-2080]
#   RAW: 'derivación ortotópica'
# [31/250] es-S0210-48062006000900012-2.txt | 45.30s | 20 chunks | 37 menciones
#   [chunk 1/18 | chars 0-49]
#   RAW: 'enfermedades concomitantes'
#   [chunk 2/18 | chars 49-339]
#   RAW: 'Descenso testicular al nacimiento\nespermarquia\nenfermedades de transmisión sexual'
#   [chunk 3/18 | chars 340-457]
#   RAW: 'erecciones matutinas'
#   [chunk 4/18 | chars 457-597]
#   RAW: 'fascies característica'
#   [chunk 5/18 | chars 598-888]
#   RAW: 'vello androide\npene con prepucio retráctil\nmeato central\ntestículo izquierdo con volumen disminuido\ntestículo izquierdo con consistencia disminuida\nvaricocele grado III\ntestículo derecho con consistencia normal'
#   [chunk 6/18 | chars 888-1038]
#   RAW: 'infertilidad'
#   [chunk 7/18 | chars 1038-1155]
#   RAW: 'hemoglobina 15,3 g/dl\nleucocitos 8,000 cél/µ\nTP 13,8 segundos\nTTP 28,9 segundos'
#   [chunk 8/18 | chars 1155-1341]
#   RAW: 'glucosa\ncreatinina\nsodio\npotasio\ncloro\npH\ndensidad\nleucocitos'
#   [chunk 9/18 | chars 1341-1467]
#   RAW: 'LH\n\nFSH\n\noestradiol\n\ntestosterona'
#   [chunk 10/18 | chars 1467-1583]
#   RAW: 'Chlamydia\nMicoplasma\nUreaplasma'
#   [chunk 11/18 | chars 1583-1839]
#   RAW: 'Análisis de semen'
#   [chunk 12/18 | chars 1839-1901]
#   RAW: 'oligozoospermia\nastenozoospermia\nteratozoospermia severa'
#   [chunk 13/18 | chars 1901-2025]
#   RAW: 'varicocele'
#   [chunk 14/18 | chars 2025-2043]
#   RAW: 'Cariotipo'
#   [chunk 15/18 | chars 2043-2197]
#   RAW: 'Microdeleciones cromosoma Y'
#   [chunk 16/18 | chars 2197-2234]
#   RAW: 'sY254 (AZFc)'
#   [chunk 17/18 | chars 2234-2316]
#   RAW: 'ZFY\nSRY\nsY86(AZFa)\nsY134 (AZFb)\nsY255 (AZFc)'
#   [chunk 18/18 | chars 2316-2421]
#   RAW: 'controles positivos\ncontroles negativos'
# ...
#   RAW: 'potasio'
#   [chunk 18/18 | chars 2476-2661]
#   RAW: 'metimazol 5 mg al día\nparálisis'
# [241/250] es-S1699-695X2015000300013-1.txt | 42.35s | 18 chunks | 41 menciones
#   [chunk 1/17 | chars 0-186]
#   RAW: 'dolor abdominal continuo y difuso\nvómitos'
#   [chunk 2/17 | chars 187-277]
#   RAW: 'cesáreas'
#   [chunk 3/17 | chars 278-624]
#   RAW: 'tensión arterial\nfrecuencia cardíaca\ntemperatura axilar\ncicatriz de laparotomía media infraumbilical\nruidos disminuidos\ndolor a la palpación\nirritación peritoneal'
#   [chunk 4/17 | chars 625-667]
#   RAW: 'hernias inguinales\nhernias crurales'
#   [chunk 5/17 | chars 667-838]
#   RAW: 'glucemia'
#   [chunk 6/17 | chars 839-939]
#   RAW: 'suboclusión de intestino delgado\ncolelitiasis'
#   [chunk 7/17 | chars 940-1072]
#   RAW: 'asas de intestino delgado dilatadas\ntorsión intestinal'
#   [chunk 8/17 | chars 1072-1396]
#   RAW: 'vómitos\ndolor abdominal\nsignos de irritación peritoneal\nhemiabdomen inferior'
#   [chunk 9/17 | chars 1397-1846]
#   RAW: 'oclusión intestinal por bridas\nasa de intestino delgado estrangulada y necrosada\nasa de intestino delgado estrangulada y necrosada'
#   [chunk 10/17 | chars 1847-2323]
#   RAW: 'trompa de Falopio derecha'
#   [chunk 11/17 | chars 2324-2480]
#   RAW: 'gran dilatación de asas de intestino delgado'
#   [chunk 12/17 | chars 2481-2686]
#   RAW: 'asas necrosadas'
#   [chunk 13/17 | chars 2687-2916]
#   RAW: 'hernia interna a través de la hoja derecha del ligamento ancho del útero'
#   [chunk 14/17 | chars 2917-3052]
#   RAW: 'hernia\nileon necrosado'
#   [chunk 15/17 | chars 3053-3134]
#   RAW: 'herniario'
#   [chunk 16/17 | chars 3135-3259]
#   RAW: 'postoperatorio'
#   [chunk 17/17 | chars 3260-3307]
#   RAW: 'control postoperatorio'
# [242/250] es-S1887-85712012000400006-1.txt | 41.73s | 17 chunks | 30 menciones
#   [chunk 1/13 | chars 0-274]
#   RAW: 'desorientación\ndificultad en la articulación del lenguaje\nvisión borrosa\nvisión doble vertical'
#   [chunk 2/13 | chars 275-356]
#   RAW: 'pérdida de conciencia\npalpitaciones\ndolor torácico\nfiebre'
#   [chunk 3/13 | chars 356-532]
#   RAW: 'exfumador  \nhipertensión  \ndislipémico'
#   [chunk 4/13 | chars 532-751]
#   RAW: 'IV par craneal del ojo derecho  \nIII par bilateral  \nVI par derecho de predominio inferior  \ndiplopía binocular vertical'
#   [chunk 5/13 | chars 752-797]
#   RAW: 'resto de los pares craneales'
#   [chunk 6/13 | chars 798-911]
#   RAW: 'déficit motor  \ndéficit sensitivo  \nRomberg  \ndismetrías  \nsignos meníngeos'
#   [chunk 7/13 | chars 912-1000]
#   RAW: 'alteración de la marcha\nlateropulsión'
#   [chunk 8/13 | chars 1000-1343]
#   RAW: 'tomografía computerizada (TC) craneal de 64 canales'
#   [chunk 9/13 | chars 1343-1492]
#   RAW: 'diplopia\ninestabilidad\ntrastorno de la marcha'
#   [chunk 10/13 | chars 1492-1824]
#   RAW: 'microinfartos solitarios en sustancia blanca profunda\nlesiones isquémicas agudas\nobstrucción de la arteria de Percheron3'
#   [chunk 11/13 | chars 1825-1931]
#   RAW: 'lesiones'
#   [chunk 12/13 | chars 1931-2108]
#   RAW: 'origen embólico\nanticogulación oral\nDabigatran\nriesgo de recurrencia'
#   [chunk 13/13 | chars 2109-2269]
#   RAW: 'autonomía de la marcha\ndiplopía'
# [243/250] es-S1887-85712014000100005-1.txt | 35.73s | 13 chunks | 35 menciones
#   [chunk 1/21 | chars 0-234]
#   RAW: 'hipertensión arterial\ncarcinoma de recto'
#   [chunk 2/21 | chars 235-357]
#   RAW: 'artrosis generalizada'
#   [chunk 3/21 | chars 357-745]
#   RAW: 'SCASEST-Killip III'
#   [chunk 4/21 | chars 746-996]
#   RAW: 'dolor\nhematoma\ncateterismo'
#   [chunk 5/21 | chars 996-1242]
#   RAW: 'dolor'
#   [chunk 6/21 | chars 1242-1253]
#   RAW: 'Palidez'
#   [chunk 7/21 | chars 1253-1307]
#   RAW: 'imposibilidad para detectar pulso radial o cubital'
#   [chunk 8/21 | chars 1307-1373]
#   RAW: 'Disminución de la temperatura respecto a miembro contralateral'
#   [chunk 9/21 | chars 1373-1425]
#   RAW: 'Anestesia y parálisis total del miembro afectado'
#   [chunk 10/21 | chars 1425-1655]
#   RAW: 'presión intracompartimental'
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'síndrome compartimental agudo'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: 'anestesia general balanceada\nvía aérea con mascarilla laríngea'
#   [chunk 13/21 | chars 1907-1969]
#   RAW: 'Cefazolina'
#   [chunk 14/21 | chars 1970-2110]
#   RAW: 'incisión cutánea'
#   [chunk 15/21 | chars 2111-2191]
#   RAW: 'hematoma'
#   [chunk 16/21 | chars 2192-2410]
#   RAW: 'sección longitudinal de la fascia antebraquial  \nmusculatura epitroclear del antebrazo  \ndescompresión del nervio mediano  \nsección del ligamento anular del carpo'
#   [chunk 17/21 | chars 2411-2487]
#   RAW: 'lesiones vasculares'
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'herida'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: 'fasciotomía\nmiembro afecto\npulso arterial'
#   [chunk 20/21 | chars 2901-3087]
#   RAW: 'relleno capilar inferior a 2 segundos\nmovilidad y sensibilidad distal\ndolor'
#   [chunk 21/21 | chars 3088-3211]
#   RAW: 'ausencia de dolor en antebrazo derecho\nestado vasculonervioso distal'
# [244/250] es-S1887-85712016000100005-1.txt | 46.50s | 21 chunks | 33 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: 'coxalgia derecha'
#   [chunk 2/22 | chars 128-229]
#   RAW: 'dolor con práctica de ejercicio físico\nlimitación de la movilidad'
#   [chunk 3/22 | chars 230-429]
#   RAW: 'mecánico'
#   [chunk 4/22 | chars 430-528]
#   RAW: 'dolor'
#   [chunk 5/22 | chars 528-725]
#   RAW: 'dolor a la palpación en tercio medio de la región inguinal derecha\ndolor a la flexión\ndolor a la aducción\ndolor a la rotaciones sobre todo interna\nmaniobra de choque positiva'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'flexión 110o bilateral\nrotación interna de 10o derecha\nrotación interna de 40o izquierda\nrotación externa de 30o derecha\nrotación externa de 40o izquierda'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'balance muscular en la escala de Daniels'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'dolor a la palpación de puntos ciáticos\nmaniobras de Valleix\nmaniobras de Fabere\nmaniobras de Lasegue\nmaniobras de Bragard'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'dolor a la palpación en la cintilla iliotibial'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'claudicación\nTrendelenburg negativo'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'dolor para la marcha\nflexión forzada de cadera\nflexión forzada de rodilla'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'deformidad en forma de joroba'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'hemograma\nbioquímica\nhormonas tiroideas\nanticuerpos\nreactantes de fase aguda'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'alteración subcondral  \nedema óseo en cadera derecha  \nirregularidad cortical  \nsinovitis en interlínea articular  \ndistensión de la bursa ilio-psoas'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'pequeño islote óseo'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'pinzamiento de la interlinea articular antero-superior y posteroinferior\nincipiente collar osteofitario femoral\nlesiones subcondrales antero-superiores de cabeza femoral\nedema en acetábulo anterosuperior'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'necrosis avascular'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'lesión quística yuxtaarticular'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'síndrome de pinzamiento femoroacetabular tipo LEVA (también conocido por CAM)'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'sulfato de glucosamina-condroitin sulfato oral 400 mg cada 12 horas durante 3 meses\nantiinflamatorios no esteroideos'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'reposo deportivo\nchoque en la articulación\nactividad física activa controlada\nflexión de la cadera\nrotaciones'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'artroscopia'
# [245/250] es-S1888-75462015000400006-1.txt | 65.90s | 22 chunks | 46 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'fractura de tercio medio de clavícula derecha\nfractura de arcos costales derechos'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'dolor a nivel de clavícula\ndolor a nivel de pared costal derechas\nafectación neurovascular del miembro superior derecho'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'fractura de arcos costales derechos cuarto y quinto\nhemotórax\nneumotórax\nfractura de tercio medio de la clavícula derecha\ntercer fragmento'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'analgesia\nantiinflamatorios no esteroideos\nedematización del miembro superior derecho\nsensibilidad\npulsos periféricos\nconstantes\nruidos cardíacos\nsoplos\nextratonos\nmurmullo vesicular\nestertores'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'CHCM=31.4g/dl\nneutrófilos=76.6%\nlinfocitos=16.4%\neosinófilos=0.9%\nfibrinógeno=645mg/dl\nGGT=52U/l\nD-Dímero positivo'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'trombosis venosa de las venas axilar, cefálica y basílica\ncompresión de la rama cubital del nervio cutáneo braquial medial a nivel del hiato basílico'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'fractura de clavícula\ntrombosadas'
# [246/250] es-S1888-75462016000400180-1.txt | 31.01s | 7 chunks | 31 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: '58 años'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomía\nmetrorragias\nmiomas'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'osteoporosis densitométrica lumbar\nT-score en L1-L4 de -3\ncifras normales en cuello femoral\ndenosumab\nsuplementos de vitamina D\nhábitos tóxicos\nantecedentes personales\nantecedentes familiares\nfractura\nIMC normal'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'dolor mecánico en el pie izquierdo'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'dolor a la movilización del antepié izquierdo'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'alteraciones de la estática de pies'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Rx de pies'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'fractura de estrés\ncallo perióstico\nedema de tejidos blandos'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'PTH\nvitamina D\nsuplementación de vitamina D'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'suplementos de vitamina D\ndenosumab'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'AINEs'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'osteoporosis a nivel lumbar\nSERMS\nbazedoxifeno\nsuplementos de calcio con vitamina D\ndolor\nsíntomas'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'callo de fractura antiguo en 2o MTT por fractura de estrés previa'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'edema de 1er y 3er MTT  \ntenosinovitis del tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'densitometría ósea'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'bazedoxifeno\nvitamina D\ndensidad mineral ósea'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'fracturas'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'osteoporosis'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'dolor'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'cambios en sus costumbres\nactividad física (sedentaria)\ncambio de tipo de calzado\nsobrecarga del pie izquierdo\nfracturas de estrés'
# [247/250] es-S1889-836X2015000200005-2.txt | 51.60s | 20 chunks | 45 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'VIH'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'astenia\ndolores óseos difusos'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'fosfatasa alcalina (FA) total y ósea\nparatohormona (PTH)'
#   [chunk 4/16 | chars 408-569]
#   RAW: '25-hidroxivitamina D (25-HCC)'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'signos degenerativos'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'astenia\nfuerza\ndificultad para caminar\npérdida de peso'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'debilidad muscular de predominio proximal'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperglucemia leve\nglucosuria marcada\nhipofosfatemia\nfosfaturia inapropiadamente alta\nhipouricemia\nacidosis metabólica\nproteinuria'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'aminoaciduria moderada\nglicina\nvalina\nserina\ntreonina'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'FGF23 sérico'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Tabla 1'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'síndrome de Fanconi incompleto  \nhipofosfatemia grave  \nosteomalacia  \nTDF'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'raltegravir\ndarunavir\nritonavir'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'suplementos de fósforo\n25-HCC\n1,25-dihidroxivitamina D (1,25 DHCC)'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: '</think>\n\nCon ello su estado fue mejorando progresivamente.'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'TDF  \ndolores óseos  \ndebilidad muscular  \npeso basal  \nalteraciones analíticas séricas  \nreabsorción de fosfato'
# [248/250] es-S1889-836X2015000400006-1.txt | 42.36s | 16 chunks | 42 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'astenia  \nalergias no conocidas  \nlupus cutáneo  \neritema malar  \nreumatología'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Tiroiditis de Hashimoto'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'apendicectomía'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'fumadora'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'bebedora'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'hábitos tóxicos'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'anemia'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'Cesárea\nligadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'astenia\npresíncopes\nanorexia'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'menstruación muy duradera (8 días)'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'melénicas\npalidez cutánea\nmucosa'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'Epistaxis\ngingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'anemia'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'LDH  \nesquistocitos'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'PTT  \nLES'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'concentrado de hematíes\nconcentrado de plaquetas'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'afasia global\ndesviación de la comisura bucal a la izquierda\nfocalidad neurológica'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'lenguaje normal'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'síntoma neurológico'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'microangiopatía trombótica\ncrisis convulsivas'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'UCI'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'plasmaféresis'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'respuesta'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'pesa 75 kgr'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'tablas de relación'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'de volumen a reinfundir'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'plasma fresco'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'albúmina humana al 20%'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'diálisis peritoneal'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'plasmaféresis'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'heparina'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'PTM'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'mal estado general'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: '17 sesiones'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'Incidencia de las mismas:'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'hipotensión\nconvulsiones importantes'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'PTM'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'fallo del test de aire\nSET'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: ''
# [249/250] es-S2254-28842014000200009-1.txt | 77.28s | 40 chunks | 56 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'carcinoma seroso papilar'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'quimioterapia adyuvante\ncarboplatino\npaclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'CA 125'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'resección anterior de recto superior\nbiopsia intraoperatoria\nlesión hepática\nmetastásica'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'carboplatino\npaclitaxel\nCA 125'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'disnea\nvómitos\npérdida de conocimiento\nTAS/TAD de 70/50 mmHg'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'infusión'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'desensibilización'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'disnea\nsudoración\ntensiones\nsal de platino'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'trabectedina\nadriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'enfermedad'
# [250/250] es-S2340-98942015000100005-1.txt | 26.03s | 11 chunks | 25 menciones
#
# Predicciones guardadas en distemist_llm_predictions.tsv
# Tiempo medio por archivo: 38.91s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd


def prf(tp, fp, fn):
    p  = tp / (tp + fp) if (tp + fp) else 0.0
    r  = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1


df_pred  = pd.read_csv(PREDICTIONS_TSV, sep="\t")
df_gs    = pd.read_csv(GS_TEST_TSV, sep="\t")
df_gs    = df_gs[df_gs["filename"].isin(df_pred["filename"].unique())]

set_gs   = set(zip(df_gs["filename"],   df_gs["label"],   df_gs["off0"],   df_gs["off1"]))
set_pred = set(zip(df_pred["filename"], df_pred["label"], df_pred["off0"], df_pred["off1"]))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1   = prf(tp, fp, fn)

report = {"Estricta": {"tp": tp, "fp": fp, "fn": fn, "precision": round(p, 4), "recall": round(r, 4), "fscore": round(f1, 4)}}

print(f"── ESTRICTA ──  P={p:.4f}  R={r:.4f}  F1={f1:.4f}  (TP={tp} FP={fp} FN={fn})\n")

thresholds = [0.0, 0.5, 0.8]
results    = {t: {"tp": 0, "fp": 0, "fn": 0} for t in thresholds}

for filename in df_pred["filename"].unique():
    gs_ints   = list(zip(df_gs[df_gs["filename"] == filename]["off0"],   df_gs[df_gs["filename"] == filename]["off1"]))
    pred_ints = list(zip(df_pred[df_pred["filename"] == filename]["off0"], df_pred[df_pred["filename"] == filename]["off1"]))

    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )

    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi); matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ──  P=0.1933  R=0.6109  F1=0.2937  (TP=1587 FP=6621 FN=1011)
#
# ── IoU ──
# IoU >= 0.0:  P=0.2746  R=0.8676  F1=0.4172  (TP=2254 FP=5954 FN=344)
# IoU >= 0.5:  P=0.2340  R=0.7394  F1=0.3555  (TP=1921 FP=6287 FN=677)
# IoU >= 0.8:  P=0.1990  R=0.6286  F1=0.3022  (TP=1633 FP=6575 FN=965)
