# %% [markdown]
# # Pipeline Zero-Shot NER — ProcTemIST con BioMistral-7B-DARE
#
# Inferencia zero-shot para reconocimiento de procedimientos en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "BioMistral/BioMistral-7B-DARE"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo PROCEDIMIENTO medico (exploraciones, pruebas diagnosticas, intervenciones, tratamientos, cirugias, etc.).\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'radiografia', no escribas 'Rx'.\n"
    "4. REPETICIONES: Si un procedimiento aparece varias veces en el texto, debes listarlo varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio.\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
PROCTEMIST_ROOT      = f"{PROJECT_ROOT}/proctemist"
TEXT_FILES_TEST_DIR  = f"{PROCTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{PROCTEMIST_ROOT}/medprocner_tsv_test_subtask1.tsv"
PREDICTIONS_TSV      = "proctemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary_proctemist.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : BioMistral/BioMistral-7B-DARE
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
    trust_remote_code = True,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.6.7: Fast Mistral patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/651 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# BioMistral/BioMistral-7B-DARE does not have a padding token! Will use pad_token = <unk>.
#
# Modelo cargado: BioMistral/BioMistral-7B-DARE
# Parámetros totales: 3,752,071,168

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

def build_ner_messages(text):
    return [
        {
            "role": "user",
            "content": f"{SYSTEM_PROMPT}\n\nTexto para analizar:\n{text}",
        }
    ]

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            full_output = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        marker = "<|im_start|>assistant"
        idx    = full_output.rfind(marker)
        result = full_output[idx + len(marker):].strip() if idx != -1 else full_output.strip()
        result = re.sub(r"<think>.*?</think>", "", result, flags=re.DOTALL).strip()
        result = re.sub(r"<think>.*",          "", result, flags=re.DOTALL).strip()

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename":   txt_path.stem,
            "ann_id":     f"T{mark_idx}",
            "label":      "PROCEDIMIENTO",
            "start_span": off0,
            "end_span":   off1,
            "text":       span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "ann_id", "label", "start_span", "end_span", "text"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'Procedimiento: Radiografia, Exploración física, Hemograma, Glucosa, Presión arterial.'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'Procedimiento: refiere dolor lumbar derecho'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'La exploración física fue normal.'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'Ultrasonido abdominal, masa suprarrenal derecha, hipoecogénica, 80 mms, riñón derecha, polo superior.'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'Urograma descendente, proceso expansivo en la suprarrenal derecha, el polo superior de riñón derecho desplazado hacia abajo.'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'TAC helicoidal, masa tumoral, diámetro mayor de 8,7x76 cms, contornos irregulares, densidad heterogénea de 100 - 37 UH, tabicada, compatible con tumor suprarrenal de densidad grasa.'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'Procedimiento: Estudio hormonal para la determinación de cortisol'
#   [chunk 8/13 | chars 744-799]
#   RAW: '"cirugía por abordaje lumbar"'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'Procedimiento: Los hallazgos transoperatorios\nProcedimiento: un tumor localizado en la glándula suprarrenal derecha\nProcedimiento: bien delimitado de bordes irregulares con lobulaciones'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'adrenalectomía derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'Procedimiento: evolución post operatoria'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'Procedimiento: patólogo, pieza, peso, dimensiones, corte, áreas amarillas - naranjas, hemorragias, tejido adiposo, calcificaciones.'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'El examen histopatológico: mielolipoma de la glándula adrenal con extensas áreas de calcificaciones.'
# [1/250] S0004-06142006000100010-1.txt | 29.64s | 13 chunks | 4 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'Procedimientos:\n\n* gastrectomía subtotal\n* adenocarcinoma gástrico\n* hipertensión arterial'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'Procedimientos:\n\n* Exploración digestiva\n* Radiografía de abdomen\n* Tomografía de abdomen con contraste oral y IV'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'La exploración física se objetivó una gran tumoración de consistencia firme, indolora, móvil y que ocupaba las tres cuartas partes del abdomen.'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'Procedimiento: ascitis por carcinomatosis, obstrucción intestinal tumoral o tumoración abdominal.'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'Procedimientos: radiografia, exploración física, hemoglobina, hematocrito, VCM, RDW, VSG, PCR, PSA, creatinina, urea.'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'Los marcadores tumorales hepáticos y digestivos resultaron anodinos.'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'gastroscopia, pólipo inflamatorio, muñón gástrico, recidiva tumoral'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'Procedimiento: colonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'Procedimiento: ecografía abdominopélvica.'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'Procedimiento: riñón izquierdo, riñón derecho'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'Procedimientos:\nUrografía intravenosa'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'Procedimiento: TAC'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'Procedimiento: Imagen cálcica, exploración teórica zona de pelvis renal, riñón hidronefrótico, compresión, desplazamiento, estructuras abdominales.'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'Procedimiento: hidronefrosis gigante secundaria a uropatía obstructiva litiásica, drenaje percutáneo, nefrectomía.'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'Nefrectomía simple derecha por lumbotomía subcostal evacuando 7.800 mililitros de contenido serohemático.'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'Linfadenectomía hiliar ampliada'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'Procedimiento: Cultivo del fluido, citología.'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'Procedimiento: examen histológico'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'Procedimientos:\n\n* Revestimiento epitelial\n* Exploración\n* Prueba diagnóstica\n* Infiltración del parénquima renal'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'Procedimientos:\n\n* Nidos sólidos de células de citoplasma amplio, claro y de alto grado nuclear (grado 3 de Fuhrman)\n* Infiltración ganglionar de carcinoma de células renales tipo célula clara.'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'La evolución posterior fue desfavorable, con aparición de metástasis hepáticas y el eventual fallecimiento del paciente a los dos meses.'
# [2/250] S0004-06142006000100014-1.txt | 44.61s | 21 chunks | 6 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'Procedimiento: Consulta por dolor a nivel de hipogastrio, eyaculación dolorosa, hemospermia y sensación de peso a nivel testicular atribuido hasta entonces a varicocele derecho ya conocido desde hacía un año.'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'Prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'Exploración física, varicocele derecho, testículos.'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'Procedimiento: tacto rectal, exploración de próstata, próstata irregular, aumentada de tamaño, induradas, dolorosa.'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'Ecografía urológica integral, ecografía testicular, quiste simple'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'TAC abdómino-pélvica, metástasis, hemangiomas.'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'Procedimiento: RMN, hemangiomas.'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'La Rx de tórax no presentaba alteraciones.'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'Los marcadores tumorales y el PSA presentaban unos valores dentro de la normalidad.'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'Procedimientos:\n- Alfa-feto-proteína\n- Beta-HCG\n- PSA'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'Procedimiento: orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'Procedimiento: pieza, exploración macroscópica, pulpa testicular, nodular, coloración, testículo, polo superior.'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'Procedimiento: informe histopatológico, tumor de células de Leydig, infiltración, espacios perineurales, canales vasculares capsulares, músculo liso, atípia, mitosis.'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'Procedimiento: control evolutivo'
# [3/250] S0004-06142006000500002-2.txt | 29.97s | 14 chunks | 3 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'Procedimientos:\n1. Ecografía\n2. Orquidopexia\n3. Criptorquidia'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'Procedimiento: cólicos nefríticos de repetición, expulsión de litiasis, LEOC.'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Ureterolitectomía'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'Procedimiento: Fumador de 1 paquete de cigarrillos/día.'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'Procedimiento: consultó al urólogo de zona por esterilidad y nódulo en testículo izquierdo de meses de evolución que había aumentado de tamaño en las últimas semanas.'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'Espermiograma, azoospermia, total.'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'La ecografía-doppler testicular fue informada como testículo derecho con masa de 19 x 23 mm en polo superior con flujo aumentado, compatible con tumor testicular y quiste de cordón izquierdo.'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'Exploración física, quiste de epidídimo'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'Procedimiento: exploración testicular derecha'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'Procedimiento: completar estudio.'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'La Rx de tórax era normal y en la TAC toraco-abdómino-pélvico no se observaban metástasis.'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'Procedimiento: analítica tampoco, valores séricos hormonales, marcadores tumorales, alfa-fetoproteina, beta-HCG.'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: '"orquiectomía radical inguinal derecha", "biopsia del testículo izquierdo"'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'Procedimiento: testículo derecho de 3,2 x 3 cm.'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'Procedimiento: superficie testicular'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'Procedimiento: Corte'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'Procedimiento: Exploración testicular'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'Procedimiento: cordón espermático'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'Procedimiento: biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Procedimiento: Tumor de células de Leydig'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'Procedimiento: exploración testicular, biopsia testicular, atrofia de parénquima testicular, hiperplasia de células de Leydig, espermiogénesis.'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'Procedimiento: Bordes quirúrgicos libres.'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'Procedimiento: Biopsia del teste izquierdo.'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'Procedimiento: radiografia'
# [4/250] S0004-06142006000500002-3.txt | 46.13s | 25 chunks | 4 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'Procedimiento: ecografía, masa renal derecha'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'TAC abdomino-pélvica, masa sólida, heterogénea, 6 cm, polo superior, riñón derecho, vena renal permeable.'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'Nefrectomía radical derecha por laparotomía subcostal.'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'Procedimiento: diagnóstico anatomopatológico'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'Procedimiento: cirugía'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'Procedimiento: seguimiento de neoplasia'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'Exploración, TAC, recidiva tumoral, quirúrgico, pilar diafragmático derecho posterior, hígado, implantes peritoneales, mayor, cuatro centímetros, adyacente, hilio hepático.'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'La extirpación de las masas tumorales, la resección de la adyacente al hígado así como varios implantes peritoneales y retroperitoneales, la biopsia intraoperatoria compatible en todas las piezas con carcinoma de células claras de alto grado.'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'Procedimiento: masa retroperitoneal paravertebral'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Procedimiento: Interferón (Intrón A)'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'Procedimientos:\n\n* Revisiones\n* TAC de abdomen de control\n* Cirugía\n* Lesiones hepáticas\n* Recidiva del lecho quirúrgico\n* Implantales peritoneales'
# [5/250] S0004-06142006000900015-1.txt | 25.94s | 11 chunks | 0 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'Procedimiento: Paciente varón de 29 años.'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'Procedimiento: ecografía, estudio, tumoración, testículo izquierdo, testículo derecho, neoplasia.'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'Procedimiento: No presenta otra sintomatología urológica, no astenia, no pérdida de peso.'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'Procedimiento: Tampoco'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'Procedimiento: exploración física'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'Procedimientos:\nAmbos, no dolorosos, de consistencia normales y de superficie regulares.'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'Procedimiento: Epidídimos y cordones'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'Procedimientos:\n- Hemostasia\n- Bioquímica\n- Hemograma\n- Alfa-feto proteína\n- Beta-hCG'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'Procedimiento: ecografía con flujo Doppler'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'Procedimiento: teste izquierdo, exploración, prueba diagnóstica, lesión, Doppler.'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'Procedimiento: Microlitiasis testiculares bilaterales.'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de tórax, TAC toraco-abdomino-pélvico con contraste.'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'Procedimiento: orquiectomía bilateral vía inguinal.'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'Procedimientos:\n\n* Testículo izquierdo atrófico\n* Múltiples focos microscópicos de seminoma clásico\n* Áreas de neoplasia intratubular de células germinales (NICG)\n* Infiltración vascular'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'Procedimiento: testículo derecho, tumoración, seminoma clásico, parénquima, tumoración, NICG, focos de atrofia.'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'Túnica albugínea, rete testis, epidídimo y borde quirúrgico libres de tumor.'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'Carboplatino'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'Procedimiento: remisión completa'
# [6/250] S0004-06142007000200017-1.txt | 37.15s | 18 chunks | 2 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'Procedimientos:\nRadiografia'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'Procedimientos:\n\n* Exploración genital\n* Radiografía de pelvis\n* Tomografía de pelvis\n* Tomografía de abdomen y pelvis\n* Tomografía de pelvis con contraste\n* Tomografía de pelvis con resonancia magnética\n* Tomografía de pelvis con resonancia magnética con contraste\n* Tomografía de pelvis con resonancia magnética con contraste y ultrasonido'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'Procedimientos:\n1. Examen físico\n2. Edema\n3. Pene\n4. Escroto\n5. Eritema\n6. Dolor'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'Procedimiento: Adenopatías inguinales'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'Procedimientos:\n- Estudios complementarios\n- Hemograma completo'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'Procedimiento: Serología'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Procedimiento: Prueba de Mantoux, RX de cadera.'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'Psoas derecho engrosado de 48 mm TAC simple de hipogastrio y pelvis: Necrosis aséptica de la cabeza del fémur con hipertrofia del psoas a ese nivel.'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'Exploración retroperitoneal derecha.'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'Adenectomía de ilíaca derecha y cava.'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'Linfangioplastia con aguja.'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'Fasciotomía de la raíz del pene.'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'Procedimientos:'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'Procedimiento: Linfedema primario inflamatorio local de pene y escroto.'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'Necosis aséptica de la cabeza del fémur.'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'Procedimiento: valoración multidisciplinaria\nProcedimiento: valoración multidisciplinaria'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'Linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'Procedimientos:\nAnatomía Quirúrgica'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'La piel y dermis; el dartos, túnica muscular de fibras lisas (músculo peripeneal de Sappey), que contribuye con su contracción a comprimir los conductos venosos subyacentes en la erección; y la cubierta celulosa rica en fibras elásticas donde se sitúan los vasos linfáticos dilatados y venas, arterias y nervios superficiales, se encuentran formando un bloque difícil de distinguir en capas y que debe ser extirpado en su totalidad respetando la fascia penis delgada adherida a los órganos eréctiles, esponjosos y cavernosos que contienen la uretra y dorsalmente la arteria peneana.'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'Exploración de testículos, extirpación de recubrimiento de testículos, eritroide, capa vaginal, paquete vasculo nervioso, epidídimo.'
# [7/250] S0004-06142007000600012-1.txt | 50.86s | 20 chunks | 9 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'Procedimiento: Nódulo testicular'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'Exploración, nódulo duro, móvil, doloroso, cordón espermático derecho.'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'Procedimiento: determinación de marcadores tumorales y hormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'Procedimiento: ecografía'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'Procedimiento: Estudio de RNM\nProcedimiento: Imagen de señal baja en T2\nProcedimiento: Tejido con bajo contenido en agua\nProcedimiento: Fibroso o cicatricial\nProcedimiento: Diámetro máximo de 43 mm'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'Procedimiento: exéresis quirúrgica, separación del conducto deferente.'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'Procedimientos:'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'Procedimiento: Estudio macroscópico, pieza, formación redondeada, coloración pardusca, consistencia elástica, bien delimitada, 5 cm de diámetro máximo, superficie blanquecina, homogénea, aspecto fibroso.'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'Procedimiento: microscopio, lesión, células, amplio citoplasma, eosinófilo, estriaciones transversales, estroma fibroblástico, células vacuoladas, células multinucleadas, actividad mitótica.'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'Procedimientos:\n\n* Estudio inmunohistoquímico\n* Desmina\n* Vimentina\n* Actina de músculo liso específica'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'Procedimiento: Granada.'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'Procedimientos:\n\n* Exploración física general\n* Radiografía de tórax\n* Tomografía torácica\n* Tomografía abdominal\n* Tomografía cefálica\n* Tomografía de cadena cervical\n* Tomografía de cadena lumbosacra\n* Tomografía de cadena cervical y lumbosacra\n* Tomografía de cadena cervical y torácica\n* Tomografía de cadena cervical, torácica y lumbosacra\n* Tomografía de cadena cervical, torácica y abdominal\n* Tomografía de cadena cervical, torácica, abdominal y lumbosacra\n* Tomografía de cadena cervical, torácica, abdominal y cadena cervical y lumbosacra\n* Tomografía de cadena cervical, torácica, abdominal y cadena cervical, lumbosacra y torácica'
# [8/250] S0004-06142007000600014-1.txt | 41.90s | 12 chunks | 0 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'Procedimiento: herida de arma de fuego, exploración de herida de arma de fuego, cirugía de herida de arma de fuego, cirugía de herida de arma de fuego con orificio de entrada en la nalga, cirugía de herida de arma de fuego con orificio de entrada en la nalga de unos 4 milímetros de diámetro y sin orificio de salida.'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'Procedimiento: herida de bala en el muslo derecho con orificio de entrada por detrás y salida por delante.'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'Procedimiento: Exploración abdominal'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'Procedimiento: radiografia simple de abdomen, bala, fractura de la rama descendente derecha de la sínfisis del pubis.'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'Procedimiento: Retención, sondaje, catéter suprapúbico.'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'Laparotomía, colostomía izquierda.'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'Uretrografía, comprobando que hay paso de contraste desde la uretra hasta el recto, lo que provoca fiebre alta con escalofríos que se mantiene durante unos días.'
#   [chunk 8/18 | chars 981-1144]
#   RAW: '"Colonoscopia"'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'Uretrotomo endoscópico, uretra prostática, orificio, recto.'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: '"A pesar de todo se consigue encontrar el camino que lleva hasta la vejiga y por último se deja una sonda del dieciocho."'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'Procedimiento: laparotomía hasta la sínfisis del pubis.'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'Procedimiento: Retzius Space Exploration, Radiological Control, Palpation of Anterior Prostate Face, Hyperplastic Prostate, Touching Prostate Nodule.'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'Procedimiento: pinza de anillo, control radiológico, extraer bala.'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'Procedimiento: postoperatorio, sonda'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'Procedimientos:\n\n* colonoscopia\n* orificio rectal\n* colostomía'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'Procedimiento: sonda'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'Uretrografía, Uretrografía, Uretrografía'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'Procedimiento: ultrasonido'
# [9/250] es-S0004-06142007000900010-1.txt | 39.69s | 18 chunks | 0 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Procedimientos:\n- Apendicectomía\n- Hernia discal\n- Hiato\n- Fractura de tibia y peroné\n- Cólico nefrítico derecho'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'Procedimiento: Estudio ecográfico'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'TAC, masa, riñón, derecho, cortical, 5 cm, bordes, externos, lobulados, espacio, perirrenal, adenopatías, dilatación, vía, renal, excretora.'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'Nefrectomía radical derecha'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'Procedimiento: Estudio macroscópico'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'Procedimiento: estudio microscópico'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'Procedimientos:\n\n* Estudio inmunohistoquímico para determinación de vimentina, citoqueratina 7, citoqueratina de amplio espectro, CD34, cromogranina y EMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'Procedimiento: Granada.'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'Procedimientos médicos:\n\n* Exploración física general\n* Radiografía de tórax\n* Tomografía torácica\n* Tomografía abdominal\n* Tomografía cefálica\n* Tomografía de cadena cervical\n* Tomografía de cadena lumbosacra\n* Tomografía de cadena cervical y lumbosacra\n* Tomografía de cadena cervical y torácica\n* Tomografía de cadena cervical, torácica y lumbosacra\n* Tomografía de cadena cervical, torácica y abdominal\n* Tomografía de cadena cervical, torácica, abdominal y lumbosacra\n* Tomografía de cadena cervical, torácica, abdominal y cadena cervical y lumbosacra\n* Tomografía de cadena cervical, torácica, abdominal y cadena cervical y lumbosacra y cadena cervical y lumbosacra\n* Tomografía de cadena cervical, torácica, abdominal y cadena cervical y lumbosacra y cadena cervical y lumbosacra y cadena cervical y torácica y lumbos'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'Procedimientos:\nradiografia, exploración generalizada, expresión generalizada de vimentina, focal de citoqueraina 7, EMA, CD34.'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'La paciente cursa tras la intervención sin incidentes destacables y se encuentra asintomática a los 24 meses de la intervención.'
# [10/250] es-S0004-06142007000900012-1.txt | 41.61s | 11 chunks | 2 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'Procedimientos:\nSK, exploración, prueba diagnóstica, intervención, tratamiento, cirugía, radiografía, sinusitis, bronquiectasias, desprendimiento retina, testículo, induración.'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'Procedimiento: exploración lumbar, radiografia testicular izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'Exploración, neoplasia'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'Procedimiento: palpación'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'Procedimiento: ecografía, tumor testicular, tipo seminoma, ganglios locorregionales.'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'Procedimiento: radiografia de tórax, situs inversus, evidenciado por el apex de la silueta cardiaca y la cámara de gases gástrica a la derecha y alguna imagen cicatricial con probables bronquiectasias en lóbulo inferior izquierdo.'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'Procedimientos:\n\n* Analítica\n* LDH\n* GOT\n* GPT'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'Procedimiento: Marcadores tumorales, orquiectomía inguinal, raquianestesia, prótesis testicular.'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'Procedimiento: seminoma clásico'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'Procedimiento: No se evidencia invasión vascular.'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Procedimiento: Neoplasia germinal intratubular.'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'Fibrosis e hialinización tubular de testículo no tumoral.'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'Exploración física, exploración por imágenes, observación, normalidad bioquímica, parámetros tumorales, tratamiento adicional, Servicio de Oncología, diagnóstico de seminoma grado I, criterios de mal pronóstico, acuerdo, observando, tras un año de seguimiento, bioquímica, imágenes, exploración física, pruebas por imágenes, negativas, normalidad, parámetros tumorales, tratamiento adicional, Servicio de Oncología, diagnóstico de seminoma grado I, criterios de mal pronóstico, acuerdo, observando, tras un año de seguimiento, bioquímica, imágenes, exploración física, pruebas por imágenes, negativas, normalidad, parámetros tumorales, tratamiento adicional, Servicio de Oncología, diagnóstico de seminoma grado I, criterios de mal pronóstico, acuerdo, observando, tras un año de seguimiento, bioquímica, imágenes, exploración física, pruebas por imágenes, negativas, normalidad, parámetros tumorales'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'Procedimiento: orquiectomía, espermiogramas.'
# [11/250] es-S0004-06142008000300011-1.txt | 45.99s | 14 chunks | 1 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'Procedimiento: Radiografía de abdomen'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'Procedimiento: Tos, inspiración'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'Procedimiento: No refiere fiebre ni sensación distérmica.'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'Procedimiento: No coluria ni acolia.'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'La exploración física la paciente se encuentra consciente y orientada, afectada por el dolor e impresiona de gravedad.'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'Procedimiento: Palidez mucocutánea.'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'Procedimiento: Paciente afebril y normotensa.'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Procedimiento: Auscultación cardiopulmonar'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'Procedimiento: Abdomen sin masas ni megalias, con dolor abdominal generalizado a la palpación, más intenso en epigastrio, sin signos de irritación peritoneal (Murphy negativo).'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'Procedimiento: No se aprecia circulación colateral.'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'Procedimiento: No edemas en miembros inferiores.'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'Procedimiento: No signos de trombosis venosa profunda (TVP).'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'Procedimiento: Analítica, Bioquímica, Transaminasas, GOT, GPT.'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'Procedimiento: Hemograma con hemoglobina, hematocrito, leucocitos y plaquetas.'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'Procedimiento: Hemostasia'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'TC, trombo con densidad grasa, riñón izquierdo, vena renal izquierda, vena cava inferior, ostium de aurícula derecha.'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'Procedimiento: Venas suprahepáticas libres.'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'Procedimiento: No oclusión completa de la luz de VCI.'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'Procedimiento: Anormalidad inespecífica de cabeza de páncreas.'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'ECO abdómino-pélvico, hígado, vía biliar intra y extrahepática.'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Procedimiento: Lipoma en VCI.'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'Procedimiento: Signos ecográficos de colecistitis, probablemente perforada y posible pancreatitis.'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'Liquido libre en pelvis, espacio perihepático, periesplénico y perirrenal derecho (en mayor cuantía que en TC previo).'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'Procedimiento: Diagnóstico diferencial entre patología bilio-pancreática vs.'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'Procedimiento: TC, angiomiolipoma (AML)'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'lipoma renal que se extiende hacia VCI y ostium de la aurícula derecha, con paso de contraste en todo el recorrido de las estructuras venosas, con vena porta y suprahepáticas permeables.'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'Procedimientos:\n- Hepatomegalia\n- Vena porta\n- Vena suprahepática\n- Contraste\n- Edema periportal\n- Bazo\n- Páncreas atigrado\n- Líquido libre'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'Procedimiento: paracentesis, control ecográfico'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'Procedimiento: Obtener resultado analítico de trasudado. Procedimiento: Descartar proceso peritoneal.'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'En ecografía transesofágica la paciente presenta buena función ventricular sin trombo intracavitario, estando la tricúspide libre y existiendo derrame pericárdico.'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Procedimiento: Síndrome de Budd-Chiari secundario a trombo en cava (AML vs. Trombo en cava)'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'Procedimiento: Lipoma'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'Procedimiento: INTERVENCIÓN QUIRÚRGICA.'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'Procedimiento: trombo, nivel quirúrgico IV, situación supradiafragmática, ostium de aurícula derecha.'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'Incisión tipo Chevron y acceso a retroperitoneo mediante apertura desde asa fija hasta hiato de Winslow para permitir completa liberación ascendente del paquete intestinal, incluyendo ligadura de vena mesentérica inferior.'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'Procedimiento: movilización hepática'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'Procedimiento: liberación del riñón izquierdo y su hilio correspondiente, liberación de la vena cava, empezando a nivel infrarrenal y ascendiendo hasta nivel suprahepático con control de vena renal derecha (VRD) y sección del resto de ramas excepto venas suprahepáticas que se comprueban libres de trombo tumoral y son las únicas que fijan la cava al hígado.'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'Procedimiento: Ampliación del hiato diafragmático, expulsión del trombo hasta nivel infradiafragmático.'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'Clampaje de pedículo hepático (maniobra de Pringle), de VCI proximal y distal y VRD con posterior cavotomía y apertura VRI, extracción completa del trombo y nefrectomía izquierda.'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'Procedimiento: angiomiolipoma de predominio lipomatoso del seno renal con infiltración vascular.'
# [12/250] es-S0004-06142008000300012-1.txt | 93.39s | 40 chunks | 5 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'Procedimiento: Exploración urológica, cólico nefrítico, hematuria.'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'En tratamiento con diclofenaco por artrosis y lumbalgia.'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'La radiografía y ecografía mostraron una litiasis en el grupo calicial medio del riñón derecho y un quiste renal gigante.'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'TAC, quiste renal simple (Bosniak I), riñón derecho, litiasis ipsilateral de 8 milímetros.'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'Procedimiento: Serología de hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Procedimiento: Hemograma'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'Procedimiento: Quiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'Procedimiento: Información'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'Procedimiento: drenaje percutáneo, esclerosis del quiste.'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'Procedimiento: cistitis, exploración, fiebre elevada, dolor lumbar derecho.'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'Procedimiento: tratamiento antibiótico de modo domiciliario.'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'Procedimiento: drenaje percutáneo'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'Procedimiento: Mide'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'Procedimiento: Calcificación de la pared'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'TAC con cortes tardíos'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'Procedimiento: microhematuria, leucocituria.'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'Procedimiento: Cistitis'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'Procedimiento: litiasis'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'Procedimiento: Infección urinaria por E.Coli, tratamiento con Amoxicilina-Clavulanico, tratamiento con Trimetropin-Sulfametoxazol.'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'Procedimiento: litotricia extracorpórea'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'Procedimiento: Desde entonces la paciente esta asintomática.'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'Procedimiento: TAC'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Procedimiento: Bosniak IIF'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'Ecografías de control, UIV, y TAC, confirman que la lesión no ha variado su aspecto.'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'Procedimiento: comunicación con la vía urinaria'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'Procedimiento: N/A'
# [13/250] es-S0004-06142008000300013-1.txt | 40.10s | 26 chunks | 3 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'Prostatectomía radical con linfadenectomía obturatriz, carcinoma de próstata medianamente diferenciado, afectación microscópica limitada de los márgenes de resección.'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'Procedimiento: cirugía prostática'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'TAC abdominal'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'TAC post orquiectomía detecta adenopatías retroperitoneales desde área inguinal hasta bifurcación de renales.'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'Orquiectomía inguinal, linfoma testicular difuso de célula grande tipo B, quimioterapia citorreductiva, R-CHOPx8, remisión completa.'
#   [chunk 6/6 | chars 916-1121]
#   RAW: '"IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFOVM / DHAP", "IFO'
# [14/250] es-S0004-06142008000400011-2.txt | 30.85s | 6 chunks | 2 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'Procedimiento: Mujer de 52 años de edad, con hipertensión arterial como único antecedente de interés.'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'Procedimiento: Consultación al Servicio de Ginecología por metrorragias acompañadas de dolor abdominal.'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'Procedimiento: No refería hematuria ni dolor en fosas renales.'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'ecografía vaginal, masa anexial izquierda, 7 cm, muy vascularizada, útero grande, ovario derecho normales.'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'TC abdómino-pélvico, masa compleja, riñón derecho, 64 x 65 mm, intensa captación de contraste, áreas hipodensas centrales.'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'Procedimiento: 17 mm nodulo dependiente del polo superior del mismo riñón, 10 mm nodulo dependiente del polo superior del mismo riñón.'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'Procedimiento: Lesión sólido-quística'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'Procedimiento: No se observaron adenopatías regionales ni implantes metastásicos peritoneales.'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'Procedimientos:\nhisterectomía total, doble anexectomía, nefrectomía radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'Procedimiento: estudio histológico intraoperatorio de la estructura ovárica'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'Procedimiento: diagnóstico histológico renal, carcinoma de células renales, grado I de Fuhrman, grasa perirrenal, vena renal.'
# [15/250] es-S0004-06142008000400013-1.txt | 27.26s | 11 chunks | 0 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'Procedimientos:\n\n* gastrectomía\n* carcinoma de próstata\n* prostatectomía radical\n* ganglio linfático\n* PSA'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'Procedimiento: Lesión exofítica, glande'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'Procedimiento: exploración, lesión, traumatismo, sangrado, roce.'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'Procedimiento: exploración del paciente, lesión redondeada exofítica, color rojizo oscuro, diámetro de dos centímetros, tendencia al sangrado, consistencia elástica, no dolorosa.'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'Procedimientos:\n\n* Linfadenectomías\n* Biopsia de la lesión\n\nLa salida del sistema NER medico de alta precisión sería:\n\nLinfadenectomíasBiopsia de la lesión'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: '"análisis anatomopatológico intraoperatorio", "lesión", "células indiferenciadas", "hipercromatismo nuclear", "pleomorfismo", "mitosis", "pigmento negruzco", "melanoma"'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'Procedimiento: resección, penectomía subtotal, linfadenectomía inguinal superficial bilateral'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'TAC tóracoabdominal'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'Procedimiento: Estudio anatomopatológico, pieza penectomía'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'S-100, HMB 45, melanoma'
# [16/250] es-S0004-06142008000400016-1.txt | 25.70s | 10 chunks | 1 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'Procedimientos:\n\n* Histerectomía abdominal con doble anexectomía por endometriosis\n* Ecografía abdominal'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'Exploración, fosa lumbar derecha, fosa lumbar izquierda, patología retroperitoneal.'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'Urografía intravenosa (UIV) y Tomografía computerizada (TAC) simultáneos, observándose riñón derecha funcionante con retraso en la captación y eliminación de contraste y borramiento de la línea de psoas derecha.'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'Procedimiento: TAC, lobulada, líquido, contraste, extravasación, uréter.'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'Ureterolisis, exéresis del urinoma, anastomosis termino-terminal del uréter tras refrescamiento de los bordes y liberación de ambos extremos.'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'Procedimiento: catéter doble J, tutorización, uréter, retirada, cirugía.'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'Procedimiento: evolución, paciente, favorable, complicaciones, postoperatorio.'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'Procedimiento: control, intervención, UIV.'
# [17/250] es-S0004-06142008000500009-1.txt | 20.72s | 8 chunks | 0 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'Procedimiento: Infecciones Urinarias (ITUs)'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'Procedimientos:\n\n* Histerectomía vía vaginal\n* Absceso de cúpula vaginal\n* ECO absceso en cúpula vaginal\n* TC absceso en cúpula vaginal'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'Procedimiento: No DM.'
#   [chunk 4/15 | chars 616-623]
#   RAW: 'Procedimientos:\nNo HTA.'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'Procedimiento: No alergias conocidas.'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'Procedimiento: No hematuria.'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'Procedimiento: No cólicos.'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'Procedimiento: Infecciones de orina'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'Procedimientos:\n\n* G2 A0V2'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'Procedimientos:\n\n* Rx aparato urinario simple\n* ecografía transvaginal'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'Procedimiento: Rx.'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'Procedimiento: ecografía transvaginal con litiasis intravesical, no móvil y con el antecedente quirúrgico referido, se sospecha desde el inicio la presencia de cuerpo extraño intravesical por probable pérdida de material utilizado en la cirugía.'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'Uretrocistoscopia, TC pélvico'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'Procedimiento: cistoslirectomía, cistogasomectomía'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'Procedimientos:\n\n* Tras buena evolución\n* paciente está asintomática\n* desaparecieron las infecciones de orina de repetición\n* episodio aislado'
# [18/250] es-S0004-06142008000700003-1.txt | 28.92s | 15 chunks | 1 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'Procedimiento: EPOC'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'Procedimiento: Entrevista'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'Procedimiento: No factores ambientales de riesgo ni antecedentes familiares.'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'Procedimiento: Uretrorragia, imposibilidad para la micción.'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'Procedimiento: sondaje urinario, talla suprapúbica, estudio.'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'Ecografía, divertículo único, tamaño similar a vejiga, imágenes polipoideas parietales menores de 2-3 cm, neoplasia vesical.'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'Ureterotomía, cistoscopia'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'Procedimiento: análisis inmunohistoquímico, vimentina, actina.'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'Cistectomía parcial, diverticulectomía, leiomiosarcoma de bajo grado.'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'Procedimiento: Marcado pleomorfismo celular.'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'Procedimiento: Focos de necrosis intratumoral, imágenes de necrosis celular aislada.'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'Procedimiento: Extensas áreas de cambio mixoide.'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'Procedimiento: Intensa inflamación intra y peritumoral.'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'Infiltración de todo el espesor de la pared diverticular hasta el tejido adiposo peridiverticular provocando reacción fibrosa peritumoral.'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'Procedimiento: Márgenes quirúrgicos libres de tumor.'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'Inmunohistoquímica\nVimentina\nActina\nDesmina\nEMA\nCitoqueratinas de Alto Peso Molecular'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'Leiomiosarcoma de bajo grado con infiltración de todas las capas, tratamiento complementario.'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'TAC toracoabdominal, gammagrafía ósea, RMN pélvica'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'Radioterapia locorregional y quimioterapia complementaria.'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'Procedimiento: radioterapia locorregional a dosis de 57 Gy.'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'ifosfamida-adriamicina'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'Cistoscopia, citología urinaria, TAC toraco-abdomino-pélvico'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: 'Procedimiento: REVISIONES'
# [19/250] es-S0004-06142009000400011-1.txt | 43.43s | 23 chunks | 8 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'Procedimiento: Hombre de 42 años, quien consultó por masa y dolor testicular derecho, de 2 meses de evolución, que aumentó en forma progresiva.'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'Procedimiento: N/A'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'Procedimiento: ecografía testicular'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'Procedimiento: orquidectomia'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'Procedimiento: histopatologico, infiltración, neoplasia, maligna, hematolinfoide, células, pequeño, tamaño, irregulares, citoplasma, escaso, angiotropismo, necrosis, áreas.'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'Procedimiento: Ki67, ACL, CD3, TdT, CD30, ALK, bcl2, bcl6, CD10.'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'Linfoma no Hodgkin T periférico no especificado.'
# [20/250] es-S0004-06142010000100015-1.txt | 15.69s | 7 chunks | 1 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'Procedimiento: ecografía renal'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'Ecografía: lesión quística compleja, multiseptada, de contornos polilobulados, de 11 cm de diámetro y con calcificaciones puntiformes periféricas, que ocupa la práctica totalidad de dicho riñón.'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'Procedimiento: T.C. abdomino-pélvico'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'Procedimiento: Ausencia de adenopatías retroperitoneales.'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'Procedimiento: nefroma multilocular quístico, carcinoma de células renales quístico'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'Renograma isotópico con Tc-99m. Riñón izquierdo de inferior captación y funcionalismo, con imagen fría central que podría corresponder a lesión ocupante.'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'Procedimiento: Función del R.I.\nProcedimiento: Gammagrafía ósea.'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'Nefrectomía'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'Procedimiento: Nefroma quístico multilocular'
# [21/250] es-S0210-48062003000900009-1.txt | 18.92s | 9 chunks | 3 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'Procedimiento: Exploración testicular derecha, prueba de coloración de la sangre testicular, prueba de función testicular, ultrasonografía testicular, biopsia testicular.'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'Procedimiento: Presenta, síndrome, constitucional.'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'Procedimientos:\nFiebre en picos de hasta 39ºC, sudación profusa, no-clínica miccional, nohematuria.'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC, inhaladores, oxígeno crónico domiciliario.'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'Exploración física, crepitantes en la auscultación pulmonar, edemas en miembros inferiores, no adenopatías, hematomas en ambos miembros superiores.'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'Exploración genital en el hemiescroto derecho, edema de cubiertas, aumento de la consistencia del epidídimo y del teste, desaparición del surco epidídimo testicular, sin signos de fluctuación ni de abcesificación.'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'Procedimiento: Tacto rectal. Procedimiento: Próstata. Procedimiento: Adenomatosa. Procedimiento: Grado II-III/IV.'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'Procedimiento: Analítica, Hemoglobina, Plaquetas, Leucocitos.'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'Procedimiento: Coagulación'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'Lactato deshidrogenasa (LDH) elevada, BHCG, CEA, AFP, función renal, hepática y pancreática normales.'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'Radiografía de tórax, radiografía de abdomen.'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'Procedimiento: Ecografía renal y vesical, próstata.'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'Ecografía testicular, testículo izquierdo normal, testículo derecho se distingue hasta tres áreas heterogéneas con disminución de la ecogenicidad, sin calcificaciones que afectan a polo superior, inferior y epidídimo, no-hidrocele.'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'Procedimiento: orquiectomía radical por vía inguinal.'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'Procedimiento: Anatomía patológica, macroscópica, tumor testículo, masa blanquecina, lobulada, corte, masa, infiltra, albugínea, epidídimo, capa externa, borde hiliar.'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'Procedimiento: Microscopía, linfoma difuso B, células grandes, índice de proliferación, marcadores CD 20+.'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'TAC de cuerpo completo de estadiaje, apreciándose esplenomegalia homogénea, adenopatías retroperitoneales aisladas inferiores a 1 cm, como hallazgos destacables.'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'Procedimientos: exploración post-quirúrgica, sudación profusa, fiebre en picos, astenia, edemas de los miembros inferiores.'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'Procedimiento: Analíticamente persiste.'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'Procedimiento: biopsia de medula ósea'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'Procedimiento: plasmocitosis intersticial, infiltración por células linfoblásticas.'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'Procedimiento: Frotis sanguíneo'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'Procedimiento: test de Coombs directo, agregación plaquetaria, inmunoglobulina G.'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'fibroscopia,lesión polipoidea,seno piriforme.'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'TAC cervical'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab, CHOP'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'Procedimiento: R-CHOP'
#   [chunk 28/29 | chars 3813-3891]
# ...
#   [chunk 6/22 | chars 726-884]
#   RAW: 'Procedimiento: balance articular de caderas.'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'Procedimiento: balance muscular, escala de Daniels, 5/5 global bilateral.'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'Procedimientos:\nValleix, Fabere, Lasegue, Bragard'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'Procedimiento: Tampoco presenta dolor a la palpación en la cintilla iliotibial y el test de Ober es negativo.'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'Exploración de la marcha, ausencia de claudicación, apoyo monopodal alterno derecho-izquierdo, Trendelenburg negativo.'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'Procedimiento: Presenta dolor para la marcha con flexión forzada de cadera y rodilla.'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'La radiología simple anteroposterior (AP) presentó una deformidad en forma de joroba en región cérvico-cefálica femoral derecha.'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'Procedimientos:\n1. Hemograma\n2. Bioquímica\n3. Hormonas tiroideas\n4. Anticuerpos\n5. Reactantes de fase aguda'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'Resonancia magnética de cadera, leve alteración subcondral, edema óseo en cadera derecha, irregularidad cortical, leve sinovitis en interlínea articular, distensión de la bursa ilio-psoas.'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'Procedimiento: radiografia de cabeza femoral'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'Artrografía, pinzamiento interlinea articular antero-superior y posteroinferior, collar osteofitario femoral incipiente con lesiones subcondrales antero-superiores de cabeza femoral y focos de edema en acetábulo anterosuperior.'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'Procedimiento: No se visualiza necrosis avascular ni lesiones en el labrum.'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'Procedimiento: visualización de una lesión quística yuxtaarticular en relación con trocánter mayor.'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'Procedimiento: diagnóstico de síndrome de pinzamiento femoroacetabular tipo LEVA (también conocido por CAM)\nProcedimiento: tratamiento con magnetoterapia (15 sesiones)'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: '"Tratamiento", "farmacológico", "asociación", "sulfato de glucosamina-condroitin sulfato", "oral", "400 mg", "cada", "12 horas", "durante", "3 meses", "antiinflamatorios", "no esteroideos", "demanda", "dolor"'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'Procedimiento: reposo deportivo, flexión de la cadera, rotaciones'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'Procedimiento: artroscopia'
# [245/250] es-S1888-75462015000400006-1.txt | 54.90s | 22 chunks | 0 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'Procedimientos:\n- Fractura de tercio medio de clavícula derecha\n- Fractura de arcos costales derechos'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'Procedimientos:\nradiografia, exploración clínica, exploración física, palpación, auscultación, percusión, movilidad, fuerza muscular, fuerza motora, fuerza sensitiva, reflejos, sensibilidad, coordinación, equilibrio, marcha, postura, gaita, función respiratoria, función cardiovascular, función digestiva, función renal, función hepática, función endocrina, función inmunológica, función neurológica, función psicológica, función social, función sexual, función intelectual, función educativa, función laboral, función familiar, función comunitaria, función espiritual, función religiosa, función cultural, función estética, función de comunicación, función de trabajo, función de juego, función de aprendizaje, función de crecimiento, función de desarrollo, función de reproducción, función de adaptación, función de respuesta al estrés, función de respuesta al cambio, función de respuesta al desafío, función de respuesta al riesgo, función de respuesta al daño'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'Procedimientos:\nradiografia simple de tórax\nfractura de arcos costales derechos cuarto y quinto\nfractura de tercio medio de la clavícula derecha con tercer fragmento\ntomografía axial computarizada'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'Procedimientos:\n\n* Analgesia\n* Antiinflamatorios no esteroideos\n* Colocación de vendaje\n* Consulta\n* Edematización\n* Pulsos periféricos\n* Auscultación cardiorrespiratoria\n* Ruidos cardíacos normales\n* Frecuencia normal\n* Soplos\n* Extratonos\n* Murmullo vesicular'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'La espirometría, el electrocardiograma y el ecocardiograma fueron normales; la analítica sanguínea mostró valores anormales de CHCM=31.4g/dl, neutrófilos=76.6%, linfocitos=16.4%, eosinófilos=0.9%, fibrinógeno=645mg/dl, GGT=52U/l y D-Dímero positivo.'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'axilar, cefálica, basílica, cubital, nervio cutáneo braquial medial, hiato basílico'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'Procedimientos:\n- Vendaje en ocho\n- Cabestrillo sencillo\n- Radiografías\n- Utrasonografía-Doppler seriadas de control\n- Tinzapaina sódica\n- Tratamiento con Tinzapaina sódica'
# [246/250] es-S1888-75462016000400180-1.txt | 46.80s | 7 chunks | 4 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'Procedimiento: Describir'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'Procedimiento: histerectomía'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'Procedimientos:\n\n* Valoración en Ginecología por osteoporosis densitométrica lumbar\n* Tratamiento con denosumab y suplementos de vitamina D\n* Hábitos tóxicos\n* Antecedentes personales ni familiares de fractura\n* IMC normal'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'Procedimiento: Consultó, dolor mecánico, pie izquierdo, inicio agudo, inflamación, causa desencadenante, AINEs, refractario.'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'Procedimiento: exploración, dolor a la movilización del antepié izquierdo.'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'Procedimiento: No se observaron alteraciones de la estática de pies.'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Procedimiento: Rx de pies'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'Procedimiento: RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo, RMN de pie izquierdo'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'Procedimiento: estudio analítico'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'Procedimiento: tratamiento con suplementos de vitamina D y denosumab.'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'Procedimientos:\n\n* Valorada\n* Servicio de Traumatología\n* tratamiento conservador\n* descarga\n* reposo relativo\n* AINEs\n* magnetoterapia'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'Procedimiento: radiografia lumbar, exploración clínica, tratamiento con SERMS (bazedoxifeno), suplementos de calcio con vitamina D.'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'Procedimiento: Rx, callo de fractura, fractura de estrés, previa, 2o MTT, fractura antiguo.'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'Procedimiento: RMN de pie izquierdo'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'Nueva densitometría ósea, T-score en columna lumbar de -3,5.'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'Procedimiento: radiografia'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'Las fracturas fueron tratadas con rehabilitación y descarga con mejoría progresiva.'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'Procedimiento: osteoporosis'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'Procedimiento: cambio de estación'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'Procedimiento: exploraciones, pruebas diagnosticas, intervenciones, tratamientos, cirugias, etc.'
# [247/250] es-S1889-836X2015000200005-2.txt | 56.83s | 20 chunks | 1 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'Procedimiento: Presentación de caso.'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'Procedimiento: revisión ambulatoria'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'Procedimientos:\n1. Fosfatasa alcalina (FA) total\n2. Fosfatasa alcalina (FA) ósea\n3. Paratohormona (PTH)'
#   [chunk 4/16 | chars 408-569]
#   RAW: '25-HCC, calcio total e iónico y otros parámetros bioquímicos rutinarios en suero, elemental y sedimento de orina.'
#   [chunk 5/16 | chars 570-697]
#   RAW: '"radiografia simple de columna", "gammagrafía con Tc99"'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'Procedimientos: exploración, prueba diagnóstica, intervención, tratamiento, cirugía.'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'La exploración física era anodina, salvo por debilidad muscular de predominio proximal.'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'Procedimientos: radiografia, exploración física, prueba de glucosa, prueba de fosfato, prueba de urina, prueba de proteína.'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'Procedimientos:\n- Aminoaciduria moderada\n- Glicina (x2)\n- Valina (x2)\n- Serina (x4)\n- Treonina (x4)'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'Procedimiento: FGF23'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Procedimientos:\n- Otros parámetros\n- Tabla 1.'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'Procedimiento: síndrome de Fanconi incompleto, hipofosfatemia grave, probable osteomalacia, TDF.'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'Procedimiento: Retirado, tratamiento'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'Procedimientos: suplementos de fósforo, 25-HCC, 1,25-dihidroxivitamina D (1,25 DHCC)'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'Procedimiento:'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'Procedimientos:\n\n* Retirada de TDF\n* Exploración\n* Prueba diagnóstica\n* Intervención\n* Tratamiento\n* Cirugía\n* Reabsorción de fosfato'
# [248/250] es-S1889-836X2015000400006-1.txt | 36.71s | 16 chunks | 1 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'Procedimientos:\nRadiografia de tórax, exploración física general, prueba de anticuerpos antinucleares, prueba de anticuerpos anticitoplasmáticos, prueba de anticuerpos antifosfolípidos, prueba de anticuerpos anticardiolipínicos, prueba de anticuerpos antifactor V Leiden, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C renal, prueba de anticuerpos antiproteína C'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Tiroiditis de Hashimoto.'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'Apendicectomía.'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'Procedimiento: Exfumadora'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'Procedimiento: No bebedora.'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'Procedimientos:\nradiografia'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'Procedimiento: episodios de anemia tras los 2 partos.'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'Cesárea y ligadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'Procedimientos:\n- Consulta\n- Exploración'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'Procedimiento: Menstruación'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'Procedimiento: No heces melénicas, palidez cutánea y mucosa.'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'Procedimientos:\nEpistaxis\nGingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'Procedimientos:\n\n* Analítica\n* Anemia\n* Hemoglobina\n* Trombopenia\n* Plaquetas'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'Procedimiento: Frotis sanguíneo con presencia de esquistocitos.'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'Procedimientos:\n- Exploraciones normales\n- Diagnóstico'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'Procedimiento: transfusión de concentrado de hematíes y plaquetas.'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'Procedimiento: Exploración, prueba diagnóstica, intervención, tratamiento, cirugía, etc.'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'Procedimiento: Posteriormente habla con lenguaje normal sin focalidad evidente.'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'Procedimiento: Estudio de hematología'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'Plasmaféresis'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'Procedimiento: ingreso en UCI'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'Procedimiento: Plasmaféresis'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'Procedimiento: Tratamiento'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'La paciente pesa 75 kgr.'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'Procedimiento: radiografia'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'Procedimiento: volumen a reinfundir'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'Procedimiento: Plasma fresco + 350 cc.'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'Procedimiento: albúmina humana al 20% + 1.400 cc.'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'Procedimiento: solución Dianeal® 1,36% de diálisis peritoneal.'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: '1a plasmaféresis en UCI se intenta implantar un catéter en yugular derecha, pero debido a su dificultad y exceso de sangrado, se coloca un catéter doble luz en femoral izquierda.'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE (Hospal®), PTE-2000'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'Procedimiento: heparina'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'Procedimiento: Pulsación arterial'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'Procedimientos:\n- UCI\n- sedada\n- constantes mantenidas'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: 'Procedimiento: 17 sesiones'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'Procedimiento: Incidencia de las mismas'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: '1. Procedimiento: Hipotensión y convulsiones importantes.\n2. Procedimiento: Diazepam.\n3. Procedimiento: Salino fisiológico.'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'Procedimiento: 16a'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'Procedimiento: test de aire, SET'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'Procedimiento: resto de las sesiones'
# [249/250] es-S2254-28842014000200009-1.txt | 79.12s | 40 chunks | 8 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Procedimiento: intervención, carcinoma seroso papilar, ovario izquierdo, ganglio de la cadena aorto-cava, estadio IIIC.'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'Procedimiento: quimioterapia adyuvante con carboplatino y paclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'Procedimiento: seguimiento'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'TAC: resección anterior de recto superior con biopsia intraoperatoria de una lesión hepática que confirmó la naturaleza metastásica.'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'Procedimiento: tratamiento, carboplatino, paclitaxel, CA 125'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'Procedimiento: exploración, prueba diagnóstica, intervención, tratamiento, cirugía, infusión, carboplatino.'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'Procedimiento: detención de la infusión, administración de corticoides'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'Procedimiento: desensibilización, enlentecimiento de la velocidad de infusión.'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'Procedimientos:\n- Disoluciones con concentraciones de 0,02, 0,2 y 2 mg/ml respectivamente.'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'Trabectedina, adriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'Procedimiento: Tras el tercer ciclo, se normalizaron los marcadores y se completó hasta el sexto, manteniéndose en estos momentos libre de enfermedad.'
# [250/250] es-S2340-98942015000100005-1.txt | 25.43s | 11 chunks | 0 menciones
#
# Predicciones guardadas en proctemist_llm_predictions.tsv
# Tiempo medio por archivo: 42.05s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd

def prf(tp, fp, fn):
    p = tp / (tp + fp) if (tp + fp) else 0.0
    r = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1

df_pred = pd.read_csv(PREDICTIONS_TSV, sep='\t')
df_gs = pd.read_csv(GS_TEST_TSV, sep='\t')
df_gs = df_gs[df_gs['filename'].isin(df_pred['filename'].unique())]

set_gs = set(zip(df_gs['filename'], df_gs['label'], df_gs['start_span'], df_gs['end_span']))
set_pred = set(zip(df_pred['filename'], df_pred['label'], df_pred['start_span'], df_pred['end_span']))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1 = prf(tp, fp, fn)

report = {'Estricta': {'tp': tp, 'fp': fp, 'fn': fn,
                       'precision': round(p, 4), 'recall': round(r, 4), 'fscore': round(f1, 4)}}

print(f'── ESTRICTA ── P={p:.4f} R={r:.4f} F1={f1:.4f} (TP={tp} FP={fp} FN={fn})\n')

thresholds = [0.0, 0.5, 0.8]
results = {t: {'tp': 0, 'fp': 0, 'fn': 0} for t in thresholds}

for filename in df_pred['filename'].unique():
    gs_ints = list(zip(df_gs[df_gs['filename'] == filename]['start_span'],
                       df_gs[df_gs['filename'] == filename]['end_span']))
    pred_ints = list(zip(df_pred[df_pred['filename'] == filename]['start_span'],
                         df_pred[df_pred['filename'] == filename]['end_span']))
    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )
    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi)
                matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ── P=0.1634 R=0.0282 F1=0.0481 (TP=84 FP=430 FN=2893)
#
# ── IoU ──
# IoU >= 0.0:  P=0.6459  R=0.1115  F1=0.1901  (TP=332 FP=182 FN=2646)
# IoU >= 0.5:  P=0.2724  R=0.0470  F1=0.0802  (TP=140 FP=374 FN=2838)
# IoU >= 0.8:  P=0.1965  R=0.0339  F1=0.0578  (TP=101 FP=413 FN=2877)
