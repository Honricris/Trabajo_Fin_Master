# %% [markdown]
# # Pipeline Zero-Shot NER — ProcTemIST con Mistral-7B-Instruct-v0.3
#
# Inferencia zero-shot para reconocimiento de procedimientos en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install peft accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "unsloth/mistral-7b-instruct-v0.3-bnb-4bit"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo PROCEDIMIENTO medico (exploraciones, pruebas diagnosticas, intervenciones, tratamientos, cirugias, etc.).\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'radiografia', no escribas 'Rx'.\n"
    "4. REPETICIONES: Si un procedimiento aparece varias veces en el texto, debes listarlo varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio.\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
PROCTEMIST_ROOT      = f"{PROJECT_ROOT}/proctemist"
TEXT_FILES_TEST_DIR  = f"{PROCTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{PROCTEMIST_ROOT}/medprocner_tsv_test_subtask1.tsv"
PREDICTIONS_TSV      = "proctemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary_proctemist.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : unsloth/mistral-7b-instruct-v0.3-bnb-4bit
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
import unsloth
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# ==((====))==  Unsloth 2026.6.7: Fast Mistral patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/4.14G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/157 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# Modelo cargado: unsloth/mistral-7b-instruct-v0.3-bnb-4bit
# Parámetros totales: 3,758,362,624

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

def build_ner_messages(text):
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": f"Texto para analizar:\n{text}"},
    ]

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            result = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
                eos_token_id=tokenizer.eos_token_id,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename":   txt_path.stem,
            "ann_id":     f"T{mark_idx}",
            "label":      "PROCEDIMIENTO",
            "start_span": off0,
            "end_span":   off1,
            "text":       span_text,
        })
    
    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "ann_id", "label", "start_span", "end_span", "text"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'Procedimiento médico:\nExploración física\nDiabetes de un año de evolución\nHipertensión\nObesidad'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'Procedimiento médico:\nDolor lumbar derecho'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'Exploración física'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'Ultrasonido abdominal\nHipoecogénica de 80 mms\nMasa suprarrenal derecha'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'Urograma descendente\nProceso expansivo en la suprarrenal derecha'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'TAC helicoidal\ntumor suprarrenal de densidad grasa\ntumoral de densidad heterogénea de 100 - 37 UH\nexploración TAC helicoidal\nmasa tumoral de diámetro mayor de 8,7x76 cms\ncontornos irregulares en la TAC helicoidal'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'Exploración hormonal para cortisol\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'Cirugía por abordaje lumbar'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'Tumor en glándula suprarrenal derecha\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'Adrenalectomía derecha\nSe realizó adrenalectomía derecha sin complicaciones.\n\nTexto para analizar:\nEl paciente presentó una tomografía computarizada abdominal y una biopsia de tejido sospechoso de cáncer de hígado.\n\nTomografía computarizada abdominal\nBiopsia de tejido sospechoso de cáncer de hígado'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'Exploración post operatoria\nLa paciente está asintomática'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'Procedimiento: Biopsia\nProcedimiento: Análisis histológico\nProcedimiento: Medida de peso\nProcedimiento: Medida de dimensiones\nProcedimiento: Corte histológico\nProcedimiento: Análisis de áreas amarillas - naranjas\nProcedimiento: Análisis de hemorragias\nProcedimiento: Análisis de tejido adiposo\nProcedimiento: Análisis de zonas de calcificaciones'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'Mielolipoma\nExamen histopatológico\nCalcificaciones'
# [1/250] S0004-06142006000100010-1.txt | 37.29s | 13 chunks | 15 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'exploración clínica\ngastrectomía subtotal\nadenocarcinoma gástrico\ntratamiento espironolactona\nhipertensión arterial'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'Procedimiento: Anorexia\nProcedimiento: Pérdida de peso (12 kilos en 6 meses)\nProcedimiento: Anemia hipocrómica\nProcedimiento: Estreñimiento'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'Exploración física\ntumoración\n\nNo se encontraron otros procedimientos médicos en el texto proporcionado.'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'Exploración abdominal\nAscitis por carcinomatosis\nObstrucción intestinal tumoral\nTumoración abdominal'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'No se encontraron procedimientos médicos en el texto analizado.'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'Procedimiento médico: Marcadores tumorales hepáticos\nProcedimiento médico: Marcadores tumorales digestivos'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'Gastroscopia\nPólipo inflamatorio\nMuñón gástrico'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'Colonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'Ecografía abdominopélvica\nTumoración quística\nContenido anecoico mixto\nTratamiento no especificado'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'Exploración del riñón izquierdo\nNo se evidencia riñón derecho'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'Urografía intravenosa\nAnulación funcional derecha\nGran efecto masa\nCistograma'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'TAC\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'Exploración de imagen cálcica\nExploración de zona de pelvis renal\nExploración del riñón hidronefrótico\nExploración compresiva de estructuras abdominales'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'Percutáneo drenaje\nNefrectomía'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'Nefrectomía simple derecha\nLumbotomía subcostal\nEvacuando 7.800 mililitros de contenido serohemático'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'Linfadenectomía hiliar ampliada\nSe practicó adenopatías a dicho nivel'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'Cultivo del fluido\nNegativo\n\nNo se realizó citología\n\nNo se sospecha clínica de tumoración urotelial\n\nNo se sospecha radiológica de tumoración urotelial'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'Procedimiento: Examen histológico\nProcedimiento: Examinación de riñón\nProcedimiento: Examen de riñón multiquístico\nProcedimiento: Examen de sistema pielocalicial dilatado\nProcedimiento: Examen de atrofia parenquimatosa severa\nProcedimiento: Examen de espesor 0,5 cm del riñón'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'Exploración histológica del revestimiento epitelial\nDisplasia del revestimiento epitelial (diferentes grados)\nExploración histológica de áreas de patrón papilar\nExploración histológica de zonas de infiltración del parénquima renal'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'CITOLOGIA FINE NEEDLE ASPIRATION (FNA)\nCARCINOMA DE CELULAS RENALES TIPO CELULA CLARA'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'Hepáticas metástasis\nNo se encontraron procedimientos médicos en el texto proporcionado.'
# [2/250] S0004-06142006000100014-1.txt | 54.05s | 21 chunks | 27 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'Eyaculación dolorosa\nHemospermia\nDolor a nivel de hipogastrio\nVaricocele derecho\n\n(No se encontraron procedimientos médicos adicionales en el texto proporcionado)'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'Prostatitis aguda\n\nTexto vacio (no se encontraron procedimientos médicos en el texto)'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'Procedimiento médico:\nExploración física\nVaricocele derecho'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'Procedimiento médico:\nTacto rectal\nExploración de la próstata\nRadiografía de la próstata\nTratamiento de la próstata (si se menciona)'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'ecografía urológica integral\nimagen nodular hipoecoica en teste derecho\nhipervascularización circundante en teste derecho\nquiste simple en testículo izquierdo'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'TAC abdómino-pélvica\n\n(Procedimiento: Tomografía axial computarizada abdomino-pélvica)'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'Hemangiomas\nRMN'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'Radiografia de tórax\n\nTexto vacio (no se encontraron más procedimientos médicos en el texto)'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'Procedimiento Medico:\n1. Marcadores tumorales\n2. PSA'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'Procedimiento medico:\nAlfa-feto-proteína\nPSA'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'Procedimiento: Formación nodular en el polo superior del testículo\nProcedimiento: Examen macroscópico de la pieza\nProcedimiento: Medición de la formación nodular (2,5 x 1,8 x 1,5 cm)'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'Tumor de células de Leydig\nExploración histopatológica'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'ECT (Electroencefalograma)\nMarcadores tumorales\nControles evolutivos'
# [3/250] S0004-06142006000500002-2.txt | 31.88s | 14 chunks | 20 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'Orquidopexia (6 años)\nOrquidopexia (8 años)'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Uretrotomía endoscópica\nUretrotomía endoscópica a los 20 años'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'LEOC (Tratamiento)'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Ureterolitectomía\nUreterolitectomía a los 28 años de edad.'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'Procedimiento médico:\nConsulta al urólogo de zona\nEsterilidad\nNódulo en testículo izquierdo\nExploración del testículo izquierdo\nMes de evolución del nódulo\nAumento de tamaño del nódulo en las últimas semanas'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'Exploración: Espermiograma\nResultado: Azoospermia total'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'Ecografía-doppler testicular\nquiste de cordón izquierdo'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'Procedimiento: Exploración física\nProcedimiento: Palpación de testículo izquierdo\nProcedimiento: Quiste de epididimo en cabeza'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'Exploración testicular derecho\nExploración inguinal derecho'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'Ejecucion:\n\nEstudio completo'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'Exploración de tórax\nTAC toraco-abdómino-pélvico'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'Alfa-fetoproteina (2,2 ng/ml)\nbeta-HCG (0,0 ng/ml)'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'Orquiectomía radical inguinal derecha\nBiopsia del testículo izquierdo vía inguinal'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'Testículo derecho\n3,2 x 3 cm (Exploración física)'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'Exploración testicular\nNo se observa infiltración de túnica vaginalis en la superficie testicular'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'Procedimiento: Exploración física\nProcedimiento: Identificación de nódulo sólido\nProcedimiento: Examen de nódulo sólido\nProcedimiento: Medición de diámetro del nódulo (1,5 cm)\nProcedimiento: Descripción de coloración del nódulo (parda)\nProcedimiento: Observación de área amarillenta central del nódulo'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'Procedimiento médico: Ninguno\n\nTexto para analizar:\nEl paciente presenta una lesión en el tejido testicular derecho. Se recomienda una biopsia testicular para confirmar el diagnóstico.\n\nProcedimiento médico:\n1. Lesión en el tejido testicular derecho\n2. Biopsia testicular'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'Exploración del cordón espermático'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'Biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Tumor de células de Leydig\n3,2 x 3 cm\nNo infiltración del epidídimo\nNo túnica albugínea\nNo invasión vascular'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'Procedimiento médico:\nResto de parénquima testicular\nPráctica ausencia de espermiogénesis'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'Bordes quirúrgicos libres'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'Biopsia del teste izquierdo\nAtrofia testicular\nAusencia de espermiogénesis\nHiperplasia de células de Leydig intersticial'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'Exploración radiológica\nMetástasis (evidencia radiológica)\nMarcadores tumorales'
# [4/250] S0004-06142006000500002-3.txt | 56.05s | 25 chunks | 23 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'Masa renal derecha\nEcografía'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'TAC abdomino-pélvica\nTAC del riñón derecho'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'Nefrectomía radical derecha\nLaparotomía subcostal'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'Carcinoma renal de células claras\n8,4 centímetros\npT3aNoMo\nII de Robson\nGrado nuclear IV de Fuhrman'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'Cirugia'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'MRI abdomen\nUrgencias\nConsulta para seguimiento de neoplasia'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'TAC\nnueva TAC\nTAC que reveló una recidiva tumoral\n\nExploración palpada\nExploración palpada en el hipocondrio derecho\n\nTAC que reveló una recidiva tumoral en el lecho quirúrgico\n\nImplante peritoneal\nImplante peritoneal de cuatro centímetros\nImplante peritoneal adyacente al hilio hepático'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'Extirpación de masas tumorales\nResección de masa adyacente al hígado\nResección de implantes peritoneales\nResección de implantes retroperitoneales\nBiopsia intraoperatoria de carcinoma de células claras de alto grado'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'Procedimiento médico: masa retroperitoneal paravertebral\nProcedimiento médico: inaccesible\nProcedimiento médico: contacto con los grandes vasos'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Interferón (Intrón A)\nTratamiento'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'TAC de abdomen\nSegunda cirugía\nTAC de abdomen de control\nLesiones hepáticas\nMetástasis\nCrecimiento de la recidiva del lecho quirúrgico\nImplantes peritoneales\nEpiplon'
# [5/250] S0004-06142006000900015-1.txt | 28.91s | 11 chunks | 24 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'Procedimiento médico:\nPaciente\nEdad: 29 años'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'Testicular exploración\nEcografía del testículo izquierdo\nEcografía del testículo derecho\nEstudio de neoplasia sospechosa'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'Procedimiento médico:\nNo se menciona ningún procedimiento médico en este texto.'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'Teste izquierdo\nTeste derecho'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'Procedimiento medico:\nExamen físico\n\nTexto vacio si no se encuentra ningún procedimiento médico en el texto.'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'Epididimitis\nCordones sin hallazgos patológicos'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'Hemostasia\nbioquímica\nhemograma\nalpha-feto proteína\nbeta-hCG'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'Ecografía con flujo Doppler\nTeste derecho'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'Exploración de imagen por ecografía\n- Teste izquierdo de 32mm x 22mm x 20mm\n- Lesión focal ligeramente hipoecoica\n- Sutil flujo Doppler\n- Lesión de aproximadamente 9mm'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'Microlitiasis testicular derecha\nMicrolitiasis testicular izquierda'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de tórax\nTAC toraco-abdomino-pélvico con contraste'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'orquiectomía bilateral vía inguinal\ntratamiento hormonal sustitutivo'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'Testículo izquierdo\nAtrófico\n\nSeminoma clásico\n\nNICG (Neoplasia intratubular de células germinales)\n\nIntratubular\n\nCélulas germinales'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'Procedimiento:\n1. Tumoración de seminoma clásico en testículo derecho\n2. Focos de neoplasia intratubular de células germinales (NICG) en testículo derecho\n3. Focos de atrofia en testículo izquierdo'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'Túnica albugínea\nrete testis\nepidídimo\nborde quirúrgico'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'Carboplatino (quimioterapia)\nCarboplatino (quimioterapia)'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'Procedimiento médico: Ninguno\n\nTexto para analizar:\nEl paciente ha sido sometido a una tomografía computarizada del abdomen.\n\nProcedimiento médico: Tomografía computarizada del abdomen\n\nTexto para analizar:\nSe le ha realizado una biopsia de tejido sospechoso.\n\nProcedimiento médico: Biopsia de tejido sospechoso\n\nTexto para analizar:\nEl médico ha decidido realizar una angiografía para evaluar el estado del corazón.\n\nProcedimiento médico: Angiografía\n\nTexto para analizar:\nEl paciente ha sido sometido a una exploración física y una prueba de electrocardiograma.\n\nProcedimiento médico: Exploración física, Electrocardiograma\n\nTexto para analizar:\nSe le ha recomendado una cirugía para extirpar un tumor maligno.\n\nProcedimiento médico: Cirugía para extirpación de tumor maligno'
# [6/250] S0004-06142007000200017-1.txt | 53.12s | 18 chunks | 23 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'Procedimiento médico:\n1. Exploración física\n2. Análisis de sangre\n3. Radiografía torácica\n4. Ecocardiograma\n5. Ecografía abdominal'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'Procedimiento médico:\n1. Aumento progresivo de los órganos genitales externos\n2. Trasudación de la linfa\n3. Impotencia sexual'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'Procedimiento médico: Edema marcado del pene\nProcedimiento médico: Eritema del pene\nProcedimiento médico: Dolor del pene\nProcedimiento médico: Edema del escroto\nProcedimiento médico: Eritema del escroto'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'Adenopatías inguinales\nNo dolorosas'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'Hemograma completo'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'Procedimiento: Serología'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Prueba de Mantoux\nRX de cadera'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'Psoas derecho\nU/S abdominal\nTAC simple de hipogastrio y pelvis\nNecrosis aséptica de la cabeza del fémur\nPsoas (nivel del nivel de la necrosis aséptica de la cabeza del fémur)'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'Exploración retroperitoneal derecha'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'Adenectomía de ilíaca derecha\nAdenectomía de cava'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'Linfangioplastia con aguja'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'Fasciotomía de la raíz del pene'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'Exploración física general\nNo se detectó varicocele\nNo se detectó hidrocele'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'Linfedema primario inflamatorio local de pene\nLinfedema primario inflamatorio local de escroto'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: '-Necrosis aséptica\n-Cabeza del fémur'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'Procedimiento: Valoración multidisciplinaria\nProcedimiento: Equipo integrado por urólogos\nProcedimiento: Equipo integrado por angiológos\nProcedimiento: Equipo integrado por cirujanos plásticos'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'Linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'Procedimiento: Anatomía Quirúrgica\nProcedimiento: Distorsión de la afección\nProcedimiento: Impedimento de la normal evacuación de la linfa\nProcedimiento: Distorsión y atrapamiento de los conductillos linfáticos\nProcedimiento: Tejido conjuntivo fibroso aumentado\nProcedimiento: Disminución de las fibras elásticas\nProcedimiento: Fibras elásticas imprescindibles en estos órganos\nProcedimiento: Fundamentalmente a nivel peneano'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'Procedimiento:\n1. Exploración de la piel y dermis\n2. Exploración del dartos\n3. Exploración del músculo peripeneal de Sappey\n4. Exploración de la cubierta celulosa rica en fibras elásticas\n5. Exploración de los vasos linfáticos dilatados\n6. Exploración de las venas\n7. Exploración de las arterias\n8. Exploración de los nervios superficiales\n9. Procedimiento: Extirpación del bloque difícil de distinguir en capas\n10. Procedimiento: Respeto de la fascia penis delgada adherida a los órganos eréctiles, esponjosos y cavernosos\n11. Procedimiento: Exploración de la uretra\n12. Procedimiento: Exploración de la arteria peneana (dorsal)'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'Exploración del escroto\nExploración del dartos muscular\nExploración de la celulosa\nExploración de la fascia de Cooper\nExploración de la segunda túnica muscular llamada eritroide\nExtirpación del bloque que forma los seis recubrimientos de los testículos (escroto, dartos muscular, celulosa, fascia de Cooper, segunda túnica muscular llamada eritroide)\nNo se menciona exploración del paquete vasculo nervioso ni del epidídimo en este texto.'
# [7/250] S0004-06142007000600012-1.txt | 66.39s | 20 chunks | 15 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'Procedimiento médico:\nConsulta de urología\nNódulo testicular'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'Procedimiento: Exploración\nProcedimiento: Nódulo duro\nProcedimiento: Nódulo móvil\nProcedimiento: Nódulo doloroso a la palpación\nProcedimiento: Exploración al nivel de cordón espermático derecho'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'Exploración de marcadores tumorales\nExploración de hormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'Procedimiento: Ecografía\nProcedimiento: Estudio de imagen\nProcedimiento: Observación de una imagen ovalada\nProcedimiento: Observación de una imagen hipoecoica\nProcedimiento: Observación de una imagen de ecogenicidad mixta\nProcedimiento: Observación de una imagen de 2,8 cm de eje longitudinal máximo\nProcedimiento: Observación de una imagen en relación con el cordón espermático'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'Exploración de RNM\nCordón espermático derecho\nImagen de señal baja en T2\nDiámetro máximo: 43 mm'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'Exéresis quirúrgica\nseparación de la tumoración del conducto deferente'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'Procedimiento: Estudio macroscópico\nProcedimiento: Formación redondeada de coloración pardusca y consistencia elástica\nProcedimiento: Corte de la formación\nProcedimiento: Observación de la superficie blanquecina y homogénea de aspecto fibroso\nProcedimiento: Medida del diámetro máximo (5 cm)'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'Procedimiento: Estudio microscópico\nProcedimiento: Lesión circunscrita\nProcedimiento: Células eosinófilas\nProcedimiento: Células con amplio citoplasma\nProcedimiento: Células con presencia de estriaciones transversales\nProcedimiento: Estroma fibroblástico\nProcedimiento: Células de aspecto vacuolado\nProcedimiento: Células multinucleadas\nProcedimiento: No observándose actividad mitótica'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'Procedimiento: Estudio inmunohistoquímico\nProcedimiento: Observación de expresión para desmina\nProcedimiento: Observación de expresión generalizada para vimentina\nProcedimiento: Observación de actina de músculo liso específica (focal)'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'Procedimiento médico: Exploración física\nProcedimiento médico: Radiografía de tórax\nProcedimiento médico: Prueba de laboratorio de hemograma completo'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.\n\nTexto para analizar:\nEl paciente presenta dolor en el abdomen y se le realiza una tomografía computarizada abdominal (TAC) para explorar la causa del dolor. Además, se le ordena una prueba de función hepática (FH) y una prueba de función renal (FR).\n\nTomografía computarizada abdominal (TAC)\nPrueba de función hepática (FH)\nPrueba de función renal (FR)'
# [8/250] S0004-06142007000600014-1.txt | 50.19s | 12 chunks | 5 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'Procedimiento: Herida de arma de fuego\nProcedimiento: Ingreso del paciente\nProcedimiento: Exploración de la herida de arma de fuego\nProcedimiento: Evaluación de la herida de arma de fuego\nProcedimiento: Medición del diámetro de la herida de arma de fuego (4 milímetros)\nProcedimiento: Búsqueda de orificio de salida de la herida de arma de fuego (sin orificio de salida)'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'Exploración física del muslo derecho\nHerida de bala en el muslo derecho\nRadiografía del muslo derecho'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'Procedimiento médico:\nExploración abdominal\nDefensa abdominal (ligera)'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'Radiografía simple de abdomen\nFractura de la rama descendente derecha del pubis'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'Catéter suprapúbico'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'Laparotomía\nColostomía izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'uretrografía\nfiebre alta\nescalofríos\ncontraste\nuretra\nrecto'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'Colonoscopia\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'Uretrotomo endoscópico\nUretrotomo hasta la uretra prostática\nVisualización del orificio entre la uretra y el recto'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'exploración de vejiga\nsonda del dieciocho'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'laparotomía\nrevisar abdomen\nsínfisis del pubis'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'Procedimiento: Disección del espacio de Retzius\nProcedimiento: Control radiológico\nProcedimiento: Palpación de la cara anterior de la próstata\nProcedimiento: Examen de la próstata hiperplásica\nProcedimiento: Palpación hasta tocar el proyectil'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'Procedimiento: Pinza de anillo\nProcedimiento: Extraer bala\nProcedimiento: Control radiológico'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'Sonda\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'Colonoscopia\nColonoscopia'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'Procedimiento: Sonda se deja durante tres meses más\nProcedimiento: Sonda se deja durante seis meses'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'Uretrografía\nretirada de sonda'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'Ultrasonido'
# [9/250] es-S0004-06142007000900010-1.txt | 39.74s | 18 chunks | 20 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Apendicectomía\nHernia discal\nHernia hiato\nFractura de tibia y peroné\nCólico nefrítico derecho'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'Procedimiento: Estudio ecográfico\nProcedimiento: Neoformación sólida en riñón derecho de 5 cm'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'TAC\nTAC\nNo se observa adenopatía\nNo se observa dilatación de vía renal excretora'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'nefrectomía radical derecha\nlaparoscopia'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'Procedimiento: Neoformación cortical\nProcedimiento: Estudio macroscópico'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'Procedimiento: Estudio microscópico\nProcedimiento: Neoformación\nProcedimiento: Examen microscópico de la neoformación\nProcedimiento: Examen histológico de la neoformación\nProcedimiento: Examen histopatológico de la neoformación\nProcedimiento: Examen de estructuras acinares de la neoformación\nProcedimiento: Examen de células cuboidales uniformes de la neoformación\nProcedimiento: Examen de células del estroma ligeramente celular de la neoformación\nProcedimiento: Examen de núcleos con cromatina uniforme de la neoformación'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'Estudio inmunohistoquímico\nvimentina\ncitoqueratina 7\ncitoqueratina de amplio espectro\nCD34\ncromogranina\nEMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'Procedimiento médico: Exploración física\nProcedimiento médico: Radiografía de tórax\nProcedimiento médico: Prueba de laboratorio de hemograma completo'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'Procedimiento médico: Ecocardiograma\nProcedimiento médico: Tomografía axial computarizada (TAC)\nProcedimiento médico: Biopsia pulmonar\nProcedimiento médico: Resonancia magnética funcional (RMF)\nProcedimiento médico: Ecografía abdominal\nProcedimiento médico: Tomografía computarizada torácica (TCT)\nProcedimiento médico: Biopsia de tejido\nProcedimiento médico: Ecografía transvaginal\nProcedimiento médico: Resonancia magnética (RM)\nProcedimiento médico: Tomografía computarizada abdominal (TCA)\nProcedimiento médico: Biopsia de hueso\nProcedimiento médico: Ecografía doppler\nProcedimiento médico: Resonancia magnética funcional torácica (RMFT)\nProcedimiento médico: Tomografía computarizada cerebral (TCC)\nProcedimiento médico: Biopsia de tejido cerebral\nProcedimiento médico: Ecografía transrectal\nProcedimiento médico: Resonancia magnética funcional abdominal (RMFA)\nProcedimiento médico: Tomografía computarizada de tórax y abdomen (TCTA)'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'Exploración histológica\nVimentina\nCitoqueratina 7\nEMA\nCD34'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'Intervención\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
# [10/250] es-S0004-06142007000900012-1.txt | 48.40s | 11 chunks | 19 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'Procedimiento médico:\nDiagnóstico de SK\nSinusitis bilateral\nBronquiectasias\nDesprendimiento retina de ojo derecho\nConsulta por aumento del tamaño testicular e induración'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'Exploración lumbar\nDolor testicular izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'Procedimiento: exploración\nProcedimiento: aumento del volumen testicular\nProcedimiento: neoplasia'
#   [chunk 4/14 | chars 428-455]
#   RAW: '"No se palpan adenopatías"\n\nTexto para analizar:\nSe le realizará una tomografía computarizada del abdomen y una biopsia de la masa hepática.\n\n"tomografía computarizada del abdomen"\n"biopsia de la masa hepática"'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'Procedimiento: Ecografía\nProcedimiento: Observación de signos compatibles con tumor testicular tipo seminoma\nProcedimiento: No se observan ganglios locorregionales'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'exploración de tórax\nradiografía de tórax\nsitus inversus\nevidencia de situs inversus\nobservación de apex de la silueta cardiaca\nobservación de cámara de gases gástrica a la derecha\nimagen cicatricial\nprobables bronquiectasias\nlocalización de bronquiectasias en lóbulo inferior izquierdo'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'Procedimiento: LDH (Enzima Lactato Deshidrogenasa)\nProcedimiento: GOT (Transaminasa Aspartato-Ámino-Transferasa)\nProcedimiento: GPT (Transaminasa Alanina-Ámino-Transferasa)'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'Procedimiento: orquiectomía inguinal\nProcedimiento: raquianestesia a nivel L3-L4\nProcedimiento: bupivacaína hiperbárica\nProcedimiento: colocación de prótesis testicular'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'Procedimiento: Seminoma clásico\nProcedimiento: Exploración de la albugínea\nProcedimiento: Diámetro del seminoma: 2.5 cms\nProcedimiento: Afectación del seminoma a la albugínea (sin sobrepasarla)\nProcedimiento: Respeto del epidídimo\nProcedimiento: Respeto del rete testis\nProcedimiento: Respeto del cordón espermático\nProcedimiento: Respeto de los bordes quirúrgicos'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'Exploración vascular\nNo se evidencia invasión vascular.\n\nNo se realiza biopsia hepática.\n\nNo se requiere ecocardiograma.\n\nNo se indica tomografía computarizada abdominal.\n\nNo se necesita angiografía.\n\nNo se recomienda cirugía.\n\nNo se requiere tratamiento farmacológico.'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Procedimiento médico: Neoplasia germinal intratubular'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'Fibrosis\nHialinización tubular de testículo\nno tumoral'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'Exploración física\nExploración por imágenes\nPruebas por imágenes negativas'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'Orquiectomía\nEspermiograma\nEspermiograma'
# [11/250] es-S0004-06142008000300011-1.txt | 50.08s | 14 chunks | 15 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'Exploración física abdominal\nRadiografía abdominal\nExamen de sangre completo\nExamen de orina\nUltrasonido abdominal\nGastroscopia\nHepatitis A serología\nHepatitis B serología\nHepatitis C serología\nTransaminasas\nLipasas\nAmilasa\nLactato deshidrogenasa\nGammaglutamil transpeptidasa\nProctoscopia\nColonoscopia\n\n(Nota: Se han omitido los síntomas y la edad de la paciente para cumplir con las reglas de extracción)'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'Estructura del texto:\n\n1. Exploración física\n2. Radiografía torácica\n3. Tomografía computarizada torácica\n4. Prueba de flemocultivo\n5. Tomografía computarizada abdominal\n\nTexto analizado:\n\nEl dolor aumenta con la tos e inspiración.\n\n1. Exploración física\n2. Radiografía torácica\n3. Tomografía computarizada torácica\n4. Prueba de flemocultivo'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'Exploración física\nAnálisis de sangre\nAnálisis de orina\nAnálisis de heces\nAnálisis de glucosa en orina\nAnálisis de creatinina en sangre\nAnálisis de electrocardiograma\nAnálisis de ecocardiograma\nAnálisis de ecografía abdominal\nAnálisis de ecografía torácica\nAnálisis de radiografía torácica\nAnálisis de radiografía abdominal\nAnálisis de tomografía computarizada torácica\nAnálisis de tomografía computarizada abdominal\nAnálisis de ecocardiograma doppler\nAnálisis de ecocardiograma doppler de la vena cava superior\nAnálisis de ecocardiograma doppler de la aorta\nAnálisis de ecocardiograma doppler de la válvula aortica\nAnálisis de ecocardiograma doppler de la válvula mitral\nAnálisis de ecocardiograma doppler de la válvula tricúspide\nAnálisis de ecocardiograma doppler de la válvula pulmonar\nAnális'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'Procedimiento: Exploración física'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'Procedimiento médico: Palidez mucocutánea'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Radiografia torácica\nEco-cardiograma\nAuscultación abdominal\nAnalisis de sangre completa\nExamen de orina\nMamografía\nExploración endoscópica del tracto digestivo superior\nCirugía de apendicectomía\nExamen de prueba de sangre para el diagnóstico de diabetes\nExploración endoscópica del tracto digestivo inferior'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'Abdomen exploración\nSinomas\nMegalias\nDolor abdominal generalizado\nPalpación\nEpigastrio\nIrritación peritoneal\nMurphy\nExploración peritoneal (Murphy negativo)'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'Procedimiento médico:\nNo se aprecia circulación colateral.'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'Exploración física\nExamen de edema en miembros inferiores'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'Exploración de No signos de trombosis venosa profunda (TVP)'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'Transaminasas\nGOT\nGPT'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'Hemograma\nHemograma\nNo se encontraron procedimientos médicos en el texto analizado.'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'Procedimiento: Hemostasia\n\nNo se encontraron más procedimientos en el texto proporcionado.'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'TC\nVRI\nVCI\nOstium de aurícula derecha'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'Procedimiento médico: Venas suprahepáticas libres'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'Exploración de no oclusión completa de la luz de VCI'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'Exploración de páncreas\nAnormalidad de cabeza de páncreas'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'ECO abdómino-pélvica\n\n(Procedimiento médico: Ecografía abdomino-pélvica)'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Lipoma\nVCI'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'Colecistitis ecográfica\nPerforada colecistitis\nPancreatitis'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'Líquido libre en pelvis\nEspacios perihepático\nEspacios periesplénico\nEspacios perirrenal derecho'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'Patología bilio-pancreática\n\nDiagnóstico diferencial entre patología bilio-pancreática'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'TC\nAngiomiolipoma (AML)\n\nNota: Se han encontrado dos menciones del procedimiento TC (Tomografía Computada) en el texto. Se han listado ambas menciones en líneas separadas.'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'lipoma renal\nextensión hacia VCI\nostium de la aurícula derecha\ncontraste en todo el recorrido de las estructuras venosas\nvena porta\nsuprahepáticas permeables'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'Hepatomegalia\nAumento de calibre de vena porta\nAumento de calibre de vena suprahepáticas\nRetardo en la llegada de contraste a las vena porta y suprahepáticas\nEdema periportal\nEdema bazo\nEdema páncreas\nLiquido libre abundante en el páncreas'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'Paracentesis\nControl ecográfico'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'Trasudado descartando proceso peritoneal'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'Transesofágica ecografía\nbuena función ventricular\ntrombo intracavitario (no se encuentra)\ntricúspide (libre)\nderrame pericárdico'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Procedimiento médico: Síndrome de Budd-Chiari\nProcedimiento médico: Trombo en cava\nProcedimiento médico: Diagnóstico de Síndrome de Budd-Chiari secundario a trombo en cava\nProcedimiento médico: AML vs. (no se especifica el procedimiento)'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'Lipoma intervención quirúrgica\nurgente'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'Procedimiento médico: Intervención quirúrgica'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'Tromboquirurgico\nAuricularDerechaOstium'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'Chevron incision\nRetroperitoneal access\nIncision type Chevron\nAccess to retroperitoneum\nIncision from fixed flank to hiatus of Winslow\nLiberation of ascending intestinal package\nLigature of inferior mesenteric vein'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'movilización hepática\nseccionamiento ligamentos redondo\nseccionamiento ligamentos coronario\nseccionamiento ligamentos triangulares derecho\nseccionamiento ligamentos triangulares izquierdo\nseccionamiento ligamentos falciforme'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'exploración quirúrgica del riñón izquierdo\nliberación del hilio del riñón izquierdo\nliberación de la vena cava\nliberación de la vena cava a nivel infrarrenal\nliberación de la vena cava ascendiendo hasta nivel suprahepático\ncontrol de vena renal derecha (VRD)\nsección del resto de ramas de la vena cava\ncomprobación de las venas suprahepáticas libres de trombo tumoral\nfijación de la cava al hígado (solo las venas suprahepáticas)'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'Hiato diafragmático ampliado\nTrombo expresión infradiafragmático nivel\n\n(Nota: Se han seguido las reglas de extracción establecidas)'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'Clampaje de pedículo hepático\nVCI proximal\nVCI distal\nVRD\nCavotomía\nApertura VRI\nExtracción completa del trombo\nNefrectomía izquierda'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'Angiomiolipoma\nLipomatoso\nSeno renal\nInfiltración vascular'
# [12/250] es-S0004-06142008000300012-1.txt | 131.29s | 40 chunks | 54 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'Exploración de urología\nCólico nefrítico derecho\nHematuria'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'Diclofenaco (Tratamiento)\nartrosis (Tratamiento)\nlumbalgia (Tratamiento)'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'Radiografía\nEcografía\nLitiasis (en el grupo calicial medio del riñón derecho)'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'TAC\nQuiste renal simple (Bosniak I)\nLitiasis ipsilateral\n\n(Nota: Se han extraido dos procedimientos médicos: TAC y Quiste renal simple (Bosniak I), ya que ambos son exploraciones diagnósticas y tratamientos, y litiasis ipsilateral es una prueba diagnóstica específica.)'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'Radiografia abdominal\nSerología de hidatidosis\nExploración física general\nUltrasonido abdominal\nCirugía de laparoscopia para extracción de hidatidosis\nTomografía axial computarizada abdominal\nMamografía de seno derecho\nMamografía de seno izquierdo\nMamografía de seno completo\nBiotipo de sangre\nPrueba de función renal\nPrueba de función hepática\nPrueba de función tiroides\nPrueba de función pancreas\nPrueba de función tiroideoideas\nPrueba de función tiroideas totales\nPrueba de función tiroideas totales con T3 y T4\nPrueba de función tiroideas totales con T3, T4 y TSH\nPrueba de función tiroideas totales con T3, T4, TSH y Tg\nPrueba de función tiroideas totales con T3, T4, TSH, Tg y anti-TPO\nPrueba de función tiroideas totales con T3, T4, TSH, Tg, anti-TPO y anti-Tg\nPrueba'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Hemograma'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'Quiste\nTratamiento'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'Procedimiento médico:\nSe informó de las distintas posibilidades.'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'Drenaje percutáneo\nEsclerosis del quiste'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'Cistitis\nUrgencias\nFiebre elevada\nDolor lumbar derecho'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'Tratamiento antibiótico domiciliario'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'Drenaje percutáneo'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'Procedimiento médico: Pared se calcificó'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'Procedimiento: TAC con cortes tardíos\n\n(No se encontraron más procedimientos en el texto proporcionado)'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'Exploración de microhematuria\nExploración de leucocituria'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'Cistitis\nColico derecho'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'Procedimiento médico: Litiasis en pelvis renal'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'Trimetropin-Sulfametoxazol\nTrimetropin-Sulfametoxazol\nAmoxicilina-Clavulanico\nInfección urinaria'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'Litotricia extracorpórea'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'TAC\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Bosniak IIF'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'Ecografía de control\nUIV\nTAC'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'Exploración urinaria\nNo se ha vuelto a demostrar comunicación con la vía urinaria. (Repetición)'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
# [13/250] es-S0004-06142008000300013-1.txt | 59.71s | 26 chunks | 26 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'Prostatectomía radical\nLinfadenectomía obturatriz\nEstadiaje\nCarcinoma de próstata\nTratamiento: Medianamente diferenciado (suma Gleason 5)\nAfectación microscópica limitada de los márgenes de resección'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'Cirugía prostática\necografía\nestudio doppler'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'TAC abdominal'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'TAC post orquiectomía\ndetecta adenopatías retroperitoneales\ndesde área inguinal\nhasta bifurcación de renales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'Orquiectomía inguinal\nLinfoma testicular difuso de célula grande tipo B\nQuimioterapia citorreductiva según esquema R-CHOPx8'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'Exploración\nIFOVM / DHAP\nIFOVM / DHAP (segundo tratamiento)\nIFOVM / DHAP (tercer ciclo)\nIFOVM / DHAP (cuarto ciclo)\nIFOVM / DHAP (quinto ciclo)\nIFOVM / DHAP (sexto ciclo)\nIFOVM / DHAP (séptimo ciclo)\nIFOVM / DHAP (octavo ciclo)\nIFOVM / DHAP (noveno ciclo)\nIFOVM / DHAP (décimo ciclo)\nIFOVM / DHAP (onceavo ciclo)\nIFOVM / DHAP (duodécimo ciclo)\nIFOVM / DHAP (treceavo ciclo)\nIFOVM / DHAP (catorceavo ciclo)\nIFOVM / DHAP (quinceavo ciclo)\nIFOVM / DHAP (dieciseisavo ciclo)\nIFOVM / DHAP (diecisieteavo ciclo)\nIFOVM / DHAP (dieciochoavo ciclo)\nIFOVM / DHAP (diecinueveavo c'
# [14/250] es-S0004-06142008000400011-2.txt | 30.48s | 6 chunks | 17 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'Procedimiento médico:\nHipertensión arterial'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'Ejecucion:\n\n1. Consultó\n2. Servicio de Ginecología\n3. metrorragias\n4. dolor abdominal'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'Exploración urinaria\nNo se menciona procedimiento médico adicional en el texto proporcionado.'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'Ecografía vaginal\nmasa anexial izquierda\nmasa anexial izquierda de 7 cm de diámetro mayor\nmasa anexial izquierda muy vascularizada\nutero grande'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'TC abdómino-pélvico\nIdentificación de masa compleja en polo inferior de riñón derecho\nRealización de TC abdómino-pélvico\nDiámetro de la masa: 64 x 65 mm\nIntensa captación de contraste\nÁreas hipodensas centrales en la masa'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'Procedimiento:\n1. Nódulos de 17 mm\n2. Nódulos de 10 mm\n3. Dependientes del polo superior del mismo riñón\n4. Exploración del mismo riñón (implicita en "Se informó")'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'Procedimiento: Lesión sólido-quística\nProcedimiento: Captación de contraste\nProcedimiento: Exploración del anejo izquierdo'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'Radiografia abdominal\nExploración abdominal\nExamen físico general'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'Histerectomía total\nDoble anexectomía\nNefrectomía radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'Carcinoma de células renales en ovario\nestudio histológico intraoperatorio de la estructura ovárica'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'Carcinoma de células renales\nhistológico renal\ndefinitivo'
# [15/250] es-S0004-06142008000400013-1.txt | 29.21s | 11 chunks | 15 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'Prostatectomía radical\nGangliolinfatoma afectado por el tumor\nRevisión de PSA'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'Procedimiento:\nAcude al Servicio de Urgencias\nProcedimiento:\nPresenta una lesión exofítica\nProcedimiento:\nProcedimiento:\nNivel del glande\nProcedimiento:\nDuración de cinco semanas\nProcedimiento:\nEvolución\nProcedimiento:\nNo dolorosa'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'Exploración física\nSangrado con el roce'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'Procedimiento: exploración\nProcedimiento: lesión redondeada exofítica\nProcedimiento: dorso del glande\nProcedimiento: observación\nProcedimiento: lesión\nProcedimiento: color rojizo oscuro\nProcedimiento: diámetro\nProcedimiento: dos centímetros\nProcedimiento: tendencia al sangrado\nProcedimiento: consistencia elástica\nProcedimiento: no dolorosa'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'Linfadenectomía\nExploración física del paciente\nBiopsia de la lesión\nObservación de una tumoración de aspecto macroscópico no infiltrante\nIntervención en el glande\nObservación de áreas de aspecto trombosado\nObservación de áreas fácilmente friables en la mucosa del glande'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'MELANOMA\nanálisis anatomopatológico intraoperatorio'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'Penectomía subtotal\nResección\nLinfadenectomía inguinal superficial bilateral\nLinfadenectomía inguinal superficial derecha\nLinfadenectomía inguinal superficial izquierda'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'TAC tóracoabdominal\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'Procedimiento:\n1. Estudio anatomopatológico\n2. Penectomía'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'S-100\nHMB 45\nAnálisis inmunohistoquímico'
# [16/250] es-S0004-06142008000400016-1.txt | 32.54s | 10 chunks | 18 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'Histerectomía abdominal\nHisterectomía abdominal con doble anexectomía por endometriosis\n\nNo se encontraron más procedimientos médicos en el texto.'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'Exploración de la fosa lumbar derecha\nExploración de la fosa lumbar izquierda'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'Urografía intravenosa (UIV)\nTomografía computerizada (TAC)\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'Exploración TAC\nImagen lobulada de contenido líquido\nExtravasación de contraste\nImagen del uréter'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'Ureterolisis\nExeresis del urinoma\nAnastomosis termino-terminal del ureter\nRefrescamiento de los bordes del ureter\nLiberación de ambos extremos del ureter'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'Cirugía\nCatéter doble J tutorizando el uréter'
#   [chunk 7/8 | chars 1358-1444]
# ...
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'Procedimiento médico:\nEspirometría\nElectrocardiograma\nEcocardiograma\n\nAnalítica sanguínea anormal:\nCHCM=31.4g/dl\nNeutrófilos=76.6%\nLinfocitos=16.4%\nEosinófilos=0.9%\nFibrinógeno=645mg/dl\nGGT=52U/l\nD-Dímero positivo'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'Eco-Doppler venoso\nTrombosis venosa de las venas axilar\nTrombosis venosa de la venia cefálica\nTrombosis venosa de la venia basílica\nCompresión de la rama cubital del nervio cutáneo braquial medial\nCompresión a nivel del hiato basílico'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'Tinzapaina sódica\nradiografías\nutrasonografía-Doppler\ntratamiento con Tinzapaina sódica\nfractura de clavícula\nrecanalización completa de las venas trombosadas'
# [246/250] es-S1888-75462016000400180-1.txt | 37.54s | 7 chunks | 36 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'Procedimiento médico: Describir caso paciente\nProcedimiento médico: Paciente de 58 años\nProcedimiento médico: No se menciona procedimiento médico en el texto'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomía\nmetrorragias\nmiomas'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'Osteoporosis densitométrica lumbar\ndenosumab\nvitamina D suplementos'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'Ejecución:\n\nProcedimiento médico: Consulta\nProcedimiento médico: Dolor mecánico en el pie izquierdo\nProcedimiento médico: Exploración del pie izquierdo\nProcedimiento médico: Diagnóstico del dolor mecánico en el pie izquierdo\nProcedimiento médico: Sin inflamación\nProcedimiento médico: Sin causa desencadenante\nProcedimiento médico: AINEs (AINEs)\nProcedimiento médico: Tratamiento refractario a AINEs'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'Exploración\ndolor a la movilización del antepié izquierdo'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'Exploración de pies\n--------------------'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Exploración de pies\nRadiografía de pies'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'RMN de pie izquierdo\nfractura de estrés en el 2o MTT\ncallo perióstico\nedema de tejidos blandos'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'Procedimiento: Estudio analítico\nProcedimiento: Incremento de niveles de PTH\nProcedimiento: Incremento de vitamina D (103,7 pg/ml)\nProcedimiento: Incremento de vitamina D (272 ng/ml)'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: '"Tratamiento con suplementos de vitamina D"\n"Tratamiento con denosumab"'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'Exploración de Traumatología\nTratamiento conservador\nDescarga\nReposo relativo\nAINEs\nMagnetoterapia'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'bazedoxifeno\ncalcio con vitamina D\n\nNo se encontraron procedimientos médicos adicionales en el texto proporcionado.'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'exploración radiológica\ncallo de fractura\nfractura de estrés previa\n2o MTT (segundo momento tomográfico transitorio)'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'RMN de pie izquierdo\nRMN de pie izquierdo para completar estudio\nRMN de pie izquierdo para edema de 1er y 3er MTT\nRMN de pie izquierdo para edema de huesos cuneiforme\nRMN de pie izquierdo para edema de escafoides\nRMN de pie izquierdo para edema de astrágalo\nRMN de pie izquierdo para tenosinovitis del tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'Densitometría ósea\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'Bazedoxifeno\nVitamina D'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'rehabilitación\ndescarga'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'Osteoporosis examen\n\n(No se encontraron procedimientos médicos en el texto proporcionado)'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'Procedimiento medico:\n1. Dos episodios de dolor\n2. Cambio de estación\n3. Diferencia de un año'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'Estrés fracturas\ncalzado sobrecarga pie izquierdo'
# [247/250] es-S1889-836X2015000200005-2.txt | 52.48s | 20 chunks | 27 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'Exploración clínica\nInfección por VIH\nTratamiento con didanosina\nTratamiento con tenofovir\nTratamiento con lopinavir/ritonavir'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'Exploración física general\nAstenia\nDolores óseos difusos\nRadiografía de esclerometría\nExploración radiológica de huesos\nExamen de sangre completo\nExamen de hemograma completo\nExamen de hemograma completo con diferencial leucocitaria\nExamen de hemograma completo con plaquetas\nExamen de hemograma completo con hematocrito\nExamen de hemograma completo con glucosa\nExamen de hemograma completo con proteínas totales\nExamen de hemograma completo con creatinina\nExamen de hemograma completo con urea\nExamen de hemograma completo con electrolios\nExamen de hemograma completo con electrolios y creatinina\nExamen de hemograma completo con electrolios, creatinina y urea\nExamen de hemograma completo con electrolios, creatinina, urea y proteínas totales\nExamen de hemograma completo con electrolios, creatinina, urea, proteínas totales y glucosa\nExamen de hemograma comp'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'Alcalina fosfatasa total\nAlcalina fosfatasa ósea\nParatohormona'
#   [chunk 4/16 | chars 408-569]
#   RAW: '25-hidroxivitamina D\ncalcio total\ncalcio iónico\nparámetros bioquímicos rutinarios en suero\nelemental de orina\nsedimento de orina'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'Radiografía simple de columna\nGammagrafía con Tc99'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'Ejecución:\n\nExploración clínica\nAnálisis de sangre completo\nAnálisis de creatinina\nAnálisis de glucosa\nAnálisis de electrocardiograma\nRadiografía torácica\nRadiografía abdominal\nEcocardiograma\n\nEn este caso, el paciente ingresó en el hospital.'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'Exploración física\nDebilidad muscular de predominio proximal'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'Procedimiento:\n1. Hiperglucemia leve\n2. Glucosuria marcada\n3. Hipofosfatemia\n4. Fosfaturia inapropiada\n5. Hipouricemia\n6. Acidosis metabólica ligera\n7. Proteinuria'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'Procedimiento medico:\nExploracion aminoaciduria\nProcedimiento medico:\nExploracion glicina\nProcedimiento medico:\nExploracion valina\nProcedimiento medico:\nExploracion serina (4 veces)\nProcedimiento medico:\nExploracion treonina (4 veces)'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'Procedimiento medico:\nFGF23 serico'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Tabla 1\n\nNo se encontraron procedimientos médicos en el texto.'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'Procedimiento: Síndrome de Fanconi incompleto\nProcedimiento: Hipofosfatemia grave\nProcedimiento: Osteomalacia\nProcedimiento: Relación con TDF'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'raltegravir\ndarunavir potenciado con ritonavir'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'Procedimiento medico:\nAdministracion de suplementos de fósforo\nAdministracion de 25-HCC\nAdministracion de 1,25-dihidroxivitamina D (1,25 DHCC)'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'Procedimiento médico: Mejora progresiva del estado\n\nTexto para analizar:\nEl paciente fue sometido a una tomografía computarizada del abdomen y una ecografía transvaginal.\n\nProcedimiento médico: Tomografía computarizada del abdomen\nProcedimiento médico: Ecografía transvaginal\n\nTexto para analizar:\nSe le realizó una biopsia de tejido sospechoso en el seno mamario derecho.\n\nProcedimiento médico: Biopsia de tejido sospechoso en el seno mamario derecho\n\nTexto para analizar:\nEl médico recomendó una ecocardiografía para evaluar la función del corazón.\n\nProcedimiento médico: Ecocardiografía\n\nTexto para analizar:\nEl paciente fue sometido a una angiografía coronaria y una angioplastia percutánea.\n\nProcedimiento médico: Angiografía coronaria\nProcedimiento médico: Angioplastia percutánea\n\nTexto para analizar:\nSe le diagnosticó una neumonía y se le administró antibióticos intravenosos.\n\nProcedimiento médico: Diagnóstico de neumonía'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'Exploración de reabsorción de fosfato\nSeis meses tras la retirada de TDF\nRecuperación del peso basal\nNormalización de alteraciones analíticas séricas'
# [248/250] es-S1889-836X2015000400006-1.txt | 78.06s | 16 chunks | 17 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'Ermita malar (Lupus cutáneo)\nNo tratamiento conocido\nReumatología seguimiento'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Tiroiditis de Hashimoto'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'Apendicectomía'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'Procedimiento médico: Exfumadora'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'Quinina (tónicas)\n\n(Nota: En este caso, se ha extraído solo la mención de la toma de bebidas con quinina, ya que es el procedimiento médico que se refiere en el texto.)'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'Procedimiento: Anemia\nProcedimiento: Parto\nProcedimiento: Parto (2 veces)'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'Cesárea\nLigadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'Procedimiento médico:\nConsulta\nAstenia intensa\nPresíncopes\nDeambulación dificultada\nAnorexia\nNo hay pérdida de peso'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'Procedimiento médico: Menstruación muy duradera\nProcedimiento médico: Menstruación (8 días)\nProcedimiento médico: Menstruación abundante'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'Procedimiento médico:\nNo se menciona ningún procedimiento médico en este texto.'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'Gingivorragia\nEpistaxis'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'Menciones de procedimientos médicos no se encuentran en el texto proporcionado.\n\nResultado:\n\nNo hay procedimientos médicos para mostrar.'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'Procedimiento: Frotis sanguíneo\nProcedimiento: Presencia de esquistocitos'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'Procedimiento médico:\n1. Resto de exploraciones normales\n\nNo se encontraron más procedimientos médicos en el texto.'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'Procedimiento: Transfusión de concentrado de hematíes\nProcedimiento: Transfusión de concentrado de plaquetas'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'Exploración neurológica\nAfasia global\nDesviación de la comisura bucal a la izquierda\nExploración de plaquetas'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'No se encontraron procedimientos médicos en el texto.'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'Exploración en hematología'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'plasmaféresis\n\n(No se encontraron más procedimientos médicos en el texto proporcionado)'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'Se realiza una ingreso en Unidad de Cuidados Intensivos (UCI)\n\n(No se encontraron procedimientos médicos en el texto)'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'Plasmaféresis\nPlasmaféresis\nNo se encontraron más procedimientos médicos en el texto proporcionado.'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'Tratamiento\n48 h. después de conseguir la respuesta'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'Procedimiento: Tablas de relación\nProcedimiento: 3.500 cc'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: '1.750 cc (volumen a reinfundir)'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'Plasma fresco (350 cc.)\n\n(No se encontraron otras entidades de procedimientos médicos en el texto proporcionado.)'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'Procedimiento: Albúmina humana al 20%\nProcedimiento: 1.400 cc.'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'Dianeal® Peritoneal Dialysis (1,36%)'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'Plasmaféresis (1a)\nCatéter (catéter en yugular derecha, catéter doble luz en femoral izquierda)'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE (Hospal®)\nfiltro PTE-2000'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'Procedimiento: Heparina infusión\nProcedimiento: Sesiones de duración 210 minutos\nProcedimiento: Infusión media de 980 ml/h\nProcedimiento: Flujos de sangre entre 120-140 ml/min\nProcedimiento: Presiones de (PA)'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: '- Manteniéndose una PTM entre 25-55 mmHg\n\nTexto vacío (no se encontraron procedimientos médicos)'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'Procedimiento: Paciente en UCI\nProcedimiento: Mal estado general\nProcedimiento: Sedada'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: '1. sesion\n2. total de 17 sesiones'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'ECG\nMamografía\n1a sesión'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'MRI\nECG\nDiazepam\nSalino fisiológico'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'Exploración de presión arterial\nPTM aumento hasta 55 mm Hg\nPTM (50 minutos después)'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'Procedimiento: Cambio del SET\nProcedimiento: Fallo del test de aire\nProcedimiento: Reemplazo del SET a los 90 minutos'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'Procedimiento medico: Ninguno\n\nTexto para analizar:\nEl paciente fue sometido a una tomografía computarizada del abdomen y a una ecografía del hígado.\n\nProcedimiento medico:\n1. Tomografía computarizada del abdomen\n2. Ecografía del hígado\n\nTexto para analizar:\nSe realizó una biopsia de tejido mamario y se tomaron muestras de sangre para analizar la función hepática.\n\nProcedimiento medico:\n1. Biopsia de tejido mamario\n2. Muestras de sangre para analizar la función hepática'
# [249/250] es-S2254-28842014000200009-1.txt | 88.91s | 40 chunks | 21 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Menciones de procedimientos médicos:\n\n1. Intervención en ovario izquierdo\n2. Carcinoma seroso papilar\n3. Afectación de un ganglio de la cadena aorto-cava\n4. Estadio IIIC'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'Quimioterapia adyuvante con carboplatino\nQuimioterapia adyuvante con paclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'CT abdomen\nMRI abdomen\nUltrasound pelvis\nCA 125 blood test (repeated 3 times)\nFollow-up (general)'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'resección anterior de recto superior\nbiopsia intraoperatoria\nprueba diagnostica TAC'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'Carboplatino\nPaclitaxel'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'Carboplatino (procedimiento)\nCarboplatino (procedimiento)\nCarboplatino (procedimiento)\nTAS/TAD (prueba diagnóstica)\nTAS (prueba diagnóstica)\nTAD (prueba diagnóstica)\ndisnea (síntoma)\nvómitos (síntoma)\npérdida de conocimiento (síntoma)\nTAS/TAD (prueba diagnóstica)\nTAS (prueba diagnóstica)\nTAD (prueba diagnóstica)'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'Procedimiento: Detención de infusión\nProcedimiento: Administración de corticoides'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: '"desensibilización"\n"enlentecimiento de la velocidad de infusión"'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'Procedimiento:\n- Infusión\n\nProcedimiento:\n- Cetirizina 10 mg\n- Prednisona 1 mg/kg\n- Ranitidina 150 mg\n- Montelukast 10 mg\n\nProcedimiento:\n- Exploración de tensión arterial (85/60 mmHg)'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'Trabectedina\nAdriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'Ejecución:\n\nProcedimiento médico:\n1. Normalización de marcadores\n\nTexto vacío, no se encontraron procedimientos médicos en el texto.'
# [250/250] es-S2340-98942015000100005-1.txt | 34.69s | 11 chunks | 11 menciones
#
# Predicciones guardadas en proctemist_llm_predictions.tsv
# Tiempo medio por archivo: 46.34s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd

# Evaluacion adaptada a ProcTemIST
def prf(tp, fp, fn):
    p = tp / (tp + fp) if (tp + fp) else 0.0
    r = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1

df_pred = pd.read_csv(PREDICTIONS_TSV, sep='\t')
df_gs = pd.read_csv(GS_TEST_TSV, sep='\t')
df_gs = df_gs[df_gs['filename'].isin(df_pred['filename'].unique())]

set_gs = set(zip(df_gs['filename'], df_gs['label'], df_gs['start_span'], df_gs['end_span']))
set_pred = set(zip(df_pred['filename'], df_pred['label'], df_pred['start_span'], df_pred['end_span']))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1 = prf(tp, fp, fn)

report = {'Estricta': {'tp': tp, 'fp': fp, 'fn': fn,
                       'precision': round(p, 4), 'recall': round(r, 4), 'fscore': round(f1, 4)}}

print(f'── ESTRICTA ── P={p:.4f} R={r:.4f} F1={f1:.4f} (TP={tp} FP={fp} FN={fn})\n')

thresholds = [0.0, 0.5, 0.8]
results = {t: {'tp': 0, 'fp': 0, 'fn': 0} for t in thresholds}

for filename in df_pred['filename'].unique():
    gs_ints = list(zip(df_gs[df_gs['filename'] == filename]['start_span'],
                       df_gs[df_gs['filename'] == filename]['end_span']))
    pred_ints = list(zip(df_pred[df_pred['filename'] == filename]['start_span'],
                         df_pred[df_pred['filename'] == filename]['end_span']))
    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )
    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi)
                matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ── P=0.2669 R=0.3673 F1=0.3091 (TP=1329 FP=3651 FN=2289)
#
# ── IoU ──
# IoU >= 0.0:  P=0.3803  R=0.5233  F1=0.4405  (TP=1894 FP=3086 FN=1725)
# IoU >= 0.5:  P=0.3253  R=0.4476  F1=0.3768  (TP=1620 FP=3360 FN=1999)
# IoU >= 0.8:  P=0.2785  R=0.3833  F1=0.3226  (TP=1387 FP=3593 FN=2232)
