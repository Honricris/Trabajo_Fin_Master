# %% [markdown]
# # Pipeline Zero-Shot NER — ProcTemIST con salamandra-7b-instruct
#
# Inferencia zero-shot para reconocimiento de procedimientos en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "BSC-LT/salamandra-7b-instruct"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo PROCEDIMIENTO medico (exploraciones, pruebas diagnosticas, intervenciones, tratamientos, cirugias, etc.).\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'radiografia', no escribas 'Rx'.\n"
    "4. REPETICIONES: Si un procedimiento aparece varias veces en el texto, debes listarlo varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio.\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
PROCTEMIST_ROOT      = f"{PROJECT_ROOT}/proctemist"
TEXT_FILES_TEST_DIR  = f"{PROCTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{PROCTEMIST_ROOT}/medprocner_tsv_test_subtask1.tsv"
PREDICTIONS_TSV      = "proctemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary_proctemist.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : BSC-LT/salamandra-7b-instruct
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name        = MODEL_NAME,
    max_seq_length    = MAX_SEQ_LENGTH,
    dtype             = torch.float16,
    load_in_4bit      = True,
    token             = hf_token,
    trust_remote_code = True,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.6.7: Fast Llama patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.81M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/19.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/513 [00:00<?, ?B/s]
# Unsloth: Will load BSC-LT/salamandra-7b-instruct as a legacy tokenizer.
# Modelo cargado: BSC-LT/salamandra-7b-instruct
# Parámetros totales: 4,932,767,744

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    """Divide el texto en chunks de oraciones completas con sus offsets.
    Si max_chars es None, devuelve una oración por chunk."""
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

def build_ner_messages(text):
    return [
        {"role": "system", "content": SYSTEM_PROMPT},
        {"role": "user",   "content": f"Texto para analizar:\n{text}"},
    ]

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            full_output = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue


        marker = "<|im_start|>assistant"
        idx    = full_output.rfind(marker)
        result = full_output[idx + len(marker):].strip() if idx != -1 else full_output.strip()
        result = re.sub(r"<think>.*?</think>", "", result, flags=re.DOTALL).strip()

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        # Búsqueda de offsets con cursor por mención (maneja repeticiones)
        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename":   txt_path.stem,
            "ann_id":     f"T{mark_idx}",
            "label":      "PROCEDIMIENTO",
            "start_span": off0,
            "end_span":   off1,
            "text":       span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "ann_id", "label", "start_span", "end_span", "text"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer LlamaTokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'Vacío'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'Dolor Lumbar Derecho'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'Exploracion fisica normal.'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'Ultrasonido abdominal'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'Urograma descendente'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'TAC helicoidal: Masa tumoral con un diámetro > 8,7 x 76 cm, contornos irregulares y densidad heterogénea entre 100-37 UH, tabicado, compatible con tumor suprarrenal de tejido graso.'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'CORTISOL'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'Cirugia por abordaje lumbar'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'Tumor en glandula supresrenal derecha'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'Adrenalectomia derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'Asintomatica'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'Radiografía de tórax.'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'EXAMEN HISTOPATOLOGICO: Mielolipoma de glandula adrenal con extensas areas de calcificaciones.'
# [1/250] S0004-06142006000100010-1.txt | 19.48s | 13 chunks | 4 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'Procedimientos medicos: Gastrectomia Subtotal, Adenocarcinoma Gástrico, Hipertensión Arterial.'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'Enfermedad digestiva crónica con anorexia, perdida de peso, anemia e intolerancia a los alimentos grasos.'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'Tumoración abdominal firme e indolora'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'Así es exactamente cómo debe quedar:\nAscitis por carcinomatosis, obstrucción intestinal tumoral o tumoración abdominal.'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'Procedimientos medicos:\n- Hemoglobina\n- Hematocrito\n- Volumen corpuscular medio\n- Ancho promedio de distribución\n- Velocidad de sedimentación globular\n- Proteína C reactiva'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'Análisis del texto:\nMarcadores tumorales hepáticos y digestivos. Anodino.'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'Gastroscopia: Pólipo inflamatorio en muñón gástrico; Sin evidencia de recidiva tumoral.'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'colonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'Ecografía abdominopelvica'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'Riñon izquierdo normal. Riñon derecho ausente.'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'Urografia intravensiva'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'TAC abdominopélvica con contraste intravenoso.'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'Radiografía de abdomen superior. Pelvis renal derecha. Imagen cálcica. Hidronefrosis. Compresión e desplazamiento de estructuras abdominales.'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'Draenage percutaneo y nefrectomia'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'Nefrectomia simple derecha por lumbotomía subcostal'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'Linfadenectomia hiliar ampliada'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'Citologia'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'Biopsia renal'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'Biopsia renal con patrón papilar y zona de infiltración del parenquima renal.'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'Carcinoma de celulas renales tipo celular clara con infiltracion ganglionar'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'Metastasis hepaticas'
# [2/250] S0004-06142006000100014-1.txt | 27.29s | 21 chunks | 2 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'Varicocelectomia derecha'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'Prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'Varicocelectomia derecha'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'Tacto rectal: Prostatitis crónica con signos de inflamacion e infección.'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'Ecografía urológica integral\nImagen nodular hipoecoica en téste derecha\nHipervascularización circundante\nQuiste simple en testículo izquierda'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'TAC abdómino-pélvico: Metástasis/Hemangioma hepático.'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'RMN'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'RX TORAX NEGATIVA'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'PSA'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'PSA: 1.5 ng/ml'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'Orquiectomia radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'TXT VACIO'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'Tumor de celulas de Leydig difuso'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'Asintomatico tras diez anos de revisiones evolutivas. Marcadores tumores normales. Negativo.'
# [3/250] S0004-06142006000500002-2.txt | 15.40s | 14 chunks | 6 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'Orquidopexia'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Uretrotomia Endoscopica a los 20 anos.'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'LEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Ureterolitectomia'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'Paquete diario de cigarrillos.'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'Nódulo testicular'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'Azoospermia'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'Ecografía Doppler Testicular'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'Quiste de epididimitis en cabeza izquierda.'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'Exploracion del testiculo izquierdo.'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'Estudio completo.'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'RX TORAX: Normal \nTAC TORACO-ABDOMINO-PELVICO: Sin Metastasis'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'texto vacío'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'Orquiectomia Radical Inguinal Derecha Biopsia Testículo Izquierdo Vìa Inguinal'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'texto vacío'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'Procedimiento: Exploración testicular.'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'Nódulo sólido bien delimitado de 1,5 cm de diámetro de coloración parda con área amarillenta central.'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'texto vacío'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'Biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Tumor de celulas de Leydig de 3,2x3cm'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'Atrofia testicular con hiperplasia de celulas de leydig e infertilidad.'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'Procedimiento medico: Bordes quirúrgicos libres.'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'Biopsia testículo izquierda: Atrofia testicular + Hiperplasia células Leydig intersticial'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'Radiografía'
# [4/250] S0004-06142006000500002-3.txt | 27.70s | 25 chunks | 5 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'Ecografía'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'TAC abdominopelvica'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'Nefrectomia radical derecha por laparotomiia subcostal.'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'Carcinoma renal de celulas claras de 8,4 cm estadio T3aN0M0 II de robson grado nuclear iv fuhrman'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'Cirugia'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'Dolor en hipocondrio derecho'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'NUEVA TAC - Recidiva tumoral en lecho quirúrgico - Infiltración del pilar diafragmático derecho posterior y el hígado - Implantes peritoneales - El más grande mide 4 cm y está junto al hilio hepático'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'Biopsia intraoperatoria compatible en todas las piezas con carcinoma de celulas claras de alto grado.'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'texto vacío'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Interferon intrón a'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'TAC de abdomen + implantes peritoneales en epiplón + recidiva del lecho quirúrgico + múltiples lesiones hepáticas + respuesta a analgésicos suaves'
# [5/250] S0004-06142006000900015-1.txt | 16.94s | 11 chunks | 1 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'No se menciona ningún procedimiento médico.'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'Ecografía del testículo izquierdo: Hipogénico e Indoloro\nEcografía del Testículo Derecho: Parénquima Heterogéneo Sospechoso de Neoplasia'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'Vacío'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'texto vacío'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'Teste hipotroficos y testé hipertróficos'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'EPIDÍDIMO Y CORDONES SIN HALLAZGOS PATOLÓGICOS.'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'Hemostasia, Bioquimica, Hemograma, Alfa-Feto Proteina, Beta-HCG'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'Ecografía con flujo doppler'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'Ultrasonido de hígado y vesícula biliar.'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'Microlitiasis testicular bilateral.'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de torax + TAC toraco-abdomino-pelvico'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'Orquiectomia bilaterales via inguinales'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'Biopsia testicular con resultado positivo para seminoma classic y NICG'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'Seminoma classic with features of intraepithelial lymphocytes in the seminiferous tubules and focal necrosis.'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'Tunica albuginea, rete testis, epididymo y margen operatorio sin tumor.'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'Carboplatino'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'No se menciona ningún procedimiento médico relevante en este texto. Por lo tanto, mi respuesta es vacía: " ".'
# [6/250] S0004-06142007000200017-1.txt | 23.71s | 18 chunks | 2 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'No se menciona ningún procedimiento médico específico en el contexto provisto. Por lo tanto, mi respuesta será vacía:\n\n```\n"Paciente: YSS Edad: 32 años Raza: Negra."\n```'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'Procedimientos médicos:\n- Aumento progresivo de los órganos genitales externos\n- Trasudación de la linfa\n- Impotencia sexual'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'Edema, Eritema, Dolor'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'Adenopatía inguinal no dolorosa.'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'Hemograma completo: cifras normales.'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'No se encontró ninguna entidad de tipo "PROCEDIMIENTO MEDICO" en el texto proporcionado. Por lo tanto, mi respuesta es: """.'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Negativa - Totales - Fraccionadas - Normales - Cadera - Lesión - Óseo -Ausencia - Lesion - Osis - RX - Radiografías - Pruebas - Exploración - Diagnóstica - Intervención - Tratamiento - Cirugía - Procedimientos médicos'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'Psoas derecho engrosado de 48 mm'
#   [chunk 9/20 | chars 853-946]
#   RAW: '- Exploración retroperitoneal derecha.'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'Adenectomia de iliaca derecha y cava.'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'Linfangioplastia con aguja.'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'Fasciotomía de la raíz del pene.'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'No se encontraron procedimientos médicos relevantes en el texto proporcionado.'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'linfede ma primary inflammatory local of penis and scrotum'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'Necosis aséptica de la cabeza del femur.'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'VALORACION MULTIPROFESIONAL'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'Linfangiectomia'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'Procedimiento: Anatomia quirurgica \nEnfermedad: Distorsion de anatomia quirurgica \nAfeccion: Distortion and atraparmiento of the lymphatic ducts \nConductualitos Linfaticos: Conductuillos linfaticos \nTejido Conjunctivo Fibroso Aumentado: Increased connective tissue \nDisminucion De Las FIBRAS Elasticas: Decreased elastic fibres'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'Dartos, tunica muscular de fibras lisas, músculo peripeneal de Sappey, uretra, arteria penina dorsal'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'EXPLORACION: bolsa de las seis cubiertas que componen el recubrimiento de los testículos; escroto, dartos muscular, celulosa, fascia de Cooper, segunda tunica muscular llamada eritroide.'
# [7/250] S0004-06142007000600012-1.txt | 37.47s | 20 chunks | 4 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'Nódulo testicular'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'Nódulo duro, móvil y doloroso a la palpación a nivel del cordón espermático derecho.'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'Marcador Tumoral Normal \nHormona Normal'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'Ecografía'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'RMN del cordón espermático derecho: Imagen de señal baja en T2 (posiblemente fibrosa/cicatrizal) con 43mm de diámetro maximo.'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'EXÉRESIS QUIRÚRGICA PARATESTICIAL DERECHA'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'No es posible extraer información sobre procedimientos médicos a partir del texto proporcionado. Por lo tanto, mi respuesta será vacía.'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'Biopsia de tejido muscular.'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'Biopsia de tejido muscular.'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'Desmina\nVimentina\nActina de músculo liso especifica'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'No se encontró ninguna información relevante sobre procedimientos médicos relacionados con Granada. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'No se ha proporcionado ningún texto para analizar. Por favor proporciona el texto con las menciones a procedimientos médicos que desees extraer.'
# [8/250] S0004-06142007000600014-1.txt | 18.02s | 12 chunks | 4 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'Herida de arma de fuego en la nalga'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'Herida de bala en el muslo derecho'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'No se menciona ningún procedimiento médico específico en este texto. Por lo tanto, mi respuesta es: "texto vacío"'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'Radiografìa simple de abdomen: Bala a nivel de sínfisis del pubis y Fractura de rama descendiente derecha del mismo.'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'Cateterismo suprapubico'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'Laparotomia, Colostomia izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'Uretrografia'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'colonoscopia'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'Uretrotomo endoscopico'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'Sonda 18'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'Laparotomia'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'Radiografía'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'Extracción de bala mediante pinzas de anillo bajo control radiológico.'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'Alta hospitalaria tras extracción de vesícula biliar con sonda nasogástrica.'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'colonoscopia'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'No hay procedimientos médicos en este texto.'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'Uretrografia'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'Ultrasonido'
# [9/250] es-S0004-06142007000900010-1.txt | 18.47s | 18 chunks | 4 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Apendicectomia\nHernia Discal\nHernia de Hiato\nFractura de Tibia y Peroneo\nColico Nefrico Derecho'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'Ecografía'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'TAC del riñon derecho con una masa de 5cm de tamaño y bordes lobulares'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'Nefrectomia radical derecha laparoscopica'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'Neoformacion cortical de 5cm de diametro maximo, bien delimitada, pero no encapsulada, que deforma la superficie cortical sin atravesarla, con una superficie de corte de coloracion amarillenta con areas de aspecto hemorragicas y areas quisticas.'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'Estudio Microscopico: Estructuras Acinares Tapizadas Por Pequenas Celulas Cuboidales Uniformes Con Escaso Citoplasma Y Nucleos Con Cromatina Uniforme Inmersas En Un Estroma Ligeramente Celular'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'vimentina\ncitoqueratina 7\ncitoqueratina de amplio espectro\nCD34\ncromogranina\nEMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'No se encontró ninguna información relevante sobre procedimientos médicos relacionados con Granada. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'No se ha proporcionado ningún texto para análisis. Por favor proporciona un texto con los procedimientos médicos a extraer.'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'vimentina\ncitoqueraina 7\nEMA\nCD34'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'Intervención: Intervención'
# [10/250] es-S0004-06142007000900012-1.txt | 21.39s | 11 chunks | 11 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK, sinusitis bilateral, bronquiectasias, desprendimiento retina ojo derecho, aumento del tamaño testicular e induración.'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'Dolor Lumbar Irradiado a Testículo Izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'Exploracion: Aumento de volumen testicular, doloroso e indoloro, de consistencia petrea sugestivos de neoplasia.'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'texto vacío'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'Ecografía: Signos compatibles con tumor testicular tipo seminoma sin ganglios locorregionales.'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'Radiografía de tórax: Situs inversus; Apex de silueta cardíaca derecha e imágenes cicatrizales con posibles bronquiectasias en lóbulo inferior izquierdo.'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'LDH: 340; GOT: 44; GPT: 44'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'Orquiectomia inguinal bajo raquia a nivel l3-l4'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'Procedimiento: Seminoma classic'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'texto vacío'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Intratubular neoplasm of the testes.'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'Procedimiento: Fibrosis e hialinización tubular de testículo no tumoral.'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'Seguimiento normalidad tumoral'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'Orquiectomia'
# [11/250] es-S0004-06142008000300011-1.txt | 19.91s | 14 chunks | 0 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'Procedimientos médicos: Dolor abdominal difuso, Náuseas, Vómitos biliosos, Mal estado general.'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'Dolor + aumento + tos + inspiracion'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'Fiebre: NO se refiere a fiebre ni sensación distérmica.'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'Coluria y acolia.'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'Exploracion fisica'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'Palidez mucocutáneo.'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'No se menciona ningún procedimiento médico específico. Por lo tanto, mi respuesta es: "texto vacío"'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Auscultación cardio-pulmonar sin hallazgo alguno.'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'Dolor abdominal generalizado a la palpacion, mas intenso en epigastrio. Abdominales sin masas ni megalias. Signos de irritacion peritoneal negativos. Murphy Negativo.'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'texto vacío'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'Edema en miembro inferior derecho. Edema en miembro inferior izquierdo.'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'texto vacio'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'Bioquimica Normal\nAumento Transaminasa (GPT) 171 U/L\n(GOT): 146 U/L'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'El resultado del hemograma es normal. La hemoglobina está dentro del rango esperado, así como los glóbulos blancos y rojos. El número de plaquetas también se encuentra dentro de lo considerado normal. Por tanto, todo parece indicar que este paciente goza de buena salud desde el punto de vista sanguíneo. Sin embargo, sería prudente consultar a un médico especialista si persiste alguna duda o inquietud sobre su estado general de salud.'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'INR: 1.3\ntiempo de cefalina: 53.3 segundos'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'TC, VRI, VCI, aurícula derecha.'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'Suprahepaticas Venenos libre'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'Vació'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'Procedimiento: Anomalías del páncreas.'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'ECO abdominopelvica normal'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Vaciamiento del canal inferior.'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'Ecografía de abdomen superior con signos de colecistitis aguda y probable peritonitis. Pancreatitis sospechosa.'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'Liquido libre en pelvis, espacios peripelviano, perihepatico, periesplenico y prerenial derecho(en mayor cuantia que en TC previo)'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'patología pancreático-duodenal. Se realiza ecografía abdominal con Doppler color y se detecta una lesión hipoecoica en lóbulo izquierdo del hígado. El paciente es remitido a servicio de radiodiagnóstico donde se le practica una tomografía axial computarizada (TAC) helicoidal multicorte sin contraste oral previo. En esta prueba se visualiza una masa sólida heterogénea de 8 cm x 9 cm de diámetro máximo, localizada en fosa ilíaca izquierda, que desplaza ligeramente el colon descendente hacia arriba y lateralmente; dicha masa está bien definida y tiene bordes lisos. La TAC también muestra imágenes sugestivas de colecistitis aguda. Por último, se lleva a cabo una colangiopancreatografía retrógrada endoscópica (CPRE), cuyo resultado fue negativo.'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'TC, derrame pleural bilateral, engrosamiento de pliegues gástricos, aumento de la captación de contraste y AML'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'Vena Porta y suprahepaticas permeables.'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'Imágenes sugestiva de congestión hepática: hepatomegalia, aumento de calibre de vena porta y suprahepáticas con retraso en la llegada del contraste a las misma, edema peritonial, bazo y pancreas atrigado y abundante liquido libre.'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'Paracentesis'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'Trasudado'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'Ecografía transesofágica'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Síndrome de Budd-Chiari secundario a trombo en cava (AML vs. AML)'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'Intervención Quirúrgica Urgent'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'Intervención quirúrgica.'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'Trombo quirúrgico 4º grado por supradiáfrasis y llegada a orificio auricular derecho.'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'Chevron'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'Seccionar los ligamentos redondo, coronario, triangulares derechos e izquierdos y falciforme.'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'Liberación del riñon izquierdo e hilio, liberacion de la vena cava desde infra-renal hasta suprahepatico, comprobacion de VRD y seccion de demas ramas de la cava, fijación de la misma al higado.'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'Ampliación del hiato diafragmático y extracción del trombo a nivel subdiafragmático.'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'Clamping of the liver hilum (Pringle maneuver), occlusion of the superior and inferior vena cava and right atrium with subsequent cavotomy and opening of the left renal vein, extraction of complete thrombus and left nephrectomy.'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'Angiomiolipoma de predominio lipomatoso del seno renal con infiltración vascular.'
# [12/250] es-S0004-06142008000300012-1.txt | 75.57s | 40 chunks | 8 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'Hematuria y colico nefriitico derecho'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'Diclofenaco'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'Radiografía: Litiasis en el grupo calicial medio del riñón derecho \nEcografía: Quiste renal gigante'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'TAC -> Tomografía Axial Computarizada\nQuiste Renal Simple -> Cisto-renograma con medio de contraste\nRiñon Derecho -> Riñon izquierdo\nLitiasis Ipsilateral -> Litiasis contralateral'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'Negativa serologia de hidatiosis.'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Resultado del hemograma: Dentro de los parámetros normales.'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'Quiste lumbricoides.'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'No se especifica ningún procedimiento médico. Por lo tanto, mi respuesta es: "texto vacío"'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'Drenaje percutáneo y esclerosis del quiste.'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'Cistitis'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'antibiotico domicilio'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'Drenaje percutaneo'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'No se menciona ningún procedimiento médico. Por lo tanto, mi respuesta es: "No se especifica".'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'No es posible realizar extracción con este texto.'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'TAC con cortes tardíos'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'Leucocitos en orina'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'No se menciona ningún procedimiento médico específico en este texto. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'LITHIASI RENAL EN PELVIS.'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'Amoxicilina-clavulánico\nTrimetoprim-sulfametoxazol'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'litotricia extracorpórea'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'Asintomatica'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'TAC'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Nada'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'Ecografía de control, UIV y TAC.'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'Vía urinaria.'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'Asintomatica'
# [13/250] es-S0004-06142008000300013-1.txt | 28.41s | 26 chunks | 7 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'PROSTATECTOMÍA RADICAL CON LINFADENECTOMÍA OBTURATRIZ'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'Ecografía y Doppler'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'TAC abdominal'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'TAC post orquiectomia detecto adenompatia retroperitoneal desd area inginal hasta bifercacion de renales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'Orquiectomia inguinal\nlinfoma testicular \nesquema R-CHOPx8'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'IFOVM/DHAP'
# [14/250] es-S0004-06142008000400011-2.txt | 8.08s | 6 chunks | 4 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'texto vacío'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'Metrorragia con dolor abdominal.'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'Fosas renales'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'Ecografía Vaginal'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'TC abdomen-pelvico'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'Nódulo de 17mm'
#   [chunk 7/11 | chars 858-965]
#   RAW: "'lesión sólido-quística de 90 x 65 mm, con intensa captación de contraste.'"
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'Implante metastático peritoneal'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'histerectomia total y doble anexecto mia nefroctomi radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'Metastasis de Carcinoma de Celulas Renales en Ovario'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'Carcinoma de celulas renales grado I de Fuhrman'
# [15/250] es-S0004-06142008000400013-1.txt | 11.62s | 11 chunks | 2 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'PROSTATECTOMÍA RADICAL'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'Lesion exofitica no dolorosa en glande de 5 semanas'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'Lesion previa'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'Exploracion del paciente. Lesion redondeada exoetica de color rojo oscuro de 2 cm de diametro. Consistencia elastica y no dolorosa. Tendencia a sangrar.'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'Biopsia de lesion'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'Melanoma'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'Reseccion: Penectomia Subtotal \nMargen Seguridad: Cuatro centimetros \nLinfadenectomia Inguinal Superficial Bilateral \nGanglio: No Afectado Por El Tumor'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'TAC tóracoabdominal'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'Penectomia'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'S-100\nHMB 45'
# [16/250] es-S0004-06142008000400016-1.txt | 13.38s | 10 chunks | 5 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'Ecografía abdominal'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'Percusión y palpación de fosa lumbar izquierda'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'UROGRAFÍA INTRAVENOSA (UIV) Y TOMOGRAFÍA COMPUTERIZADA (TC) SIMULTÁNEOS'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'TAC: Lobulacion liquida con extravasacion de contraste incluyendo ureters.'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'Ureterolisis y exeresis de urinoma via iliaca'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'Cateterismo uretral con tubo doble j'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'Procedimiento: Postoperatorio.'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'Intervención: Intervento quirúrgico. \nProcedimiento: UIV.'
# [17/250] es-S0004-06142008000500009-1.txt | 10.62s | 8 chunks | 2 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'Infecciones urinarias'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'histerectomia via vaginal por prolapso uterino hace 7 meses'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'DM'
#   [chunk 4/15 | chars 616-623]
#   RAW: 'No se encontró ninguna información relevante sobre procedimientos médicos relacionados con "No HTA". Por lo tanto, no es posible proporcionar ningún resultado específico a partir del texto proporcionado.'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'No alergias conocidas.'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'No se encontró ninguna entidad de tipo "PROCEDIMIENTO MEDICO".'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'Esporádica infección urinaria.'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'No se encontró ninguna información relevante sobre procedimientos médicos en el texto proporcionado. Por lo tanto, mi respuesta es vacía.'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'Ecografía transvaginal'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'RX.'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'Ecografía Transvaginal con Litiasis Intravesical, No Móvil y Antecedente Quirúrgico Referido'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'Uretrocistoscopia'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'Cistogastromectioma'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'Radiografía de tórax y abdomen.'
# [18/250] es-S0004-06142008000700003-1.txt | 17.60s | 15 chunks | 6 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'Vacío'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'FUMADOR 20 PAQUETES AÑO'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'texto vacío'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'Uretrorragia'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'Talla suprapúbica'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'Ecografía\nGran globo vesical\nDivertículo único\nTamaño similar a vejiga\nDiámetro mayor de 13cm\nImágenes polipoideas parietales\nMenores de 2-3 cm\nEn vejiga y divertículo\nSujetos a neoplasia vesical'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'Ureterotomía\nCistoscopia\nResección transuretral'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'vimentina y actina'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'Cistectomia parcial y diverticulecto'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'Marcación de células con morfología variada.'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'Necrosis intratumoral y múltiple imagenes de necrosis celular aislada.'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'Mixoid change in extensive areas.'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'Inflamacion intra y peritumoral intensa.'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'Fibrosis peritumoral'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'MARGENES QUIRURGICOS LIBRES DE TUMOR.'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'Vimentina\nActina\nDesmina\nEMA\nCitoqueratinas de alto peso molecular'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'El texto contiene 8 procedimientos médicos diferentes. Los extraigo y te los presento a continuación:\n- Leiomiosarcoma de bajo grado\n- Infiltración de todas las capas\n- Comité clínico\n- Tratamiento complementario\n- Alto riesgo del paciente'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'TAC toracoabdominal, gammagrafía ósea y RMN pélvica'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'Radioterapia local + Quimioterapia complementarias'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'Radioterapia loco-regional a dosis de 57Gy'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'Ifosamida-Adriamina 3 cycles'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'Cistoscopia, citologia urinaria, TAC toraco-abdomino-pelvico'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: 'Revisiones periodicas'
# [19/250] es-S0004-06142009000400011-1.txt | 31.51s | 23 chunks | 16 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'Masa testicular derecha.'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'No se encontró ninguna información sobre procedimientos médicos en el texto proporcionado. Por lo tanto, mi respuesta es vacía.'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'Ecografía testicular: Aumento difuso del tamaño del testículo derecho, medido 6.2x5.8x4.2 cm, con alteración difusa de la ecogenicidad.'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'Orquidectomía'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'Infiltracion difusa del parenquima testicular por una neoplasia maligna hemo linfoide compues ta por celulas de pequeno tamano, irregulares, de citoplasma escaso, las cua les presenta ban an giotropis mo, con areas de necro sis asoci adas.'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'ACL\nCD3\nKi67\nTdT\nCD30\nALK\nbcl2\nbcl6\nCD10'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'Linfedema'
# [20/250] es-S0004-06142010000100015-1.txt | 14.23s | 7 chunks | 9 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'Ecografía'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'Ecografía: lesión quística compleja, multiseptada, de contornos polilobulados, de 11 cm de diámetro y con calcificaciones puntiformes periféricas, que ocupa la práctica totalidad de dicho riñón.'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'TC Abdomino-Pelvico: Lesion Renal Izquierda de 11x7cm de diametro, Multiseptada y con Calcificaciones Puntiformes.'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'Retroperitoneal'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'nefroma multilocular quistico'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'Renograma isotopico con tecnecio 99 m. riñon izquierdo de menor captacion e infuncionalismo con imagen fria central que podria corresponder a lesion ocupante.'
#   [chunk 7/9 | chars 870-929]
#   RAW: '"Gammagrafia Oséa"'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'Nefrectomia'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'Nefroma quístico multilocular'
# [21/250] es-S0210-48062003000900009-1.txt | 13.86s | 9 chunks | 3 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'Dolor testicular derecha. Aumento del diametro y de la consistencia testicular en el ultimo mes.'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'No se menciona ningún procedimiento médico específico en este texto. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC con tratamiento con inhaladores y oxígeno crónico domiciliario.'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'Radiografía de tórax y ecocardiograma doppler color.'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'Edema de cubiertas\nAumento de la consistencia del epidídimo\nDisparición del surco epididimario testicular'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'TAP grado II-III/IV'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'Hemoglobina: 8,1 gr/dl\nPrevia Hemoglobina: 13,5 gr/dl\nPlaqueta: 51000\nLeucocito: 9100'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'COAGULACION ELEVACIÓN DEL FIBRINÓGENO 1500'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'Bajo estas condiciones, se puede concluir que los resultados son normales.'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'Radiografía de tórax\nRadiografía de abdomen normal'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'Ecografía renal y vesical sin alteraciones.'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'Ecografía testicular, testículo izquierdo normal, testículo derecho se distingue hasta tres áreas heterogéneas con disminución de la ecogenicidad, sin calcificaciones que afectan a polo superior, inferior y epidídimo, no-hidrocele.'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'Orquiectomia radical por via inguinales una exploracion.'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'Macroscopicamente presenta una lesión testicular de 8x6x4cm con aspecto quístico-gelatinoso, que se extiende a nivel del epididimario e intravesical. En su interior contiene material gelatinosos de color blanco. Al corte muestra una estructura lobular de 5,5cm que invade albuginea y epididimio sin llegar a rebasar los limites capsulares o hilio testiculares.'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'microscopico-el-testiculo-esta-afectado-por-linfoma-difuco-B-de-celulas-grandes--con-alto-indice-de-proliferacion-(minb1)-y-marcadores-cd-20+'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'TAC de cuerpo completo de estadiaje'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'Sudacion profusa\nFiebre en picos\nAstenia\nEdema de miembros inferiores'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'Anemia con Hb de 8,9 g/dL, plaquetas a 37000 y formula normal de leucocitos y linfocitos.'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'Biopsia de medula ósea'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'Plasmocitosis intersticial y Linfoblastosis.'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'Frotis sanguineo'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'Agregacion plaquetaria + Test de coombs directo + Debilmente positivo a inmunoglobulina g'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'Fibroscopia del seno piriforme'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'TAC cervical normal.'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab\nCHOP'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'R-CHOP'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'Radioterapia genital coadyuvante y quimioprofilaxis cerebral.'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: 'No es posible extraer información sobre procedimientos médicos a partir del texto proporcionado. Por lo tanto, mi respuesta será vacía.'
# [22/250] es-S0210-48062004000200011-1.txt | 51.92s | 29 chunks | 15 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: 'Disuria'
#   [chunk 2/12 | chars 224-442]
#   RAW: 'TACTO RECTAL\nPSA\nECO ABDOMINAL'
#   [chunk 3/12 | chars 442-700]
#   RAW: 'Ureterolitectomia del tercio superior del uretero hace 35 anos en otro centro, a traves de una lumbotomi.'
#   [chunk 4/12 | chars 700-997]
#   RAW: 'Ecografía del hilo renal izquierdo con una masa parahilariana de aproximadamente 6cm de diametro. Riñon derecho normal. Prostatic size of approximately 35cc and a pSAs within the reference range.'
#   [chunk 5/12 | chars 997-1381]
#   RAW: 'TAC con el resultado de imagen paropiélica izquierda, de 5-6 cm de diámetro, de aspecto sólido, que se extiende desde el hilio renal hasta por debajo del polo inferior, con compresión del riñón y con un dudoso plano graso de separación con el mismo, calcificaciones en su interior y muy baja vascularización.'
#   [chunk 6/12 | chars 1381-1562]
#   RAW: 'Exéresis de masa renal'
#   [chunk 7/12 | chars 1562-1624]
#   RAW: 'Lumbotomía izquierda'
#   [chunk 8/12 | chars 1624-1775]
#   RAW: 'DISECION RENAL'
#   [chunk 9/12 | chars 1776-1889]
#   RAW: 'Biopsia intraoperatoria de tejido con fibras textiles.'
#   [chunk 10/12 | chars 1889-2050]
#   RAW: 'EXÉRESIS TOTAL DEL TUMOR CONSERVANDO LA UNIDAD RENAL'
#   [chunk 11/12 | chars 2050-2234]
#   RAW: 'EXÉRESIS DE MASA'
#   [chunk 12/12 | chars 2234-2418]
#   RAW: 'Colagenizacion'
# [23/250] es-S0210-48062004000500009-1.txt | 19.54s | 12 chunks | 4 menciones
#   [chunk 1/11 | chars 0-130]
#   RAW: 'Ecografía'
#   [chunk 2/11 | chars 130-212]
#   RAW: 'colelitis-hidrocelectomia-derecha'
#   [chunk 3/11 | chars 213-358]
#   RAW: 'No se menciona ningún procedimiento médico en este texto.'
#   [chunk 4/11 | chars 359-424]
#   RAW: 'Exploracion fisica abdomen'
#   [chunk 5/11 | chars 424-618]
#   RAW: 'Ecografía: Nódulo exofítico de 4x2cm en polo superior del riñón derecho con áreas sólidas, quísticas y vascularizadas (eco-Doppler)'
#   [chunk 6/11 | chars 619-824]
#   RAW: 'TC abdominopelvica'
#   [chunk 7/11 | chars 825-1174]
#   RAW: 'RMN abdominal\nmasa de 4,2 x 3,3 x 3 cm\nhipointensa en las secuencias T1\nmarcadamente hiperintensa en las T2\nvarios septos lineales en su interior\nrealce lineal de las paredes del quiste y de los septos internos tras administrar gadolinio\ndiagnóstica de masa quística mínimamente complicada'
#   [chunk 8/11 | chars 1174-1373]
#   RAW: 'Tumorectomia'
#   [chunk 9/11 | chars 1373-1584]
#   RAW: 'Carcinoma de celulas claras renal quistico multilocular grado 1 de fuhrman'
#   [chunk 10/11 | chars 1584-1768]
#   RAW: 'TC de control a los 6 meses de la intervención. Se observan cambios postquirurgicos a nivel de la cortical renal y de la grasa adyacente, sin evidencia de recidiva local.'
#   [chunk 11/11 | chars 1769-1877]
#   RAW: 'ecografía y TC'
# [24/250] es-S0210-48062004000800009-1.txt | 18.96s | 11 chunks | 6 menciones
#   [chunk 1/18 | chars 0-125]
#   RAW: 'Hipertensión Arterial\nDiabetes mellitus tipo II\nSíndrome de ansiedad'
#   [chunk 2/18 | chars 126-342]
#   RAW: 'Urologia'
#   [chunk 3/18 | chars 342-444]
#   RAW: 'Fosa Lumbar DERECHA'
#   [chunk 4/18 | chars 445-481]
#   RAW: 'Abdomen blando y depresible.'
#   [chunk 5/18 | chars 481-622]
#   RAW: 'Ecografía'
#   [chunk 6/18 | chars 623-681]
#   RAW: 'ECO INTERNO VESICAL CON ECHOS COMPATIBLES CON COAGULOS.'
#   [chunk 7/18 | chars 682-723]
#   RAW: 'Cistoscopia'
#   [chunk 8/18 | chars 723-815]
#   RAW: 'TAC abdominopelvico\nRX TORAX\nBioquimica hematicas\nHemogramas'
#   [chunk 9/18 | chars 815-1067]
#   RAW: 'TC'
#   [chunk 10/18 | chars 1068-1159]
#   RAW: 'Trombosis venosa renal + Adenopatía retroperitoneal'
#   [chunk 11/18 | chars 1159-1259]
#   RAW: 'Análisis sangre: Anemia Ferropénica; VSG normal; Calcio Normal'
#   [chunk 12/18 | chars 1259-1377]
#   RAW: 'Embolización selectiva'
#   [chunk 13/18 | chars 1377-1611]
#   RAW: 'Arteriografía de aorta abdominal + Cateterización selectiva de arteria renal derecha'
#   [chunk 14/18 | chars 1612-1842]
#   RAW: 'Embolización arterial con partículas de alcohol de polivinilo (PVA) de 355 a 500 micras (Contour®, Boston Scientific).'
#   [chunk 15/18 | chars 1842-1978]
#   RAW: 'Alta Hospitalaria'
#   [chunk 16/18 | chars 1978-2122]
#   RAW: 'TC cerebral'
#   [chunk 17/18 | chars 2123-2327]
#   RAW: 'Insomnio y algia músculo-esquelética.'
#   [chunk 18/18 | chars 2328-2451]
#   RAW: 'IECAS y calcio antagonistas.'
# [25/250] es-S0210-48062005000300014-1.txt | 19.97s | 18 chunks | 9 menciones
#   [chunk 1/23 | chars 0-303]
#   RAW: 'by-pass aorto-coronario'
#   [chunk 2/23 | chars 304-472]
#   RAW: 'Polaquiuria diurna con micción en dos tiempos.'
#   [chunk 3/23 | chars 473-537]
#   RAW: 'Hematuria total con coágulos.'
#   [chunk 4/23 | chars 538-662]
#   RAW: 'Toracotomia'
#   [chunk 5/23 | chars 663-744]
#   RAW: 'PROSTATA Hiperplasia Benigna Grado II'
#   [chunk 6/23 | chars 744-859]
#   RAW: 'PSA 0,9 ng/ml'
#   [chunk 7/23 | chars 859-954]
#   RAW: 'Ecografía initial normal renal and exophytic lesion in the base of the bladder - right face.'
#   [chunk 8/23 | chars 955-1058]
#   RAW: 'Cistoscopia'
#   [chunk 9/23 | chars 1059-1337]
#   RAW: 'RTU'
#   [chunk 10/23 | chars 1337-1535]
#   RAW: 'TAC posterior normal, se detecta ateromatosis calcificada aorto-ilio-femoral y engrosamiento de pared vesical.'
#   [chunk 11/23 | chars 1535-1606]
#   RAW: 'Cistoprostatectomia Radical y Neovejiga Ileo-Tipica Camey II'
#   [chunk 12/23 | chars 1607-1681]
#   RAW: 'alta'
#   [chunk 13/23 | chars 1681-2063]
#   RAW: 'Carcinoma seroso ovárico'
#   [chunk 14/23 | chars 2064-2101]
#   RAW: 'Psammoma'
#   [chunk 15/23 | chars 2102-2257]
#   RAW: 'Lesiones de displasia epitelial en uretra prostatica + Carcinoma de prostata bien diferenciado en lobulo derecho Gleason 4(2+2)'
#   [chunk 16/23 | chars 2258-2433]
#   RAW: 'linfadenectomia izquierda'
#   [chunk 17/23 | chars 2433-2569]
#   RAW: 'CEA'
#   [chunk 18/23 | chars 2569-2698]
#   RAW: 'Carboplatino\nGenciatina\nCisplatino'
#   [chunk 19/23 | chars 2699-2883]
#   RAW: 'infecciones urinarias,anemia,leucopenia,transfusiones sanguineas,factores estimulantes de colonias(filgastrim)'
#   [chunk 20/23 | chars 2883-3084]
#   RAW: 'Ecografía\nTAC'
#   [chunk 21/23 | chars 3085-3184]
#   RAW: 'Analgesia continua'
#   [chunk 22/23 | chars 3185-3362]
#   RAW: 'TAC, exploracion radiologica del abdomen, imagenes nodulares, recidiva mesenterica, hemiabdomen izquierdo, dilatacion urinaria bilaterales'
#   [chunk 23/23 | chars 3363-3520]
#   RAW: 'Fallecimiento a los 14 meses del diagnóstico por deterioro progresivo de la función renal y el estado general debido a la propagación intra e interperitoneal.'
# [26/250] es-S0210-48062005000400012-1.txt | 29.24s | 23 chunks | 14 menciones
#   [chunk 1/14 | chars 0-252]
#   RAW: 'PROSTATITIS CRÓNICA'
#   [chunk 2/14 | chars 253-383]
#   RAW: 'Radiologia convencional'
#   [chunk 3/14 | chars 384-463]
#   RAW: 'El resultado fue negativo en los dos tipos de medio utilizados.'
#   [chunk 4/14 | chars 464-603]
#   RAW: 'Rosa de bengala: positivo; Sero-aglutinacion: positiva (1/20); Antibrucelacoombs: positivo.'
#   [chunk 5/14 | chars 603-699]
#   RAW: 'Rifampicina y Doxiciclina'
#   [chunk 6/14 | chars 699-778]
#   RAW: 'Vacío'
#   [chunk 7/14 | chars 779-873]
#   RAW: 'Signo del psoas positivo y región ilíaca izquierda empastada.'
#   [chunk 8/14 | chars 874-1072]
#   RAW: 'Tomografía Axial Computerizada (TAC): Espondilodiscitis L5-S1 con afectación de partes blandas circundantes y absceso de psoas bilateral de pequeño tamaño.'
#   [chunk 9/14 | chars 1073-1166]
#   RAW: 'Ciprofloxacino 400mg/12h'
#   [chunk 10/14 | chars 1167-1288]
#   RAW: 'Drenaje Transcutaneo'
#   [chunk 11/14 | chars 1288-1512]
#   RAW: 'NUEVA TAC - Abscesos de psoas bilaterales - Gran tamaño - Tejido circundante - Espondilodiscitis - L5-S1'
#   [chunk 12/14 | chars 1513-1701]
#   RAW: 'Discectomia l5 s1'
#   [chunk 13/14 | chars 1702-1889]
#   RAW: 'Doxiciclina 100mg/12 horas y Septrin Forte 1/12 horas'
#   [chunk 14/14 | chars 1889-2001]
#   RAW: 'texto vacío'
# [27/250] es-S0210-48062005000700012-1.txt | 19.61s | 14 chunks | 1 menciones
#   [chunk 1/9 | chars 0-273]
#   RAW: 'Vaciamiento testicular unilateral izquierdo.'
#   [chunk 2/9 | chars 274-308]
#   RAW: 'Fiebre: NO symptoms.'
#   [chunk 3/9 | chars 309-436]
#   RAW: 'Hidrocele de mediano tamaño'
#   [chunk 4/9 | chars 437-494]
#   RAW: 'No se encontraron procedimientos médicos en este texto.'
#   [chunk 5/9 | chars 495-675]
#   RAW: 'Ecografía escrotal -> exploración; imagen nodular -> prueba diagnóstica; intratesticular -> intraabdominal; bordes bien definidos -> características; neoplasia testicular -> tumor; hidrocele -> efusión; contenido anecoico -> líquido con ecos.'
#   [chunk 6/9 | chars 676-720]
#   RAW: 'Procedimiento: Marcadores tumorales (AFP y ß-HCG).'
#   [chunk 7/9 | chars 721-814]
#   RAW: 'Orquiectomia inguinal izquierda'
#   [chunk 8/9 | chars 815-895]
#   RAW: 'TAC abdominal'
#   [chunk 9/9 | chars 896-1115]
#   RAW: 'infrarrojo'
# [28/250] es-S0210-48062006000200018-1.txt | 11.11s | 9 chunks | 2 menciones
#   [chunk 1/20 | chars 0-213]
#   RAW: 'Masa testicular izquierda'
#   [chunk 2/20 | chars 214-416]
#   RAW: 'Masa testicular'
#   [chunk 3/20 | chars 417-715]
# ...
#   RAW: 'Enfermedad de Crohn'
#   [chunk 11/17 | chars 2324-2480]
#   RAW: 'Laparoscopía'
#   [chunk 12/17 | chars 2481-2686]
#   RAW: 'Cirugia Abierta'
#   [chunk 13/17 | chars 2687-2916]
#   RAW: 'Laparotomia infraumbilical'
#   [chunk 14/17 | chars 2917-3052]
#   RAW: 'Reduccion de hernia\nReseccion de 25cm de ileon necrosado\nReconstruccion con Anastomosis Termino-Terminal Manual'
#   [chunk 15/17 | chars 3053-3134]
#   RAW: 'Cierre del orificio herniario con sutura contínua de seda 0/0.'
#   [chunk 16/17 | chars 3135-3259]
#   RAW: 'Alta hospitalaria'
#   [chunk 17/17 | chars 3260-3307]
#   RAW: 'Control postoperatorio al mes.'
# [242/250] es-S1887-85712012000400006-1.txt | 21.22s | 17 chunks | 0 menciones
#   [chunk 1/13 | chars 0-274]
#   RAW: 'Debería ser evaluado por un médico especialista en neurología o neurofisiología clínica para realizarle los estudios pertinentes y determinar su diagnóstico.'
#   [chunk 2/13 | chars 275-356]
#   RAW: 'texto vacío'
#   [chunk 3/13 | chars 356-532]
#   RAW: 'Enalapril y Simvastatina'
#   [chunk 4/13 | chars 532-751]
#   RAW: 'Diplopia binocular vertical del VI par derecho de predominio inferior. Paresia del IV par craneal del ojo derecho. Afectación incompleta del III par bilateral.'
#   [chunk 5/13 | chars 752-797]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado. Por lo tanto, mi respuesta es: "texto vacío"'
#   [chunk 6/13 | chars 798-911]
#   RAW: 'Romberg Negativo'
#   [chunk 7/13 | chars 912-1000]
#   RAW: 'Lateropulsion derecha'
#   [chunk 8/13 | chars 1000-1343]
#   RAW: 'Tomografía computerizada (TC) craneal de 64 canales'
#   [chunk 9/13 | chars 1343-1492]
#   RAW: 'Diplopia, oclución monocular alternante e inestabilidad.'
#   [chunk 10/13 | chars 1492-1824]
#   RAW: 'Resonancia Philips de 1,5T'
#   [chunk 11/13 | chars 1825-1931]
#   RAW: 'Flair y difusión'
#   [chunk 12/13 | chars 1931-2108]
#   RAW: 'Dabigatran'
#   [chunk 13/13 | chars 2109-2269]
#   RAW: 'tratamiento reabilitador'
# [243/250] es-S1887-85712014000100005-1.txt | 16.09s | 13 chunks | 3 menciones
#   [chunk 1/21 | chars 0-234]
#   RAW: 'Radiografía'
#   [chunk 2/21 | chars 235-357]
#   RAW: 'Unidad de dolor'
#   [chunk 3/21 | chars 357-745]
#   RAW: 'PRASUGREL, ACETILSALICILICO ACIDO e INTERVENCION CORONARIA PERCUTANEA PRIMARIA VÍA RADIAL DERECHA'
#   [chunk 4/21 | chars 746-996]
#   RAW: 'Cateterismo venoso periférico.'
#   [chunk 5/21 | chars 996-1242]
#   RAW: 'Extensión de musculatura flexora de antebrazo'
#   [chunk 6/21 | chars 1242-1253]
#   RAW: 'Palidez.'
#   [chunk 7/21 | chars 1253-1307]
#   RAW: 'Imposibilidad para detectar pulso radial o cubital.'
#   [chunk 8/21 | chars 1307-1373]
#   RAW: 'Disminucion de la temperatura respecto a miembro contralateral.'
#   [chunk 9/21 | chars 1373-1425]
#   RAW: 'Anestesia y paralisis total del miembro afecto.'
#   [chunk 10/21 | chars 1425-1655]
#   RAW: 'Intra-Compartmental pressure monitor system'
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'Procedimiento: Tratamiento Quirúrgico Urgente del Síndrome Compartimental Agudo en Antebrazo Derecho'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: 'Procedimiento Quirúrgico: Anestesia General Balanceada + Control de Vía Aérea con Mascarilla Laríngea'
#   [chunk 13/21 | chars 1907-1969]
#   RAW: 'Cefazolina 2 g intravenoso.'
#   [chunk 14/21 | chars 1970-2110]
#   RAW: 'incision cutanea sobre linea media de cara volar de antebrazo desde la flexura del codillo hasta la linia de kaplan'
#   [chunk 15/21 | chars 2111-2191]
#   RAW: 'Hematoma'
#   [chunk 16/21 | chars 2192-2410]
#   RAW: 'Fascia antebraquial - Descompresión nerviosa - Ligamento anular del carpo'
#   [chunk 17/21 | chars 2411-2487]
#   RAW: 'Arterial.'
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'Nitrofural Vessel Loops Compresas esteriles Malla elastica Vasos sanguineos Vendaje no compresivo Cierre quirurgico Heridas Impregnado en nitrofurales'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: 'Fasciotomía'
#   [chunk 20/21 | chars 2901-3087]
#   RAW: 'Cirugia'
#   [chunk 21/21 | chars 3088-3211]
#   RAW: 'texto vacío'
# [244/250] es-S1887-85712016000100005-1.txt | 26.18s | 21 chunks | 8 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: 'Coxalgia derecha'
#   [chunk 2/22 | chars 128-229]
#   RAW: 'Dolor durante el ejercicio y limitacion de movimiento en algunas posiciones.'
#   [chunk 3/22 | chars 230-429]
#   RAW: 'No se menciona ningún procedimiento médico.'
#   [chunk 4/22 | chars 430-528]
#   RAW: 'Marcha'
#   [chunk 5/22 | chars 528-725]
#   RAW: 'Dolor a la palpacion en tercio medio de region inguinal derecha. Dolor a la flexion, adduccion y rotaciones sobretodo interna. Maniobra del choqeu positivo.'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'Flexion bilateral 110 grados\nRotacion interna derecha 10 grados\nRotacion interna izquierda 40 grados\nRotacion externa derecha 30 grados\nRotacion externa izquierda 40 grados'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'Procedimiento: Balance Muscular Global Bilateral'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'Valleix, Fabere, Lasegue y Bragard'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'Negativo'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'Trendelenburg negativo.'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'Dolor para la marcha con flexión forzada de cadera y rodilla.'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'Deformidad en forma de joroba en región cérvico-cefálica femoral derecha.'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'hemograma\nbioquimica\nhormonas tiroideas\nanticuerpos\nreactantes de fase aguda'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'Resonancia Magnetica de Cadera'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'Islote óseo en la cabeza femoral con un ángulo alfa superior a 50º.'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'Artrografia'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'Labrum normal.'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'Lesion cystica yuxtaarticular del trocanter mayor.'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'magnetoterapia 15 sessions'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'Sulfato de glucosamina-condroitinsulfato oral 400mg cada 12horas durante 3meses y AINEs a demanda si presenta dolor.'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'Reposo Deportivo'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'Artroscopia'
# [245/250] es-S1888-75462015000400006-1.txt | 29.16s | 22 chunks | 13 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'Fractura de tercio medio de clavicula derecha y fractura de arcos costales derechos'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'texto vacío'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'Radiología Simple: Fracturas de arcos costales derecho 4º y 5º; Fractura del tercio medio de la clavicula derecha. Tomografía Axial Computada: Tercer Fragmento de la Clavicula Derecha.'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'Vendaje en ocho'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'Espirometria, Electrocardiograma, Ecocardiograma, Analítica Sanguinea, CHCM 31.4 g/dl, Neutrofilos 76.6%, Linfocitos 16.4%, Eosinofilicos 0.9%, Fibrinogeno 645 mg/dl, GGT 52 U/L, D-Dimer Positivo'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'eco-Doppler venoso: Trombosis venosa de las venas axilar, cefálica y basílica con compresión de la rama cubital del nervio cutáneo braquial medial a nivel del hiato basílico (a, 2b)'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'Tinzapain Sódico, Radiografías, Ultrasonido Doppler seriado de control'
# [246/250] es-S1888-75462016000400180-1.txt | 18.23s | 7 chunks | 1 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'Vacío'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomia'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'Denosumab'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'Dolor mecanico en el pie izquierdo'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'Exploracion: Ninguno\nProcedimiento: Dolor a la movilizacion del antepie izquierdo'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'texto vacío'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'RX de Pies'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'MRT del pie izquierdo'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'Vitamina D: 272 ng/ml\nPTH: 103,7pg/ml'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'Suplementos de vitamina D y Denosumab.'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'Descarga, reposo relativo, AINEs y magnetoterapia'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'SERMS (bazedoxifeno)'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'RX'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'MRT of left foot to complete the study that showed an edema of first and third MTJ, of cuneiform bone, scaphoid and talus, and posterior tibial tendon synovitis.'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'Densitometria osea columna vertebral Lumbar 0/0'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'BAZEDOXIFENO VITAMINA D'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'Rehabilitación y descarga'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'Osteoporosis'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'No es posible extraer información sobre procedimientos médicos del texto proporcionado.'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'Procedimiento: sobrecarga del pie izquierdo'
# [247/250] es-S1889-836X2015000200005-2.txt | 22.06s | 20 chunks | 8 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'Didanosina\nTenofovir\nLopinavir/Ritonavir'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'Revisiones ambulatorias'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'Fosfatasa alcalina total, Fosfatasa alcalina ósea, Paratohormona.'
#   [chunk 4/16 | chars 408-569]
#   RAW: 'No se encontró ninguna entidad del tipo "PROCEDIMIENTO MEDICO" en el texto proporcionado. Por lo tanto, no es posible realizar extracción alguna.'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'Radiografía simple de columna\nGammagrafía con Tc99'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'Ingreso hospitalario'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'Exploración fisica: Anodica, Debilidad muscular, Predominio Proximal.'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperglucemia leve (154 mg/dl)\nglucosuria marcada (4+)\nhipofosfatemia\nfosfaturia inapropiadamente alta\nhipouricemia (2mg/dl)\nligera acidosis metabolica (bicarbonato 19mmol/l)\nproteinuria (945 mg/24h)'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'Aminoaciduria moderada con aumentos de los siguientes aminoácidos: glicina x 2; valina x 2; serina x 4 y treonina x 4.'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'No se encontró ninguna entidad de tipo "PROCEDIMIENTO MEDICO" en el texto proporcionado. Por lo tanto, mi respuesta será un texto vacío.'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Tabla 1'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'Diagnóstico: Síndrome de Fanconi incompleto con hipofosfatemia grave y probable osteomalacia, en relación con TDF.'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'Raltegravir y darunavir potenciado con ritonavir.'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'Fósforo, 25-HCC y 1,25-dihidroxivitamina D (1,25 DHCC)'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'No se encontró ninguna entidad de tipo "PROCEDIMIENTO MEDICO" en el texto proporcionado. Por lo tanto, mi respuesta es: """.'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'Fase 0: Reabsorcion de Fosfato Discreta Baja'
# [248/250] es-S1889-836X2015000400006-1.txt | 31.21s | 16 chunks | 14 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'Enfermedad reumática crónica no especificada'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Hashimoto'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'Apendicectomia.'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'No se menciona ningún procedimiento médico relevante. Por lo tanto, mi respuesta es: "texto vacío"'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'Tomar bebidas con quinina (tónica) es considerado un hábito tóxico?'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'No se encontraron procedimientos médicos en el texto proporcionado.'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'cesarea y ligadura de trompas en el tercer trimestre del embarazo'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'Procedimientos médicos: \n- Consulta\n- Astenia\n- Presíncopes\n- Anorexia\n- Deambulación\n- Pérdida de peso'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'Procedimiento: Menstruacion Duradera y Abundante'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'Palidez cutánea y mucosa.'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'EPISTAXIS Y GINGIVORRAGIA'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'texto vacío'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'Frotis sanguineo con presencia de esquistositis.'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'PTT normal'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'Se transfundieron dos concentrados de hematies y uno de plaquetas.'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'Afasia global y desviacion de la comisura bucal a la izquierda.'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'No se menciona ningún procedimiento médico específico en este texto. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'texto vacío'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'Plasmaferesis'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'UCI'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'Plasmaferesis'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'tratamiento'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'Vacío'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'No se menciona ningún procedimiento médico específico. Por lo tanto, mi respuesta es vacía: " ".'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'De volumen a reinfundar, por lo que se programan: 1.750 cc.'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'Procedimiento: Plasmaféresis'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'Albúmina Humana 20% y 1400 CCs.'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'Dianeal® 1,36% de diálisis peritoneal.'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'plasmaféresis'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE (Hospal®)'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'Procedimiento: Infusiones de Heparina'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'PV de 70 a 90 mmHg'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'VACIO'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: 'Sesiones: 17'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'No se encontró ninguna entidad de tipo "PROCEDIMIENTO MEDICO" en el texto proporcionado. Por lo tanto, mi respuesta es vacía.'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'Diazepam + Salino Fisiológico'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'PTM'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'SET de prueba de aire con resultado anormal a los 90 minutos antes de la hora programada. Se cambia el SET y se vuelve a realizar la prueba.'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'Sesiones realizadas sin problemas. Bien toleradas por la paciente.'
# [249/250] es-S2254-28842014000200009-1.txt | 46.88s | 40 chunks | 10 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'Carcinoma seroso papilar del ovario izquierdo y afección de un ganglio de la cadena aorto-cava.'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'Carboplatino y Paclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'CA 125'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'RESECION ANTERIOR DEL RECTO SUPERIOR\nBIOPCIA INTRAOPERATORIA LENTION HEPATICA\nTAC\nTOMOGRAFIA AXIAL COMPUTADA\nINTERVENCION QUIRURGICA\nEXPLORACION RADIOLOGICA\nPROCEDIMIENTOS MEDICOS\nINSTRUMENTAL QUIRURGICO\nCIRUGIA\nPROCESO CANCERIGENO\nPROCESO METASTATICO\nLIMITES INTERVIEWS\nEXTREMIDADES INFERIORES\nABDOMEN\nORGANOS INTERNOS\nCUERPO HUMANO\nPELVIS\nAPARECE EN EL SIGUIENTE TIPO DE TEXTOS:\nARTICULOS CIENTIFICOS\nNOTICIAS CIENTIFICAS\nLIBROS CIENTIFICOS\nETC...'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'Carboplatino y Paclitaxel'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'Carboplatino'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'infusiones de corticoide'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'Desensibilizacion 5'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'Cetirizina 10mg\nPrednisona 1mg/kg\nRanitidina 150mg\nMontelukast 10mg'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'Trabecedina y Adriamicina Liposomal Pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'Tercer ciclo. Marcadores normales. Sexto ciclo. Enfermedad normalizada. Libre de enfermedad.'
# [250/250] es-S2340-98942015000100005-1.txt | 23.74s | 11 chunks | 5 menciones
#
# Predicciones guardadas en proctemist_llm_predictions.tsv
# Tiempo medio por archivo: 23.60s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd

def prf(tp, fp, fn):
    p = tp / (tp + fp) if (tp + fp) else 0.0
    r = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1

df_pred = pd.read_csv(PREDICTIONS_TSV, sep='\t')
df_gs = pd.read_csv(GS_TEST_TSV, sep='\t')
df_gs = df_gs[df_gs['filename'].isin(df_pred['filename'].unique())]

set_gs = set(zip(df_gs['filename'], df_gs['label'], df_gs['start_span'], df_gs['end_span']))
set_pred = set(zip(df_pred['filename'], df_pred['label'], df_pred['start_span'], df_pred['end_span']))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1 = prf(tp, fp, fn)

report = {'Estricta': {'tp': tp, 'fp': fp, 'fn': fn,
                       'precision': round(p, 4), 'recall': round(r, 4), 'fscore': round(f1, 4)}}

print(f'── ESTRICTA ── P={p:.4f} R={r:.4f} F1={f1:.4f} (TP={tp} FP={fp} FN={fn})\n')

thresholds = [0.0, 0.5, 0.8]
results = {t: {'tp': 0, 'fp': 0, 'fn': 0} for t in thresholds}

for filename in df_pred['filename'].unique():
    gs_ints = list(zip(df_gs[df_gs['filename'] == filename]['start_span'],
                       df_gs[df_gs['filename'] == filename]['end_span']))
    pred_ints = list(zip(df_pred[df_pred['filename'] == filename]['start_span'],
                         df_pred[df_pred['filename'] == filename]['end_span']))
    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )
    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi)
                matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ── P=0.2464 R=0.1002 F1=0.1425 (TP=358 FP=1095 FN=3215)
#
# ── IoU ──
# IoU >= 0.0:  P=0.3799  R=0.1544  F1=0.2196  (TP=552 FP=901 FN=3022)
# IoU >= 0.5:  P=0.2946  R=0.1198  F1=0.1703  (TP=428 FP=1025 FN=3146)
# IoU >= 0.8:  P=0.2615  R=0.1063  F1=0.1512  (TP=380 FP=1073 FN=3194)
