# %% [markdown]
# # Pipeline Five-Shot NER — ProcTemIST con salamandra-7b-instruct
#
# Inferencia five-shot para reconocimiento de procedimientos en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# !pip install -q nbstripout

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "BSC-LT/salamandra-7b-instruct"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo PROCEDIMIENTO medico (exploraciones, pruebas diagnosticas, intervenciones, tratamientos, cirugias, etc.).\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'radiografia', no escribas 'Rx'.\n"
    "4. REPETICIONES: Si un procedimiento aparece varias veces en el texto, debes listarlo varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio.\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
PROCTEMIST_ROOT      = f"{PROJECT_ROOT}/proctemist"
TEXT_FILES_TEST_DIR  = f"{PROCTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{PROCTEMIST_ROOT}/medprocner_tsv_test_subtask1.tsv"
PREDICTIONS_TSV      = "proctemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary_proctemist.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : BSC-LT/salamandra-7b-instruct
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name        = MODEL_NAME,
    max_seq_length    = MAX_SEQ_LENGTH,
    dtype             = torch.float16,
    load_in_4bit      = True,
    token             = hf_token,
    trust_remote_code = True,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# Unsloth: WARNING `trust_remote_code` is True.
# Are you certain you want to do remote code execution?
# ==((====))==  Unsloth 2026.6.8: Fast Llama patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.562 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/730 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.81M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/19.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/513 [00:00<?, ?B/s]
# Unsloth: Will load BSC-LT/salamandra-7b-instruct as a legacy tokenizer.
# Modelo cargado: BSC-LT/salamandra-7b-instruct
# Parámetros totales: 4,932,767,744

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    """Divide el texto en chunks de oraciones completas con sus offsets.
    Si max_chars es None, devuelve una oración por chunk."""
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

EXAMPLES = [
    {
        "text": "En la exploración física destaca palidez de piel, Tª: 37,2 ºC y en la auscultación pulmonar crepitantes en base derecha.",
        "mentions": "exploración física\nauscultación pulmonar",
    },
    {
        "text": "Paciente de 38 años, con amputación de antepié izquierdo por arteriopatía por enfermedad de Buerger.",
        "mentions": "amputación de antepié izquierdo",
    },
    {
        "text": "Dada la edad de la enferma y con el diagnóstico de neoplasia de cabeza de páncreas, se optó por tratamiento paliativo con colocación de endoprótesis (endoprótesis biliar tipo wall stent de 10 x 70 mm de longitud) quedando alojada desde colédoco proximal hasta el interior de la luz duodenal.",
        "mentions": "tratamiento paliativo\ncolocación de endoprótesis\nendoprótesis biliar tipo wall stent",
    },
    {
        "text": "La paciente se mantuvo en DPA hasta agosto de 2002, momento en el que se le realiza un trasplante renal, precisando trasplantectomía por trombosis.",
        "mentions": "DPA\ntrasplante renal\ntrasplantectomía",
    },
    {
        "text": "Los padres activaban el aparato en casa para lograr la expansión y una vez por semana nosotros modificábamos la tensión de las cadenetas para lograr la retrusión de la premaxila.",
        "mentions": "expansión\nmodificábamos la tensión de las cadenetas\nretrusión de la premaxila",
    },
]


def build_ner_messages(text):
    messages = [{"role": "system", "content": SYSTEM_PROMPT}]
    for ex in EXAMPLES:
        messages.append({"role": "user",      "content": f"Texto para analizar:\n{ex['text']}"})
        messages.append({"role": "assistant", "content": ex["mentions"]})
    messages.append({"role": "user", "content": f"Texto para analizar:\n{text}"})
    return messages

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            full_output = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue


        marker = "<|im_start|>assistant"
        idx    = full_output.rfind(marker)
        result = full_output[idx + len(marker):].strip() if idx != -1 else full_output.strip()
        result = re.sub(r"<think>.*?</think>", "", result, flags=re.DOTALL).strip()

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        # Búsqueda de offsets con cursor por mención (maneja repeticiones)
        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename":   txt_path.stem,
            "ann_id":     f"T{mark_idx}",
            "label":      "PROCEDIMIENTO",
            "start_span": off0,
            "end_span":   off1,
            "text":       span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "ann_id", "label", "start_span", "end_span", "text"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer LlamaTokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'paciente femenina\nobesidad\ndiabetes\nhipertensión\nun año de evolución'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'dolor lumbar derecho'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'exploración física'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'ultrasonido abdominal\nmasa suprarrenal derecha hipoecogénica\nde 80 mms\nque comprime el polo superior del riñon derecho'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'urograma descendente\nproceso expansivo en la suprarrenal derecha\npolo superior de riñón derecho desplazados hacia abajo'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'TAC helicoidal\nmasa tumoral\ndiámetro mayor de 8,7x76 cms\ncontornos irregulares\ndensidad heterogénea\ncompatible con tumor suprarrenal de densidad grasa'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'estudio hormonal\ndeterminación de cortisol\nnormal'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'abordaje lumbar'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'localizado en la glándula suprarrenal derecha\nbien delimitado de bordes irregulares con lobulaciones'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'adrenalectomía derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'post operatoria\nevolución favorable\nsintomática'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'peso de 171,4 g\ndimensiones de 9 x 8 x 6 cm\náreas amarillas-naranjas\nhemorragias\ntejido adiposo\ncalcificaciones'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'mielolipoma de la glándula adrenal\nextensas áreas de calcificaciones'
# [1/250] S0004-06142006000100010-1.txt | 29.40s | 13 chunks | 32 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'gastrectomía subtotal\nadenocarcinoma gástrico\nhipertensión arterial'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'anorexia\npérdida de peso\nhipocrómica\nestreñimiento'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'gran tumoración\nconsistencia firme\nindolora\nmóvil\nocupaba las tres cuartas partes del abdomen'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'adenocarcinoma gástrico\ndeterioro del estado general\nestreñimiento\nanemia\nsospecha clínica'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'hemoglobina\nhematocrito\nVCM\nRDW\nVS\nPCR\nPSA\ncreatinina\nurea'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'marcadores tumorales hepáticos y digestivos'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'gastroscopia\npólipo inflamatorio\nmuñón gástrico'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'desplazamiento intestinal\nintolerancia del paciente'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'ecografía abdominopélvica\ntumoración quística\ntabiques incompletos\ncontenido anecoico mixto\nocupaba la totalidad de la cavidad abdominal'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'riñón izquierdo\ncaracterísticas normales\nriñón derecho'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'urografía intravenosa\ngran efecto masa\nluminograma digestivo\nimpronta sobre la pared lateral derecha del cistograma'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'masa quística\nTAC\ngran tamaño'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'imagen cálcica\nzona de pelvis renal\nriñón hidronefrótico\ncompresión y desplazamiento de todas las estructuras abdominales'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'hidronefrosis gigante\nuropatía obstructiva litiásica\nnefrostomía percutánea\nnefrectomía'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'nefrectomía simple derecha\nlumbotomía subcostal\nevacuando 7.800 mililitros de contenido serohemático'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'linfadenectomía hiliar ampliada'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'cultivo del fluido\ncitología'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'aspecto multiquístico\ndilatación del sistema pielocalicial\natrofia parenquimatosa severa'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'displasia\npatrón papilar\ninfiltración del parénquima renal'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'nidos sólidos de células de citoplasma amplio, claro y de alto grado nuclear\ninfiltración ganglionar de carcinoma de células renales tipo célula clara'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'metástasis hepáticas\nfallecimiento del paciente'
# [2/250] S0004-06142006000100014-1.txt | 41.11s | 21 chunks | 68 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'hipogastrio\neyaculación dolorosa\nhemospermia\npeso testicular'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'antecedentes personales\nepisodio de prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'exploración fisica\nvaricocele derecho\nmasas a nivel de los testiculos'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'tacto rectal\npróstata irregular\nligeramente aumentada de tamaño\ninduradas\ndolorosa a la exploración'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'ecografía urológica integral\nhipoecoica\nhipervascularización circundante\nquiste simple'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'TAC abdómino-pélvico\nimágenes que pueden corresponder con metástasis o hemangiomas'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'RMn\nhemangioma'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'RX de tórax'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'marcadores tumorales\nPSA\nnormalidad'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'alfa-feto-proteína\nbeta-HCG\nPSA'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'formación nodular\ncoloración identical a la de la pulpa testicular\ntestículo'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'tumor de células de Leydig difuso\ninfiltraba espacios perineurales\ncanales vasculares capsulares adyacentes\nmúsculo liso\nmoderada atipia\nescasas mitosis'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'controles evolutivos\nmarcadores tumorales'
# [3/250] S0004-06142006000500002-2.txt | 27.32s | 14 chunks | 34 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'urólogo de zona\nneoplasia de testículo\ncriptorquidia bilateral\norquidopexia'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'cólicos nefríticos\nlitisis\nLEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'uretero litiasis\nlitectomia'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'fumar 1 paquete de cigarrillos diarios'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'urólogo de zona\nesterilidad\nnódulo en testículo izquierdo'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'azoospermia total'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'ecografía-doppler testicular\nmasa de 19 x 23 mm\nflujo aumentado\ntumor testicular\nquiste de cordón izquierdo'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'exploración física\nquiste de epidídimo en cabeza'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'testículo derecho\ncanal inguinal'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'estudio'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'RX de tórax\nTAC toraco-abdómino-pélvico'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'analítica\nmarcadores tumorales\nalfa-fetoproteina\nbeta-HCG'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'orquiectomía radical inguinal derecha\nbiopsia del testículo izquierdo'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'informe macroscópico de la pieza\ntestículo derecho\nde 3,2 x 3 cm'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'superficie testicular\nlisa\ninfiltración de túnica vaginalis'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'nódulo sólido\ndelimitado\ndiámetro\ncoloración parda\nárea amarillenta central'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'tejido testicular restante\ncolor anaranjado'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'alteraciones del cordón espermático'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Tumor de células de Leydig\nsin objetivarse infiltración del epidídimo\ntúnica albugínea\ninvasión vascular'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'atrofia\nhiperplasia de células de Leydig\npráctica ausencia de espermiogénesis'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'bordes quirúrgicos libres'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'biopsia del teste izquierdo\natrofia testicular\nhiperplasia de células de Leydig intersticial'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'marcadores tumorales\nmetástasis\nvalor de la normalidad'
# [4/250] S0004-06142006000500002-3.txt | 45.00s | 25 chunks | 56 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'masa renal derecha'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'TAC abdominopelvique\nmasa solida y heterogénea\naproximadamente 6cm\nlocalizada en polo superior del riñon derecho\nvena renal permeable'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'nefrectomía radical derecha\nlaparotomía subcostal'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'carcinoma renal de células claras\nestadio pT3aNoMo\nII de Robson\ngrado nuclear IV de Fuhrman'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'alta hospitalaria\ncirugía'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'neoplasia\ndolor en hipocondrio derecho'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'hipocondrio derecho\nrecidiva tumoral\nlecho quirúrgico\ninfiltraba pilar diafragmático derecho posterior e hígado\nimplantes peritoneales'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'extirpación de las masas tumorales\nresección de la masa tumoral adjacent a l hígado\nimplantes peritoneales y retroperitoneales\nbiopsia intraoperatoria compatible con carcinoma de células claras de alto grado'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'masa retroperitoneal paravertebral'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Interferón intrón a'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'molestias abdominales inespecíficas\nlesiones hepáticas\ncrecimiento de la recidiva del lecho quirúrgico\nimplantes peritoneales'
# [5/250] S0004-06142006000900015-1.txt | 24.03s | 11 chunks | 23 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'varón\naños'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'hipogénico\ndisminuído de tamaño\nheterogéneo'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'astenia\npérdida de peso'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'antecedentes personales de interés'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'hipotrófico\naumentado de tamaño'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'dolorosos\nconsistencia normal\nsuperficie regular'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'epidídimides\ncordón epididimario'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'hemostasia\nbioquímica\nhemograma\nalfa-feto proteína\nbeta-hCG'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'ecografía con flujo Doppler\nlesión hipoecoica\nbordes lobulados\nheterogénea\naumento del flujo Doppler'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'teste izquierdo\nlesión focal\nflujo Doppler'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'microlitiasis testicular bilateral'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de tórax\nTAC toraco-abdomino-pélvico con contraste'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'tumor testicular bilateral\norquiectomía bilateral\nvía inguinal\ntratamiento hormonal sustitutivo'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'testículo izquierdo atrofio\nfocos microscópicos de seminoma clásico\namplias areas de NICG\ninfiltracion tumoral en albuginea\nrete testis\nepididimo\ninfiltracion vascular'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'seminoma clásico\nfocos de NICG\natrofia del testículo restante'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'túnica albugínea\nrete testis\nepidídimo\nborde quirúrgico'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'carboplatino\nprotocolo del hospital'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'remisión completa de la enfermedad'
# [6/250] S0004-06142007000200017-1.txt | 32.41s | 18 chunks | 41 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'YSS\nEdad\nRaza\nNegra'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'antecedentes personales\npatologías asociadas\npaciente que acude a consulta\naumento progresivo de los órganos genitales externos\nlinfa\nimpotencia sexual'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'edema marcado del pene y escroto con eritema y dolor'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'adenopatías inguinales no dolorosas'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'estudios complementarios\ncifras normales'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'serología: No reactiva'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'prueba de Mantoux\nproteínas totales y fraccionadas\nRX de cadera'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'Psoas derecho engrosado de 48 mm\nnecrosis aséptica de la cabeza del fémur'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'procedimientos quirúrgicos\n- Exploración retroperitoneal derecha'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'adenectomía de ilíaca derecha y cava'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'linfangioplastia con aguja'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'fasciotomía de la raíz del pene'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'quiluria\nedema de los miembros inferiores\nvaricocele\nhidrocele'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'linfedema primario inflamatorio local de pene y escroto'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'necosi aséptica de la cabeza del femur'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'valoración multidisciplinaria'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'afección\nevacuación de la linfa\ntejido conjuntivo fibroso aumentado\ndisminución de las fibras elásticas\nnivel peneano'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'piel y dermis\ndartos\ntúnica muscular de fibras lisas\ncubierta celulosa rica en fibras elásticas'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'escroto\ndarтос muscular\ncelulosa\nfascia de Cooper\nsegunda túnica muscular llamada eritroide'
# [7/250] S0004-06142007000600012-1.txt | 34.61s | 20 chunks | 42 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'urología\nnódulo testicular'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'nódulo duro\nmovil\ndoloroso a la palpacion'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'marcadores tumorales\nhormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'imagen ovalada\nhipoecoica\nmixta\necogenicidad\ntamaño\nrelacionado con el cordón espermático'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'estudio de RNM\nimagen de señal baja en T2'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'tumoración paratesticular derecha\nexéresis quirúrgica\nconducto deferente'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'sin incidentes\nactualmente asintomático'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'formación redondeada\ncoloración pardusca\nconsistencia elástica\nbien delimitada\ndiámetro máximo\nsuperficie blanquecina\naspecto fibroso'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'estudio microscópico\nlesión bien circunscrita\ncitoplasma eosinófilo\nestriaciones transversales\nestroma fibroblástico\nvacuolado\nmultinucleadas\nmitótico'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'estudio inmunohistoquímico\nintensidad\ngeneralización\nexpresión\nneoplásicas\nactina de músculo liso'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'Granada'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'No es posible extraer información médica del texto proporcionado ya que carece de contexto o detalles relevantes sobre procedimientos médicos específicos. Por lo tanto, no puedo proporcionar ninguna respuesta basada en reglas de extracción establecidas anteriormente. Es importante tener más datos contextuales antes de intentar realizar cualquier análisis médico.'
# [8/250] S0004-06142007000600014-1.txt | 26.97s | 12 chunks | 34 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'herida de arma de fuego\norificio de entrada\norificio de salida'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'herida de bala\nentrada por detrás\nsalida por delante\nestructuras importantes'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'defensa abdominal'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'bala\nfractura de la rama descendente derecha del pubis'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'retención\nsondaje\ncatéter suprapúbico'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'laparotomía\ncolostomía izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'uretrografía\npaso de contraste\nrecto\nfiebre alta con escalofríos'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'perforación rectal'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'uretrotomo endoscópico\nureta prostática\nvisualizando el orificio'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'vejiga\nsonda del dieciocho'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'laparotomía\nsínfisis del pubis'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'espacio de Retzius\ncontrol radiológico\nhiperplasia de la próstata'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'extraer la bala'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'postoperatorio\nsondas'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'nueva colonoscopia\ncierre de la colostomia'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'sondajes\nse le deja tres meses más'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'uretrografía\nse comprueba que la brecha se ha cerrado\nsonda'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'ultrasonido'
# [9/250] es-S0004-06142007000900010-1.txt | 28.75s | 18 chunks | 34 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'apendicectomía\nhernia discal\nde hiato\nfractura de tibia y peroné\ncólico nefrítico derecho'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'neoformación sólida\nriñón derecho\n5 cm'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'masa a nivel cortical de riñón derecho\naproximadamente 5 cm\nbordes externos lobulados\nno afecta al espacio perirrenal\nadenopatías\ndilatación de vía renal excretora'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'nefrectomía radical derecha'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'neoformación cortical\ndiámetro máximo\nbien delimitado\nno encapsulado\ndeforma la superficie cortical\nsin atravesarla\nsuperficie de corte\ncoloración amarillenta\náreas de aspecto hemorrágicas\náreas quísticas'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'estudio microscópico\nestructuras acinares\npequeñas células cuboidales uniformes\nescaso citoplasma\nnúcleos con cromatina uniforme\ninmersas en un estroma ligeramente celular'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'estudio inmunohistoquímico\nvimentina\ncitoqueratina 7\ncitoqueratina de amplio espectro\nCD34\ncromogranina\nEMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'Granada'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'País'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'vimentina\ncitoqueraina 7\nEMA\nCD34'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'intervención\nincidentes destacables\nsíntomas'
# [10/250] es-S0004-06142007000900012-1.txt | 25.61s | 11 chunks | 42 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK\nsinusitis bilateral\nbronquiectasias\ndesprendimiento retina de ojo derecho\naumento del tamaño testicular\ninduración'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'dolor lumbar\nirradiación a testículo izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'aumento del volumen testicular\nconsistencia pétrea'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'adenopatías'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'ecografía\nseminoma'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'situs inversus\nsilhueta cardiaca\nimagenes cicatrizales con posibles bronquiectasias'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'LDH\nGOT\nGPT'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'a-fetoproteína\nb-HCG\norquiectomía inguinal\nraquianestesia\nhiperbarica\nprótesis testicular'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'seminoma clásico\ndiámetro\nalbugínea\nepidídimo\nrete testis\ncordón espermático\nbordes quirúrgicos'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'invasión vascular'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'neoplasia germinal intratubular'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'fibrosis e hialinización tubular de testículo no tumoral'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'seminoma grado I\noncoloogia\nseguimiento normalidad bioquimica de los parametros tumorales\nexploracion fisica negativa\npruebas por imagenes negaticas'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'orquiectomia\nespermiograma\nazoospermia'
# [11/250] es-S0004-06142008000300011-1.txt | 26.38s | 14 chunks | 33 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'dolor abdominal difuso\nepigastrio\nnáuseas\nvómitos biliosos\nmal estado general'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'dolor\ntos\ninspiración'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'fiebre\nsensación distérmica'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'Coluria e ictericia.'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'consciente\norientada\ndolor\ngravedad'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'palidez mucocutáneo'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'afebril\nnormotensa'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'auscultación cardiopulmonar\nsin hallazgos'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'abdomen\nsin masas ni megalias\ndolor abdominal generalizado\nepigastrio\nsignos de irritación peritoneal'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'circulación colateral'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'edema de miembros inferiores'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'TVP'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'bioquímica normal\naumento de transaminasas\nGPT: 171 U/L'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'hemoglobina\nhematocrito\nleucocitos\nplaquetas'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'INR\ntiempo de cefalina'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'TC\ntrombo con densidad grasa\nriñón izquierdo\nvena renal izquierda\nvena cava inferior\nostium de aurícula derecha'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'venas suprahepáticas libres'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'no oclusión completa de la luz de VCI'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'anormalidad inespecifica de cabeza de pancreas'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'ECO abdominopelvique\nhígado y vías biliares intra y extrahepáticas normales'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'lipoma en VCI'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'ecografía\npancreatitis'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'líquido libre en pelvis\nespacios perihepático\nperiesplénico\nperirrenal derecho'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'patología bilio-pancreática'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'TC\nderrame pleural bilateral\nengrosamiento de pliegues gástricos\naumento de la captación de contraste\nangiomiolipoma'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'lipoma renal\nVCI\naurícula derecha\ncontraste\nvenas porta y suprahepáticas'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'imágenes sugestivas de congestión hepática\nhepatomegalia\naumento de calibre de vena porta y suprahepáticas\ncon retraso en la llegada del contraste a las mismas\nedema periportal\nbazo atrigado\nabundante liquido libre'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'paracentesis\ncontrol ecográfico'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'análisis del trasudado\ndescartar proceso peritoneal'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'ecografía transesofágica\nfunción ventricular\ntrombo intracavitario\ntricúspide\npericardio'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Síndrome de Budd-Chiari\ntrombo en cava'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'intervención quirúrgica urgente'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'intervención quirúrgica'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'trombo\nnivel quirúrgico IV'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'incisión tipo Chevron\nacceso a retroperitoneo\nliberación ascendente del paquete intestinal'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'seccionando los ligamentos redondo, coronario, triangulares derecho e izquierdo y falciforme'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'liberación del riñón izquierdo\nvenas suprahepáticas'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'hiato diafragmático\ntrombo'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'clampaje de pedículo hepático\ncava proximal\ncava distal\nVRD\nnefrectomía izquierda'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'angiomiolipoma de predominio lipomatoso del seno renal con infiltración vascular'
# [12/250] es-S0004-06142008000300012-1.txt | 69.44s | 40 chunks | 85 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'urología\ncólico nefrítico\nhematuria'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'diclofenaco\nartrosis\nlumbalgia'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'litisis en el grupo calicial medio del riñón derecho\nquiste renal gigante'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'TAC\nquiste renal simple\nlitiaisis ipsilateral'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'serología de hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'hemograma dentro de la normalidad'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'molestias lumbares\nquiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'posibilidades'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'quiste\ndrenaje percutáneo\nesclerosis del quiste'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'cuadro de cistitis\nfiebre elevada\ndolor lumbar derecho'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'antibiotico de modo domiciliario'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'drenaje percutáneo\nquiste'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: '6,4 cm'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'pared\ncalcificado'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'TAC\nquiste\nsistema pielocalicial'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'microhematuria\nleucocituria'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'cólico derecho\ncistitis'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'litiasis\npelvis renal'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'infección urinaria\nAmoxicilina-Clavulanico\nTrimetropin-Sulfametoxazol'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'infección\nlitiasis'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'paciente está asintomático'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'ruptura del quiste\nTAC\ndiámetro\ncalcificaciones gruesas y nodulares\nno capta contraste'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Bosniak IIF'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'ecografía de control\nUIV\nTAC'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'comunicación con la vía urinaria'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'paciente\nsíntomas\nsintomatología'
# [13/250] es-S0004-06142008000300013-1.txt | 37.09s | 26 chunks | 47 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'prostatectomía radical\nlinfadenectomía obturatriz\ncarcinoma de próstata medianamente diferenciado\nafectación microscópica limitada de los márgenes de resección'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'cirugía prostática\naumento de volumen testicular\nmarcadores de tumor testicular\necografía\nflujo vascular'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'evaluación preoperatoria\nTAC abdominal\nhallazgos'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'TAC post orquiectomia\nadenopatías retroperitoneales\nárea inguinal a bifurcacion de renales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'linfoma testicular difuso de célula grande tipo B\nesquema R-CHOPx8\nremisión completa tras la inducción'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'esquema IFOVM/DHAP\nremisión inicial\nnueva recidiva\nfallecimiento'
# [14/250] es-S0004-06142008000400011-2.txt | 14.92s | 6 chunks | 18 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'hipertensión arterial'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'metrorragias\ndolor abdominal'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'hematuria\ndolor en fosas renales'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'ecografía vaginal\nmasa anexial izquierda\nútero grande\novario derecho normal'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'carcinoma ovárico primario\nTC abdómino-pélvico\nmasa compleja\nintensa captación de contraste\náreas hipodensas centrales'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'nódulos de 17 y 10 mm'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'anejo izquierdo\nlesión sólido-quística\nintensidad de captación del contraste'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'implante metastásico peritoneal'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'histerectomía total\nanexectomía\nnefrectomía radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'estudio histológico intraoperatorio\nmetástasis de carcinoma de células renales\novario'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'carcinoma de células renales grado I de Fuhrman'
# [15/250] es-S0004-06142008000400013-1.txt | 19.89s | 11 chunks | 23 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'antecedentes de gastrectomía\nadenocarcinoma gástrico\ncarcinoma de próstata Gleason VII\nprostatectomía radical\nbloqueo androgénico\nPSA de 0,06'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'urgencias\nlesión exofítica\nglande'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'lesión previa\ntraumatismo en la zona\nsangrado con el roce'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'lesión redondeada exofítica\ncolor rojizo oscuro\naproximadamente dos centímetros de diámetro\nconsistencia elástica\nno dolorosa'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'linfadenectomías\nbiopsia de la lesión'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'análisis anatomopatológico intraoperatorio\nhipercromatismo nuclear\npleomorfismo\nmitosis\npigmento negruzco'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'resección\npenectomía subtotal\nmargen de seguridad\nlinfadenectomía inguinal superficial bilateral'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'TAC tóracoabdominal\nausencia de enfermedad metastásica'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'penectomía\nestudio anatomopatológico\npieza quirúrgica\nprofundidad máxima de invasión'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'S-100\nHMB 45\nmelanoma'
# [16/250] es-S0004-06142008000400016-1.txt | 22.52s | 10 chunks | 36 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'histerectomía abdominal\ndoble anexectomía\necografía abdominal'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'fosa lumbar derecha\nfosa lumbar izquierda'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'urografía intravenisa\nTomografía computerizada'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'TAC\nimagen lobulada\nextravasación de contraste'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'ureterolisis\nexéresis del urinoma\nanastomosis termo-terminal del uréter'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'catéter doble j\nureteres'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'evolución de la paciente\npostoperatorio'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'función renal\nvía urinaria'
# [17/250] es-S0004-06142008000500009-1.txt | 13.12s | 8 chunks | 16 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'Infecciones urinarias'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'histerectomía vía vaginal\nabsceso de cúpula vaginal'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'DM'
#   [chunk 4/15 | chars 616-623]
#   RAW: 'HTA'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'Alergias conocidas'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'hematuria'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'cólico'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'infecciones de orina'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'No entiendo lo que quieres decir. ¿Podrías reformular tu pregunta?'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'urgencias\nlitiasis vesical'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'RX'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'ecografía transvaginal\nlitiasis intravesical\nantecedente quirúrgico\ncorresponde a un cuerpo extraño intravesical'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'uretrocistoscopia\napreciándose un gran pelotón de gasas adherido a la pared vesical\nno se moviliza por estar calcificado'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'litiasis intravesical\ncuerpo extraño\nciegoslitectomía\ncistogastromectiomía'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'buena evolución\npaciente está asintomático\ninfecciones de orina de repetición\nvida absolutamente normal'
# [18/250] es-S0004-06142008000700003-1.txt | 23.51s | 15 chunks | 20 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'EPOC moderado'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'fumador\nno bebedor'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'antecedentes familiares'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'uretrorragia\nimposibilidad para la micción'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'imposibilidad para el sondaje urinario\nestudio'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'ecografía\ngran globo vesical\ndivertículo único\nvejiga\nimágenes polipoideas parietales'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'ureterotomía\ncistoscopia\nresección transuretral'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'marcadores epiteliales\nmarcadores fibroblásticos\nvimentina\nactina'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'cirugía\nleiomiosarcoma de bajo grado'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'pleomorfismo celular'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'focos de necrosis intratumoral\nimágenes de necrosis celular aislada'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'cambios mixoides'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'inflamación intra y peritumoral'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'infiltración\ntejido adiposo peridiverticular\nreacción fibrosa peritumoral'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'márgenes quirúrgicos libres de tumor'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'Marcador de diferenciación muscular\nDesminá\nmarcadores epiteliales'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'leiomiosarcoma de bajo grado\ninfiltración de todas las capas\ncomité clínico\ntratamiento complementario'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'TAC toracoabdominal\ngammagrafía ósea\nRM pelvico'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'administración de radioterapia locorregional\nquimioterapia complementaria'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'radioterapia locorregional\ndosis de 57 Gy'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'quimioterapia\ncombinación ifosfamida-adriamicina\ndosis habituales\ntres ciclos'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'ciistotopia\ncitologia urinaria\nTAC toraco-abdomino-pelvico'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: 'libre de enfermedad\nrevisiones periódicas\nenfermedad\ncalidad de vida'
# [19/250] es-S0004-06142009000400011-1.txt | 38.96s | 23 chunks | 49 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'hombre de 42 años\nmasa y dolor testicular derecho\nde 2 meses de evolución\nque aumentó en forma progresiva'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'antecedentes patológicos\nsintomatología'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'ecografía testicular\naumento difuso del tamaño del testículo derecho\nalteración difusa de la ecogenicidad del mismo'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'orquidectomia\naumento del tamaño del testiculo'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'estudio histopatológico\ninfiltración difusa del parenquima testicular\nneoplasia maligna hematolinfodea'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'ACL\nCD3\nKi67\nTdT\nCD30\nALK\nbcl2\nbcl6\nCD10'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'linfoma no hodgkin t periférico no especificado'
# [20/250] es-S0004-06142010000100015-1.txt | 15.18s | 7 chunks | 20 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'lesión renal'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'lesión quística compleja\nmultiseptada\ncontornos polilobulados\ndiámetro de 11cm\ncalcificaciones puntiformes periféricas'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'lesión renal izquierda\ndiámetro\nmultiseptada\ncalcificaciones puntiformes'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'Adenopatías Retroperitoneales'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'nefroma multilocular quístico\ncarcinoma de células renales quístico'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'renograma isotópico\nTc-99m\nriñón izquierdo\ninferior captación\nfuncionalismo\nimagen fría central'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'R.I.\nfunción del R.I.\ngammagrafía ósea'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'nefrectomía'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'nefroma quístico multilocular'
# [21/250] es-S0210-48062003000900009-1.txt | 16.59s | 9 chunks | 23 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'dolor testicular\naumento del diámetro\nconsistencia testicular'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'síndrome constitucional\npérdida de 3 kg de peso en el último mes'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'picos de fiebre\nsudación profusa\nno clínica miccional\nno hematuria'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC\ninhaladores\noxígeno crónico domiciliario'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'palidez mucocutánea\ncrepitantes en la auscultación pulmonar\nedemas en miembros inferiores\nno adenopatías\nhematomas en ambos miembros superiores'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'edema de cubiertas\naumento de la consistencia del epidídimo y del teste\ndisparición del surco epidídimo testicular'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'tactro rectal\nadenoma prostatico\ngrado ii-iii/iv'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'hemoglobina\nplaquetas\nleucocitos'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'coagulación elevación del fibrinógeno'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'BCHC\nCEA\nAFP\nfunción renal\nhepática y pancreática normal'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'Radiografía de tórax\ncongestión vascular\nabdomen normal'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'ecografía renal y vesical\npróstata'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'ecografía testicular\ntestículos\náreas heterogéneas\ndisminución de la ecogenicidad\ncalcificaciones\npolo superior\ninferior\nepidídimo\nno hidrocele'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'absceso testicular\ntuberculosis testicular\nbrucelosis\ntumor testicular\norquiectomía radical\nvía inguinal'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'tumor testículo\nmasa blanquecina lobulada\ninfiltra albugínea y epidídimo'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'linfoma difuso B de células grandes\nalto índice de proliferación\nmarcadores CD 20+'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'linfoma testicular primario\nTAC de cuerpo completo de estadiaje\nesplenomegalia homogénea\nadenopatías retroperitoneales aislidas menores a 1cm'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'sudación profusa\nfiebre en picos\nastenia\nedema de los miembros inferiores'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'anemia\nhemoglobina\nplaquetas\nleucocitos\nlinfocitos'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'síntomas B\nlinfoma testicular primario\nbiopsia de medula ósea'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'plasmocitosis intersticial\ninfiltración por células linfoblásticas'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'frotis sanguíneo'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'agregación plaquetaria\ntest de Coombs directo\ndébil positividad a inmunoglobulina G'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'disfonía\ndisfagia\nfibroscopia\nlesión polipoidea en seno piriforme'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'TAC cervical normal'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab\nCHOP'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'quimioterapia\nR-CHOP'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'administración de radioterapia genital\nquimioprofilaxis cerebral'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: 'libre de enfermedad'
# [22/250] es-S0210-48062004000200011-1.txt | 58.18s | 29 chunks | 77 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: 'sintomatología de tracto urinario inferior\naumento de frecuencia miccional nocturna\nligera disuria\nleve disminución del calibre miccional'
#   [chunk 2/12 | chars 224-442]
#   RAW: 'tacto rectal\ndeterminación de PSA\necografía abdominal'
#   [chunk 3/12 | chars 442-700]
#   RAW: 'intervención sobre el ojo izquierdo\nureterolitectomía del tercio superior del uréter'
#   [chunk 4/12 | chars 700-997]
#   RAW: 'masa parahiliar\nriñón izquierdo\ndiámetro\nriñón derecho\npróstata\nPSA'
#   [chunk 5/12 | chars 997-1381]
#   RAW: 'TAC\nimagen paropiélica izquierda\nde 5-6 cm de diámetro\naspecto sólido\nse extiende desde el hilio renal hasta por debajo del polo inferior\ncompresión del riñón\ncon un dudoso plano graso de separación con el mismo\ncalcificaciones en su interior\nmuy baja vascularización'
#   [chunk 6/12 | chars 1381-1562]
#   RAW: 'masa renal\nestudio de extensión\nrevisión quirúrgica\nexéresis de la masa\nnefrectomía'
#   [chunk 7/12 | chars 1562-1624]
#   RAW: 'lumbotomía izquierda'
#   [chunk 8/12 | chars 1624-1775]
#   RAW: 'disección renal\nmasa comprimiendo riñón'
#   [chunk 9/12 | chars 1776-1889]
#   RAW: 'biopsia intraoperatoria\nfibras textiles'
#   [chunk 10/12 | chars 1889-2050]
#   RAW: 'intervención previa\nexéresis de la tumoración\nconservando la unidad renal'
#   [chunk 11/12 | chars 2050-2234]
#   RAW: 'exéresis de la masa\nfragmentos deshilachados de una o varias gasas\nmaterial de aspecto caseoso'
#   [chunk 12/12 | chars 2234-2418]
#   RAW: 'análisis anatomopatológico\nmaterial hialino\ntendencia a la colagenización\nreacción inflamatoria\nhistiocitos'
# [23/250] es-S0210-48062004000500009-1.txt | 28.12s | 12 chunks | 43 menciones
#   [chunk 1/11 | chars 0-130]
#   RAW: 'epigastralgia\nmasa renal'
#   [chunk 2/11 | chars 130-212]
#   RAW: 'colelitiasis\nhidrocelectomía derecha'
#   [chunk 3/11 | chars 213-358]
#   RAW: 'anamnesis\ndolor en fosas renales\nhematuria\nepisodios de infección urinaria\nastenia\nanorexia\npérdida de peso'
#   [chunk 4/11 | chars 359-424]
#   RAW: 'exploración física\nmasas abdominales\nmegalias'
#   [chunk 5/11 | chars 424-618]
#   RAW: 'ecografía\nnódulo exofítico\ndiámetro mayor\nriñón derecho\nvascularizadas'
#   [chunk 6/11 | chars 619-824]
#   RAW: 'masa renal compleja\nlesión quística compleja\nnaturaleza benigna'
#   [chunk 7/11 | chars 825-1174]
#   RAW: 'RMN abdominal\nmasa de 4,2 x 3,3 x 3 cm\nhipointensa en las secuencias T1\nmarcadamente hiperintensa en las T2\nvarios septos lineales en su interior\nrealce lineal de las paredes del quiste y de los septos internos tras administrar gadolinio'
#   [chunk 8/11 | chars 1174-1373]
#   RAW: 'TC\necografía\ntumorectomía'
#   [chunk 9/11 | chars 1373-1584]
#   RAW: 'carcinoma de células claras renales\nquístico multilocular\ngrado I de Fuhrman\nmárgenes de resección negativos'
#   [chunk 10/11 | chars 1584-1768]
#   RAW: 'TC de control\nintervención quirúrgica\ncortical renal\ngrasa adyacente\nevidencia de recidiva local'
#   [chunk 11/11 | chars 1769-1877]
#   RAW: 'paciente\nsintomático\necografía\nTC'
# [24/250] es-S0210-48062004000800009-1.txt | 25.40s | 11 chunks | 41 menciones
#   [chunk 1/18 | chars 0-125]
#   RAW: 'antecedentes de HTA\nHipertiroidismo\nDiabetes Mellitus tipo II\nsíndrome de ansiedad'
#   [chunk 2/18 | chars 126-342]
#   RAW: 'hematuria franca\nmonosintomática\nvarias semanas de evolución\nsin otra sintomatología associated\nalteración del estado general'
#   [chunk 3/18 | chars 342-444]
#   RAW: 'fosa lumbar derecha\nmasa palpable'
#   [chunk 4/18 | chars 445-481]
#   RAW: 'abdomen blando y depresible'
#   [chunk 5/18 | chars 481-622]
#   RAW: 'estudio ecográfico\nmasa sólida heterogénea\npolo inferior del riñón derecho\nriñón contralateral normal'
#   [chunk 6/18 | chars 623-681]
#   RAW: 'eco interno compatible con coágulo'
#   [chunk 7/18 | chars 682-723]
#   RAW: 'estudio cistoscópico'
#   [chunk 8/18 | chars 723-815]
#   RAW: 'TAC abdominopelvico\nRX tórax\nbioquímica hemática\nhemograma'
#   [chunk 9/18 | chars 815-1067]
#   RAW: 'masa tumoral\nhiperdensa\nnecrosis\ndistorsión del parenquima renal\nvalor de atenuacion'
#   [chunk 10/18 | chars 1068-1159]
#   RAW: 'vena renal\ntrombo\nadenopatías locorregionales retroperitoneales'
#   [chunk 11/18 | chars 1159-1259]
#   RAW: 'anemia ferropénica\naumento de la VSG\nnormocalcemia'
#   [chunk 12/18 | chars 1259-1377]
#   RAW: 'cirugía radical\nembolización selectiva'
#   [chunk 13/18 | chars 1377-1611]
#   RAW: 'punción en la arteria femoral común derecha\narteríografa de aorta abdominal\nselectivamente la arteria renal derecha'
#   [chunk 14/18 | chars 1612-1842]
#   RAW: 'arteria del tumor\nparículas de alcohol de polivinilo\nContour®'
#   [chunk 15/18 | chars 1842-1978]
#   RAW: 'hospitalización\nsucesivos controles'
#   [chunk 16/18 | chars 1978-2122]
#   RAW: 'TC cerebral'
#   [chunk 17/18 | chars 2123-2327]
#   RAW: 'seguimiento\nhematuria\ninsomnio\nalgia músculoesquelética\ncontroladas con tratamiento sintomático'
#   [chunk 18/18 | chars 2328-2451]
#   RAW: 'tensión arterial\nIECAS\ncalcio antagonistas'
# [25/250] es-S0210-48062005000300014-1.txt | 33.05s | 18 chunks | 41 menciones
#   [chunk 1/23 | chars 0-303]
#   RAW: 'cardiopatía isquémica\ninfarto de miocardio\nby-pass aorto-coronario\narteriosclerosis de troncos supraaórticos\nextremidades inferiores\nEPOC\nfumador\nhernia discal\nestenosis de canal'
#   [chunk 2/23 | chars 304-472]
#   RAW: 'síntomas de tramo urinario inferior\nmicción nocturna\npolaquiuria diurna\nmicción en dos tiempos'
#   [chunk 3/23 | chars 473-537]
#   RAW: 'hematuria total con coágulos'
#   [chunk 4/23 | chars 538-662]
#   RAW: 'deterioro del estado general\nabdomen globuloso\ncicatriz de toracotomía'
#   [chunk 5/23 | chars 663-744]
#   RAW: 'hiperplasia benigna grado II'
#   [chunk 6/23 | chars 744-859]
#   RAW: 'hemograma normal\nfunción renal normal\nleve hiperuricemia\nPSA 0,9 ng/ml'
#   [chunk 7/23 | chars 859-954]
#   RAW: 'ecografía inicial\nriñones normales\nlesión exofítica en base vesical-cara derecha'
#   [chunk 8/23 | chars 955-1058]
#   RAW: 'citología\nneoplasia vesical'
#   [chunk 9/23 | chars 1059-1337]
#   RAW: 'RTU\ncarcinoma mixto\npapilar de células transicionales\ngrado II-III infiltrante de músculo liso\nadenocarcinoma mucoide infiltrante\nlesiones de carcinoma in situ\ncistitis glandular quística\n(estadio pT2-pT3 G-III)'
#   [chunk 10/23 | chars 1337-1535]
#   RAW: 'TAC posterior\nateromatosis calcificada aorto-ilio-femoral'
#   [chunk 11/23 | chars 1535-1606]
#   RAW: 'cistoprostatectomía radical\nneovejiga ileal tipo Camey II'
#   [chunk 12/23 | chars 1607-1681]
#   RAW: 'postoperatorio\ncomplicaciones\nalta hospitalaria'
#   [chunk 13/23 | chars 1681-2063]
#   RAW: 'carcinoma seroso ovárico'
#   [chunk 14/23 | chars 2064-2101]
#   RAW: 'psammoma'
#   [chunk 15/23 | chars 2102-2257]
#   RAW: 'lesiones asociadas de displasia epitelial\ncarcinoma de próstata bien diferenciado'
#   [chunk 16/23 | chars 2258-2433]
#   RAW: 'linfadenectomía izquierda\ncarcinoma micropapilar'
#   [chunk 17/23 | chars 2433-2569]
#   RAW: 'Immunophenotypically the micropapillary component expressed cytokeratin 7, CA125, cytokeratin 20, BX2 and P53, being negative for CEA.'
#   [chunk 18/23 | chars 2569-2698]
#   RAW: 'carboplatino\ngencitabina\ncisplatino'
#   [chunk 19/23 | chars 2699-2883]
#   RAW: 'infecciones urinarias\nanemia\nleucopenia\ntransfusiones sanguíneas\nfactores estimulantes de colonias'
#   [chunk 20/23 | chars 2883-3084]
#   RAW: 'QMT\nimagen mediante ecografía y TAC\nevolución satisfactoria de ambos riñones y la neovejiga'
#   [chunk 21/23 | chars 3085-3184]
#   RAW: 'dolores óseos\nanalgesia'
#   [chunk 22/23 | chars 3185-3362]
#   RAW: 'TAC\nrecidiva mesentérica\ndilatación renoureteral bilateral'
#   [chunk 23/23 | chars 3363-3520]
#   RAW: 'función renal\ndeterioro progresivo\nestado general\nprogresión intra y retroperitoneal'
# [26/250] es-S0210-48062005000400012-1.txt | 50.05s | 23 chunks | 66 menciones
#   [chunk 1/14 | chars 0-252]
#   RAW: 'ingesta de un producto lácteo no higienizado\nfiebre\nmalestar general'
#   [chunk 2/14 | chars 253-383]
#   RAW: 'hemograma\nbioquímica\npruebas de coagulación\nradiología convencional'
#   [chunk 3/14 | chars 384-463]
#   RAW: 'hemocultivos\nmedios convencionales\nRuiz Castañeda\nnegativos'
#   [chunk 4/14 | chars 464-603]
#   RAW: 'Rosa de Bengala: positivo\nserro-aglutinación: positiva (1/20)\nantibrucelacoombs: positivo'
#   [chunk 5/14 | chars 603-699]
#   RAW: 'Rifampicina\ndoxaciclina'
#   [chunk 6/14 | chars 699-778]
#   RAW: 'recaida\ndolor lumbar\nfiebre'
#   [chunk 7/14 | chars 779-873]
#   RAW: 'región ilíaca izquierda\nsigno del psoas positivo'
#   [chunk 8/14 | chars 874-1072]
#   RAW: 'espondilodiscitis L5-S1\nafectación de partes blandas circundantes\nabsceso de psoas bilateral de pequeño tamaño'
#   [chunk 9/14 | chars 1073-1166]
#   RAW: 'antibiotico\nciprofloxacino 400mg/12h'
#   [chunk 10/14 | chars 1167-1288]
#   RAW: 'drenaje transcutáneo de las colecciones del psoas'
#   [chunk 11/14 | chars 1288-1512]
#   RAW: 'abscesos de psoas bilaterales\nespondilodiscitis en L5-S1'
#   [chunk 12/14 | chars 1513-1701]
#   RAW: 'intervenido por el servicio de urología y neurocirugía\ndiscectomía L5-S1'
#   [chunk 13/14 | chars 1702-1889]
# ...
#   [chunk 15/17 | chars 3053-3134]
#   RAW: 'cierre del orificio herniario\nsutra contínua de seda 0/0'
#   [chunk 16/17 | chars 3135-3259]
#   RAW: 'postoperatorio\nalta clínica'
#   [chunk 17/17 | chars 3260-3307]
#   RAW: 'control postoperatorio al mes'
# [242/250] es-S1887-85712012000400006-1.txt | 32.89s | 17 chunks | 33 menciones
#   [chunk 1/13 | chars 0-274]
#   RAW: 'urgencias\ndesorientación\ndificultad en la articulación del lenguaje\nemisión y comprensión conservadas\nvisión borrosa\nvisión doble vertical'
#   [chunk 2/13 | chars 275-356]
#   RAW: 'pérdida de conciencia\npalpitaciones\ndolor torácico\nfiebre'
#   [chunk 3/13 | chars 356-532]
#   RAW: 'exfumador\nhipertensión arterial\ndislipidemia'
#   [chunk 4/13 | chars 532-751]
#   RAW: 'paresia del IV par craneal del ojo derecho\nafectación incompleta del III par bilateral\nVI par derecho de predominio inferior'
#   [chunk 5/13 | chars 752-797]
#   RAW: 'pares craneales'
#   [chunk 6/13 | chars 798-911]
#   RAW: 'Romberg negativo\nno dismetrías\nsignos meníngeos'
#   [chunk 7/13 | chars 912-1000]
#   RAW: 'alteración de la marcha\nlateropulsión hacia la derecha'
#   [chunk 8/13 | chars 1000-1343]
#   RAW: 'hemograma\nbioquímica\nestudio de coagulación\nradiografía simple de tórax\nelectrocardiograma\ntomografía computerizada (TC) craneal'
#   [chunk 9/13 | chars 1343-1492]
#   RAW: 'diplopia\noclusión monocular alternante\ninestabilidad\ntrastorno de la marcha'
#   [chunk 10/13 | chars 1492-1824]
#   RAW: 'estudio con RM encefálica\nresonancia Philips de 1,5 T\nmicroinfartos solitarios en sustancia blanca profunda\nlesiones isquémicas agudas de localización paramedial en ambos tálamos y mesencéfalo anterior\nobstrucción de la arteria de Percheron'
#   [chunk 11/13 | chars 1825-1931]
#   RAW: 'Flair\nDifusión'
#   [chunk 12/13 | chars 1931-2108]
#   RAW: 'anticogulación oral\ndabigatrán\nelevado riesgo de recurrencia'
#   [chunk 13/13 | chars 2109-2269]
#   RAW: 'evolución de la paciente\nrehabilitador\nautonomía de la marcha\ndiplopía'
# [243/250] es-S1887-85712014000100005-1.txt | 29.13s | 13 chunks | 43 menciones
#   [chunk 1/21 | chars 0-234]
#   RAW: 'antecedentes de hipertensión arterial\ncarcinoma de recto tratado 15 años atrás con radioterapia, cirugía y quimioterapia'
#   [chunk 2/21 | chars 235-357]
#   RAW: 'Unidad de Dolor\nopioide'
#   [chunk 3/21 | chars 357-745]
#   RAW: 'SCASEST-Killip III\nIntervención Coronaria Percutánea primaria\nstents'
#   [chunk 4/21 | chars 746-996]
#   RAW: 'punción de cateterismo\nformación de hematoma\ncara volar de antebrazo derecho'
#   [chunk 5/21 | chars 996-1242]
#   RAW: 'dolor\nexacerbado con la extensión passiva de dedos'
#   [chunk 6/21 | chars 1242-1253]
#   RAW: 'Palidez'
#   [chunk 7/21 | chars 1253-1307]
#   RAW: 'imposibilidad para detectar pulso radial o cubital'
#   [chunk 8/21 | chars 1307-1373]
#   RAW: 'Disminución de la temperatura'
#   [chunk 9/21 | chars 1373-1425]
#   RAW: 'anestesia\nparálisis total del miembro afectado'
#   [chunk 10/21 | chars 1425-1655]
#   RAW: 'medición de la presión intracompartimental\nIntra-Compartmental pressure monitor system de Stryker®'
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'síndrome compartimental agudo\nantebrazo derecho\ntratamiento quirúrgico urgente'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: 'anestesia general balanceada\ncontrol de la vía aérea\nmascarilla laríngea'
#   [chunk 13/21 | chars 1907-1969]
#   RAW: 'profilaxis antibiótica\nCefazolina intravenosa'
#   [chunk 14/21 | chars 1970-2110]
#   RAW: 'incisión cutánea\nlínea media\nflexura del codo\nlínea de Kaplan'
#   [chunk 15/21 | chars 2111-2191]
#   RAW: 'tejido celular subcutáneo\ninfiltrado por hematoma'
#   [chunk 16/21 | chars 2192-2410]
#   RAW: 'sección longitudinal de la fascia antebraquial\nexposición de la musculatura epitroclear del antebrazo\ndescompresión del nervio mediano'
#   [chunk 17/21 | chars 2411-2487]
#   RAW: 'lesiones vasculares\nsignos de sangrado activo arterial'
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'cierre quirúrgico\nmalla con elásticos vasculares\nvendaje no compresivo'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: 'fasciotomía\ncoloración\ntemperatura\npulso arterial'
#   [chunk 20/21 | chars 2901-3087]
#   RAW: 'cirugía\nreevaluada\nrelleno capilar\nmovilidad\nsensibilidad distal\nno refiriendo clínica de dolor'
#   [chunk 21/21 | chars 3088-3211]
#   RAW: 'antebrazo derecho\nvasculonervioso distal'
# [244/250] es-S1887-85712016000100005-1.txt | 38.99s | 21 chunks | 49 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: 'coxalgia derecha\ncaracterísticas mecánicas'
#   [chunk 2/22 | chars 128-229]
#   RAW: 'dolor\nmovilidad en ciertas posturas'
#   [chunk 3/22 | chars 230-429]
#   RAW: 'bicicleta\ncarrera\nmarcha'
#   [chunk 4/22 | chars 430-528]
#   RAW: 'dolor\nmarcha'
#   [chunk 5/22 | chars 528-725]
#   RAW: 'dolor a la palpación\nregión inguinal derecha\nflexión\naducción\nrotaciones\nmaniobra de choque positivo'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'flexión 110o bilateral\nrotación interna de 10o derecha, 40o izquierda\nrotación externa de 30o derecha, 40o izquierda'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'escala de Daniels\nglobal bilateral'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'puntos ciáticos\nmaniobras de Valleix\nFabere\nLasegue\nBragard\nnegativas'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'palpación\ncinitla iliotibial\ntest de ober'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'marcha\nclaudicación\napoyo monopodal alterno derecho-izquierdo\nTrendelenburg negativo'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'dolor para la marcha\nflexión forzada de cadera y rodilla'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'deformidad en forma de joroba\nregión cérvico-cefálica femoral derecha'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'hemograma\nbioquímica\nhormonas tiroideas\nanticuerpos\nreactantes de fase aguda'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'resonancia magnética de cadera\nleve alteración subcondral\nedema óseo\nirregularidad cortical\nleve sinovitis\ndistensión de la bursa ilio-psoas'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'cabeza femoral\nislote óseo\nángulo alfa superior a 50º'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'artrografía\npinzamiento de la interlinea articular antero-superior y posteroinferior\ncollare osteofitario femoral\nlesiones subcondrales antero-superiores de cabeza femoral\nfocos de edema en acetábulo anterosuperior'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'necrosis avascular\nlabrum'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'lesión quística yuxtaarticular'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'síndrome de pinzamiento femoroacetabular\nmagnetoterapia'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'sulfato de glucosamina-condroitin sulfato oral\nantiinflamatorios no esteroideos a demanda'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'reposo deportivo\nactividad física activa controlada\nflexión de la cadera\nrotaciones'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'valoración de cirugía artroscópica'
# [245/250] es-S1888-75462015000400006-1.txt | 45.17s | 22 chunks | 64 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'fractura de tercio medio de clavicula derecha\nfractura de arcos costales derechos'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'hemodinámicamente estable\nsin disnea\ndolor a nivel de clavícula y pared costal derechos'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'fractura de arcos costales derechos cuarto y quinto\nsin evidencia de hemotórax ni neumotórax\ntercer fragmento de la clavicula derecha'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'analgesia\nantiinflamatorios no esteroideos\nvendaje en ocho'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'espirometría\nelectrocardiograma\necocadiograma\nanalítica sanguinea\nCHCM\nneutrófilos\nlinfocitos\neosinófilos\nfibrinógeno\nGGT\nD-DiMero positivo'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'trombosis venosa\nvenas axilar, cefálica y basílica\ncompresión de la rama cubital del nervio cutáneo braquial medial a nivel del hiato basílico'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'síntomas\nvenas trombosadas'
# [246/250] es-S1888-75462016000400180-1.txt | 18.08s | 7 chunks | 20 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'paciente de 58 años'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomía'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'osteoporosis densitométrica\ndenosumab\nsuplementos de vitamina D'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'dolor mecánico\nAINEs'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'antepié izquierdo'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'estática de pies'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Rx de pies\nhallazgos patológicos'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'fractura de estrés\ncallo periótico\nedema de tejidos blandos'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'estudio analítico\nincremento de los niveles de PTH y vitamina D\nsuplementación de vitamina D\nfunción renal normal\ncalcio sérico y urinario normal'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'suspendió el tratamiento con suplementos de vitamina D\ndenosumab'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'valorada por el servicio de traumatologia\ntratamiento conservador\ndescarga\nreposo relativo\nAINEs\nmagnetoterapia\nmejoría progressiva'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'SERMS\nsuplementos de calcio con vitamina D'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'Rxt\nfractura de estrés'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'edema de 1er y 3er MTT\nhuesos cuneiforme, escafoides y astrágalo\ntenosinovitis del tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'densitometría ósea\nT-score'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'bazedoxifeno\nvitamina D\ndensidad mineral ósea'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'rehabilitación\ndescarga'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'osteoporosis\nfactor predisponente\npaciente no era obesa\nno había presentado traumatismos\notros factores de riesgo'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'dolor\nmes\nestación\naño'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'tipo de calzado'
# [247/250] es-S1889-836X2015000200005-2.txt | 34.15s | 20 chunks | 44 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'infección por VIH\ndidanosina\ntenofovir\nlopinavir/ritonavir'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'revisiones ambulatorias\nastenia\ndolores óseos difusos'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'determinaciones\nfosfatasa alcalina\nparatohormona'
#   [chunk 4/16 | chars 408-569]
#   RAW: 'elemental y sedimento de orina'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'radiografía simple de columna\ngamamgrafía con Tc99'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'astenia\ndisminución de fuerza\ndificultad para caminar\npérdida de 7 kg de peso'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'debilidad muscular de predominio proximal'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperglucemia leve\nglucosuria marcada\nhipofosfatemia\nfosfaturia inapropiadamente alta\nhipouricemia\nligera acidosis metabólica\nproteinuria'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'aminoaciduria moderada\nvalina\nserrina\ntreonina'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'FGF23 sérico'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'Tabla 1'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'síndrome de Fanconi incompleto\nhipofosfatemia grave\nosteomalacia\nTDF'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'fármaco\nraltegravir\ndarunavir potenciado con ritonavir'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'suplementos de fósforo\n25-HCC\n1,25-dihidroxivitamina D'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'mejorando progresivamente'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'dolores óseos\ndebilidad muscular\npeso basal\nalteraciones analíticas séricas\nreabsorción de fosfato'
# [248/250] es-S1889-836X2015000400006-1.txt | 29.84s | 16 chunks | 45 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'astenia\nlupus cutáneo\neritema malar'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'tiroiditis de Hashimoto'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'apendicectomía'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'exfumador/a'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'no bebedora'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'hábitos tóxicos\nquinina'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'anemia\npartos'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'cesárea\nligadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'astenia\npresíncopes\nanorexia'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'duración\nabundancia'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'palidez cutánea y mucosa'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'epistaxis\ngingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'anemia\nhemoglobina\ntrombopenia\nplaquetas'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'esquistocitos'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'resto de exploraciones normales\ndiagnóstico: según los datos clínicos y de laboratorio, la paciente presenta un cuadro compatible de PTT en el contexto del LES'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'concentrado de hematíes\nconcentrado de plaquetas'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'afasia global\ndevoluelve un texto vacio'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'lenguaje normal'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'ingreso en hematología\nestudio de síntomas neurológicos'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'microangiopatía trombótica\nplasmaféresis'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'UCI'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'plasmaféresis\nrecambio\nvolumen plasmático'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'prolongarse\nrespuesta'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'peso'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'relación\ntotal de 3.500 cc'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'reinfundir\nprograman: 1.750 cc'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'plasma fresco\ncc'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'albúmina humana al 20%\n1.400 cc'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'Dianeal 1,36 % de diálisis peritoneal'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'plasmaféresis\nyugular derecha\nfemoral izquierda'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE\nPTE-2000'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'heparina\nduración de las sesiones\ninfusión media\nflujo sanguíneo\npresión arterial'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'PV\nPTM'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'estado general\nconstantes mantenidas'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: 'sesiones'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'sesión\nagitación'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'hipotensión\nconvulsiones\ndiazepam\nsalino fisiológico'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'PTM\nfaltaban 50 minutos\nfinalizando la sesión'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'fallo del test de aire\ncambiar el SET'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'sesión\ntolerado'
# [249/250] es-S2254-28842014000200009-1.txt | 56.94s | 40 chunks | 65 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'intervenida\ncarcinoma seroso papilar\nafectación de un ganglio de la cadena aorto-cava'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'quimioterapia adyuvante\ncarboplatino\npaclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'seguimiento\nelevación del marcador tumoral\nCA 125'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'resección anterior de recto superior\nbiopsia intraoperatoria de una lesión hepática'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'carboplatino\npaclitaxel\nCA 125'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'carboplatino\ndisnea\nvómitos\npérdida de conocimiento\nTAS/TAD de 70/50 mmHg'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'infusión\ncorticoides'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'esquema de desensibilización\nenlentecimiento de la velocidad de infusión'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'disolución\npremedicación\ncetrizina\nprednisona\nranitidina\nmontelukazt'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'quimioterapia\ntrabecedentina\nadriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'tercer ciclo\nmarcadores\nsexto ciclo\nlibre de enfermedad'
# [250/250] es-S2340-98942015000100005-1.txt | 21.93s | 11 chunks | 30 menciones
#
# Predicciones guardadas en proctemist_llm_predictions.tsv
# Tiempo medio por archivo: 29.78s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd

def prf(tp, fp, fn):
    p = tp / (tp + fp) if (tp + fp) else 0.0
    r = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1

df_pred = pd.read_csv(PREDICTIONS_TSV, sep='\t')
df_gs = pd.read_csv(GS_TEST_TSV, sep='\t')
df_gs = df_gs[df_gs['filename'].isin(df_pred['filename'].unique())]

set_gs = set(zip(df_gs['filename'], df_gs['label'], df_gs['start_span'], df_gs['end_span']))
set_pred = set(zip(df_pred['filename'], df_pred['label'], df_pred['start_span'], df_pred['end_span']))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1 = prf(tp, fp, fn)

report = {'Estricta': {'tp': tp, 'fp': fp, 'fn': fn,
                       'precision': round(p, 4), 'recall': round(r, 4), 'fscore': round(f1, 4)}}

print(f'── ESTRICTA ── P={p:.4f} R={r:.4f} F1={f1:.4f} (TP={tp} FP={fp} FN={fn})\n')

thresholds = [0.0, 0.5, 0.8]
results = {t: {'tp': 0, 'fp': 0, 'fn': 0} for t in thresholds}

for filename in df_pred['filename'].unique():
    gs_ints = list(zip(df_gs[df_gs['filename'] == filename]['start_span'],
                       df_gs[df_gs['filename'] == filename]['end_span']))
    pred_ints = list(zip(df_pred[df_pred['filename'] == filename]['start_span'],
                         df_pred[df_pred['filename'] == filename]['end_span']))
    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )
    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi)
                matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ── P=0.1560 R=0.4052 F1=0.2253 (TP=1466 FP=7930 FN=2152)
#
# ── IoU ──
# IoU >= 0.0:  P=0.2323  R=0.6032  F1=0.3355  (TP=2183 FP=7213 FN=1436)
# IoU >= 0.5:  P=0.1872  R=0.4860  F1=0.2703  (TP=1759 FP=7637 FN=1860)
# IoU >= 0.8:  P=0.1583  R=0.4109  F1=0.2285  (TP=1487 FP=7909 FN=2132)
