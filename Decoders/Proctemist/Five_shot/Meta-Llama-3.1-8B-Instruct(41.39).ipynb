# %% [markdown]
# # Pipeline Five-Shot NER — ProcTemIST con Meta-Llama-3.1-8B-Instruct
#
# Inferencia five-shot para reconocimiento de procedimientos en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo PROCEDIMIENTO medico (exploraciones, pruebas diagnosticas, intervenciones, tratamientos, cirugias, etc.).\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'radiografia', no escribas 'Rx'.\n"
    "4. REPETICIONES: Si un procedimiento aparece varias veces en el texto, debes listarlo varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio.\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Distemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
PROCTEMIST_ROOT      = f"{PROJECT_ROOT}/proctemist"
TEXT_FILES_TEST_DIR  = f"{PROCTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{PROCTEMIST_ROOT}/medprocner_tsv_test_subtask1.tsv"
PREDICTIONS_TSV      = "proctemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary_proctemist.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# ==((====))==  Unsloth 2026.6.8: Fast Llama patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.562 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/5.70G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# Unsloth: Will load unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit as a legacy tokenizer.
# Modelo cargado: unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit
# Parámetros totales: 4,540,600,320

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    """Divide el texto en chunks de oraciones completas con sus offsets.
    Si max_chars es None, devuelve una oración por chunk."""
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

EXAMPLES = [
    {
        "text": "En la exploración física destaca palidez de piel, Tª: 37,2 ºC y en la auscultación pulmonar crepitantes en base derecha.",
        "mentions": "exploración física\nauscultación pulmonar",
    },
    {
        "text": "Paciente de 38 años, con amputación de antepié izquierdo por arteriopatía por enfermedad de Buerger.",
        "mentions": "amputación de antepié izquierdo",
    },
    {
        "text": "Dada la edad de la enferma y con el diagnóstico de neoplasia de cabeza de páncreas, se optó por tratamiento paliativo con colocación de endoprótesis (endoprótesis biliar tipo wall stent de 10 x 70 mm de longitud) quedando alojada desde colédoco proximal hasta el interior de la luz duodenal.",
        "mentions": "tratamiento paliativo\ncolocación de endoprótesis\nendoprótesis biliar tipo wall stent",
    },
    {
        "text": "La paciente se mantuvo en DPA hasta agosto de 2002, momento en el que se le realiza un trasplante renal, precisando trasplantectomía por trombosis.",
        "mentions": "DPA\ntrasplante renal\ntrasplantectomía",
    },
    {
        "text": "Los padres activaban el aparato en casa para lograr la expansión y una vez por semana nosotros modificábamos la tensión de las cadenetas para lograr la retrusión de la premaxila.",
        "mentions": "expansión\nmodificábamos la tensión de las cadenetas\nretrusión de la premaxila",
    },
]

def build_ner_messages(text):
    messages = [{"role": "system", "content": SYSTEM_PROMPT}]
    for ex in EXAMPLES:
        messages.append({"role": "user",      "content": f"Texto para analizar:\n{ex['text']}"})
        messages.append({"role": "assistant", "content": ex["mentions"]})
    messages.append({"role": "user", "content": f"Texto para analizar:\n{text}"})
    return messages

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            result = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                # Fallback: reintentar desde el inicio del chunk
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename":   txt_path.stem,
            "ann_id":     f"T{mark_idx}",
            "label":      "PROCEDIMIENTO",
            "start_span": off0,
            "end_span":   off1,
            "text":       span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "ann_id", "label", "start_span", "end_span", "text"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'vacío'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'dolor lumbar derecho'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'exploración física'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'ultrasonido abdominal\nmasa suprarrenal derecha'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'urograma descendente'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'TAC helicoidal\ntumor suprarrenal'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'estudio hormonal'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'cirugía\nabordaje lumbar'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'tumor'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'adrenalectomía derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'evolución post operatoria'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'corte'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'examen histopatológico\nmielolipoma'
# [1/250] S0004-06142006000100010-1.txt | 19.62s | 13 chunks | 16 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'gastrectomía subtotal'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'análisis vacío'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'exploración física\ntumoración'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'ascitis por carcinomatosis\nobstrucción intestinal tumoral\ntumoración abdominal'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'análisis de sangre'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'marcadores tumorales hepáticos\nmarcadores tumorales digestivos'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'gastroscopia\npólipo inflamatorio en muñón gástrico'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'colonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'ecografía abdominopélvica'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'exploración'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'lesión quística intraabdominal\nurografía intravenosa'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'TAC'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'imagen cálcica\ncompresión'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'hidronefrosis gigante\ndrenaje percutáneo\nnefrectomía'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'nefrectomía simple derecha\nlumbotomía subcostal'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'linfadenectomía hiliar ampliada'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'cultivo del fluido'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'examen histológico'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'displasia'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'infiltración ganglionar de carcinoma de células renales tipo célula clara'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'metástasis hepáticas'
# [2/250] S0004-06142006000100014-1.txt | 29.65s | 21 chunks | 26 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'dolor a nivel de hipogastrio\neyaculación dolorosa\nhemospermia\nvaricocele derecho'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'prostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'exploración física\nvaricocele derecho'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'tacto rectal\nexploración'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'ecografía urológica\nimagen nodular hipoecoica\nhipervascularización circundante\nquiste simple en testículo izquierdo'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'TAC abdómino-pélvica'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'RMN'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'Rx de tórax'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'marcadores tumorales\nPSA'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'Alfa-feto-proteína\nbeta-HCG\nPSA'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'formación nodular'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'tumor de células de Leydig'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'controles evolutivos'
# [3/250] S0004-06142006000500002-2.txt | 21.82s | 14 chunks | 25 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'orquidopexia'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'cólicos nefríticos\nexpulsión de litiasis\ntratamiento con LEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'ureterolitectomía'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'vacío'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'consultó al urólogo\nesterilidad\nexploración de nódulo en testículo izquierdo'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'espermiograma\nazoospermia total'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'ecografía-doppler\nmasa de 19 x 23 mm\nflujo aumentado'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'exploración física\npalpaba\nquiste de epidídimo'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'explorar'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'estudio'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'Rx de tórax\nTAC toraco-abdómino-pélvico'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'analítica\nvalores séricos hormonales\nmarcadores tumorales\nalfa-fetoproteina\nbeta-HCG'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'orquiectomía radical inguinal derecha\nbiopsia del testículo izquierdo'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'exploración macroscópica'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'exploración de superficie testicular'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'corte'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'El texto no menciona un procedimiento médico.'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'alteraciones'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'biopsia'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'tumor de células de Leydig'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'atrofia\nhiperplasia de células de Leydig\nausencia de espermiogénesis'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'bordes quirúrgicos'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'biopsia\natrofia testicular\nausencia de espermiogénesis\nhiperplasia de células de Leydig intersticial'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'controles evolutivos'
# [4/250] S0004-06142006000500002-3.txt | 43.93s | 25 chunks | 40 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'ecografía'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'TAC abdomino-pélvica'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'nefrectomía radical derecha\nlaparotomía subcostal'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'carcinoma renal'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'cirugía'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'seguimiento de su neoplasia'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'exploración\nTAC\nrecidiva tumoral\nimplantes peritoneales'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'extirpación de las masas tumorales\nresección\nbiopsia intraoperatoria'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'exploración'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'tratamiento con Interferón (Intrón A)'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'revisiones\nTAC de abdomen\ncirugía\nlesiones hepáticas\ncrecimiento de la recidiva del lecho quirúrgico\nimplantes peritoneales en epiplon'
# [5/250] S0004-06142006000900015-1.txt | 21.72s | 11 chunks | 19 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'vacío'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'estudio\necografía'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'No hay entidades de tipo PROCEDIMIENTO médico en este texto.'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'vacío'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'palpa\nteste izquierdo hipotrófico\nteste derecho'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'vacío'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'epidídimos'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'hemostasia\nbioquímica\nhemograma\nalfa-feto proteína\nbeta-hCG'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'ecografía con flujo Doppler'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'teste izquierdo'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'microlitiasis testiculares'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de tórax\nTAC toraco-abdomino-pélvico con contraste'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'orquiectomía bilateral\ntratamiento hormonal sustitutivo'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'anatomía patológica\ntestículo izquierdo'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'tumoración\nseminoma clásico\nneoplasia intratubular de células germinales (NICG)\natrofia'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'túnica albugínea\nrete testis\nepídimo\nborde quirúrgico'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'quimioterapia\nciclos de quimioterapia\ncarboplatino'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'vacío'
# [6/250] S0004-06142007000200017-1.txt | 32.94s | 18 chunks | 30 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'No se encontraron entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'aumento progresivo de los órganos genitales externos\ntrasudación de la linfa'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'examen físico'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'adenopatías inguinales'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'estudios complementarios'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'serología'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Prueba de Mantoux\nRX de cadera'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'U/S abdominal\nTAC simple'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'exploración retroperitoneal derecha'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'adenectomía de ilíaca derecha\nadenectomía de cava'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'linfangioplastia'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'fasciotomía'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'Quiluria'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: 'linfedema primario inflamatorio local de pene y escroto'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: 'necrosis aséptica de la cabeza del fémur'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'valoración\ncirugía plástica'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'evacuación de la linfa\ndistorsión\natrapamiento de los conductillos linfáticos\ntejido conjuntivo fibroso'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'extirpación'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'recubrimiento de los testículos\nextirpado'
# [7/250] S0004-06142007000600012-1.txt | 34.49s | 20 chunks | 24 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'exploración'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'exploración\npalpación'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'determinación de marcadores tumorales\ndeterminación de hormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'ecografía'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'estudio de RNM'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'exéresis quirúrgica\ntumoración paratesticular'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'El texto no menciona procedimientos médicos.'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'estudio macroscópico'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'estudio microscópico'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'estudio inmunohistoquímico\nexpresión para desmina\nexpresión para vimentina\nexpresión para actina de músculo liso específica'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'No se encontraron menciones de procedimientos médicos en el texto.'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'No se encontraron entidades de tipo PROCEDIMIENTO médico en el texto.'
# [8/250] S0004-06142007000600014-1.txt | 22.24s | 12 chunks | 11 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'herida de arma de fuego'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'herida de bala\nexploración'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'defensa abdominal'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'radiografía simple de abdomen\nfractura de la rama descendente derecha'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'sondaje\ncatéter suprapúbico'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'laparotomía\ncolostomía izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'uretrografía'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'intervención\ncolonoscopia\nperforación rectal'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'introducción de un uretrotomo endoscópico\nvisualización'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'sonda'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'laparotomía'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'disecar el espacio de Retzius\npalpa la cara anterior de la próstata\ncontrol radiológico'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'pinza de anillo\nextraer la bala'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'postoperatorio'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'colonoscopia\ncolostomía'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'No hay entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'uretrografía'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'ultrasonido'
# [9/250] es-S0004-06142007000900010-1.txt | 29.93s | 18 chunks | 24 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'apendicectomía\nhernia discal\nhernia de hiato\nfractura de tibia\nfractura de peroné\ncólico nefrítico'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'estudio ecográfico'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'TAC\nmasa a nivel cortical de riñón derecho'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'nefrectomía radical derecha\nlaparoscopia'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'estudio macroscópico'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'estudio microscópico'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'estudio inmunohistoquímico\ndeterminación de vimentina\ndeterminación de citoqueratina 7\ndeterminación de citoqueratina de amplio espectro\ndeterminación de CD34\ndeterminación de cromogranina\ndeterminación de EMA'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'No se encontraron menciones de procedimientos médicos en el texto.'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'No hay entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'expresión generalizada de vimentina\nfocal de citoqueraina 7\nEMA en las células epiteliales\nCD34 en el componente estromal'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'intervención'
# [10/250] es-S0004-06142007000900012-1.txt | 26.15s | 11 chunks | 18 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK\nsinusitis bilateral\nbronquiectasias\ndesprendimiento retina'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'dolor lumbar\nirradia a testículo izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'exploración\naumento del volumen testicular\nneoplasia'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'palpar adenopatías'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'ecografía\ntumor testicular\nseminoma'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'Rx de tórax\nsitus inversus\ncámara de gases gástrica\nbronquiectasias'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'analítica'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'orquiectomía inguinal\ncolocación de prótesis testicular'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'seminoma'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'No se evidencia invasión vascular'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'neoplasia germinal intratubular'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'fibrosis e hialinización tubular de testículo'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'exploración física\npruebas por imágenes'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'orquiectomía\nespermiogramas'
# [11/250] es-S0004-06142008000300011-1.txt | 25.37s | 14 chunks | 26 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'dolor abdominal difuso\nnáuseas\nvómitos biliosos'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'tós'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'vacío'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'vacío'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'exploración física'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'palidez mucocutánea'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'vacío'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'auscultación cardiopulmonar'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'palpación'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'circulación colateral'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'No hay entidades de tipo PROCEDIMIENTO médico en este texto.'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'trombosis venosa profunda'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'análisis bioquímica\naumento de transaminasas\nanálisis de GOT\nanálisis de GPT'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'hemograma'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'hemostasia'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'TC\ntrombo'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'exploración de venas suprahepáticas'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'oclusión completa de la luz de VCI'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'anormalidad inespecífica de cabeza de páncreas'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'TC\nECO abdómino-pélvica'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'excisión de lipoma'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'colecistitis\nperforada\npancreatitis'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'TC'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'diagnóstico diferencial'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'TC\nderrame pleural bilateral\nengrosamiento de pliegues gástricos\naumento de la captación de contraste\nangiomiolipoma (AML)'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'exploración'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'hepatomegalia\naumento de calibre de vena porta\nretardo de la llegada de contraste a las mismas\nedema periportal\nexploración'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'paracentesis'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'trasudado'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'ecografía transesofágica\nderrame pericárdico'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'diagnóstico de Síndrome de Budd-Chiari'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'intervención quirúrgica'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'intervención quirúrgica'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'trombo\ncirugía'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'incisión tipo Chevron\nacceso a retroperitoneo\napertura desde asa fija hasta hiato de Winslow\nliberación ascendente del paquete intestinal\nligadura de vena mesentérica inferior'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'movilización hepática\nseccionando los ligamentos redondo\nseccionando los ligamentos coronario\nseccionando los ligamentos triangulares derecho\nseccionando los ligamentos triangulares izquierdo\nseccionando los ligamentos falciforme'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'liberación del riñón izquierdo\nliberación del hilio correspondiente\nliberación de la vena cava\nsección del resto de ramas'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'ampliación del hiato diafragmático\nexprimir el trombo'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'clampaje de pedículo hepático\nmaniobra de Pringle\nVCI proximal\nVCI distal\nVRD\ncavotomía\napertura VRI\nnefrectomía izquierda'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'angiomiolipoma'
# [12/250] es-S0004-06142008000300012-1.txt | 77.23s | 40 chunks | 56 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'cólico nefrítico\nhematuria'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'tratamiento con diclofenaco'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'litiasis en el grupo calicial medio del riñón derecho\necografía\nquiste renal gigante\nradiografía'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'TAC\nquiste renal simple'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'serología de hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'hemograma'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'tratada del quiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'No se encontraron entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'drenaje percutáneo\nesclerosis del quiste'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'cistitis'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'tratamiento antibiótico'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'drenaje percutáneo'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'No se encontraron entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'calcificación'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'TAC'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'microhematuria\nleucocituria'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'cólico derecho\ncistitis'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'litiasis'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'infección urinaria\ntratamiento con Amoxicilina-Clavulanico\ntratamiento con Trimetropin-Sulfametoxazol'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'litiasis\nlitotricia extracorpórea'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'vacío'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'TAC'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Bosniak IIF'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'ecografías de control\nUIV\nTAC'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'vacío'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: '(No se encontraron procedimientos médicos en el texto)'
# [13/250] es-S0004-06142008000300013-1.txt | 43.13s | 26 chunks | 31 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'prostatectomía\nlinfadenectomía obturatriz'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'cirugía prostática\necografía\nestudio doppler'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'TAC abdominal'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'TAC post orquiectomía\nadenopatías retroperitoneales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'orquiectomía inguinal\nquimioterapia citorreductiva\nR-CHOPx8'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'tratada en segunda línea mediante esquema IFOVM / DHAP'
# [14/250] es-S0004-06142008000400011-2.txt | 12.28s | 6 chunks | 12 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'ninguno'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'metrorragias\ndolor abdominal'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'No hay entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'ecografía vaginal\nmasa anexial izquierda'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'estudio de estadificación\nTC abdómino-pélvico\nrealización de TC abdómino-pélvico'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'exploración'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'lesión sólido-quística'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'adenopatías regionales\nimplantes metastásicos peritoneales'
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'histerectomía total\ndoble anexectomía\nnefrectomía radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'estudio histológico intraoperatorio\nmetástasis'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'diagnóstico histológico renal'
# [15/250] es-S0004-06142008000400013-1.txt | 20.26s | 11 chunks | 16 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'gastrectomía\nprostatectomía radical'
#   [chunk 2/10 | chars 402-554]
#   RAW: 'lesión exofítica'
#   [chunk 3/10 | chars 555-713]
#   RAW: 'lesión'
#   [chunk 4/10 | chars 713-944]
#   RAW: 'exploración'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'biopsia\nlinfadenectomías'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'análisis anatomopatológico intraoperatorio'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'resección\npenectomía subtotal\nlinfadenectomía inguinal superficial bilateral'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'TAC tóracoabdominal'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'penectomía'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'análisis inmunohistoquímico\nS-100\nHMB 45'
# [16/250] es-S0004-06142008000400016-1.txt | 16.74s | 10 chunks | 16 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'histerectomía abdominal\nanexectomía'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'exploración\npalpación profunda de fosa lumbar derecha\npercusión y palpación de fosa lumbar izquierda'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'urografía intravenosa (UIV)\nTomografía computerizada (TAC)'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'TAC\nimagen lobulada de contenido líquido\nextravasación de contraste'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'estudio preoperatorio\nureterolisis\nexéresis del urinoma\nanastomosis termino-terminal del uréter'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'cirugía\nretirada del catéter doble J'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: 'evolución'
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'intervención\nUIV'
# [17/250] es-S0004-06142008000500009-1.txt | 17.25s | 8 chunks | 18 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: 'infecciones urinarias'
#   [chunk 2/15 | chars 191-608]
#   RAW: 'histerectomía vía vaginal\nabsceso de cúpula vaginal\nECO\nTC'
#   [chunk 3/15 | chars 609-615]
#   RAW: 'vacío'
#   [chunk 4/15 | chars 616-623]
#   RAW: '(No hay entidades de tipo PROCEDIMIENTO médico en el texto)'
#   [chunk 5/15 | chars 624-646]
#   RAW: 'vacío'
#   [chunk 6/15 | chars 647-660]
#   RAW: 'No hay entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 7/15 | chars 661-672]
#   RAW: 'vacío'
#   [chunk 8/15 | chars 673-706]
#   RAW: 'infecciones de orina'
#   [chunk 9/15 | chars 707-729]
#   RAW: 'G2 A0V2'
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'Rx aparato urinario simple\nlitiasis vesical\necografía transvaginal'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'Rx'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'ecografía transvaginal\ncirugía'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'uretrocistoscopia\nTC pélvico'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'litiasis intravesical por cuerpo extraño\ncistogasomectomía\ncistoslitectomía'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: 'evolución'
# [18/250] es-S0004-06142008000700003-1.txt | 26.08s | 15 chunks | 19 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: 'EPOC'
#   [chunk 2/23 | chars 94-187]
#   RAW: 'fumador'
#   [chunk 3/23 | chars 188-250]
#   RAW: 'vacío'
#   [chunk 4/23 | chars 250-368]
#   RAW: 'uretrorragia\nmicción'
#   [chunk 5/23 | chars 369-484]
#   RAW: 'sondaje urinario\ntalla suprapúbica\nestudio'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'ecografía\ndivertículo'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'ureterotomía\ncistoscopia\nresección transuretral'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'análisis inmunohistoquímico'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'cirugía\ncistectomía parcial\ndiverticulectomía'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: 'No se extrajo ninguna entidad de tipo PROCEDIMIENTO médico.'
#   [chunk 11/23 | chars 1694-1774]
#   RAW: 'necrosis intratumoral\nnecrosis celular aislada'
#   [chunk 12/23 | chars 1775-1808]
#   RAW: 'cambio mixoide'
#   [chunk 13/23 | chars 1809-1849]
#   RAW: 'inflamación intra\ninflamación peritumoral'
#   [chunk 14/23 | chars 1850-1988]
#   RAW: 'infiltración'
#   [chunk 15/23 | chars 1989-2027]
#   RAW: 'margenes quirúrgicos'
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'inmunohistoquímica'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: 'leiomiosarcoma'
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'TAC toracoabdominal\ngammagrafía ósea\nRMN pélvica'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'administración de radioterapia locorregional\nadministración de quimioterapia'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'radioterapia locorregional'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'quimioterapia\nifosfamida\nadriamicina'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'tratamiento\ncistoscopias\ncitología urinaria\nTAC toraco-abdomino-pélvico'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: 'revisiones periódicas'
# [19/250] es-S0004-06142009000400011-1.txt | 40.42s | 23 chunks | 36 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: 'masa testicular\ndolor testicular'
#   [chunk 2/7 | chars 129-182]
#   RAW: 'Niega'
#   [chunk 3/7 | chars 183-346]
#   RAW: 'ecografía testicular'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'orquidectomia'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'estudio histopatológico\ninfiltración difusa del parénquima testicular\nneoplasia maligna hematolinfoide'
#   [chunk 6/7 | chars 734-856]
#   RAW: 'negativas para TdT\nnegativas para CD30\nnegativas para ALK\nnegativas para bcl2\nnegativas para bcl6\nnegativas para CD10'
#   [chunk 7/7 | chars 857-952]
#   RAW: 'diagnóstico de Linfoma no Hodgkin T periférico no especificado'
# [20/250] es-S0004-06142010000100015-1.txt | 14.34s | 7 chunks | 7 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'lesión renal'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'ecografía'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'T.C. abdomino-pélvico\nlesión renal izquierda'
#   [chunk 4/9 | chars 523-567]
#   RAW: 'ausencia de adenopatías retroperitoneales'
#   [chunk 5/9 | chars 567-704]
#   RAW: 'nefroma multilocular quístico\ncarcinoma de células renales quístico'
#   [chunk 6/9 | chars 704-869]
#   RAW: 'renograma isotópico\nTc-99m'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'Gammagrafía ósea'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'lesión renal Bosniak III\nintervención quirúrgica\nnefrectomía'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'nefroma quístico'
# [21/250] es-S0210-48062003000900009-1.txt | 15.91s | 9 chunks | 14 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: 'dolor testicular'
#   [chunk 2/29 | chars 181-260]
#   RAW: 'pérdida de peso'
#   [chunk 3/29 | chars 261-344]
#   RAW: 'fiebre\nsudación profusa\nmiccional\nnohematuria'
#   [chunk 4/29 | chars 345-451]
#   RAW: 'EPOC'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'exploración física\nauscultación pulmonar'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'exploración genital\nedema de cubiertas\naumento de la consistencia del epidídimo\naumento de la consistencia del testículo\ndesaparición del surco epidídimo testicular'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'tacto rectal'
#   [chunk 8/29 | chars 937-1043]
#   RAW: 'hemoglobina'
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'coagulación'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'Lactato deshidrogenasa (LDH)'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'radiografía de tórax\nradiografía de abdomen'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'ecografía renal\necografía vesical'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'ecografía testicular'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'orquiectomía radical'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'tumor testículo'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'microscópicamente\nlinfoma difuso B de células grandes\nmarcadores CD 20+'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'TAC de cuerpo completo de estadiaje\nesplenomegalia\nadenopatías retroperitoneales'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: 'evolución post-quirúrgica'
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'anemia'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'biopsia de medula ósea'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: 'plasmocitosis intersticial\ninfiltración por células linfoblásticas'
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'frotis sanguíneo'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'agregación plaquetaria\ntest de Coombs directo'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'fibroscopia\nlesión polipoidea'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'TAC cervical'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'Rituximab\nciclo de CHOP\nciclofosfamida\ndoxorrubicina\nvincristina\nprednisona'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'tratamiento con quimioterapia\nR-CHOP'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'radioterapia genital\nquimioprofilaxis cerebral'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: 'vacío'
# [22/250] es-S0210-48062004000200011-1.txt | 51.78s | 29 chunks | 48 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: 'aumento de frecuencia miccional nocturna\ndisuria\ndisminución del calibre miccional'
#   [chunk 2/12 | chars 224-442]
#   RAW: 'tacto rectal\necografía abdominal'
#   [chunk 3/12 | chars 442-700]
#   RAW: 'intervención sobre el ojo izquierdo\nureterolitectomía'
#   [chunk 4/12 | chars 700-997]
#   RAW: 'estudio ecográfico\nmasa parahiliar'
#   [chunk 5/12 | chars 997-1381]
#   RAW: 'TAC'
#   [chunk 6/12 | chars 1381-1562]
#   RAW: 'estudio de extensión\nrevisión quirúrgica\nexéresis de la masa\nnefrectomía'
#   [chunk 7/12 | chars 1562-1624]
#   RAW: 'lumbotomía izquierda'
#   [chunk 8/12 | chars 1624-1775]
#   RAW: 'maniobras de disección renal'
#   [chunk 9/12 | chars 1776-1889]
#   RAW: 'biopsia intraoperatoria'
#   [chunk 10/12 | chars 1889-2050]
#   RAW: 'intervención previa\nexéresis\ntumoración'
#   [chunk 11/12 | chars 2050-2234]
#   RAW: 'exéresis'
#   [chunk 12/12 | chars 2234-2418]
#   RAW: 'análisis anatomopatológico'
# [23/250] es-S0210-48062004000500009-1.txt | 21.79s | 12 chunks | 22 menciones
#   [chunk 1/11 | chars 0-130]
#   RAW: 'estudio de epigastralgia\nexploración ecográfica'
#   [chunk 2/11 | chars 130-212]
#   RAW: 'colelitiasis\nhidrocelectomía derecha'
#   [chunk 3/11 | chars 213-358]
#   RAW: 'anamnesis'
#   [chunk 4/11 | chars 359-424]
#   RAW: 'exploración física'
#   [chunk 5/11 | chars 424-618]
#   RAW: 'ecografía\nEco-doppler'
#   [chunk 6/11 | chars 619-824]
#   RAW: 'TC abdomino-pélvica'
#   [chunk 7/11 | chars 825-1174]
#   RAW: 'RNM abdominal\nmasa quística'
#   [chunk 8/11 | chars 1174-1373]
#   RAW: 'exploración quirúrgica\nincisión en el flanco\ntumorectomía'
#   [chunk 9/11 | chars 1373-1584]
#   RAW: 'estudio histológico'
#   [chunk 10/11 | chars 1584-1768]
#   RAW: 'TC\nintervención'
#   [chunk 11/11 | chars 1769-1877]
#   RAW: 'ecografía\nTC'
# [24/250] es-S0210-48062004000800009-1.txt | 17.89s | 11 chunks | 18 menciones
#   [chunk 1/18 | chars 0-125]
#   RAW: 'vacío'
#   [chunk 2/18 | chars 126-342]
#   RAW: 'hematuria franca'
#   [chunk 3/18 | chars 342-444]
#   RAW: 'exploración física\nmasa palpable'
#   [chunk 4/18 | chars 445-481]
#   RAW: 'abdomen'
#   [chunk 5/18 | chars 481-622]
#   RAW: 'estudio ecográfico\nmasa sólida heterogénea'
#   [chunk 6/18 | chars 623-681]
#   RAW: 'ecos internos'
#   [chunk 7/18 | chars 682-723]
#   RAW: 'estudio cistoscópico'
#   [chunk 8/18 | chars 723-815]
#   RAW: 'TAC abdominopélvico\nRx torax\nbioquímica hemática\nhemograma'
#   [chunk 9/18 | chars 815-1067]
#   RAW: 'TC'
#   [chunk 10/18 | chars 1068-1159]
#   RAW: 'trombosada'
#   [chunk 11/18 | chars 1159-1259]
#   RAW: 'anemia ferropénica\naumento de la VSG'
#   [chunk 12/18 | chars 1259-1377]
#   RAW: 'cirugía radical\nembolización selectiva'
#   [chunk 13/18 | chars 1377-1611]
#   RAW: 'arteriografía de aorta abdominal\ncateterización de la arteria renal derecha\ncatéter angiográfico visceral Cobra 2'
#   [chunk 14/18 | chars 1612-1842]
#   RAW: 'embolización\nocluyendo totalmente el flujo'
#   [chunk 15/18 | chars 1842-1978]
#   RAW: 'alta hospitalaria'
#   [chunk 16/18 | chars 1978-2122]
#   RAW: 'embolización\nTC cerebral'
#   [chunk 17/18 | chars 2123-2327]
#   RAW: 'seguimiento'
#   [chunk 18/18 | chars 2328-2451]
#   RAW: 'IECAS'
# [25/250] es-S0210-48062005000300014-1.txt | 28.63s | 18 chunks | 26 menciones
#   [chunk 1/23 | chars 0-303]
#   RAW: 'triple by-pass aorto-coronario'
#   [chunk 2/23 | chars 304-472]
#   RAW: 'micción nocturna\npolaquiuria diurna\nmicción en dos tiempos'
#   [chunk 3/23 | chars 473-537]
#   RAW: 'hematuria'
#   [chunk 4/23 | chars 538-662]
#   RAW: 'exploración física\ntoracotomía'
#   [chunk 5/23 | chars 663-744]
#   RAW: 'palpación rectal\nhiperplasia benigna'
#   [chunk 6/23 | chars 744-859]
#   RAW: 'hemograma\nfunción renal'
#   [chunk 7/23 | chars 859-954]
#   RAW: 'ecografía\nlesión exofítica'
#   [chunk 8/23 | chars 955-1058]
#   RAW: 'citología\ncistoscopia'
#   [chunk 9/23 | chars 1059-1337]
#   RAW: 'análisis de fragmentos tras RTU\ncarcinoma mixto\npapilar de células transicionales\ninfiltrante de músculo liso\nadenocarcinoma mucoide\ninfiltrante\nlesiones de carcinoma in situ\ncistitis glandular quística'
#   [chunk 10/23 | chars 1337-1535]
#   RAW: 'TAC\nengrosamiento de pared vesical\nateromatosis calcificada aorto-ilio-femoral'
#   [chunk 11/23 | chars 1535-1606]
#   RAW: 'cistoprostatectomía\nneovejiga ileal tipo Camey II'
#   [chunk 12/23 | chars 1607-1681]
#   RAW: 'postoperatorio'
#   [chunk 13/23 | chars 1681-2063]
#   RAW: 'análisis histológico'
#   [chunk 14/23 | chars 2064-2101]
#   RAW: 'No se observaban cuerpos de psammoma.'
#   [chunk 15/23 | chars 2102-2257]
#   RAW: 'displasia epitelial en uretra prostática\ncarcinoma de próstata'
#   [chunk 16/23 | chars 2258-2433]
#   RAW: 'linfadenectomía izquierda'
#   [chunk 17/23 | chars 2433-2569]
#   RAW: 'inmunofenotipia\ncitoqueratina 7\nCA125\ncitoqueratina 20\nBX2\nP53\ninmunofenotipia'
#   [chunk 18/23 | chars 2569-2698]
#   RAW: 'quimioterapia\nadministración de carboplatino\nadministración de gencitabina'
#   [chunk 19/23 | chars 2699-2883]
#   RAW: 'transfusiones sanguíneas\nfactores estimulantes de colonias\nfilgastrim'
#   [chunk 20/23 | chars 2883-3084]
#   RAW: 'QMT\necografía\nTAC'
#   [chunk 21/23 | chars 3085-3184]
#   RAW: 'dolores óseos\nanalgesia'
#   [chunk 22/23 | chars 3185-3362]
#   RAW: 'TAC\nintervención'
#   [chunk 23/23 | chars 3363-3520]
#   RAW: 'deterioro progresivo de la función renal'
# [26/250] es-S0210-48062005000400012-1.txt | 46.80s | 23 chunks | 50 menciones
#   [chunk 1/14 | chars 0-252]
#   RAW: 'prostatitis crónica'
#   [chunk 2/14 | chars 253-383]
#   RAW: 'hemograma\nbioquímica\npruebas de coagulación\nradiología convencional'
#   [chunk 3/14 | chars 384-463]
#   RAW: 'hemocultivos'
#   [chunk 4/14 | chars 464-603]
#   RAW: 'estudio serológico\nsero-aglutinación'
#   [chunk 5/14 | chars 603-699]
#   RAW: 'tratamiento con Rifampicina\ntratamiento con doxaciclina'
#   [chunk 6/14 | chars 699-778]
#   RAW: 'recaída'
#   [chunk 7/14 | chars 779-873]
#   RAW: 'exploración\nsigno del psoas'
#   [chunk 8/14 | chars 874-1072]
#   RAW: 'tomografía axial computerizada (TAC)\nespondilodiscitis\nabsceso de psoas'
#   [chunk 9/14 | chars 1073-1166]
#   RAW: 'tratamiento antibiótico'
#   [chunk 10/14 | chars 1167-1288]
#   RAW: 'drenaje transcutáneo de las colecciones del psoas'
#   [chunk 11/14 | chars 1288-1512]
#   RAW: 'TAC\nabscesos de psoas bilaterales\nespondilodiscitis en L5-S1'
#   [chunk 12/14 | chars 1513-1701]
#   RAW: 'drenaje de ambos músculos\ndiscectomía L5-S1'
#   [chunk 13/14 | chars 1702-1889]
#   RAW: 'postoperatorio\ntratamiento antibiótico\ndoxiciclina\nseptrim forte'
#   [chunk 14/14 | chars 1889-2001]
#   RAW: 'cirugía'
# [27/250] es-S0210-48062005000700012-1.txt | 26.43s | 14 chunks | 27 menciones
#   [chunk 1/9 | chars 0-273]
#   RAW: 'vasectomizado'
#   [chunk 2/9 | chars 274-308]
#   RAW: 'vacío'
#   [chunk 3/9 | chars 309-436]
#   RAW: 'exploración física\nhidrocele'
#   [chunk 4/9 | chars 437-494]
#   RAW: 'análisis generales de sangre\nanálisis de orina'
#   [chunk 5/9 | chars 495-675]
#   RAW: 'ecografía escrotal\nneoplasia testicular\nhidrocele'
#   [chunk 6/9 | chars 676-720]
#   RAW: '(Ningún procedimiento médico se menciona en este texto)'
#   [chunk 7/9 | chars 721-814]
#   RAW: 'orquiectomía inguinal izquierda\ncolocación de prótesis testicular siliconada'
#   [chunk 8/9 | chars 815-895]
#   RAW: 'TAC abdominal'
#   [chunk 9/9 | chars 896-1115]
#   RAW: 'infarto testicular'
# [28/250] es-S0210-48062006000200018-1.txt | 15.21s | 9 chunks | 11 menciones
#   [chunk 1/20 | chars 0-213]
#   RAW: 'diagnóstico de masa testicular izquierda'
#   [chunk 2/20 | chars 214-416]
#   RAW: 'palpación\nmasa testicular'
#   [chunk 3/20 | chars 417-715]
#   RAW: 'estudio ecográfico'
#   [chunk 4/20 | chars 716-764]
#   RAW: 'estudio'
#   [chunk 5/20 | chars 765-1091]
#   RAW: 'resonancia nuclear magnética\nRNM'
#   [chunk 6/20 | chars 1092-1094]
#   RAW: 'No hay texto para analizar.'
#   [chunk 7/20 | chars 1094-1121]
#   RAW: 'sin masas\nsin adenopatías'
#   [chunk 8/20 | chars 1122-1164]
#   RAW: 'remisión a urología'
#   [chunk 9/20 | chars 1165-1212]
#   RAW: 'vacío'
#   [chunk 10/20 | chars 1213-1487]
#   RAW: 'examen físico'
#   [chunk 11/20 | chars 1488-1795]
#   RAW: 'palpación\nmasa esférica adenomatosa'
#   [chunk 12/20 | chars 1795-1944]
#   RAW: 'examen físico'
#   [chunk 13/20 | chars 1945-2128]
#   RAW: 'cirugía\nexploración\nresección'
#   [chunk 14/20 | chars 2129-2822]
#   RAW: 'incisión escrotal transversa\ndisección por planos\napéndice testicular\nconducto deferente'
#   [chunk 15/20 | chars 2823-3076]
#   RAW: 'sección\nligadura\nhemostasia exhaustiva\ncorte\nestudio anatomopatológico'
#   [chunk 16/20 | chars 3077-3268]
#   RAW: 'bolsillo en espacio subdartos\nfijado con material de sutura orgánico absorbible'
#   [chunk 17/20 | chars 3269-3370]
#   RAW: 'cierre por planos\nbloqueo del nervio ilioinguinal'
#   [chunk 18/20 | chars 3371-3478]
#   RAW: 'alta'
#   [chunk 19/20 | chars 3479-3595]
#   RAW: 'cortes histológicos'
#   [chunk 20/20 | chars 3596-3633]
#   RAW: 'Sin neoplasia intratubular seminal'
# [29/250] es-S0210-48062006000400012-1.txt | 33.92s | 20 chunks | 29 menciones
#   [chunk 1/10 | chars 0-478]
#   RAW: 'tratamiento antibiótico\nprostatitis aguda'
#   [chunk 2/10 | chars 478-650]
#   RAW: 'exploración\ntumefacción en la zona perineal'
#   [chunk 3/10 | chars 651-736]
#   RAW: 'tacto rectal'
#   [chunk 4/10 | chars 736-917]
#   RAW: 'pruebas complementarias\nleucocitosis'
#   [chunk 5/10 | chars 917-1100]
#   RAW: 'ecografía abdominal\necografía transperineal'
#   [chunk 6/10 | chars 1100-1248]
#   RAW: 'drenaje percutáneo\ncolocación de un catéter suprapúbico'
#   [chunk 7/10 | chars 1249-1377]
#   RAW: 'punción transperineal ecodirigida\ndrenaje'
#   [chunk 8/10 | chars 1377-1517]
#   RAW: 'cultivos'
#   [chunk 9/10 | chars 1517-1642]
#   RAW: 'evolución del paciente\nretirándose'
#   [chunk 10/10 | chars 1643-1786]
#   RAW: 'micción uretral'
# [30/250] es-S0210-48062006000700012-1.txt | 17.60s | 10 chunks | 16 menciones
#   [chunk 1/20 | chars 0-17]
#   RAW: 'vacío'
#   [chunk 2/20 | chars 18-70]
#   RAW: 'hematuria'
#   [chunk 3/20 | chars 71-230]
#   RAW: 'ecografía\nureterohidronefrosis'
#   [chunk 4/20 | chars 231-314]
#   RAW: 'RTU-biopsia'
#   [chunk 5/20 | chars 315-356]
#   RAW: 'estudio de extensión'
#   [chunk 6/20 | chars 357-401]
#   RAW: 'vacío'
#   [chunk 7/20 | chars 402-582]
#   RAW: 'cistoprostatectomía radical laparoscópica\nderivación urinaria tipo Bricker'
#   [chunk 8/20 | chars 582-628]
#   RAW: 'curso operatorio'
#   [chunk 9/20 | chars 629-826]
#   RAW: 'revisión postoperatoria\ncirugía\nureterohidronefrosis izquierda'
#   [chunk 10/20 | chars 826-938]
#   RAW: 'conversión en una derivación continente'
#   [chunk 11/20 | chars 939-1003]
#   RAW: 'ninguna mención de procedimiento médico se encontró en el texto.'
#   [chunk 12/20 | chars 1004-1132]
#   RAW: 'laparotomía exploradora\ndisección pélvica\nidentificación del muñón uretral'
#   [chunk 13/20 | chars 1133-1184]
#   RAW: 'construcción de neovejiga ileal'
#   [chunk 14/20 | chars 1185-1257]
#   RAW: 'tiempo quirúrgico'
#   [chunk 15/20 | chars 1258-1345]
#   RAW: 'alta'
#   [chunk 16/20 | chars 1345-1454]
#   RAW: 'cirugía'
#   [chunk 17/20 | chars 1454-1746]
#   RAW: 'cirugía'
#   [chunk 18/20 | chars 1747-1906]
#   RAW: 'asa de Bricker\nanastomosó'
#   [chunk 19/20 | chars 1907-2008]
#   RAW: 'retiró la sonda vesical'
#   [chunk 20/20 | chars 2009-2080]
#   RAW: 'derivación ortotópica'
# [31/250] es-S0210-48062006000900012-2.txt | 32.33s | 20 chunks | 22 menciones
#   [chunk 1/18 | chars 0-49]
#   RAW: 'vacío'
#   [chunk 2/18 | chars 49-339]
#   RAW: 'circuncidado'
#   [chunk 3/18 | chars 340-457]
#   RAW: 'erecciones matutinas'
#   [chunk 4/18 | chars 457-597]
#   RAW: 'exploración física'
#   [chunk 5/18 | chars 598-888]
#   RAW: 'distribución de vello androide\nprepucio retráctil\nmeato central\nvaricocele grado III\ntestículo izquierdo\ntestículo derecho'
#   [chunk 6/18 | chars 888-1038]
#   RAW: 'estudio de fertilidad'
#   [chunk 7/18 | chars 1038-1155]
#   RAW: 'biometría hemática'
#   [chunk 8/18 | chars 1155-1341]
#   RAW: 'Química sanguínea\nexamen general de orina'
#   [chunk 9/18 | chars 1341-1467]
#   RAW: 'Hormonas'
#   [chunk 10/18 | chars 1467-1583]
#   RAW: 'cultivos de orina\ncultivos de semen\nbúsqueda de Chlamydia\nbúsqueda de Micoplasma\nbúsqueda de Ureaplasma\nbúsqueda de secreción uretral'
#   [chunk 11/18 | chars 1583-1839]
#   RAW: 'análisis de semen'
#   [chunk 12/18 | chars 1839-1901]
#   RAW: 'oligozoospermia\nastenozoospermia\nteratozoospermia'
#   [chunk 13/18 | chars 1901-2025]
#   RAW: 'ultrasonido escrotal\nvaricocele'
#   [chunk 14/18 | chars 2025-2043]
#   RAW: 'cariotipo'
#   [chunk 15/18 | chars 2043-2197]
#   RAW: 'microdeleciones cromosoma Y\nreacción en cadena polimerasa múltiplex de STS cromosoma Y'
#   [chunk 16/18 | chars 2197-2234]
#   RAW: 'sY254\nsY127'
#   [chunk 17/18 | chars 2234-2316]
#   RAW: 'análisis genético'
#   [chunk 18/18 | chars 2316-2421]
#   RAW: 'análisis'
# [32/250] es-S0210-48062007000300014-1.txt | 32.39s | 18 chunks | 28 menciones
#   [chunk 1/8 | chars 0-288]
#   RAW: 'vasectomía'
#   [chunk 2/8 | chars 289-332]
#   RAW: 'negaba'
#   [chunk 3/8 | chars 333-481]
#   RAW: 'exploración\ntumoración perineal\ntumoración paracavernosa izquierda'
#   [chunk 4/8 | chars 481-635]
#   RAW: 'ecografía de partes blandas'
#   [chunk 5/8 | chars 635-730]
#   RAW: 'Resonancia Magnética Nuclear'
#   [chunk 6/8 | chars 731-846]
#   RAW: 'localización'
#   [chunk 7/8 | chars 846-940]
#   RAW: 'estudio bacteriológico\npunción'
#   [chunk 8/8 | chars 940-1080]
#   RAW: 'tratamiento antiagregante'
# [33/250] es-S0210-48062007000700014-1.txt | 12.09s | 8 chunks | 9 menciones
#   [chunk 1/27 | chars 0-214]
#   RAW: 'estudio ecográfico\ntumoración en testículo derecho'
#   [chunk 2/27 | chars 214-285]
#   RAW: 'vacío'
#   [chunk 3/27 | chars 286-319]
#   RAW: 'herniorrafia inguinal bilateral'
#   [chunk 4/27 | chars 319-409]
#   RAW: 'tumoración'
#   [chunk 5/27 | chars 409-514]
#   RAW: 'exploración física\npalpa aumento del testículo derecho\ntumoración'
#   [chunk 6/27 | chars 514-601]
#   RAW: 'pruebas complementarias'
#   [chunk 7/27 | chars 602-759]
#   RAW: 'Ecografía testicular\ntumoración en testículo derecho'
#   [chunk 8/27 | chars 760-783]
#   RAW: 'teste izquierdo'
#   [chunk 9/27 | chars 784-906]
#   RAW: 'tomografía axial computerizada (TAC)\nadenopatías retrocavas\nadenopatías paraaórticas'
#   [chunk 10/27 | chars 907-1226]
#   RAW: 'orquiectomia inguinal derecha'
#   [chunk 11/27 | chars 1227-1464]
#   RAW: 'quimioterapia\nBEP (bleomicina, etopósido y cisplatino)'
#   [chunk 12/27 | chars 1464-1604]
#   RAW: 'tumoración dolorosa'
#   [chunk 13/27 | chars 1604-1732]
#   RAW: 'exploración física\ntumoración indurada'
#   [chunk 14/27 | chars 1732-1912]
#   RAW: 'exploraciones complementarias\nLactato deshidrogenasa (LDH)\nalfafetoproteína (AFP)\nbeta-gonadotropina coriónica (Beta-HCG)'
#   [chunk 15/27 | chars 1913-1961]
#   RAW: 'radiografía de tórax'
#   [chunk 16/27 | chars 1962-2136]
#   RAW: 'ecografía testicular\ntumoración testicular'
#   [chunk 17/27 | chars 2137-2192]
#   RAW: 'calcificación en vertiente anteroinferior de testículo'
#   [chunk 18/27 | chars 2193-2282]
#   RAW: 'tomografía Axial Computerizada'
#   [chunk 19/27 | chars 2283-2325]
#   RAW: 'exploración de riñones'
#   [chunk 20/27 | chars 2326-2366]
#   RAW: 'adenopatías'
#   [chunk 21/27 | chars 2366-2652]
#   RAW: 'orquiectomía radical izquierda'
#   [chunk 22/27 | chars 2652-2696]
#   RAW: 'postoperatorio'
#   [chunk 23/27 | chars 2696-2782]
#   RAW: 'valoración de tratamiento adyuvante\ncontrol'
#   [chunk 24/27 | chars 2783-2915]
#   RAW: 'tratamiento conservador de control'
#   [chunk 25/27 | chars 2915-3431]
#   RAW: 'Tomografía Axial Computerizada\nadenopatía retroperitoneal izquierda\nhidronefrosis'
#   [chunk 26/27 | chars 3431-3556]
#   RAW: 'tratamiento con quimioterapia\netopósido\ncisplatino'
#   [chunk 27/27 | chars 3556-3703]
#   RAW: 'controles periódicos'
# [34/250] es-S0210-48062007001000004-1.txt | 48.17s | 27 chunks | 40 menciones
#   [chunk 1/17 | chars 0-131]
#   RAW: 'dolor hipogástrico\nfiebre\ndisuria'
#   [chunk 2/17 | chars 132-311]
#   RAW: 'tratamiento con captopril\ntratamiento con atorvastatina\ntratamiento con alopurinol'
#   [chunk 3/17 | chars 312-437]
#   RAW: 'exploración física\nmasa palpable'
#   [chunk 4/17 | chars 438-637]
#   RAW: 'análisis del sedimento urinario\nmicrohematuria'
#   [chunk 5/17 | chars 638-741]
#   RAW: 'ecografía abdominal\nabsceso en hipogastrio'
#   [chunk 6/17 | chars 742-1027]
#   RAW: 'TC abdómino-pélvica'
#   [chunk 7/17 | chars 1027-1216]
#   RAW: 'drenaje percutáneo\ntoma de muestras para microbiología\nantibioterapia intravenosa'
#   [chunk 8/17 | chars 1217-1379]
#   RAW: 'cultivos seriados'
#   [chunk 9/17 | chars 1380-1406]
#   RAW: 'No se encontraron entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 10/17 | chars 1406-1712]
#   RAW: 'TC\nenema opaco\ncolonoscopia\ncistoscopia'
#   [chunk 11/17 | chars 1712-1790]
#   RAW: 'laparotomía exploradora'
#   [chunk 12/17 | chars 1791-1922]
#   RAW: 'laparotomía media'
#   [chunk 13/17 | chars 1922-2130]
#   RAW: 'exéresis\napertura accidental'
#   [chunk 14/17 | chars 2131-2310]
#   RAW: 'linfadenectomía ilio-ceco-apendicular\nresección segmentaria apéndico-cecal'
#   [chunk 15/17 | chars 2311-2395]
#   RAW: 'cistoadenoma mucinoso\nmucocele\napendicectomía'
#   [chunk 16/17 | chars 2395-2529]
#   RAW: 'intervención\nherida quirúrgica'
#   [chunk 17/17 | chars 2530-2687]
#   RAW: 'cirugía'
# [35/250] es-S0210-48062009000200019-1.txt | 32.56s | 17 chunks | 32 menciones
#   [chunk 1/14 | chars 0-113]
#   RAW: 'adenomectomia prostática\ncólicos nefríticos izquierdos\núlcus péptico'
#   [chunk 2/14 | chars 114-137]
#   RAW: 'vacío'
#   [chunk 3/14 | chars 138-167]
# ...
#   [chunk 12/18 | chars 1371-1489]
#   RAW: 'pérdida de fuerza\nhipopotasemia\nparálisis periódica'
#   [chunk 13/18 | chars 1490-1884]
#   RAW: 'estudio hormonal'
#   [chunk 14/18 | chars 1885-1976]
#   RAW: 'vitamina D\nPTH'
#   [chunk 15/18 | chars 1977-2140]
#   RAW: 'gammagrafía tiroidea'
#   [chunk 16/18 | chars 2141-2226]
#   RAW: 'Vacío'
#   [chunk 17/18 | chars 2227-2475]
#   RAW: 'tratamiento con potasio intravenoso\nnormalización de las cifras'
#   [chunk 18/18 | chars 2476-2661]
#   RAW: 'tratamiento con metimazol'
# [241/250] es-S1699-695X2015000300013-1.txt | 26.76s | 18 chunks | 19 menciones
#   [chunk 1/17 | chars 0-186]
#   RAW: 'dolor abdominal'
#   [chunk 2/17 | chars 187-277]
#   RAW: 'realización de dos cesáreas'
#   [chunk 3/17 | chars 278-624]
#   RAW: 'exploración abdominal\nlaparotomía'
#   [chunk 4/17 | chars 625-667]
#   RAW: 'hernias inguinales\nhernias crurales'
#   [chunk 5/17 | chars 667-838]
#   RAW: 'análisis de sangre\nglucemia'
#   [chunk 6/17 | chars 839-939]
#   RAW: 'radiografía simple de abdomen\nsuboclusión de intestino delgado\ncolelitiasis'
#   [chunk 7/17 | chars 940-1072]
#   RAW: 'TAC\ntorsión intestinal'
#   [chunk 8/17 | chars 1072-1396]
#   RAW: 'exploraciones complementarias\nlaparoscópia exploradora'
#   [chunk 9/17 | chars 1397-1846]
#   RAW: 'oclusión intestinal por bridas\nlaparoscopía exploradora\nasa de intestino delgado estrangulada\nnecrosada'
#   [chunk 10/17 | chars 1847-2323]
#   RAW: 'trompa de Falopio derecha\nligamento ancho'
#   [chunk 11/17 | chars 2324-2480]
#   RAW: 'dilatación de asas de intestino delgado\nmanipular el instrumental quirúrgico por laparoscópia'
#   [chunk 12/17 | chars 2481-2686]
#   RAW: 'reconversión a cirugía abierta'
#   [chunk 13/17 | chars 2687-2916]
#   RAW: 'reconversión\nlaparotomía infraumbilical iterativa\nhernia interna'
#   [chunk 14/17 | chars 2917-3052]
#   RAW: 'reducción de la hernia\nresección de ileon\nreconstrucción con anastomosis termino-terminal'
#   [chunk 15/17 | chars 3053-3134]
#   RAW: 'cierre con sutura continua'
#   [chunk 16/17 | chars 3135-3259]
#   RAW: 'postoperatorio'
#   [chunk 17/17 | chars 3260-3307]
#   RAW: 'control postoperatorio'
# [242/250] es-S1887-85712012000400006-1.txt | 33.12s | 17 chunks | 30 menciones
#   [chunk 1/13 | chars 0-274]
#   RAW: 'vacío'
#   [chunk 2/13 | chars 275-356]
#   RAW: 'vacío'
#   [chunk 3/13 | chars 356-532]
#   RAW: 'exfumador\ntratamiento con enalapril\ntratamiento con simvastatina'
#   [chunk 4/13 | chars 532-751]
#   RAW: 'exploración\nparesia del IV par craneal del ojo derecho\nafectación incompleta del III par bilateral\nVI par derecho'
#   [chunk 5/13 | chars 752-797]
#   RAW: 'El texto no menciona procedimientos médicos, por lo que no hay entidades de tipo PROCEDIMIENTO médico para extraer.'
#   [chunk 6/13 | chars 798-911]
#   RAW: 'Romberg'
#   [chunk 7/13 | chars 912-1000]
#   RAW: 'alteración de la marcha\nlateropulsión hacia la derecha'
#   [chunk 8/13 | chars 1000-1343]
#   RAW: 'protocolo básico de urgencias\nhemograma\nbioquímica\nestudio de coagulación\nradiografía simple de tórax\nelectrocardiograma\ntomografía computerizada (TC) craneal'
#   [chunk 9/13 | chars 1343-1492]
#   RAW: 'oclusión monocular alternante'
#   [chunk 10/13 | chars 1492-1824]
#   RAW: 'estudio con RM encefálica\nresonancia Philips de 1,5 T'
#   [chunk 11/13 | chars 1825-1931]
#   RAW: 'secuencias Flair\nDifusión'
#   [chunk 12/13 | chars 1931-2108]
#   RAW: 'anticogulación oral\nDabigatran'
#   [chunk 13/13 | chars 2109-2269]
#   RAW: 'tratamiento rehabilitador\nautonomía de la marcha\ndiplopía'
# [243/250] es-S1887-85712014000100005-1.txt | 28.13s | 13 chunks | 27 menciones
#   [chunk 1/21 | chars 0-234]
#   RAW: 'radioterapia\ncirugía\nquimioterapia'
#   [chunk 2/21 | chars 235-357]
#   RAW: 'tratamiento ambulatorio\nanalgésicos opioides'
#   [chunk 3/21 | chars 357-745]
#   RAW: 'dolor torácico agudo\nSCASEST-Killip III\nIntervención Coronaria Percutánea\ncolocación de stents'
#   [chunk 4/21 | chars 746-996]
#   RAW: 'cateterismo'
#   [chunk 5/21 | chars 996-1242]
#   RAW: 'exploración'
#   [chunk 6/21 | chars 1242-1253]
#   RAW: 'palidez'
#   [chunk 7/21 | chars 1253-1307]
#   RAW: 'detener pulso radial\ndetener pulso cubital'
#   [chunk 8/21 | chars 1307-1373]
#   RAW: 'disminución de la temperatura'
#   [chunk 9/21 | chars 1373-1425]
#   RAW: 'anestesia\nparálisis total'
#   [chunk 10/21 | chars 1425-1655]
#   RAW: 'medición de la presión intracompartimental\ndiagnóstico de confirmación\nIntra-Compartmental pressure monitor system'
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'tratamiento quirúrgico'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: 'procedimiento quirúrgico\nanestesia general\ncontrol de la vía aérea con mascarilla laríngea'
#   [chunk 13/21 | chars 1907-1969]
#   RAW: 'profilaxis antibiótica\nadministración de Cefazolina'
#   [chunk 14/21 | chars 1970-2110]
#   RAW: 'incisión cutánea'
#   [chunk 15/21 | chars 2111-2191]
#   RAW: 'infiltrado'
#   [chunk 16/21 | chars 2192-2410]
#   RAW: 'sección longitudinal de la fascia antebraquial\ndescompresión del nervio mediano\nsección del ligamento anular del carpo'
#   [chunk 17/21 | chars 2411-2487]
#   RAW: 'lesiones vasculares'
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'cierre quirúrgico\ncubrir la herida con compresas estériles impregnadas en Nitrofural\ncierre de circunstancias\nmalla con elásticos vasculares (vessel loops) de contención\nvendaje no compresivo'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: 'fasciotomía'
#   [chunk 20/21 | chars 2901-3087]
#   RAW: 'cirugía'
#   [chunk 21/21 | chars 3088-3211]
#   RAW: 'ausencia de dolor en antebrazo derecho'
# [244/250] es-S1887-85712016000100005-1.txt | 41.39s | 21 chunks | 36 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: 'coxalgia'
#   [chunk 2/22 | chars 128-229]
#   RAW: 'práctica de ejercicio físico'
#   [chunk 3/22 | chars 230-429]
#   RAW: 'bicicleta\ncarrera'
#   [chunk 4/22 | chars 430-528]
#   RAW: 'marcha'
#   [chunk 5/22 | chars 528-725]
#   RAW: 'exploración física\ndolor a la palpación\nmaniobra de choque positiva'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'balance articular de caderas'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'balance muscular'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'maniobras de Valleix\nmaniobras de Fabere\nmaniobras de Lasegue\nmaniobras de Bragard'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'palpación'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'exploración de la marcha\nausencia de claudicación\napoyo monopodal alterno derecho-izquierdo\nTrendelenburg'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: 'dolor para la marcha\nflexión forzada de cadera\nflexión forzada de rodilla'
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'radiología simple anteroposterior (AP)'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'analítica\nhemograma\nbioquímica\nhormonas tiroideas\nanticuerpos\nreactantes de fase aguda'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'resonancia magnética de cadera\nalteración subcondral\nedema óseo en cadera derecha\nirregularidad cortical\nsinovitis en interlínea articular\ndistensión de la bursa ilio-psoas'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: 'islote óseo'
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'artrografía\npinzamiento de la interlinea articular antero-superior\npinzamiento de la interlinea articular posteroinferior\nincipiente collar osteofitario femoral\nlesiones subcondrales antero-superiores de cabeza femoral\nfocos de edema en acetábulo anterosuperior'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: 'necrosis avascular\nlesiones en el labrum'
#   [chunk 18/22 | chars 2322-2412]
#   RAW: 'lesión quística yuxtaarticular'
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'tratamiento con magnetoterapia\n15 sesiones de magnetoterapia'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'tratamiento farmacológico\nasociación de sulfato de glucosamina-condroitin sulfato oral'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: 'reposo deportivo\nactividad física activa controlada\nflexión de la cadera'
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'cirugía artroscópica\nartroscopia'
# [245/250] es-S1888-75462015000400006-1.txt | 49.27s | 22 chunks | 48 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: 'fractura de tercio medio de clavícula derecha\nfractura de arcos costales derechos'
#   [chunk 2/7 | chars 348-577]
#   RAW: 'dolor a nivel de clavícula\ndolor a nivel de pared costal derecha'
#   [chunk 3/7 | chars 578-865]
#   RAW: 'estudio radiológico simple\nfractura de arcos costales derechos cuarto y quinto\nfractura de tercio medio de la clavícula derecha con tercer fragmento\ntomografía axial computarizada'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'colocación de vendaje\nauscultación cardiorrespiratoria'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'espirometría\nelectrocardiograma\necocardiograma'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'estudio de eco-Doppler venoso\ntrombosis venosa\ncompresión de la rama cubital del nervio cutáneo braquial'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'vendaje\ncabestrillo sencillo\nradiografías\nutrasonografía-Doppler\ntratamiento con Tinzapaina sódica\nconsolidación de la fractura de clavícula\nrecanalización completa de las venas trombosadas'
# [246/250] es-S1888-75462016000400180-1.txt | 22.06s | 7 chunks | 22 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'vacío'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomía'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'valoración en Ginecología\ndensitométrica lumbar\ntratamiento con denosumab\nsuplementos de vitamina D'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'dolor mecánico'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'movilización del antepié izquierdo'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'alteraciones de la estática de pies'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Rx'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'RMN\nfractura de estrés\ncallo perióstico\nedema de tejidos blandos'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'estudio analítico\nsuplementación de vitamina D'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'tratamiento con suplementos de vitamina D\ntratamiento con denosumab'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'tratamiento conservador\ndescarga\nreposo relativo\nAINEs\nmagnetoterapia'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'tratamiento con SERMS\nsuplementos de calcio con vitamina D'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'Rx\nfractura de estrés'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'RMN\nedema de 1er y 3er MTT\ntenosinovitis del tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'densitometría ósea'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'densidad mineral ósea'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'rehabilitación\ndescarga'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'osteoporosis'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'ninguno'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'fracturas de estrés'
# [247/250] es-S1889-836X2015000200005-2.txt | 35.53s | 20 chunks | 32 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'Vacío'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'revisiones ambulatorias'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'determinaciones\nelevación de la fosfatasa alcalina total\nelevación de la fosfatasa alcalina ósea\ndeterminaciones\nelevación de la paratohormona'
#   [chunk 4/16 | chars 408-569]
#   RAW: '25-hidroxivitamina D'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'radiografía simple de columna\ngammagrafía con Tc99'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'ninguno'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'exploración física\ndebilidad muscular'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperglucemia\nglucosuria\nhipofosfatemia\nfosfaturia\nhipouricemia\nacidosis metabólica\nproteinuria'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'aminoaciduria'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'FGF23 sérico'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'No hay entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'diagnóstico de síndrome de Fanconi incompleto\nhipofosfatemia grave\nosteomalacia'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'tratamiento con raltegravir\ntratamiento con darunavir potenciado con ritonavir'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: 'administración de suplementos de fósforo\nadministración de 25-HCC\nadministración de 1,25-dihidroxivitamina D'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'vacío'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'retirada de TDF'
# [248/250] es-S1889-836X2015000400006-1.txt | 32.25s | 16 chunks | 21 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'astenia\nlupus cutáneo'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'tiroiditis de Hashimoto'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'apendicectomía'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'exfumadora'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'vacío'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'tomas de bebidas con quinina'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'anemia'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'cesárea\nligadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'astenia\npresíncopes\ndeambulación'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'menstruación'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'heces melénicas'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'epistaxis\ngingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'análisis de sangre\nanemia\ntrombopenia'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'frotis sanguíneo'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'exploraciones'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'transfusión de concentrado de hematíes\ntransfusión de concentrado de plaquetas'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'afasia global'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'habla'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'ingreso'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'plasmaféresis'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'ingresa en UCI'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'plasmaféresis'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'tratamiento'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'vacío'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'vacío'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: 'reinfundir'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'trasfusión de plasma fresco'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'No se encontraron entidades de tipo PROCEDIMIENTO médico en el texto.'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'diálisis peritoneal'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'plasmaféresis\nimplantar un catéter en yugular derecha\ncolocar un catéter doble luz en femoral izquierda'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'técnica'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'infusión'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'PTM'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: '(Texto no contiene procedimientos médicos)'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: 'Se le realizaron un total de 17 sesiones.'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'No se encontraron entidades de tipo PROCEDIMIENTO médico en el texto proporcionado.'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'tratamiento'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'PTM'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'fallo del test de aire\ncambio de SET'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'El texto no menciona procedimientos médicos.'
# [249/250] es-S2254-28842014000200009-1.txt | 61.28s | 40 chunks | 37 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'intervención\ncarcinoma seroso papilar en ovario izquierdo\nafectación de un ganglio de la cadena aorto-cava'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'quimioterapia adyuvante\ncarboplatino\npaclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'elevación de CA 125'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'TAC\nresección anterior de recto superior\nbiopsia intraoperatoria'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'tratamiento con carboplatino y paclitaxel'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'infusión de carboplatino'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'infusión\nadministración de corticoides'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'esquema de desensibilización'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'infusión'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'quimioterapia\ntrabectedina\nadriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'tratamiento'
# [250/250] es-S2340-98942015000100005-1.txt | 21.15s | 11 chunks | 18 menciones
#
# Predicciones guardadas en proctemist_llm_predictions.tsv
# Tiempo medio por archivo: 28.54s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd

def prf(tp, fp, fn):
    p = tp / (tp + fp) if (tp + fp) else 0.0
    r = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1

df_pred = pd.read_csv(PREDICTIONS_TSV, sep='\t')
df_gs = pd.read_csv(GS_TEST_TSV, sep='\t')
df_gs = df_gs[df_gs['filename'].isin(df_pred['filename'].unique())]

set_gs = set(zip(df_gs['filename'], df_gs['label'], df_gs['start_span'], df_gs['end_span']))
set_pred = set(zip(df_pred['filename'], df_pred['label'], df_pred['start_span'], df_pred['end_span']))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1 = prf(tp, fp, fn)

report = {'Estricta': {'tp': tp, 'fp': fp, 'fn': fn,
                       'precision': round(p, 4), 'recall': round(r, 4), 'fscore': round(f1, 4)}}

print(f'── ESTRICTA ── P={p:.4f} R={r:.4f} F1={f1:.4f} (TP={tp} FP={fp} FN={fn})\n')

thresholds = [0.0, 0.5, 0.8]
results = {t: {'tp': 0, 'fp': 0, 'fn': 0} for t in thresholds}

for filename in df_pred['filename'].unique():
    gs_ints = list(zip(df_gs[df_gs['filename'] == filename]['start_span'],
                       df_gs[df_gs['filename'] == filename]['end_span']))
    pred_ints = list(zip(df_pred[df_pred['filename'] == filename]['start_span'],
                         df_pred[df_pred['filename'] == filename]['end_span']))
    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )
    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi)
                matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ── P=0.3333 R=0.5459 F1=0.4139 (TP=1975 FP=3950 FN=1643)
#
# ── IoU ──
# IoU >= 0.0:  P=0.4638  R=0.7593  F1=0.5759  (TP=2748 FP=3177 FN=871)
# IoU >= 0.5:  P=0.3875  R=0.6344  F1=0.4811  (TP=2296 FP=3629 FN=1323)
# IoU >= 0.8:  P=0.3423  R=0.5604  F1=0.4250  (TP=2028 FP=3897 FN=1591)
