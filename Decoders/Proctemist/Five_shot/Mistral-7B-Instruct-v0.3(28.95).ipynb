# %% [markdown]
# # Pipeline 5-Shot NER — ProcTemIST con Mistral-7B-Instruct-v0.3
#
# Inferencia 5-shot para reconocimiento de procedimientos médicos en textos clínicos en español.
# El modelo base se carga directamente sin entrenamiento ni adaptadores LoRA.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Preparación para inferencia](#4-preparacion-para-inferencia)
# 5. [Inferencia](#5-inferencia)
# 6. [Evaluación](#6-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install peft accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME     = "unsloth/mistral-7b-instruct-v0.3-bnb-4bit"
MAX_SEQ_LENGTH = 4096

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS = None   # None para oraciones sueltas
SPACY_MODEL     = "es_core_news_md"

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo PROCEDIMIENTO medico "
    "(exploraciones, pruebas diagnosticas, intervenciones, tratamientos, cirugias, etc.).\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'radiografia', no escribas 'Rx'.\n"
    "4. REPETICIONES: Si un procedimiento aparece varias veces en el texto, "
    "debes listarlo varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Unicamente el texto de la mencion, una por linea. "
    "PROHIBIDO usar caracteres de lista al inicio.\n"
    "7. Si no hay ningun procedimiento, devuelve una respuesta completamente vacia."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas ProcTemIST ──────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
PROCTEMIST_ROOT      = f"{PROJECT_ROOT}/proctemist"
TEXT_FILES_TEST_DIR  = f"{PROCTEMIST_ROOT}/text_files_test"
GS_TEST_TSV          = f"{PROCTEMIST_ROOT}/medprocner_tsv_test_subtask1.tsv"
PREDICTIONS_TSV      = "proctemist_5shot_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary_5shot.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
# Out:
# Modelo base        : unsloth/mistral-7b-instruct-v0.3-bnb-4bit
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
import unsloth
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# ==((====))==  Unsloth 2026.6.8: Fast Mistral patching. Transformers: 5.13.0.1.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.562 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/4.14G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/157 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# Modelo cargado: unsloth/mistral-7b-instruct-v0.3-bnb-4bit
# Parámetros totales: 3,758,362,624

# %% [markdown]
# ## 4. Preparación para inferencia
#
# Carga de spaCy, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc
import time
import re
import json
import logging
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from transformers import pipeline

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

# ── Ejemplos few-shot ─────────────────────────────────────────────────────────
EXAMPLES = [
    {
        "text": "En la exploración física destaca palidez de piel, Tª: 37,2 ºC y en la auscultación pulmonar crepitantes en base derecha.",
        "mentions": "exploración física\nauscultación pulmonar",
    },
    {
        "text": "Paciente de 38 años, con amputación de antepié izquierdo por arteriopatía por enfermedad de Buerger.",
        "mentions": "amputación de antepié izquierdo",
    },
    {
        "text": "Dada la edad de la enferma y con el diagnóstico de neoplasia de cabeza de páncreas, se optó por tratamiento paliativo con colocación de endoprótesis (endoprótesis biliar tipo wall stent de 10 x 70 mm de longitud) quedando alojada desde colédoco proximal hasta el interior de la luz duodenal.",
        "mentions": "tratamiento paliativo\ncolocación de endoprótesis\nendoprótesis biliar tipo wall stent",
    },
    {
        "text": "La paciente se mantuvo en DPA hasta agosto de 2002, momento en el que se le realiza un trasplante renal, precisando trasplantectomía por trombosis.",
        "mentions": "DPA\ntrasplante renal\ntrasplantectomía",
    },
    {
        "text": "Los padres activaban el aparato en casa para lograr la expansión y una vez por semana nosotros modificábamos la tensión de las cadenetas para lograr la retrusión de la premaxila.",
        "mentions": "expansión\nmodificábamos la tensión de las cadenetas\nretrusión de la premaxila",
    },
]

def build_ner_messages(text):
    messages = [{"role": "system", "content": SYSTEM_PROMPT}]
    for ex in EXAMPLES:
        messages.append({"role": "user", "content": f"Texto para analizar:\n{ex['text']}"})
        messages.append({"role": "assistant", "content": ex["mentions"]})
    messages.append({"role": "user", "content": f"Texto para analizar:\n{text}"})
    return messages

sample_prompt = tokenizer.apply_chat_template(
    build_ner_messages("Oración de prueba."),
    tokenize=False,
    add_generation_prompt=True,
)
n_tokens = len(tokenizer.encode(sample_prompt))
print(f"Tokens en contexto 5-shot (sin texto real): {n_tokens}")
print(f"Tokens disponibles para texto real         : {MAX_SEQ_LENGTH - n_tokens - MAX_NEW_TOKENS}")

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")
# Out:
# spaCy: core_news_md v3.8.0
# Tokens en contexto 5-shot (sin texto real): 705
# Tokens disponibles para texto real         : 3091
# Archivos de test a procesar: 250

# %% [markdown]
# ## 5. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.
# Se guarda un checkpoint tras cada archivo para permitir reanudar la inferencia.

# %%
# ── Inferencia con checkpoint por archivo ─────────────────────────────────────
CHECKPOINT_FILE = "/kaggle/working/inference_checkpoint_5shot.json"

if Path(CHECKPOINT_FILE).exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
    print(f"Retomando desde checkpoint: {len(done_files)} archivos ya procesados")
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text         = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0           = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            result = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
                eos_token_id=tokenizer.eos_token_id,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped      = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename":   txt_path.stem,
            "ann_id":     f"T{mark_idx}",
            "label":      "PROCEDIMIENTO",
            "start_span": off0,
            "end_span":   off1,
            "text":       span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "ann_id", "label", "start_span", "end_span", "text"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: 'exploración\ndiabetes\nhipertensión\nobesidad'
#   [chunk 2/13 | chars 91-170]
#   RAW: 'exploración física\nradiografía lumbar derecha'
#   [chunk 3/13 | chars 171-204]
#   RAW: 'exploración física'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'ultrasonido abdominal\nmasa suprarrenal derecha\nhipoecogénica\n80 mms\ncomprime el polo superior de riñón derecho'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'urograma descendente\nproceso expansivo en la suprarrenal derecha\nel polo superior de riñón derecho desplazado hacia abajo'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'radiografia\nTAC helicoidal\ntumoral\ndiámetro mayor de 8,7x76 cms\ncontornos irregulares\ndensidad heterogénea de 100 - 37 UH\ntabicada\ncompatible con tumor suprarrenal de densidad grasa'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'cortisol\ndeterminación de cortisol\nFigura 1'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'cirugía\nabordaje lumbar'
#   [chunk 9/13 | chars 800-949]
#   RAW: 'tumor\nglándula suprarrenal derecha\ntransoperatorios'
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'adrenalectomía derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: 'exploración\nprueba diagnostica\nintervención\ncirugia'
#   [chunk 12/13 | chars 1090-1294]
#   RAW: 'radiografía\nexploración\nprueba diagnostica\nintervención\ntratamiento\ncirugía'
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'mielolipoma\nhistopatológico\nglándula adrenal\ncalcificaciones'
# [1/250] S0004-06142006000100010-1.txt | 31.86s | 13 chunks | 30 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'gastrectomía subtotal\nadenocarcinoma gástrico\nhipertensión arterial\ntratamiento con espironolactona'
#   [chunk 2/21 | chars 198-412]
#   RAW: 'radiografia abdominal\necografía abdominal\nendoscopia digestiva superior\nendoscopia digestiva inferior\nbiopsia de tejido intestinal\nprueba de sensibilidad a la lactosa\nprueba de sensibilidad a la gluten\nprueba de sensibilidad a los fructosas\nprueba de sensibilidad a los láctisos\nprueba de sensibilidad a los glutenos\nprueba de sensibilidad a los fructanos\nprueba de sensibilidad a los láctanos\nprueba de sensibilidad a los glutanos\nprueba de sensibilidad a los fructanos\nprueba de sensibilidad a los láctanos\nprueba de sensibilidad a los glutanos\nprueba de sensibilidad a los fructanos\nprueba de sensibilidad a los láctanos\nprueba de sensibilidad a los glutanos\nprueba de sensibilidad a los fructanos\nprueba de sensibilidad a los láctanos\nprueba de sensibilidad a los glutanos\nprueba de sensibilidad a los fructanos\nprueba de sensibilidad a los láctanos\nprueba de sensibilidad a los glutanos'
#   [chunk 3/21 | chars 413-561]
#   RAW: 'exploración física\ntumoración\nconsistencia firme\nindolora\nmóvil\nocupaba las tres cuartas partes del abdomen'
#   [chunk 4/21 | chars 561-806]
#   RAW: 'procedimiento medico\nascitis por carcinomatosis\nobstrucción intestinal tumoral\ntumoración abdominal'
#   [chunk 5/21 | chars 807-994]
#   RAW: 'radiografia\nexploración física\nprueba diagnostica\nintervención\ntratamiento\ncirugía\nhematología\nhemoglobina\nhematies\nhematocrito\nVCM\nRDW\nVSG\nPCR\nPSA\ncreatinina\nurea'
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'radiografía hepática\nradiografía digestiva'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'gastroscopia\npólipo inflamatorio\nmuñón gástrico\nrecidiva tumoral'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'colonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'ecografía abdominopélvica\ntumoración quística\ntabiques incompletos\ncontenido anecoico mixto\nocupaba la totalidad de la cavidad abdominal'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: 'riñón izquierdo\nriñón derecho'
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'urografía intravenosa\nnormofunción contralateral\ngran efecto masa\ncistograma'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'TAC\nmasa quística\n29,5 cm x 27,5 cm x 16 cm\nmúltiples tabiques\nparedes bien definidas\nocupa la práctica totalidad del abdomen'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: 'imagen cálcica\ncompresión\ndesplazamiento de todas las estructuras abdominales'
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'drenaje percutáneo\nnefrectomía'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'nefrectomía simple derecha\nlumbotomía subcostal\nevacuando 7.800 mililitros de contenido serohemático'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'linfadenectomía hiliar ampliada\nadenopatías'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'cultivo del fluido\nnegativo\nno realizándose citología'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'riñón\nmultiquístico\ndilatación del sistema pielocalicial\natrofia parenquimatosa severa\nespesor 0,5 cm'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: 'exploración\nprueba diagnostica\nintervención\ntratamiento\ncirugía'
#   [chunk 20/21 | chars 3107-3323]
#   RAW: 'radiografia\nexploración\nprueba diagnostica\nintervención\ncirugia\ncarcinoma de células renales tipo célula clara\ninfiltración ganglionar'
#   [chunk 21/21 | chars 3323-3461]
#   RAW: 'radiografía\nprueba diagnóstica\nintervención\ntratamiento\ncirugía'
# [2/250] S0004-06142006000100014-1.txt | 68.46s | 21 chunks | 65 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: 'exploración\ndolor a nivel de hipogastrio\neyaculación dolorosa\nhemospermia\nsensación de peso a nivel testicular\nvaricocele derecho'
#   [chunk 2/14 | chars 218-324]
#   RAW: 'procedimiento medico\nprostatitis aguda'
#   [chunk 3/14 | chars 324-462]
#   RAW: 'exploración física\nvaricocele derecho'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'exploración rectal\npróstata irregular\npróstata aumentada de tamaño\nzonas induradas\nexploración dolorosa'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'ecografía urológica integral\nimagen nodular hipoecoica en teste derecho\nhipervascularización circundante\nquiste simple en testículo izquierdo'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'TAC abdómino-pélvica\nmetástasis\nhemangiomas'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'RMN\nhemangiomas'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'radiografia de tórax\nradiografia de tórax\nradiografia de tórax\nradiografia de tórax'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'radiografia\nexploración física\nprueba diagnostica (PSA)'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: 'Alfa-feto-proteína\nbeta-HCG\nPSA'
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: 'procedimiento medico\nexploración\nmacroscópica\nformación nodular\ncoloración\npulpa testicular\ntamaño: 2,5 x 1,8 x 1,5 cm\npolo superior del testículo'
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'tumor de células de Leydig difuso\ninfiltraba espacios perineurales\ninfiltraba canales vasculares capsulares adyacentes\ninfiltraba músculo liso\nmoderada atípia\nescasas mitosis'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'radiografía\nexploración\nprueba diagnostica\nintervención\ntratamiento\ncirugía'
# [3/250] S0004-06142006000500002-2.txt | 38.14s | 14 chunks | 32 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'neoplasia de testículo\norquidopexia (2 veces)'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'procedimiento medico\nLEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Ureterolitectomía'
#   [chunk 5/25 | chars 528-569]
#   RAW: 'procedimiento medico\nexploración física\nradiografía torácica\necocardiograma\necograma abdominal\ntomografía computarizada\nbiopsia pulmonar\nbiopsia de tejido pulmonar\nbiopsia de pulmón\nbiopsia de pulmón por técnica de aspiración\nbiopsia de pulmón por técnica de punción\nbiopsia de pulmón por técnica de punción percutánea\nbiopsia de pulmón por técnica de punción percutánea guiada por ecografía\nbiopsia de pulmón por técnica de punción percutánea guiada por tomografía computarizada\nbiopsia de pulmón por técnica de punción percutánea guiada por tomografía computarizada y ecografía\nbiopsia de pulmón por técnica de punción percutánea guiada por tomografía computarizada, ecografía y angiografía\nbiopsia de pulmón por técnica de punción percutánea guiada por tomografía computarizada, ecografía y angiografía y broncoscopia\nbiopsia de pulmón por técnica de punción percutánea guiada por tomografía'
#   [chunk 6/25 | chars 569-734]
#   RAW: 'procedimiento medico\nconsultó al urólogo de zona\nesterilidad\nnódulo en testículo izquierdo\nmes de evolución\naumentado de tamaño en las últimesemanas'
#   [chunk 7/25 | chars 735-785]
#   RAW: 'espermiograma\nazoospermia total'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'ecografía-doppler testicular\ntestículo derecho\nmasa de 19 x 23 mm\npolo superior\nflujo aumentado\ntumor testicular\nquiste de cordón izquierdo'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'exploración física\ntestículo izquierdo\nquiste de epidídimo'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: 'exploración testicular derecho\nexploración inguinal derecho'
#   [chunk 11/25 | chars 1178-1213]
#   RAW: 'completar el estudio'
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'Rx de tórax\nTAC toraco-abdómino-pélvico'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'analítica\nhormonales\nalfa-fetoproteina\nbeta-HCG'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'orquiectomía radical inguinal derecha\nbiopsia del testículo izquierdo vía inguinal'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: 'procedimiento medico\ntesticular derecho\nexploración macroscópica'
#   [chunk 16/25 | chars 1669-1750]
#   RAW: 'exploración testicular\nlisa\nsin observarse infiltración de túnica vaginalis'
#   [chunk 17/25 | chars 1751-1879]
#   RAW: 'radiografía\nexploración\nprueba diagnostica\nintervención\ntratamiento\ncirugia'
#   [chunk 18/25 | chars 1880-1933]
#   RAW: 'radiografia\nbiopsia\necografía\ntomografía computarizada\nmamografía\necocardiograma\nangiografía\nresonancia magnética\nendoscopia\nbiopsia fine needle\nbiopsia de tejido\nbiopsia de tejido percutánea\nbiopsia de tejido transrectal\nbiopsia de tejido transvaginal\nbiopsia de tejido transesofágica\nbiopsia de tejido transbronquial\nbiopsia de tejido transcutánea\nbiopsia de tejido transnasal\nbiopsia de tejido transcraneal\nbiopsia de tejido transorbital\nbiopsia de tejido transauricular\nbiopsia de tejido transpalpebral\nbiopsia de tejido transmandibular\nbiopsia de tejido transmaxilar\nbiopsia de tejido transparotidaria\nbiopsia de tejido transcervical\nbiopsia de tejido transvaginal endometrial\nbiopsia de tejido transvaginal endocervical\nbiopsia de tejido transvaginal endometrial y endocervical\nbiopsia de tejido transvaginal endomet'
#   [chunk 19/25 | chars 1934-1981]
#   RAW: 'cordón espermático\nno presenta alteraciones'
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'Tumor de células de Leydig\n3,2 x 3 cm\nhistopatológico'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: 'Resto de parénquima testicular\natrofia\nhiperplasia de células de Leydig\npráctica ausencia de espermiogénesis'
#   [chunk 23/25 | chars 2359-2385]
#   RAW: 'Bordes quirúrgicos libres.'
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'biopsia del teste izquierdo\natrofia testicular\nausencia de espermiogénesis\nhiperplasia de células de Leydig intersticial'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'radiografía\nmetástasis\nmarcadores tumorales'
# [4/250] S0004-06142006000500002-3.txt | 88.16s | 25 chunks | 47 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'masa renal derecha\necográficamente\ndiagnosticado'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'TAC abdomino-pélvica\npresencia de una masa sólida y heterogénea\naproximadamente 6 cm\nlocalizada en polo superior del riñón derecho\nvena renal permeable'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'nefrectomía radical derecha\nlaparotomía subcostal'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'carcinoma renal\ncélulas claras\n8,4 centímetros\npT3aNoMo\nII de Robson\ngrado nuclear IV de Fuhrman'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'cirugía'
#   [chunk 6/11 | chars 665-854]
#   RAW: 'radiografia\nexploración\nintervención\ncirugía'
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'exploración\npalpaba una masa dolorosa en el hipocondrio derecho\nrealizó nueva TAC\nreveló una recidiva tumoral en el lecho quirúrgico\ninfiltraba pilar diafragmático derecho posterior e hígado\nevidenciaron implantes peritoneales\nel mayor, de cuatro centímetros adyacente al hilio hepático'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'extirpación de masas tumorales\nresecación de masas adyacentes al hígado\nresecación de implantes peritoneales\nresecación de implantes retroperitoneales\nbiopsia intraoperatoria'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: 'radiografia\nexploración\nintervención'
#   [chunk 10/11 | chars 1569-1760]
#   RAW: 'Interferón\nIntrón A\ntratamiento'
#   [chunk 11/11 | chars 1760-2135]
#   RAW: '1. TAC de abdomen\n2. revisiones\n3. analgésicos suaves\n4. cirugía\n5. TAC de abdomen de control\n6. múltiples lesiones hepáticas\n7. metástasis\n8. crecimiento de la recidiva del lecho quirúrgico\n9. implantes peritoneales en epiplon'
# [5/250] S0004-06142006000900015-1.txt | 35.98s | 11 chunks | 28 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: 'PROCEDIMIENTO medico\nexploración\nPaciente varón de 29 años.'
#   [chunk 2/18 | chars 27-350]
#   RAW: 'exploración\necografía'
#   [chunk 3/18 | chars 350-424]
#   RAW: 'exploración urológica\nno astenia\nno pérdida de peso'
#   [chunk 4/18 | chars 425-475]
#   RAW: 'exploración física\nprueba diagnostica\ncirugía'
#   [chunk 5/18 | chars 475-585]
#   RAW: 'exploración física\nteste izquierdo hipotrófico\nteste derecho aumentado de tamaño'
#   [chunk 6/18 | chars 586-657]
#   RAW: 'exploración física\npalpación abdominal\npalpación de abdomen'
#   [chunk 7/18 | chars 658-707]
#   RAW: 'Epididimos\ncordones'
#   [chunk 8/18 | chars 707-915]
#   RAW: 'hemostasia\nbioquímica\nhemograma\nalpha-feto proteína\nbeta-hCG'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'ecografía con flujo Doppler\nteste derecho\nlesión hipoecoica\nbordes lobulados\nheterogénea\nocupa prácticamente todo el testículo\naumento del flujo Doppler'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'radiografía\nteste izquierdo\nmedidas: 32mm x 22mm x 20mm\nlesión focal ligeramente hipoecoica\nmedidas de la lesión: 9mm\nsutil flujo Doppler'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: 'microlitiasis testicular derecho\nmicrolitiasis testicular izquierdo'
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de tórax\nTAC toraco-abdomino-pélvico con contraste'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'orquiectomía bilateral\ntratamiento hormonal sustitutivo'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'testículo izquierdo atrófico\nmúltiples focos microscópicos de seminoma clásico\nneoplasia intratubular de células germinales (NICG)\nausencia de infiltración tumoral en albugínea\nausencia de infiltración tumoral en rete testis\nausencia de infiltración tumoral en epidídimo'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: 'procedimiento medico\ntestículo derecho\ntumoración\nseminoma clásico\nneoplasia intratubular de células germinales (NICG)\natrofia'
#   [chunk 16/18 | chars 2303-2380]
#   RAW: 'túnica albugínea\nrete testis\nepidídimo\nborde quirúrgico libres de tumor'
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'quimioterapia\ncarboplatino\nprotocolo del hospital'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: 'radiografía\nexploración física\nprueba de laboratorio\ntratamiento farmacológico\ncirugía\nintervención quirúrgica\nterapia intensiva\nhospitalización\nrehabilitación\nfisioterapia\npsicoterapia\npsicología\npsiquiatría\npsicólogo\npsicóloga\npsiquiatra\npsiquiatra infantil\npsiquiatra adolescente\npsiquiatra geriátrica\npsiquiatra de la salud mental\npsiquiatra de la salud mental infantil\npsiquiatra de la salud mental adolescente\npsiquiatra de la salud mental geriátrica\npsiquiatra de la salud mental de la mujer\npsiquiatra de la salud mental de la mujer adolescente\npsiquiatra de la salud mental de la mujer geriátrica\npsiquiatra de la salud mental de la mujer en el embarazo\npsiquiatra de la salud mental de la mujer en el embarazo y el parto\npsiquiatra de la salud mental de la mujer en el embarazo, el parto y el puerperio\npsiquiatra de la salud mental de la'
# [6/250] S0004-06142007000200017-1.txt | 66.22s | 18 chunks | 41 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: 'PROCEDIMIENTO medico\nexploración\nedad\nraza'
#   [chunk 2/20 | chars 40-266]
#   RAW: 'radiografia\nexploración física\nprueba de laboratorio\nprueba de imagen (ecografía, tomografía, resonancia magnética, etc.)\nprueba de función (ecocardiograma, electromiografía, etc.)\nprueba de sangre (hemograma, glucosa, etc.)\nprueba de orina (urinálisis, etc.)\nprueba de semen (spermiograma, etc.)\nprueba de biopsia (biopsia de tejido, biopsia de hueso, etc.)\nprueba de biopsia de tejido (biopsia de tejido, biopsia de hueso, etc.)\nprueba de biopsia de hueso (biopsia de tejido, biopsia de hueso, etc.)\nprueba de biopsia de tejido (biopsia de tejido, biopsia de hueso, etc.)\nprueba de biopsia de hueso (biopsia de tejido, biopsia de hueso, etc.)\nprueba de biopsia de tejido (biopsia de tejido, biopsia de hueso, etc.)\nprueba de'
#   [chunk 3/20 | chars 266-403]
#   RAW: 'exploración física\ngenitales externos\nedema marcado del pene y escroto\neritema\ndolor'
#   [chunk 4/20 | chars 404-442]
#   RAW: 'adenopatías inguinales\n\n(No se encontraron procedimientos médicos en el texto)'
#   [chunk 5/20 | chars 442-554]
#   RAW: 'estudios complementarios\nHemograma completo'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'Serología'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Prueba de Mantoux\nRX de cadera'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'U/S abdominal\nexploración ultrasonográfica\nPsoas derecho engrosado de 48 mm\n\nTAC simple de hipogastrio y pelvis\ntomografía axial computarizada\nnecrosis aséptica de la cabeza del fémur\nhipertrofia del psoas a ese nivel'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'procedimientos quirúrgicos\nExploración retroperitoneal derecha'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'Adenectomía de ilíaca derecha\nAdenectomía de cava'
#   [chunk 11/20 | chars 986-1014]
#   RAW: '-Linfangioplastia con aguja'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'Fasciotomía de la raíz del pene'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: 'radiografia\nexploración\nprueba diagnostica\nintervención\ncirugia'
#   [chunk 14/20 | chars 1193-1435]
#   RAW: '-exploración clínica\n-diagnóstico de linfedema primario inflamatorio local de pene y escroto'
#   [chunk 15/20 | chars 1435-1477]
#   RAW: '- exploración\n- intervención\n- cirugía'
#   [chunk 16/20 | chars 1477-1609]
#   RAW: 'valoración\nequipo multidisciplinario\nurólogos\nangiológos\ncirujanos plásticos'
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: 'Anatomía Quirúrgica\ndistorsionada\nevacuación de la linfa\ndistorsión y atrapamiento de los conductillos linfáticos\ntejido conjuntivo fibroso aumentado\ndisminución de las fibras elásticas\ntejido peneano'
#   [chunk 19/20 | chars 1978-2560]
#   RAW: 'dartos\nmúsculo peripeneal de Sappey\ntúnica muscular de fibras lisas\ncubierta celulosa rica en fibras elásticas\nextirpado en su totalidad\nfascia penis delgada\nórganos eréctiles\nesponjosos y cavernosos\nuretra\narteria peneana'
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'exploración\nextirpación\nrecubrimiento de los testículos\nescroto\ndartos muscular\ncelulosa\nfascia de Cooper\nsegunda túnica muscular llamada eritroide'
# [7/250] S0004-06142007000600012-1.txt | 71.58s | 20 chunks | 50 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: 'procedimiento medico\nurologia\nnodulo testicular\nconsulta\nexploración'
#   [chunk 2/12 | chars 207-321]
#   RAW: 'exploración\nnódulo duro\nmóvil\ndoloroso a la palpación\ncordón espermático derecho'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'marcadores tumorales\nhormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'ecografía\nexploración de imagen\nimagen ovalada\nhipoecoica\necogenicidad mixta\neje longitudinal máximo de 2,8 cm\nrelación con el cordón espermático'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'RNM\ncordón espermático derecho\nimagen de señal baja en T2\ntejido con bajo contenido en agua\nposiblemente fibroso o cicatricial\ndiámetro máximo 43 mm'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'tumoración paratesticular derecha\nexéresis quirúrgica\nseparándose la tumoración del conducto deferente'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: 'exploración\nprueba diagnostica\nintervención\ntratamiento\ncirugia'
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'procedimiento medico\nestudio macroscópico\nformación redondeada\ncoloración pardusca\nconsistencia elástica\ndelimitada\ndiámetro máximo\n5 cm\nsuperficie blanquecina\nhomogénea\naspecto fibroso'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'exploración microscópica\nlesión bien circunscrita\ncélulas con amplio citoplasma eosinófilo\npresencia de estriaciones transversales\ncélulas inmersas en un estroma fibroblástico\ncélulas de aspecto vacuolado\ncélulas multinucleadas\nno observándose actividad mitótica'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'inmunohistoquímico\ndesmina\nvimentina\nactina de músculo liso específica'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: 'radiografia\necocardiograma\ntomografía computarizada\necografía abdominal\nbiopsia\ncirugía\nangiografía\necocardiografía\nresonancia magnética\nbiopsia de tejido\ncirugía de abdomen\nangiografía de abdomen\nbiopsia de hueso\ncirugía de hueso\nangiografía de hueso\nbiopsia de tejido blando\ncirugía de tejido blando\nangiografía de tejido blando\nbiopsia de tejido duro\ncirugía de tejido duro\nangiografía de tejido duro\nbiopsia de hueso duro\ncirugía de hueso duro\nangiografía de hueso duro\nbiopsia de tejido maligno\ncirugía de tejido maligno\nangiografía de tejido maligno\nbiopsia de hueso maligno\ncirugía de hueso maligno\nangiografía de hueso maligno\nbiopsia de tejido benigno\ncirugía de tejido benigno\nangiografía de tejido benigno\nbiopsia de hueso benigno\ncirugía de hues'
#   [chunk 12/12 | chars 1890-1900]
#   RAW: 'radiografia\nexploración física\nprueba de laboratorio\nprueba de imagen\ncirugía\nintervención\ntratamiento\nintervención quirúrgica\nexploración clínica\nprueba diagnóstica\ntratamiento médico\nintervención médica\ncirugía quirúrgica\nexploración médica\nprueba diagnóstica clínica\ntratamiento quirúrgico\nintervención clínica\nprueba de laboratorio clínico\ntratamiento clínico\nintervención clínica quirúrgica\nprueba diagnóstica quirúrgica\ntratamiento quirúrgico clínico\nintervención quirúrgica clínica\nprueba diagnóstica clínica quirúrgica\ntratamiento clínico quirúrgico\nintervención clínica quirúrgica diagnóstica\nprueba diagnóstica clínica quirúrgica diagnóstica\ntratamiento clínico quirúrgico diagnóstico\nintervención clínica quirúrgica diagnóstica quirúrgica\nprueba diagnóstica clín'
# [8/250] S0004-06142007000600014-1.txt | 72.37s | 12 chunks | 42 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: 'radiografía\necografía\ntomografía computarizada\necocardiograma\nangiografía\nbiopsia\ncirugía\nhemostasia\nsutura\nterapia antibiótica\nterapia antitrombótica\nterapia de dolor\nterapia de rehabilitación\nterapia de cuidados intensivos\nterapia de nutrición\nterapia de ventilación mecánica\nterapia de transfusión de sangre\nterapia de transfusión de plasma\nterapia de transfusión de plaquetas\nterapia de transfusión de eritrocitos\nterapia de transfusión de globulinas\nterapia de transfusión de albumina\nterapia de transfusión de fibrinogénico\nterapia de transfusión de factor VIII\nterapia de transfusión de factor IX\nterapia de transfusión de factor X\nterapia de transfusión de factor XI\nterapia de transfusión de factor XII\nterapia de transfusión de factor XIII\nterapia de transfusión de vitamina K\nterapia de transfusión de heparina\nterapia de transf'
#   [chunk 2/18 | chars 175-330]
#   RAW: 'exploración física\nherida de bala\nmuslo derecho\norificio de entrada\norificio de salida'
#   [chunk 3/18 | chars 331-405]
#   RAW: 'exploración física\nabdomen defensado ligeramente'
#   [chunk 4/18 | chars 406-568]
#   RAW: 'radiografía simple de abdomen\nbalasituada a la altura de la sínfisis del pubis\nfractura de la rama descendente derecha del mismo'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'catéter suprapúbico'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'laparotomía\ncolostomía izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'uretrografía\nuretra\nrecto\ncontraste\nfiebre alta\nescalofríos'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'colonoscopia'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'uretrotomo endoscópico\nuretra prostática\norificio\nvisualizarse el orificio\nuretra con el recto'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'vejiga\nsonda del dieciocho'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'laparotomía\nrevisa el abdomen\ncomprobándose que no hay ninguna lesión'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'diseca el espacio de Retzius\ncontrol radiológico\npalpa la cara anterior de la próstata\nhiperplásica\ntocar el proyectil'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'radiografía\npinza de anillo\nextraer la bala'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: 'sonda'
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'colonoscopia\ncolostomía\ncierre de colostomía'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: 'radiografía\nexploración\nintervención\ntratamiento\ncirugía'
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'uretrografía\nretirada la sonda'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'ultrasonido'
# [9/250] es-S0004-06142007000900010-1.txt | 54.19s | 18 chunks | 35 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'exploración\napendicectomía\nhernia discal y de hiato\nfractura de tibia y peroné\ncólico nefrítico derecho'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'ecográfico\nneofomación sólida\nriñón derecho\n5 cm'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'TAC\nmasa a nivel cortical de riñón derecho\naproximadamente 5 cm\nbordes externos lobulados\nno afectar al espacio perirrenal\nno observándose adenopatías\nno dilatación de vía renal excretora'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'nefrectomía radical derecha\nlaparoscopia'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'neoformación cortical\n5 cm de diámetro máximo\nbien delimitada\nno encapsulada\ndeforma la superficie cortical sin atravesarla\ncoloración amarillenta\náreas de aspecto hemorrágicas\náreas quísticas'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'exploración microscópica\nneoformación\nestructuras acinares\ncélulas cuboidales uniformes\ncromatina uniforme\nestroma ligeramente celular'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'estudio inmunohistoquímico\ndeterminación de vimentina\ncitoqueratina 7\ncitoqueratina de amplio espectro\nCD34\ncromogranina\nEMA (Master Diagnostic.)'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: 'radiografia\necocardiograma\ntomografía computarizada\necografía abdominal\nbiopsia\ncirugía\nangiografía\necocardiografía\nresonancia magnética\nbiopsia de tejido\ncirugía de abdomen\nangiografía de abdomen\nbiopsia de hueso\ncirugía de hueso\nangiografía de hueso\nbiopsia de tejido blando\ncirugía de tejido blando\nangiografía de tejido blando\nbiopsia de tejido duro\ncirugía de tejido duro\nangiografía de tejido duro\nbiopsia de hueso duro\ncirugía de hueso duro\nangiografía de hueso duro\nbiopsia de tejido maligno\ncirugía de tejido maligno\nangiografía de tejido maligno\nbiopsia de hueso maligno\ncirugía de hueso maligno\nangiografía de hueso maligno\nbiopsia de tejido benigno\ncirugía de tejido benigno\nangiografía de tejido benigno\nbiopsia de hueso benigno\ncirugía de hues'
#   [chunk 9/11 | chars 1355-1362]
#   RAW: 'radiografia\nexploración\nprueba diagnóstica\nintervención\ntratamiento\ncirugía'
#   [chunk 10/11 | chars 1362-1507]
#   RAW: 'exploración\ncitoqueraina 7\nEMA\nCD34'
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'intervención'
# [10/250] es-S0004-06142007000900012-1.txt | 50.32s | 11 chunks | 37 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: 'SK\ndiagnosticado de SK\nsinusitis bilateral\nbronquiectasias\ndesprendimiento retina de ojo derecho\nconsulta por aumento del tamaño testicular e induración'
#   [chunk 2/14 | chars 197-304]
#   RAW: 'exploración\ndolor lumbar\ndolor testicular izquierdo'
#   [chunk 3/14 | chars 305-427]
#   RAW: 'neoplasia\nexploración\naumento del volumen testicular\nindoloro\nconsistencia pétrea'
#   [chunk 4/14 | chars 428-455]
#   RAW: 'radiografía abdominal\necocardiograma\necograma torácico\necografía abdominal\necocardiografía\necograma abdominal'
#   [chunk 5/14 | chars 455-566]
#   RAW: 'ecografía\ntumor testicular tipo seminoma\nganglios locorregionales'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'radiografia de tórax\nsitus inversus\nobserva situs inversus\nevidenciado por el apex de la silueta cardiaca\nevidenciado por la cámara de gases gástrica a la derecha\nobserva la cámara de gases gástrica a la derecha\nalguna imagen cicatricial\nevidencia probables bronquiectasias\nen lóbulo inferior izquierdo'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'LDH: 340\nGOT: 44\nGPT: 44'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'Marcadores tumorales\na-fetoproteína\nb-HCG\norquiectomía inguinal\nraquianestesia\nL3-L4\nbupivacaína hiperbárica\nprótesis testicular'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'procedimiento medico\nseminoma clásico\ndiagnóstico\ndiámetro\n2.5 cms\nalbugínea\nresectado\nepidídimo\nrete testis\ncordón espermático\nbordes quirúrgicos\nrespetado'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: 'radiografia\nangiografía\necografía\ntomografía computarizada\necocardiograma\nbiopsia\ncirugía\nintervención endovascular\nterapia quimioterápica\nterapia radioterápica\nterapia de quimioterapia y radioterapia\nterapia de quimioterapia\nterapia radioterapia\nterapia de quimioterapia y radioterapia\nterapia de quimioterapia\nterapia radioterapia\nterapia de quimioterapia y radioterapia\nterapia de quimioterapia\nterapia radioterapia\nterapia de quimioterapia y radioterapia\nterapia de quimioterapia\nterapia radioterapia\nterapia de quimioterapia y radioterapia\nterapia de quimioterapia\nterapia radioterapia\nterapia de quimioterapia y radioterapia\nterapia de quimioterapia\nterapia radioterapia\nterapia de quimioterapia y radioterapia\nter'
#   [chunk 11/14 | chars 1318-1350]
#   RAW: 'Neoplasia germinal intratubular'
#   [chunk 12/14 | chars 1351-1409]
#   RAW: 'fibrosis\nhialinización tubular\ntestículo no tumoral'
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'exploración física\npruebas por imágenes'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'orquiectomía\nespermiogramas\nazooospermia'
# [11/250] es-S0004-06142008000300011-1.txt | 60.14s | 14 chunks | 48 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: 'exploración abdominal\nradiografía abdominal\nprueba de hepatitis B\nprueba de hepatitis C\nprueba de hepatitis D\nprueba de hepatitis E\nprueba de hepatitis A\necografía abdominal\necocardiograma\necograma\nprueba de bilirrubina\nprueba de transaminasas\nprueba de proteínas hepáticas\nprueba de glucosa\nprueba de electrolios\nprueba de hemograma\nprueba de coagulación\nprueba de proteínas C reactivas\nprueba de proteínas S reactivas\nprueba de proteínas A reactivas\nprueba de proteínas B reactivas\nprueba de proteínas L reactivas\nprueba de proteínas M reactivas\nprueba de proteínas F reactivas\nprueba de proteínas A amiloide\nprueba de proteínas B amiloide\nprueba de proteínas C amiloide\nprueba de proteínas S amiloide\nprueba de proteínas L amiloide\nprueba de proteínas M amiloide\nprueba de proteínas F amilo'
#   [chunk 2/40 | chars 199-241]
#   RAW: 'radiografía torácica\ntomografía computarizada torácica\necografía torácica\necocardiograma\necograma\necocardiografía\necocardiograma Doppler\necocardiografía Doppler\necocardiograma transesofágico\necocardiografía transesofágica\necocardiograma Doppler transesofágico\necocardiografía Doppler transesofágica\necocardiograma de estrés\necocardiografía de estrés\necocardiograma de estrés dobutaminio\necocardiografía de estrés dobutaminio\necocardiograma de estrés adenosina\necocardiografía de estrés adenosina\necocardiograma de estrés dobutaminio y adenosina\necocardiografía de estrés dobutaminio y adenosina\necocardiograma de estrés dobutaminio y adenosina con vasodilatadores\necocardiografía de estrés dobutaminio y adenosina con vasodilatadores\necocardiograma de estrés dobutaminio y adenosina con vasodilatadores y nitrato de nit'
#   [chunk 3/40 | chars 242-284]
#   RAW: 'radiografía\necocardiograma\necograma abdominal\necografía torácica\necocardiografía\necografía transvaginal\necografía transrectal\necocardiografía Doppler\necografía Doppler abdominal\necografía Doppler torácica\necocardiografía Doppler transesofágica\necografía Doppler transvaginal\necocardiografía Doppler transrectal\necocardiografía Doppler transthorácica\necocardiografía Doppler transesofágica Doppler\necocardiografía Doppler transvaginal Doppler\necocardiografía Doppler transrectal Doppler\necocardiografía Doppler transthorácica Doppler\necocardiografía Doppler transesofágica Doppler transvaginal\necocardiografía Doppler transesofágica Doppler transrectal\necocardiografía Doppler transesofágica Doppler transthorácica\necocardiografía Doppler transesofágica Doppler transrectal Doppler\necocardiografía Doppler transesofágica Doppler transthorácica Doppler transvaginal\necocardiografía Doppler transesofágica Doppler transthorácica Doppler transrectal\necocardiografía Doppler transesofág'
#   [chunk 4/40 | chars 285-307]
#   RAW: 'radiografía abdominal\necografía abdominal\necocardiograma\necograma torácico\ntomografía computarizada abdominal\necocardiografía\necocardiograma doppler\necocardiografía doppler\necocardiografía transesofágica\necocardiografía transtorácica\necocardiografía transesofágica doppler\necocardiografía transtorácica doppler\necocardiografía transesofágica con contrastante\necocardiografía transtorácica con contrastante\necocardiografía transesofágica con contrastante doppler\necocardiografía transtorácica con contrastante doppler\necocardiografía transesofágica con contrastante agitada\necocardiografía transtorácica con contrastante agitada\necocardiografía transesofágica con contrastante agitada doppler\necocardiografía transtorácica con contrastante agitada doppler\necocardiografía transesofágica con contrastante agitada y agitación\necocardiografía transtorácica con contrastante agitada y agitación\necocardiografía transesofágica con contrastante agitada y agitación doppler\necocardiografía tr'
#   [chunk 5/40 | chars 307-427]
#   RAW: 'exploración física\nconsciente y orientada\ndolor'
#   [chunk 6/40 | chars 428-448]
#   RAW: 'radiografía abdominal\necocardiograma\necograma torácico\necografía abdominal\necocardiografía\necograma abdominal\necocardiograma torácico\necografía torácica\necocardiografía abdominal'
#   [chunk 7/40 | chars 449-479]
#   RAW: 'procedimiento medico\nexploración\nnormotensa'
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Auscultación cardiopulmonar\nsin hallazgos'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'abdomen\nsin masas ni megalias\ndolor abdominal generalizado a la palpación\nintenso en epigastrio\nsin signos de irritación peritoneal\nMurphy negativo'
#   [chunk 10/40 | chars 685-721]
#   RAW: 'circulación colateral'
#   [chunk 11/40 | chars 722-755]
#   RAW: 'exploración física\nauscultación pulmonar\necocardiograma\necografia abdominal\nradiografía de tórax\nradiografía de abdomen\necocardiografía transesofágica\necograma abdominal\nradiografía de piernas\nradiografía de miembros inferiores'
#   [chunk 12/40 | chars 756-802]
#   RAW: 'radiografía\nexploración\nprueba diagnostica\nintervención\ntratamiento\ncirugía'
#   [chunk 13/40 | chars 802-902]
#   RAW: 'transaminasas\nGOT: 146 U/L\nGPT: 171 U/L'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'Hemograma\nhemoglobina: 11.4 g/dL\nhematocrito: 34%\nleucocitos: 12700\nneutrofilia: no\nplaquetas: 291000'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'hemostasia\nINR\ntiempo de cefalina'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'TC\nobserva trombo con densidad grasa\nextiende desde riñón izquierdo a vena renal izquierda\nextiende a vena cava inferior\nextiende al ostium de aurícula derecha'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: 'Venas suprahepáticas libres.'
#   [chunk 18/40 | chars 1278-1316]
#   RAW: 'No oclusión completa de la luz de VCI.'
#   [chunk 19/40 | chars 1317-1366]
#   RAW: 'Anormalidad inespecífica de cabeza de páncreas.'
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'ECO abdómino-pélvica\nhígado\nvía biliar intra y extrahepática normales'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: 'Lipoma\nVCI'
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'colecistitis\nperforada\npancreatitis'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'radiografía\nexploración\nprueba diagnostica\nintervención\ncirugia'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: 'diagnóstico diferencial\npatología bilio-pancreática'
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'TC\nderrame pleural bilateral\nengrosamiento de pliegues gástricos\naumento de la captación de contraste\nangiomiolipoma (AML)'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: 'lipoma renal\nextiende hacia VCI y ostium de la aurícula derecha\npaso de contraste en todo el recorrido de las estructuras venosas\nvena porta y suprahepáticas permeables'
#   [chunk 27/40 | chars 2225-2465]
#   RAW: 'hepatomegalia\naumento de calibre de vena porta y suprahepáticas con retardo e la llegada de contraste a las mismas\nedema periportal\nedema páncreas\nabundante líquido libre'
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'paracentesis\ncontrol ecográfico\nexcluir con mayor certeza proceso peritoneal infeccioso/ tumoral'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'trasudado\nperitoneal\nresultado analítico'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'ecografía transesofágica\ntricúspide libre\nderrame pericárdico'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: 'Síndrome de Budd-Chiari\ntrombosis en cava\ndiagnóstico de Síndrome de Budd-Chiari secundario a trombo en cava'
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'intervención quirúrgica urgente\nLipoma'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'INTERVENCIÓN QUIRÚRGICA'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: 'trombo\nnivel quirúrgico IV\nostium de aurícula derecha'
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'incisión tipo Chevron\nacceso a retroperitoneo\napertura desde asa fija hasta hiato de Winslow\nliberación ascendente del paquete intestinal\nligadura de vena mesentérica inferior'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'movilización hepática\nseccionando los ligamentos\nligamentos redondo\nligamentos coronario\nligamentos triangulares derecho\nligamentos triangulares izquierdo\nligamentos falciforme'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'libera el riñón izquierdo\nliberación de la vena cava\nliberación de la vena cava, empezando a nivel infrarrenal y ascendiendo hasta nivel suprahepático\ncontrol de vena renal derecha (VRD)\nsección del resto de ramas\ncomprueban libres de trombo tumoral\nvenas suprahepáticas que se comprueban libres de trombo tumoral y son las únicas que fijan la cava al hígado.'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'amplía el hiato diafragmático\nexprime el trombo hasta nivel infradiafragmático'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'clampaje de pedículo hepático\nVCI proximal y distal\nVRD\ncavotomía\napertura VRI\nextracción completa del trombo\nnefrectomía izquierda'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'angiomiolipoma de predominio lipomatoso\nseno renal\ninfiltración vascular'
# [12/250] es-S0004-06142008000300012-1.txt | 183.25s | 40 chunks | 97 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: 'radiografía abdominal\necografía abdominal\necografía renal\necografía Doppler renal\necografía transvaginal\necografía transrectal\necografía ultrasonográfica\necografía renales\necografía de riñón derecho\necografía de riñón izquierdo\necografía de vesícula biliar\necografía de hígado\necografía de páncreas\necografía de riñón y vesícula biliar\necografía de riñón y hígado\necografía de riñón y páncreas\necografía de riñón y vesícula biliar y hígado\necografía de riñón y vesícula biliar y páncreas\necografía de riñón y hígado y páncreas\necografía de riñón y vesícula biliar y hígado y páncreas\necografía de riñón y vesícula biliar y hígado y páncreas y hígado\necografía de riñón y vesícula biliar y hígado y páncreas y riñón derecho\necografía de riñón y vesícula biliar y hígado y páncreas y riñón izquierdo\necografía de riñón'
#   [chunk 2/26 | chars 114-171]
#   RAW: 'diclofenaco\nartrosis\nlumbalgia'
#   [chunk 3/26 | chars 171-292]
#   RAW: 'radiografía\necografía\nlitiasis\nquiste renal gigante'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'TAC\nquiste renal simple (Bosniak I)\nlitiasis ipsilateral'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'Serología de hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Hemograma'
#   [chunk 7/26 | chars 549-618]
#   RAW: 'tratamiento\nquiste'
#   [chunk 8/26 | chars 619-664]
#   RAW: 'Se le informó de las distintas posibilidades\n\nprocedimientos:\n- información'
#   [chunk 9/26 | chars 665-728]
#   RAW: 'drenaje percutáneo\nesclerosis del quiste'
#   [chunk 10/26 | chars 728-860]
#   RAW: 'cistitis\nurgencias\nfiebre elevada\ndolor lumbar derecho'
#   [chunk 11/26 | chars 861-919]
#   RAW: 'tratamiento antibiótico\ntratamiento antibiótico de modo domiciliario'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'drenaje percutáneo'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: 'radiografía\nmide 6,4 centímetros'
#   [chunk 14/26 | chars 1060-1089]
#   RAW: 'radiografía\ncalcificación de la pared'
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'TAC\nTAC con cortes tardíos'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: 'microhematuria\nleucocituria'
#   [chunk 17/26 | chars 1235-1301]
#   RAW: 'radiografía abdominal\necografía abdominal\necografía renales\necografía urinaria\necografía pelvis\necografía transvaginal\necografía transrectal\necografía Doppler\necografía Doppler abdominal\necografía Doppler renal\necografía Doppler urinaria\necografía Doppler pelvis\necografía Doppler transvaginal\necografía Doppler transrectal\necografía endorectal\necografía endovaginal\necografía endouretral\necografía endometrial\necografía endocervical\necografía endometrial transvaginal\necografía endometrial transrectal\necografía endometrial endorectal\necografía endometrial endovaginal\necografía endometrial endouretral\necografía endometrial transvaginal Doppler\necografía endometrial transrectal Doppler\necografía endometrial endorectal Doppler\necografía endometrial endovaginal Doppler\necografía endometrial endouretral Doppler\necografía transabdominal\necografía transabdominal Doppler\necografía transabdominal con contraste\necografía transabdominal con contraste Doppler\necografía transabdominal con contraste color Doppler\necografía transabdominal con contraste color Dop'
#   [chunk 18/26 | chars 1302-1344]
#   RAW: 'radiografia de pelvis renal'
#   [chunk 19/26 | chars 1345-1501]
#   RAW: 'Amoxicilina-Clavulanico\nTrimetropin-Sulfametoxazol'
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'litotricia extracorpórea'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: 'radiografía\necocardiograma\necograma abdominal\ntomografía axial computarizada\nbiopsia de tejido\nprueba de función renal\nprueba de función hepática\nprueba de función tiroides\nprueba de función pancreas\nprueba de función tiroide\nprueba de función hepatitis\nprueba de función hepatocitológica\nprueba de función hematológica\nprueba de función coagulación\nprueba de función hematopoyética\nprueba de función hematológica completa\nprueba de función hematopoyética completa\nprueba de función hematológica completa\nprueba de función hematopoyética completa\nprueba de función hematológica completa\nprueba de función hematopoyética completa\nprueba de función hematológica completa\nprueba de función hematopoyética completa\nprueba de función hematológica completa\nprueba de función hematopoyética completa\nprueba de función hematológica completa\nprueba de fun'
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'TAC\nruptura del quiste\nTAC'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: 'Bosniak IIF\ntrascurencio de 2 años más'
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'Ecografía de control\nEcografía\nUIV\nTAC'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: 'exploración\nurinaria\ncomunicación'
#   [chunk 26/26 | chars 2035-2072]
#   RAW: 'La paciente permanece asintomática.'
# [13/250] es-S0004-06142008000300013-1.txt | 96.62s | 26 chunks | 40 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'prostatectomía radical\nlinfadenectomía obturatriz\ncarcinoma de próstata\nresección'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'cirugía prostática\necografía\nestudio doppler'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'TAC abdominal'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'TAC post orquiectomía\nadenopatías retroperitoneales\narea inguinal\nbifurcación de renales'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'orquiectomía inguinal\ndiagnosticado de linfoma testicular difuso de célula grande tipo B\nquimioterapia citorreductiva según esquema R-CHOPx8\nremisión completa tras la inducción'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'IFOVM / DHAP\nesquema IFOVM / DHAP\nIFOVM / DHAP (3 ciclos)\nIFOVM / DHAP (nueva recidiva)'
# [14/250] es-S0004-06142008000400011-2.txt | 17.12s | 6 chunks | 17 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: 'procedimiento medico\nhipertensión arterial'
#   [chunk 2/11 | chars 87-171]
#   RAW: 'procedimiento medico\nconsultó al Servicio de Ginecología\nmetrorragias\ndolor abdominal'
#   [chunk 3/11 | chars 172-219]
#   RAW: 'radiografía abdominal\necografía abdominal\necocardiograma\necograma torácico\necocardiografía\necografía renal\necografía transvaginal\necografía transrectal\necocardiograma doppler\necocardiografía doppler\necocardiograma transthorácico\necocardiografía transthorácica\necocardiograma doppler transthorácico\necocardiografía doppler transthorácica\necocardiograma doppler abdominal\necocardiografía doppler abdominal\necocardiograma doppler renal\necocardiografía doppler renal\necocardiograma doppler torácico\necocardiografía doppler torácica\necocardiograma doppler abdominal y torácico\necocardiografía doppler abdominal y torácica\necocardiograma doppler abdominal, renal y torácico\necocardiografía doppler abdominal, renal y torácica\necocardiograma doppler abdominal, renal, torácico y cardiaco\necocardiografía doppler abdominal, renal, torácica y cardiaca'
#   [chunk 4/11 | chars 220-394]
#   RAW: 'ecografía vaginal\nmasa anexial izquierda\ndiámetro mayor 7 cm\nvascularizada\nútero grande\novario derecho normales'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'TC abdómino-pélvico\nrealización de TC abdómino-pélvico\nidentificándose una masa compleja en polo inferior de riñón derecho\ndiámetro de 64 x 65 mm\nintensa captación de contraste\náreas hipodensas centrales'
#   [chunk 6/11 | chars 686-857]
#   RAW: 'radiografía abdominal\necografía abdominal\ntomografía computarizada abdominal\nbiopsia de los nódulos del riñón\nmamografía del riñón\nresonancia magnética del riñón\nangiografía del riñón\ncirugía del riñón\nbiopsia de tejido del riñón\nterapia de quimioterapia del riñón\nterapia de radioterapia del riñón\nterapia de radioterapia de los nódulos del riñón\nterapia de cirugía de los nódulos del riñón\nterapia de biopsia de los nódulos del riñón\nterapia de biopsia del riñón\nterapia de angiografía del riñón\nterapia de resonancia magnética del riñón\nterapia de tomografía computarizada abdominal\nterapia de ecografía abdominal\nterapia de radiografía abdominal'
#   [chunk 7/11 | chars 858-965]
#   RAW: 'radiografía\nexploración\nlesión sólido-quística\ncaptación de contraste'
#   [chunk 8/11 | chars 966-1047]
#   RAW: 'radiografía\nexploración\nprueba diagnóstica\nintervención\ntratamiento\ncirugía'
#   [chunk 9/11 | chars 1047-1258]
# ...
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'espirometría\nelectrocardiograma\necocardiograma\nanalítica sanguínea\nCHCM=31.4g/dl\nneutrófilos=76.6%\nlinfocitos=16.4%\neosinófilos=0.9%\nfibrinógeno=645mg/dl\nGGT=52U/l\nD-Dímero positivo'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'eco-Doppler venoso\ntrombosis venosa de las venas axilar, cefálica y basílica\ncompresión del nervio cutáneo braquial medial a nivel del hiato basílico'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'radiografía\nutrasonografía-Doppler\ntratamiento con Tinzapaina sódica\nventajes en ocho por cabestrillo sencillo\nrehabilitación funcional\nfractura de clavícula\nconsolidación de la fractura de clavícula\nrecanalización completa de las venas trombosadas'
# [246/250] es-S1888-75462016000400180-1.txt | 38.17s | 7 chunks | 46 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: 'procedimiento medico\nexploración\npaciente de 58 años'
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomía\nmetrorragias\nmiomas'
#   [chunk 3/20 | chars 141-448]
#   RAW: 'exploración ginecología\nosteoporosis densitométrica lumbar\ntratada con denosumab\nsuplementos de vitamina D\nnormales en cuello femoral\nno refería hábitos tóxicos\nantecedentes personales ni familiares de fractura\nIMC normal'
#   [chunk 4/20 | chars 449-629]
#   RAW: 'procedimiento medico\ndolor mecánico\npie izquierdo\nAINEs'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'exploración\ndolor a la movilización del antepié izquierdo'
#   [chunk 6/20 | chars 737-790]
#   RAW: 'radiografía de pies\nexploración física de pies'
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Rx de pies'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'RMN de pie izquierdo\nfractura de estrés en el 2o MTT\ncallo perióstico\nedema de tejidos blandos'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'procedimiento medico\nestudio analítico\nincremento de niveles de PTH\nincremento de niveles de vitamina D\nsuplementación de vitamina D\nniveles de PTH\nniveles de vitamina D\ncalcio sérico\ncalcio urinario\nfunción renal'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: 'tratamiento con suplementos de vitamina D\ndenosumab'
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'tratamiento conservador\ndescarga\nreposo relativo\nAINEs\nmagnetoterapia'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'bazedoxifeno\ncalcio con vitamina D\ndolor en el pie izquierdo'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'radiografia\nfractura de estrés previa\ncallo de fractura antiguo\n2o MTT'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'RMN de pie izquierdo\nedema de 1er y 3er MTT\nedema de huesos cuneiforme\nedema de escafoides\nedema de astrágalo\ntenosinovitis del tibial posterior'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'densitometría ósea\nT-score en columna lumbar de -3,5'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: 'bazedoxifeno\nvitamina D\nreanudarlos'
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'rehabilitación\ndescarga\ntratamiento'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: 'osteoporosis\n\n(No hay más procedimientos en el texto)'
#   [chunk 19/20 | chars 2706-2869]
#   RAW: 'radiografía\necocardiograma\ntomografía computarizada\nresonancia magnética\nangiografía\necocardiografía transesofágica\necocardiografía doppler\nelectrocardiograma\necograma\necocardiograma de estres\necocardiograma de estres dobutaminado\necocardiograma de estres dobutaminado con vasodilatadores\necocardiograma de estres con vasodilatadores\necocardiograma de estres con vasodilatadores y dobutaminado\necocardiograma de estres con vasodilatadores y dobutaminado con vasodilatadores\necocardiograma de estres con vasodilatadores y dobutaminado con vasodilatadores y dobutaminado\necocardiograma de estres con vasodilatadores y dobutaminado con vasodilatadores y dobutaminado con vasodilatadores y dobutaminado con vasodilatadores y dobutaminado con vasodilatadores y dobutaminado con vasodilatadores y dobutaminado con vasodilatadores y dobutaminado con vasodilatadores y dobutaminado con vasodilatadores'
#   [chunk 20/20 | chars 2870-3148]
#   RAW: 'exploración física\ncirugía\nfracturas de estrés'
# [247/250] es-S1889-836X2015000200005-2.txt | 68.35s | 20 chunks | 50 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: 'didanosina\ntenofovir\nlopinavir/ritonavir'
#   [chunk 2/16 | chars 158-268]
#   RAW: 'exploraciones\ndolores óseos difusos'
#   [chunk 3/16 | chars 269-407]
#   RAW: 'fosfatasa alcalina (FA)\nPTH (paratohormona)'
#   [chunk 4/16 | chars 408-569]
#   RAW: '25-hidroxivitamina D\ncalcio total\ncalcio iónico\nparámetros bioquímicos rutinarios en suero\nelemental y sedimento de orina'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'radiografía simple de columna\ngammagrafía con Tc99'
#   [chunk 6/16 | chars 697-865]
#   RAW: 'exploración\nintervención\ncirugía\ntratamiento\nprueba diagnostica'
#   [chunk 7/16 | chars 866-953]
#   RAW: 'exploración física\ndebilidad muscular de predominio proximal'
#   [chunk 8/16 | chars 954-1201]
#   RAW: 'hiperglucemia leve\nglucosuria marcada\nhipofosfatemia\nfosfaturia inapropiadamente alta\nhipouricemia\nacidosis metabólica\nproteinuria'
#   [chunk 9/16 | chars 1202-1315]
#   RAW: 'radiografía\naminoaciduria moderada\nvalores aumentados de glicina\nvalina\nserina\ntreonina'
#   [chunk 10/16 | chars 1316-1347]
#   RAW: 'FGF23 sérico'
#   [chunk 11/16 | chars 1348-1392]
#   RAW: 'radiografía\necocardiograma\necograma\necocardiografía\neco-Doppler\neco-Doppler abdominal\neco-Doppler de la vena cava\neco-Doppler de la arteria femoral\neco-Doppler de la arteria carótida\neco-Doppler de la arteria tibial\neco-Doppler de la arteria poplítea\neco-Doppler de la arteria radial\neco-Doppler de la arteria ulnar\neco-Doppler de la arteria axilar\neco-Doppler de la arteria subclavia\neco-Doppler de la arteria iliaca\neco-Doppler de la arteria femoral poplítea\neco-Doppler de la arteria tibial peroneal\neco-Doppler de la arteria tibial posterior\neco-Doppler de la arteria tibial anterior\neco-Doppler de la arteria dorsal de la mano\neco-Doppler de la arteria dorsal del pie\neco-Doppler de la arteria plant'
#   [chunk 12/16 | chars 1392-1553]
#   RAW: 'diagnóstico de síndrome de Fanconi incompleto\nhipofosfatemia grave\nprobable osteomalacia\nrelación con TDF'
#   [chunk 13/16 | chars 1554-1655]
#   RAW: 'tratamiento\nraltegravir\ndarunavir potenciado con ritonavir'
#   [chunk 14/16 | chars 1656-1750]
#   RAW: '1. administración de suplementos de fósforo\n2. administración de 25-HCC\n3. administración de 1,25-dihidroxivitamina D (1,25 DHCC)'
#   [chunk 15/16 | chars 1751-1800]
#   RAW: 'radiografía\necocardiograma\necograma abdominal\ntomografía axial computarizada\nbiopsia de tejido\nbiopsia de tejido percutánea\nbiopsia de tejido endoscópica\nbiopsia de tejido transfórmica\nbiopsia de tejido transfórmica endoscópica\nbiopsia de tejido transfórmica percutánea\nbiopsia de tejido transfórmica percutánea endoscópica\nbiopsia de tejido transfórmica percutánea endoscópica con sedación\nbiopsia de tejido transfórmica percutánea endoscópica con sedación y anestesia local\nbiopsia de tejido transfórmica percutánea endoscópica con sedación, anestesia local y analgésico\nbiopsia de tejido transfórmica percutánea endoscópica con sedación, anestesia local, analgésico y antibiótico\nbiopsia de tejido transfórmica percutánea endoscópica con sedación, anestesia local, analgésico, antibió'
#   [chunk 16/16 | chars 1801-2071]
#   RAW: 'exploración\nprueba analítica séricas\ntratamiento de TDF\ndolores óseos\ndebilidad muscular\npeso basal\nreabsorción de fosfato'
# [248/250] es-S1889-836X2015000400006-1.txt | 76.36s | 16 chunks | 37 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: 'radiografía\nexploración física\npruebas diagnosticas\nlupus cutáneo\ntratamiento\nreumatología'
#   [chunk 2/40 | chars 206-230]
#   RAW: 'Tiroiditis de Hashimoto'
#   [chunk 3/40 | chars 231-246]
#   RAW: 'Apendicectomía'
#   [chunk 4/40 | chars 247-276]
#   RAW: 'Exfumadora'
#   [chunk 5/40 | chars 277-289]
#   RAW: 'radiografia\necocardiograma\necograma abdominal\necografia\ntomografía axial computarizada\nresonancia magnética\nangiografía\necocardiografía\necocardiograma doppler\necocardiograma transesofágico\necocardiograma transtorácico\necocardiograma doppler transesofágico\necocardiograma transtorácico doppler\necocardiograma doppler transesofágico transtorácico\necocardiograma doppler transtorácico transesofágico\nangiografía coronaria\nangiografía cerebral\nangiografía aorta\nangiografía pulmonar\nangiografía mesenterica\nangiografía renal\nangiografía hepática\nangiografía portahepática\nangiografía femoral\nangiografía poplítea\nangiografía tibial\nangiografía plantar\nangiografía carpiana\nangiografía metacarpiana\nangiografía digital\nangiografía palmar\nangiografía dorsal\nangiografía plantar lateral\nangiografía plantar medial\nangiografía plantar central\nangiografía plantar lateral medial\nangi'
#   [chunk 6/40 | chars 290-360]
#   RAW: 'PROCEDIMIENTO medico:\ntomas de bebidas con quinina (tónicas)'
#   [chunk 7/40 | chars 361-399]
#   RAW: 'procedimiento medico\nanemia\nparto'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'Cesárea\nligadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: 'Enfermedad actual:\nconsulta\npruebas diagnosticas (intensa astenia y presíncopes)\nintervenciones (deambulación dificultada)\ntratamientos (anorexia)'
#   [chunk 10/40 | chars 604-651]
#   RAW: 'Menstruación\nduradera\nabundante'
#   [chunk 11/40 | chars 652-697]
#   RAW: 'exploración física\nauscultación cardiaca\nauscultación abdominal'
#   [chunk 12/40 | chars 698-725]
#   RAW: 'Epistaxis\ngingivorragia'
#   [chunk 13/40 | chars 725-825]
#   RAW: 'exploración analítica\nanemia\nhemoglobina\ntrombopenia\nplaquetas'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'LDH\nfrotis sanguíneo\npresencia de esquistocitos'
#   [chunk 15/40 | chars 890-1052]
#   RAW: 'Exploraciones\n- Resto de exploraciones normales\n\nDiagnóstico\n- PTT'
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'transfusión de hematíes\ntransfusión de plaquetas'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'procedimiento medico\nafasia global\ndesviación de la comisura bucal a la izquierda'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: 'exploración\nprueba diagnostica'
#   [chunk 19/40 | chars 1366-1445]
#   RAW: 'hematología\nestudio'
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'plasmaféresis'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: 'exploración clínica\ningreso en UCI'
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'Plan de sesiones de plasmaféresis\n1. Volumen de recambio: 1 veces el volumen plasmático\n2. Volumen de recambio: 1,5 veces el volumen plasmático'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: 'tratamiento\n48 h. después de conseguir la respuesta.'
#   [chunk 24/40 | chars 1838-1862]
#   RAW: 'procedimiento medico\nradiografia\necocardiograma\ntomografía computarizada\nbiopsia\ncirugia\ntratamiento farmacológico\nterapia intensiva\ntransfusión de sangre\ndrenaje\nendoscopia\necografía\nelectrocardiograma\necocardiografía\nresonancia magnética\nangiografía\neco Doppler\nbiopsia de tejido\nbiopsia de tejido blando\nbiopsia de tejido duro\nbiopsia de tejido maligno\nbiopsia de tejido benigno\nbiopsia de tejido sólido\nbiopsia de tejido cistoso\nbiopsia de tejido hematológico\nbiopsia de tejido hematopoyético\nbiopsia de tejido hematopoyético periférico\nbiopsia de tejido hematopoyético medular\nbiopsia de tejido hematopoyético medular periférica\nbiopsia de tejido hematopoyético medular periférica de cadera\nbiopsia de tejido hematopoyético medular periférica de cadera izquierda\nbiopsia de tejido hematopoyético medular per'
#   [chunk 25/40 | chars 1862-1927]
#   RAW: 'radiografía\ntablas de relación\nexploración'
#   [chunk 26/40 | chars 1928-1987]
#   RAW: '1.750 cc. (reinfusión de volumen)'
#   [chunk 27/40 | chars 1988-2014]
#   RAW: 'plasma fresco\n+ 350 cc.'
#   [chunk 28/40 | chars 2015-2052]
#   RAW: 'albúmina humana al 20%\n1.400 cc.'
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'diálisis peritoneal\nsolución Dianeal® 1,36%'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'plasmaféresis\ncatéter en yugular derecha\ncatéter doble luz en femoral izquierda'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE (Hospal®)\nfiltro PTE-2000'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: 'heparina\ndosis de 15-5-5-5 mgr\nduración de las sesiones de unos 210 minutos\ninfusión media de 980 ml/h\nflujos de sangre entre 120-140 ml/min\npresiones de (PA.'
#   [chunk 33/40 | chars 2628-2709]
#   RAW: 'radiografía\nexploración física\nprueba de presión arterial\nprueba de volumen venoso\nprueba de tensión músculo-esquelética'
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'procedimiento medico\nmal estado general\nsedada\nmantenidas (constantes)'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: '17 sesiones\n\n1. exploración\n2. prueba diagnóstica\n3. intervención\n4. tratamiento\n5. cirugía\n6. radiografía\n7. tomografía\n8. ecografía\n9. biopsia\n10. angiografía\n11. endoscopia\n12. broncoscopia\n13. laparoscopia\n14. colposcopia\n15. mamografía\n16. ecocardiografía\n17. electrocardiografía'
#   [chunk 36/40 | chars 2842-2902]
#   RAW: 'radiografia\nexploración física\necocardiograma\necograma abdominal\ntomografía computarizada\nprueba de función hepática\nprueba de función renal\nprueba de función pulmonar\nprueba de función cardiaca\nprueba de función hematológica\nprueba de función endocrina\nprueba de función inmunológica\nprueba de función neurológica\nprueba de función psicológica\nprueba de función auditiva\nprueba de función vestibular\nprueba de función oculares\nprueba de función gastrointestinal\nprueba de función hematopoyética\nprueba de función oncológica\nprueba de función genética\nprueba de función nutricional\nprueba de función metabólica\nprueba de función infecciosa\nprueba de función respiratoria\nprueba de función urinaria\nprueba de función sexual\nprueba de función reumatológica\nprueba de función dermatológica\nprueba de función endocrinológica\nprueba'
#   [chunk 37/40 | chars 2902-3034]
#   RAW: 'exploración física\ndiazepam\nsalino fisiológico'
#   [chunk 38/40 | chars 3034-3125]
#   RAW: 'radiografía\nPTM\ncirugía'
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'radiografía\ncambiar el SET'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: 'exploración\ntratamiento\ncirugía'
# [249/250] es-S2254-28842014000200009-1.txt | 143.23s | 40 chunks | 59 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'carcinoma seroso papilar\nintervención\novario izquierdo\nganglio de la cadena aorto-cava\nestadio IIIC'
#   [chunk 2/11 | chars 208-315]
#   RAW: 'quimioterapia adyuvante\ncarboplatino\npaclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: 'radiografía\nexploración\nprueba diagnostica\nintervención\ntratamiento\ncirugía'
#   [chunk 4/11 | chars 459-661]
#   RAW: 'resección anterior de recto superior\nbiopsia intraoperatoria\nbiopsia de una lesión hepática'
#   [chunk 5/11 | chars 661-783]
#   RAW: 'carboplatino\npaclitaxel\nCA 125 de 123.3 U/ml'
#   [chunk 6/11 | chars 784-1007]
#   RAW: 'carboplatino\ninfusión de carboplatino\ndisnea\nvómitos\npérdida de conocimiento\nTAS/TAD de 70/50 mmHg'
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'corticoides\ninfusión'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'desensibilización\nenlentecimiento de la velocidad de infusión'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'exploración\nprueba diagnostica\nintervencion\ntratamiento\ncirugia\n\n- radiografia\n- Cetirizina 10 mg\n- Prednisona 1 mg/kg\n- Ranitidina 150 mg\n- Montelukast 10 mg\n\ntratamiento\nintervencion\n\n- infusión de disoluciones con concentraciones de 0,02, 0,2 y 2 mg/ml respectivamente\n- premedicación con Cetirizina 10 mg, Prednisona 1 mg/kg, Ranitidina 150 mg y Montelukast 10 mg la noche anterior y media hora antes de la infusión\n- detener la infusión\n- recomendación de no volver a usar ninguna sal de platino'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'trabectedina\nadriamicina liposomal pegilada'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: 'exploración\nprueba diagnostica\nintervención\ntratamiento\ncirugía'
# [250/250] es-S2340-98942015000100005-1.txt | 37.87s | 11 chunks | 28 menciones
#
# Predicciones guardadas en proctemist_5shot_predictions.tsv
# Tiempo medio por archivo: 57.95s

# %% [markdown]
# ## 6. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd

def prf(tp, fp, fn):
    p = tp / (tp + fp) if (tp + fp) else 0.0
    r = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1

df_pred = pd.read_csv(PREDICTIONS_TSV, sep='\t')
df_gs   = pd.read_csv(GS_TEST_TSV, sep='\t')
df_gs   = df_gs[df_gs['filename'].isin(df_pred['filename'].unique())]

set_gs   = set(zip(df_gs['filename'],   df_gs['label'],   df_gs['start_span'],   df_gs['end_span']))
set_pred = set(zip(df_pred['filename'], df_pred['label'], df_pred['start_span'], df_pred['end_span']))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1   = prf(tp, fp, fn)

report = {'Estricta': {'tp': tp, 'fp': fp, 'fn': fn,
                       'precision': round(p, 4), 'recall': round(r, 4), 'fscore': round(f1, 4)}}

print(f'── ESTRICTA ── P={p:.4f} R={r:.4f} F1={f1:.4f} (TP={tp} FP={fp} FN={fn})\n')

thresholds = [0.0, 0.5, 0.8]
results = {t: {'tp': 0, 'fp': 0, 'fn': 0} for t in thresholds}

for filename in df_pred['filename'].unique():
    gs_ints   = list(zip(df_gs[df_gs['filename']     == filename]['start_span'],
                         df_gs[df_gs['filename']     == filename]['end_span']))
    pred_ints = list(zip(df_pred[df_pred['filename'] == filename]['start_span'],
                         df_pred[df_pred['filename'] == filename]['end_span']))
    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )
    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi)
                matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]['tp'] += tp_t
        results[t]['fp'] += len(pred_ints) - tp_t
        results[t]['fn'] += len(gs_ints)   - tp_t

print('── IoU ──')
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]['tp'], results[t]['fp'], results[t]['fn']
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f'IoU >= {t}'] = {'tp': tp_t, 'fp': fp_t, 'fn': fn_t,
                              'precision': round(p_t, 4), 'recall': round(r_t, 4), 'fscore': round(f1_t, 4)}
    print(f'IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})')

with open(EVAL_SUMMARY_JSON, 'w', encoding='utf-8') as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ── P=0.1995 R=0.5276 F1=0.2895 (TP=1909 FP=7659 FN=1709)
#
# ── IoU ──
# IoU >= 0.0:  P=0.2921  R=0.7723  F1=0.4239  (TP=2795 FP=6773 FN=824)
# IoU >= 0.5:  P=0.2453  R=0.6485  F1=0.3560  (TP=2347 FP=7221 FN=1272)
# IoU >= 0.8:  P=0.2070  R=0.5474  F1=0.3004  (TP=1981 FP=7587 FN=1638)
