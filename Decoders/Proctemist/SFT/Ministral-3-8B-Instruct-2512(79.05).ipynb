# %% [markdown]
# # Pipeline QLoRA NER — ProcTemIST con Ministral-3-8B-Instruct-2512
#
# Flujo completo de fine-tuning generativo para reconocimiento de procedimientos médicos en textos clínicos en español.
# Cubre configuración, entrenamiento con SFT, inferencia por oraciones y evaluación.
#
# ## Contenido
#
# 1. [Entorno y dependencias](#1-entorno-y-dependencias)
# 2. [Configuración](#2-configuracion)
# 3. [Carga del modelo](#3-carga-del-modelo)
# 4. [Adaptadores LoRA](#4-adaptadores-lora)
# 5. [Dataset](#5-dataset)
# 6. [Entrenamiento](#6-entrenamiento)
# 7. [Preparación para inferencia](#7-preparacion-para-inferencia)
# 8. [Inferencia](#8-inferencia)
# 9. [Evaluación](#9-evaluacion)

# %% [markdown]
# ## 1. Entorno y dependencias
#
# Instalación de paquetes e importación de librerías.

# %%
# %%capture
# !pip uninstall -y Pillow
# !pip install "Pillow==11.3.0" --quiet

# !pip install git+https://github.com/huggingface/transformers.git --upgrade --quiet

# !pip install --no-deps "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "unsloth_zoo @ git+https://github.com/unslothai/unsloth-zoo.git"

# !pip install peft accelerate bitsandbytes trl==0.15.2 --quiet

# !pip install -q spacy
# !python -m spacy download es_core_news_md --quiet

# %% [markdown]
# ## 2. Configuración
#
# Hiperparámetros, rutas del dataset y credenciales.

# %%
import os
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1"

# ── Modelo ────────────────────────────────────────────────────────────────────
MODEL_NAME = "unsloth/Ministral-3-8B-Instruct-2512-unsloth-bnb-4bit"

# ── LoRA ──────────────────────────────────────────────────────────────────────
LORA_R         = 64
LORA_ALPHA     = 128
LORA_DROPOUT   = 0
MAX_SEQ_LENGTH = 4096

# ── Entrenamiento ─────────────────────────────────────────────────────────────
BATCH_SIZE       = 1
GRAD_ACCUM       = 32
LEARNING_RATE    = 3e-5
NUM_TRAIN_EPOCHS = 2
WARMUP_RATIO     = 0.05
WEIGHT_DECAY     = 0.01
MAX_GRAD_NORM    = 0.3
TRAIN_SEED       = 3407
OUTPUT_DIR       = "outputs_lora"

# ── Dataset / chunking ────────────────────────────────────────────────────────
MAX_CHUNK_CHARS      = None   # None para oraciones sueltas
SPACY_MODEL          = "es_core_news_md"
MAX_NEGATIVE_RATIO   = None   # Ej: 0.5 => 1 negativo por cada 2 positivos
NEGATIVE_SAMPLE_SEED = 3407

# ── Prompt del sistema ────────────────────────────────────────────────────────
SYSTEM_PROMPT = (
    "Actua como un sistema NER medico de alta precision.\n\n"
    "REGLAS DE EXTRACCION:\n"
    "1. Extrae exclusivamente entidades de tipo PROCEDIMIENTO medico (exploraciones, pruebas diagnosticas, intervenciones, tratamientos, cirugias, etc.).\n"
    "2. COPIA Y PEGA de forma literal: No cambies mayusculas, minusculas ni tildes.\n"
    "3. PROHIBIDO USAR SINONIMOS: Si el texto dice 'radiografia', no escribas 'Rx'.\n"
    "4. REPETICIONES: Si un procedimiento aparece varias veces en el texto, debes listarlo varias veces en lineas separadas.\n"
    "5. ORDEN: Extrae las menciones en el mismo orden en que aparecen en el texto.\n"
    "6. FORMATO: Únicamente el texto de la mención, una por línea. PROHIBIDO usar caracteres de lista al inicio (como '-', '*', '•', '1.').\n"
    "7. Si no hay nada, devuelve un texto vacio."
)

# ── Inferencia ────────────────────────────────────────────────────────────────
MAX_NEW_TOKENS   = 300
MAX_TEST_FILES   = 250   # None para procesar todos
PRINT_RAW_OUTPUT = True

# ── Rutas Proctemist ───────────────────────────────────────────────────────────
PROJECT_ROOT         = "/kaggle/input/datasets/user"
PROCTEMIST_ROOT      = f"{PROJECT_ROOT}/proctemist"
TEXT_FILES_TRAIN_DIR = f"{PROCTEMIST_ROOT}/text_files_train"
TEXT_FILES_TEST_DIR  = f"{PROCTEMIST_ROOT}/text_files_test"
GS_TRAIN_TSV         = f"{PROCTEMIST_ROOT}/medprocner_tsv_train_subtask1.tsv"
GS_TEST_TSV          = f"{PROCTEMIST_ROOT}/medprocner_tsv_test_subtask1.tsv"
PREDICTIONS_TSV      = "proctemist_llm_predictions.tsv"
EVAL_SUMMARY_JSON    = "evaluation_summary_proctemist.json"

try:
    from kaggle_secrets import UserSecretsClient
    hf_token = UserSecretsClient().get_secret("HF_TOKEN")
except Exception:
    hf_token = None

print(f"Modelo base        : {MODEL_NAME}")
print(f"LoRA r={LORA_R}, alpha={LORA_ALPHA}")
print(f"MAX_SEQ_LENGTH     : {MAX_SEQ_LENGTH}")
print(f"MAX_CHUNK_CHARS    : {MAX_CHUNK_CHARS}")
print(f"Epochs             : {NUM_TRAIN_EPOCHS}")
print(f"MAX_NEW_TOKENS     : {MAX_NEW_TOKENS}")
print(f"MAX_TEST_FILES     : {MAX_TEST_FILES}")
print(f"MAX_NEGATIVE_RATIO : {MAX_NEGATIVE_RATIO}")
# Out:
# Modelo base        : unsloth/Ministral-3-8B-Instruct-2512-unsloth-bnb-4bit
# LoRA r=64, alpha=128
# MAX_SEQ_LENGTH     : 4096
# MAX_CHUNK_CHARS    : None
# Epochs             : 2
# MAX_NEW_TOKENS     : 300
# MAX_TEST_FILES     : 250
# MAX_NEGATIVE_RATIO : None

# %% [markdown]
# ## 3. Carga del modelo
#
# Carga cuantizada en 4-bit con distribución automática entre GPUs disponibles.

# %%
import torch
from unsloth import FastLanguageModel

print(f"GPUs disponibles: {torch.cuda.device_count()}")
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"  GPU {i}: {props.name} — {round(props.total_memory / 1024**3, 1)} GB VRAM")

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name     = MODEL_NAME,
    max_seq_length = MAX_SEQ_LENGTH,
    dtype          = torch.float16,
    load_in_4bit   = True,
    token          = hf_token,
)

if hasattr(tokenizer, "tokenizer"):
    tokenizer = tokenizer.tokenizer

print(f"\nModelo cargado: {MODEL_NAME}")
print(f"Parámetros totales: {sum(p.numel() for p in model.parameters()):,}")
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# Unsloth: Could not find `steps_per_generation` in grpo_trainer
# Unsloth: Could not find `generation_batch_size` in grpo_trainer
# GPUs disponibles: 2
#   GPU 0: Tesla T4 — 14.6 GB VRAM
#   GPU 1: Tesla T4 — 14.6 GB VRAM
# ==((====))==  Unsloth 2026.6.1: Fast Ministral3 patching. Transformers: 5.10.0.dev0.
#    \\   /|    Tesla T4. Num GPUs = 2. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/531 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/131 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/976 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# The tokenizer you are loading from 'unsloth/Ministral-3-8B-Instruct-2512-unsloth-bnb-4bit' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Modelo cargado: unsloth/Ministral-3-8B-Instruct-2512-unsloth-bnb-4bit
# Parámetros totales: 5,403,199,488

# %% [markdown]
# ## 4. Adaptadores LoRA
#
# Inyección de adaptadores LoRA sobre todas las proyecciones lineales del modelo.

# %%
from peft import LoraConfig, get_peft_model

lora_config = LoraConfig(
    r              = LORA_R,
    lora_alpha     = LORA_ALPHA,
    target_modules = "all-linear",
    lora_dropout   = LORA_DROPOUT,
    bias           = "none",
    task_type      = "CAUSAL_LM",
)

model = get_peft_model(model, lora_config)
model.config.use_cache = False

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total     = sum(p.numel() for p in model.parameters())
print(f"Parámetros entrenables: {trainable:,}  ({100*trainable/total:.2f}%)")
model.print_trainable_parameters()
# Out:
# Parámetros entrenables: 215,613,440  (3.84%)
# trainable params: 215,613,440 || all params: 9,133,639,680 || trainable%: 2.3607

# %% [markdown]
# ## 5. Dataset
#
# Segmentación por oraciones, construcción de prompts y ensamblado del dataset de entrenamiento.

# %%
import random
import numpy as np
import pandas as pd
import spacy
from pathlib import Path
from datasets import Dataset

nlp_spacy = spacy.load(SPACY_MODEL, disable=["ner", "lemmatizer"])
print(f"spaCy: {nlp_spacy.meta['name']} v{nlp_spacy.meta['version']}")


def chunk_text_by_sentences(text, nlp, max_chars=MAX_CHUNK_CHARS):
    """Divide el texto en chunks de oraciones completas con sus offsets.
    Si max_chars es None, devuelve una oración por chunk."""
    doc = nlp(text)
    if max_chars is None:
        return [(text[s.start_char:s.end_char], s.start_char, s.end_char) for s in doc.sents]

    chunks, current_chars, chunk_start, current_end = [], 0, None, None
    for sent in doc.sents:
        if current_chars + len(sent.text) > max_chars and chunk_start is not None:
            chunks.append((text[chunk_start:current_end], chunk_start, current_end))
            current_chars, chunk_start, current_end = 0, None, None
        if chunk_start is None:
            chunk_start = sent.start_char
        current_chars += len(sent.text)
        current_end = sent.end_char
    if chunk_start is not None:
        chunks.append((text[chunk_start:current_end], chunk_start, current_end))
    return chunks


def mentions_in_chunk(spans_with_offsets, chunk_start, chunk_end):
    return [span for span, off0, off1 in spans_with_offsets if chunk_start <= off0 < chunk_end]


def build_training_example(text, mentions):
    messages = [
        {"role": "system",    "content": SYSTEM_PROMPT},
        {"role": "user",      "content": f"Texto para analizar:\n{text}"},
        {"role": "assistant", "content": "\n".join(mentions) if mentions else ""},
    ]
    return tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=False)


df_gs = pd.read_csv(GS_TRAIN_TSV, sep="\t").sort_values(["filename", "start_span"])
text_dir = Path(TEXT_FILES_TRAIN_DIR)

positive_texts, negative_texts = [], []
for doc_id, group in df_gs.groupby("filename", sort=False):
    txt_path = text_dir / f"{doc_id}.txt"
    if not txt_path.exists():
        continue
    text = txt_path.read_text(encoding="utf-8")
    spans = list(zip(group["text"], group["start_span"], group["end_span"]))
    chunks = chunk_text_by_sentences(text, nlp_spacy)
    changed = True
    while changed:
        changed = False
        for i in range(len(chunks) - 1):
            _, cs, ce = chunks[i]
            _, ns, ne = chunks[i + 1]
            for _, off0, off1 in spans:
                if cs <= off0 < ce and off1 > ce:
                    chunks[i] = (text[cs:ne], cs, ne)
                    chunks.pop(i + 1)
                    changed = True
                    break
            if changed:
                break
    for chunk_text, char_start, char_end in chunks:
        mentions = mentions_in_chunk(spans, char_start, char_end)
        example  = build_training_example(chunk_text, mentions)
        (positive_texts if mentions else negative_texts).append(example)

if MAX_NEGATIVE_RATIO is None:
    negative_texts_used = negative_texts
else:
    max_neg = max(0, int(len(positive_texts) * MAX_NEGATIVE_RATIO))
    negative_texts_used = (
        random.Random(NEGATIVE_SAMPLE_SEED).sample(negative_texts, k=max_neg)
        if max_neg < len(negative_texts) else negative_texts
    )

formatted_texts = positive_texts + negative_texts_used
dataset = Dataset.from_dict({"text": formatted_texts})

lengths   = [len(tokenizer.encode(t)) for t in formatted_texts]
truncados = sum(1 for l in lengths if l > MAX_SEQ_LENGTH)

print(f"Dataset: {len(dataset)} chunks (max_chars={MAX_CHUNK_CHARS})")
print(f"Positivos: {len(positive_texts)} | Negativos usados: {len(negative_texts_used)} / {len(negative_texts)} (ratio={MAX_NEGATIVE_RATIO})")
print(f"Tokens — min:{min(lengths)}  max:{max(lengths)}  media:{np.mean(lengths):.0f}  p95:{np.percentile(lengths,95):.0f}")
print(f"Truncados (>{MAX_SEQ_LENGTH}): {truncados} ({100*truncados/len(lengths):.1f}%)")
print(f"Menciones totales GS: {len(df_gs)}")
# Out:
# spaCy: core_news_md v3.8.0
# Dataset: 11685 chunks (max_chars=None)
# Positivos: 6940 | Negativos usados: 4745 / 4745 (ratio=None)
# Tokens — min:238  max:601  media:282  p95:338
# Truncados (>4096): 0 (0.0%)
# Menciones totales GS: 11065

# %% [markdown]
# ## 6. Entrenamiento
#
# `SFTTrainer` con `DataCollatorForCompletionOnlyLM` para entrenar únicamente sobre las respuestas del asistente.

# %%
import gc
import torch
from trl import SFTTrainer, SFTConfig, DataCollatorForCompletionOnlyLM

os.environ["PYTORCH_ALLOC_CONF"] = "expandable_segments:True"
os.environ["ACCELERATE_MIXED_PRECISION"] = "fp16"

tokenizer.padding_side = "right"

def filter_fn(examples):
    tokens = tokenizer(examples["text"], add_special_tokens=False)
    return [len(t) <= MAX_SEQ_LENGTH for t in tokens["input_ids"]]

def tokenize_fn(examples):
    return tokenizer(examples["text"], truncation=True, max_length=MAX_SEQ_LENGTH)

train_data = (
    dataset
    .filter(filter_fn, batched=True, num_proc=2)
    .map(tokenize_fn, batched=True, num_proc=2, remove_columns=["text"])
)
print(f"Train: {len(train_data)} ejemplos")

response_template_ids = tokenizer.encode("[/INST]", add_special_tokens=False)
data_collator = DataCollatorForCompletionOnlyLM(
    response_template=response_template_ids,
    tokenizer=tokenizer,
)

trainer = SFTTrainer(
    model         = model,
    tokenizer     = tokenizer,
    train_dataset = train_data,
    data_collator = data_collator,
    args = SFTConfig(
        max_seq_length              = MAX_SEQ_LENGTH,
        packing                     = False,
        dataset_kwargs              = {"skip_prepare_dataset": True},
        per_device_train_batch_size = BATCH_SIZE,
        gradient_accumulation_steps = GRAD_ACCUM,
        num_train_epochs            = NUM_TRAIN_EPOCHS,
        warmup_ratio                = WARMUP_RATIO,
        learning_rate               = LEARNING_RATE,
        fp16                        = True,
        bf16                        = False,
        logging_steps               = 10,
        optim                       = "paged_adamw_8bit",
        weight_decay                = WEIGHT_DECAY,
        max_grad_norm               = MAX_GRAD_NORM,
        lr_scheduler_type           = "linear",
        seed                        = TRAIN_SEED,
        output_dir                  = OUTPUT_DIR,
        report_to                   = "none",
        remove_unused_columns       = False,
        ddp_find_unused_parameters  = False,
        gradient_checkpointing      = True,
        eval_strategy               = "no",
        save_strategy               = "no",
    ),
)

trainer_stats = trainer.train()

for i in range(torch.cuda.device_count()):
    used  = round(torch.cuda.max_memory_reserved(i) / 1024**3, 3)
    total = round(torch.cuda.get_device_properties(i).total_memory / 1024**3, 1)
    print(f"GPU {i}: VRAM pico = {used} GB / {total} GB ({100*used/total:.1f}%)")

print(f"Tiempo : {trainer_stats.metrics['train_runtime']:.0f} s  ({trainer_stats.metrics['train_runtime']/60:.1f} min)")
print(f"Loss   : {trainer_stats.metrics.get('train_loss', 'N/A'):.4f}")

# ── Guardar adaptadores LoRA ──────────────────────────────────────────────────
LORA_SAVE_DIR = "/kaggle/working/lora_adapter"
model.save_pretrained(LORA_SAVE_DIR)
tokenizer.save_pretrained(LORA_SAVE_DIR)
print(f"Adaptadores LoRA guardados en: {LORA_SAVE_DIR}")
# Out:
# Filter (num_proc=2):   0%|          | 0/11685 [00:00<?, ? examples/s]
# Map (num_proc=2):   0%|          | 0/11685 [00:00<?, ? examples/s]
# warmup_ratio is deprecated and will be removed in v5.2. Use `warmup_steps` instead.
# Train: 11685 ejemplos
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 11,685 | Num Epochs = 2 | Total steps = 732
# O^O/ \_/ \    Batch size per device = 1 | Gradient accumulation steps = 32
# \        /    Data Parallel GPUs = 1 | Total batch size (1 x 32 x 1) = 32
#  "-____-"     Trainable parameters = 215,613,440 of 9,133,639,680 (2.36% trained)
# Unsloth: Double buffering enabled (parallel H2D + compute) for backward pass.
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='3' max='732' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  3/732 00:53 < 10:54:43, 0.02 it/s, Epoch 0.01/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %% [markdown]
# ## 7. Preparación para inferencia
#
# Liberación del trainer, configuración del pipeline generativo y listado de archivos de test.

# %%
import gc, time, re, json, logging
import pandas as pd
from pathlib import Path
from transformers import pipeline

LORA_SAVE_DIR = "/kaggle/input/datasets/user/checkpoint1/lora_adapter"

if "trainer" in dir():
    del trainer
    gc.collect()
    torch.cuda.empty_cache()
else:

    import torch
    from unsloth import FastLanguageModel
    from peft import PeftModel
    model_base, tokenizer = FastLanguageModel.from_pretrained(
        model_name     = MODEL_NAME,
        max_seq_length = MAX_SEQ_LENGTH,
        dtype          = torch.float16,
        load_in_4bit   = True,
        token          = hf_token,
    )
    if hasattr(tokenizer, "tokenizer"):
        tokenizer = tokenizer.tokenizer
    model = PeftModel.from_pretrained(model_base, LORA_SAVE_DIR)
    print(f"Adaptador cargado desde {LORA_SAVE_DIR}")

logging.getLogger("transformers.generation.utils").setLevel(logging.ERROR)
model.eval()

pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
)

def build_ner_messages(text):
    return [
        {
            "role": "user",
            "content": f"{SYSTEM_PROMPT}\n\nTexto para analizar:\n{text}",
        }
    ]

txt_files = sorted(Path(TEXT_FILES_TEST_DIR).glob("*.txt"))
if MAX_TEST_FILES is not None:
    txt_files = txt_files[:MAX_TEST_FILES]

print(f"Archivos de test a procesar: {len(txt_files)}")

# %% [markdown]
# ## 8. Inferencia
#
# Segmentación por oraciones, extracción de menciones y ajuste de offsets al documento completo.

# %%
import json 
import gc
import time
import re
from pathlib import Path
import pandas as pd
import torch

CHECKPOINT_INPUT = Path("/kaggle/input/datasets/user/checkpoint1/inference_checkpoint.json")
CHECKPOINT_FILE = Path("/kaggle/working/inference_checkpoint.json")

if CHECKPOINT_INPUT.exists():
    with open(CHECKPOINT_INPUT) as f:
        ckpt = json.load(f)
    print(f"Retomando desde checkpoint inicial de Input: {len(ckpt['done_files'])} archivos ya procesados")
elif CHECKPOINT_FILE.exists():
    with open(CHECKPOINT_FILE) as f:
        ckpt = json.load(f)
    print(f"Retomando desde checkpoint de trabajo: {len(ckpt['done_files'])} archivos ya procesados")
else:
    ckpt = None

if ckpt:
    pred_rows       = ckpt["pred_rows"]
    inference_times = ckpt["inference_times"]
    done_files      = set(ckpt["done_files"])
else:
    pred_rows, inference_times, done_files = [], [], set()

total_files = len(txt_files)

for i, txt_path in enumerate(txt_files):
    if txt_path.stem in done_files:
        print(f"[{i+1}/{total_files}] {txt_path.name} — ya procesado, saltando")
        continue

    text = txt_path.read_text(encoding="utf-8")
    raw_mentions = []
    t0 = time.time()

    chunks = chunk_text_by_sentences(text, nlp_spacy)

    for chunk_idx, (chunk_text, chunk_char_start, chunk_char_end) in enumerate(chunks):
        prompt = tokenizer.apply_chat_template(
            build_ner_messages(chunk_text),
            tokenize=False,
            add_generation_prompt=True,
        )
        try:
            result = pipe(
                prompt,
                max_new_tokens=MAX_NEW_TOKENS,
                max_length=None,
                do_sample=False,
            )[0]["generated_text"].strip()
        except RuntimeError as e:
            if "out of memory" in str(e).lower():
                gc.collect()
                torch.cuda.empty_cache()
            continue

        if PRINT_RAW_OUTPUT:
            print(f"  [chunk {chunk_idx+1}/{len(chunks)} | chars {chunk_char_start}-{chunk_char_end}]")
            print(f"  RAW: {repr(result)}")

        search_cursors = {}
        for mention in [line.strip() for line in result.splitlines() if line.strip()]:
            pattern = re.escape(mention)
            cursor  = search_cursors.get(mention, chunk_char_start)
            match   = re.search(pattern, text[cursor:chunk_char_end], re.IGNORECASE)
            if not match:
                match = re.search(pattern, text[chunk_char_start:chunk_char_end], re.IGNORECASE)
                if not match:
                    continue
                off0 = chunk_char_start + match.start()
                off1 = chunk_char_start + match.end()
            else:
                off0 = cursor + match.start()
                off1 = cursor + match.end()
            search_cursors[mention] = off1
            raw_mentions.append((text[off0:off1], off0, off1))

    t_infer = time.time() - t0
    inference_times.append(t_infer)

    raw_mentions.sort(key=lambda x: x[1])
    seen_offsets = set()
    deduped = []
    for span_text, off0, off1 in raw_mentions:
        if (off0, off1) not in seen_offsets:
            seen_offsets.add((off0, off1))
            deduped.append((span_text, off0, off1))

    for mark_idx, (span_text, off0, off1) in enumerate(deduped, 1):
        pred_rows.append({
            "filename":   txt_path.stem,
            "ann_id":     f"T{mark_idx}",
            "label":      "PROCEDIMIENTO",
            "start_span": off0,
            "end_span":   off1,
            "text":       span_text,
        })

    done_files.add(txt_path.stem)
    print(f"[{i+1}/{total_files}] {txt_path.name} | {t_infer:.2f}s | {len(chunks)} chunks | {len(deduped)} menciones")

    with open(CHECKPOINT_FILE, "w") as f:
        json.dump({"pred_rows": pred_rows, "inference_times": inference_times,
                   "done_files": list(done_files)}, f)

pd.DataFrame(pred_rows, columns=["filename", "ann_id", "label", "start_span", "end_span", "text"]).to_csv(
    PREDICTIONS_TSV, sep="\t", index=False
)
print(f"\nPredicciones guardadas en {PREDICTIONS_TSV}")
if inference_times:
    print(f"Tiempo medio por archivo: {sum(inference_times)/len(inference_times):.2f}s")
# Out:
# Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
#   [chunk 1/13 | chars 0-90]
#   RAW: ''
#   [chunk 2/13 | chars 91-170]
#   RAW: ''
#   [chunk 3/13 | chars 171-204]
#   RAW: 'exploración física'
#   [chunk 4/13 | chars 205-347]
#   RAW: 'ultrasonido abdominal'
#   [chunk 5/13 | chars 348-472]
#   RAW: 'Urograma descendente'
#   [chunk 6/13 | chars 473-667]
#   RAW: 'TAC helicoidal'
#   [chunk 7/13 | chars 668-744]
#   RAW: 'estudio hormonal para la determinación de cortisol'
#   [chunk 8/13 | chars 744-799]
#   RAW: 'cirugía por abordaje lumbar'
#   [chunk 9/13 | chars 800-949]
#   RAW: ''
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   [chunk 10/13 | chars 950-1003]
#   RAW: 'adrenalectomía derecha'
#   [chunk 11/13 | chars 1004-1090]
#   RAW: ''
#   [chunk 12/13 | chars 1090-1294]
#   RAW: ''
#   [chunk 13/13 | chars 1295-1397]
#   RAW: 'examen histopatológico'
# [1/250] S0004-06142006000100010-1.txt | 67.60s | 13 chunks | 8 menciones
#   [chunk 1/21 | chars 0-197]
#   RAW: 'gastrectomía subtotal'
#   [chunk 2/21 | chars 198-412]
#   RAW: ''
#   [chunk 3/21 | chars 413-561]
#   RAW: 'exploración física'
#   [chunk 4/21 | chars 561-806]
#   RAW: ''
#   [chunk 5/21 | chars 807-994]
#   RAW: ''
#   [chunk 6/21 | chars 995-1063]
#   RAW: 'marcadores tumorales hepáticos y digestivos'
#   [chunk 7/21 | chars 1064-1164]
#   RAW: 'gastroscopia'
#   [chunk 8/21 | chars 1165-1279]
#   RAW: 'colonoscopia'
#   [chunk 9/21 | chars 1280-1460]
#   RAW: 'ecografía abdominopélvica'
#   [chunk 10/21 | chars 1461-1572]
#   RAW: ''
#   [chunk 11/21 | chars 1572-1920]
#   RAW: 'urografía intravenosa\nluminograma digestivo\ncistograma'
#   [chunk 12/21 | chars 1921-2082]
#   RAW: 'TAC'
#   [chunk 13/21 | chars 2083-2239]
#   RAW: ''
#   [chunk 14/21 | chars 2239-2409]
#   RAW: 'drenaje percutáneo\nnefrectomía'
#   [chunk 15/21 | chars 2410-2526]
#   RAW: 'nefrectomía simple derecha por lumbotomía subcostal\nlumbotomía subcostal'
#   [chunk 16/21 | chars 2527-2617]
#   RAW: 'linfadenectomía hiliar ampliada'
#   [chunk 17/21 | chars 2618-2756]
#   RAW: 'cultivo del fluido\ncitología\nradiológica'
#   [chunk 18/21 | chars 2756-2950]
#   RAW: 'examen histológico'
#   [chunk 19/21 | chars 2951-3107]
#   RAW: ''
#   [chunk 20/21 | chars 3107-3323]
#   RAW: ''
#   [chunk 21/21 | chars 3323-3461]
#   RAW: ''
# [2/250] S0004-06142006000100014-1.txt | 58.33s | 21 chunks | 19 menciones
#   [chunk 1/14 | chars 0-217]
#   RAW: ''
#   [chunk 2/14 | chars 218-324]
#   RAW: ''
#   [chunk 3/14 | chars 324-462]
#   RAW: 'exploración física'
#   [chunk 4/14 | chars 463-598]
#   RAW: 'tacto rectal\nexploración'
#   [chunk 5/14 | chars 598-777]
#   RAW: 'ecografía urológica integral'
#   [chunk 6/14 | chars 777-905]
#   RAW: 'TAC abdómino-pélvica'
#   [chunk 7/14 | chars 906-980]
#   RAW: 'RMN'
#   [chunk 8/14 | chars 981-1024]
#   RAW: 'Rx de tórax'
#   [chunk 9/14 | chars 1024-1107]
#   RAW: 'marcadores tumorales'
#   [chunk 10/14 | chars 1108-1174]
#   RAW: ''
#   [chunk 11/14 | chars 1174-1269]
#   RAW: 'orquiectomía radical inguinal derecha'
#   [chunk 12/14 | chars 1270-1439]
#   RAW: ''
#   [chunk 13/14 | chars 1440-1638]
#   RAW: 'histopatológico'
#   [chunk 14/14 | chars 1638-1801]
#   RAW: 'marcadores tumorales'
# [3/250] S0004-06142006000500002-2.txt | 33.54s | 14 chunks | 11 menciones
#   [chunk 1/25 | chars 0-323]
#   RAW: 'ecográfico\norquidopexia'
#   [chunk 2/25 | chars 324-362]
#   RAW: 'Uretrotomía endoscópica'
#   [chunk 3/25 | chars 363-486]
#   RAW: 'LEOC'
#   [chunk 4/25 | chars 487-527]
#   RAW: 'Ureterolitectomía'
#   [chunk 5/25 | chars 528-569]
#   RAW: ''
#   [chunk 6/25 | chars 569-734]
#   RAW: ''
#   [chunk 7/25 | chars 735-785]
#   RAW: 'espermiograma'
#   [chunk 8/25 | chars 786-978]
#   RAW: 'ecografía-doppler testicular'
#   [chunk 9/25 | chars 978-1089]
#   RAW: 'exploración física se palpaba un testículo izquierdo'
#   [chunk 10/25 | chars 1090-1178]
#   RAW: ''
#   [chunk 11/25 | chars 1178-1213]
#   RAW: ''
#   [chunk 12/25 | chars 1214-1304]
#   RAW: 'Rx de tórax\nTAC toraco-abdómino-pélvico'
#   [chunk 13/25 | chars 1305-1470]
#   RAW: 'analítica\nvalores séricos hormonales\nmarcadores tumorales'
#   [chunk 14/25 | chars 1470-1575]
#   RAW: 'orquiectomía radical inguinal derecha\nbiopsia del testículo izquierdo vía inguinal'
#   [chunk 15/25 | chars 1576-1668]
#   RAW: ''
#   [chunk 16/25 | chars 1669-1750]
#   RAW: ''
#   [chunk 17/25 | chars 1751-1879]
#   RAW: ''
#   [chunk 18/25 | chars 1880-1933]
#   RAW: ''
#   [chunk 19/25 | chars 1934-1981]
#   RAW: ''
#   [chunk 20/25 | chars 1982-2064]
#   RAW: 'biopsia del testículo izquierdo'
#   [chunk 21/25 | chars 2064-2223]
#   RAW: 'histopatológico'
#   [chunk 22/25 | chars 2224-2358]
#   RAW: ''
#   [chunk 23/25 | chars 2359-2385]
#   RAW: ''
#   [chunk 24/25 | chars 2386-2536]
#   RAW: 'biopsia del teste izquierdo'
#   [chunk 25/25 | chars 2536-2723]
#   RAW: 'radiológica\nmarcadores tumorales'
# [4/250] S0004-06142006000500002-3.txt | 66.16s | 25 chunks | 20 menciones
#   [chunk 1/11 | chars 0-175]
#   RAW: 'ecográficamente'
#   [chunk 2/11 | chars 176-353]
#   RAW: 'TAC abdomino-pélvica'
#   [chunk 3/11 | chars 353-447]
#   RAW: 'nefrectomía radical derecha por laparotomía subcostal'
#   [chunk 4/11 | chars 448-603]
#   RAW: 'diagnóstico anatomopatológico'
#   [chunk 5/11 | chars 604-664]
#   RAW: 'cirugía'
#   [chunk 6/11 | chars 665-854]
#   RAW: ''
#   [chunk 7/11 | chars 855-1199]
#   RAW: 'exploración\nTAC'
#   [chunk 8/11 | chars 1199-1464]
#   RAW: 'extirpación de las masas tumorales, resecándose la adyacente al hígado así como varios implantes peritoneales y retroperitoneales\nbiopsia intraoperatoria'
#   [chunk 9/11 | chars 1465-1569]
#   RAW: ''
#   [chunk 10/11 | chars 1569-1760]
#   RAW: ''
#   [chunk 11/11 | chars 1760-2135]
#   RAW: 'analgésicos\nTAC de abdomen\ncirugía'
# [5/250] S0004-06142006000900015-1.txt | 40.09s | 11 chunks | 12 menciones
#   [chunk 1/18 | chars 0-26]
#   RAW: ''
#   [chunk 2/18 | chars 27-350]
#   RAW: 'ecografía'
#   [chunk 3/18 | chars 350-424]
#   RAW: ''
#   [chunk 4/18 | chars 425-475]
#   RAW: ''
#   [chunk 5/18 | chars 475-585]
#   RAW: 'exploración física'
#   [chunk 6/18 | chars 586-657]
#   RAW: ''
#   [chunk 7/18 | chars 658-707]
#   RAW: ''
#   [chunk 8/18 | chars 707-915]
#   RAW: 'hemostasia\nbioquímica\nhemograma'
#   [chunk 9/18 | chars 915-1173]
#   RAW: 'ecografía con flujo Doppler\nflujo Doppler'
#   [chunk 10/18 | chars 1174-1315]
#   RAW: 'flujo Doppler'
#   [chunk 11/18 | chars 1316-1364]
#   RAW: ''
#   [chunk 12/18 | chars 1364-1608]
#   RAW: 'Radiografía de tórax\nTAC toraco-abdomino-pélvico con contraste'
#   [chunk 13/18 | chars 1608-1760]
#   RAW: 'orquiectomía bilateral vía inguinal\ntratamiento hormonal sustitutivo'
#   [chunk 14/18 | chars 1760-2060]
#   RAW: 'anatomía patológica'
#   [chunk 15/18 | chars 2061-2302]
#   RAW: ''
#   [chunk 16/18 | chars 2303-2380]
#   RAW: ''
#   [chunk 17/18 | chars 2380-2486]
#   RAW: 'quimioterapia con carboplatino'
#   [chunk 18/18 | chars 2486-2561]
#   RAW: ''
# [6/250] S0004-06142007000200017-1.txt | 45.19s | 18 chunks | 14 menciones
#   [chunk 1/20 | chars 0-39]
#   RAW: ''
#   [chunk 2/20 | chars 40-266]
#   RAW: ''
#   [chunk 3/20 | chars 266-403]
#   RAW: 'examen físico'
#   [chunk 4/20 | chars 404-442]
#   RAW: ''
#   [chunk 5/20 | chars 442-554]
#   RAW: 'Hemograma completo'
#   [chunk 6/20 | chars 555-578]
#   RAW: 'Serología'
#   [chunk 7/20 | chars 579-688]
#   RAW: 'Prueba de Mantoux\nProteinas totales y fraccionadas\nRX de cadera'
#   [chunk 8/20 | chars 689-853]
#   RAW: 'U/S abdominal\nTAC simple de hipogastrio y pelvis'
#   [chunk 9/20 | chars 853-946]
#   RAW: 'procedimientos quirúrgicos\nExploración retroperitoneal derecha'
#   [chunk 10/20 | chars 947-985]
#   RAW: 'Adenectomía de ilíaca derecha y cava'
#   [chunk 11/20 | chars 986-1014]
#   RAW: 'Linfangioplastia con aguja'
#   [chunk 12/20 | chars 1015-1049]
#   RAW: 'Fasciotomía de la raíz del pene'
#   [chunk 13/20 | chars 1049-1193]
#   RAW: ''
#   [chunk 14/20 | chars 1193-1435]
#   RAW: ''
#   [chunk 15/20 | chars 1435-1477]
#   RAW: ''
#   [chunk 16/20 | chars 1477-1609]
#   RAW: ''
#   [chunk 17/20 | chars 1610-1646]
#   RAW: 'linfangiectomía'
#   [chunk 18/20 | chars 1646-1977]
#   RAW: ''
#   [chunk 19/20 | chars 1978-2560]
#   RAW: ''
#   [chunk 20/20 | chars 2561-2919]
#   RAW: 'bolsas de las seis cubiertas que componen el recubrimiento de los testículos: el escroto, el dartos muscular, la celulosa, la fascia de Cooper, la segunda túnica muscular llamada eritroide, forman también un bloque que debe ser extirpado'
# [7/250] S0004-06142007000600012-1.txt | 68.40s | 20 chunks | 15 menciones
#   [chunk 1/12 | chars 0-206]
#   RAW: ''
#   [chunk 2/12 | chars 207-321]
#   RAW: 'exploración\npalpación a nivel de cordón espermático derecho'
#   [chunk 3/12 | chars 322-413]
#   RAW: 'determinación de marcadores tumorales y hormonas'
#   [chunk 4/12 | chars 413-623]
#   RAW: 'estudio de imagen\necografía'
#   [chunk 5/12 | chars 624-863]
#   RAW: 'RNM'
#   [chunk 6/12 | chars 863-1020]
#   RAW: 'tumoración paratesticular derecha se procede a su exéresis quirúrgica'
#   [chunk 7/12 | chars 1021-1100]
#   RAW: ''
#   [chunk 8/12 | chars 1100-1347]
#   RAW: 'estudio macroscópico'
#   [chunk 9/12 | chars 1348-1683]
#   RAW: 'estudio microscópico'
#   [chunk 10/12 | chars 1684-1880]
#   RAW: 'estudio inmunohistoquímico'
#   [chunk 11/12 | chars 1881-1889]
#   RAW: ''
#   [chunk 12/12 | chars 1890-1900]
#   RAW: ''
# [8/250] S0004-06142007000600014-1.txt | 36.37s | 12 chunks | 10 menciones
#   [chunk 1/18 | chars 0-174]
#   RAW: ''
#   [chunk 2/18 | chars 175-330]
#   RAW: ''
#   [chunk 3/18 | chars 331-405]
#   RAW: ''
#   [chunk 4/18 | chars 406-568]
#   RAW: 'radiografía simple de abdomen'
#   [chunk 5/18 | chars 569-671]
#   RAW: 'sondaje\nse pone un catéter suprapúbico'
#   [chunk 6/18 | chars 672-784]
#   RAW: 'laparotomía\ncolostomía izquierda'
#   [chunk 7/18 | chars 785-980]
#   RAW: 'uretrografía'
#   [chunk 8/18 | chars 981-1144]
#   RAW: 'intervención\ncolonoscopia'
#   [chunk 9/18 | chars 1145-1305]
#   RAW: 'se introduce un uretrotomo endoscópico hasta la uretra prostática'
#   [chunk 10/18 | chars 1306-1427]
#   RAW: 'se deja una sonda'
#   [chunk 11/18 | chars 1427-1593]
#   RAW: 'laparotomía hasta la sínfisis del pubis'
#   [chunk 12/18 | chars 1594-1773]
#   RAW: 'se diseca el espacio de Retzius\ncontrol radiológico, se palpa la cara anterior de la próstata'
#   [chunk 13/18 | chars 1774-1884]
#   RAW: 'pinza de anillo y siempre bajo control radiológico se consigue agarrar y extraer la bala'
#   [chunk 14/18 | chars 1885-1987]
#   RAW: ''
#   [chunk 15/18 | chars 1987-2165]
#   RAW: 'colonoscopia\nse cierra la colostomía'
#   [chunk 16/18 | chars 2166-2246]
#   RAW: ''
#   [chunk 17/18 | chars 2247-2372]
#   RAW: 'uretrografía\nse retira la sonda'
#   [chunk 18/18 | chars 2373-2569]
#   RAW: 'ultrasonido'
# [9/250] es-S0004-06142007000900010-1.txt | 63.17s | 18 chunks | 19 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: 'apendicectomía'
#   [chunk 2/11 | chars 208-294]
#   RAW: 'estudio ecográfico'
#   [chunk 3/11 | chars 294-543]
#   RAW: 'TAC'
#   [chunk 4/11 | chars 544-651]
#   RAW: 'nefrectomía radical derecha mediante laparoscopia'
#   [chunk 5/11 | chars 651-941]
#   RAW: 'estudio macroscópico'
#   [chunk 6/11 | chars 941-1178]
#   RAW: 'estudio microscópico'
#   [chunk 7/11 | chars 1179-1345]
#   RAW: 'estudio inmunohistoquímico'
#   [chunk 8/11 | chars 1346-1354]
#   RAW: ''
#   [chunk 9/11 | chars 1355-1362]
#   RAW: ''
#   [chunk 10/11 | chars 1362-1507]
#   RAW: ''
#   [chunk 11/11 | chars 1507-1637]
#   RAW: 'intervención\nintervención'
# [10/250] es-S0004-06142007000900012-1.txt | 28.14s | 11 chunks | 9 menciones
#   [chunk 1/14 | chars 0-196]
#   RAW: ''
#   [chunk 2/14 | chars 197-304]
#   RAW: ''
#   [chunk 3/14 | chars 305-427]
#   RAW: 'exploración'
#   [chunk 4/14 | chars 428-455]
#   RAW: ''
#   [chunk 5/14 | chars 455-566]
#   RAW: 'ecografía'
#   [chunk 6/14 | chars 567-788]
#   RAW: 'Rx de tórax'
#   [chunk 7/14 | chars 788-868]
#   RAW: 'analítica'
#   [chunk 8/14 | chars 869-1072]
#   RAW: 'Marcadores tumorales\norquiectomía inguinal\nraquianestesia a nivel L3-L4\nse coloca prótesis testicular'
#   [chunk 9/14 | chars 1072-1282]
#   RAW: 'resultado anatomopatológico'
#   [chunk 10/14 | chars 1283-1317]
#   RAW: ''
#   [chunk 11/14 | chars 1318-1350]
#   RAW: ''
#   [chunk 12/14 | chars 1351-1409]
#   RAW: ''
#   [chunk 13/14 | chars 1409-1730]
#   RAW: 'exploración física\npruebas por imágenes'
#   [chunk 14/14 | chars 1731-1827]
#   RAW: 'orquiectomía\nespermiogramas'
# [11/250] es-S0004-06142008000300011-1.txt | 36.16s | 14 chunks | 13 menciones
#   [chunk 1/40 | chars 0-198]
#   RAW: ''
#   [chunk 2/40 | chars 199-241]
#   RAW: ''
#   [chunk 3/40 | chars 242-284]
#   RAW: ''
#   [chunk 4/40 | chars 285-307]
#   RAW: ''
#   [chunk 5/40 | chars 307-427]
#   RAW: 'exploración física'
#   [chunk 6/40 | chars 428-448]
#   RAW: ''
#   [chunk 7/40 | chars 449-479]
#   RAW: ''
#   [chunk 8/40 | chars 480-522]
#   RAW: 'Auscultación cardiopulmonar'
#   [chunk 9/40 | chars 523-684]
#   RAW: 'palpación'
#   [chunk 10/40 | chars 685-721]
#   RAW: ''
#   [chunk 11/40 | chars 722-755]
#   RAW: ''
#   [chunk 12/40 | chars 756-802]
#   RAW: ''
#   [chunk 13/40 | chars 802-902]
#   RAW: 'bioquímica'
#   [chunk 14/40 | chars 903-1013]
#   RAW: 'Hemograma'
#   [chunk 15/40 | chars 1014-1069]
#   RAW: 'Hemostasia'
#   [chunk 16/40 | chars 1069-1248]
#   RAW: 'TC'
#   [chunk 17/40 | chars 1249-1277]
#   RAW: ''
#   [chunk 18/40 | chars 1278-1316]
#   RAW: ''
#   [chunk 19/40 | chars 1317-1366]
#   RAW: ''
#   [chunk 20/40 | chars 1366-1538]
#   RAW: 'TC\nECO abdómino-pélvica'
#   [chunk 21/40 | chars 1539-1553]
#   RAW: ''
#   [chunk 22/40 | chars 1554-1637]
#   RAW: 'ecográficos'
#   [chunk 23/40 | chars 1638-1758]
#   RAW: 'TC'
#   [chunk 24/40 | chars 1758-1830]
#   RAW: ''
#   [chunk 25/40 | chars 1831-2037]
#   RAW: 'TC'
#   [chunk 26/40 | chars 2038-2224]
#   RAW: ''
#   [chunk 27/40 | chars 2225-2465]
#   RAW: ''
#   [chunk 28/40 | chars 2465-2711]
#   RAW: 'paracentesis bajo control ecográfico'
#   [chunk 29/40 | chars 2712-2787]
#   RAW: 'analítico de trasudado'
#   [chunk 30/40 | chars 2788-2952]
#   RAW: 'ecografía transesofágica'
#   [chunk 31/40 | chars 2952-3043]
#   RAW: ''
#   [chunk 32/40 | chars 3044-3218]
#   RAW: 'intervención quirúrgica'
#   [chunk 33/40 | chars 3218-3242]
#   RAW: 'INTERVENCIÓN QUIRÚRGICA'
#   [chunk 34/40 | chars 3243-3370]
#   RAW: ''
#   [chunk 35/40 | chars 3371-3604]
#   RAW: 'incisión tipo Chevron y acceso a retroperitoneo\nliberación ascendente del paquete intestinal\nligadura de vena mesentérica inferior'
#   [chunk 36/40 | chars 3605-3732]
#   RAW: 'movilización hepática se logra seccionando los ligamentos redondo, coronario, triangulares derecho e izquierdo y falciforme'
#   [chunk 37/40 | chars 3733-4113]
#   RAW: 'se libera el riñón izquierdo y su hilio\nliberación de la vena cava\ncontrol de vena renal derecha\nvena renal derecha (VRD) y sección del resto de ramas'
#   [chunk 38/40 | chars 4114-4201]
#   RAW: 'Se amplía el hiato diafragmático\nse exprime el trombo hasta nivel infradiafragmático'
#   [chunk 39/40 | chars 4202-4394]
#   RAW: 'clampaje de pedículo hepático (maniobra de Pringle), de VCI proximal y distal y VRD\ncavotomía\napertura VRI\nextracción completa del trombo\nnefrectomía izquierda'
#   [chunk 40/40 | chars 4394-4498]
#   RAW: 'ANATOMÍA PATOLÓGICA'
# [12/250] es-S0004-06142008000300012-1.txt | 124.99s | 40 chunks | 33 menciones
#   [chunk 1/26 | chars 0-113]
#   RAW: ''
#   [chunk 2/26 | chars 114-171]
#   RAW: ''
#   [chunk 3/26 | chars 171-292]
#   RAW: 'radiografía\necografía'
#   [chunk 4/26 | chars 293-476]
#   RAW: 'TAC'
#   [chunk 5/26 | chars 477-512]
#   RAW: 'Serología de hidatidosis'
#   [chunk 6/26 | chars 513-549]
#   RAW: 'Hemograma'
#   [chunk 7/26 | chars 549-618]
#   RAW: ''
#   [chunk 8/26 | chars 619-664]
#   RAW: ''
#   [chunk 9/26 | chars 665-728]
#   RAW: 'drenaje percutáneo\nesclerosis del quiste'
#   [chunk 10/26 | chars 728-860]
#   RAW: ''
#   [chunk 11/26 | chars 861-919]
#   RAW: 'tratamiento antibiótico'
#   [chunk 12/26 | chars 919-1037]
#   RAW: 'drenaje percutáneo'
#   [chunk 13/26 | chars 1038-1059]
#   RAW: ''
#   [chunk 14/26 | chars 1060-1089]
#   RAW: ''
#   [chunk 15/26 | chars 1090-1191]
#   RAW: 'TAC con cortes tardíos'
#   [chunk 16/26 | chars 1192-1235]
#   RAW: ''
#   [chunk 17/26 | chars 1235-1301]
#   RAW: ''
#   [chunk 18/26 | chars 1302-1344]
#   RAW: ''
#   [chunk 19/26 | chars 1345-1501]
#   RAW: ''
#   [chunk 20/26 | chars 1502-1594]
#   RAW: 'litiasis mediante litotricia extracorpórea'
#   [chunk 21/26 | chars 1595-1641]
#   RAW: ''
#   [chunk 22/26 | chars 1641-1829]
#   RAW: 'TAC'
#   [chunk 23/26 | chars 1830-1887]
#   RAW: ''
#   [chunk 24/26 | chars 1888-1972]
#   RAW: 'Ecografías\nUIV\nTAC'
#   [chunk 25/26 | chars 1973-2034]
#   RAW: ''
#   [chunk 26/26 | chars 2035-2072]
#   RAW: ''
# [13/250] es-S0004-06142008000300013-1.txt | 51.93s | 26 chunks | 15 menciones
#   [chunk 1/6 | chars 0-244]
#   RAW: 'prostatectomía radical\nlinfadenectomía obturatriz\nresección'
#   [chunk 2/6 | chars 245-479]
#   RAW: 'cirugía prostática\nmarcadores de tumor testicular\necografía\nestudio doppler'
#   [chunk 3/6 | chars 480-554]
#   RAW: 'TAC abdominal'
#   [chunk 4/6 | chars 555-668]
#   RAW: 'TAC\norquiectomía'
#   [chunk 5/6 | chars 668-915]
#   RAW: 'orquiectomía inguinal\nquimioterapia citorreductiva según esquema R-CHOP\nR-CHOP'
#   [chunk 6/6 | chars 916-1121]
#   RAW: 'esquema IFOVM / DHAP'
# [14/250] es-S0004-06142008000400011-2.txt | 30.96s | 6 chunks | 14 menciones
#   [chunk 1/11 | chars 0-86]
#   RAW: ''
#   [chunk 2/11 | chars 87-171]
#   RAW: ''
#   [chunk 3/11 | chars 172-219]
#   RAW: ''
#   [chunk 4/11 | chars 220-394]
#   RAW: 'ecografía vaginal'
#   [chunk 5/11 | chars 395-685]
#   RAW: 'estudio de estadificación\nTC abdómino-pélvico'
#   [chunk 6/11 | chars 686-857]
#   RAW: ''
#   [chunk 7/11 | chars 858-965]
#   RAW: ''
#   [chunk 8/11 | chars 966-1047]
#   RAW: ''
#   [chunk 9/11 | chars 1047-1258]
#   RAW: 'histerectomía total\ndoble anexectomía\nnefrectomía radical derecha'
#   [chunk 10/11 | chars 1259-1392]
#   RAW: 'estudio histológico intraoperatorio de la estructura ovárica'
#   [chunk 11/11 | chars 1393-1556]
#   RAW: 'diagnóstico histológico renal'
# [15/250] es-S0004-06142008000400013-1.txt | 29.60s | 11 chunks | 8 menciones
#   [chunk 1/10 | chars 0-401]
#   RAW: 'gastrectomía\nprostatectomía radical\nbloqueo androgénico'
#   [chunk 2/10 | chars 402-554]
#   RAW: ''
#   [chunk 3/10 | chars 555-713]
#   RAW: ''
#   [chunk 4/10 | chars 713-944]
#   RAW: 'exploración'
#   [chunk 5/10 | chars 945-1271]
#   RAW: 'se palpaban linfadenectomías\nexploración física\nbiopsia\nintervención'
#   [chunk 6/10 | chars 1271-1522]
#   RAW: 'análisis anatomopatológico intraoperatorio'
#   [chunk 7/10 | chars 1522-1741]
#   RAW: 'resección con una penectomía subtotal\nlinfadenectomía inguinal superficial bilateral'
#   [chunk 8/10 | chars 1742-1819]
#   RAW: 'TAC tóracoabdominal'
#   [chunk 9/10 | chars 1820-1925]
#   RAW: 'estudio anatomopatológico\npieza penectomía'
#   [chunk 10/10 | chars 1926-2018]
#   RAW: 'análisis inmunohistoquímico con S-100 y HMB 45'
# [16/250] es-S0004-06142008000400016-1.txt | 44.72s | 10 chunks | 15 menciones
#   [chunk 1/8 | chars 0-422]
#   RAW: 'histerectomía abdominal con doble anexectomía\nantiinflamatorios\necografía abdominal'
#   [chunk 2/8 | chars 423-632]
#   RAW: 'exploración\npalpación profunda de fosa lumbar derecha\npercusión y palpación de fosa lumbar izquierda'
#   [chunk 3/8 | chars 632-854]
#   RAW: 'urografía intravenosa\nUIV\nTomografía computerizada\nTAC'
#   [chunk 4/8 | chars 855-1003]
#   RAW: 'TAC'
#   [chunk 5/8 | chars 1004-1275]
#   RAW: 'urinoma por ligadura o sección del uréter derecho\nestudio preoperatorio\nvía iliaca, ureterolisis\nexéresis del urinoma\nanastomosis termino-terminal del uréter\nrefrescamiento de los bordes\nliberación de ambos extremos'
#   [chunk 6/8 | chars 1276-1357]
#   RAW: 'Se deja catéter doble J tutorizando el uréter\ncirugía'
#   [chunk 7/8 | chars 1358-1444]
#   RAW: ''
#   [chunk 8/8 | chars 1445-1560]
#   RAW: 'intervención\nUIV'
# [17/250] es-S0004-06142008000500009-1.txt | 49.28s | 8 chunks | 22 menciones
#   [chunk 1/15 | chars 0-191]
#   RAW: ''
#   [chunk 2/15 | chars 191-608]
#   RAW: 'histerectomía vía vaginal\ncirugía\nECO\nTC'
#   [chunk 3/15 | chars 609-615]
#   RAW: ''
#   [chunk 4/15 | chars 616-623]
#   RAW: ''
#   [chunk 5/15 | chars 624-646]
#   RAW: ''
#   [chunk 6/15 | chars 647-660]
#   RAW: ''
#   [chunk 7/15 | chars 661-672]
#   RAW: ''
#   [chunk 8/15 | chars 673-706]
#   RAW: ''
#   [chunk 9/15 | chars 707-729]
#   RAW: ''
#   [chunk 10/15 | chars 729-1143]
#   RAW: 'Rx aparato urinario simple\necografía transvaginal'
#   [chunk 11/15 | chars 1143-1169]
#   RAW: 'Rx'
#   [chunk 12/15 | chars 1170-1426]
#   RAW: 'ecografía transvaginal\ncirugía'
#   [chunk 13/15 | chars 1426-1742]
#   RAW: 'uretrocistoscopia\nTC pélvico'
#   [chunk 14/15 | chars 1742-2058]
#   RAW: 'cirugía\nhisterectomía\nextracción de la misma mediante cistoslitectomía\ncistogasomectomía mediante apertura vesical a cielo abierto'
#   [chunk 15/15 | chars 2058-2288]
#   RAW: ''
# [18/250] es-S0004-06142008000700003-1.txt | 44.20s | 15 chunks | 14 menciones
#   [chunk 1/23 | chars 0-93]
#   RAW: ''
#   [chunk 2/23 | chars 94-187]
#   RAW: ''
#   [chunk 3/23 | chars 188-250]
#   RAW: ''
#   [chunk 4/23 | chars 250-368]
#   RAW: ''
#   [chunk 5/23 | chars 369-484]
#   RAW: 'sondaje urinario\nse colocó talla suprapúbica'
#   [chunk 6/23 | chars 485-787]
#   RAW: 'ecografía'
#   [chunk 7/23 | chars 787-1080]
#   RAW: 'ecográficos\nureterotomía\ncistoscopia\nresección transuretral'
#   [chunk 8/23 | chars 1080-1407]
#   RAW: 'resultado anatomopatológico\nanálisis inmunohistoquímico'
#   [chunk 9/23 | chars 1408-1663]
#   RAW: 'cirugía\ncistectomía parcial\ndiverticulectomía\nresultado anatomopatológico'
#   [chunk 10/23 | chars 1664-1693]
#   RAW: ''
#   [chunk 11/23 | chars 1694-1774]
#   RAW: ''
#   [chunk 12/23 | chars 1775-1808]
#   RAW: ''
#   [chunk 13/23 | chars 1809-1849]
#   RAW: ''
#   [chunk 14/23 | chars 1850-1988]
#   RAW: ''
#   [chunk 15/23 | chars 1989-2027]
#   RAW: ''
#   [chunk 16/23 | chars 2027-2256]
#   RAW: 'Inmunohistoquímica'
#   [chunk 17/23 | chars 2257-2490]
#   RAW: ''
#   [chunk 18/23 | chars 2491-2666]
#   RAW: 'estudio de extensión\nTAC toracoabdominal\ngammagrafía ósea\nRMN pélvica'
#   [chunk 19/23 | chars 2666-2753]
#   RAW: 'radioterapia locorregional\nquimioterapia complementaria'
#   [chunk 20/23 | chars 2754-2818]
#   RAW: 'radioterapia locorregional'
#   [chunk 21/23 | chars 2819-2976]
#   RAW: 'quimioterapia'
#   [chunk 22/23 | chars 2977-3172]
#   RAW: 'cistoscopias\ncitología urinaria\nTAC toraco-abdomino-pélvico'
#   [chunk 23/23 | chars 3172-3334]
#   RAW: ''
# [19/250] es-S0004-06142009000400011-1.txt | 71.00s | 23 chunks | 25 menciones
#   [chunk 1/7 | chars 0-128]
#   RAW: ''
#   [chunk 2/7 | chars 129-182]
#   RAW: ''
#   [chunk 3/7 | chars 183-346]
#   RAW: 'ecografía testicular'
#   [chunk 4/7 | chars 347-453]
#   RAW: 'orquidectomia'
#   [chunk 5/7 | chars 454-733]
#   RAW: 'estudio histopatologico'
#   [chunk 6/7 | chars 734-856]
#   RAW: ''
#   [chunk 7/7 | chars 857-952]
#   RAW: ''
# [20/250] es-S0004-06142010000100015-1.txt | 12.24s | 7 chunks | 3 menciones
#   [chunk 1/9 | chars 0-207]
#   RAW: 'ecográfico'
#   [chunk 2/9 | chars 207-402]
#   RAW: 'Ecografía'
#   [chunk 3/9 | chars 402-522]
#   RAW: 'T.C. abdomino-pélvico'
#   [chunk 4/9 | chars 523-567]
#   RAW: ''
#   [chunk 5/9 | chars 567-704]
#   RAW: ''
#   [chunk 6/9 | chars 704-869]
#   RAW: 'renograma isotópico con Tc-99m'
#   [chunk 7/9 | chars 870-929]
#   RAW: 'Gammagrafía ósea'
#   [chunk 8/9 | chars 929-1048]
#   RAW: 'intervención quirúrgica\nnefrectomía'
#   [chunk 9/9 | chars 1048-1119]
#   RAW: 'anatomopatológico'
# [21/250] es-S0210-48062003000900009-1.txt | 25.29s | 9 chunks | 8 menciones
#   [chunk 1/29 | chars 0-180]
#   RAW: ''
#   [chunk 2/29 | chars 181-260]
#   RAW: ''
#   [chunk 3/29 | chars 261-344]
#   RAW: ''
#   [chunk 4/29 | chars 345-451]
#   RAW: 'inhaladores\noxígeno crónico domiciliario'
#   [chunk 5/29 | chars 451-656]
#   RAW: 'exploración física\nauscultación pulmonar'
#   [chunk 6/29 | chars 657-885]
#   RAW: 'exploración genital en el hemiescroto derecho'
#   [chunk 7/29 | chars 886-937]
#   RAW: 'Tacto rectal'
#   [chunk 8/29 | chars 937-1043]
#   RAW: ''
#   [chunk 9/29 | chars 1044-1129]
#   RAW: 'Coagulación'
#   [chunk 10/29 | chars 1130-1231]
#   RAW: 'función renal, hepática y pancreática'
#   [chunk 11/29 | chars 1232-1313]
#   RAW: 'Radiografía de tórax\nradiografía de abdomen'
#   [chunk 12/29 | chars 1313-1386]
#   RAW: 'Ecografía renal y vesical'
#   [chunk 13/29 | chars 1387-1620]
#   RAW: 'Ecografía testicular'
#   [chunk 14/29 | chars 1620-1783]
#   RAW: 'orquiectomía radical por vía inguinal'
#   [chunk 15/29 | chars 1783-2020]
#   RAW: 'anatomía patológica\nmacroscópica'
#   [chunk 16/29 | chars 2021-2175]
#   RAW: 'Microscópicamente'
#   [chunk 17/29 | chars 2176-2416]
#   RAW: 'TAC de cuerpo completo'
#   [chunk 18/29 | chars 2416-2549]
#   RAW: ''
#   [chunk 19/29 | chars 2550-2676]
#   RAW: 'fórmula leucocitaria y linfocitaria'
#   [chunk 20/29 | chars 2676-2949]
#   RAW: 'biopsia de medula ósea'
#   [chunk 21/29 | chars 2950-3041]
#   RAW: ''
#   [chunk 22/29 | chars 3041-3176]
#   RAW: 'frotis sanguíneo'
#   [chunk 23/29 | chars 3177-3330]
#   RAW: 'test de Coombs directo'
#   [chunk 24/29 | chars 3330-3481]
#   RAW: 'fibroscopia'
#   [chunk 25/29 | chars 3482-3505]
#   RAW: 'TAC cervical'
#   [chunk 26/29 | chars 3506-3737]
#   RAW: 'ciclo de CHOP'
#   [chunk 27/29 | chars 3738-3812]
#   RAW: 'quimioterapia\nR-CHOP'
#   [chunk 28/29 | chars 3813-3891]
#   RAW: 'radioterapia genital\nquimioprofilaxis cerebral'
#   [chunk 29/29 | chars 3892-3953]
#   RAW: ''
# [22/250] es-S0210-48062004000200011-1.txt | 80.07s | 29 chunks | 28 menciones
#   [chunk 1/12 | chars 0-224]
#   RAW: ''
#   [chunk 2/12 | chars 224-442]
#   RAW: 'tacto rectal\ndeterminación de PSA\necografía abdominal'
#   [chunk 3/12 | chars 442-700]
#   RAW: 'intervención sobre el ojo izquierdo\nureterolitectomía del tercio superior del uréter\nlumbotomía'
#   [chunk 4/12 | chars 700-997]
#   RAW: 'estudio ecográfico'
#   [chunk 5/12 | chars 997-1381]
#   RAW: 'TAC'
#   [chunk 6/12 | chars 1381-1562]
#   RAW: 'estudio de extensión\nexéresis de la masa\nnefrectomía'
#   [chunk 7/12 | chars 1562-1624]
#   RAW: 'lumbotomía izquierda'
#   [chunk 8/12 | chars 1624-1775]
#   RAW: 'disección renal'
#   [chunk 9/12 | chars 1776-1889]
#   RAW: 'biopsia intraoperatoria'
#   [chunk 10/12 | chars 1889-2050]
#   RAW: 'exéresis de la totalidad de la tumoración'
#   [chunk 11/12 | chars 2050-2234]
#   RAW: 'exéresis de la masa'
#   [chunk 12/12 | chars 2234-2418]
#   RAW: 'análisis anatomopatológico de la pared de la tumoración'
# [23/250] es-S0210-48062004000500009-1.txt | 44.78s | 12 chunks | 17 menciones
#   [chunk 1/11 | chars 0-130]
#   RAW: 'ecográfico'
#   [chunk 2/11 | chars 130-212]
#   RAW: 'hidrocelectomía derecha'
#   [chunk 3/11 | chars 213-358]
#   RAW: 'anamnesis'
#   [chunk 4/11 | chars 359-424]
#   RAW: 'exploración física'
#   [chunk 5/11 | chars 424-618]
#   RAW: 'ecografía\nEco-doppler'
#   [chunk 6/11 | chars 619-824]
#   RAW: 'TC abdomino-pélvica'
#   [chunk 7/11 | chars 825-1174]
#   RAW: 'RNM abdominal\ngadolinio'
#   [chunk 8/11 | chars 1174-1373]
#   RAW: 'TC\necográficos\nexploración quirúrgica\nincisión en el flanco\ntumorectomía'
#   [chunk 9/11 | chars 1373-1584]
#   RAW: 'estudio histológico\nresección'
#   [chunk 10/11 | chars 1584-1768]
#   RAW: 'TC\nintervención'
#   [chunk 11/11 | chars 1769-1877]
#   RAW: 'ecografía\nTC'
# [24/250] es-S0210-48062004000800009-1.txt | 36.02s | 11 chunks | 20 menciones
#   [chunk 1/18 | chars 0-125]
#   RAW: ''
#   [chunk 2/18 | chars 126-342]
#   RAW: ''
#   [chunk 3/18 | chars 342-444]
#   RAW: 'exploración física'
#   [chunk 4/18 | chars 445-481]
#   RAW: ''
#   [chunk 5/18 | chars 481-622]
#   RAW: 'estudio ecográfico'
#   [chunk 6/18 | chars 623-681]
#   RAW: ''
#   [chunk 7/18 | chars 682-723]
#   RAW: 'estudio cistoscópico'
#   [chunk 8/18 | chars 723-815]
#   RAW: 'TAC abdominopélvico\nRx torax\nbioquímica hemática\nhemograma'
#   [chunk 9/18 | chars 815-1067]
#   RAW: 'TC'
#   [chunk 10/18 | chars 1068-1159]
#   RAW: ''
#   [chunk 11/18 | chars 1159-1259]
#   RAW: ''
#   [chunk 12/18 | chars 1259-1377]
#   RAW: 'cirugía radical\nembolización selectiva'
#   [chunk 13/18 | chars 1377-1611]
#   RAW: 'punción en la arteria femoral común derecha\narteriografía de aorta abdominal\nse cateteriza selectivamente la arteria renal derecha con un catéter angiográfico visceral Cobra 2'
#   [chunk 14/18 | chars 1612-1842]
#   RAW: 'se emboliza la arteria que irriga al tumor con partículas de alcohol de polivinilo'
#   [chunk 15/18 | chars 1842-1978]
#   RAW: ''
#   [chunk 16/18 | chars 1978-2122]
#   RAW: 'postembolización\nTC cerebral'
#   [chunk 17/18 | chars 2123-2327]
#   RAW: ''
#   [chunk 18/18 | chars 2328-2451]
#   RAW: 'IECAS\ncalcio antagonistas'
# [25/250] es-S0210-48062005000300014-1.txt | 55.31s | 18 chunks | 18 menciones
#   [chunk 1/23 | chars 0-303]
#   RAW: 'triple by-pass aorto-coronario'
#   [chunk 2/23 | chars 304-472]
#   RAW: ''
#   [chunk 3/23 | chars 473-537]
#   RAW: ''
#   [chunk 4/23 | chars 538-662]
#   RAW: 'exploración física\ntoracotomía'
#   [chunk 5/23 | chars 663-744]
#   RAW: 'tacto rectal\nse palpaba próstata'
#   [chunk 6/23 | chars 744-859]
#   RAW: 'analítica de sangre\nhemograma\nfunción renal'
#   [chunk 7/23 | chars 859-954]
#   RAW: 'ecografía'
#   [chunk 8/23 | chars 955-1058]
#   RAW: 'citología\ncistoscopia'
#   [chunk 9/23 | chars 1059-1337]
#   RAW: 'análisis de fragmentos tras RTU'
#   [chunk 10/23 | chars 1337-1535]
#   RAW: 'TAC'
#   [chunk 11/23 | chars 1535-1606]
#   RAW: 'cistoprostatectomía radical\nneovejiga ileal tipo Camey II'
#   [chunk 12/23 | chars 1607-1681]
#   RAW: ''
#   [chunk 13/23 | chars 1681-2063]
#   RAW: 'análisis histológico'
#   [chunk 14/23 | chars 2064-2101]
#   RAW: ''
#   [chunk 15/23 | chars 2102-2257]
#   RAW: ''
#   [chunk 16/23 | chars 2258-2433]
#   RAW: 'linfadenectomía izquierda'
#   [chunk 17/23 | chars 2433-2569]
#   RAW: 'Inmunofenotípicamente'
#   [chunk 18/23 | chars 2569-2698]
#   RAW: 'quimioterapia'
#   [chunk 19/23 | chars 2699-2883]
#   RAW: 'transfusiones sanguíneas\nfactores estimulantes de colonias (filgastrim)'
#   [chunk 20/23 | chars 2883-3084]
#   RAW: 'QMT\necografía\nTAC'
#   [chunk 21/23 | chars 3085-3184]
#   RAW: 'analgesia'
#   [chunk 22/23 | chars 3185-3362]
#   RAW: 'TAC\nintervención'
#   [chunk 23/23 | chars 3363-3520]
#   RAW: ''
# [26/250] es-S0210-48062005000400012-1.txt | 66.19s | 23 chunks | 27 menciones
#   [chunk 1/14 | chars 0-252]
#   RAW: ''
#   [chunk 2/14 | chars 253-383]
#   RAW: 'hemograma\nbioquímica\npruebas de coagulación\nradiología convencional'
#   [chunk 3/14 | chars 384-463]
#   RAW: 'hemocultivos en medios convencionales y de Ruiz Castañeda'
#   [chunk 4/14 | chars 464-603]
#   RAW: 'estudio serológico para Brucella\nRosa de Bengala\nsero-aglutinación\nantibrucela-coombs'
#   [chunk 5/14 | chars 603-699]
#   RAW: ''
#   [chunk 6/14 | chars 699-778]
#   RAW: ''
#   [chunk 7/14 | chars 779-873]
#   RAW: 'exploración la región ilíaca izquierda'
#   [chunk 8/14 | chars 874-1072]
#   RAW: 'tomografía axial computerizada\nTAC'
#   [chunk 9/14 | chars 1073-1166]
#   RAW: 'tratamiento antibiótico'
#   [chunk 10/14 | chars 1167-1288]
#   RAW: 'drenaje transcutáneo de las colecciones del psoas'
#   [chunk 11/14 | chars 1288-1512]
#   RAW: 'TAC'
#   [chunk 12/14 | chars 1513-1701]
#   RAW: 'drenaje de ambos músculos\ndiscectomía L5-S1'
#   [chunk 13/14 | chars 1702-1889]
#   RAW: 'tratamiento antibiótico'
#   [chunk 14/14 | chars 1889-2001]
#   RAW: 'cirugía'
# [27/250] es-S0210-48062005000700012-1.txt | 51.40s | 14 chunks | 19 menciones
#   [chunk 1/9 | chars 0-273]
#   RAW: 'vasectomizado'
#   [chunk 2/9 | chars 274-308]
#   RAW: ''
#   [chunk 3/9 | chars 309-436]
#   RAW: 'exploración física'
#   [chunk 4/9 | chars 437-494]
#   RAW: 'análisis generales de sangre y orina'
#   [chunk 5/9 | chars 495-675]
#   RAW: 'ecografía escrotal'
#   [chunk 6/9 | chars 676-720]
#   RAW: 'Marcadores tumorales'
#   [chunk 7/9 | chars 721-814]
#   RAW: 'orquiectomía inguinal izquierda con colocación de prótesis testicular siliconada'
#   [chunk 8/9 | chars 815-895]
#   RAW: 'TAC abdominal'
#   [chunk 9/9 | chars 896-1115]
#   RAW: 'estudio microscópico'
# [28/250] es-S0210-48062006000200018-1.txt | 26.04s | 9 chunks | 8 menciones
#   [chunk 1/20 | chars 0-213]
#   RAW: ''
#   [chunk 2/20 | chars 214-416]
#   RAW: 'se palpó incidentalmente una masa testicular'
#   [chunk 3/20 | chars 417-715]
#   RAW: 'estudio ecográfico\ndoppler'
#   [chunk 4/20 | chars 716-764]
#   RAW: ''
#   [chunk 5/20 | chars 765-1091]
#   RAW: 'resonancia nuclear magnética\nRNM'
#   [chunk 6/20 | chars 1092-1094]
#   RAW: ''
#   [chunk 7/20 | chars 1094-1121]
#   RAW: ''
#   [chunk 8/20 | chars 1122-1164]
#   RAW: ''
#   [chunk 9/20 | chars 1165-1212]
#   RAW: ''
#   [chunk 10/20 | chars 1213-1487]
#   RAW: 'examen físico'
#   [chunk 11/20 | chars 1488-1795]
#   RAW: ''
#   [chunk 12/20 | chars 1795-1944]
#   RAW: 'examen físico'
#   [chunk 13/20 | chars 1945-2128]
#   RAW: 'cirugía\nexploración y resección'
#   [chunk 14/20 | chars 2129-2822]
#   RAW: 'anestesia general\nincisión escrotal transversa\ndisección por planos hasta la albugínea'
#   [chunk 15/20 | chars 2823-3076]
#   RAW: 'sección, ligadura con hemostasia\nestudio anatomopatológico'
#   [chunk 16/20 | chars 3077-3268]
#   RAW: 'bolsillo en espacio subdartos donde se aloja el testículo sano y es fijado con material de sutura orgánico absorbible'
#   [chunk 17/20 | chars 3269-3370]
#   RAW: 'cierre por planos\nbloqueo del nervio ilioinguinal del lado izquierdo'
#   [chunk 18/20 | chars 3371-3478]
#   RAW: ''
#   [chunk 19/20 | chars 3479-3595]
#   RAW: 'patología\ncortes histológicos'
#   [chunk 20/20 | chars 3596-3633]
#   RAW: ''
# [29/250] es-S0210-48062006000400012-1.txt | 61.75s | 20 chunks | 19 menciones
#   [chunk 1/10 | chars 0-478]
#   RAW: 'tratamiento antibiótico\nsedimento patológico\nurocultivo'
#   [chunk 2/10 | chars 478-650]
#   RAW: 'exploración'
#   [chunk 3/10 | chars 651-736]
#   RAW: 'tacto rectal'
#   [chunk 4/10 | chars 736-917]
#   RAW: 'sedimento de orina'
#   [chunk 5/10 | chars 917-1100]
#   RAW: 'prueba de imagen diagnostica\necografía abdominal y transperineal'
#   [chunk 6/10 | chars 1100-1248]
#   RAW: 'sedación\ndrenaje percutáneo del absceso\ncolocación de un catéter suprapúbico'
#   [chunk 7/10 | chars 1249-1377]
#   RAW: 'punción transperineal ecodirigida\nse deja "pig-tail" de 7 French como drenaje'
#   [chunk 8/10 | chars 1377-1517]
#   RAW: 'cultivos del contenido purulento y de la orina\nantibiótico'
#   [chunk 9/10 | chars 1517-1642]
#   RAW: ''
#   [chunk 10/10 | chars 1643-1786]
#   RAW: 'ecográficamente'
# [30/250] es-S0210-48062006000700012-1.txt | 44.69s | 10 chunks | 16 menciones
#   [chunk 1/20 | chars 0-17]
#   RAW: ''
#   [chunk 2/20 | chars 18-70]
#   RAW: ''
#   [chunk 3/20 | chars 71-230]
#   RAW: 'ecografía'
#   [chunk 4/20 | chars 231-314]
#   RAW: 'RTU-biopsia'
#   [chunk 5/20 | chars 315-356]
#   RAW: 'estudio de extensión'
#   [chunk 6/20 | chars 357-401]
#   RAW: ''
#   [chunk 7/20 | chars 402-582]
#   RAW: 'cistoprostatectomía radical laparoscópica\nderivación urinaria tipo Bricker'
#   [chunk 8/20 | chars 582-628]
#   RAW: ''
#   [chunk 9/20 | chars 629-826]
#   RAW: 'cirugía'
#   [chunk 10/20 | chars 826-938]
#   RAW: 'conversión en una derivación continente'
#   [chunk 11/20 | chars 939-1003]
#   RAW: ''
#   [chunk 12/20 | chars 1004-1132]
#   RAW: 'laparotomía exploradora\ndisección pélvica'
#   [chunk 13/20 | chars 1133-1184]
#   RAW: 'neovejiga ileal con 45 cm de íleon'
#   [chunk 14/20 | chars 1185-1257]
#   RAW: ''
#   [chunk 15/20 | chars 1258-1345]
#   RAW: ''
#   [chunk 16/20 | chars 1345-1454]
#   RAW: 'cirugía'
#   [chunk 17/20 | chars 1454-1746]
#   RAW: 'cirugía\nautocateterismos'
#   [chunk 18/20 | chars 1747-1906]
#   RAW: 'asa de Bricker se liberó de la pared abdominal\nasa de Bricker se anastomosó a la chimenea de la neovejiga\nreimplante ureteral'
#   [chunk 19/20 | chars 1907-2008]
#   RAW: 'sonda vesical se retiró'
#   [chunk 20/20 | chars 2009-2080]
#   RAW: 'derivación ortotópica'
# [31/250] es-S0210-48062006000900012-2.txt | 60.83s | 20 chunks | 17 menciones
#   [chunk 1/18 | chars 0-49]
#   RAW: ''
#   [chunk 2/18 | chars 49-339]
#   RAW: ''
#   [chunk 3/18 | chars 340-457]
#   RAW: ''
#   [chunk 4/18 | chars 457-597]
#   RAW: 'Exploración física'
#   [chunk 5/18 | chars 598-888]
#   RAW: ''
#   [chunk 6/18 | chars 888-1038]
#   RAW: 'estudio de fertilidad'
#   [chunk 7/18 | chars 1038-1155]
#   RAW: 'Biometría hemática'
#   [chunk 8/18 | chars 1155-1341]
#   RAW: 'Química sanguínea\nExamen general de orina'
#   [chunk 9/18 | chars 1341-1467]
#   RAW: ''
#   [chunk 10/18 | chars 1467-1583]
#   RAW: 'Cultivos de orina y semen\nBúsqueda de Chlamydia, Micoplasma y Ureaplasma en secreción uretral'
#   [chunk 11/18 | chars 1583-1839]
#   RAW: 'Análisis de semen'
#   [chunk 12/18 | chars 1839-1901]
#   RAW: ''
#   [chunk 13/18 | chars 1901-2025]
#   RAW: 'Ultrasonido escrotal'
#   [chunk 14/18 | chars 2025-2043]
#   RAW: ''
#   [chunk 15/18 | chars 2043-2197]
#   RAW: 'Microdeleciones cromosoma Y mediante técnica de reacción en cadena polimerasa múltiplex de STS cromosoma Y'
#   [chunk 16/18 | chars 2197-2234]
#   RAW: ''
#   [chunk 17/18 | chars 2234-2316]
#   RAW: ''
#   [chunk 18/18 | chars 2316-2421]
#   RAW: ''
# [32/250] es-S0210-48062007000300014-1.txt | 47.16s | 18 chunks | 10 menciones
#   [chunk 1/8 | chars 0-288]
#   RAW: 'vasectomía'
#   [chunk 2/8 | chars 289-332]
#   RAW: ''
#   [chunk 3/8 | chars 333-481]
#   RAW: 'exploración'
#   [chunk 4/8 | chars 481-635]
#   RAW: 'ecografía de partes blandas'
#   [chunk 5/8 | chars 635-730]
#   RAW: 'Resonancia Magnética Nuclear'
#   [chunk 6/8 | chars 731-846]
#   RAW: ''
#   [chunk 7/8 | chars 846-940]
#   RAW: 'estudio bacteriológico\npunción con cultivo'
#   [chunk 8/8 | chars 940-1080]
#   RAW: 'tratamiento antiagregante vía oral'
# [33/250] es-S0210-48062007000700014-1.txt | 19.83s | 8 chunks | 7 menciones
#   [chunk 1/27 | chars 0-214]
#   RAW: 'estudio ecográfico'
#   [chunk 2/27 | chars 214-285]
#   RAW: ''
#   [chunk 3/27 | chars 286-319]
#   RAW: 'Herniorrafia inguinal bilateral'
#   [chunk 4/27 | chars 319-409]
#   RAW: ''
#   [chunk 5/27 | chars 409-514]
#   RAW: 'exploración física'
#   [chunk 6/27 | chars 514-601]
#   RAW: ''
#   [chunk 7/27 | chars 602-759]
#   RAW: 'Ecografía testicular'
#   [chunk 8/27 | chars 760-783]
#   RAW: ''
#   [chunk 9/27 | chars 784-906]
#   RAW: 'Tomografía axial computerizada\nTAC'
#   [chunk 10/27 | chars 907-1226]
#   RAW: 'orquiectomia inguinal derecha\nAnatomía Patológica'
#   [chunk 11/27 | chars 1227-1464]
#   RAW: 'quimioterapia según el esquema BEP\nesquema BEP (bleom<icina, etopósido y cisplatino)'
#   [chunk 12/27 | chars 1464-1604]
#   RAW: ''
#   [chunk 13/27 | chars 1604-1732]
#   RAW: 'exploración física'
#   [chunk 14/27 | chars 1732-1912]
#   RAW: ''
#   [chunk 15/27 | chars 1913-1961]
#   RAW: 'Radiografía de tórax'
#   [chunk 16/27 | chars 1962-2136]
#   RAW: 'Ecografía testicular\nflujo doppler color'
#   [chunk 17/27 | chars 2137-2192]
#   RAW: ''
#   [chunk 18/27 | chars 2193-2282]
#   RAW: 'Tomografía Axial Computerizada toraco-abdomino-pélvico'
#   [chunk 19/27 | chars 2283-2325]
#   RAW: ''
#   [chunk 20/27 | chars 2326-2366]
#   RAW: ''
#   [chunk 21/27 | chars 2366-2652]
#   RAW: 'orquiectomía radical izquierda vía inguinal\nAnatomía Patológica'
#   [chunk 22/27 | chars 2652-2696]
#   RAW: ''
#   [chunk 23/27 | chars 2696-2782]
#   RAW: 'tratamiento adyuvante'
#   [chunk 24/27 | chars 2783-2915]
#   RAW: ''
#   [chunk 25/27 | chars 2915-3431]
#   RAW: 'Tomografía Axial Computerizada\nanalíticas sanguíneas\nhemograma\nbioquímica\nhemostasia'
#   [chunk 26/27 | chars 3431-3556]
#   RAW: 'quimioterapia'
#   [chunk 27/27 | chars 3556-3703]
#   RAW: ''
# [34/250] es-S0210-48062007001000004-1.txt | 76.42s | 27 chunks | 24 menciones
#   [chunk 1/17 | chars 0-131]
#   RAW: ''
#   [chunk 2/17 | chars 132-311]
#   RAW: ''
#   [chunk 3/17 | chars 312-437]
#   RAW: 'exploración física'
#   [chunk 4/17 | chars 438-637]
#   RAW: 'analítica de sangre\nanálisis del sedimento urinario\ntira reactiva'
#   [chunk 5/17 | chars 638-741]
#   RAW: 'ecografía abdominal'
#   [chunk 6/17 | chars 742-1027]
#   RAW: 'TC abdómino-pélvica'
#   [chunk 7/17 | chars 1027-1216]
#   RAW: 'drenaje percutáneo con toma de muestras para microbiología\nantibioterapia intravenosa de amplio espectro'
#   [chunk 8/17 | chars 1217-1379]
#   RAW: 'cultivos seriados'
#   [chunk 9/17 | chars 1380-1406]
#   RAW: ''
#   [chunk 10/17 | chars 1406-1712]
#   RAW: 'TC\nenema opaco\ncolonoscopia\ncistoscopia'
#   [chunk 11/17 | chars 1712-1790]
#   RAW: 'laparotomía exploradora'
#   [chunk 12/17 | chars 1791-1922]
#   RAW: 'laparotomía media'
#   [chunk 13/17 | chars 1922-2130]
#   RAW: 'exéresis\nestudio anátomo-patológico intraoperatorio'
#   [chunk 14/17 | chars 2131-2310]
#   RAW: 'linfadenectomía ilio-ceco-apendicular\ndiagnóstico intraoperatorio por congelación\nresección segmentaria apéndico-cecal'
#   [chunk 15/17 | chars 2311-2395]
#   RAW: 'diagnóstico patológico'
#   [chunk 16/17 | chars 2395-2529]
#   RAW: 'intervención'
#   [chunk 17/17 | chars 2530-2687]
#   RAW: 'cirugía'
# [35/250] es-S0210-48062009000200019-1.txt | 61.23s | 17 chunks | 23 menciones
#   [chunk 1/14 | chars 0-113]
#   RAW: 'Adenomectomia prostática'
#   [chunk 2/14 | chars 114-137]
#   RAW: ''
#   [chunk 3/14 | chars 138-167]
#   RAW: ''
#   [chunk 4/14 | chars 168-211]
#   RAW: ''
#   [chunk 5/14 | chars 211-266]
#   RAW: 'LEOCH'
#   [chunk 6/14 | chars 266-347]
#   RAW: 'Leoch'
#   [chunk 7/14 | chars 348-393]
#   RAW: ''
#   [chunk 8/14 | chars 393-510]
#   RAW: 'analgesia IV'
#   [chunk 9/14 | chars 510-682]
#   RAW: 'Leoch\neco\nTac'
#   [chunk 10/14 | chars 683-719]
#   RAW: ''
#   [chunk 11/14 | chars 719-1044]
#   RAW: 'Leoch\nadministración de 3 concentrados de hematíes\ndrenaje del hematoma mediante incisión lumbar'
#   [chunk 12/14 | chars 1045-1174]
#   RAW: 'lumbotomías'
#   [chunk 13/14 | chars 1175-1216]
#   RAW: 'intervención'
#   [chunk 14/14 | chars 1217-1286]
#   RAW: 'ecografía renal\nUIV\nfunción renal'
# [36/250] es-S0210-48062009000300013-1.txt | 35.21s | 14 chunks | 15 menciones
#   [chunk 1/5 | chars 0-213]
#   RAW: ''
#   [chunk 2/5 | chars 214-421]
#   RAW: 'soporte ventilatorio\nestudios de imagen de la pelvis'
#   [chunk 3/5 | chars 422-511]
#   RAW: 'reconstrucción de las imágenes de TAC\nTAC'
#   [chunk 4/5 | chars 512-670]
#   RAW: 'cistoscopia'
#   [chunk 5/5 | chars 671-809]
#   RAW: 'acceso suprapúbico se reparó la vejiga\nextirpó el fragmento óseo'
# [37/250] es-S0210-48062009000400015-2.txt | 21.35s | 5 chunks | 7 menciones
#   [chunk 1/9 | chars 0-318]
#   RAW: 'herniorrafia inguinal izquierda y umbilical'
#   [chunk 2/9 | chars 319-787]
#   RAW: 'TAC toracoabdominopélvico\nanalítica de PSA\necografía transrectal\nbiopsias prostáticas'
#   [chunk 3/9 | chars 788-831]
#   RAW: ''
#   [chunk 4/9 | chars 831-966]
#   RAW: 'tacto rectal'
#   [chunk 5/9 | chars 967-990]
#   RAW: ''
#   [chunk 6/9 | chars 991-1143]
#   RAW: 'ecografía transrectal'
#   [chunk 7/9 | chars 1144-1197]
#   RAW: ''
#   [chunk 8/9 | chars 1198-1243]
#   RAW: 'biopsias prostáticas por sextantes'
#   [chunk 9/9 | chars 1243-1439]
#   RAW: 'anatomopatológico'
# [38/250] es-S0210-48062009000400020-1.txt | 27.89s | 9 chunks | 9 menciones
#   [chunk 1/24 | chars 0-767]
#   RAW: 'by-pass aorto-coronario\ntratamiento antiagregante\ntriple terapia\ntest del aliento\ninhibidores de la bomba de protones\na-bloqueantes\nCPAP\namigdalectomía'
#   [chunk 2/24 | chars 768-890]
#   RAW: 'ecografía abdominal'
#   [chunk 3/24 | chars 891-967]
#   RAW: ''
#   [chunk 4/24 | chars 967-1266]
#   RAW: 'resección transuretral\nRTU'
#   [chunk 5/24 | chars 1266-1280]
#   RAW: ''
#   [chunk 6/24 | chars 1281-1465]
#   RAW: 'colecistectomía laparoscópica\nbiopsia ganglionar'
#   [chunk 7/24 | chars 1465-1546]
#   RAW: 'R.T.U. de próstata'
#   [chunk 8/24 | chars 1547-1722]
#   RAW: 'estudio histológico\nRTU'
#   [chunk 9/24 | chars 1723-1842]
#   RAW: ''
#   [chunk 10/24 | chars 1843-2069]
#   RAW: ''
#   [chunk 11/24 | chars 2070-2134]
#   RAW: ''
#   [chunk 12/24 | chars 2135-2205]
#   RAW: ''
#   [chunk 13/24 | chars 2206-2261]
#   RAW: 'técnicas de inmunohisoquímica'
#   [chunk 14/24 | chars 2262-2565]
#   RAW: 'estudio molecular mediante PCR'
#   [chunk 15/24 | chars 2565-2722]
#   RAW: 'diagnóstico anatomopatológico'
#   [chunk 16/24 | chars 2723-2817]
#   RAW: 'biopsia de médula ósea'
#   [chunk 17/24 | chars 2818-2845]
#   RAW: 'TAC tóraco-abdominal\nPET'
#   [chunk 18/24 | chars 2846-3182]
#   RAW: 'TAC\ncolecistectomía\nPET'
#   [chunk 19/24 | chars 3183-3231]
#   RAW: 'cariotipo'
#   [chunk 20/24 | chars 3231-3653]
#   RAW: 'tratamiento con poliquimioterápia de primera linea con FMD\nFMD 6 ciclos/ 4 semanas (Fludarabin, Mitoxantrone, Dexametasona) asociado con anticuerpos monoclonales anti-CD20\nanticuerpos monoclonales anti-CD20'
#   [chunk 21/24 | chars 3654-3671]
#   RAW: ''
#   [chunk 22/24 | chars 3671-3774]
#   RAW: ''
#   [chunk 23/24 | chars 3775-3888]
#   RAW: 'estudios de imagen\nTAC\nPET'
#   [chunk 24/24 | chars 3889-3979]
#   RAW: ''
# [39/250] es-S0210-48062009000600012-1.txt | 90.18s | 24 chunks | 32 menciones
#   [chunk 1/6 | chars 0-265]
#   RAW: 'ventilación mecánica\nhemocultivo'
#   [chunk 2/6 | chars 266-449]
#   RAW: 'DPA'
#   [chunk 3/6 | chars 450-911]
#   RAW: 'ultrafiltrado'
#   [chunk 4/6 | chars 912-1026]
#   RAW: 'ultrafiltración'
#   [chunk 5/6 | chars 1027-1745]
#   RAW: ''
#   [chunk 6/6 | chars 1746-1876]
#   RAW: 'dializado\nse retiró el catéter peritoneal'
# [40/250] es-S0210-56912008000200007-1.txt | 16.62s | 6 chunks | 7 menciones
#   [chunk 1/9 | chars 0-65]
#   RAW: ''
#   [chunk 2/9 | chars 66-242]
#   RAW: 'TACHT'
#   [chunk 3/9 | chars 243-356]
#   RAW: ''
#   [chunk 4/9 | chars 357-427]
#   RAW: ''
#   [chunk 5/9 | chars 427-609]
#   RAW: 'endoprótesis en la aorta torácica descendente por vía femoral izquierda\noclusión parcial de la arteria subclavia izquierda'
#   [chunk 6/9 | chars 610-651]
#   RAW: ''
#   [chunk 7/9 | chars 652-718]
#   RAW: 'TACHT'
#   [chunk 8/9 | chars 718-841]
#   RAW: ''
#   [chunk 9/9 | chars 842-907]
#   RAW: 'TACHT'
# [41/250] es-S0210-56912008000400007-3.txt | 21.72s | 9 chunks | 5 menciones
#   [chunk 1/14 | chars 0-79]
#   RAW: ''
#   [chunk 2/14 | chars 80-119]
#   RAW: 'evacuación neuroquirúrgica'
#   [chunk 3/14 | chars 120-213]
#   RAW: 'sedoanalgesia\nrelajación\nosmóticos'
#   [chunk 4/14 | chars 214-305]
#   RAW: ''
#   [chunk 5/14 | chars 306-370]
#   RAW: 'DP'
#   [chunk 6/14 | chars 371-440]
#   RAW: ''
#   [chunk 7/14 | chars 441-478]
#   RAW: ''
#   [chunk 8/14 | chars 479-574]
#   RAW: ''
#   [chunk 9/14 | chars 575-829]
#   RAW: 'TC\nmonitorización de la PIC\nse coloca un nuevo sensor'
#   [chunk 10/14 | chars 830-887]
#   RAW: ''
#   [chunk 11/14 | chars 888-961]
#   RAW: 'DP'
#   [chunk 12/14 | chars 962-1019]
#   RAW: 'DP\nDS'
#   [chunk 13/14 | chars 1020-1067]
#   RAW: ''
#   [chunk 14/14 | chars 1068-1180]
#   RAW: ''
# [42/250] es-S0210-56912009000800006-3.txt | 28.24s | 14 chunks | 11 menciones
#   [chunk 1/26 | chars 0-20]
#   RAW: ''
#   [chunk 2/26 | chars 21-71]
#   RAW: ''
#   [chunk 3/26 | chars 71-163]
#   RAW: ''
#   [chunk 4/26 | chars 164-241]
#   RAW: ''
#   [chunk 5/26 | chars 242-317]
#   RAW: ''
#   [chunk 6/26 | chars 317-464]
#   RAW: 'examen físico\nexploración del tórax'
#   [chunk 7/26 | chars 465-519]
#   RAW: ''
#   [chunk 8/26 | chars 520-707]
#   RAW: 'gasometría arterial\noxígeno suplementario'
#   [chunk 9/26 | chars 708-742]
#   RAW: ''
#   [chunk 10/26 | chars 743-891]
#   RAW: ''
#   [chunk 11/26 | chars 891-1111]
#   RAW: 'Rx de tórax'
#   [chunk 12/26 | chars 1112-1187]
#   RAW: 'análisis para VIH por ELISA\nWestern Blot'
#   [chunk 13/26 | chars 1187-1271]
#   RAW: 'broncoscopia\nbiopsia transbronquial\nlavado broncoalveolar\nLBA'
#   [chunk 14/26 | chars 1272-1325]
#   RAW: 'estudio histopatológico'
#   [chunk 15/26 | chars 1326-1426]
#   RAW: ''
#   [chunk 16/26 | chars 1426-1614]
#   RAW: 'ventilación mecánica invasiva'
#   [chunk 17/26 | chars 1615-1768]
#   RAW: ''
#   [chunk 18/26 | chars 1769-1997]
#   RAW: 'extubar'
#   [chunk 19/26 | chars 1997-2063]
#   RAW: ''
#   [chunk 20/26 | chars 2064-2166]
#   RAW: 'ventilación mecánica invasiva'
#   [chunk 21/26 | chars 2167-2208]
#   RAW: 'Swan-Ganz'
#   [chunk 22/26 | chars 2209-2366]
#   RAW: 'radiografía de tórax\nLBA\nestudio de patología'
#   [chunk 23/26 | chars 2367-2480]
#   RAW: 'rt-PCR'
#   [chunk 24/26 | chars 2480-2600]
#   RAW: 'ventilación mecánica invasiva'
#   [chunk 25/26 | chars 2601-2640]
#   RAW: ''
#   [chunk 26/26 | chars 2641-2729]
#   RAW: ''
# [43/250] es-S0210-56912011000200009-1.txt | 62.53s | 26 chunks | 21 menciones
#   [chunk 1/35 | chars 0-205]
#   RAW: ''
#   [chunk 2/35 | chars 206-327]
#   RAW: ''
#   [chunk 3/35 | chars 327-709]
#   RAW: ''
#   [chunk 4/35 | chars 709-772]
#   RAW: ''
#   [chunk 5/35 | chars 773-809]
#   RAW: ''
#   [chunk 6/35 | chars 810-870]
#   RAW: 'cirugía vascular'
#   [chunk 7/35 | chars 871-907]
#   RAW: ''
#   [chunk 8/35 | chars 908-950]
#   RAW: 'tratamiento sustitutivo'
#   [chunk 9/35 | chars 951-1126]
#   RAW: 'benzodiacepinas\nantidepresivos'
#   [chunk 10/35 | chars 1127-1163]
#   RAW: ''
#   [chunk 11/35 | chars 1164-1346]
#   RAW: ''
#   [chunk 12/35 | chars 1347-1725]
#   RAW: ''
#   [chunk 13/35 | chars 1726-1889]
#   RAW: 'restricción hídrica\ndiurético'
#   [chunk 14/35 | chars 1890-2023]
# ...
#   RAW: 'extracción de un canino superior izquierdo incluido'
#   [chunk 2/19 | chars 290-392]
#   RAW: ''
#   [chunk 3/19 | chars 393-647]
#   RAW: 'radiografía panorámica\nradiografía lateral'
#   [chunk 4/19 | chars 648-804]
#   RAW: 'exploración intraoral'
#   [chunk 5/19 | chars 805-899]
#   RAW: ''
#   [chunk 6/19 | chars 900-1299]
#   RAW: 'tratamiento ortodóncico\nreposición protésica en la región canina\ninserción de un implante osteointegrado\nextracción del canino incluido\nrestauración protésica'
#   [chunk 7/19 | chars 1299-1430]
#   RAW: 'tratamiento ortodóncico'
#   [chunk 8/19 | chars 1431-1532]
#   RAW: 'extracción del canino incluido\ninserción de un implante'
#   [chunk 9/19 | chars 1533-1641]
#   RAW: 'anestesia local\nse levantó un colgajo mucoperióstico por palatino'
#   [chunk 10/19 | chars 1642-1757]
#   RAW: 'osteotomía\nodontosección del diente\ndiente, su extracción\nlegrado del lecho'
#   [chunk 11/19 | chars 1758-1869]
#   RAW: 'se levantó un colgajo mucoperióstico vestibular'
#   [chunk 12/19 | chars 1870-2072]
#   RAW: 'Se colocó un implante cilíndrico de hidroxiapatita de 3,25 mm de diámetro y 15 mm de longitud, procurando el anclaje crestal hasta el suelo de las fosas nasales'
#   [chunk 13/19 | chars 2073-2213]
#   RAW: 'Se colocó una membrana reabsorbible de colágeno\nregeneración ósea guiada del defecto con hueso de banco desmineralizado'
#   [chunk 14/19 | chars 2214-2374]
#   RAW: 'se insertaron de forma convencional implantes en la posición del segundo premolar superior derecho y primer molar inferior izquierdo'
#   [chunk 15/19 | chars 2375-2429]
#   RAW: ''
#   [chunk 16/19 | chars 2429-2566]
#   RAW: 'colocación del pilar transepitelial'
#   [chunk 17/19 | chars 2567-2649]
#   RAW: 'reconstrucción protésica se realizó con una corona implantosoportada cementada'
#   [chunk 18/19 | chars 2650-2760]
#   RAW: 'ortodoncia'
#   [chunk 19/19 | chars 2761-2920]
#   RAW: ''
# [239/250] es-S1699-65852007000300003-1.txt | 98.64s | 19 chunks | 26 menciones
#   [chunk 1/24 | chars 0-207]
#   RAW: ''
#   [chunk 2/24 | chars 208-373]
#   RAW: ''
#   [chunk 3/24 | chars 374-466]
#   RAW: ''
#   [chunk 4/24 | chars 467-515]
#   RAW: ''
#   [chunk 5/24 | chars 516-556]
#   RAW: ''
#   [chunk 6/24 | chars 556-720]
#   RAW: 'exploración física de ambas muñecas'
#   [chunk 7/24 | chars 721-800]
#   RAW: ''
#   [chunk 8/24 | chars 800-876]
#   RAW: 'balance articular (BA) de las muñecas'
#   [chunk 9/24 | chars 877-897]
#   RAW: ''
#   [chunk 10/24 | chars 898-921]
#   RAW: ''
#   [chunk 11/24 | chars 922-946]
#   RAW: ''
#   [chunk 12/24 | chars 947-985]
#   RAW: ''
#   [chunk 13/24 | chars 986-1007]
#   RAW: ''
#   [chunk 14/24 | chars 1007-1136]
#   RAW: 'palpación a nivel de la articulación radio-carpiana distal\npalpación de la cabeza del radio'
#   [chunk 15/24 | chars 1137-1168]
#   RAW: 'BA de codo completo'
#   [chunk 16/24 | chars 1169-1233]
#   RAW: 'balance muscular (BM) flexo-extensión de las muñecas'
#   [chunk 17/24 | chars 1233-1281]
#   RAW: ''
#   [chunk 18/24 | chars 1282-1322]
#   RAW: ''
#   [chunk 19/24 | chars 1323-1431]
#   RAW: ''
#   [chunk 20/24 | chars 1432-1514]
#   RAW: 'signo de Tinnel\nsigno de Phalen'
#   [chunk 21/24 | chars 1514-1626]
#   RAW: 'radiografía anteroposterior y lateral de ambas muñecas'
#   [chunk 22/24 | chars 1626-1846]
#   RAW: 'radiografía'
#   [chunk 23/24 | chars 1846-1991]
#   RAW: 'tratamiento quirúrgico de reconstrucción del carpo\nRehabilitación'
#   [chunk 24/24 | chars 1992-2144]
#   RAW: 'férula posicional bilateral nocturna\nfisioterapia\ntonificación musculatura intrínseca de mano\nelectroterapia analgésica'
# [240/250] es-S1699-695X2015000200010-1.txt | 66.83s | 24 chunks | 16 menciones
#   [chunk 1/18 | chars 0-157]
#   RAW: ''
#   [chunk 2/18 | chars 158-245]
#   RAW: ''
#   [chunk 3/18 | chars 246-338]
#   RAW: ''
#   [chunk 4/18 | chars 339-432]
#   RAW: ''
#   [chunk 5/18 | chars 433-612]
#   RAW: ''
#   [chunk 6/18 | chars 612-737]
#   RAW: 'exploración física'
#   [chunk 7/18 | chars 738-798]
#   RAW: ''
#   [chunk 8/18 | chars 799-885]
#   RAW: ''
#   [chunk 9/18 | chars 886-938]
#   RAW: ''
#   [chunk 10/18 | chars 939-1073]
#   RAW: 'palpación'
#   [chunk 11/18 | chars 1074-1370]
#   RAW: 'analítica'
#   [chunk 12/18 | chars 1371-1489]
#   RAW: ''
#   [chunk 13/18 | chars 1490-1884]
#   RAW: 'estudio hormonal'
#   [chunk 14/18 | chars 1885-1976]
#   RAW: ''
#   [chunk 15/18 | chars 1977-2140]
#   RAW: 'gammagrafía tiroidea'
#   [chunk 16/18 | chars 2141-2226]
#   RAW: ''
#   [chunk 17/18 | chars 2227-2475]
#   RAW: ''
#   [chunk 18/18 | chars 2476-2661]
#   RAW: 'función tiroidea'
# [241/250] es-S1699-695X2015000300013-1.txt | 30.24s | 18 chunks | 6 menciones
#   [chunk 1/17 | chars 0-186]
#   RAW: ''
#   [chunk 2/17 | chars 187-277]
#   RAW: 'cesáreas'
#   [chunk 3/17 | chars 278-624]
#   RAW: 'exploración abdominal\nlaparotomía media infraumbilical\npalpación'
#   [chunk 4/17 | chars 625-667]
#   RAW: ''
#   [chunk 5/17 | chars 667-838]
#   RAW: 'análisis de sangre'
#   [chunk 6/17 | chars 839-939]
#   RAW: 'radiografía simple de abdomen'
#   [chunk 7/17 | chars 940-1072]
#   RAW: 'TAC'
#   [chunk 8/17 | chars 1072-1396]
#   RAW: 'laparoscópia exploradora'
#   [chunk 9/17 | chars 1397-1846]
#   RAW: 'anestesia general\nlaparoscópia exploradora'
#   [chunk 10/17 | chars 1847-2323]
#   RAW: ''
#   [chunk 11/17 | chars 2324-2480]
#   RAW: 'laparoscópia'
#   [chunk 12/17 | chars 2481-2686]
#   RAW: 'cirugía abierta'
#   [chunk 13/17 | chars 2687-2916]
#   RAW: 'laparotomía infraumbilical'
#   [chunk 14/17 | chars 2917-3052]
#   RAW: 'reducción de la hernia\nresección de 25 cm de ileon necrosado\nreconstrucción con anastomosis termino-terminal manual'
#   [chunk 15/17 | chars 3053-3134]
#   RAW: 'Sobre el orificio herniario se realiza el cierre con sutura continua de seda 0/0'
#   [chunk 16/17 | chars 3135-3259]
#   RAW: ''
#   [chunk 17/17 | chars 3260-3307]
#   RAW: ''
# [242/250] es-S1887-85712012000400006-1.txt | 54.58s | 17 chunks | 17 menciones
#   [chunk 1/13 | chars 0-274]
#   RAW: ''
#   [chunk 2/13 | chars 275-356]
#   RAW: ''
#   [chunk 3/13 | chars 356-532]
#   RAW: ''
#   [chunk 4/13 | chars 532-751]
#   RAW: 'exploración'
#   [chunk 5/13 | chars 752-797]
#   RAW: ''
#   [chunk 6/13 | chars 798-911]
#   RAW: ''
#   [chunk 7/13 | chars 912-1000]
#   RAW: ''
#   [chunk 8/13 | chars 1000-1343]
#   RAW: 'hemograma\nbioquímica\nestudio de coagulación\nradiografía simple de tórax\nelectrocardiograma\ntomografía computerizada (TC) craneal\nTC'
#   [chunk 9/13 | chars 1343-1492]
#   RAW: 'oclusión monocular alternante'
#   [chunk 10/13 | chars 1492-1824]
#   RAW: 'RM encefálica\nresonancia Philips de 1,5 T'
#   [chunk 11/13 | chars 1825-1931]
#   RAW: 'secuencias Flair\nDifusión'
#   [chunk 12/13 | chars 1931-2108]
#   RAW: 'anticogulación oral'
#   [chunk 13/13 | chars 2109-2269]
#   RAW: 'tratamiento rehabilitador'
# [243/250] es-S1887-85712014000100005-1.txt | 38.84s | 13 chunks | 15 menciones
#   [chunk 1/21 | chars 0-234]
#   RAW: 'radioterapia\ncirugía\nquimioterapia'
#   [chunk 2/21 | chars 235-357]
#   RAW: 'analgésicos opioides'
#   [chunk 3/21 | chars 357-745]
#   RAW: 'Intervención Coronaria Percutánea primaria por vía radial derecha\ncolocación de dos stents'
#   [chunk 4/21 | chars 746-996]
#   RAW: 'punción de cateterismo'
#   [chunk 5/21 | chars 996-1242]
#   RAW: 'exploración'
#   [chunk 6/21 | chars 1242-1253]
#   RAW: ''
#   [chunk 7/21 | chars 1253-1307]
#   RAW: ''
#   [chunk 8/21 | chars 1307-1373]
#   RAW: ''
#   [chunk 9/21 | chars 1373-1425]
#   RAW: 'Anestesia\nparálisis total del miembro'
#   [chunk 10/21 | chars 1425-1655]
#   RAW: 'medición de la presión intracompartimental con "Intra-Compartmental pressure monitor system"'
#   [chunk 11/21 | chars 1656-1783]
#   RAW: 'tratamiento quirúrgico'
#   [chunk 12/21 | chars 1783-1906]
#   RAW: 'procedimiento quirúrgico\nanestesia general\ncontrol de la vía aérea con mascarilla laríngea'
#   [chunk 13/21 | chars 1907-1969]
#   RAW: 'Profilaxis antibiótica'
#   [chunk 14/21 | chars 1970-2110]
#   RAW: 'incisión cutánea sobre línea media de cara volar de antebrazo, desde la flexura de codo hasta la línea de Kaplan'
#   [chunk 15/21 | chars 2111-2191]
#   RAW: ''
#   [chunk 16/21 | chars 2192-2410]
#   RAW: 'Se realizó una sección longitudinal de la fascia antebraquial\nse realizó una descompresión del nervio mediano mediante sección del ligamento anular del carpo'
#   [chunk 17/21 | chars 2411-2487]
#   RAW: ''
#   [chunk 18/21 | chars 2488-2733]
#   RAW: 'cierre quirúrgico\ncubrir la herida con compresas estériles impregnadas en Nitrofural\ncierre de circunstancias mediante malla con elásticos vasculares (vessel loops) de contención\nvendaje no compresivo'
#   [chunk 19/21 | chars 2733-2900]
#   RAW: 'fasciotomía'
#   [chunk 20/21 | chars 2901-3087]
#   RAW: 'cirugía'
#   [chunk 21/21 | chars 3088-3211]
#   RAW: ''
# [244/250] es-S1887-85712016000100005-1.txt | 91.31s | 21 chunks | 25 menciones
#   [chunk 1/22 | chars 0-127]
#   RAW: ''
#   [chunk 2/22 | chars 128-229]
#   RAW: ''
#   [chunk 3/22 | chars 230-429]
#   RAW: ''
#   [chunk 4/22 | chars 430-528]
#   RAW: ''
#   [chunk 5/22 | chars 528-725]
#   RAW: 'exploración física\npalpación en tercio medio de la región inguinal derecha\nmaniobra de choque'
#   [chunk 6/22 | chars 726-884]
#   RAW: 'balance articular de caderas'
#   [chunk 7/22 | chars 885-956]
#   RAW: 'balance muscular en la escala de Daniels'
#   [chunk 8/22 | chars 957-1077]
#   RAW: 'palpación de puntos ciáticos\nmaniobras de Valleix, Fabere, Lasegue y Bragard'
#   [chunk 9/22 | chars 1078-1172]
#   RAW: 'palpación en la cintilla iliotibial\ntest de Ober'
#   [chunk 10/22 | chars 1173-1326]
#   RAW: 'exploración de la marcha'
#   [chunk 11/22 | chars 1327-1397]
#   RAW: ''
#   [chunk 12/22 | chars 1398-1528]
#   RAW: 'radiología simple anteroposterior (AP)'
#   [chunk 13/22 | chars 1529-1652]
#   RAW: 'analítica\nhemograma\nbioquímica\nhormonas tiroideas\nanticuerpos\nreactantes de fase aguda'
#   [chunk 14/22 | chars 1652-1908]
#   RAW: 'resonancia magnética de cadera'
#   [chunk 15/22 | chars 1909-1992]
#   RAW: ''
#   [chunk 16/22 | chars 1993-2260]
#   RAW: 'artrografía'
#   [chunk 17/22 | chars 2261-2321]
#   RAW: ''
#   [chunk 18/22 | chars 2322-2412]
#   RAW: ''
#   [chunk 19/22 | chars 2412-2639]
#   RAW: 'magnetoterapia'
#   [chunk 20/22 | chars 2640-2840]
#   RAW: 'tratamiento farmacológico\nantiinflamatorios no esteroideos'
#   [chunk 21/22 | chars 2841-3040]
#   RAW: ''
#   [chunk 22/22 | chars 3040-3146]
#   RAW: 'artroscopia\ncirugía artroscópica'
# [245/250] es-S1888-75462015000400006-1.txt | 72.35s | 22 chunks | 24 menciones
#   [chunk 1/7 | chars 0-348]
#   RAW: ''
#   [chunk 2/7 | chars 348-577]
#   RAW: ''
#   [chunk 3/7 | chars 578-865]
#   RAW: 'estudio radiológico simple\ntomografía axial computarizada'
#   [chunk 4/7 | chars 865-1387]
#   RAW: 'analgesia\nantiinflamatorios no esteroideos\ncolocación de vendaje en ocho\nauscultación cardiorrespiratoria'
#   [chunk 5/7 | chars 1387-1636]
#   RAW: 'espirometría\nelectrocardiograma\necocardiograma\nanalítica sanguínea'
#   [chunk 6/7 | chars 1637-1845]
#   RAW: 'eco-Doppler venoso'
#   [chunk 7/7 | chars 1845-2190]
#   RAW: 'Se sustituyó el vendaje en ocho por cabestrillo sencillo\nrehabilitación funcional\nradiografías\nutrasonografía-Doppler\nrecanalización completa de las venas trombosadas'
# [246/250] es-S1888-75462016000400180-1.txt | 39.51s | 7 chunks | 16 menciones
#   [chunk 1/20 | chars 0-47]
#   RAW: ''
#   [chunk 2/20 | chars 48-140]
#   RAW: 'histerectomía'
#   [chunk 3/20 | chars 141-448]
#   RAW: ''
#   [chunk 4/20 | chars 449-629]
#   RAW: 'AINEs'
#   [chunk 5/20 | chars 630-736]
#   RAW: 'exploración'
#   [chunk 6/20 | chars 737-790]
#   RAW: ''
#   [chunk 7/20 | chars 791-861]
#   RAW: 'Rx de pies'
#   [chunk 8/20 | chars 862-995]
#   RAW: 'RMN de pie izquierdo'
#   [chunk 9/20 | chars 996-1240]
#   RAW: 'estudio analítico'
#   [chunk 10/20 | chars 1241-1311]
#   RAW: ''
#   [chunk 11/20 | chars 1312-1467]
#   RAW: 'descarga\nreposo relativo\nAINEs\nmagnetoterapia'
#   [chunk 12/20 | chars 1468-1850]
#   RAW: 'SERMS\nsuplementos de calcio con vitamina D'
#   [chunk 13/20 | chars 1851-1968]
#   RAW: 'Rx'
#   [chunk 14/20 | chars 1969-2142]
#   RAW: 'RMN de pie izquierdo'
#   [chunk 15/20 | chars 2143-2234]
#   RAW: 'densitometría ósea'
#   [chunk 16/20 | chars 2235-2436]
#   RAW: ''
#   [chunk 17/20 | chars 2437-2522]
#   RAW: 'rehabilitación y descarga'
#   [chunk 18/20 | chars 2522-2705]
#   RAW: ''
#   [chunk 19/20 | chars 2706-2869]
#   RAW: ''
#   [chunk 20/20 | chars 2870-3148]
#   RAW: ''
# [247/250] es-S1889-836X2015000200005-2.txt | 44.19s | 20 chunks | 16 menciones
#   [chunk 1/16 | chars 0-157]
#   RAW: ''
#   [chunk 2/16 | chars 158-268]
#   RAW: ''
#   [chunk 3/16 | chars 269-407]
#   RAW: ''
#   [chunk 4/16 | chars 408-569]
#   RAW: 'elemental y sedimento de orina'
#   [chunk 5/16 | chars 570-697]
#   RAW: 'radiografía simple de columna\ngammagrafía con Tc99'
#   [chunk 6/16 | chars 697-865]
#   RAW: ''
#   [chunk 7/16 | chars 866-953]
#   RAW: 'exploración física'
#   [chunk 8/16 | chars 954-1201]
#   RAW: ''
#   [chunk 9/16 | chars 1202-1315]
#   RAW: ''
#   [chunk 10/16 | chars 1316-1347]
#   RAW: ''
#   [chunk 11/16 | chars 1348-1392]
#   RAW: ''
#   [chunk 12/16 | chars 1392-1553]
#   RAW: ''
#   [chunk 13/16 | chars 1554-1655]
#   RAW: ''
#   [chunk 14/16 | chars 1656-1750]
#   RAW: ''
#   [chunk 15/16 | chars 1751-1800]
#   RAW: ''
#   [chunk 16/16 | chars 1801-2071]
#   RAW: ''
# [248/250] es-S1889-836X2015000400006-1.txt | 28.19s | 16 chunks | 4 menciones
#   [chunk 1/40 | chars 0-205]
#   RAW: ''
#   [chunk 2/40 | chars 206-230]
#   RAW: ''
#   [chunk 3/40 | chars 231-246]
#   RAW: 'Apendicectomía'
#   [chunk 4/40 | chars 247-276]
#   RAW: ''
#   [chunk 5/40 | chars 277-289]
#   RAW: ''
#   [chunk 6/40 | chars 290-360]
#   RAW: ''
#   [chunk 7/40 | chars 361-399]
#   RAW: 'partos'
#   [chunk 8/40 | chars 400-440]
#   RAW: 'Cesárea\nligadura de trompas'
#   [chunk 9/40 | chars 440-603]
#   RAW: ''
#   [chunk 10/40 | chars 604-651]
#   RAW: ''
#   [chunk 11/40 | chars 652-697]
#   RAW: ''
#   [chunk 12/40 | chars 698-725]
#   RAW: ''
#   [chunk 13/40 | chars 725-825]
#   RAW: 'analítica'
#   [chunk 14/40 | chars 826-889]
#   RAW: 'Frotis sanguíneo'
#   [chunk 15/40 | chars 890-1052]
#   RAW: ''
#   [chunk 16/40 | chars 1052-1126]
#   RAW: 'se transfunde un concentrado de hematíes y otro de plaquetas'
#   [chunk 17/40 | chars 1127-1300]
#   RAW: 'pasar las plaquetas'
#   [chunk 18/40 | chars 1301-1366]
#   RAW: ''
#   [chunk 19/40 | chars 1366-1445]
#   RAW: ''
#   [chunk 20/40 | chars 1445-1584]
#   RAW: 'plasmaféresis'
#   [chunk 21/40 | chars 1585-1649]
#   RAW: ''
#   [chunk 22/40 | chars 1649-1762]
#   RAW: 'sesiones de plasmaféresis'
#   [chunk 23/40 | chars 1762-1838]
#   RAW: ''
#   [chunk 24/40 | chars 1838-1862]
#   RAW: ''
#   [chunk 25/40 | chars 1862-1927]
#   RAW: ''
#   [chunk 26/40 | chars 1928-1987]
#   RAW: ''
#   [chunk 27/40 | chars 1988-2014]
#   RAW: ''
#   [chunk 28/40 | chars 2015-2052]
#   RAW: ''
#   [chunk 29/40 | chars 2053-2101]
#   RAW: 'diálisis peritoneal'
#   [chunk 30/40 | chars 2101-2334]
#   RAW: 'plasmaféresis\nse intenta implantar un catéter en yugular derecha\nse coloca un catéter doble luz en femoral izquierda'
#   [chunk 31/40 | chars 2334-2426]
#   RAW: 'PRISMA CRRT-TPE\nfiltro PTE-2000'
#   [chunk 32/40 | chars 2426-2627]
#   RAW: ''
#   [chunk 33/40 | chars 2628-2709]
#   RAW: ''
#   [chunk 34/40 | chars 2709-2799]
#   RAW: 'sedada'
#   [chunk 35/40 | chars 2800-2842]
#   RAW: ''
#   [chunk 36/40 | chars 2842-2902]
#   RAW: ''
#   [chunk 37/40 | chars 2902-3034]
#   RAW: ''
#   [chunk 38/40 | chars 3034-3125]
#   RAW: ''
#   [chunk 39/40 | chars 3125-3228]
#   RAW: 'test de aire'
#   [chunk 40/40 | chars 3228-3322]
#   RAW: ''
# [249/250] es-S2254-28842014000200009-1.txt | 82.55s | 40 chunks | 18 menciones
#   [chunk 1/11 | chars 0-207]
#   RAW: ''
#   [chunk 2/11 | chars 208-315]
#   RAW: 'quimioterapia adyuvante con carboplatino y paclitaxel'
#   [chunk 3/11 | chars 316-458]
#   RAW: ''
#   [chunk 4/11 | chars 459-661]
#   RAW: 'TAC\nresección anterior de recto superior\nbiopsia intraoperatoria de una lesión hepática'
#   [chunk 5/11 | chars 661-783]
#   RAW: ''
#   [chunk 6/11 | chars 784-1007]
#   RAW: ''
#   [chunk 7/11 | chars 1008-1110]
#   RAW: 'corticoides'
#   [chunk 8/11 | chars 1111-1225]
#   RAW: 'desensibilización'
#   [chunk 9/11 | chars 1226-1678]
#   RAW: 'infusión\nsal de platino'
#   [chunk 10/11 | chars 1678-1796]
#   RAW: 'quimioterapia'
#   [chunk 11/11 | chars 1797-1934]
#   RAW: ''
# [250/250] es-S2340-98942015000100005-1.txt | 29.59s | 11 chunks | 9 menciones
#
# Predicciones guardadas en proctemist_llm_predictions.tsv
# Tiempo medio por archivo: 48.23s

# %% [markdown]
# ## 9. Evaluación
#
# Métrica estricta por coincidencia exacta de offsets y métricas por solapamiento (IoU) a distintos umbrales.

# %%
import json
import pandas as pd


def prf(tp, fp, fn):
    p  = tp / (tp + fp) if (tp + fp) else 0.0
    r  = tp / (tp + fn) if (tp + fn) else 0.0
    f1 = 2 * p * r / (p + r) if (p + r) else 0.0
    return p, r, f1


df_pred  = pd.read_csv(PREDICTIONS_TSV, sep="\t")
df_gs    = pd.read_csv(GS_TEST_TSV, sep="\t")
df_gs    = df_gs[df_gs["filename"].isin(df_pred["filename"].unique())]

set_gs   = set(zip(df_gs["filename"],   df_gs["label"],   df_gs["start_span"],   df_gs["end_span"]))
set_pred = set(zip(df_pred["filename"], df_pred["label"], df_pred["start_span"], df_pred["end_span"]))

tp, fp, fn = len(set_gs & set_pred), len(set_pred - set_gs), len(set_gs - set_pred)
p, r, f1   = prf(tp, fp, fn)

report = {"Estricta": {"tp": tp, "fp": fp, "fn": fn, "precision": round(p, 4), "recall": round(r, 4), "fscore": round(f1, 4)}}

print(f"── ESTRICTA ──  P={p:.4f}  R={r:.4f}  F1={f1:.4f}  (TP={tp} FP={fp} FN={fn})\n")

thresholds = [0.0, 0.5, 0.8]
results    = {t: {"tp": 0, "fp": 0, "fn": 0} for t in thresholds}

for filename in df_pred["filename"].unique():
    gs_ints   = list(zip(df_gs[df_gs["filename"] == filename]["start_span"],   df_gs[df_gs["filename"] == filename]["end_span"]))
    pred_ints = list(zip(df_pred[df_pred["filename"] == filename]["start_span"], df_pred[df_pred["filename"] == filename]["end_span"]))

    iou_matrix = sorted(
        [(max(0, min(p1,g1) - max(p0,g0)) / (max(p1,g1) - min(p0,g0)), pi, gi)
         for pi, (p0, p1) in enumerate(pred_ints)
         for gi, (g0, g1) in enumerate(gs_ints)
         if max(p1,g1) - min(p0,g0) > 0 and min(p1,g1) - max(p0,g0) > 0],
        reverse=True,
    )

    for t in thresholds:
        matched_p, matched_g = set(), set()
        for iou, pi, gi in iou_matrix:
            if iou >= t and pi not in matched_p and gi not in matched_g:
                matched_p.add(pi); matched_g.add(gi)
        tp_t = len(matched_p)
        results[t]["tp"] += tp_t
        results[t]["fp"] += len(pred_ints) - tp_t
        results[t]["fn"] += len(gs_ints)   - tp_t

print("── IoU ──")
for t in thresholds:
    tp_t, fp_t, fn_t = results[t]["tp"], results[t]["fp"], results[t]["fn"]
    p_t, r_t, f1_t   = prf(tp_t, fp_t, fn_t)
    report[f"IoU >= {t}"] = {"tp": tp_t, "fp": fp_t, "fn": fn_t,
                              "precision": round(p_t, 4), "recall": round(r_t, 4), "fscore": round(f1_t, 4)}
    print(f"IoU >= {t}:  P={p_t:.4f}  R={r_t:.4f}  F1={f1_t:.4f}  (TP={tp_t} FP={fp_t} FN={fn_t})")

with open(EVAL_SUMMARY_JSON, "w", encoding="utf-8") as f:
    json.dump(report, f, ensure_ascii=False, indent=2)
# Out:
# ── ESTRICTA ──  P=0.7839  R=0.7971  F1=0.7905  (TP=2884 FP=795 FN=734)
#
# ── IoU ──
# IoU >= 0.0:  P=0.9076  R=0.9226  F1=0.9150  (TP=3339 FP=340 FN=280)
# IoU >= 0.5:  P=0.8540  R=0.8682  F1=0.8611  (TP=3142 FP=537 FN=477)
# IoU >= 0.8:  P=0.7937  R=0.8069  F1=0.8002  (TP=2920 FP=759 FN=699)
